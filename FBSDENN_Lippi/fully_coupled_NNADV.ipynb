# %% [markdown]
# ### Sistema Fully Coupled
# $$
# \begin{cases}
# dS_t =\mu(c-S_t)dt + \sigma_1dW^1_t\\
#
# dH_t = \mu(c-H_t)dt + \sigma_2 dW^2_t\\
#
# dV_t = a(X^2_t+bH_t+c e^{t}(Z^3_t\sigma_3^{-1}-X_t)/2)dt + \sigma_3 dW^3_t\\
#
# dX_t = V_t dt
#
# \end{cases}
# $$

# %% [markdown]
# ### Soluzione
# $$
#     u(t,s,h,v,x) = e^{-t}(e^s + e^{s}h + v^2 + xv)
# $$

# %%
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from abc import ABC, abstractmethod

class FBSNN(ABC): # Forward-Backward Stochastic Neural Network
    def __init__(self, Xi, T,
                       M, N, D,
                       layers):
        
        self.Xi = Xi # initial point
        self.T = T # terminal time
        
        self.M = M # number of trajectories
        self.N = N # number of time snapshots
        self.D = D # number of dimensions
        
        # layers
        self.layers = layers # (D+1) --> 1

        #MODIFICHE LIPPI
        #impostazioni modificabili
        activation = "sin"
        clip_grad_norm = 1.0
        use_antithetic_sampling = True
        path_loss_weight = 1.0
        terminal_y_loss_weight = 10.0
        terminal_z_loss_weight = 1.0

        #importo come parametri del modello
        self.activation = activation
        self.clip_grad_norm = clip_grad_norm
        self.use_antithetic_sampling = use_antithetic_sampling
        self.path_loss_weight = path_loss_weight
        self.terminal_y_loss_weight = terminal_y_loss_weight
        self.terminal_z_loss_weight = terminal_z_loss_weight
        
        # initialize NN
        self.weights, self.biases = self.initialize_NN(layers)
        
        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        # tf placeholders and graph (training)
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.t_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, 1]) # M x (N+1) x 1
        self.W_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, self.D]) # M x (N+1) x D
        self.Xi_tf = tf.placeholder(tf.float32, shape=[1, D]) # 1 x D

        self.loss, self.X_pred, self.Y_pred, self.Y0_pred = self.loss_function(self.t_tf, self.W_tf, self.Xi_tf)
                
        # optimizers
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.learning_rate)
        #self.train_op = self.optimizer.minimize(self.loss)
        #cambiamo il train_op per implementare il clipping
        gradients_and_variables = self.optimizer.compute_gradients(self.loss)
        if self.clip_grad_norm is not None:
            non_null_grads_and_vars = [(g, v) for g, v in gradients_and_variables if g is not None]
            if non_null_grads_and_vars:
                gradients, variables = zip(*non_null_grads_and_vars)
                gradients, _ = tf.clip_by_global_norm(gradients, self.clip_grad_norm)
                clipped = list(zip(gradients, variables))
                untouched = [(g, v) for g, v in gradients_and_variables if g is None]
                gradients_and_variables = clipped + untouched
        self.train_op = self.optimizer.apply_gradients(gradients_and_variables)
                
        # initialize session and variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
    
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases
        
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim],
                                               stddev=xavier_stddev), dtype=tf.float32)
    
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1
        
        H = X
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            pre_activation = tf.add(tf.matmul(H, W), b)
            if self.activation == "sin":
                H = tf.sin(pre_activation)
            elif self.activation == "tanh":
                H = tf.tanh(pre_activation)
            elif self.activation == "swish":
                H = pre_activation * tf.sigmoid(pre_activation)
            else:
                raise ValueError("Unsupported activation '{}'. Use: sin, tanh, swish".format(self.activation))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
    def net_u(self, t, X): # M x 1, M x D
        
        u = self.neural_net(tf.concat([t,X], 1), self.weights, self.biases) # M x 1
        Du = tf.gradients(u, X)[0] # M x D
        
        return u, Du

    def Dg_tf(self, X): # M x D
        return tf.gradients(self.g_tf(X), X)[0] # M x D
        
    def loss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        loss = 0
        X_list = []
        Y_list = []
        
        t0 = t[:,0,:]
        W0 = W[:,0,:]
        X0 = tf.tile(Xi,[self.M,1]) # M x D
        Y0, Z0 = self.net_u(t0,X0) # M x 1, M x D
        
        X_list.append(X0)
        Y_list.append(Y0)
        
        for n in range(0,self.N):
            t1 = t[:,n+1,:]
            W1 = W[:,n+1,:]
            X1 = X0 + self.mu_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.squeeze(tf.matmul(self.sigma_tf(t0,X0,Y0),tf.expand_dims(W1-W0,-1)), axis=[-1])
            Y1_tilde = Y0 + self.phi_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.reduce_sum(Z0*tf.squeeze(tf.matmul(self.sigma_tf(t0,X0,Y0),tf.expand_dims(W1-W0,-1))), axis=1, keepdims = True)
            Y1, Z1 = self.net_u(t1,X1)
            
            loss += self.path_loss_weight * tf.reduce_mean(tf.square(Y1 - Y1_tilde))

            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            
            X_list.append(X0)
            Y_list.append(Y0)
            
        loss += self.terminal_y_loss_weight * tf.reduce_mean(tf.square(Y1 - self.g_tf(X1)))
        loss += self.terminal_z_loss_weight * tf.reduce_mean(tf.square(Z1 - self.Dg_tf(X1)))

        X = tf.stack(X_list,axis=1)
        Y = tf.stack(Y_list,axis=1)
        
        return loss, X, Y, Y[0,0,0]

    def fetch_minibatch(self):
        T = self.T
        
        M = self.M
        N = self.N
        D = self.D
        
        Dt = np.zeros((M,N+1,1)) # M x (N+1) x 1
        DW = np.zeros((M,N+1,D)) # M x (N+1) x D
        
        dt = T/N
        
        Dt[:,1:,:] = dt
        if self.use_antithetic_sampling and M > 1:
            half_M = M // 2
            DW_half = np.sqrt(dt) * np.random.normal(size=(half_M, N, D))
            DW[:half_M,1:, :] = DW_half
            DW[half_M:2*half_M,1:, :] = -DW_half
            if M % 2 == 1:
                DW[-1,1:, :] = np.sqrt(dt) * np.random.normal(size=(N, D))
        else:
            DW[:,1:, :] = np.sqrt(dt)*np.random.normal(size=(M,N,D))
       
        t = np.cumsum(Dt,axis=1) # M x (N+1) x 1
        W = np.cumsum(DW,axis=1) # M x (N+1) x D
        
        return t, W
    
    def train(self, N_Iter, learning_rate):
        
        start_time = time.time()
        for it in range(N_Iter):
            
            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D
            
            tf_dict = {self.Xi_tf: self.Xi, self.t_tf: t_batch, self.W_tf: W_batch, self.learning_rate: learning_rate}
            
            self.sess.run(self.train_op, tf_dict)
            
            # Print
            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.loss, self.Y0_pred, self.learning_rate], tf_dict)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' % 
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()
                
    
    def predict(self, Xi_star, t_star, W_star):
        
        tf_dict = {self.Xi_tf: Xi_star, self.t_tf: t_star, self.W_tf: W_star}
        
        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        
        return X_star, Y_star
    
    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def phi_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        pass # M x1
    
    @abstractmethod
    def g_tf(self, X): # M x D
        pass # M x 1
    
    @abstractmethod
    def mu_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return np.zeros([M,D]) # M x D
    
    @abstractmethod
    def sigma_tf(self, t, X, Y): # M x 1, M x D, M x 1
        M = self.M
        D = self.D
        return tf.matrix_diag(tf.ones([M,D])) # M x D x D
    ###########################################################################
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class NN(FBSNN):
    def __init__(self, Xi, T, M, N, D, layers, parameters):
        self.mu = parameters['mu']
        self.c = parameters['c']
        self.b = parameters['b']
        self.a = parameters['a']
        self.s1 = parameters['s1']
        self.s2 = parameters['s2']
        self.s3 = parameters['s3']
        super().__init__(Xi, T, M, N, D, layers)
    
    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu = tf.cast(self.mu, tf.float32)
        c = tf.cast(self.c, tf.float32)
        a = tf.cast(self.a, tf.float32)
        b = tf.cast(self.b, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        #Accoppiamento
        #Z ha dimensione [M, D]. Le colonne sono nella forma
        #[Z_S, Z_H, Z_V, Z_X]
        Z_V = Z[:, 2:3]
        exp_t = tf.exp(t)
        V_from_Z = 0.5 * ((exp_t * Z_V / s3) - X_state)
        dS = mu * (c - S)
        dH = mu * (c - H)
        dV = self.a * (X_state**2 + b*H + c*V_from_Z)
        dX = V
        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        exp_T = tf.exp(-self.T)
        exp_S = tf.exp(S)
        val = exp_S + (exp_S * H) + (V**2) + (X_state*V)
        return exp_T * val

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        
        mu = tf.cast(self.mu, tf.float32)
        c = tf.cast(self.c, tf.float32)
        a = tf.cast(self.a, tf.float32)
        b = tf.cast(self.b, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        
        exp_t = tf.exp(-t)
        exp_S = tf.exp(S)

        term1 = (1.0 + H) * (mu * (c - S) * exp_S)
        term2 = mu * (c - H) * exp_S
        term3 = (2.0 * V + X_state) * (a * (X_state**2 + b * H + c * V))
        term4 = V**2 + s3**2
        term5 = 0.5 * exp_S * (s1**2) * (1.0 + H)
        
        equation = term1 + term2 + term3 + term4 + term5
        equation = tf.cast(equation, tf.float32)
        
        return -(Y - (exp_t * equation))
    
    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)

        return tf.stack([r1, r2, r3, r4], axis=1)

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    M = 1024      
    N = 200      
    D = 4
    T = 1.0

    params = {
        'mu': np.float32(1.0),
        'c': np.float32(1.0),
        'b': np.float32(1.0),
        'a': np.float32(1.0),
        's1': np.float32(0.5),
        's2': np.float32(0.5),
        's3': np.float32(0.5),        
    }

    Xi = np.array([1.5, 0.5, 0.5, 0.5]).reshape(1, D)
    
    layers = [D+1] + 4*[256] + [1]
    
    model = NN(Xi, T, M, N, D, layers, params)

    print("===WARMUP===")
    model.train(N_Iter = 500, learning_rate=1e-4)
    
    print("=== Avvio training (High Precision) ===")
    # Strategia di training a step
    model.train(N_Iter = 3000, learning_rate = 1e-3)
    model.train(N_Iter = 5000, learning_rate = 1e-4)
    model.train(N_Iter = 5000, learning_rate = 1e-5) 
    model.train(N_Iter = 3000, learning_rate = 1e-6) 

    # --- PLOTTING ---
    t_test, W_test = model.fetch_minibatch()
    X_pred, Y_pred = model.predict(Xi, t_test, W_test)

    def u_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X = Xi_arr[:, 3:4]
        # u = e^-t * (e^S + e^S*H + V^2 + X*V)
        return np.exp(-t) * (np.exp(S) + np.exp(S)*H + V**2 + X*V)
    
    Xi_reshaped = X_pred.reshape(-1, D)
    t_reshaped = t_test.reshape(-1, 1)
    
    # Calcolo soluzione esatta sui punti predetti
    Y_exact = u_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, 1)
    
    exact_Y0 = u_exact(np.array([[0.0]]), Xi)[0,0]
    print(f"\nPredicted Y0: {Y_pred[0,0,0]:.4f}")
    print(f"Exact Y0:     {exact_Y0:.4f}")
    
    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], Y_pred[0,:,0], 'b', label='Learned Y')
    plt.plot(t_test[0,:,0], Y_exact[0,:,0], 'r--', label='Exact Y')
    # Plot di altre traiettorie per vedere la varianza
    plt.plot(t_test[1:5,:,0].T, Y_pred[1:5,:,0].T, 'b')
    plt.plot(t_test[1:5,:,0].T, Y_exact[1:5,:,0].T, 'r--')
    plt.title("Soluzione Full-coupled 4D")
    plt.xlabel("Tempo t")
    plt.ylabel("Y_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
#
# ===WARMUP===
# It: 0, Loss: 2.175e+02, Y0: 0.012, Time: 61.84, Learning Rate: 1.000e-04
# It: 10, Loss: 7.488e+01, Y0: 0.430, Time: 3.52, Learning Rate: 1.000e-04
# It: 20, Loss: 1.046e+01, Y0: 1.033, Time: 3.50, Learning Rate: 1.000e-04
# It: 30, Loss: 1.095e+01, Y0: 1.264, Time: 3.50, Learning Rate: 1.000e-04
# It: 40, Loss: 8.650e+00, Y0: 1.151, Time: 3.50, Learning Rate: 1.000e-04
# It: 50, Loss: 6.238e+00, Y0: 1.557, Time: 3.51, Learning Rate: 1.000e-04
# It: 60, Loss: 4.571e+00, Y0: 1.955, Time: 3.49, Learning Rate: 1.000e-04
# It: 70, Loss: 3.285e+00, Y0: 2.427, Time: 3.50, Learning Rate: 1.000e-04
# It: 80, Loss: 2.053e+00, Y0: 3.078, Time: 3.55, Learning Rate: 1.000e-04
# It: 90, Loss: 1.548e+00, Y0: 3.088, Time: 3.48, Learning Rate: 1.000e-04
# It: 100, Loss: 1.488e+00, Y0: 2.720, Time: 3.48, Learning Rate: 1.000e-04
# It: 110, Loss: 1.697e+00, Y0: 2.470, Time: 3.52, Learning Rate: 1.000e-04
# It: 120, Loss: 1.314e+00, Y0: 2.479, Time: 3.50, Learning Rate: 1.000e-04
# It: 130, Loss: 1.280e+00, Y0: 2.601, Time: 3.48, Learning Rate: 1.000e-04
# It: 140, Loss: 1.412e+00, Y0: 2.621, Time: 3.48, Learning Rate: 1.000e-04
# It: 150, Loss: 1.367e+00, Y0: 2.658, Time: 3.50, Learning Rate: 1.000e-04
# It: 160, Loss: 1.252e+00, Y0: 2.713, Time: 3.49, Learning Rate: 1.000e-04
# It: 170, Loss: 1.175e+00, Y0: 2.885, Time: 3.50, Learning Rate: 1.000e-04
# It: 180, Loss: 1.174e+00, Y0: 2.887, Time: 3.50, Learning Rate: 1.000e-04
# It: 190, Loss: 1.003e+00, Y0: 2.955, Time: 3.50, Learning Rate: 1.000e-04
# It: 200, Loss: 9.217e-01, Y0: 3.033, Time: 3.52, Learning Rate: 1.000e-04
# It: 210, Loss: 8.581e-01, Y0: 3.098, Time: 3.51, Learning Rate: 1.000e-04
# It: 220, Loss: 1.234e+00, Y0: 3.146, Time: 3.51, Learning Rate: 1.000e-04
# It: 230, Loss: 8.377e-01, Y0: 3.174, Time: 3.55, Learning Rate: 1.000e-04
# It: 240, Loss: 9.438e-01, Y0: 3.173, Time: 3.48, Learning Rate: 1.000e-04
# It: 250, Loss: 1.102e+00, Y0: 3.264, Time: 3.54, Learning Rate: 1.000e-04
# It: 260, Loss: 1.052e+00, Y0: 3.223, Time: 3.48, Learning Rate: 1.000e-04
# It: 270, Loss: 6.816e-01, Y0: 3.281, Time: 3.48, Learning Rate: 1.000e-04
# It: 280, Loss: 7.406e-01, Y0: 3.349, Time: 3.47, Learning Rate: 1.000e-04
# It: 290, Loss: 6.791e-01, Y0: 3.424, Time: 3.52, Learning Rate: 1.000e-04
# It: 300, Loss: 5.609e-01, Y0: 3.492, Time: 3.50, Learning Rate: 1.000e-04
# It: 310, Loss: 5.037e-01, Y0: 3.423, Time: 3.48, Learning Rate: 1.000e-04
# It: 320, Loss: 5.757e-01, Y0: 3.325, Time: 3.46, Learning Rate: 1.000e-04
# It: 330, Loss: 6.236e-01, Y0: 3.309, Time: 3.53, Learning Rate: 1.000e-04
# It: 340, Loss: 4.992e-01, Y0: 3.351, Time: 3.49, Learning Rate: 1.000e-04
# It: 350, Loss: 4.936e-01, Y0: 3.478, Time: 3.48, Learning Rate: 1.000e-04
# It: 360, Loss: 4.846e-01, Y0: 3.554, Time: 3.48, Learning Rate: 1.000e-04
# It: 370, Loss: 4.366e-01, Y0: 3.614, Time: 3.47, Learning Rate: 1.000e-04
# It: 380, Loss: 5.028e-01, Y0: 3.701, Time: 3.48, Learning Rate: 1.000e-04
# It: 390, Loss: 4.392e-01, Y0: 3.754, Time: 3.49, Learning Rate: 1.000e-04
# It: 400, Loss: 6.941e-01, Y0: 3.768, Time: 3.47, Learning Rate: 1.000e-04
# It: 410, Loss: 3.930e-01, Y0: 3.753, Time: 3.49, Learning Rate: 1.000e-04
# It: 420, Loss: 5.036e-01, Y0: 3.803, Time: 3.50, Learning Rate: 1.000e-04
# It: 430, Loss: 4.679e-01, Y0: 3.808, Time: 3.47, Learning Rate: 1.000e-04
# It: 440, Loss: 5.193e-01, Y0: 3.819, Time: 3.46, Learning Rate: 1.000e-04
# It: 450, Loss: 4.784e-01, Y0: 3.873, Time: 3.47, Learning Rate: 1.000e-04
# It: 460, Loss: 5.527e-01, Y0: 3.929, Time: 3.46, Learning Rate: 1.000e-04
# It: 470, Loss: 4.508e-01, Y0: 3.874, Time: 3.49, Learning Rate: 1.000e-04
# It: 480, Loss: 5.215e-01, Y0: 4.003, Time: 3.48, Learning Rate: 1.000e-04
# It: 490, Loss: 4.128e-01, Y0: 3.963, Time: 3.50, Learning Rate: 1.000e-04
# === Avvio training (High Precision) ===
# It: 0, Loss: 1.442e+00, Y0: 4.047, Time: 0.34, Learning Rate: 1.000e-03
# It: 10, Loss: 1.011e+00, Y0: 4.112, Time: 3.49, Learning Rate: 1.000e-03
# It: 20, Loss: 4.427e-01, Y0: 4.370, Time: 3.52, Learning Rate: 1.000e-03
# It: 30, Loss: 9.155e-01, Y0: 4.405, Time: 3.47, Learning Rate: 1.000e-03
# It: 40, Loss: 4.650e-01, Y0: 4.320, Time: 3.50, Learning Rate: 1.000e-03
# It: 50, Loss: 9.038e-01, Y0: 4.306, Time: 3.53, Learning Rate: 1.000e-03
# It: 60, Loss: 3.739e-01, Y0: 4.256, Time: 3.48, Learning Rate: 1.000e-03
# It: 70, Loss: 7.074e-01, Y0: 4.348, Time: 3.47, Learning Rate: 1.000e-03
# It: 80, Loss: 4.798e-01, Y0: 4.351, Time: 3.51, Learning Rate: 1.000e-03
# It: 90, Loss: 4.754e-01, Y0: 4.358, Time: 3.48, Learning Rate: 1.000e-03
# It: 100, Loss: 4.578e-01, Y0: 4.387, Time: 3.48, Learning Rate: 1.000e-03
# It: 110, Loss: 5.146e-01, Y0: 4.393, Time: 3.50, Learning Rate: 1.000e-03
# It: 120, Loss: 3.498e-01, Y0: 4.426, Time: 3.50, Learning Rate: 1.000e-03
# It: 130, Loss: 5.887e-01, Y0: 4.471, Time: 3.46, Learning Rate: 1.000e-03
# It: 140, Loss: 2.690e-01, Y0: 4.553, Time: 3.51, Learning Rate: 1.000e-03
# It: 150, Loss: 7.887e-01, Y0: 4.693, Time: 3.49, Learning Rate: 1.000e-03
# It: 160, Loss: 1.127e+00, Y0: 4.415, Time: 3.52, Learning Rate: 1.000e-03
# It: 170, Loss: 2.846e-01, Y0: 4.608, Time: 3.50, Learning Rate: 1.000e-03
# It: 180, Loss: 7.960e-01, Y0: 4.765, Time: 3.48, Learning Rate: 1.000e-03
# It: 190, Loss: 5.641e-01, Y0: 4.368, Time: 3.48, Learning Rate: 1.000e-03
# It: 200, Loss: 4.755e-01, Y0: 4.702, Time: 3.48, Learning Rate: 1.000e-03
# It: 210, Loss: 6.158e-01, Y0: 4.623, Time: 3.49, Learning Rate: 1.000e-03
# It: 220, Loss: 6.956e-01, Y0: 4.606, Time: 3.48, Learning Rate: 1.000e-03
# It: 230, Loss: 3.744e-01, Y0: 4.807, Time: 3.51, Learning Rate: 1.000e-03
# It: 240, Loss: 4.790e-01, Y0: 4.842, Time: 3.50, Learning Rate: 1.000e-03
# It: 250, Loss: 5.919e-01, Y0: 4.813, Time: 3.50, Learning Rate: 1.000e-03
# It: 260, Loss: 3.586e-01, Y0: 5.028, Time: 3.51, Learning Rate: 1.000e-03
# It: 270, Loss: 4.944e-01, Y0: 5.144, Time: 3.51, Learning Rate: 1.000e-03
# It: 280, Loss: 5.140e-01, Y0: 5.166, Time: 3.47, Learning Rate: 1.000e-03
# It: 290, Loss: 4.046e-01, Y0: 5.328, Time: 3.51, Learning Rate: 1.000e-03
# It: 300, Loss: 4.331e-01, Y0: 5.409, Time: 3.56, Learning Rate: 1.000e-03
# It: 310, Loss: 5.298e-01, Y0: 5.286, Time: 3.49, Learning Rate: 1.000e-03
# It: 320, Loss: 2.840e-01, Y0: 5.432, Time: 3.48, Learning Rate: 1.000e-03
# It: 330, Loss: 3.694e-01, Y0: 5.467, Time: 3.49, Learning Rate: 1.000e-03
# It: 340, Loss: 4.971e-01, Y0: 5.376, Time: 3.47, Learning Rate: 1.000e-03
# It: 350, Loss: 3.036e-01, Y0: 5.518, Time: 3.49, Learning Rate: 1.000e-03
# It: 360, Loss: 3.572e-01, Y0: 5.637, Time: 3.54, Learning Rate: 1.000e-03
# It: 370, Loss: 4.563e-01, Y0: 5.495, Time: 3.51, Learning Rate: 1.000e-03
# It: 380, Loss: 2.952e-01, Y0: 5.623, Time: 3.51, Learning Rate: 1.000e-03
# It: 390, Loss: 3.139e-01, Y0: 5.625, Time: 3.53, Learning Rate: 1.000e-03
# It: 400, Loss: 4.182e-01, Y0: 5.485, Time: 3.48, Learning Rate: 1.000e-03
# It: 410, Loss: 2.775e-01, Y0: 5.667, Time: 3.48, Learning Rate: 1.000e-03
# It: 420, Loss: 3.172e-01, Y0: 5.672, Time: 3.50, Learning Rate: 1.000e-03
# It: 430, Loss: 4.135e-01, Y0: 5.544, Time: 3.47, Learning Rate: 1.000e-03
# It: 440, Loss: 2.656e-01, Y0: 5.666, Time: 3.49, Learning Rate: 1.000e-03
# It: 450, Loss: 3.787e-01, Y0: 5.758, Time: 3.51, Learning Rate: 1.000e-03
# It: 460, Loss: 3.665e-01, Y0: 5.577, Time: 3.49, Learning Rate: 1.000e-03
# It: 470, Loss: 1.552e-01, Y0: 5.668, Time: 3.49, Learning Rate: 1.000e-03
# It: 480, Loss: 5.092e-01, Y0: 6.024, Time: 3.50, Learning Rate: 1.000e-03
# It: 490, Loss: 4.059e-01, Y0: 5.443, Time: 3.51, Learning Rate: 1.000e-03
# It: 500, Loss: 6.335e-01, Y0: 5.599, Time: 3.52, Learning Rate: 1.000e-03
# It: 510, Loss: 1.647e-01, Y0: 5.523, Time: 3.52, Learning Rate: 1.000e-03
# It: 520, Loss: 2.553e-01, Y0: 5.346, Time: 3.48, Learning Rate: 1.000e-03
# It: 530, Loss: 4.511e-01, Y0: 5.759, Time: 3.49, Learning Rate: 1.000e-03
# It: 540, Loss: 2.166e-01, Y0: 5.481, Time: 3.49, Learning Rate: 1.000e-03
# It: 550, Loss: 2.206e-01, Y0: 5.521, Time: 3.51, Learning Rate: 1.000e-03
# It: 560, Loss: 1.570e-01, Y0: 5.707, Time: 3.48, Learning Rate: 1.000e-03
# It: 570, Loss: 2.068e-01, Y0: 5.583, Time: 3.49, Learning Rate: 1.000e-03
# It: 580, Loss: 2.042e-01, Y0: 5.854, Time: 3.51, Learning Rate: 1.000e-03
# It: 590, Loss: 1.466e-01, Y0: 5.718, Time: 3.49, Learning Rate: 1.000e-03
# It: 600, Loss: 1.882e-01, Y0: 5.649, Time: 3.50, Learning Rate: 1.000e-03
# It: 610, Loss: 1.712e-01, Y0: 5.802, Time: 3.51, Learning Rate: 1.000e-03
# It: 620, Loss: 1.036e-01, Y0: 5.907, Time: 3.52, Learning Rate: 1.000e-03
# It: 630, Loss: 1.280e-01, Y0: 6.071, Time: 3.50, Learning Rate: 1.000e-03
# It: 640, Loss: 2.076e-01, Y0: 6.086, Time: 3.50, Learning Rate: 1.000e-03
# It: 650, Loss: 1.809e-01, Y0: 6.221, Time: 3.50, Learning Rate: 1.000e-03
# It: 660, Loss: 1.788e-01, Y0: 6.003, Time: 3.53, Learning Rate: 1.000e-03
# It: 670, Loss: 2.139e-01, Y0: 6.164, Time: 3.52, Learning Rate: 1.000e-03
# It: 680, Loss: 1.751e-01, Y0: 6.073, Time: 3.51, Learning Rate: 1.000e-03
# It: 690, Loss: 1.516e-01, Y0: 6.100, Time: 3.49, Learning Rate: 1.000e-03
# It: 700, Loss: 1.418e-01, Y0: 6.034, Time: 3.51, Learning Rate: 1.000e-03
# It: 710, Loss: 1.689e-01, Y0: 6.178, Time: 3.48, Learning Rate: 1.000e-03
# It: 720, Loss: 1.087e-01, Y0: 6.066, Time: 3.49, Learning Rate: 1.000e-03
# It: 730, Loss: 1.715e-01, Y0: 6.144, Time: 3.47, Learning Rate: 1.000e-03
# It: 740, Loss: 1.278e-01, Y0: 6.042, Time: 3.46, Learning Rate: 1.000e-03
# It: 750, Loss: 1.763e-01, Y0: 6.102, Time: 3.49, Learning Rate: 1.000e-03
# It: 760, Loss: 1.329e-01, Y0: 6.058, Time: 3.49, Learning Rate: 1.000e-03
# It: 770, Loss: 1.810e-01, Y0: 6.167, Time: 3.48, Learning Rate: 1.000e-03
# It: 780, Loss: 1.066e-01, Y0: 6.118, Time: 3.48, Learning Rate: 1.000e-03
# It: 790, Loss: 1.744e-01, Y0: 6.189, Time: 3.50, Learning Rate: 1.000e-03
# It: 800, Loss: 1.046e-01, Y0: 6.152, Time: 3.48, Learning Rate: 1.000e-03
# It: 810, Loss: 1.389e-01, Y0: 6.231, Time: 3.49, Learning Rate: 1.000e-03
# It: 820, Loss: 1.144e-01, Y0: 6.149, Time: 3.48, Learning Rate: 1.000e-03
# It: 830, Loss: 1.345e-01, Y0: 6.289, Time: 3.51, Learning Rate: 1.000e-03
# It: 840, Loss: 1.134e-01, Y0: 6.255, Time: 3.50, Learning Rate: 1.000e-03
# It: 850, Loss: 1.462e-01, Y0: 6.358, Time: 3.49, Learning Rate: 1.000e-03
# It: 860, Loss: 7.679e-02, Y0: 6.329, Time: 3.52, Learning Rate: 1.000e-03
# It: 870, Loss: 1.797e-01, Y0: 6.516, Time: 3.51, Learning Rate: 1.000e-03
# It: 880, Loss: 7.804e-02, Y0: 6.420, Time: 3.49, Learning Rate: 1.000e-03
# It: 890, Loss: 1.656e-01, Y0: 6.552, Time: 3.52, Learning Rate: 1.000e-03
# It: 900, Loss: 9.302e-02, Y0: 6.430, Time: 3.50, Learning Rate: 1.000e-03
# It: 910, Loss: 1.029e-01, Y0: 6.488, Time: 3.50, Learning Rate: 1.000e-03
# It: 920, Loss: 9.700e-02, Y0: 6.311, Time: 3.50, Learning Rate: 1.000e-03
# It: 930, Loss: 1.124e-01, Y0: 6.539, Time: 3.49, Learning Rate: 1.000e-03
# It: 940, Loss: 8.347e-02, Y0: 6.512, Time: 3.48, Learning Rate: 1.000e-03
# It: 950, Loss: 1.257e-01, Y0: 6.573, Time: 3.51, Learning Rate: 1.000e-03
# It: 960, Loss: 8.465e-02, Y0: 6.432, Time: 3.49, Learning Rate: 1.000e-03
# It: 970, Loss: 1.149e-01, Y0: 6.464, Time: 3.49, Learning Rate: 1.000e-03
# It: 980, Loss: 8.665e-02, Y0: 6.389, Time: 3.50, Learning Rate: 1.000e-03
# It: 990, Loss: 1.251e-01, Y0: 6.499, Time: 3.49, Learning Rate: 1.000e-03
# It: 1000, Loss: 7.427e-02, Y0: 6.431, Time: 3.48, Learning Rate: 1.000e-03
# It: 1010, Loss: 9.324e-02, Y0: 6.536, Time: 3.48, Learning Rate: 1.000e-03
# It: 1020, Loss: 7.838e-02, Y0: 6.342, Time: 3.49, Learning Rate: 1.000e-03
# It: 1030, Loss: 1.174e-01, Y0: 6.430, Time: 3.53, Learning Rate: 1.000e-03
# It: 1040, Loss: 1.011e-01, Y0: 6.473, Time: 3.48, Learning Rate: 1.000e-03
# It: 1050, Loss: 1.138e-01, Y0: 6.536, Time: 3.49, Learning Rate: 1.000e-03
# It: 1060, Loss: 7.814e-02, Y0: 6.344, Time: 3.50, Learning Rate: 1.000e-03
# It: 1070, Loss: 9.938e-02, Y0: 6.400, Time: 3.50, Learning Rate: 1.000e-03
# It: 1080, Loss: 8.469e-02, Y0: 6.356, Time: 3.50, Learning Rate: 1.000e-03
# It: 1090, Loss: 1.251e-01, Y0: 6.476, Time: 3.49, Learning Rate: 1.000e-03
# It: 1100, Loss: 7.216e-02, Y0: 6.338, Time: 3.51, Learning Rate: 1.000e-03
# It: 1110, Loss: 1.230e-01, Y0: 6.491, Time: 3.51, Learning Rate: 1.000e-03
# It: 1120, Loss: 7.807e-02, Y0: 6.397, Time: 3.50, Learning Rate: 1.000e-03
# It: 1130, Loss: 1.193e-01, Y0: 6.495, Time: 3.51, Learning Rate: 1.000e-03
# It: 1140, Loss: 6.618e-02, Y0: 6.415, Time: 3.49, Learning Rate: 1.000e-03
# It: 1150, Loss: 8.462e-02, Y0: 6.495, Time: 3.47, Learning Rate: 1.000e-03
# It: 1160, Loss: 1.312e-01, Y0: 6.334, Time: 3.49, Learning Rate: 1.000e-03
# It: 1170, Loss: 8.276e-02, Y0: 6.468, Time: 3.52, Learning Rate: 1.000e-03
# It: 1180, Loss: 8.191e-02, Y0: 6.490, Time: 3.50, Learning Rate: 1.000e-03
# It: 1190, Loss: 6.364e-02, Y0: 6.497, Time: 3.50, Learning Rate: 1.000e-03
# It: 1200, Loss: 7.669e-02, Y0: 6.419, Time: 3.52, Learning Rate: 1.000e-03
# It: 1210, Loss: 9.366e-02, Y0: 6.503, Time: 3.48, Learning Rate: 1.000e-03
# It: 1220, Loss: 9.286e-02, Y0: 6.234, Time: 3.49, Learning Rate: 1.000e-03
# It: 1230, Loss: 9.115e-02, Y0: 6.031, Time: 3.53, Learning Rate: 1.000e-03
# It: 1240, Loss: 7.924e-02, Y0: 6.110, Time: 3.49, Learning Rate: 1.000e-03
# It: 1250, Loss: 1.988e-01, Y0: 6.030, Time: 3.48, Learning Rate: 1.000e-03
# It: 1260, Loss: 6.995e-02, Y0: 6.061, Time: 3.48, Learning Rate: 1.000e-03
# It: 1270, Loss: 9.961e-02, Y0: 6.208, Time: 3.50, Learning Rate: 1.000e-03
# It: 1280, Loss: 7.056e-02, Y0: 6.076, Time: 3.49, Learning Rate: 1.000e-03
# It: 1290, Loss: 3.548e-01, Y0: 6.403, Time: 3.50, Learning Rate: 1.000e-03
# It: 1300, Loss: 1.360e-01, Y0: 6.139, Time: 3.51, Learning Rate: 1.000e-03
# It: 1310, Loss: 8.755e-02, Y0: 5.858, Time: 3.47, Learning Rate: 1.000e-03
# It: 1320, Loss: 1.682e-01, Y0: 5.960, Time: 3.47, Learning Rate: 1.000e-03
# It: 1330, Loss: 2.154e-01, Y0: 6.312, Time: 3.50, Learning Rate: 1.000e-03
# It: 1340, Loss: 9.980e-02, Y0: 5.966, Time: 3.48, Learning Rate: 1.000e-03
# It: 1350, Loss: 6.082e-02, Y0: 6.409, Time: 3.49, Learning Rate: 1.000e-03
# It: 1360, Loss: 6.355e-02, Y0: 6.273, Time: 3.53, Learning Rate: 1.000e-03
# It: 1370, Loss: 1.147e-01, Y0: 5.927, Time: 3.47, Learning Rate: 1.000e-03
# It: 1380, Loss: 1.194e-01, Y0: 6.278, Time: 3.47, Learning Rate: 1.000e-03
# It: 1390, Loss: 7.186e-02, Y0: 6.444, Time: 3.50, Learning Rate: 1.000e-03
# It: 1400, Loss: 9.190e-02, Y0: 6.338, Time: 3.47, Learning Rate: 1.000e-03
# It: 1410, Loss: 2.155e-01, Y0: 6.438, Time: 3.47, Learning Rate: 1.000e-03
# It: 1420, Loss: 1.186e-01, Y0: 6.321, Time: 3.52, Learning Rate: 1.000e-03
# It: 1430, Loss: 8.120e-02, Y0: 6.266, Time: 3.50, Learning Rate: 1.000e-03
# It: 1440, Loss: 2.691e-01, Y0: 6.494, Time: 3.47, Learning Rate: 1.000e-03
# It: 1450, Loss: 6.748e-02, Y0: 6.291, Time: 3.52, Learning Rate: 1.000e-03
# It: 1460, Loss: 1.076e-01, Y0: 6.283, Time: 3.48, Learning Rate: 1.000e-03
# It: 1470, Loss: 2.524e-01, Y0: 6.675, Time: 3.48, Learning Rate: 1.000e-03
# It: 1480, Loss: 5.963e-02, Y0: 6.350, Time: 3.49, Learning Rate: 1.000e-03
# It: 1490, Loss: 8.958e-02, Y0: 6.308, Time: 3.50, Learning Rate: 1.000e-03
# It: 1500, Loss: 2.520e-01, Y0: 6.394, Time: 3.50, Learning Rate: 1.000e-03
# It: 1510, Loss: 7.281e-02, Y0: 6.279, Time: 3.49, Learning Rate: 1.000e-03
# It: 1520, Loss: 1.055e-01, Y0: 6.352, Time: 3.48, Learning Rate: 1.000e-03
# It: 1530, Loss: 2.473e-01, Y0: 6.508, Time: 3.50, Learning Rate: 1.000e-03
# It: 1540, Loss: 7.369e-02, Y0: 6.299, Time: 3.51, Learning Rate: 1.000e-03
# It: 1550, Loss: 1.017e-01, Y0: 6.316, Time: 3.51, Learning Rate: 1.000e-03
# It: 1560, Loss: 2.025e-01, Y0: 6.376, Time: 3.50, Learning Rate: 1.000e-03
# It: 1570, Loss: 6.562e-02, Y0: 6.245, Time: 3.51, Learning Rate: 1.000e-03
# It: 1580, Loss: 8.872e-02, Y0: 6.302, Time: 3.51, Learning Rate: 1.000e-03
# It: 1590, Loss: 2.187e-01, Y0: 6.489, Time: 3.51, Learning Rate: 1.000e-03
# It: 1600, Loss: 6.794e-02, Y0: 6.284, Time: 3.49, Learning Rate: 1.000e-03
# It: 1610, Loss: 8.470e-02, Y0: 6.231, Time: 3.55, Learning Rate: 1.000e-03
# It: 1620, Loss: 2.384e-01, Y0: 6.316, Time: 3.50, Learning Rate: 1.000e-03
# It: 1630, Loss: 6.442e-02, Y0: 6.226, Time: 3.50, Learning Rate: 1.000e-03
# It: 1640, Loss: 1.089e-01, Y0: 6.297, Time: 3.53, Learning Rate: 1.000e-03
# It: 1650, Loss: 1.725e-01, Y0: 6.436, Time: 3.49, Learning Rate: 1.000e-03
# It: 1660, Loss: 8.621e-02, Y0: 6.407, Time: 3.47, Learning Rate: 1.000e-03
# It: 1670, Loss: 6.532e-02, Y0: 6.177, Time: 3.51, Learning Rate: 1.000e-03
# It: 1680, Loss: 1.974e-01, Y0: 6.393, Time: 3.48, Learning Rate: 1.000e-03
# It: 1690, Loss: 7.288e-02, Y0: 6.241, Time: 3.50, Learning Rate: 1.000e-03
# It: 1700, Loss: 9.282e-02, Y0: 6.238, Time: 3.51, Learning Rate: 1.000e-03
# It: 1710, Loss: 1.790e-01, Y0: 6.331, Time: 3.48, Learning Rate: 1.000e-03
# It: 1720, Loss: 6.588e-02, Y0: 6.193, Time: 3.49, Learning Rate: 1.000e-03
# It: 1730, Loss: 9.343e-02, Y0: 6.348, Time: 3.54, Learning Rate: 1.000e-03
# It: 1740, Loss: 1.892e-01, Y0: 6.496, Time: 3.50, Learning Rate: 1.000e-03
# It: 1750, Loss: 9.817e-02, Y0: 6.242, Time: 3.48, Learning Rate: 1.000e-03
# It: 1760, Loss: 1.306e-01, Y0: 6.301, Time: 3.48, Learning Rate: 1.000e-03
# It: 1770, Loss: 2.666e-01, Y0: 6.321, Time: 3.48, Learning Rate: 1.000e-03
# It: 1780, Loss: 5.493e-02, Y0: 6.307, Time: 3.49, Learning Rate: 1.000e-03
# It: 1790, Loss: 6.811e-02, Y0: 6.223, Time: 3.51, Learning Rate: 1.000e-03
# It: 1800, Loss: 2.059e-01, Y0: 6.383, Time: 3.50, Learning Rate: 1.000e-03
# It: 1810, Loss: 7.166e-02, Y0: 6.248, Time: 3.49, Learning Rate: 1.000e-03
# It: 1820, Loss: 9.709e-02, Y0: 6.225, Time: 3.50, Learning Rate: 1.000e-03
# It: 1830, Loss: 1.437e-01, Y0: 6.319, Time: 3.53, Learning Rate: 1.000e-03
# It: 1840, Loss: 7.089e-02, Y0: 6.242, Time: 3.49, Learning Rate: 1.000e-03
# It: 1850, Loss: 1.047e-01, Y0: 6.251, Time: 3.49, Learning Rate: 1.000e-03
# It: 1860, Loss: 1.645e-01, Y0: 6.289, Time: 3.54, Learning Rate: 1.000e-03
# It: 1870, Loss: 5.441e-02, Y0: 6.180, Time: 3.49, Learning Rate: 1.000e-03
# It: 1880, Loss: 8.471e-02, Y0: 6.313, Time: 3.48, Learning Rate: 1.000e-03
# It: 1890, Loss: 1.531e-01, Y0: 6.453, Time: 3.51, Learning Rate: 1.000e-03
# It: 1900, Loss: 9.226e-02, Y0: 6.151, Time: 3.48, Learning Rate: 1.000e-03
# It: 1910, Loss: 1.013e-01, Y0: 6.237, Time: 3.50, Learning Rate: 1.000e-03
# It: 1920, Loss: 1.499e-01, Y0: 6.280, Time: 3.50, Learning Rate: 1.000e-03
# It: 1930, Loss: 4.408e-02, Y0: 6.157, Time: 3.50, Learning Rate: 1.000e-03
# It: 1940, Loss: 9.309e-02, Y0: 6.230, Time: 3.50, Learning Rate: 1.000e-03
# It: 1950, Loss: 8.388e-02, Y0: 6.196, Time: 3.53, Learning Rate: 1.000e-03
# It: 1960, Loss: 8.508e-02, Y0: 6.258, Time: 3.49, Learning Rate: 1.000e-03
# It: 1970, Loss: 1.266e-01, Y0: 6.096, Time: 3.54, Learning Rate: 1.000e-03
# It: 1980, Loss: 1.060e-01, Y0: 6.032, Time: 3.49, Learning Rate: 1.000e-03
# It: 1990, Loss: 6.139e-02, Y0: 6.111, Time: 3.48, Learning Rate: 1.000e-03
# It: 2000, Loss: 6.131e-02, Y0: 6.587, Time: 3.52, Learning Rate: 1.000e-03
# It: 2010, Loss: 6.832e-02, Y0: 6.243, Time: 3.55, Learning Rate: 1.000e-03
# It: 2020, Loss: 6.857e-02, Y0: 6.359, Time: 3.55, Learning Rate: 1.000e-03
# It: 2030, Loss: 6.186e-02, Y0: 6.287, Time: 3.50, Learning Rate: 1.000e-03
# It: 2040, Loss: 5.204e-02, Y0: 6.335, Time: 3.51, Learning Rate: 1.000e-03
# It: 2050, Loss: 1.030e-01, Y0: 6.443, Time: 3.51, Learning Rate: 1.000e-03
# It: 2060, Loss: 5.307e-02, Y0: 6.478, Time: 3.50, Learning Rate: 1.000e-03
# It: 2070, Loss: 1.394e-01, Y0: 6.233, Time: 3.49, Learning Rate: 1.000e-03
# It: 2080, Loss: 8.684e-02, Y0: 5.996, Time: 3.53, Learning Rate: 1.000e-03
# It: 2090, Loss: 4.188e-02, Y0: 6.235, Time: 3.48, Learning Rate: 1.000e-03
# It: 2100, Loss: 1.268e-01, Y0: 6.544, Time: 3.49, Learning Rate: 1.000e-03
# It: 2110, Loss: 3.729e-02, Y0: 6.497, Time: 3.54, Learning Rate: 1.000e-03
# It: 2120, Loss: 4.679e-02, Y0: 6.529, Time: 3.51, Learning Rate: 1.000e-03
# It: 2130, Loss: 3.954e-02, Y0: 6.471, Time: 3.52, Learning Rate: 1.000e-03
# It: 2140, Loss: 5.007e-02, Y0: 6.574, Time: 3.52, Learning Rate: 1.000e-03
# It: 2150, Loss: 3.380e-02, Y0: 6.514, Time: 3.52, Learning Rate: 1.000e-03
# It: 2160, Loss: 3.841e-02, Y0: 6.613, Time: 3.50, Learning Rate: 1.000e-03
# It: 2170, Loss: 7.839e-02, Y0: 6.536, Time: 3.50, Learning Rate: 1.000e-03
# It: 2180, Loss: 5.817e-02, Y0: 6.522, Time: 3.47, Learning Rate: 1.000e-03
# It: 2190, Loss: 4.631e-02, Y0: 6.490, Time: 3.47, Learning Rate: 1.000e-03
# It: 2200, Loss: 3.506e-02, Y0: 6.607, Time: 3.50, Learning Rate: 1.000e-03
# It: 2210, Loss: 7.948e-02, Y0: 6.523, Time: 3.49, Learning Rate: 1.000e-03
# It: 2220, Loss: 3.792e-02, Y0: 6.564, Time: 3.50, Learning Rate: 1.000e-03
# It: 2230, Loss: 4.886e-02, Y0: 6.523, Time: 3.53, Learning Rate: 1.000e-03
# It: 2240, Loss: 3.801e-02, Y0: 6.521, Time: 3.47, Learning Rate: 1.000e-03
# It: 2250, Loss: 3.613e-02, Y0: 6.473, Time: 3.47, Learning Rate: 1.000e-03
# It: 2260, Loss: 5.171e-02, Y0: 6.503, Time: 3.47, Learning Rate: 1.000e-03
# It: 2270, Loss: 3.842e-02, Y0: 6.505, Time: 3.54, Learning Rate: 1.000e-03
# It: 2280, Loss: 4.085e-02, Y0: 6.547, Time: 3.51, Learning Rate: 1.000e-03
# It: 2290, Loss: 3.631e-02, Y0: 6.530, Time: 3.50, Learning Rate: 1.000e-03
# It: 2300, Loss: 3.942e-02, Y0: 6.564, Time: 3.49, Learning Rate: 1.000e-03
# It: 2310, Loss: 4.504e-02, Y0: 6.499, Time: 3.47, Learning Rate: 1.000e-03
# It: 2320, Loss: 3.420e-02, Y0: 6.532, Time: 3.50, Learning Rate: 1.000e-03
# It: 2330, Loss: 3.888e-02, Y0: 6.499, Time: 3.51, Learning Rate: 1.000e-03
# It: 2340, Loss: 4.173e-02, Y0: 6.565, Time: 3.49, Learning Rate: 1.000e-03
# It: 2350, Loss: 3.617e-02, Y0: 6.513, Time: 3.48, Learning Rate: 1.000e-03
# It: 2360, Loss: 4.496e-02, Y0: 6.540, Time: 3.49, Learning Rate: 1.000e-03
# It: 2370, Loss: 3.556e-02, Y0: 6.533, Time: 3.51, Learning Rate: 1.000e-03
# It: 2380, Loss: 3.639e-02, Y0: 6.553, Time: 3.49, Learning Rate: 1.000e-03
# It: 2390, Loss: 4.262e-02, Y0: 6.491, Time: 3.50, Learning Rate: 1.000e-03
# It: 2400, Loss: 3.556e-02, Y0: 6.527, Time: 3.48, Learning Rate: 1.000e-03
# It: 2410, Loss: 3.843e-02, Y0: 6.467, Time: 3.49, Learning Rate: 1.000e-03
# It: 2420, Loss: 3.275e-02, Y0: 6.518, Time: 3.51, Learning Rate: 1.000e-03
# It: 2430, Loss: 4.165e-02, Y0: 6.494, Time: 3.51, Learning Rate: 1.000e-03
# It: 2440, Loss: 3.535e-02, Y0: 6.563, Time: 3.48, Learning Rate: 1.000e-03
# It: 2450, Loss: 3.236e-02, Y0: 6.461, Time: 3.50, Learning Rate: 1.000e-03
# It: 2460, Loss: 3.709e-02, Y0: 6.540, Time: 3.49, Learning Rate: 1.000e-03
# It: 2470, Loss: 3.539e-02, Y0: 6.514, Time: 3.51, Learning Rate: 1.000e-03
# It: 2480, Loss: 3.508e-02, Y0: 6.559, Time: 3.53, Learning Rate: 1.000e-03
# It: 2490, Loss: 3.802e-02, Y0: 6.469, Time: 3.50, Learning Rate: 1.000e-03
# It: 2500, Loss: 3.551e-02, Y0: 6.511, Time: 3.49, Learning Rate: 1.000e-03
# It: 2510, Loss: 4.097e-02, Y0: 6.483, Time: 3.52, Learning Rate: 1.000e-03
# It: 2520, Loss: 3.493e-02, Y0: 6.554, Time: 3.52, Learning Rate: 1.000e-03
# It: 2530, Loss: 3.171e-02, Y0: 6.441, Time: 3.52, Learning Rate: 1.000e-03
# It: 2540, Loss: 4.115e-02, Y0: 6.501, Time: 3.47, Learning Rate: 1.000e-03
# It: 2550, Loss: 3.985e-02, Y0: 6.433, Time: 3.51, Learning Rate: 1.000e-03
# It: 2560, Loss: 3.317e-02, Y0: 6.506, Time: 3.49, Learning Rate: 1.000e-03
# It: 2570, Loss: 3.937e-02, Y0: 6.469, Time: 3.52, Learning Rate: 1.000e-03
# It: 2580, Loss: 3.267e-02, Y0: 6.491, Time: 3.50, Learning Rate: 1.000e-03
# It: 2590, Loss: 3.386e-02, Y0: 6.469, Time: 3.50, Learning Rate: 1.000e-03
# It: 2600, Loss: 4.310e-02, Y0: 6.519, Time: 3.51, Learning Rate: 1.000e-03
# It: 2610, Loss: 2.879e-02, Y0: 6.428, Time: 3.49, Learning Rate: 1.000e-03
# It: 2620, Loss: 6.406e-02, Y0: 6.517, Time: 3.47, Learning Rate: 1.000e-03
# It: 2630, Loss: 3.588e-02, Y0: 6.432, Time: 3.49, Learning Rate: 1.000e-03
# It: 2640, Loss: 3.095e-02, Y0: 6.516, Time: 3.49, Learning Rate: 1.000e-03
# It: 2650, Loss: 3.518e-02, Y0: 6.416, Time: 3.48, Learning Rate: 1.000e-03
# It: 2660, Loss: 2.902e-02, Y0: 6.440, Time: 3.49, Learning Rate: 1.000e-03
# It: 2670, Loss: 3.026e-02, Y0: 6.464, Time: 3.50, Learning Rate: 1.000e-03
# It: 2680, Loss: 3.611e-02, Y0: 6.496, Time: 3.48, Learning Rate: 1.000e-03
# It: 2690, Loss: 2.793e-02, Y0: 6.412, Time: 3.49, Learning Rate: 1.000e-03
# It: 2700, Loss: 3.434e-02, Y0: 6.447, Time: 3.51, Learning Rate: 1.000e-03
# It: 2710, Loss: 3.672e-02, Y0: 6.413, Time: 3.50, Learning Rate: 1.000e-03
# It: 2720, Loss: 2.907e-02, Y0: 6.494, Time: 3.48, Learning Rate: 1.000e-03
# It: 2730, Loss: 2.473e-02, Y0: 6.376, Time: 3.52, Learning Rate: 1.000e-03
# It: 2740, Loss: 3.802e-02, Y0: 6.459, Time: 3.50, Learning Rate: 1.000e-03
# It: 2750, Loss: 2.835e-02, Y0: 6.432, Time: 3.49, Learning Rate: 1.000e-03
# It: 2760, Loss: 3.780e-02, Y0: 6.464, Time: 3.50, Learning Rate: 1.000e-03
# It: 2770, Loss: 3.297e-02, Y0: 6.385, Time: 3.52, Learning Rate: 1.000e-03
# It: 2780, Loss: 3.632e-02, Y0: 6.488, Time: 3.52, Learning Rate: 1.000e-03
# It: 2790, Loss: 3.349e-02, Y0: 6.450, Time: 3.50, Learning Rate: 1.000e-03
# It: 2800, Loss: 3.189e-02, Y0: 6.500, Time: 3.52, Learning Rate: 1.000e-03
# It: 2810, Loss: 2.950e-02, Y0: 6.351, Time: 3.49, Learning Rate: 1.000e-03
# It: 2820, Loss: 2.792e-02, Y0: 6.424, Time: 3.50, Learning Rate: 1.000e-03
# It: 2830, Loss: 2.967e-02, Y0: 6.395, Time: 3.52, Learning Rate: 1.000e-03
# It: 2840, Loss: 3.911e-02, Y0: 6.434, Time: 3.48, Learning Rate: 1.000e-03
# It: 2850, Loss: 2.752e-02, Y0: 6.406, Time: 3.50, Learning Rate: 1.000e-03
# It: 2860, Loss: 3.371e-02, Y0: 6.435, Time: 3.52, Learning Rate: 1.000e-03
# It: 2870, Loss: 2.975e-02, Y0: 6.352, Time: 3.51, Learning Rate: 1.000e-03
# It: 2880, Loss: 2.857e-02, Y0: 6.361, Time: 3.50, Learning Rate: 1.000e-03
# It: 2890, Loss: 3.182e-02, Y0: 6.382, Time: 3.54, Learning Rate: 1.000e-03
# It: 2900, Loss: 3.018e-02, Y0: 6.447, Time: 3.46, Learning Rate: 1.000e-03
# It: 2910, Loss: 2.991e-02, Y0: 6.295, Time: 3.49, Learning Rate: 1.000e-03
# It: 2920, Loss: 3.810e-02, Y0: 6.386, Time: 3.52, Learning Rate: 1.000e-03
# It: 2930, Loss: 3.249e-02, Y0: 6.359, Time: 3.50, Learning Rate: 1.000e-03
# It: 2940, Loss: 2.855e-02, Y0: 6.390, Time: 3.51, Learning Rate: 1.000e-03
# It: 2950, Loss: 2.831e-02, Y0: 6.331, Time: 3.55, Learning Rate: 1.000e-03
# It: 2960, Loss: 3.979e-02, Y0: 6.323, Time: 3.50, Learning Rate: 1.000e-03
# It: 2970, Loss: 2.834e-02, Y0: 6.351, Time: 3.50, Learning Rate: 1.000e-03
# It: 2980, Loss: 2.643e-02, Y0: 6.409, Time: 3.52, Learning Rate: 1.000e-03
# It: 2990, Loss: 2.493e-02, Y0: 6.251, Time: 3.52, Learning Rate: 1.000e-03
# It: 0, Loss: 4.393e-02, Y0: 6.286, Time: 0.35, Learning Rate: 1.000e-04
# It: 10, Loss: 1.874e-02, Y0: 6.346, Time: 3.53, Learning Rate: 1.000e-04
# It: 20, Loss: 1.431e-02, Y0: 6.324, Time: 3.49, Learning Rate: 1.000e-04
# It: 30, Loss: 1.300e-02, Y0: 6.360, Time: 3.51, Learning Rate: 1.000e-04
# It: 40, Loss: 1.271e-02, Y0: 6.413, Time: 3.51, Learning Rate: 1.000e-04
# It: 50, Loss: 1.565e-02, Y0: 6.399, Time: 3.54, Learning Rate: 1.000e-04
# It: 60, Loss: 1.813e-02, Y0: 6.453, Time: 3.53, Learning Rate: 1.000e-04
# It: 70, Loss: 1.304e-02, Y0: 6.388, Time: 3.51, Learning Rate: 1.000e-04
# It: 80, Loss: 1.444e-02, Y0: 6.399, Time: 3.51, Learning Rate: 1.000e-04
# It: 90, Loss: 1.179e-02, Y0: 6.396, Time: 3.48, Learning Rate: 1.000e-04
# It: 100, Loss: 1.250e-02, Y0: 6.396, Time: 3.50, Learning Rate: 1.000e-04
# It: 110, Loss: 1.700e-02, Y0: 6.393, Time: 3.53, Learning Rate: 1.000e-04
# It: 120, Loss: 1.198e-02, Y0: 6.392, Time: 3.51, Learning Rate: 1.000e-04
# It: 130, Loss: 1.323e-02, Y0: 6.390, Time: 3.50, Learning Rate: 1.000e-04
# It: 140, Loss: 1.375e-02, Y0: 6.437, Time: 3.53, Learning Rate: 1.000e-04
# It: 150, Loss: 1.411e-02, Y0: 6.483, Time: 3.50, Learning Rate: 1.000e-04
# It: 160, Loss: 1.248e-02, Y0: 6.368, Time: 3.47, Learning Rate: 1.000e-04
# It: 170, Loss: 1.214e-02, Y0: 6.357, Time: 3.52, Learning Rate: 1.000e-04
# It: 180, Loss: 1.298e-02, Y0: 6.414, Time: 3.51, Learning Rate: 1.000e-04
# It: 190, Loss: 1.355e-02, Y0: 6.409, Time: 3.50, Learning Rate: 1.000e-04
# It: 200, Loss: 1.042e-02, Y0: 6.398, Time: 3.54, Learning Rate: 1.000e-04
# It: 210, Loss: 1.713e-02, Y0: 6.423, Time: 3.50, Learning Rate: 1.000e-04
# It: 220, Loss: 1.279e-02, Y0: 6.424, Time: 3.49, Learning Rate: 1.000e-04
# It: 230, Loss: 1.259e-02, Y0: 6.434, Time: 3.56, Learning Rate: 1.000e-04
# It: 240, Loss: 1.112e-02, Y0: 6.441, Time: 3.51, Learning Rate: 1.000e-04
# It: 250, Loss: 1.020e-02, Y0: 6.428, Time: 3.48, Learning Rate: 1.000e-04
# It: 260, Loss: 1.109e-02, Y0: 6.463, Time: 3.53, Learning Rate: 1.000e-04
# It: 270, Loss: 9.167e-03, Y0: 6.495, Time: 3.50, Learning Rate: 1.000e-04
# It: 280, Loss: 9.617e-03, Y0: 6.438, Time: 3.48, Learning Rate: 1.000e-04
# It: 290, Loss: 1.102e-02, Y0: 6.453, Time: 3.49, Learning Rate: 1.000e-04
# It: 300, Loss: 1.162e-02, Y0: 6.453, Time: 3.50, Learning Rate: 1.000e-04
# It: 310, Loss: 1.200e-02, Y0: 6.455, Time: 3.50, Learning Rate: 1.000e-04
# It: 320, Loss: 1.350e-02, Y0: 6.446, Time: 3.49, Learning Rate: 1.000e-04
# It: 330, Loss: 8.920e-03, Y0: 6.422, Time: 3.49, Learning Rate: 1.000e-04
# It: 340, Loss: 1.268e-02, Y0: 6.466, Time: 3.51, Learning Rate: 1.000e-04
# It: 350, Loss: 1.153e-02, Y0: 6.457, Time: 3.48, Learning Rate: 1.000e-04
# It: 360, Loss: 9.258e-03, Y0: 6.463, Time: 3.51, Learning Rate: 1.000e-04
# It: 370, Loss: 1.025e-02, Y0: 6.430, Time: 3.49, Learning Rate: 1.000e-04
# It: 380, Loss: 8.659e-03, Y0: 6.413, Time: 3.47, Learning Rate: 1.000e-04
# It: 390, Loss: 8.439e-03, Y0: 6.460, Time: 3.53, Learning Rate: 1.000e-04
# It: 400, Loss: 9.857e-03, Y0: 6.437, Time: 3.50, Learning Rate: 1.000e-04
# It: 410, Loss: 1.043e-02, Y0: 6.478, Time: 3.48, Learning Rate: 1.000e-04
# It: 420, Loss: 9.686e-03, Y0: 6.485, Time: 3.50, Learning Rate: 1.000e-04
# It: 430, Loss: 1.086e-02, Y0: 6.397, Time: 3.48, Learning Rate: 1.000e-04
# It: 440, Loss: 1.035e-02, Y0: 6.456, Time: 3.48, Learning Rate: 1.000e-04
# It: 450, Loss: 1.069e-02, Y0: 6.394, Time: 3.50, Learning Rate: 1.000e-04
# It: 460, Loss: 8.890e-03, Y0: 6.484, Time: 3.50, Learning Rate: 1.000e-04
# It: 470, Loss: 1.074e-02, Y0: 6.472, Time: 3.48, Learning Rate: 1.000e-04
# It: 480, Loss: 8.431e-03, Y0: 6.423, Time: 3.52, Learning Rate: 1.000e-04
# It: 490, Loss: 9.302e-03, Y0: 6.420, Time: 3.49, Learning Rate: 1.000e-04
# It: 500, Loss: 8.422e-03, Y0: 6.409, Time: 3.49, Learning Rate: 1.000e-04
# It: 510, Loss: 9.185e-03, Y0: 6.408, Time: 3.51, Learning Rate: 1.000e-04
# It: 520, Loss: 9.010e-03, Y0: 6.431, Time: 3.52, Learning Rate: 1.000e-04
# It: 530, Loss: 1.008e-02, Y0: 6.448, Time: 3.49, Learning Rate: 1.000e-04
# It: 540, Loss: 7.984e-03, Y0: 6.469, Time: 3.50, Learning Rate: 1.000e-04
# It: 550, Loss: 7.876e-03, Y0: 6.468, Time: 3.49, Learning Rate: 1.000e-04
# It: 560, Loss: 7.535e-03, Y0: 6.400, Time: 3.49, Learning Rate: 1.000e-04
# It: 570, Loss: 1.428e-02, Y0: 6.464, Time: 3.51, Learning Rate: 1.000e-04
# It: 580, Loss: 1.117e-02, Y0: 6.537, Time: 3.47, Learning Rate: 1.000e-04
# It: 590, Loss: 1.044e-02, Y0: 6.501, Time: 3.48, Learning Rate: 1.000e-04
# It: 600, Loss: 3.787e-02, Y0: 6.543, Time: 3.49, Learning Rate: 1.000e-04
# It: 610, Loss: 7.692e-03, Y0: 6.423, Time: 3.53, Learning Rate: 1.000e-04
# It: 620, Loss: 7.462e-03, Y0: 6.413, Time: 3.48, Learning Rate: 1.000e-04
# It: 630, Loss: 8.103e-03, Y0: 6.420, Time: 3.49, Learning Rate: 1.000e-04
# It: 640, Loss: 7.829e-03, Y0: 6.479, Time: 3.50, Learning Rate: 1.000e-04
# It: 650, Loss: 6.945e-03, Y0: 6.423, Time: 3.51, Learning Rate: 1.000e-04
# It: 660, Loss: 7.839e-03, Y0: 6.441, Time: 3.50, Learning Rate: 1.000e-04
# It: 670, Loss: 7.124e-03, Y0: 6.478, Time: 3.50, Learning Rate: 1.000e-04
# It: 680, Loss: 7.162e-03, Y0: 6.458, Time: 3.51, Learning Rate: 1.000e-04
# It: 690, Loss: 7.200e-03, Y0: 6.436, Time: 3.49, Learning Rate: 1.000e-04
# It: 700, Loss: 8.026e-03, Y0: 6.458, Time: 3.51, Learning Rate: 1.000e-04
# It: 710, Loss: 1.014e-02, Y0: 6.481, Time: 3.48, Learning Rate: 1.000e-04
# It: 720, Loss: 7.552e-03, Y0: 6.549, Time: 3.50, Learning Rate: 1.000e-04
# It: 730, Loss: 7.071e-03, Y0: 6.510, Time: 3.53, Learning Rate: 1.000e-04
# It: 740, Loss: 9.344e-03, Y0: 6.476, Time: 3.48, Learning Rate: 1.000e-04
# It: 750, Loss: 8.344e-03, Y0: 6.454, Time: 3.47, Learning Rate: 1.000e-04
# It: 760, Loss: 7.918e-03, Y0: 6.471, Time: 3.52, Learning Rate: 1.000e-04
# It: 770, Loss: 7.330e-03, Y0: 6.449, Time: 3.51, Learning Rate: 1.000e-04
# It: 780, Loss: 1.034e-02, Y0: 6.445, Time: 3.50, Learning Rate: 1.000e-04
# It: 790, Loss: 7.282e-03, Y0: 6.455, Time: 3.50, Learning Rate: 1.000e-04
# It: 800, Loss: 8.422e-03, Y0: 6.483, Time: 3.51, Learning Rate: 1.000e-04
# It: 810, Loss: 8.617e-03, Y0: 6.470, Time: 3.50, Learning Rate: 1.000e-04
# It: 820, Loss: 6.772e-03, Y0: 6.506, Time: 3.50, Learning Rate: 1.000e-04
# It: 830, Loss: 8.794e-03, Y0: 6.461, Time: 3.51, Learning Rate: 1.000e-04
# It: 840, Loss: 8.741e-03, Y0: 6.490, Time: 3.50, Learning Rate: 1.000e-04
# It: 850, Loss: 6.338e-03, Y0: 6.456, Time: 3.51, Learning Rate: 1.000e-04
# It: 860, Loss: 6.666e-03, Y0: 6.501, Time: 3.48, Learning Rate: 1.000e-04
# It: 870, Loss: 6.549e-03, Y0: 6.465, Time: 3.50, Learning Rate: 1.000e-04
# It: 880, Loss: 6.477e-03, Y0: 6.469, Time: 3.49, Learning Rate: 1.000e-04
# It: 890, Loss: 6.563e-03, Y0: 6.462, Time: 3.51, Learning Rate: 1.000e-04
# It: 900, Loss: 6.468e-03, Y0: 6.515, Time: 3.50, Learning Rate: 1.000e-04
# It: 910, Loss: 7.979e-03, Y0: 6.473, Time: 3.50, Learning Rate: 1.000e-04
# It: 920, Loss: 9.612e-03, Y0: 6.482, Time: 3.51, Learning Rate: 1.000e-04
# It: 930, Loss: 6.605e-03, Y0: 6.472, Time: 3.49, Learning Rate: 1.000e-04
# It: 940, Loss: 7.984e-03, Y0: 6.492, Time: 3.50, Learning Rate: 1.000e-04
# It: 950, Loss: 8.908e-03, Y0: 6.458, Time: 3.51, Learning Rate: 1.000e-04
# It: 960, Loss: 6.931e-03, Y0: 6.522, Time: 3.52, Learning Rate: 1.000e-04
# It: 970, Loss: 6.598e-03, Y0: 6.451, Time: 3.50, Learning Rate: 1.000e-04
# It: 980, Loss: 6.207e-03, Y0: 6.477, Time: 3.53, Learning Rate: 1.000e-04
# It: 990, Loss: 6.335e-03, Y0: 6.452, Time: 3.51, Learning Rate: 1.000e-04
# It: 1000, Loss: 6.966e-03, Y0: 6.472, Time: 3.49, Learning Rate: 1.000e-04
# It: 1010, Loss: 5.712e-03, Y0: 6.542, Time: 3.55, Learning Rate: 1.000e-04
# It: 1020, Loss: 5.987e-03, Y0: 6.482, Time: 3.47, Learning Rate: 1.000e-04
# It: 1030, Loss: 5.974e-03, Y0: 6.463, Time: 3.48, Learning Rate: 1.000e-04
# It: 1040, Loss: 6.856e-03, Y0: 6.487, Time: 3.49, Learning Rate: 1.000e-04
# It: 1050, Loss: 6.003e-03, Y0: 6.487, Time: 3.50, Learning Rate: 1.000e-04
# It: 1060, Loss: 6.260e-03, Y0: 6.492, Time: 3.48, Learning Rate: 1.000e-04
# It: 1070, Loss: 7.467e-03, Y0: 6.463, Time: 3.50, Learning Rate: 1.000e-04
# It: 1080, Loss: 1.108e-02, Y0: 6.460, Time: 3.49, Learning Rate: 1.000e-04
# It: 1090, Loss: 9.132e-03, Y0: 6.531, Time: 3.50, Learning Rate: 1.000e-04
# It: 1100, Loss: 6.692e-03, Y0: 6.501, Time: 3.50, Learning Rate: 1.000e-04
# It: 1110, Loss: 7.300e-03, Y0: 6.478, Time: 3.50, Learning Rate: 1.000e-04
# It: 1120, Loss: 8.958e-03, Y0: 6.494, Time: 3.47, Learning Rate: 1.000e-04
# It: 1130, Loss: 7.088e-03, Y0: 6.469, Time: 3.48, Learning Rate: 1.000e-04
# It: 1140, Loss: 7.883e-03, Y0: 6.461, Time: 3.52, Learning Rate: 1.000e-04
# It: 1150, Loss: 9.412e-03, Y0: 6.512, Time: 3.48, Learning Rate: 1.000e-04
# It: 1160, Loss: 7.430e-03, Y0: 6.473, Time: 3.50, Learning Rate: 1.000e-04
# It: 1170, Loss: 7.286e-03, Y0: 6.475, Time: 3.48, Learning Rate: 1.000e-04
# It: 1180, Loss: 9.348e-03, Y0: 6.453, Time: 3.49, Learning Rate: 1.000e-04
# It: 1190, Loss: 8.358e-03, Y0: 6.470, Time: 3.49, Learning Rate: 1.000e-04
# It: 1200, Loss: 6.412e-03, Y0: 6.484, Time: 3.51, Learning Rate: 1.000e-04
# It: 1210, Loss: 1.268e-02, Y0: 6.481, Time: 3.48, Learning Rate: 1.000e-04
# It: 1220, Loss: 6.375e-03, Y0: 6.462, Time: 3.49, Learning Rate: 1.000e-04
# It: 1230, Loss: 1.370e-02, Y0: 6.450, Time: 3.53, Learning Rate: 1.000e-04
# It: 1240, Loss: 7.490e-03, Y0: 6.455, Time: 3.47, Learning Rate: 1.000e-04
# It: 1250, Loss: 6.504e-03, Y0: 6.475, Time: 3.49, Learning Rate: 1.000e-04
# It: 1260, Loss: 6.635e-03, Y0: 6.461, Time: 3.52, Learning Rate: 1.000e-04
# It: 1270, Loss: 8.193e-03, Y0: 6.480, Time: 3.51, Learning Rate: 1.000e-04
# It: 1280, Loss: 7.132e-03, Y0: 6.441, Time: 3.49, Learning Rate: 1.000e-04
# It: 1290, Loss: 6.954e-03, Y0: 6.455, Time: 3.53, Learning Rate: 1.000e-04
# It: 1300, Loss: 9.542e-03, Y0: 6.484, Time: 3.50, Learning Rate: 1.000e-04
# It: 1310, Loss: 8.600e-03, Y0: 6.475, Time: 3.48, Learning Rate: 1.000e-04
# It: 1320, Loss: 6.752e-03, Y0: 6.468, Time: 3.49, Learning Rate: 1.000e-04
# It: 1330, Loss: 8.163e-03, Y0: 6.494, Time: 3.52, Learning Rate: 1.000e-04
# It: 1340, Loss: 7.129e-03, Y0: 6.478, Time: 3.49, Learning Rate: 1.000e-04
# It: 1350, Loss: 6.399e-03, Y0: 6.443, Time: 3.47, Learning Rate: 1.000e-04
# It: 1360, Loss: 8.005e-03, Y0: 6.475, Time: 3.48, Learning Rate: 1.000e-04
# It: 1370, Loss: 7.368e-03, Y0: 6.467, Time: 3.49, Learning Rate: 1.000e-04
# It: 1380, Loss: 6.660e-03, Y0: 6.471, Time: 3.47, Learning Rate: 1.000e-04
# It: 1390, Loss: 8.120e-03, Y0: 6.507, Time: 3.49, Learning Rate: 1.000e-04
# It: 1400, Loss: 5.996e-03, Y0: 6.453, Time: 3.47, Learning Rate: 1.000e-04
# It: 1410, Loss: 8.794e-03, Y0: 6.446, Time: 3.49, Learning Rate: 1.000e-04
# It: 1420, Loss: 8.269e-03, Y0: 6.475, Time: 3.53, Learning Rate: 1.000e-04
# It: 1430, Loss: 6.850e-03, Y0: 6.459, Time: 3.49, Learning Rate: 1.000e-04
# It: 1440, Loss: 1.040e-02, Y0: 6.449, Time: 3.48, Learning Rate: 1.000e-04
# It: 1450, Loss: 9.197e-03, Y0: 6.451, Time: 3.48, Learning Rate: 1.000e-04
# It: 1460, Loss: 7.928e-03, Y0: 6.466, Time: 3.49, Learning Rate: 1.000e-04
# It: 1470, Loss: 6.517e-03, Y0: 6.442, Time: 3.51, Learning Rate: 1.000e-04
# It: 1480, Loss: 9.156e-03, Y0: 6.467, Time: 3.50, Learning Rate: 1.000e-04
# It: 1490, Loss: 8.407e-03, Y0: 6.499, Time: 3.51, Learning Rate: 1.000e-04
# It: 1500, Loss: 9.841e-03, Y0: 6.502, Time: 3.48, Learning Rate: 1.000e-04
# It: 1510, Loss: 8.375e-03, Y0: 6.481, Time: 3.50, Learning Rate: 1.000e-04
# It: 1520, Loss: 6.130e-03, Y0: 6.472, Time: 3.47, Learning Rate: 1.000e-04
# It: 1530, Loss: 7.458e-03, Y0: 6.451, Time: 3.49, Learning Rate: 1.000e-04
# It: 1540, Loss: 7.764e-03, Y0: 6.442, Time: 3.49, Learning Rate: 1.000e-04
# It: 1550, Loss: 5.710e-03, Y0: 6.445, Time: 3.50, Learning Rate: 1.000e-04
# It: 1560, Loss: 8.814e-03, Y0: 6.455, Time: 3.52, Learning Rate: 1.000e-04
# It: 1570, Loss: 1.049e-02, Y0: 6.468, Time: 3.52, Learning Rate: 1.000e-04
# It: 1580, Loss: 7.492e-03, Y0: 6.465, Time: 3.50, Learning Rate: 1.000e-04
# It: 1590, Loss: 7.409e-03, Y0: 6.468, Time: 3.48, Learning Rate: 1.000e-04
# It: 1600, Loss: 9.687e-03, Y0: 6.479, Time: 3.46, Learning Rate: 1.000e-04
# It: 1610, Loss: 6.944e-03, Y0: 6.456, Time: 3.53, Learning Rate: 1.000e-04
# It: 1620, Loss: 7.021e-03, Y0: 6.476, Time: 3.52, Learning Rate: 1.000e-04
# It: 1630, Loss: 9.892e-03, Y0: 6.488, Time: 3.47, Learning Rate: 1.000e-04
# It: 1640, Loss: 6.065e-03, Y0: 6.444, Time: 3.58, Learning Rate: 1.000e-04
# It: 1650, Loss: 7.047e-03, Y0: 6.436, Time: 3.49, Learning Rate: 1.000e-04
# It: 1660, Loss: 7.714e-03, Y0: 6.459, Time: 3.49, Learning Rate: 1.000e-04
# It: 1670, Loss: 6.350e-03, Y0: 6.476, Time: 3.51, Learning Rate: 1.000e-04
# It: 1680, Loss: 1.166e-02, Y0: 6.448, Time: 3.47, Learning Rate: 1.000e-04
# It: 1690, Loss: 7.583e-03, Y0: 6.433, Time: 3.50, Learning Rate: 1.000e-04
# It: 1700, Loss: 7.080e-03, Y0: 6.476, Time: 3.50, Learning Rate: 1.000e-04
# It: 1710, Loss: 7.221e-03, Y0: 6.445, Time: 3.46, Learning Rate: 1.000e-04
# It: 1720, Loss: 7.114e-03, Y0: 6.454, Time: 3.48, Learning Rate: 1.000e-04
# It: 1730, Loss: 6.702e-03, Y0: 6.421, Time: 3.56, Learning Rate: 1.000e-04
# It: 1740, Loss: 7.429e-03, Y0: 6.461, Time: 3.48, Learning Rate: 1.000e-04
# It: 1750, Loss: 8.130e-03, Y0: 6.481, Time: 3.50, Learning Rate: 1.000e-04
# It: 1760, Loss: 5.907e-03, Y0: 6.431, Time: 3.53, Learning Rate: 1.000e-04
# It: 1770, Loss: 1.187e-02, Y0: 6.422, Time: 3.51, Learning Rate: 1.000e-04
# It: 1780, Loss: 8.663e-03, Y0: 6.471, Time: 3.49, Learning Rate: 1.000e-04
# It: 1790, Loss: 6.777e-03, Y0: 6.460, Time: 3.49, Learning Rate: 1.000e-04
# It: 1800, Loss: 6.751e-03, Y0: 6.497, Time: 3.49, Learning Rate: 1.000e-04
# It: 1810, Loss: 7.615e-03, Y0: 6.502, Time: 3.47, Learning Rate: 1.000e-04
# It: 1820, Loss: 6.389e-03, Y0: 6.434, Time: 3.49, Learning Rate: 1.000e-04
# It: 1830, Loss: 6.652e-03, Y0: 6.427, Time: 3.50, Learning Rate: 1.000e-04
# It: 1840, Loss: 7.576e-03, Y0: 6.459, Time: 3.50, Learning Rate: 1.000e-04
# It: 1850, Loss: 6.625e-03, Y0: 6.452, Time: 3.48, Learning Rate: 1.000e-04
# It: 1860, Loss: 6.187e-03, Y0: 6.444, Time: 3.48, Learning Rate: 1.000e-04
# It: 1870, Loss: 7.776e-03, Y0: 6.459, Time: 3.49, Learning Rate: 1.000e-04
# It: 1880, Loss: 6.171e-03, Y0: 6.477, Time: 3.48, Learning Rate: 1.000e-04
# It: 1890, Loss: 6.514e-03, Y0: 6.460, Time: 3.53, Learning Rate: 1.000e-04
# It: 1900, Loss: 6.197e-03, Y0: 6.465, Time: 3.48, Learning Rate: 1.000e-04
# It: 1910, Loss: 6.648e-03, Y0: 6.456, Time: 3.50, Learning Rate: 1.000e-04
# It: 1920, Loss: 5.193e-03, Y0: 6.448, Time: 3.49, Learning Rate: 1.000e-04
# It: 1930, Loss: 6.545e-03, Y0: 6.446, Time: 3.49, Learning Rate: 1.000e-04
# It: 1940, Loss: 1.057e-02, Y0: 6.493, Time: 3.46, Learning Rate: 1.000e-04
# It: 1950, Loss: 5.818e-03, Y0: 6.528, Time: 3.50, Learning Rate: 1.000e-04
# It: 1960, Loss: 5.415e-03, Y0: 6.526, Time: 3.48, Learning Rate: 1.000e-04
# It: 1970, Loss: 4.763e-03, Y0: 6.492, Time: 3.47, Learning Rate: 1.000e-04
# It: 1980, Loss: 5.645e-03, Y0: 6.541, Time: 3.52, Learning Rate: 1.000e-04
# It: 1990, Loss: 5.196e-03, Y0: 6.506, Time: 3.49, Learning Rate: 1.000e-04
# It: 2000, Loss: 5.858e-03, Y0: 6.579, Time: 3.48, Learning Rate: 1.000e-04
# It: 2010, Loss: 5.558e-03, Y0: 6.499, Time: 3.49, Learning Rate: 1.000e-04
# It: 2020, Loss: 4.590e-03, Y0: 6.548, Time: 3.49, Learning Rate: 1.000e-04
# It: 2030, Loss: 5.155e-03, Y0: 6.527, Time: 3.48, Learning Rate: 1.000e-04
# It: 2040, Loss: 6.160e-03, Y0: 6.595, Time: 3.51, Learning Rate: 1.000e-04
# It: 2050, Loss: 5.660e-03, Y0: 6.518, Time: 3.49, Learning Rate: 1.000e-04
# It: 2060, Loss: 5.691e-03, Y0: 6.603, Time: 3.48, Learning Rate: 1.000e-04
# It: 2070, Loss: 4.831e-03, Y0: 6.496, Time: 3.50, Learning Rate: 1.000e-04
# It: 2080, Loss: 5.905e-03, Y0: 6.536, Time: 3.51, Learning Rate: 1.000e-04
# It: 2090, Loss: 7.497e-03, Y0: 6.494, Time: 3.49, Learning Rate: 1.000e-04
# It: 2100, Loss: 4.628e-03, Y0: 6.528, Time: 3.49, Learning Rate: 1.000e-04
# It: 2110, Loss: 5.614e-03, Y0: 6.565, Time: 3.52, Learning Rate: 1.000e-04
# It: 2120, Loss: 8.776e-03, Y0: 6.558, Time: 3.48, Learning Rate: 1.000e-04
# It: 2130, Loss: 8.510e-03, Y0: 6.565, Time: 3.51, Learning Rate: 1.000e-04
# It: 2140, Loss: 4.860e-03, Y0: 6.546, Time: 3.53, Learning Rate: 1.000e-04
# It: 2150, Loss: 4.932e-03, Y0: 6.539, Time: 3.47, Learning Rate: 1.000e-04
# It: 2160, Loss: 6.886e-03, Y0: 6.541, Time: 3.49, Learning Rate: 1.000e-04
# It: 2170, Loss: 8.542e-03, Y0: 6.616, Time: 3.51, Learning Rate: 1.000e-04
# It: 2180, Loss: 5.446e-03, Y0: 6.559, Time: 3.50, Learning Rate: 1.000e-04
# It: 2190, Loss: 6.189e-03, Y0: 6.518, Time: 3.49, Learning Rate: 1.000e-04
# It: 2200, Loss: 7.119e-03, Y0: 6.547, Time: 3.49, Learning Rate: 1.000e-04
# It: 2210, Loss: 6.530e-03, Y0: 6.524, Time: 3.52, Learning Rate: 1.000e-04
# It: 2220, Loss: 6.173e-03, Y0: 6.501, Time: 3.49, Learning Rate: 1.000e-04
# It: 2230, Loss: 7.788e-03, Y0: 6.527, Time: 3.49, Learning Rate: 1.000e-04
# It: 2240, Loss: 5.399e-03, Y0: 6.507, Time: 3.48, Learning Rate: 1.000e-04
# It: 2250, Loss: 8.279e-03, Y0: 6.503, Time: 3.49, Learning Rate: 1.000e-04
# It: 2260, Loss: 7.559e-03, Y0: 6.499, Time: 3.50, Learning Rate: 1.000e-04
# It: 2270, Loss: 5.800e-03, Y0: 6.512, Time: 3.50, Learning Rate: 1.000e-04
# It: 2280, Loss: 6.526e-03, Y0: 6.514, Time: 3.47, Learning Rate: 1.000e-04
# It: 2290, Loss: 7.588e-03, Y0: 6.537, Time: 3.49, Learning Rate: 1.000e-04
# It: 2300, Loss: 5.190e-03, Y0: 6.469, Time: 3.50, Learning Rate: 1.000e-04
# It: 2310, Loss: 6.068e-03, Y0: 6.452, Time: 3.47, Learning Rate: 1.000e-04
# It: 2320, Loss: 8.356e-03, Y0: 6.508, Time: 3.48, Learning Rate: 1.000e-04
# It: 2330, Loss: 8.116e-03, Y0: 6.454, Time: 3.49, Learning Rate: 1.000e-04
# It: 2340, Loss: 6.066e-03, Y0: 6.461, Time: 3.47, Learning Rate: 1.000e-04
# It: 2350, Loss: 6.829e-03, Y0: 6.513, Time: 3.48, Learning Rate: 1.000e-04
# It: 2360, Loss: 7.850e-03, Y0: 6.490, Time: 3.49, Learning Rate: 1.000e-04
# It: 2370, Loss: 6.140e-03, Y0: 6.496, Time: 3.46, Learning Rate: 1.000e-04
# It: 2380, Loss: 7.637e-03, Y0: 6.535, Time: 3.47, Learning Rate: 1.000e-04
# It: 2390, Loss: 5.208e-03, Y0: 6.474, Time: 3.53, Learning Rate: 1.000e-04
# It: 2400, Loss: 5.889e-03, Y0: 6.470, Time: 3.48, Learning Rate: 1.000e-04
# It: 2410, Loss: 7.062e-03, Y0: 6.478, Time: 3.49, Learning Rate: 1.000e-04
# It: 2420, Loss: 6.444e-03, Y0: 6.465, Time: 3.51, Learning Rate: 1.000e-04
# It: 2430, Loss: 7.140e-03, Y0: 6.457, Time: 3.49, Learning Rate: 1.000e-04
# It: 2440, Loss: 6.721e-03, Y0: 6.495, Time: 3.50, Learning Rate: 1.000e-04
# It: 2450, Loss: 6.532e-03, Y0: 6.442, Time: 3.53, Learning Rate: 1.000e-04
# It: 2460, Loss: 5.329e-03, Y0: 6.450, Time: 3.49, Learning Rate: 1.000e-04
# It: 2470, Loss: 7.533e-03, Y0: 6.500, Time: 3.49, Learning Rate: 1.000e-04
# It: 2480, Loss: 5.910e-03, Y0: 6.464, Time: 3.52, Learning Rate: 1.000e-04
# It: 2490, Loss: 6.105e-03, Y0: 6.458, Time: 3.49, Learning Rate: 1.000e-04
# It: 2500, Loss: 1.080e-02, Y0: 6.496, Time: 3.52, Learning Rate: 1.000e-04
# It: 2510, Loss: 5.485e-03, Y0: 6.545, Time: 3.54, Learning Rate: 1.000e-04
# It: 2520, Loss: 5.941e-03, Y0: 6.480, Time: 3.50, Learning Rate: 1.000e-04
# It: 2530, Loss: 6.975e-03, Y0: 6.505, Time: 3.51, Learning Rate: 1.000e-04
# It: 2540, Loss: 1.002e-02, Y0: 6.507, Time: 3.51, Learning Rate: 1.000e-04
# It: 2550, Loss: 6.415e-03, Y0: 6.452, Time: 3.52, Learning Rate: 1.000e-04
# It: 2560, Loss: 7.300e-03, Y0: 6.453, Time: 3.50, Learning Rate: 1.000e-04
# It: 2570, Loss: 5.343e-03, Y0: 6.454, Time: 3.50, Learning Rate: 1.000e-04
# It: 2580, Loss: 6.316e-03, Y0: 6.439, Time: 3.54, Learning Rate: 1.000e-04
# It: 2590, Loss: 8.050e-03, Y0: 6.491, Time: 3.49, Learning Rate: 1.000e-04
# It: 2600, Loss: 4.687e-03, Y0: 6.471, Time: 3.48, Learning Rate: 1.000e-04
# It: 2610, Loss: 7.401e-03, Y0: 6.452, Time: 3.48, Learning Rate: 1.000e-04
# It: 2620, Loss: 6.158e-03, Y0: 6.465, Time: 3.47, Learning Rate: 1.000e-04
# It: 2630, Loss: 5.715e-03, Y0: 6.462, Time: 3.49, Learning Rate: 1.000e-04
# It: 2640, Loss: 6.420e-03, Y0: 6.466, Time: 3.50, Learning Rate: 1.000e-04
# It: 2650, Loss: 7.023e-03, Y0: 6.460, Time: 3.50, Learning Rate: 1.000e-04
# It: 2660, Loss: 5.035e-03, Y0: 6.487, Time: 3.49, Learning Rate: 1.000e-04
# It: 2670, Loss: 2.263e-02, Y0: 6.497, Time: 3.53, Learning Rate: 1.000e-04
# It: 2680, Loss: 7.313e-03, Y0: 6.492, Time: 3.49, Learning Rate: 1.000e-04
# It: 2690, Loss: 5.156e-03, Y0: 6.449, Time: 3.47, Learning Rate: 1.000e-04
# It: 2700, Loss: 8.056e-03, Y0: 6.467, Time: 3.49, Learning Rate: 1.000e-04
# It: 2710, Loss: 7.090e-03, Y0: 6.491, Time: 3.49, Learning Rate: 1.000e-04
# It: 2720, Loss: 5.704e-03, Y0: 6.435, Time: 3.50, Learning Rate: 1.000e-04
# It: 2730, Loss: 6.284e-03, Y0: 6.445, Time: 3.50, Learning Rate: 1.000e-04
# It: 2740, Loss: 7.278e-03, Y0: 6.434, Time: 3.48, Learning Rate: 1.000e-04
# It: 2750, Loss: 5.131e-03, Y0: 6.445, Time: 3.49, Learning Rate: 1.000e-04
# It: 2760, Loss: 6.100e-03, Y0: 6.467, Time: 3.49, Learning Rate: 1.000e-04
# It: 2770, Loss: 6.885e-03, Y0: 6.461, Time: 3.50, Learning Rate: 1.000e-04
# It: 2780, Loss: 5.086e-03, Y0: 6.483, Time: 3.49, Learning Rate: 1.000e-04
# It: 2790, Loss: 6.678e-03, Y0: 6.498, Time: 3.50, Learning Rate: 1.000e-04
# It: 2800, Loss: 7.443e-03, Y0: 6.497, Time: 3.52, Learning Rate: 1.000e-04
# It: 2810, Loss: 5.491e-03, Y0: 6.475, Time: 3.51, Learning Rate: 1.000e-04
# It: 2820, Loss: 5.998e-03, Y0: 6.489, Time: 3.50, Learning Rate: 1.000e-04
# It: 2830, Loss: 7.224e-03, Y0: 6.458, Time: 3.50, Learning Rate: 1.000e-04
# It: 2840, Loss: 8.598e-03, Y0: 6.498, Time: 3.49, Learning Rate: 1.000e-04
# It: 2850, Loss: 7.652e-03, Y0: 6.526, Time: 3.49, Learning Rate: 1.000e-04
# It: 2860, Loss: 7.868e-03, Y0: 6.495, Time: 3.50, Learning Rate: 1.000e-04
# It: 2870, Loss: 6.877e-03, Y0: 6.474, Time: 3.47, Learning Rate: 1.000e-04
# It: 2880, Loss: 5.629e-03, Y0: 6.469, Time: 3.46, Learning Rate: 1.000e-04
# It: 2890, Loss: 7.003e-03, Y0: 6.469, Time: 3.52, Learning Rate: 1.000e-04
# ...
# It: 880, Loss: 3.595e-03, Y0: 6.926, Time: 3.51, Learning Rate: 1.000e-06
# It: 890, Loss: 3.598e-03, Y0: 6.926, Time: 3.58, Learning Rate: 1.000e-06
# It: 900, Loss: 3.148e-03, Y0: 6.926, Time: 3.56, Learning Rate: 1.000e-06
# It: 910, Loss: 3.064e-03, Y0: 6.925, Time: 3.52, Learning Rate: 1.000e-06
# It: 920, Loss: 3.040e-03, Y0: 6.926, Time: 3.53, Learning Rate: 1.000e-06
# It: 930, Loss: 2.962e-03, Y0: 6.927, Time: 3.52, Learning Rate: 1.000e-06
# It: 940, Loss: 7.240e-03, Y0: 6.927, Time: 3.53, Learning Rate: 1.000e-06
# It: 950, Loss: 4.122e-03, Y0: 6.928, Time: 3.52, Learning Rate: 1.000e-06
# It: 960, Loss: 4.812e-03, Y0: 6.927, Time: 3.53, Learning Rate: 1.000e-06
# It: 970, Loss: 3.133e-03, Y0: 6.929, Time: 3.52, Learning Rate: 1.000e-06
# It: 980, Loss: 3.240e-03, Y0: 6.931, Time: 3.56, Learning Rate: 1.000e-06
# It: 990, Loss: 3.002e-03, Y0: 6.931, Time: 3.55, Learning Rate: 1.000e-06
# It: 1000, Loss: 3.551e-03, Y0: 6.934, Time: 3.53, Learning Rate: 1.000e-06
# It: 1010, Loss: 3.254e-03, Y0: 6.935, Time: 3.53, Learning Rate: 1.000e-06
# It: 1020, Loss: 2.924e-03, Y0: 6.936, Time: 3.54, Learning Rate: 1.000e-06
# It: 1030, Loss: 3.199e-03, Y0: 6.935, Time: 3.54, Learning Rate: 1.000e-06
# It: 1040, Loss: 3.346e-03, Y0: 6.933, Time: 3.52, Learning Rate: 1.000e-06
# It: 1050, Loss: 3.093e-03, Y0: 6.933, Time: 3.52, Learning Rate: 1.000e-06
# It: 1060, Loss: 3.568e-03, Y0: 6.932, Time: 3.54, Learning Rate: 1.000e-06
# It: 1070, Loss: 4.160e-03, Y0: 6.932, Time: 3.54, Learning Rate: 1.000e-06
# It: 1080, Loss: 3.567e-03, Y0: 6.932, Time: 3.52, Learning Rate: 1.000e-06
# It: 1090, Loss: 3.173e-03, Y0: 6.932, Time: 3.52, Learning Rate: 1.000e-06
# It: 1100, Loss: 3.007e-03, Y0: 6.933, Time: 3.53, Learning Rate: 1.000e-06
# It: 1110, Loss: 3.381e-03, Y0: 6.933, Time: 3.57, Learning Rate: 1.000e-06
# It: 1120, Loss: 3.842e-03, Y0: 6.933, Time: 3.50, Learning Rate: 1.000e-06
# It: 1130, Loss: 3.093e-03, Y0: 6.933, Time: 3.53, Learning Rate: 1.000e-06
# It: 1140, Loss: 3.127e-03, Y0: 6.933, Time: 3.57, Learning Rate: 1.000e-06
# It: 1150, Loss: 3.003e-03, Y0: 6.932, Time: 3.52, Learning Rate: 1.000e-06
# It: 1160, Loss: 3.472e-03, Y0: 6.933, Time: 3.50, Learning Rate: 1.000e-06
# It: 1170, Loss: 3.227e-03, Y0: 6.934, Time: 3.60, Learning Rate: 1.000e-06
# It: 1180, Loss: 4.034e-03, Y0: 6.933, Time: 3.52, Learning Rate: 1.000e-06
# It: 1190, Loss: 2.980e-03, Y0: 6.932, Time: 3.52, Learning Rate: 1.000e-06
# It: 1200, Loss: 3.195e-03, Y0: 6.933, Time: 3.56, Learning Rate: 1.000e-06
# It: 1210, Loss: 4.271e-03, Y0: 6.933, Time: 3.52, Learning Rate: 1.000e-06
# It: 1220, Loss: 4.336e-03, Y0: 6.934, Time: 3.52, Learning Rate: 1.000e-06
# It: 1230, Loss: 3.589e-03, Y0: 6.934, Time: 3.57, Learning Rate: 1.000e-06
# It: 1240, Loss: 3.091e-03, Y0: 6.934, Time: 3.55, Learning Rate: 1.000e-06
# It: 1250, Loss: 4.179e-03, Y0: 6.933, Time: 3.54, Learning Rate: 1.000e-06
# It: 1260, Loss: 3.887e-03, Y0: 6.934, Time: 3.56, Learning Rate: 1.000e-06
# It: 1270, Loss: 2.997e-03, Y0: 6.934, Time: 3.56, Learning Rate: 1.000e-06
# It: 1280, Loss: 3.560e-03, Y0: 6.933, Time: 3.50, Learning Rate: 1.000e-06
# It: 1290, Loss: 3.846e-03, Y0: 6.933, Time: 3.55, Learning Rate: 1.000e-06
# It: 1300, Loss: 2.954e-03, Y0: 6.934, Time: 3.54, Learning Rate: 1.000e-06
# It: 1310, Loss: 2.942e-03, Y0: 6.933, Time: 3.50, Learning Rate: 1.000e-06
# It: 1320, Loss: 3.663e-03, Y0: 6.933, Time: 3.58, Learning Rate: 1.000e-06
# It: 1330, Loss: 3.087e-03, Y0: 6.933, Time: 3.52, Learning Rate: 1.000e-06
# It: 1340, Loss: 3.000e-03, Y0: 6.931, Time: 3.52, Learning Rate: 1.000e-06
# It: 1350, Loss: 5.170e-03, Y0: 6.931, Time: 3.55, Learning Rate: 1.000e-06
# It: 1360, Loss: 3.486e-03, Y0: 6.932, Time: 3.53, Learning Rate: 1.000e-06
# It: 1370, Loss: 3.574e-03, Y0: 6.931, Time: 3.54, Learning Rate: 1.000e-06
# It: 1380, Loss: 1.995e-02, Y0: 6.931, Time: 3.51, Learning Rate: 1.000e-06
# It: 1390, Loss: 3.244e-03, Y0: 6.935, Time: 3.52, Learning Rate: 1.000e-06
# It: 1400, Loss: 2.892e-03, Y0: 6.935, Time: 3.53, Learning Rate: 1.000e-06
# It: 1410, Loss: 3.273e-03, Y0: 6.933, Time: 3.52, Learning Rate: 1.000e-06
# It: 1420, Loss: 3.343e-03, Y0: 6.932, Time: 3.56, Learning Rate: 1.000e-06
# It: 1430, Loss: 2.901e-03, Y0: 6.932, Time: 3.54, Learning Rate: 1.000e-06
# It: 1440, Loss: 9.636e-03, Y0: 6.934, Time: 3.53, Learning Rate: 1.000e-06
# It: 1450, Loss: 3.201e-03, Y0: 6.932, Time: 3.51, Learning Rate: 1.000e-06
# It: 1460, Loss: 3.128e-03, Y0: 6.931, Time: 3.51, Learning Rate: 1.000e-06
# It: 1470, Loss: 3.580e-03, Y0: 6.932, Time: 3.51, Learning Rate: 1.000e-06
# It: 1480, Loss: 3.028e-03, Y0: 6.932, Time: 3.54, Learning Rate: 1.000e-06
# It: 1490, Loss: 3.093e-03, Y0: 6.933, Time: 3.53, Learning Rate: 1.000e-06
# It: 1500, Loss: 3.196e-03, Y0: 6.932, Time: 3.56, Learning Rate: 1.000e-06
# It: 1510, Loss: 3.265e-03, Y0: 6.933, Time: 3.57, Learning Rate: 1.000e-06
# It: 1520, Loss: 3.018e-03, Y0: 6.934, Time: 3.52, Learning Rate: 1.000e-06
# It: 1530, Loss: 3.168e-03, Y0: 6.935, Time: 3.54, Learning Rate: 1.000e-06
# It: 1540, Loss: 3.663e-03, Y0: 6.936, Time: 3.56, Learning Rate: 1.000e-06
# It: 1550, Loss: 3.292e-03, Y0: 6.935, Time: 3.49, Learning Rate: 1.000e-06
# It: 1560, Loss: 3.249e-03, Y0: 6.935, Time: 3.54, Learning Rate: 1.000e-06
# It: 1570, Loss: 3.174e-03, Y0: 6.935, Time: 3.58, Learning Rate: 1.000e-06
# It: 1580, Loss: 3.145e-03, Y0: 6.935, Time: 3.55, Learning Rate: 1.000e-06
# It: 1590, Loss: 3.331e-03, Y0: 6.936, Time: 3.55, Learning Rate: 1.000e-06
# It: 1600, Loss: 3.669e-03, Y0: 6.936, Time: 3.55, Learning Rate: 1.000e-06
# It: 1610, Loss: 3.710e-03, Y0: 6.937, Time: 3.57, Learning Rate: 1.000e-06
# It: 1620, Loss: 3.049e-03, Y0: 6.937, Time: 3.55, Learning Rate: 1.000e-06
# It: 1630, Loss: 2.887e-03, Y0: 6.938, Time: 3.60, Learning Rate: 1.000e-06
# It: 1640, Loss: 3.234e-03, Y0: 6.938, Time: 3.53, Learning Rate: 1.000e-06
# It: 1650, Loss: 3.051e-03, Y0: 6.940, Time: 3.55, Learning Rate: 1.000e-06
# It: 1660, Loss: 3.042e-03, Y0: 6.940, Time: 3.57, Learning Rate: 1.000e-06
# It: 1670, Loss: 2.885e-03, Y0: 6.941, Time: 3.51, Learning Rate: 1.000e-06
# It: 1680, Loss: 3.310e-03, Y0: 6.940, Time: 3.53, Learning Rate: 1.000e-06
# It: 1690, Loss: 4.587e-03, Y0: 6.941, Time: 3.55, Learning Rate: 1.000e-06
# It: 1700, Loss: 3.014e-03, Y0: 6.939, Time: 3.53, Learning Rate: 1.000e-06
# It: 1710, Loss: 3.045e-03, Y0: 6.940, Time: 3.52, Learning Rate: 1.000e-06
# It: 1720, Loss: 2.873e-03, Y0: 6.938, Time: 3.55, Learning Rate: 1.000e-06
# It: 1730, Loss: 3.017e-03, Y0: 6.937, Time: 3.53, Learning Rate: 1.000e-06
# It: 1740, Loss: 4.155e-03, Y0: 6.938, Time: 3.56, Learning Rate: 1.000e-06
# It: 1750, Loss: 2.782e-03, Y0: 6.938, Time: 3.58, Learning Rate: 1.000e-06
# It: 1760, Loss: 3.124e-03, Y0: 6.939, Time: 3.54, Learning Rate: 1.000e-06
# It: 1770, Loss: 2.928e-03, Y0: 6.939, Time: 3.52, Learning Rate: 1.000e-06
# It: 1780, Loss: 3.025e-03, Y0: 6.938, Time: 3.55, Learning Rate: 1.000e-06
# It: 1790, Loss: 3.358e-03, Y0: 6.938, Time: 3.54, Learning Rate: 1.000e-06
# It: 1800, Loss: 3.703e-03, Y0: 6.938, Time: 3.51, Learning Rate: 1.000e-06
# It: 1810, Loss: 3.345e-03, Y0: 6.939, Time: 3.52, Learning Rate: 1.000e-06
# It: 1820, Loss: 3.155e-03, Y0: 6.937, Time: 3.52, Learning Rate: 1.000e-06
# It: 1830, Loss: 3.045e-03, Y0: 6.938, Time: 3.52, Learning Rate: 1.000e-06
# It: 1840, Loss: 2.844e-03, Y0: 6.937, Time: 3.55, Learning Rate: 1.000e-06
# It: 1850, Loss: 5.782e-03, Y0: 6.938, Time: 3.53, Learning Rate: 1.000e-06
# It: 1860, Loss: 3.669e-03, Y0: 6.939, Time: 3.52, Learning Rate: 1.000e-06
# It: 1870, Loss: 3.166e-03, Y0: 6.939, Time: 3.53, Learning Rate: 1.000e-06
# It: 1880, Loss: 3.262e-03, Y0: 6.938, Time: 3.56, Learning Rate: 1.000e-06
# It: 1890, Loss: 3.117e-03, Y0: 6.938, Time: 3.51, Learning Rate: 1.000e-06
# It: 1900, Loss: 3.420e-03, Y0: 6.939, Time: 3.52, Learning Rate: 1.000e-06
# It: 1910, Loss: 3.456e-03, Y0: 6.939, Time: 3.55, Learning Rate: 1.000e-06
# It: 1920, Loss: 3.285e-03, Y0: 6.941, Time: 3.54, Learning Rate: 1.000e-06
# It: 1930, Loss: 3.068e-03, Y0: 6.940, Time: 3.54, Learning Rate: 1.000e-06
# It: 1940, Loss: 4.968e-03, Y0: 6.942, Time: 3.54, Learning Rate: 1.000e-06
# It: 1950, Loss: 2.978e-03, Y0: 6.941, Time: 3.53, Learning Rate: 1.000e-06
# It: 1960, Loss: 3.030e-03, Y0: 6.943, Time: 3.51, Learning Rate: 1.000e-06
# It: 1970, Loss: 3.407e-03, Y0: 6.943, Time: 3.55, Learning Rate: 1.000e-06
# It: 1980, Loss: 3.511e-03, Y0: 6.944, Time: 3.52, Learning Rate: 1.000e-06
# It: 1990, Loss: 2.964e-03, Y0: 6.942, Time: 3.54, Learning Rate: 1.000e-06
# It: 2000, Loss: 3.613e-03, Y0: 6.941, Time: 3.53, Learning Rate: 1.000e-06
# It: 2010, Loss: 3.138e-03, Y0: 6.940, Time: 3.51, Learning Rate: 1.000e-06
# It: 2020, Loss: 3.048e-03, Y0: 6.941, Time: 3.53, Learning Rate: 1.000e-06
# It: 2030, Loss: 3.016e-03, Y0: 6.942, Time: 3.58, Learning Rate: 1.000e-06
# It: 2040, Loss: 2.998e-03, Y0: 6.941, Time: 3.54, Learning Rate: 1.000e-06
# It: 2050, Loss: 3.139e-03, Y0: 6.940, Time: 3.54, Learning Rate: 1.000e-06
# It: 2060, Loss: 3.137e-03, Y0: 6.940, Time: 3.57, Learning Rate: 1.000e-06
# It: 2070, Loss: 3.181e-03, Y0: 6.941, Time: 3.52, Learning Rate: 1.000e-06
# It: 2080, Loss: 3.128e-03, Y0: 6.940, Time: 3.55, Learning Rate: 1.000e-06
# It: 2090, Loss: 3.091e-03, Y0: 6.938, Time: 3.56, Learning Rate: 1.000e-06
# It: 2100, Loss: 2.961e-03, Y0: 6.940, Time: 3.51, Learning Rate: 1.000e-06
# It: 2110, Loss: 3.120e-03, Y0: 6.940, Time: 3.53, Learning Rate: 1.000e-06
# It: 2120, Loss: 3.249e-03, Y0: 6.940, Time: 3.53, Learning Rate: 1.000e-06
# It: 2130, Loss: 2.898e-03, Y0: 6.940, Time: 3.49, Learning Rate: 1.000e-06
# It: 2140, Loss: 8.306e-03, Y0: 6.941, Time: 3.53, Learning Rate: 1.000e-06
# It: 2150, Loss: 3.002e-03, Y0: 6.941, Time: 3.60, Learning Rate: 1.000e-06
# It: 2160, Loss: 3.540e-03, Y0: 6.940, Time: 3.52, Learning Rate: 1.000e-06
# It: 2170, Loss: 3.838e-03, Y0: 6.939, Time: 3.51, Learning Rate: 1.000e-06
# It: 2180, Loss: 1.044e-02, Y0: 6.940, Time: 3.57, Learning Rate: 1.000e-06
# It: 2190, Loss: 3.350e-03, Y0: 6.943, Time: 3.57, Learning Rate: 1.000e-06
# It: 2200, Loss: 3.475e-03, Y0: 6.944, Time: 3.54, Learning Rate: 1.000e-06
# It: 2210, Loss: 3.003e-03, Y0: 6.944, Time: 3.55, Learning Rate: 1.000e-06
# It: 2220, Loss: 3.608e-03, Y0: 6.944, Time: 3.53, Learning Rate: 1.000e-06
# It: 2230, Loss: 3.040e-03, Y0: 6.943, Time: 3.56, Learning Rate: 1.000e-06
# It: 2240, Loss: 2.900e-03, Y0: 6.943, Time: 3.54, Learning Rate: 1.000e-06
# It: 2250, Loss: 3.172e-03, Y0: 6.944, Time: 3.55, Learning Rate: 1.000e-06
# It: 2260, Loss: 3.012e-03, Y0: 6.944, Time: 3.52, Learning Rate: 1.000e-06
# It: 2270, Loss: 3.048e-03, Y0: 6.942, Time: 3.57, Learning Rate: 1.000e-06
# It: 2280, Loss: 3.421e-03, Y0: 6.942, Time: 3.57, Learning Rate: 1.000e-06
# It: 2290, Loss: 3.140e-03, Y0: 6.942, Time: 3.52, Learning Rate: 1.000e-06
# It: 2300, Loss: 3.497e-03, Y0: 6.948, Time: 3.58, Learning Rate: 1.000e-06
# It: 2310, Loss: 3.380e-03, Y0: 6.948, Time: 3.54, Learning Rate: 1.000e-06
# It: 2320, Loss: 4.804e-03, Y0: 6.946, Time: 3.55, Learning Rate: 1.000e-06
# It: 2330, Loss: 3.068e-03, Y0: 6.944, Time: 3.55, Learning Rate: 1.000e-06
# It: 2340, Loss: 2.903e-03, Y0: 6.945, Time: 3.54, Learning Rate: 1.000e-06
# It: 2350, Loss: 3.216e-03, Y0: 6.947, Time: 3.51, Learning Rate: 1.000e-06
# It: 2360, Loss: 2.969e-03, Y0: 6.948, Time: 3.55, Learning Rate: 1.000e-06
# It: 2370, Loss: 2.826e-03, Y0: 6.948, Time: 3.55, Learning Rate: 1.000e-06
# It: 2380, Loss: 3.144e-03, Y0: 6.950, Time: 3.51, Learning Rate: 1.000e-06
# It: 2390, Loss: 3.000e-03, Y0: 6.949, Time: 3.55, Learning Rate: 1.000e-06
# It: 2400, Loss: 3.207e-03, Y0: 6.948, Time: 3.60, Learning Rate: 1.000e-06
# It: 2410, Loss: 1.458e-02, Y0: 6.947, Time: 3.53, Learning Rate: 1.000e-06
# It: 2420, Loss: 3.292e-03, Y0: 6.946, Time: 3.54, Learning Rate: 1.000e-06
# It: 2430, Loss: 3.438e-03, Y0: 6.944, Time: 3.58, Learning Rate: 1.000e-06
# It: 2440, Loss: 3.243e-03, Y0: 6.944, Time: 3.51, Learning Rate: 1.000e-06
# It: 2450, Loss: 4.373e-03, Y0: 6.945, Time: 3.52, Learning Rate: 1.000e-06
# It: 2460, Loss: 3.107e-03, Y0: 6.946, Time: 3.55, Learning Rate: 1.000e-06
# It: 2470, Loss: 2.931e-03, Y0: 6.948, Time: 3.54, Learning Rate: 1.000e-06
# It: 2480, Loss: 3.489e-03, Y0: 6.948, Time: 3.53, Learning Rate: 1.000e-06
# It: 2490, Loss: 3.174e-03, Y0: 6.948, Time: 3.53, Learning Rate: 1.000e-06
# It: 2500, Loss: 3.384e-03, Y0: 6.948, Time: 3.53, Learning Rate: 1.000e-06
# It: 2510, Loss: 4.039e-03, Y0: 6.948, Time: 3.52, Learning Rate: 1.000e-06
# It: 2520, Loss: 3.257e-03, Y0: 6.948, Time: 3.57, Learning Rate: 1.000e-06
# It: 2530, Loss: 2.990e-03, Y0: 6.947, Time: 3.52, Learning Rate: 1.000e-06
# It: 2540, Loss: 3.135e-03, Y0: 6.946, Time: 3.53, Learning Rate: 1.000e-06
# It: 2550, Loss: 6.380e-03, Y0: 6.945, Time: 3.58, Learning Rate: 1.000e-06
# It: 2560, Loss: 4.492e-03, Y0: 6.946, Time: 3.52, Learning Rate: 1.000e-06
# It: 2570, Loss: 6.454e-03, Y0: 6.947, Time: 3.56, Learning Rate: 1.000e-06
# It: 2580, Loss: 3.098e-03, Y0: 6.950, Time: 3.56, Learning Rate: 1.000e-06
# It: 2590, Loss: 3.123e-03, Y0: 6.950, Time: 3.52, Learning Rate: 1.000e-06
# It: 2600, Loss: 2.902e-03, Y0: 6.951, Time: 3.54, Learning Rate: 1.000e-06
# It: 2610, Loss: 3.846e-03, Y0: 6.949, Time: 3.57, Learning Rate: 1.000e-06
# It: 2620, Loss: 3.760e-03, Y0: 6.949, Time: 3.50, Learning Rate: 1.000e-06
# It: 2630, Loss: 2.991e-03, Y0: 6.949, Time: 3.52, Learning Rate: 1.000e-06
# It: 2640, Loss: 3.098e-03, Y0: 6.947, Time: 3.50, Learning Rate: 1.000e-06
# It: 2650, Loss: 3.159e-03, Y0: 6.948, Time: 3.52, Learning Rate: 1.000e-06
# It: 2660, Loss: 2.943e-03, Y0: 6.949, Time: 3.57, Learning Rate: 1.000e-06
# It: 2670, Loss: 3.924e-03, Y0: 6.949, Time: 3.53, Learning Rate: 1.000e-06
# It: 2680, Loss: 2.895e-03, Y0: 6.949, Time: 3.53, Learning Rate: 1.000e-06
# It: 2690, Loss: 3.395e-03, Y0: 6.951, Time: 3.54, Learning Rate: 1.000e-06
# It: 2700, Loss: 2.998e-03, Y0: 6.951, Time: 3.52, Learning Rate: 1.000e-06
# It: 2710, Loss: 3.298e-03, Y0: 6.951, Time: 3.55, Learning Rate: 1.000e-06
# It: 2720, Loss: 4.861e-03, Y0: 6.949, Time: 3.53, Learning Rate: 1.000e-06
# It: 2730, Loss: 4.258e-03, Y0: 6.949, Time: 3.50, Learning Rate: 1.000e-06
# It: 2740, Loss: 3.245e-03, Y0: 6.949, Time: 3.54, Learning Rate: 1.000e-06
# It: 2750, Loss: 3.008e-03, Y0: 6.948, Time: 3.55, Learning Rate: 1.000e-06
# It: 2760, Loss: 2.999e-03, Y0: 6.948, Time: 3.52, Learning Rate: 1.000e-06
# It: 2770, Loss: 3.133e-03, Y0: 6.950, Time: 3.56, Learning Rate: 1.000e-06
# It: 2780, Loss: 3.050e-03, Y0: 6.951, Time: 3.52, Learning Rate: 1.000e-06
# It: 2790, Loss: 3.193e-03, Y0: 6.952, Time: 3.52, Learning Rate: 1.000e-06
# It: 2800, Loss: 3.019e-03, Y0: 6.951, Time: 3.58, Learning Rate: 1.000e-06
# It: 2810, Loss: 3.164e-03, Y0: 6.956, Time: 3.51, Learning Rate: 1.000e-06
# It: 2820, Loss: 6.381e-03, Y0: 6.955, Time: 3.49, Learning Rate: 1.000e-06
# It: 2830, Loss: 2.994e-03, Y0: 6.955, Time: 3.53, Learning Rate: 1.000e-06
# It: 2840, Loss: 3.386e-03, Y0: 6.953, Time: 3.54, Learning Rate: 1.000e-06
# It: 2850, Loss: 3.446e-03, Y0: 6.953, Time: 3.50, Learning Rate: 1.000e-06
# It: 2860, Loss: 3.177e-03, Y0: 6.953, Time: 3.59, Learning Rate: 1.000e-06
# It: 2870, Loss: 3.657e-03, Y0: 6.953, Time: 3.53, Learning Rate: 1.000e-06
# It: 2880, Loss: 2.945e-03, Y0: 6.952, Time: 3.52, Learning Rate: 1.000e-06
# It: 2890, Loss: 3.171e-03, Y0: 6.953, Time: 3.56, Learning Rate: 1.000e-06
# It: 2900, Loss: 3.226e-03, Y0: 6.953, Time: 3.52, Learning Rate: 1.000e-06
# It: 2910, Loss: 4.292e-03, Y0: 6.955, Time: 3.53, Learning Rate: 1.000e-06
# It: 2920, Loss: 2.905e-03, Y0: 6.956, Time: 3.55, Learning Rate: 1.000e-06
# It: 2930, Loss: 3.006e-03, Y0: 6.955, Time: 3.52, Learning Rate: 1.000e-06
# It: 2940, Loss: 2.954e-03, Y0: 6.956, Time: 3.54, Learning Rate: 1.000e-06
# It: 2950, Loss: 4.097e-03, Y0: 6.955, Time: 3.55, Learning Rate: 1.000e-06
# It: 2960, Loss: 2.828e-03, Y0: 6.955, Time: 3.53, Learning Rate: 1.000e-06
# It: 2970, Loss: 4.207e-03, Y0: 6.954, Time: 3.53, Learning Rate: 1.000e-06
# It: 2980, Loss: 3.109e-03, Y0: 6.954, Time: 3.56, Learning Rate: 1.000e-06
# It: 2990, Loss: 3.118e-03, Y0: 6.954, Time: 3.53, Learning Rate: 1.000e-06
#
# Predicted Y0: 6.9549
# Exact Y0:     7.2225
