# %% [markdown]
# ### Sistema Fully Coupled
# $$
# \begin{cases}
# dS_t =\mu(c-S_t)dt + \sigma_1dW^1_t\\
#
# dH_t = \mu(c-H_t)dt + \sigma_2 dW^2_t\\
#
# dV_t = a(X^2_t+bH_t+c e^{t}(Z^3_t\sigma_3^{-1}-X_t)/2)dt + \sigma_3 dW^3_t\\
#
# dX_t = V_t dt
#
# \end{cases}
# $$

# %% [markdown]
# ### Soluzione
# $$
#     u(t,s,h,v,x) = e^{-t}(e^s + e^{s}h + v^2 + xv)
# $$

# %%
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from abc import ABC, abstractmethod

class FBSNN(ABC): # Forward-Backward Stochastic Neural Network
    def __init__(self, Xi, T,
                       M, N, D,
                       layers):
        
        self.Xi = Xi # initial point
        self.T = T # terminal time
        
        self.M = M # number of trajectories
        self.N = N # number of time snapshots
        self.D = D # number of dimensions
        
        # layers
        self.layers = layers # (D+1) --> 1

        #MODIFICHE LIPPI
        #impostazioni modificabili
        activation = "sin"
        clip_grad_norm = 1.0
        use_antithetic_sampling = True
        path_loss_weight = 3.0
        terminal_y_loss_weight = 5.0
        terminal_z_loss_weight = 2.0

        #importo come parametri del modello
        self.activation = activation
        self.clip_grad_norm = clip_grad_norm
        self.use_antithetic_sampling = use_antithetic_sampling
        self.path_loss_weight = path_loss_weight
        self.terminal_y_loss_weight = terminal_y_loss_weight
        self.terminal_z_loss_weight = terminal_z_loss_weight
        
        # initialize NN
        self.weights, self.biases = self.initialize_NN(layers)
        
        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        # tf placeholders and graph (training)
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.t_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, 1]) # M x (N+1) x 1
        self.W_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, self.D]) # M x (N+1) x D
        self.Xi_tf = tf.placeholder(tf.float32, shape=[1, D]) # 1 x D

        self.loss, self.X_pred, self.Y_pred, self.Y0_pred = self.loss_function(self.t_tf, self.W_tf, self.Xi_tf)
                
        # optimizers
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.learning_rate)
        #self.train_op = self.optimizer.minimize(self.loss)
        #cambiamo il train_op per implementare il clipping
        gradients_and_variables = self.optimizer.compute_gradients(self.loss)
        if self.clip_grad_norm is not None:
            non_null_grads_and_vars = [(g, v) for g, v in gradients_and_variables if g is not None]
            if non_null_grads_and_vars:
                gradients, variables = zip(*non_null_grads_and_vars)
                gradients, _ = tf.clip_by_global_norm(gradients, self.clip_grad_norm)
                clipped = list(zip(gradients, variables))
                untouched = [(g, v) for g, v in gradients_and_variables if g is None]
                gradients_and_variables = clipped + untouched
        self.train_op = self.optimizer.apply_gradients(gradients_and_variables)
                
        # initialize session and variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
    
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases
        
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim],
                                               stddev=xavier_stddev), dtype=tf.float32)
    
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1
        
        H = X
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            pre_activation = tf.add(tf.matmul(H, W), b)
            if self.activation == "sin":
                H = tf.sin(pre_activation)
            elif self.activation == "tanh":
                H = tf.tanh(pre_activation)
            elif self.activation == "swish":
                H = pre_activation * tf.sigmoid(pre_activation)
            else:
                raise ValueError("Unsupported activation '{}'. Use: sin, tanh, swish".format(self.activation))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
    def net_u(self, t, X): # M x 1, M x D
        
        u = self.neural_net(tf.concat([t,X], 1), self.weights, self.biases) # M x 1
        Du = tf.gradients(u, X)[0] # M x D
        
        return u, Du

    def Dg_tf(self, X): # M x D
        return tf.gradients(self.g_tf(X), X)[0] # M x D
        
    def loss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        loss = 0
        X_list = []
        Y_list = []
        
        t0 = t[:,0,:]
        W0 = W[:,0,:]
        X0 = tf.tile(Xi,[self.M,1]) # M x D
        Y0, Z0 = self.net_u(t0,X0) # M x 1, M x D
        
        X_list.append(X0)
        Y_list.append(Y0)
        
        for n in range(0,self.N):
            t1 = t[:,n+1,:]
            W1 = W[:,n+1,:]
            X1 = X0 + self.mu_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.squeeze(tf.matmul(self.sigma_tf(t0,X0,Y0),tf.expand_dims(W1-W0,-1)), axis=[-1])
            Y1_tilde = Y0 + self.phi_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.reduce_sum(Z0*tf.squeeze(tf.matmul(self.sigma_tf(t0,X0,Y0),tf.expand_dims(W1-W0,-1))), axis=1, keepdims = True)
            Y1, Z1 = self.net_u(t1,X1)
            
            loss += self.path_loss_weight * tf.reduce_mean(tf.square(Y1 - Y1_tilde))

            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            
            X_list.append(X0)
            Y_list.append(Y0)
            
        loss += self.terminal_y_loss_weight * tf.reduce_mean(tf.square(Y1 - self.g_tf(X1)))
        loss += self.terminal_z_loss_weight * tf.reduce_mean(tf.square(Z1 - self.Dg_tf(X1)))

        X = tf.stack(X_list,axis=1)
        Y = tf.stack(Y_list,axis=1)
        
        return loss, X, Y, Y[0,0,0]

    def fetch_minibatch(self):
        T = self.T
        
        M = self.M
        N = self.N
        D = self.D
        
        Dt = np.zeros((M,N+1,1)) # M x (N+1) x 1
        DW = np.zeros((M,N+1,D)) # M x (N+1) x D
        
        dt = T/N
        
        Dt[:,1:,:] = dt
        if self.use_antithetic_sampling and M > 1:
            half_M = M // 2
            DW_half = np.sqrt(dt) * np.random.normal(size=(half_M, N, D))
            DW[:half_M,1:, :] = DW_half
            DW[half_M:2*half_M,1:, :] = -DW_half
            if M % 2 == 1:
                DW[-1,1:, :] = np.sqrt(dt) * np.random.normal(size=(N, D))
        else:
            DW[:,1:, :] = np.sqrt(dt)*np.random.normal(size=(M,N,D))
       
        t = np.cumsum(Dt,axis=1) # M x (N+1) x 1
        W = np.cumsum(DW,axis=1) # M x (N+1) x D
        
        return t, W
    
    def train(self, N_Iter, learning_rate):
        
        start_time = time.time()
        for it in range(N_Iter):
            
            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D
            
            tf_dict = {self.Xi_tf: self.Xi, self.t_tf: t_batch, self.W_tf: W_batch, self.learning_rate: learning_rate}
            
            self.sess.run(self.train_op, tf_dict)
            
            # Print
            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.loss, self.Y0_pred, self.learning_rate], tf_dict)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' % 
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()
                
    
    def predict(self, Xi_star, t_star, W_star):
        
        tf_dict = {self.Xi_tf: Xi_star, self.t_tf: t_star, self.W_tf: W_star}
        
        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        
        return X_star, Y_star
    
    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def phi_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        pass # M x1
    
    @abstractmethod
    def g_tf(self, X): # M x D
        pass # M x 1
    
    @abstractmethod
    def mu_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return np.zeros([M,D]) # M x D
    
    @abstractmethod
    def sigma_tf(self, t, X, Y): # M x 1, M x D, M x 1
        M = self.M
        D = self.D
        return tf.matrix_diag(tf.ones([M,D])) # M x D x D
    ###########################################################################
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class NN(FBSNN):
    def __init__(self, Xi, T, M, N, D, layers, parameters):
        self.mu = parameters['mu']
        self.c = parameters['c']
        self.b = parameters['b']
        self.a = parameters['a']
        self.s1 = parameters['s1']
        self.s2 = parameters['s2']
        self.s3 = parameters['s3']
        super().__init__(Xi, T, M, N, D, layers)
    
    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu = tf.cast(self.mu, tf.float32)
        c = tf.cast(self.c, tf.float32)
        a = tf.cast(self.a, tf.float32)
        b = tf.cast(self.b, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        #Accoppiamento
        #Z ha dimensione [M, D]. Le colonne sono nella forma
        #[Z_S, Z_H, Z_V, Z_X]
        Z_V = Z[:, 2:3]
        exp_t = tf.exp(t)
        V_from_Z = 0.5 * ((exp_t * Z_V / s3) - X_state)
        dS = mu * (c - S)
        dH = mu * (c - H)
        dV = self.a * (X_state**2 + b*H + c*V_from_Z)
        dX = V
        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        exp_T = tf.exp(-self.T)
        exp_S = tf.exp(S)
        val = exp_S + (exp_S * H) + (V**2) + (X_state*V)
        return exp_T * val

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)

        mu = tf.cast(self.mu, tf.float32)
        c = tf.cast(self.c, tf.float32)
        a = tf.cast(self.a, tf.float32)
        b = tf.cast(self.b, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        exp_minus_t = tf.exp(-t)
        exp_S = tf.exp(S)

        # Coupling coerente con mu_tf: V_from_Z, non V diretto
        Z_V = Z[:, 2:3]
        V_from_Z = 0.5 * ((tf.exp(t) * Z_V / s3) - X_state)

        term1 = (1.0 + H) * (mu * (c - S) * exp_S)
        term2 = mu * (c - H) * exp_S
        term3 = (2.0 * V + X_state) * (a * (X_state**2 + b * H + c * V_from_Z))
        term4 = V**2 + s3**2
        term5 = 0.5 * exp_S * (s1**2) * (1.0 + H)

        equation = term1 + term2 + term3 + term4 + term5
        return -(Y - exp_minus_t * equation)

    
    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)

        return tf.stack([r1, r2, r3, r4], axis=1)

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    M = 1024      
    N = 200      
    D = 4
    T = 1.0

    params = {
        'mu': np.float32(1.0),
        'c': np.float32(1.0),
        'b': np.float32(1.0),
        'a': np.float32(1.0),
        's1': np.float32(0.5),
        's2': np.float32(0.5),
        's3': np.float32(0.5),        
    }

    Xi = np.array([1.5, 0.5, 0.5, 0.5]).reshape(1, D)
    
    layers = [D+1] + 4*[256] + [1]
    
    model = NN(Xi, T, M, N, D, layers, params)

    print("===WARMUP===")
    model.train(N_Iter=1000, learning_rate=1e-3)

    print("=== Avvio training ===")
    model.train(N_Iter=6000, learning_rate=5e-4)
    model.train(N_Iter=6000, learning_rate=1e-4)
    model.train(N_Iter=4000, learning_rate=5e-5)
    model.train(N_Iter=4000, learning_rate=1e-5)
 

    # --- PLOTTING ---
    t_test, W_test = model.fetch_minibatch()
    X_pred, Y_pred = model.predict(Xi, t_test, W_test)

    def u_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X = Xi_arr[:, 3:4]
        # u = e^-t * (e^S + e^S*H + V^2 + X*V)
        return np.exp(-t) * (np.exp(S) + np.exp(S)*H + V**2 + X*V)
    
    Xi_reshaped = X_pred.reshape(-1, D)
    t_reshaped = t_test.reshape(-1, 1)
    
    # Calcolo soluzione esatta sui punti predetti
    Y_exact = u_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, 1)
    
    exact_Y0 = u_exact(np.array([[0.0]]), Xi)[0,0]
    print(f"\nPredicted Y0: {Y_pred[0,0,0]:.4f}")
    print(f"Exact Y0:     {exact_Y0:.4f}")
    
    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], Y_pred[0,:,0], 'b', label='Learned Y')
    plt.plot(t_test[0,:,0], Y_exact[0,:,0], 'r--', label='Exact Y')
    # Plot di altre traiettorie per vedere la varianza
    plt.plot(t_test[1:5,:,0].T, Y_pred[1:5,:,0].T, 'b')
    plt.plot(t_test[1:5,:,0].T, Y_exact[1:5,:,0].T, 'r--')
    plt.title("Soluzione Full-coupled 4D")
    plt.xlabel("Tempo t")
    plt.ylabel("Y_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
#
# ===WARMUP===
# It: 0, Loss: 4.450e+01, Y0: 0.376, Time: 57.01, Learning Rate: 1.000e-03
# It: 10, Loss: 5.063e+00, Y0: 1.596, Time: 4.27, Learning Rate: 1.000e-03
# It: 20, Loss: 1.521e+00, Y0: 2.872, Time: 3.91, Learning Rate: 1.000e-03
# It: 30, Loss: 1.984e+00, Y0: 2.294, Time: 3.92, Learning Rate: 1.000e-03
# It: 40, Loss: 1.814e+00, Y0: 2.563, Time: 4.26, Learning Rate: 1.000e-03
# It: 50, Loss: 1.247e+00, Y0: 2.828, Time: 3.98, Learning Rate: 1.000e-03
# It: 60, Loss: 1.992e+00, Y0: 3.035, Time: 3.98, Learning Rate: 1.000e-03
# It: 70, Loss: 3.686e+00, Y0: 3.172, Time: 4.34, Learning Rate: 1.000e-03
# It: 80, Loss: 1.508e+00, Y0: 3.605, Time: 3.98, Learning Rate: 1.000e-03
# It: 90, Loss: 1.081e+00, Y0: 3.818, Time: 4.01, Learning Rate: 1.000e-03
# It: 100, Loss: 1.197e+00, Y0: 3.668, Time: 4.40, Learning Rate: 1.000e-03
# It: 110, Loss: 1.064e+00, Y0: 3.838, Time: 4.03, Learning Rate: 1.000e-03
# It: 120, Loss: 1.377e+00, Y0: 4.164, Time: 4.23, Learning Rate: 1.000e-03
# It: 130, Loss: 7.794e-01, Y0: 4.055, Time: 4.19, Learning Rate: 1.000e-03
# It: 140, Loss: 9.020e-01, Y0: 4.186, Time: 4.03, Learning Rate: 1.000e-03
# It: 150, Loss: 1.443e+00, Y0: 4.369, Time: 4.37, Learning Rate: 1.000e-03
# It: 160, Loss: 8.892e-01, Y0: 4.556, Time: 4.10, Learning Rate: 1.000e-03
# It: 170, Loss: 1.008e+00, Y0: 4.822, Time: 4.05, Learning Rate: 1.000e-03
# It: 180, Loss: 1.111e+00, Y0: 5.272, Time: 4.39, Learning Rate: 1.000e-03
# It: 190, Loss: 5.248e-01, Y0: 5.167, Time: 4.07, Learning Rate: 1.000e-03
# It: 200, Loss: 5.914e-01, Y0: 5.468, Time: 4.03, Learning Rate: 1.000e-03
# It: 210, Loss: 8.766e-01, Y0: 5.675, Time: 4.38, Learning Rate: 1.000e-03
# It: 220, Loss: 3.425e-01, Y0: 5.864, Time: 3.99, Learning Rate: 1.000e-03
# It: 230, Loss: 3.359e-01, Y0: 6.229, Time: 4.23, Learning Rate: 1.000e-03
# It: 240, Loss: 4.813e-01, Y0: 6.703, Time: 4.16, Learning Rate: 1.000e-03
# It: 250, Loss: 4.197e-01, Y0: 6.565, Time: 4.02, Learning Rate: 1.000e-03
# It: 260, Loss: 2.939e-01, Y0: 6.623, Time: 4.35, Learning Rate: 1.000e-03
# It: 270, Loss: 2.564e-01, Y0: 6.762, Time: 4.00, Learning Rate: 1.000e-03
# It: 280, Loss: 2.347e-01, Y0: 6.757, Time: 4.01, Learning Rate: 1.000e-03
# It: 290, Loss: 1.934e+00, Y0: 6.675, Time: 4.40, Learning Rate: 1.000e-03
# It: 300, Loss: 5.693e-01, Y0: 6.897, Time: 4.00, Learning Rate: 1.000e-03
# It: 310, Loss: 5.134e-01, Y0: 6.585, Time: 4.02, Learning Rate: 1.000e-03
# It: 320, Loss: 3.355e-01, Y0: 6.534, Time: 4.37, Learning Rate: 1.000e-03
# It: 330, Loss: 2.180e-01, Y0: 6.516, Time: 4.05, Learning Rate: 1.000e-03
# It: 340, Loss: 5.709e-01, Y0: 6.786, Time: 4.12, Learning Rate: 1.000e-03
# It: 350, Loss: 3.345e-01, Y0: 6.829, Time: 4.22, Learning Rate: 1.000e-03
# It: 360, Loss: 2.122e-01, Y0: 6.730, Time: 4.04, Learning Rate: 1.000e-03
# It: 370, Loss: 2.013e-01, Y0: 6.848, Time: 4.39, Learning Rate: 1.000e-03
# It: 380, Loss: 2.384e-01, Y0: 6.665, Time: 4.02, Learning Rate: 1.000e-03
# It: 390, Loss: 2.385e-01, Y0: 6.857, Time: 4.03, Learning Rate: 1.000e-03
# It: 400, Loss: 3.054e-01, Y0: 6.804, Time: 4.40, Learning Rate: 1.000e-03
# It: 410, Loss: 2.535e-01, Y0: 6.726, Time: 4.02, Learning Rate: 1.000e-03
# It: 420, Loss: 1.934e-01, Y0: 6.673, Time: 4.02, Learning Rate: 1.000e-03
# It: 430, Loss: 3.027e-01, Y0: 6.994, Time: 4.31, Learning Rate: 1.000e-03
# It: 440, Loss: 3.691e-01, Y0: 6.599, Time: 4.03, Learning Rate: 1.000e-03
# It: 450, Loss: 2.180e-01, Y0: 6.886, Time: 4.04, Learning Rate: 1.000e-03
# It: 460, Loss: 2.690e-01, Y0: 6.882, Time: 4.29, Learning Rate: 1.000e-03
# It: 470, Loss: 2.974e-01, Y0: 6.676, Time: 4.03, Learning Rate: 1.000e-03
# It: 480, Loss: 2.238e-01, Y0: 6.915, Time: 4.28, Learning Rate: 1.000e-03
# It: 490, Loss: 2.634e-01, Y0: 6.965, Time: 4.07, Learning Rate: 1.000e-03
# It: 500, Loss: 3.266e-01, Y0: 6.724, Time: 4.04, Learning Rate: 1.000e-03
# It: 510, Loss: 2.264e-01, Y0: 6.947, Time: 4.34, Learning Rate: 1.000e-03
# It: 520, Loss: 2.624e-01, Y0: 6.992, Time: 4.05, Learning Rate: 1.000e-03
# It: 530, Loss: 3.224e-01, Y0: 6.733, Time: 4.02, Learning Rate: 1.000e-03
# It: 540, Loss: 2.154e-01, Y0: 7.014, Time: 4.38, Learning Rate: 1.000e-03
# It: 550, Loss: 2.438e-01, Y0: 7.018, Time: 4.03, Learning Rate: 1.000e-03
# It: 560, Loss: 2.816e-01, Y0: 6.763, Time: 4.01, Learning Rate: 1.000e-03
# It: 570, Loss: 2.102e-01, Y0: 7.006, Time: 4.36, Learning Rate: 1.000e-03
# It: 580, Loss: 2.372e-01, Y0: 7.087, Time: 4.03, Learning Rate: 1.000e-03
# It: 590, Loss: 2.517e-01, Y0: 6.811, Time: 4.19, Learning Rate: 1.000e-03
# It: 600, Loss: 1.907e-01, Y0: 7.063, Time: 4.13, Learning Rate: 1.000e-03
# It: 610, Loss: 2.270e-01, Y0: 7.151, Time: 4.06, Learning Rate: 1.000e-03
# It: 620, Loss: 2.607e-01, Y0: 6.841, Time: 4.42, Learning Rate: 1.000e-03
# It: 630, Loss: 1.554e-01, Y0: 7.163, Time: 4.04, Learning Rate: 1.000e-03
# It: 640, Loss: 1.760e-01, Y0: 7.124, Time: 4.04, Learning Rate: 1.000e-03
# It: 650, Loss: 1.484e-01, Y0: 6.801, Time: 4.34, Learning Rate: 1.000e-03
# It: 660, Loss: 1.052e-01, Y0: 7.113, Time: 4.03, Learning Rate: 1.000e-03
# It: 670, Loss: 1.112e-01, Y0: 7.207, Time: 4.03, Learning Rate: 1.000e-03
# It: 680, Loss: 9.130e-02, Y0: 7.243, Time: 4.41, Learning Rate: 1.000e-03
# It: 690, Loss: 9.026e-02, Y0: 7.083, Time: 4.05, Learning Rate: 1.000e-03
# It: 700, Loss: 2.555e-01, Y0: 6.850, Time: 4.19, Learning Rate: 1.000e-03
# It: 710, Loss: 9.316e-02, Y0: 7.116, Time: 4.15, Learning Rate: 1.000e-03
# It: 720, Loss: 2.886e-01, Y0: 7.152, Time: 4.05, Learning Rate: 1.000e-03
# It: 730, Loss: 3.428e-01, Y0: 7.073, Time: 4.36, Learning Rate: 1.000e-03
# It: 740, Loss: 3.194e-01, Y0: 7.435, Time: 4.04, Learning Rate: 1.000e-03
# It: 750, Loss: 2.381e-01, Y0: 7.236, Time: 4.11, Learning Rate: 1.000e-03
# It: 760, Loss: 1.387e-01, Y0: 7.005, Time: 4.33, Learning Rate: 1.000e-03
# It: 770, Loss: 1.129e-01, Y0: 7.023, Time: 4.06, Learning Rate: 1.000e-03
# It: 780, Loss: 1.000e-01, Y0: 7.282, Time: 4.02, Learning Rate: 1.000e-03
# It: 790, Loss: 1.026e-01, Y0: 7.237, Time: 4.40, Learning Rate: 1.000e-03
# It: 800, Loss: 1.020e-01, Y0: 7.397, Time: 4.04, Learning Rate: 1.000e-03
# It: 810, Loss: 9.720e-02, Y0: 7.163, Time: 4.21, Learning Rate: 1.000e-03
# It: 820, Loss: 1.141e-01, Y0: 7.265, Time: 4.19, Learning Rate: 1.000e-03
# It: 830, Loss: 9.038e-02, Y0: 7.244, Time: 4.05, Learning Rate: 1.000e-03
# It: 840, Loss: 1.367e-01, Y0: 7.297, Time: 4.36, Learning Rate: 1.000e-03
# It: 850, Loss: 9.910e-02, Y0: 7.246, Time: 4.03, Learning Rate: 1.000e-03
# It: 860, Loss: 8.773e-02, Y0: 7.341, Time: 4.04, Learning Rate: 1.000e-03
# It: 870, Loss: 9.700e-02, Y0: 7.225, Time: 4.35, Learning Rate: 1.000e-03
# It: 880, Loss: 9.786e-02, Y0: 7.310, Time: 4.03, Learning Rate: 1.000e-03
# It: 890, Loss: 8.156e-02, Y0: 7.196, Time: 4.05, Learning Rate: 1.000e-03
# It: 900, Loss: 1.045e-01, Y0: 7.327, Time: 4.34, Learning Rate: 1.000e-03
# It: 910, Loss: 7.970e-02, Y0: 7.238, Time: 4.03, Learning Rate: 1.000e-03
# It: 920, Loss: 9.632e-02, Y0: 7.308, Time: 4.18, Learning Rate: 1.000e-03
# It: 930, Loss: 8.457e-02, Y0: 7.197, Time: 4.24, Learning Rate: 1.000e-03
# It: 940, Loss: 8.549e-02, Y0: 7.329, Time: 4.05, Learning Rate: 1.000e-03
# It: 950, Loss: 9.049e-02, Y0: 7.269, Time: 4.36, Learning Rate: 1.000e-03
# It: 960, Loss: 7.798e-02, Y0: 7.340, Time: 4.06, Learning Rate: 1.000e-03
# It: 970, Loss: 9.198e-02, Y0: 7.252, Time: 4.12, Learning Rate: 1.000e-03
# It: 980, Loss: 9.316e-02, Y0: 7.300, Time: 4.44, Learning Rate: 1.000e-03
# It: 990, Loss: 8.348e-02, Y0: 7.243, Time: 4.07, Learning Rate: 1.000e-03
# === Avvio training ===
# It: 0, Loss: 6.155e-02, Y0: 7.289, Time: 0.40, Learning Rate: 5.000e-04
# It: 10, Loss: 8.799e-02, Y0: 7.141, Time: 4.39, Learning Rate: 5.000e-04
# It: 20, Loss: 6.306e-02, Y0: 7.186, Time: 4.00, Learning Rate: 5.000e-04
# It: 30, Loss: 5.660e-02, Y0: 7.266, Time: 4.23, Learning Rate: 5.000e-04
# It: 40, Loss: 6.647e-02, Y0: 7.351, Time: 4.25, Learning Rate: 5.000e-04
# It: 50, Loss: 8.623e-02, Y0: 7.198, Time: 4.04, Learning Rate: 5.000e-04
# It: 60, Loss: 7.560e-02, Y0: 7.280, Time: 4.34, Learning Rate: 5.000e-04
# It: 70, Loss: 6.059e-02, Y0: 7.212, Time: 4.09, Learning Rate: 5.000e-04
# It: 80, Loss: 6.311e-02, Y0: 7.273, Time: 4.03, Learning Rate: 5.000e-04
# It: 90, Loss: 6.412e-02, Y0: 7.238, Time: 4.42, Learning Rate: 5.000e-04
# It: 100, Loss: 5.355e-02, Y0: 7.265, Time: 4.06, Learning Rate: 5.000e-04
# It: 110, Loss: 5.975e-02, Y0: 7.253, Time: 4.05, Learning Rate: 5.000e-04
# It: 120, Loss: 6.224e-02, Y0: 7.318, Time: 4.35, Learning Rate: 5.000e-04
# It: 130, Loss: 6.277e-02, Y0: 7.260, Time: 4.05, Learning Rate: 5.000e-04
# It: 140, Loss: 5.997e-02, Y0: 7.296, Time: 4.21, Learning Rate: 5.000e-04
# It: 150, Loss: 6.197e-02, Y0: 7.253, Time: 4.19, Learning Rate: 5.000e-04
# It: 160, Loss: 5.457e-02, Y0: 7.251, Time: 4.04, Learning Rate: 5.000e-04
# It: 170, Loss: 5.754e-02, Y0: 7.221, Time: 4.40, Learning Rate: 5.000e-04
# It: 180, Loss: 8.066e-02, Y0: 7.292, Time: 4.02, Learning Rate: 5.000e-04
# It: 190, Loss: 5.437e-02, Y0: 7.239, Time: 4.02, Learning Rate: 5.000e-04
# It: 200, Loss: 5.113e-02, Y0: 7.289, Time: 4.35, Learning Rate: 5.000e-04
# It: 210, Loss: 6.247e-02, Y0: 7.267, Time: 4.04, Learning Rate: 5.000e-04
# It: 220, Loss: 5.746e-02, Y0: 7.299, Time: 4.06, Learning Rate: 5.000e-04
# It: 230, Loss: 6.085e-02, Y0: 7.225, Time: 4.45, Learning Rate: 5.000e-04
# It: 240, Loss: 6.038e-02, Y0: 7.330, Time: 4.02, Learning Rate: 5.000e-04
# It: 250, Loss: 5.447e-02, Y0: 7.259, Time: 4.14, Learning Rate: 5.000e-04
# It: 260, Loss: 5.102e-02, Y0: 7.277, Time: 4.22, Learning Rate: 5.000e-04
# It: 270, Loss: 6.554e-02, Y0: 7.250, Time: 4.05, Learning Rate: 5.000e-04
# It: 280, Loss: 5.463e-02, Y0: 7.272, Time: 4.45, Learning Rate: 5.000e-04
# It: 290, Loss: 5.217e-02, Y0: 7.284, Time: 4.00, Learning Rate: 5.000e-04
# It: 300, Loss: 5.370e-02, Y0: 7.237, Time: 4.05, Learning Rate: 5.000e-04
# It: 310, Loss: 5.452e-02, Y0: 7.242, Time: 4.35, Learning Rate: 5.000e-04
# It: 320, Loss: 5.505e-02, Y0: 7.266, Time: 4.02, Learning Rate: 5.000e-04
# It: 330, Loss: 4.288e-02, Y0: 7.200, Time: 4.04, Learning Rate: 5.000e-04
# It: 340, Loss: 4.998e-02, Y0: 7.302, Time: 4.44, Learning Rate: 5.000e-04
# It: 350, Loss: 5.761e-02, Y0: 7.265, Time: 4.04, Learning Rate: 5.000e-04
# It: 360, Loss: 5.265e-02, Y0: 7.291, Time: 4.11, Learning Rate: 5.000e-04
# It: 370, Loss: 5.193e-02, Y0: 7.278, Time: 4.26, Learning Rate: 5.000e-04
# It: 380, Loss: 5.871e-02, Y0: 7.253, Time: 4.06, Learning Rate: 5.000e-04
# It: 390, Loss: 5.352e-02, Y0: 7.222, Time: 4.37, Learning Rate: 5.000e-04
# It: 400, Loss: 4.770e-02, Y0: 7.233, Time: 4.01, Learning Rate: 5.000e-04
# It: 410, Loss: 5.128e-02, Y0: 7.315, Time: 4.03, Learning Rate: 5.000e-04
# It: 420, Loss: 4.837e-02, Y0: 7.265, Time: 4.44, Learning Rate: 5.000e-04
# It: 430, Loss: 5.801e-02, Y0: 7.238, Time: 4.02, Learning Rate: 5.000e-04
# It: 440, Loss: 4.559e-02, Y0: 7.237, Time: 4.03, Learning Rate: 5.000e-04
# It: 450, Loss: 5.737e-02, Y0: 7.213, Time: 4.40, Learning Rate: 5.000e-04
# It: 460, Loss: 4.630e-02, Y0: 7.339, Time: 4.04, Learning Rate: 5.000e-04
# It: 470, Loss: 4.710e-02, Y0: 7.259, Time: 4.17, Learning Rate: 5.000e-04
# It: 480, Loss: 5.487e-02, Y0: 7.281, Time: 4.27, Learning Rate: 5.000e-04
# It: 490, Loss: 4.533e-02, Y0: 7.252, Time: 4.04, Learning Rate: 5.000e-04
# It: 500, Loss: 5.523e-02, Y0: 7.260, Time: 4.29, Learning Rate: 5.000e-04
# It: 510, Loss: 4.686e-02, Y0: 7.205, Time: 4.02, Learning Rate: 5.000e-04
# It: 520, Loss: 4.285e-02, Y0: 7.306, Time: 4.04, Learning Rate: 5.000e-04
# It: 530, Loss: 5.659e-02, Y0: 7.209, Time: 4.41, Learning Rate: 5.000e-04
# It: 540, Loss: 4.560e-02, Y0: 7.194, Time: 4.03, Learning Rate: 5.000e-04
# It: 550, Loss: 4.778e-02, Y0: 7.256, Time: 4.01, Learning Rate: 5.000e-04
# It: 560, Loss: 4.808e-02, Y0: 7.259, Time: 4.34, Learning Rate: 5.000e-04
# It: 570, Loss: 4.580e-02, Y0: 7.246, Time: 4.04, Learning Rate: 5.000e-04
# It: 580, Loss: 4.862e-02, Y0: 7.208, Time: 4.02, Learning Rate: 5.000e-04
# It: 590, Loss: 5.679e-02, Y0: 7.214, Time: 4.33, Learning Rate: 5.000e-04
# It: 600, Loss: 4.684e-02, Y0: 7.256, Time: 4.02, Learning Rate: 5.000e-04
# It: 610, Loss: 4.424e-02, Y0: 7.206, Time: 4.28, Learning Rate: 5.000e-04
# It: 620, Loss: 5.036e-02, Y0: 7.219, Time: 4.07, Learning Rate: 5.000e-04
# It: 630, Loss: 5.260e-02, Y0: 7.252, Time: 4.04, Learning Rate: 5.000e-04
# It: 640, Loss: 4.330e-02, Y0: 7.234, Time: 4.31, Learning Rate: 5.000e-04
# It: 650, Loss: 1.151e-01, Y0: 7.175, Time: 4.03, Learning Rate: 5.000e-04
# It: 660, Loss: 6.749e-02, Y0: 7.246, Time: 4.03, Learning Rate: 5.000e-04
# It: 670, Loss: 4.283e-02, Y0: 7.247, Time: 4.41, Learning Rate: 5.000e-04
# It: 680, Loss: 4.672e-02, Y0: 7.196, Time: 4.04, Learning Rate: 5.000e-04
# It: 690, Loss: 4.329e-02, Y0: 7.184, Time: 4.04, Learning Rate: 5.000e-04
# It: 700, Loss: 4.324e-02, Y0: 7.203, Time: 4.35, Learning Rate: 5.000e-04
# It: 710, Loss: 4.634e-02, Y0: 7.201, Time: 4.03, Learning Rate: 5.000e-04
# It: 720, Loss: 4.104e-02, Y0: 7.274, Time: 4.24, Learning Rate: 5.000e-04
# It: 730, Loss: 4.920e-02, Y0: 7.161, Time: 4.16, Learning Rate: 5.000e-04
# It: 740, Loss: 3.952e-02, Y0: 7.222, Time: 4.05, Learning Rate: 5.000e-04
# It: 750, Loss: 4.009e-02, Y0: 7.179, Time: 4.33, Learning Rate: 5.000e-04
# It: 760, Loss: 4.222e-02, Y0: 7.229, Time: 4.04, Learning Rate: 5.000e-04
# It: 770, Loss: 4.176e-02, Y0: 7.186, Time: 4.04, Learning Rate: 5.000e-04
# It: 780, Loss: 4.028e-02, Y0: 7.207, Time: 4.38, Learning Rate: 5.000e-04
# It: 790, Loss: 4.254e-02, Y0: 7.177, Time: 4.03, Learning Rate: 5.000e-04
# It: 800, Loss: 3.814e-02, Y0: 7.252, Time: 4.03, Learning Rate: 5.000e-04
# It: 810, Loss: 4.331e-02, Y0: 7.164, Time: 4.32, Learning Rate: 5.000e-04
# It: 820, Loss: 4.124e-02, Y0: 7.216, Time: 4.02, Learning Rate: 5.000e-04
# It: 830, Loss: 3.745e-02, Y0: 7.146, Time: 4.15, Learning Rate: 5.000e-04
# It: 840, Loss: 4.009e-02, Y0: 7.274, Time: 4.16, Learning Rate: 5.000e-04
# It: 850, Loss: 4.170e-02, Y0: 7.225, Time: 4.04, Learning Rate: 5.000e-04
# It: 860, Loss: 3.876e-02, Y0: 7.201, Time: 4.32, Learning Rate: 5.000e-04
# It: 870, Loss: 4.034e-02, Y0: 7.179, Time: 4.02, Learning Rate: 5.000e-04
# It: 880, Loss: 4.144e-02, Y0: 7.259, Time: 4.05, Learning Rate: 5.000e-04
# It: 890, Loss: 3.657e-02, Y0: 7.200, Time: 4.37, Learning Rate: 5.000e-04
# It: 900, Loss: 3.750e-02, Y0: 7.169, Time: 4.04, Learning Rate: 5.000e-04
# It: 910, Loss: 3.629e-02, Y0: 7.184, Time: 4.05, Learning Rate: 5.000e-04
# It: 920, Loss: 3.619e-02, Y0: 7.260, Time: 4.40, Learning Rate: 5.000e-04
# It: 930, Loss: 4.439e-02, Y0: 7.206, Time: 4.04, Learning Rate: 5.000e-04
# It: 940, Loss: 3.961e-02, Y0: 7.212, Time: 4.22, Learning Rate: 5.000e-04
# It: 950, Loss: 3.950e-02, Y0: 7.130, Time: 4.21, Learning Rate: 5.000e-04
# It: 960, Loss: 3.674e-02, Y0: 7.227, Time: 4.02, Learning Rate: 5.000e-04
# It: 970, Loss: 4.056e-02, Y0: 7.179, Time: 4.33, Learning Rate: 5.000e-04
# It: 980, Loss: 3.771e-02, Y0: 7.242, Time: 4.04, Learning Rate: 5.000e-04
# It: 990, Loss: 3.428e-02, Y0: 7.183, Time: 4.09, Learning Rate: 5.000e-04
# It: 1000, Loss: 3.352e-02, Y0: 7.234, Time: 4.36, Learning Rate: 5.000e-04
# It: 1010, Loss: 4.145e-02, Y0: 7.248, Time: 4.04, Learning Rate: 5.000e-04
# It: 1020, Loss: 3.594e-02, Y0: 7.183, Time: 4.08, Learning Rate: 5.000e-04
# It: 1030, Loss: 3.530e-02, Y0: 7.148, Time: 4.41, Learning Rate: 5.000e-04
# It: 1040, Loss: 3.275e-02, Y0: 7.210, Time: 4.07, Learning Rate: 5.000e-04
# It: 1050, Loss: 4.797e-02, Y0: 7.266, Time: 4.20, Learning Rate: 5.000e-04
# It: 1060, Loss: 3.243e-02, Y0: 7.270, Time: 4.16, Learning Rate: 5.000e-04
# It: 1070, Loss: 4.487e-02, Y0: 7.206, Time: 4.02, Learning Rate: 5.000e-04
# It: 1080, Loss: 3.414e-02, Y0: 7.279, Time: 4.32, Learning Rate: 5.000e-04
# It: 1090, Loss: 3.736e-02, Y0: 7.160, Time: 4.08, Learning Rate: 5.000e-04
# It: 1100, Loss: 3.149e-02, Y0: 7.218, Time: 4.03, Learning Rate: 5.000e-04
# It: 1110, Loss: 3.686e-02, Y0: 7.258, Time: 4.36, Learning Rate: 5.000e-04
# It: 1120, Loss: 3.163e-02, Y0: 7.226, Time: 4.01, Learning Rate: 5.000e-04
# It: 1130, Loss: 4.366e-02, Y0: 7.206, Time: 4.03, Learning Rate: 5.000e-04
# It: 1140, Loss: 3.246e-02, Y0: 7.241, Time: 4.31, Learning Rate: 5.000e-04
# It: 1150, Loss: 3.716e-02, Y0: 7.213, Time: 4.06, Learning Rate: 5.000e-04
# It: 1160, Loss: 3.450e-02, Y0: 7.260, Time: 4.20, Learning Rate: 5.000e-04
# It: 1170, Loss: 3.100e-02, Y0: 7.184, Time: 4.22, Learning Rate: 5.000e-04
# It: 1180, Loss: 3.453e-02, Y0: 7.229, Time: 4.04, Learning Rate: 5.000e-04
# It: 1190, Loss: 3.022e-02, Y0: 7.215, Time: 4.35, Learning Rate: 5.000e-04
# It: 1200, Loss: 3.699e-02, Y0: 7.299, Time: 4.03, Learning Rate: 5.000e-04
# It: 1210, Loss: 3.358e-02, Y0: 7.189, Time: 4.03, Learning Rate: 5.000e-04
# It: 1220, Loss: 3.377e-02, Y0: 7.265, Time: 4.31, Learning Rate: 5.000e-04
# It: 1230, Loss: 3.261e-02, Y0: 7.230, Time: 4.02, Learning Rate: 5.000e-04
# It: 1240, Loss: 2.843e-02, Y0: 7.292, Time: 4.03, Learning Rate: 5.000e-04
# It: 1250, Loss: 3.404e-02, Y0: 7.201, Time: 4.38, Learning Rate: 5.000e-04
# It: 1260, Loss: 4.811e-02, Y0: 7.305, Time: 4.04, Learning Rate: 5.000e-04
# It: 1270, Loss: 3.370e-02, Y0: 7.237, Time: 4.11, Learning Rate: 5.000e-04
# It: 1280, Loss: 3.289e-02, Y0: 7.253, Time: 4.20, Learning Rate: 5.000e-04
# It: 1290, Loss: 3.269e-02, Y0: 7.253, Time: 4.02, Learning Rate: 5.000e-04
# It: 1300, Loss: 3.023e-02, Y0: 7.267, Time: 4.30, Learning Rate: 5.000e-04
# It: 1310, Loss: 3.219e-02, Y0: 7.261, Time: 4.03, Learning Rate: 5.000e-04
# It: 1320, Loss: 3.658e-02, Y0: 7.302, Time: 4.03, Learning Rate: 5.000e-04
# It: 1330, Loss: 2.810e-02, Y0: 7.176, Time: 4.40, Learning Rate: 5.000e-04
# It: 1340, Loss: 3.019e-02, Y0: 7.205, Time: 4.05, Learning Rate: 5.000e-04
# It: 1350, Loss: 3.071e-02, Y0: 7.267, Time: 4.03, Learning Rate: 5.000e-04
# It: 1360, Loss: 2.849e-02, Y0: 7.303, Time: 4.36, Learning Rate: 5.000e-04
# It: 1370, Loss: 3.065e-02, Y0: 7.215, Time: 4.04, Learning Rate: 5.000e-04
# It: 1380, Loss: 2.825e-02, Y0: 7.279, Time: 4.13, Learning Rate: 5.000e-04
# It: 1390, Loss: 2.624e-02, Y0: 7.204, Time: 4.28, Learning Rate: 5.000e-04
# It: 1400, Loss: 2.963e-02, Y0: 7.281, Time: 4.04, Learning Rate: 5.000e-04
# It: 1410, Loss: 3.026e-02, Y0: 7.207, Time: 4.31, Learning Rate: 5.000e-04
# It: 1420, Loss: 2.710e-02, Y0: 7.246, Time: 4.07, Learning Rate: 5.000e-04
# It: 1430, Loss: 2.981e-02, Y0: 7.216, Time: 4.05, Learning Rate: 5.000e-04
# It: 1440, Loss: 3.093e-02, Y0: 7.318, Time: 4.44, Learning Rate: 5.000e-04
# It: 1450, Loss: 3.054e-02, Y0: 7.225, Time: 4.07, Learning Rate: 5.000e-04
# It: 1460, Loss: 2.629e-02, Y0: 7.281, Time: 4.05, Learning Rate: 5.000e-04
# It: 1470, Loss: 5.334e-02, Y0: 7.210, Time: 4.34, Learning Rate: 5.000e-04
# It: 1480, Loss: 3.159e-02, Y0: 7.290, Time: 4.01, Learning Rate: 5.000e-04
# It: 1490, Loss: 2.647e-02, Y0: 7.197, Time: 4.11, Learning Rate: 5.000e-04
# It: 1500, Loss: 3.406e-02, Y0: 7.234, Time: 4.29, Learning Rate: 5.000e-04
# It: 1510, Loss: 3.032e-02, Y0: 7.259, Time: 4.06, Learning Rate: 5.000e-04
# It: 1520, Loss: 3.119e-02, Y0: 7.277, Time: 4.30, Learning Rate: 5.000e-04
# It: 1530, Loss: 2.911e-02, Y0: 7.284, Time: 4.05, Learning Rate: 5.000e-04
# It: 1540, Loss: 3.385e-02, Y0: 7.300, Time: 4.04, Learning Rate: 5.000e-04
# It: 1550, Loss: 2.741e-02, Y0: 7.278, Time: 4.44, Learning Rate: 5.000e-04
# It: 1560, Loss: 3.054e-02, Y0: 7.303, Time: 4.04, Learning Rate: 5.000e-04
# It: 1570, Loss: 2.399e-02, Y0: 7.203, Time: 4.03, Learning Rate: 5.000e-04
# It: 1580, Loss: 2.627e-02, Y0: 7.315, Time: 4.37, Learning Rate: 5.000e-04
# It: 1590, Loss: 3.709e-02, Y0: 7.161, Time: 4.07, Learning Rate: 5.000e-04
# It: 1600, Loss: 3.091e-02, Y0: 7.319, Time: 4.10, Learning Rate: 5.000e-04
# It: 1610, Loss: 2.910e-02, Y0: 7.185, Time: 4.32, Learning Rate: 5.000e-04
# It: 1620, Loss: 2.680e-02, Y0: 7.270, Time: 4.05, Learning Rate: 5.000e-04
# It: 1630, Loss: 2.734e-02, Y0: 7.188, Time: 4.25, Learning Rate: 5.000e-04
# It: 1640, Loss: 2.410e-02, Y0: 7.177, Time: 4.03, Learning Rate: 5.000e-04
# It: 1650, Loss: 4.827e-02, Y0: 7.370, Time: 4.07, Learning Rate: 5.000e-04
# It: 1660, Loss: 3.549e-02, Y0: 7.436, Time: 4.39, Learning Rate: 5.000e-04
# It: 1670, Loss: 4.741e-02, Y0: 7.078, Time: 4.03, Learning Rate: 5.000e-04
# It: 1680, Loss: 4.110e-02, Y0: 7.328, Time: 4.05, Learning Rate: 5.000e-04
# It: 1690, Loss: 5.393e-02, Y0: 7.355, Time: 4.38, Learning Rate: 5.000e-04
# It: 1700, Loss: 6.531e-02, Y0: 7.197, Time: 4.04, Learning Rate: 5.000e-04
# It: 1710, Loss: 5.625e-02, Y0: 7.173, Time: 4.10, Learning Rate: 5.000e-04
# It: 1720, Loss: 3.870e-02, Y0: 7.272, Time: 4.29, Learning Rate: 5.000e-04
# It: 1730, Loss: 2.925e-02, Y0: 7.314, Time: 4.05, Learning Rate: 5.000e-04
# It: 1740, Loss: 2.686e-02, Y0: 7.284, Time: 4.29, Learning Rate: 5.000e-04
# It: 1750, Loss: 2.220e-02, Y0: 7.225, Time: 4.04, Learning Rate: 5.000e-04
# It: 1760, Loss: 2.223e-02, Y0: 7.238, Time: 4.02, Learning Rate: 5.000e-04
# It: 1770, Loss: 2.443e-02, Y0: 7.293, Time: 4.36, Learning Rate: 5.000e-04
# It: 1780, Loss: 2.787e-02, Y0: 7.207, Time: 4.02, Learning Rate: 5.000e-04
# It: 1790, Loss: 2.343e-02, Y0: 7.234, Time: 4.05, Learning Rate: 5.000e-04
# It: 1800, Loss: 2.323e-02, Y0: 7.196, Time: 4.38, Learning Rate: 5.000e-04
# It: 1810, Loss: 2.487e-02, Y0: 7.253, Time: 4.05, Learning Rate: 5.000e-04
# It: 1820, Loss: 2.778e-02, Y0: 7.268, Time: 4.03, Learning Rate: 5.000e-04
# It: 1830, Loss: 2.412e-02, Y0: 7.264, Time: 4.27, Learning Rate: 5.000e-04
# It: 1840, Loss: 2.248e-02, Y0: 7.244, Time: 4.02, Learning Rate: 5.000e-04
# It: 1850, Loss: 2.945e-02, Y0: 7.256, Time: 4.24, Learning Rate: 5.000e-04
# It: 1860, Loss: 2.049e-02, Y0: 7.209, Time: 4.12, Learning Rate: 5.000e-04
# It: 1870, Loss: 2.398e-02, Y0: 7.254, Time: 4.01, Learning Rate: 5.000e-04
# It: 1880, Loss: 2.266e-02, Y0: 7.190, Time: 4.38, Learning Rate: 5.000e-04
# It: 1890, Loss: 2.437e-02, Y0: 7.293, Time: 4.01, Learning Rate: 5.000e-04
# It: 1900, Loss: 2.252e-02, Y0: 7.220, Time: 4.02, Learning Rate: 5.000e-04
# It: 1910, Loss: 2.558e-02, Y0: 7.254, Time: 4.30, Learning Rate: 5.000e-04
# It: 1920, Loss: 2.237e-02, Y0: 7.240, Time: 4.06, Learning Rate: 5.000e-04
# It: 1930, Loss: 2.431e-02, Y0: 7.249, Time: 4.06, Learning Rate: 5.000e-04
# It: 1940, Loss: 2.361e-02, Y0: 7.221, Time: 4.38, Learning Rate: 5.000e-04
# It: 1950, Loss: 2.415e-02, Y0: 7.251, Time: 4.03, Learning Rate: 5.000e-04
# It: 1960, Loss: 2.310e-02, Y0: 7.196, Time: 4.20, Learning Rate: 5.000e-04
# It: 1970, Loss: 2.184e-02, Y0: 7.240, Time: 4.13, Learning Rate: 5.000e-04
# It: 1980, Loss: 2.303e-02, Y0: 7.235, Time: 4.04, Learning Rate: 5.000e-04
# It: 1990, Loss: 2.502e-02, Y0: 7.297, Time: 4.34, Learning Rate: 5.000e-04
# It: 2000, Loss: 2.475e-02, Y0: 7.164, Time: 4.04, Learning Rate: 5.000e-04
# It: 2010, Loss: 2.347e-02, Y0: 7.311, Time: 4.03, Learning Rate: 5.000e-04
# It: 2020, Loss: 2.176e-02, Y0: 7.214, Time: 4.40, Learning Rate: 5.000e-04
# It: 2030, Loss: 2.228e-02, Y0: 7.224, Time: 4.04, Learning Rate: 5.000e-04
# It: 2040, Loss: 2.292e-02, Y0: 7.237, Time: 4.04, Learning Rate: 5.000e-04
# It: 2050, Loss: 2.372e-02, Y0: 7.239, Time: 4.38, Learning Rate: 5.000e-04
# It: 2060, Loss: 2.044e-02, Y0: 7.262, Time: 4.03, Learning Rate: 5.000e-04
# It: 2070, Loss: 2.290e-02, Y0: 7.227, Time: 4.26, Learning Rate: 5.000e-04
# It: 2080, Loss: 2.320e-02, Y0: 7.246, Time: 4.20, Learning Rate: 5.000e-04
# It: 2090, Loss: 2.127e-02, Y0: 7.298, Time: 4.03, Learning Rate: 5.000e-04
# It: 2100, Loss: 2.339e-02, Y0: 7.209, Time: 4.34, Learning Rate: 5.000e-04
# It: 2110, Loss: 2.225e-02, Y0: 7.277, Time: 4.03, Learning Rate: 5.000e-04
# It: 2120, Loss: 2.218e-02, Y0: 7.210, Time: 4.03, Learning Rate: 5.000e-04
# It: 2130, Loss: 2.392e-02, Y0: 7.263, Time: 4.40, Learning Rate: 5.000e-04
# It: 2140, Loss: 2.063e-02, Y0: 7.260, Time: 4.04, Learning Rate: 5.000e-04
# It: 2150, Loss: 2.339e-02, Y0: 7.228, Time: 4.06, Learning Rate: 5.000e-04
# It: 2160, Loss: 2.239e-02, Y0: 7.248, Time: 4.35, Learning Rate: 5.000e-04
# It: 2170, Loss: 2.488e-02, Y0: 7.250, Time: 4.03, Learning Rate: 5.000e-04
# It: 2180, Loss: 2.009e-02, Y0: 7.228, Time: 4.16, Learning Rate: 5.000e-04
# It: 2190, Loss: 2.166e-02, Y0: 7.228, Time: 4.20, Learning Rate: 5.000e-04
# It: 2200, Loss: 2.165e-02, Y0: 7.234, Time: 4.01, Learning Rate: 5.000e-04
# It: 2210, Loss: 2.215e-02, Y0: 7.273, Time: 4.46, Learning Rate: 5.000e-04
# It: 2220, Loss: 2.362e-02, Y0: 7.211, Time: 4.01, Learning Rate: 5.000e-04
# It: 2230, Loss: 2.320e-02, Y0: 7.333, Time: 4.04, Learning Rate: 5.000e-04
# It: 2240, Loss: 2.199e-02, Y0: 7.113, Time: 4.32, Learning Rate: 5.000e-04
# It: 2250, Loss: 2.261e-02, Y0: 7.325, Time: 4.02, Learning Rate: 5.000e-04
# It: 2260, Loss: 2.296e-02, Y0: 7.196, Time: 4.04, Learning Rate: 5.000e-04
# It: 2270, Loss: 2.433e-02, Y0: 7.324, Time: 4.38, Learning Rate: 5.000e-04
# It: 2280, Loss: 2.076e-02, Y0: 7.199, Time: 4.04, Learning Rate: 5.000e-04
# It: 2290, Loss: 2.066e-02, Y0: 7.277, Time: 4.12, Learning Rate: 5.000e-04
# It: 2300, Loss: 2.001e-02, Y0: 7.189, Time: 4.23, Learning Rate: 5.000e-04
# It: 2310, Loss: 1.935e-02, Y0: 7.329, Time: 4.03, Learning Rate: 5.000e-04
# It: 2320, Loss: 2.648e-02, Y0: 7.098, Time: 4.33, Learning Rate: 5.000e-04
# It: 2330, Loss: 2.526e-02, Y0: 7.217, Time: 4.02, Learning Rate: 5.000e-04
# It: 2340, Loss: 4.985e-02, Y0: 7.189, Time: 4.03, Learning Rate: 5.000e-04
# It: 2350, Loss: 2.095e-02, Y0: 7.222, Time: 4.46, Learning Rate: 5.000e-04
# It: 2360, Loss: 3.224e-02, Y0: 7.160, Time: 4.04, Learning Rate: 5.000e-04
# It: 2370, Loss: 2.614e-02, Y0: 7.221, Time: 4.03, Learning Rate: 5.000e-04
# It: 2380, Loss: 3.068e-02, Y0: 7.241, Time: 4.33, Learning Rate: 5.000e-04
# It: 2390, Loss: 2.055e-02, Y0: 7.319, Time: 4.02, Learning Rate: 5.000e-04
# It: 2400, Loss: 3.327e-02, Y0: 7.130, Time: 4.09, Learning Rate: 5.000e-04
# It: 2410, Loss: 2.516e-02, Y0: 7.237, Time: 4.28, Learning Rate: 5.000e-04
# It: 2420, Loss: 2.345e-02, Y0: 7.189, Time: 4.03, Learning Rate: 5.000e-04
# It: 2430, Loss: 2.152e-02, Y0: 7.311, Time: 4.29, Learning Rate: 5.000e-04
# It: 2440, Loss: 3.728e-02, Y0: 7.094, Time: 4.02, Learning Rate: 5.000e-04
# It: 2450, Loss: 4.998e-02, Y0: 7.311, Time: 4.05, Learning Rate: 5.000e-04
# It: 2460, Loss: 2.286e-02, Y0: 7.239, Time: 4.36, Learning Rate: 5.000e-04
# It: 2470, Loss: 2.983e-02, Y0: 7.330, Time: 4.04, Learning Rate: 5.000e-04
# It: 2480, Loss: 2.458e-02, Y0: 7.177, Time: 4.03, Learning Rate: 5.000e-04
# It: 2490, Loss: 2.315e-02, Y0: 7.200, Time: 4.39, Learning Rate: 5.000e-04
# It: 2500, Loss: 2.329e-02, Y0: 7.275, Time: 4.08, Learning Rate: 5.000e-04
# It: 2510, Loss: 2.238e-02, Y0: 7.283, Time: 4.02, Learning Rate: 5.000e-04
# It: 2520, Loss: 2.644e-02, Y0: 7.193, Time: 4.25, Learning Rate: 5.000e-04
# It: 2530, Loss: 2.066e-02, Y0: 7.272, Time: 4.03, Learning Rate: 5.000e-04
# It: 2540, Loss: 2.387e-02, Y0: 7.194, Time: 4.25, Learning Rate: 5.000e-04
# It: 2550, Loss: 2.385e-02, Y0: 7.257, Time: 4.09, Learning Rate: 5.000e-04
# It: 2560, Loss: 2.123e-02, Y0: 7.228, Time: 4.02, Learning Rate: 5.000e-04
# It: 2570, Loss: 2.057e-02, Y0: 7.266, Time: 4.36, Learning Rate: 5.000e-04
# It: 2580, Loss: 2.144e-02, Y0: 7.187, Time: 4.00, Learning Rate: 5.000e-04
# It: 2590, Loss: 2.163e-02, Y0: 7.294, Time: 4.01, Learning Rate: 5.000e-04
# It: 2600, Loss: 2.334e-02, Y0: 7.213, Time: 4.35, Learning Rate: 5.000e-04
# It: 2610, Loss: 2.408e-02, Y0: 7.283, Time: 4.02, Learning Rate: 5.000e-04
# It: 2620, Loss: 2.603e-02, Y0: 7.232, Time: 4.00, Learning Rate: 5.000e-04
# It: 2630, Loss: 2.162e-02, Y0: 7.260, Time: 4.39, Learning Rate: 5.000e-04
# It: 2640, Loss: 2.154e-02, Y0: 7.218, Time: 4.05, Learning Rate: 5.000e-04
# It: 2650, Loss: 2.139e-02, Y0: 7.289, Time: 4.20, Learning Rate: 5.000e-04
# It: 2660, Loss: 2.105e-02, Y0: 7.209, Time: 4.15, Learning Rate: 5.000e-04
# It: 2670, Loss: 2.149e-02, Y0: 7.243, Time: 4.14, Learning Rate: 5.000e-04
# It: 2680, Loss: 2.148e-02, Y0: 7.219, Time: 4.40, Learning Rate: 5.000e-04
# It: 2690, Loss: 2.011e-02, Y0: 7.280, Time: 4.01, Learning Rate: 5.000e-04
# It: 2700, Loss: 2.152e-02, Y0: 7.183, Time: 4.04, Learning Rate: 5.000e-04
# It: 2710, Loss: 2.090e-02, Y0: 7.239, Time: 4.36, Learning Rate: 5.000e-04
# It: 2720, Loss: 2.076e-02, Y0: 7.245, Time: 4.03, Learning Rate: 5.000e-04
# It: 2730, Loss: 2.287e-02, Y0: 7.284, Time: 4.05, Learning Rate: 5.000e-04
# It: 2740, Loss: 2.015e-02, Y0: 7.212, Time: 4.42, Learning Rate: 5.000e-04
# It: 2750, Loss: 2.244e-02, Y0: 7.245, Time: 4.05, Learning Rate: 5.000e-04
# It: 2760, Loss: 2.024e-02, Y0: 7.222, Time: 4.18, Learning Rate: 5.000e-04
# It: 2770, Loss: 2.070e-02, Y0: 7.267, Time: 4.17, Learning Rate: 5.000e-04
# It: 2780, Loss: 2.236e-02, Y0: 7.203, Time: 4.06, Learning Rate: 5.000e-04
# It: 2790, Loss: 2.041e-02, Y0: 7.304, Time: 4.36, Learning Rate: 5.000e-04
# It: 2800, Loss: 2.433e-02, Y0: 7.222, Time: 4.05, Learning Rate: 5.000e-04
# It: 2810, Loss: 2.130e-02, Y0: 7.279, Time: 4.03, Learning Rate: 5.000e-04
# It: 2820, Loss: 2.174e-02, Y0: 7.168, Time: 4.34, Learning Rate: 5.000e-04
# It: 2830, Loss: 2.026e-02, Y0: 7.301, Time: 4.02, Learning Rate: 5.000e-04
# It: 2840, Loss: 2.171e-02, Y0: 7.228, Time: 4.02, Learning Rate: 5.000e-04
# It: 2850, Loss: 2.025e-02, Y0: 7.277, Time: 4.36, Learning Rate: 5.000e-04
# It: 2860, Loss: 1.989e-02, Y0: 7.206, Time: 4.01, Learning Rate: 5.000e-04
# It: 2870, Loss: 1.950e-02, Y0: 7.296, Time: 4.19, Learning Rate: 5.000e-04
# It: 2880, Loss: 2.325e-02, Y0: 7.199, Time: 4.28, Learning Rate: 5.000e-04
# It: 2890, Loss: 2.107e-02, Y0: 7.272, Time: 4.03, Learning Rate: 5.000e-04
# It: 2900, Loss: 2.115e-02, Y0: 7.236, Time: 4.39, Learning Rate: 5.000e-04
# It: 2910, Loss: 2.076e-02, Y0: 7.262, Time: 4.03, Learning Rate: 5.000e-04
# It: 2920, Loss: 2.053e-02, Y0: 7.229, Time: 4.07, Learning Rate: 5.000e-04
# It: 2930, Loss: 2.391e-02, Y0: 7.258, Time: 4.37, Learning Rate: 5.000e-04
# It: 2940, Loss: 2.013e-02, Y0: 7.265, Time: 4.03, Learning Rate: 5.000e-04
# It: 2950, Loss: 2.064e-02, Y0: 7.240, Time: 4.04, Learning Rate: 5.000e-04
# It: 2960, Loss: 2.069e-02, Y0: 7.215, Time: 4.34, Learning Rate: 5.000e-04
# It: 2970, Loss: 2.237e-02, Y0: 7.243, Time: 4.01, Learning Rate: 5.000e-04
# It: 2980, Loss: 2.151e-02, Y0: 7.252, Time: 4.10, Learning Rate: 5.000e-04
# It: 2990, Loss: 1.991e-02, Y0: 7.303, Time: 4.27, Learning Rate: 5.000e-04
# It: 3000, Loss: 2.110e-02, Y0: 7.176, Time: 4.02, Learning Rate: 5.000e-04
# It: 3010, Loss: 1.995e-02, Y0: 7.259, Time: 4.36, Learning Rate: 5.000e-04
# It: 3020, Loss: 1.938e-02, Y0: 7.247, Time: 4.02, Learning Rate: 5.000e-04
# It: 3030, Loss: 2.193e-02, Y0: 7.262, Time: 4.01, Learning Rate: 5.000e-04
# It: 3040, Loss: 2.046e-02, Y0: 7.293, Time: 4.41, Learning Rate: 5.000e-04
# It: 3050, Loss: 2.045e-02, Y0: 7.210, Time: 4.00, Learning Rate: 5.000e-04
# It: 3060, Loss: 1.927e-02, Y0: 7.238, Time: 4.08, Learning Rate: 5.000e-04
# It: 3070, Loss: 2.248e-02, Y0: 7.278, Time: 4.35, Learning Rate: 5.000e-04
# It: 3080, Loss: 2.114e-02, Y0: 7.238, Time: 4.05, Learning Rate: 5.000e-04
# It: 3090, Loss: 2.204e-02, Y0: 7.232, Time: 4.17, Learning Rate: 5.000e-04
# It: 3100, Loss: 1.895e-02, Y0: 7.259, Time: 4.28, Learning Rate: 5.000e-04
# It: 3110, Loss: 2.128e-02, Y0: 7.244, Time: 4.05, Learning Rate: 5.000e-04
# It: 3120, Loss: 2.098e-02, Y0: 7.253, Time: 4.27, Learning Rate: 5.000e-04
# It: 3130, Loss: 1.954e-02, Y0: 7.244, Time: 4.06, Learning Rate: 5.000e-04
# It: 3140, Loss: 1.986e-02, Y0: 7.211, Time: 4.03, Learning Rate: 5.000e-04
# It: 3150, Loss: 2.118e-02, Y0: 7.298, Time: 4.39, Learning Rate: 5.000e-04
# It: 3160, Loss: 2.035e-02, Y0: 7.216, Time: 4.01, Learning Rate: 5.000e-04
# It: 3170, Loss: 2.009e-02, Y0: 7.284, Time: 4.04, Learning Rate: 5.000e-04
# It: 3180, Loss: 2.058e-02, Y0: 7.222, Time: 4.39, Learning Rate: 5.000e-04
# It: 3190, Loss: 2.151e-02, Y0: 7.249, Time: 4.03, Learning Rate: 5.000e-04
# It: 3200, Loss: 2.061e-02, Y0: 7.232, Time: 4.01, Learning Rate: 5.000e-04
# It: 3210, Loss: 2.027e-02, Y0: 7.294, Time: 4.27, Learning Rate: 5.000e-04
# It: 3220, Loss: 2.257e-02, Y0: 7.214, Time: 4.04, Learning Rate: 5.000e-04
# It: 3230, Loss: 1.986e-02, Y0: 7.289, Time: 4.24, Learning Rate: 5.000e-04
# It: 3240, Loss: 1.960e-02, Y0: 7.166, Time: 4.14, Learning Rate: 5.000e-04
# It: 3250, Loss: 2.073e-02, Y0: 7.330, Time: 4.11, Learning Rate: 5.000e-04
# It: 3260, Loss: 2.327e-02, Y0: 7.176, Time: 4.30, Learning Rate: 5.000e-04
# It: 3270, Loss: 2.160e-02, Y0: 7.324, Time: 4.05, Learning Rate: 5.000e-04
# It: 3280, Loss: 2.141e-02, Y0: 7.129, Time: 4.04, Learning Rate: 5.000e-04
# It: 3290, Loss: 2.153e-02, Y0: 7.350, Time: 4.41, Learning Rate: 5.000e-04
# It: 3300, Loss: 1.918e-02, Y0: 7.153, Time: 4.04, Learning Rate: 5.000e-04
# It: 3310, Loss: 1.980e-02, Y0: 7.315, Time: 4.02, Learning Rate: 5.000e-04
# It: 3320, Loss: 2.089e-02, Y0: 7.200, Time: 4.28, Learning Rate: 5.000e-04
# It: 3330, Loss: 1.997e-02, Y0: 7.271, Time: 4.03, Learning Rate: 5.000e-04
# It: 3340, Loss: 1.914e-02, Y0: 7.177, Time: 4.19, Learning Rate: 5.000e-04
# It: 3350, Loss: 2.144e-02, Y0: 7.307, Time: 4.18, Learning Rate: 5.000e-04
# It: 3360, Loss: 2.047e-02, Y0: 7.163, Time: 4.06, Learning Rate: 5.000e-04
# It: 3370, Loss: 1.957e-02, Y0: 7.311, Time: 4.37, Learning Rate: 5.000e-04
# It: 3380, Loss: 1.840e-02, Y0: 7.186, Time: 4.05, Learning Rate: 5.000e-04
# It: 3390, Loss: 2.291e-02, Y0: 7.309, Time: 4.05, Learning Rate: 5.000e-04
# It: 3400, Loss: 1.855e-02, Y0: 7.214, Time: 4.40, Learning Rate: 5.000e-04
# It: 3410, Loss: 2.017e-02, Y0: 7.269, Time: 4.07, Learning Rate: 5.000e-04
# It: 3420, Loss: 1.869e-02, Y0: 7.221, Time: 4.04, Learning Rate: 5.000e-04
# It: 3430, Loss: 2.008e-02, Y0: 7.258, Time: 4.32, Learning Rate: 5.000e-04
# It: 3440, Loss: 1.713e-02, Y0: 7.230, Time: 4.08, Learning Rate: 5.000e-04
# It: 3450, Loss: 4.055e-02, Y0: 7.276, Time: 4.24, Learning Rate: 5.000e-04
# It: 3460, Loss: 2.035e-02, Y0: 7.232, Time: 4.20, Learning Rate: 5.000e-04
# It: 3470, Loss: 1.978e-02, Y0: 7.305, Time: 4.04, Learning Rate: 5.000e-04
# It: 3480, Loss: 1.839e-02, Y0: 7.194, Time: 4.37, Learning Rate: 5.000e-04
# It: 3490, Loss: 2.118e-02, Y0: 7.284, Time: 4.06, Learning Rate: 5.000e-04
# It: 3500, Loss: 1.847e-02, Y0: 7.213, Time: 4.03, Learning Rate: 5.000e-04
# It: 3510, Loss: 2.115e-02, Y0: 7.295, Time: 4.36, Learning Rate: 5.000e-04
# It: 3520, Loss: 2.072e-02, Y0: 7.203, Time: 4.03, Learning Rate: 5.000e-04
# It: 3530, Loss: 2.327e-02, Y0: 7.286, Time: 4.05, Learning Rate: 5.000e-04
# It: 3540, Loss: 2.205e-02, Y0: 7.214, Time: 4.33, Learning Rate: 5.000e-04
# It: 3550, Loss: 2.032e-02, Y0: 7.243, Time: 4.06, Learning Rate: 5.000e-04
# It: 3560, Loss: 1.819e-02, Y0: 7.275, Time: 4.20, Learning Rate: 5.000e-04
# It: 3570, Loss: 2.152e-02, Y0: 7.203, Time: 4.15, Learning Rate: 5.000e-04
# It: 3580, Loss: 1.904e-02, Y0: 7.270, Time: 4.05, Learning Rate: 5.000e-04
# It: 3590, Loss: 2.191e-02, Y0: 7.190, Time: 4.43, Learning Rate: 5.000e-04
# It: 3600, Loss: 1.993e-02, Y0: 7.299, Time: 4.04, Learning Rate: 5.000e-04
# It: 3610, Loss: 2.006e-02, Y0: 7.217, Time: 4.03, Learning Rate: 5.000e-04
# It: 3620, Loss: 1.870e-02, Y0: 7.317, Time: 4.40, Learning Rate: 5.000e-04
# It: 3630, Loss: 2.106e-02, Y0: 7.222, Time: 4.07, Learning Rate: 5.000e-04
# It: 3640, Loss: 1.931e-02, Y0: 7.275, Time: 4.04, Learning Rate: 5.000e-04
# It: 3650, Loss: 2.376e-02, Y0: 7.248, Time: 4.39, Learning Rate: 5.000e-04
# It: 3660, Loss: 2.024e-02, Y0: 7.236, Time: 4.04, Learning Rate: 5.000e-04
# It: 3670, Loss: 2.548e-02, Y0: 7.321, Time: 4.22, Learning Rate: 5.000e-04
# It: 3680, Loss: 2.225e-02, Y0: 7.123, Time: 4.20, Learning Rate: 5.000e-04
# It: 3690, Loss: 2.108e-02, Y0: 7.305, Time: 4.06, Learning Rate: 5.000e-04
# It: 3700, Loss: 2.238e-02, Y0: 7.232, Time: 4.48, Learning Rate: 5.000e-04
# It: 3710, Loss: 1.701e-02, Y0: 7.257, Time: 4.08, Learning Rate: 5.000e-04
# It: 3720, Loss: 3.953e-02, Y0: 7.209, Time: 4.08, Learning Rate: 5.000e-04
# It: 3730, Loss: 5.493e-02, Y0: 7.343, Time: 4.38, Learning Rate: 5.000e-04
# It: 3740, Loss: 4.556e-02, Y0: 7.263, Time: 4.03, Learning Rate: 5.000e-04
# It: 3750, Loss: 3.130e-02, Y0: 7.274, Time: 4.03, Learning Rate: 5.000e-04
# It: 3760, Loss: 2.715e-02, Y0: 7.245, Time: 4.34, Learning Rate: 5.000e-04
# It: 3770, Loss: 2.343e-02, Y0: 7.270, Time: 4.06, Learning Rate: 5.000e-04
# It: 3780, Loss: 2.236e-02, Y0: 7.354, Time: 4.21, Learning Rate: 5.000e-04
# It: 3790, Loss: 1.939e-02, Y0: 7.199, Time: 4.16, Learning Rate: 5.000e-04
# It: 3800, Loss: 1.887e-02, Y0: 7.234, Time: 4.01, Learning Rate: 5.000e-04
# It: 3810, Loss: 1.870e-02, Y0: 7.192, Time: 4.38, Learning Rate: 5.000e-04
# It: 3820, Loss: 1.918e-02, Y0: 7.300, Time: 4.02, Learning Rate: 5.000e-04
# It: 3830, Loss: 1.830e-02, Y0: 7.256, Time: 3.99, Learning Rate: 5.000e-04
# It: 3840, Loss: 1.776e-02, Y0: 7.243, Time: 4.35, Learning Rate: 5.000e-04
# It: 3850, Loss: 1.886e-02, Y0: 7.209, Time: 4.05, Learning Rate: 5.000e-04
# It: 3860, Loss: 1.912e-02, Y0: 7.268, Time: 4.05, Learning Rate: 5.000e-04
# It: 3870, Loss: 1.715e-02, Y0: 7.200, Time: 4.36, Learning Rate: 5.000e-04
# It: 3880, Loss: 1.922e-02, Y0: 7.271, Time: 4.02, Learning Rate: 5.000e-04
# It: 3890, Loss: 2.041e-02, Y0: 7.196, Time: 4.18, Learning Rate: 5.000e-04
# It: 3900, Loss: 1.799e-02, Y0: 7.304, Time: 4.23, Learning Rate: 5.000e-04
# It: 3910, Loss: 1.866e-02, Y0: 7.224, Time: 4.02, Learning Rate: 5.000e-04
# It: 3920, Loss: 1.722e-02, Y0: 7.242, Time: 4.38, Learning Rate: 5.000e-04
# It: 3930, Loss: 1.841e-02, Y0: 7.237, Time: 4.05, Learning Rate: 5.000e-04
# It: 3940, Loss: 1.685e-02, Y0: 7.250, Time: 4.02, Learning Rate: 5.000e-04
# It: 3950, Loss: 1.872e-02, Y0: 7.226, Time: 4.40, Learning Rate: 5.000e-04
# It: 3960, Loss: 1.760e-02, Y0: 7.278, Time: 4.05, Learning Rate: 5.000e-04
# It: 3970, Loss: 1.944e-02, Y0: 7.246, Time: 4.07, Learning Rate: 5.000e-04
# It: 3980, Loss: 2.313e-02, Y0: 7.228, Time: 4.38, Learning Rate: 5.000e-04
# It: 3990, Loss: 1.622e-02, Y0: 7.249, Time: 4.07, Learning Rate: 5.000e-04
# It: 4000, Loss: 1.911e-02, Y0: 7.233, Time: 4.23, Learning Rate: 5.000e-04
# It: 4010, Loss: 1.919e-02, Y0: 7.261, Time: 4.25, Learning Rate: 5.000e-04
# It: 4020, Loss: 1.739e-02, Y0: 7.233, Time: 4.02, Learning Rate: 5.000e-04
# It: 4030, Loss: 1.703e-02, Y0: 7.239, Time: 4.38, Learning Rate: 5.000e-04
# It: 4040, Loss: 1.966e-02, Y0: 7.284, Time: 4.15, Learning Rate: 5.000e-04
# It: 4050, Loss: 2.185e-02, Y0: 7.213, Time: 4.05, Learning Rate: 5.000e-04
# It: 4060, Loss: 1.764e-02, Y0: 7.301, Time: 4.44, Learning Rate: 5.000e-04
# It: 4070, Loss: 2.035e-02, Y0: 7.196, Time: 4.25, Learning Rate: 5.000e-04
# It: 4080, Loss: 1.950e-02, Y0: 7.267, Time: 4.12, Learning Rate: 5.000e-04
# It: 4090, Loss: 1.724e-02, Y0: 7.211, Time: 4.40, Learning Rate: 5.000e-04
# It: 4100, Loss: 1.921e-02, Y0: 7.284, Time: 4.09, Learning Rate: 5.000e-04
# It: 4110, Loss: 1.708e-02, Y0: 7.217, Time: 4.25, Learning Rate: 5.000e-04
# It: 4120, Loss: 1.773e-02, Y0: 7.260, Time: 4.17, Learning Rate: 5.000e-04
# It: 4130, Loss: 1.872e-02, Y0: 7.195, Time: 4.16, Learning Rate: 5.000e-04
# It: 4140, Loss: 1.788e-02, Y0: 7.279, Time: 4.44, Learning Rate: 5.000e-04
# It: 4150, Loss: 1.993e-02, Y0: 7.176, Time: 4.12, Learning Rate: 5.000e-04
# It: 4160, Loss: 1.744e-02, Y0: 7.325, Time: 4.10, Learning Rate: 5.000e-04
# It: 4170, Loss: 1.915e-02, Y0: 7.258, Time: 4.36, Learning Rate: 5.000e-04
# It: 4180, Loss: 1.885e-02, Y0: 7.220, Time: 4.05, Learning Rate: 5.000e-04
# It: 4190, Loss: 1.689e-02, Y0: 7.246, Time: 4.17, Learning Rate: 5.000e-04
# It: 4200, Loss: 1.957e-02, Y0: 7.255, Time: 4.38, Learning Rate: 5.000e-04
# It: 4210, Loss: 1.901e-02, Y0: 7.247, Time: 4.05, Learning Rate: 5.000e-04
# It: 4220, Loss: 1.927e-02, Y0: 7.240, Time: 4.32, Learning Rate: 5.000e-04
# It: 4230, Loss: 1.818e-02, Y0: 7.246, Time: 4.05, Learning Rate: 5.000e-04
# It: 4240, Loss: 1.797e-02, Y0: 7.241, Time: 4.05, Learning Rate: 5.000e-04
# It: 4250, Loss: 1.710e-02, Y0: 7.232, Time: 4.39, Learning Rate: 5.000e-04
# It: 4260, Loss: 1.790e-02, Y0: 7.294, Time: 4.07, Learning Rate: 5.000e-04
# It: 4270, Loss: 2.103e-02, Y0: 7.250, Time: 4.06, Learning Rate: 5.000e-04
# It: 4280, Loss: 2.029e-02, Y0: 7.204, Time: 4.36, Learning Rate: 5.000e-04
# It: 4290, Loss: 1.709e-02, Y0: 7.268, Time: 4.05, Learning Rate: 5.000e-04
# It: 4300, Loss: 1.857e-02, Y0: 7.232, Time: 4.09, Learning Rate: 5.000e-04
# It: 4310, Loss: 1.862e-02, Y0: 7.234, Time: 4.31, Learning Rate: 5.000e-04
# It: 4320, Loss: 1.864e-02, Y0: 7.240, Time: 4.09, Learning Rate: 5.000e-04
# It: 4330, Loss: 1.922e-02, Y0: 7.299, Time: 4.31, Learning Rate: 5.000e-04
# It: 4340, Loss: 1.736e-02, Y0: 7.201, Time: 4.08, Learning Rate: 5.000e-04
# It: 4350, Loss: 1.838e-02, Y0: 7.274, Time: 4.07, Learning Rate: 5.000e-04
# It: 4360, Loss: 1.845e-02, Y0: 7.187, Time: 4.40, Learning Rate: 5.000e-04
# It: 4370, Loss: 1.783e-02, Y0: 7.289, Time: 4.07, Learning Rate: 5.000e-04
# It: 4380, Loss: 1.879e-02, Y0: 7.178, Time: 4.09, Learning Rate: 5.000e-04
# It: 4390, Loss: 1.753e-02, Y0: 7.298, Time: 4.38, Learning Rate: 5.000e-04
# It: 4400, Loss: 2.122e-02, Y0: 7.194, Time: 4.09, Learning Rate: 5.000e-04
# It: 4410, Loss: 2.123e-02, Y0: 7.280, Time: 4.17, Learning Rate: 5.000e-04
# It: 4420, Loss: 1.948e-02, Y0: 7.215, Time: 4.29, Learning Rate: 5.000e-04
# It: 4430, Loss: 1.857e-02, Y0: 7.273, Time: 4.07, Learning Rate: 5.000e-04
# It: 4440, Loss: 1.826e-02, Y0: 7.245, Time: 4.42, Learning Rate: 5.000e-04
# It: 4450, Loss: 1.963e-02, Y0: 7.190, Time: 4.08, Learning Rate: 5.000e-04
# It: 4460, Loss: 1.983e-02, Y0: 7.248, Time: 4.07, Learning Rate: 5.000e-04
# It: 4470, Loss: 1.687e-02, Y0: 7.254, Time: 4.41, Learning Rate: 5.000e-04
# It: 4480, Loss: 1.959e-02, Y0: 7.247, Time: 4.09, Learning Rate: 5.000e-04
# It: 4490, Loss: 1.747e-02, Y0: 7.201, Time: 4.04, Learning Rate: 5.000e-04
# It: 4500, Loss: 1.715e-02, Y0: 7.242, Time: 4.40, Learning Rate: 5.000e-04
# It: 4510, Loss: 1.824e-02, Y0: 7.242, Time: 4.05, Learning Rate: 5.000e-04
# It: 4520, Loss: 1.774e-02, Y0: 7.289, Time: 4.16, Learning Rate: 5.000e-04
# It: 4530, Loss: 2.082e-02, Y0: 7.242, Time: 4.25, Learning Rate: 5.000e-04
# It: 4540, Loss: 1.740e-02, Y0: 7.254, Time: 4.06, Learning Rate: 5.000e-04
# It: 4550, Loss: 1.863e-02, Y0: 7.205, Time: 4.42, Learning Rate: 5.000e-04
# It: 4560, Loss: 1.843e-02, Y0: 7.276, Time: 4.09, Learning Rate: 5.000e-04
# It: 4570, Loss: 1.830e-02, Y0: 7.227, Time: 4.11, Learning Rate: 5.000e-04
# It: 4580, Loss: 1.835e-02, Y0: 7.289, Time: 4.40, Learning Rate: 5.000e-04
# It: 4590, Loss: 1.793e-02, Y0: 7.243, Time: 4.04, Learning Rate: 5.000e-04
# It: 4600, Loss: 1.735e-02, Y0: 7.285, Time: 4.08, Learning Rate: 5.000e-04
# It: 4610, Loss: 1.672e-02, Y0: 7.183, Time: 4.43, Learning Rate: 5.000e-04
# It: 4620, Loss: 1.966e-02, Y0: 7.302, Time: 4.12, Learning Rate: 5.000e-04
# It: 4630, Loss: 1.742e-02, Y0: 7.212, Time: 4.29, Learning Rate: 5.000e-04
# It: 4640, Loss: 1.660e-02, Y0: 7.273, Time: 4.25, Learning Rate: 5.000e-04
# It: 4650, Loss: 1.677e-02, Y0: 7.231, Time: 4.09, Learning Rate: 5.000e-04
# It: 4660, Loss: 1.759e-02, Y0: 7.291, Time: 4.50, Learning Rate: 5.000e-04
# It: 4670, Loss: 1.829e-02, Y0: 7.167, Time: 4.08, Learning Rate: 5.000e-04
# It: 4680, Loss: 1.826e-02, Y0: 7.270, Time: 4.10, Learning Rate: 5.000e-04
# It: 4690, Loss: 3.644e-02, Y0: 7.261, Time: 4.43, Learning Rate: 5.000e-04
# It: 4700, Loss: 1.916e-02, Y0: 7.219, Time: 4.11, Learning Rate: 5.000e-04
# It: 4710, Loss: 1.832e-02, Y0: 7.257, Time: 4.06, Learning Rate: 5.000e-04
# It: 4720, Loss: 1.778e-02, Y0: 7.215, Time: 4.37, Learning Rate: 5.000e-04
# It: 4730, Loss: 1.857e-02, Y0: 7.254, Time: 4.05, Learning Rate: 5.000e-04
# It: 4740, Loss: 2.004e-02, Y0: 7.267, Time: 4.31, Learning Rate: 5.000e-04
# It: 4750, Loss: 1.963e-02, Y0: 7.209, Time: 4.19, Learning Rate: 5.000e-04
# It: 4760, Loss: 2.005e-02, Y0: 7.283, Time: 4.12, Learning Rate: 5.000e-04
# It: 4770, Loss: 2.017e-02, Y0: 7.183, Time: 4.36, Learning Rate: 5.000e-04
# It: 4780, Loss: 1.896e-02, Y0: 7.333, Time: 4.03, Learning Rate: 5.000e-04
# It: 4790, Loss: 2.087e-02, Y0: 7.179, Time: 4.07, Learning Rate: 5.000e-04
# It: 4800, Loss: 2.928e-02, Y0: 7.201, Time: 4.40, Learning Rate: 5.000e-04
# It: 4810, Loss: 3.120e-02, Y0: 7.183, Time: 4.06, Learning Rate: 5.000e-04
# It: 4820, Loss: 2.125e-02, Y0: 7.219, Time: 4.04, Learning Rate: 5.000e-04
# It: 4830, Loss: 2.290e-02, Y0: 7.371, Time: 4.32, Learning Rate: 5.000e-04
# It: 4840, Loss: 1.994e-02, Y0: 7.260, Time: 4.05, Learning Rate: 5.000e-04
# It: 4850, Loss: 2.025e-02, Y0: 7.248, Time: 4.23, Learning Rate: 5.000e-04
# It: 4860, Loss: 1.756e-02, Y0: 7.136, Time: 4.15, Learning Rate: 5.000e-04
# It: 4870, Loss: 1.972e-02, Y0: 7.320, Time: 4.04, Learning Rate: 5.000e-04
# It: 4880, Loss: 2.154e-02, Y0: 7.280, Time: 4.39, Learning Rate: 5.000e-04
# It: 4890, Loss: 1.895e-02, Y0: 7.238, Time: 4.02, Learning Rate: 5.000e-04
# It: 4900, Loss: 1.941e-02, Y0: 7.206, Time: 4.07, Learning Rate: 5.000e-04
# It: 4910, Loss: 1.784e-02, Y0: 7.287, Time: 4.34, Learning Rate: 5.000e-04
# It: 4920, Loss: 1.792e-02, Y0: 7.254, Time: 4.05, Learning Rate: 5.000e-04
# It: 4930, Loss: 1.901e-02, Y0: 7.235, Time: 4.05, Learning Rate: 5.000e-04
# It: 4940, Loss: 1.835e-02, Y0: 7.237, Time: 4.37, Learning Rate: 5.000e-04
# It: 4950, Loss: 1.929e-02, Y0: 7.263, Time: 4.03, Learning Rate: 5.000e-04
# It: 4960, Loss: 1.987e-02, Y0: 7.238, Time: 4.20, Learning Rate: 5.000e-04
# It: 4970, Loss: 2.091e-02, Y0: 7.286, Time: 4.15, Learning Rate: 5.000e-04
# It: 4980, Loss: 1.730e-02, Y0: 7.189, Time: 4.04, Learning Rate: 5.000e-04
# It: 4990, Loss: 1.869e-02, Y0: 7.315, Time: 4.39, Learning Rate: 5.000e-04
# It: 5000, Loss: 1.781e-02, Y0: 7.208, Time: 4.03, Learning Rate: 5.000e-04
# It: 5010, Loss: 1.870e-02, Y0: 7.272, Time: 4.02, Learning Rate: 5.000e-04
# It: 5020, Loss: 1.978e-02, Y0: 7.218, Time: 4.37, Learning Rate: 5.000e-04
# It: 5030, Loss: 1.753e-02, Y0: 7.253, Time: 4.01, Learning Rate: 5.000e-04
# It: 5040, Loss: 1.906e-02, Y0: 7.255, Time: 4.18, Learning Rate: 5.000e-04
# It: 5050, Loss: 1.864e-02, Y0: 7.233, Time: 4.42, Learning Rate: 5.000e-04
# It: 5060, Loss: 1.965e-02, Y0: 7.200, Time: 4.06, Learning Rate: 5.000e-04
# It: 5070, Loss: 1.862e-02, Y0: 7.285, Time: 4.42, Learning Rate: 5.000e-04
# It: 5080, Loss: 1.687e-02, Y0: 7.193, Time: 4.19, Learning Rate: 5.000e-04
# It: 5090, Loss: 1.864e-02, Y0: 7.300, Time: 4.09, Learning Rate: 5.000e-04
# It: 5100, Loss: 1.794e-02, Y0: 7.191, Time: 4.43, Learning Rate: 5.000e-04
# It: 5110, Loss: 1.873e-02, Y0: 7.287, Time: 4.09, Learning Rate: 5.000e-04
# It: 5120, Loss: 1.829e-02, Y0: 7.207, Time: 4.08, Learning Rate: 5.000e-04
# It: 5130, Loss: 1.824e-02, Y0: 7.261, Time: 4.47, Learning Rate: 5.000e-04
# It: 5140, Loss: 2.309e-02, Y0: 7.203, Time: 4.09, Learning Rate: 5.000e-04
# It: 5150, Loss: 1.912e-02, Y0: 7.294, Time: 4.07, Learning Rate: 5.000e-04
# It: 5160, Loss: 1.817e-02, Y0: 7.235, Time: 4.36, Learning Rate: 5.000e-04
# It: 5170, Loss: 1.817e-02, Y0: 7.230, Time: 4.09, Learning Rate: 5.000e-04
# It: 5180, Loss: 1.763e-02, Y0: 7.257, Time: 4.40, Learning Rate: 5.000e-04
# It: 5190, Loss: 1.893e-02, Y0: 7.233, Time: 4.09, Learning Rate: 5.000e-04
# It: 5200, Loss: 1.671e-02, Y0: 7.245, Time: 4.07, Learning Rate: 5.000e-04
# It: 5210, Loss: 1.857e-02, Y0: 7.281, Time: 4.44, Learning Rate: 5.000e-04
# It: 5220, Loss: 1.895e-02, Y0: 7.245, Time: 4.03, Learning Rate: 5.000e-04
# It: 5230, Loss: 1.828e-02, Y0: 7.270, Time: 4.06, Learning Rate: 5.000e-04
# It: 5240, Loss: 1.942e-02, Y0: 7.236, Time: 4.35, Learning Rate: 5.000e-04
# It: 5250, Loss: 1.616e-02, Y0: 7.276, Time: 4.03, Learning Rate: 5.000e-04
# It: 5260, Loss: 1.868e-02, Y0: 7.229, Time: 4.09, Learning Rate: 5.000e-04
# It: 5270, Loss: 1.874e-02, Y0: 7.297, Time: 4.31, Learning Rate: 5.000e-04
# It: 5280, Loss: 1.678e-02, Y0: 7.202, Time: 4.04, Learning Rate: 5.000e-04
# It: 5290, Loss: 1.764e-02, Y0: 7.297, Time: 4.28, Learning Rate: 5.000e-04
# It: 5300, Loss: 1.716e-02, Y0: 7.239, Time: 4.06, Learning Rate: 5.000e-04
# It: 5310, Loss: 2.156e-02, Y0: 7.265, Time: 4.07, Learning Rate: 5.000e-04
# It: 5320, Loss: 1.917e-02, Y0: 7.224, Time: 4.44, Learning Rate: 5.000e-04
# It: 5330, Loss: 1.995e-02, Y0: 7.222, Time: 4.04, Learning Rate: 5.000e-04
# It: 5340, Loss: 1.804e-02, Y0: 7.261, Time: 4.04, Learning Rate: 5.000e-04
# It: 5350, Loss: 2.241e-02, Y0: 7.238, Time: 4.36, Learning Rate: 5.000e-04
# It: 5360, Loss: 1.826e-02, Y0: 7.308, Time: 4.07, Learning Rate: 5.000e-04
# It: 5370, Loss: 1.733e-02, Y0: 7.187, Time: 4.10, Learning Rate: 5.000e-04
# It: 5380, Loss: 1.969e-02, Y0: 7.270, Time: 4.31, Learning Rate: 5.000e-04
# It: 5390, Loss: 1.926e-02, Y0: 7.229, Time: 4.04, Learning Rate: 5.000e-04
# ...
# It: 1880, Loss: 1.200e-02, Y0: 7.244, Time: 4.02, Learning Rate: 1.000e-05
# It: 1890, Loss: 1.142e-02, Y0: 7.250, Time: 4.10, Learning Rate: 1.000e-05
# It: 1900, Loss: 1.296e-02, Y0: 7.252, Time: 4.19, Learning Rate: 1.000e-05
# It: 1910, Loss: 1.231e-02, Y0: 7.265, Time: 4.03, Learning Rate: 1.000e-05
# It: 1920, Loss: 1.159e-02, Y0: 7.268, Time: 4.29, Learning Rate: 1.000e-05
# It: 1930, Loss: 1.113e-02, Y0: 7.259, Time: 4.06, Learning Rate: 1.000e-05
# It: 1940, Loss: 1.154e-02, Y0: 7.261, Time: 4.03, Learning Rate: 1.000e-05
# It: 1950, Loss: 1.206e-02, Y0: 7.251, Time: 4.34, Learning Rate: 1.000e-05
# It: 1960, Loss: 1.139e-02, Y0: 7.244, Time: 4.03, Learning Rate: 1.000e-05
# It: 1970, Loss: 1.121e-02, Y0: 7.249, Time: 4.01, Learning Rate: 1.000e-05
# It: 1980, Loss: 1.222e-02, Y0: 7.259, Time: 4.31, Learning Rate: 1.000e-05
# It: 1990, Loss: 1.264e-02, Y0: 7.267, Time: 4.01, Learning Rate: 1.000e-05
# It: 2000, Loss: 1.214e-02, Y0: 7.256, Time: 4.15, Learning Rate: 1.000e-05
# It: 2010, Loss: 1.177e-02, Y0: 7.253, Time: 4.25, Learning Rate: 1.000e-05
# It: 2020, Loss: 1.148e-02, Y0: 7.252, Time: 4.03, Learning Rate: 1.000e-05
# It: 2030, Loss: 1.193e-02, Y0: 7.251, Time: 4.30, Learning Rate: 1.000e-05
# It: 2040, Loss: 1.244e-02, Y0: 7.265, Time: 4.03, Learning Rate: 1.000e-05
# It: 2050, Loss: 1.292e-02, Y0: 7.259, Time: 4.04, Learning Rate: 1.000e-05
# It: 2060, Loss: 1.294e-02, Y0: 7.262, Time: 4.38, Learning Rate: 1.000e-05
# It: 2070, Loss: 1.230e-02, Y0: 7.261, Time: 4.06, Learning Rate: 1.000e-05
# It: 2080, Loss: 1.254e-02, Y0: 7.245, Time: 4.01, Learning Rate: 1.000e-05
# It: 2090, Loss: 1.234e-02, Y0: 7.245, Time: 4.29, Learning Rate: 1.000e-05
# It: 2100, Loss: 1.304e-02, Y0: 7.244, Time: 4.05, Learning Rate: 1.000e-05
# It: 2110, Loss: 1.173e-02, Y0: 7.242, Time: 4.10, Learning Rate: 1.000e-05
# It: 2120, Loss: 1.206e-02, Y0: 7.250, Time: 4.23, Learning Rate: 1.000e-05
# It: 2130, Loss: 1.128e-02, Y0: 7.266, Time: 4.03, Learning Rate: 1.000e-05
# It: 2140, Loss: 1.102e-02, Y0: 7.262, Time: 4.27, Learning Rate: 1.000e-05
# It: 2150, Loss: 1.176e-02, Y0: 7.255, Time: 4.08, Learning Rate: 1.000e-05
# It: 2160, Loss: 1.253e-02, Y0: 7.269, Time: 4.01, Learning Rate: 1.000e-05
# It: 2170, Loss: 1.241e-02, Y0: 7.255, Time: 4.31, Learning Rate: 1.000e-05
# It: 2180, Loss: 1.210e-02, Y0: 7.235, Time: 4.03, Learning Rate: 1.000e-05
# It: 2190, Loss: 1.234e-02, Y0: 7.247, Time: 4.04, Learning Rate: 1.000e-05
# It: 2200, Loss: 1.096e-02, Y0: 7.266, Time: 4.36, Learning Rate: 1.000e-05
# It: 2210, Loss: 1.219e-02, Y0: 7.249, Time: 4.05, Learning Rate: 1.000e-05
# It: 2220, Loss: 1.252e-02, Y0: 7.250, Time: 4.01, Learning Rate: 1.000e-05
# It: 2230, Loss: 1.155e-02, Y0: 7.252, Time: 4.24, Learning Rate: 1.000e-05
# It: 2240, Loss: 1.258e-02, Y0: 7.266, Time: 4.01, Learning Rate: 1.000e-05
# It: 2250, Loss: 1.144e-02, Y0: 7.266, Time: 4.21, Learning Rate: 1.000e-05
# It: 2260, Loss: 1.317e-02, Y0: 7.270, Time: 4.13, Learning Rate: 1.000e-05
# It: 2270, Loss: 1.136e-02, Y0: 7.266, Time: 4.02, Learning Rate: 1.000e-05
# It: 2280, Loss: 1.290e-02, Y0: 7.257, Time: 4.37, Learning Rate: 1.000e-05
# It: 2290, Loss: 1.283e-02, Y0: 7.262, Time: 4.01, Learning Rate: 1.000e-05
# It: 2300, Loss: 1.257e-02, Y0: 7.261, Time: 3.99, Learning Rate: 1.000e-05
# It: 2310, Loss: 1.218e-02, Y0: 7.257, Time: 4.32, Learning Rate: 1.000e-05
# It: 2320, Loss: 1.279e-02, Y0: 7.258, Time: 4.04, Learning Rate: 1.000e-05
# It: 2330, Loss: 1.288e-02, Y0: 7.253, Time: 4.02, Learning Rate: 1.000e-05
# It: 2340, Loss: 1.159e-02, Y0: 7.246, Time: 4.37, Learning Rate: 1.000e-05
# It: 2350, Loss: 1.332e-02, Y0: 7.252, Time: 4.03, Learning Rate: 1.000e-05
# It: 2360, Loss: 1.207e-02, Y0: 7.258, Time: 4.24, Learning Rate: 1.000e-05
# It: 2370, Loss: 1.123e-02, Y0: 7.259, Time: 4.11, Learning Rate: 1.000e-05
# It: 2380, Loss: 1.152e-02, Y0: 7.251, Time: 4.03, Learning Rate: 1.000e-05
# It: 2390, Loss: 1.126e-02, Y0: 7.255, Time: 4.34, Learning Rate: 1.000e-05
# It: 2400, Loss: 1.387e-02, Y0: 7.246, Time: 4.03, Learning Rate: 1.000e-05
# It: 2410, Loss: 1.251e-02, Y0: 7.249, Time: 4.03, Learning Rate: 1.000e-05
# It: 2420, Loss: 1.260e-02, Y0: 7.260, Time: 4.30, Learning Rate: 1.000e-05
# It: 2430, Loss: 1.127e-02, Y0: 7.265, Time: 4.04, Learning Rate: 1.000e-05
# It: 2440, Loss: 1.189e-02, Y0: 7.255, Time: 4.03, Learning Rate: 1.000e-05
# It: 2450, Loss: 1.151e-02, Y0: 7.251, Time: 4.38, Learning Rate: 1.000e-05
# It: 2460, Loss: 1.192e-02, Y0: 7.255, Time: 4.01, Learning Rate: 1.000e-05
# It: 2470, Loss: 1.185e-02, Y0: 7.249, Time: 4.20, Learning Rate: 1.000e-05
# It: 2480, Loss: 1.167e-02, Y0: 7.242, Time: 4.14, Learning Rate: 1.000e-05
# It: 2490, Loss: 1.198e-02, Y0: 7.258, Time: 4.02, Learning Rate: 1.000e-05
# It: 2500, Loss: 1.246e-02, Y0: 7.254, Time: 4.32, Learning Rate: 1.000e-05
# It: 2510, Loss: 1.175e-02, Y0: 7.270, Time: 4.02, Learning Rate: 1.000e-05
# It: 2520, Loss: 1.157e-02, Y0: 7.253, Time: 4.03, Learning Rate: 1.000e-05
# It: 2530, Loss: 1.320e-02, Y0: 7.243, Time: 4.36, Learning Rate: 1.000e-05
# It: 2540, Loss: 1.157e-02, Y0: 7.255, Time: 4.01, Learning Rate: 1.000e-05
# It: 2550, Loss: 1.117e-02, Y0: 7.246, Time: 4.01, Learning Rate: 1.000e-05
# It: 2560, Loss: 1.170e-02, Y0: 7.241, Time: 4.31, Learning Rate: 1.000e-05
# It: 2570, Loss: 1.104e-02, Y0: 7.245, Time: 4.04, Learning Rate: 1.000e-05
# It: 2580, Loss: 1.176e-02, Y0: 7.247, Time: 4.10, Learning Rate: 1.000e-05
# It: 2590, Loss: 1.206e-02, Y0: 7.261, Time: 4.18, Learning Rate: 1.000e-05
# It: 2600, Loss: 1.261e-02, Y0: 7.261, Time: 4.02, Learning Rate: 1.000e-05
# It: 2610, Loss: 1.168e-02, Y0: 7.259, Time: 4.36, Learning Rate: 1.000e-05
# It: 2620, Loss: 1.166e-02, Y0: 7.262, Time: 3.98, Learning Rate: 1.000e-05
# It: 2630, Loss: 1.236e-02, Y0: 7.257, Time: 4.01, Learning Rate: 1.000e-05
# It: 2640, Loss: 1.186e-02, Y0: 7.261, Time: 4.30, Learning Rate: 1.000e-05
# It: 2650, Loss: 1.118e-02, Y0: 7.259, Time: 4.00, Learning Rate: 1.000e-05
# It: 2660, Loss: 1.132e-02, Y0: 7.251, Time: 4.00, Learning Rate: 1.000e-05
# It: 2670, Loss: 1.160e-02, Y0: 7.236, Time: 4.35, Learning Rate: 1.000e-05
# It: 2680, Loss: 1.206e-02, Y0: 7.239, Time: 4.03, Learning Rate: 1.000e-05
# It: 2690, Loss: 1.203e-02, Y0: 7.256, Time: 4.11, Learning Rate: 1.000e-05
# It: 2700, Loss: 1.233e-02, Y0: 7.249, Time: 4.21, Learning Rate: 1.000e-05
# It: 2710, Loss: 1.661e-02, Y0: 7.255, Time: 4.04, Learning Rate: 1.000e-05
# It: 2720, Loss: 1.318e-02, Y0: 7.274, Time: 4.30, Learning Rate: 1.000e-05
# It: 2730, Loss: 1.196e-02, Y0: 7.250, Time: 4.02, Learning Rate: 1.000e-05
# It: 2740, Loss: 1.156e-02, Y0: 7.244, Time: 4.03, Learning Rate: 1.000e-05
# It: 2750, Loss: 1.164e-02, Y0: 7.254, Time: 4.36, Learning Rate: 1.000e-05
# It: 2760, Loss: 1.188e-02, Y0: 7.246, Time: 4.02, Learning Rate: 1.000e-05
# It: 2770, Loss: 1.205e-02, Y0: 7.246, Time: 4.01, Learning Rate: 1.000e-05
# It: 2780, Loss: 1.276e-02, Y0: 7.259, Time: 4.33, Learning Rate: 1.000e-05
# It: 2790, Loss: 1.500e-02, Y0: 7.265, Time: 4.06, Learning Rate: 1.000e-05
# It: 2800, Loss: 1.161e-02, Y0: 7.249, Time: 4.06, Learning Rate: 1.000e-05
# It: 2810, Loss: 1.217e-02, Y0: 7.248, Time: 4.29, Learning Rate: 1.000e-05
# It: 2820, Loss: 1.146e-02, Y0: 7.266, Time: 4.01, Learning Rate: 1.000e-05
# It: 2830, Loss: 1.368e-02, Y0: 7.252, Time: 4.25, Learning Rate: 1.000e-05
# It: 2840, Loss: 1.139e-02, Y0: 7.254, Time: 4.10, Learning Rate: 1.000e-05
# It: 2850, Loss: 1.163e-02, Y0: 7.252, Time: 4.03, Learning Rate: 1.000e-05
# It: 2860, Loss: 1.136e-02, Y0: 7.257, Time: 4.30, Learning Rate: 1.000e-05
# It: 2870, Loss: 1.257e-02, Y0: 7.256, Time: 4.05, Learning Rate: 1.000e-05
# It: 2880, Loss: 1.210e-02, Y0: 7.259, Time: 4.05, Learning Rate: 1.000e-05
# It: 2890, Loss: 1.221e-02, Y0: 7.258, Time: 4.36, Learning Rate: 1.000e-05
# It: 2900, Loss: 1.195e-02, Y0: 7.280, Time: 4.01, Learning Rate: 1.000e-05
# It: 2910, Loss: 1.233e-02, Y0: 7.238, Time: 4.03, Learning Rate: 1.000e-05
# It: 2920, Loss: 1.254e-02, Y0: 7.251, Time: 4.26, Learning Rate: 1.000e-05
# It: 2930, Loss: 1.160e-02, Y0: 7.257, Time: 4.05, Learning Rate: 1.000e-05
# It: 2940, Loss: 1.184e-02, Y0: 7.247, Time: 4.21, Learning Rate: 1.000e-05
# It: 2950, Loss: 1.099e-02, Y0: 7.249, Time: 4.15, Learning Rate: 1.000e-05
# It: 2960, Loss: 1.236e-02, Y0: 7.241, Time: 4.01, Learning Rate: 1.000e-05
# It: 2970, Loss: 1.225e-02, Y0: 7.263, Time: 4.33, Learning Rate: 1.000e-05
# It: 2980, Loss: 1.321e-02, Y0: 7.247, Time: 4.03, Learning Rate: 1.000e-05
# It: 2990, Loss: 1.188e-02, Y0: 7.255, Time: 4.02, Learning Rate: 1.000e-05
# It: 3000, Loss: 1.244e-02, Y0: 7.271, Time: 4.35, Learning Rate: 1.000e-05
# It: 3010, Loss: 1.129e-02, Y0: 7.262, Time: 4.02, Learning Rate: 1.000e-05
# It: 3020, Loss: 1.231e-02, Y0: 7.255, Time: 3.98, Learning Rate: 1.000e-05
# It: 3030, Loss: 1.183e-02, Y0: 7.252, Time: 4.33, Learning Rate: 1.000e-05
# It: 3040, Loss: 1.247e-02, Y0: 7.262, Time: 4.03, Learning Rate: 1.000e-05
# It: 3050, Loss: 1.241e-02, Y0: 7.269, Time: 4.16, Learning Rate: 1.000e-05
# It: 3060, Loss: 1.299e-02, Y0: 7.269, Time: 4.15, Learning Rate: 1.000e-05
# It: 3070, Loss: 1.186e-02, Y0: 7.250, Time: 4.03, Learning Rate: 1.000e-05
# It: 3080, Loss: 1.268e-02, Y0: 7.255, Time: 4.37, Learning Rate: 1.000e-05
# It: 3090, Loss: 1.190e-02, Y0: 7.253, Time: 4.00, Learning Rate: 1.000e-05
# It: 3100, Loss: 1.196e-02, Y0: 7.256, Time: 4.01, Learning Rate: 1.000e-05
# It: 3110, Loss: 1.171e-02, Y0: 7.256, Time: 4.27, Learning Rate: 1.000e-05
# It: 3120, Loss: 1.143e-02, Y0: 7.254, Time: 4.03, Learning Rate: 1.000e-05
# It: 3130, Loss: 1.175e-02, Y0: 7.255, Time: 4.01, Learning Rate: 1.000e-05
# It: 3140, Loss: 1.286e-02, Y0: 7.253, Time: 4.34, Learning Rate: 1.000e-05
# It: 3150, Loss: 1.163e-02, Y0: 7.255, Time: 4.02, Learning Rate: 1.000e-05
# It: 3160, Loss: 1.237e-02, Y0: 7.252, Time: 4.19, Learning Rate: 1.000e-05
# It: 3170, Loss: 1.174e-02, Y0: 7.254, Time: 4.16, Learning Rate: 1.000e-05
# It: 3180, Loss: 1.202e-02, Y0: 7.253, Time: 4.02, Learning Rate: 1.000e-05
# It: 3190, Loss: 1.164e-02, Y0: 7.258, Time: 4.29, Learning Rate: 1.000e-05
# It: 3200, Loss: 1.139e-02, Y0: 7.247, Time: 4.04, Learning Rate: 1.000e-05
# It: 3210, Loss: 1.283e-02, Y0: 7.262, Time: 4.05, Learning Rate: 1.000e-05
# It: 3220, Loss: 1.223e-02, Y0: 7.262, Time: 4.34, Learning Rate: 1.000e-05
# It: 3230, Loss: 1.193e-02, Y0: 7.259, Time: 4.03, Learning Rate: 1.000e-05
# It: 3240, Loss: 1.227e-02, Y0: 7.250, Time: 4.02, Learning Rate: 1.000e-05
# It: 3250, Loss: 1.253e-02, Y0: 7.261, Time: 4.31, Learning Rate: 1.000e-05
# It: 3260, Loss: 1.228e-02, Y0: 7.272, Time: 4.01, Learning Rate: 1.000e-05
# It: 3270, Loss: 1.227e-02, Y0: 7.256, Time: 4.09, Learning Rate: 1.000e-05
# It: 3280, Loss: 1.207e-02, Y0: 7.237, Time: 4.17, Learning Rate: 1.000e-05
# It: 3290, Loss: 1.224e-02, Y0: 7.252, Time: 4.02, Learning Rate: 1.000e-05
# It: 3300, Loss: 1.133e-02, Y0: 7.255, Time: 4.24, Learning Rate: 1.000e-05
# It: 3310, Loss: 1.196e-02, Y0: 7.251, Time: 4.01, Learning Rate: 1.000e-05
# It: 3320, Loss: 1.138e-02, Y0: 7.248, Time: 4.01, Learning Rate: 1.000e-05
# It: 3330, Loss: 1.197e-02, Y0: 7.265, Time: 4.34, Learning Rate: 1.000e-05
# It: 3340, Loss: 1.210e-02, Y0: 7.254, Time: 4.02, Learning Rate: 1.000e-05
# It: 3350, Loss: 1.180e-02, Y0: 7.256, Time: 4.01, Learning Rate: 1.000e-05
# It: 3360, Loss: 1.185e-02, Y0: 7.273, Time: 4.34, Learning Rate: 1.000e-05
# It: 3370, Loss: 1.184e-02, Y0: 7.253, Time: 4.00, Learning Rate: 1.000e-05
# It: 3380, Loss: 1.280e-02, Y0: 7.244, Time: 4.01, Learning Rate: 1.000e-05
# It: 3390, Loss: 1.196e-02, Y0: 7.272, Time: 4.25, Learning Rate: 1.000e-05
# It: 3400, Loss: 1.268e-02, Y0: 7.249, Time: 4.03, Learning Rate: 1.000e-05
# It: 3410, Loss: 1.248e-02, Y0: 7.244, Time: 4.18, Learning Rate: 1.000e-05
# It: 3420, Loss: 1.194e-02, Y0: 7.269, Time: 4.12, Learning Rate: 1.000e-05
# It: 3430, Loss: 1.195e-02, Y0: 7.261, Time: 4.01, Learning Rate: 1.000e-05
# It: 3440, Loss: 1.120e-02, Y0: 7.249, Time: 4.35, Learning Rate: 1.000e-05
# It: 3450, Loss: 1.220e-02, Y0: 7.273, Time: 4.01, Learning Rate: 1.000e-05
# It: 3460, Loss: 1.198e-02, Y0: 7.256, Time: 4.00, Learning Rate: 1.000e-05
# It: 3470, Loss: 1.209e-02, Y0: 7.240, Time: 4.27, Learning Rate: 1.000e-05
# It: 3480, Loss: 1.224e-02, Y0: 7.266, Time: 4.01, Learning Rate: 1.000e-05
# It: 3490, Loss: 1.274e-02, Y0: 7.256, Time: 4.04, Learning Rate: 1.000e-05
# It: 3500, Loss: 1.183e-02, Y0: 7.247, Time: 4.36, Learning Rate: 1.000e-05
# It: 3510, Loss: 1.126e-02, Y0: 7.239, Time: 4.01, Learning Rate: 1.000e-05
# It: 3520, Loss: 1.161e-02, Y0: 7.251, Time: 4.18, Learning Rate: 1.000e-05
# It: 3530, Loss: 1.197e-02, Y0: 7.245, Time: 4.15, Learning Rate: 1.000e-05
# It: 3540, Loss: 1.211e-02, Y0: 7.237, Time: 4.01, Learning Rate: 1.000e-05
# It: 3550, Loss: 1.162e-02, Y0: 7.250, Time: 4.27, Learning Rate: 1.000e-05
# It: 3560, Loss: 1.255e-02, Y0: 7.256, Time: 4.02, Learning Rate: 1.000e-05
# It: 3570, Loss: 1.181e-02, Y0: 7.258, Time: 4.03, Learning Rate: 1.000e-05
# It: 3580, Loss: 1.231e-02, Y0: 7.253, Time: 4.39, Learning Rate: 1.000e-05
# It: 3590, Loss: 1.188e-02, Y0: 7.263, Time: 4.02, Learning Rate: 1.000e-05
# It: 3600, Loss: 1.183e-02, Y0: 7.256, Time: 4.02, Learning Rate: 1.000e-05
# It: 3610, Loss: 1.132e-02, Y0: 7.249, Time: 4.33, Learning Rate: 1.000e-05
# It: 3620, Loss: 1.145e-02, Y0: 7.248, Time: 4.00, Learning Rate: 1.000e-05
# It: 3630, Loss: 1.323e-02, Y0: 7.250, Time: 4.13, Learning Rate: 1.000e-05
# It: 3640, Loss: 1.175e-02, Y0: 7.253, Time: 4.20, Learning Rate: 1.000e-05
# It: 3650, Loss: 1.184e-02, Y0: 7.249, Time: 4.02, Learning Rate: 1.000e-05
# It: 3660, Loss: 1.197e-02, Y0: 7.241, Time: 4.35, Learning Rate: 1.000e-05
# It: 3670, Loss: 1.119e-02, Y0: 7.238, Time: 4.02, Learning Rate: 1.000e-05
# It: 3680, Loss: 1.121e-02, Y0: 7.258, Time: 4.03, Learning Rate: 1.000e-05
# It: 3690, Loss: 1.228e-02, Y0: 7.245, Time: 4.32, Learning Rate: 1.000e-05
# It: 3700, Loss: 1.220e-02, Y0: 7.252, Time: 4.05, Learning Rate: 1.000e-05
# It: 3710, Loss: 1.255e-02, Y0: 7.252, Time: 4.05, Learning Rate: 1.000e-05
# It: 3720, Loss: 1.159e-02, Y0: 7.264, Time: 4.37, Learning Rate: 1.000e-05
# It: 3730, Loss: 1.202e-02, Y0: 7.265, Time: 4.02, Learning Rate: 1.000e-05
# It: 3740, Loss: 1.206e-02, Y0: 7.267, Time: 4.07, Learning Rate: 1.000e-05
# It: 3750, Loss: 1.155e-02, Y0: 7.265, Time: 4.20, Learning Rate: 1.000e-05
# It: 3760, Loss: 1.259e-02, Y0: 7.251, Time: 4.02, Learning Rate: 1.000e-05
# It: 3770, Loss: 1.178e-02, Y0: 7.252, Time: 4.33, Learning Rate: 1.000e-05
# It: 3780, Loss: 1.156e-02, Y0: 7.256, Time: 4.02, Learning Rate: 1.000e-05
# It: 3790, Loss: 1.168e-02, Y0: 7.247, Time: 4.01, Learning Rate: 1.000e-05
# It: 3800, Loss: 1.185e-02, Y0: 7.252, Time: 4.36, Learning Rate: 1.000e-05
# It: 3810, Loss: 1.822e-02, Y0: 7.256, Time: 4.02, Learning Rate: 1.000e-05
# It: 3820, Loss: 1.243e-02, Y0: 7.272, Time: 4.02, Learning Rate: 1.000e-05
# It: 3830, Loss: 1.251e-02, Y0: 7.255, Time: 4.31, Learning Rate: 1.000e-05
# It: 3840, Loss: 1.180e-02, Y0: 7.239, Time: 4.02, Learning Rate: 1.000e-05
# It: 3850, Loss: 1.140e-02, Y0: 7.248, Time: 4.08, Learning Rate: 1.000e-05
# It: 3860, Loss: 1.201e-02, Y0: 7.273, Time: 4.30, Learning Rate: 1.000e-05
# It: 3870, Loss: 1.260e-02, Y0: 7.268, Time: 3.99, Learning Rate: 1.000e-05
# It: 3880, Loss: 1.208e-02, Y0: 7.237, Time: 4.23, Learning Rate: 1.000e-05
# It: 3890, Loss: 1.227e-02, Y0: 7.254, Time: 4.00, Learning Rate: 1.000e-05
# It: 3900, Loss: 1.181e-02, Y0: 7.260, Time: 4.05, Learning Rate: 1.000e-05
# It: 3910, Loss: 1.217e-02, Y0: 7.247, Time: 4.35, Learning Rate: 1.000e-05
# It: 3920, Loss: 1.221e-02, Y0: 7.254, Time: 4.03, Learning Rate: 1.000e-05
# It: 3930, Loss: 1.274e-02, Y0: 7.251, Time: 4.01, Learning Rate: 1.000e-05
# It: 3940, Loss: 1.144e-02, Y0: 7.262, Time: 4.38, Learning Rate: 1.000e-05
# It: 3950, Loss: 1.317e-02, Y0: 7.264, Time: 4.01, Learning Rate: 1.000e-05
# It: 3960, Loss: 1.266e-02, Y0: 7.253, Time: 4.02, Learning Rate: 1.000e-05
# It: 3970, Loss: 1.233e-02, Y0: 7.250, Time: 4.25, Learning Rate: 1.000e-05
# It: 3980, Loss: 1.195e-02, Y0: 7.276, Time: 4.04, Learning Rate: 1.000e-05
# It: 3990, Loss: 1.333e-02, Y0: 7.245, Time: 4.20, Learning Rate: 1.000e-05
#
# Predicted Y0: 7.2470
# Exact Y0:     7.2225
