# %%
## Rete neurale con normalizzazione della loss
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from abc import ABC, abstractmethod

class FBSNN(ABC): # Forward-Backward Stochastic Neural Network
    def __init__(self, Xi, T,
                       M, N, D, alpha,
                       layers):

        self.Xi = Xi # initial point
        self.T = T # terminal time

        self.M = M # number of trajectories
        self.N = N # number of time snapshots
        self.D = D # number of dimensions

        # layers
        self.layers = layers # (D+1) --> 1

        # initialize NN
        self.weights, self.biases = self.initialize_NN(layers)

        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))

        # tf placeholders and graph (training)
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.alpha = alpha
        self.t_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, 1]) # M x (N+1) x 1
        self.W_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, self.D]) # M x (N+1) x D
        self.Xi_tf = tf.placeholder(tf.float32, shape=[1, D]) # 1 x D

        # ----- LOSS -----
        self.loss, self.X_pred, self.Y_pred, self.Y0_pred, self.Z_pred = \
            self.loss_function(self.t_tf, self.W_tf, self.Xi_tf)

        # ----- PRETRAINING LOSS -----
        self.preloss, _, _, _, _ = \
            self.preloss_function(self.t_tf, self.W_tf, self.Xi_tf)

        # optimizers (same optimizer, two different train ops)
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)

        self.train_op = self.optimizer.minimize(self.loss)
        self.pretrain_op = self.optimizer.minimize(self.preloss)

        # initialize session and variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim],
                                               stddev=xavier_stddev), dtype=tf.float32)

    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = X
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            K = tf.add(tf.matmul(H, W), b)
            H1 = tf.keras.activations.relu(K)
            H2 = tf.sin(K)
            H = tf.add(H1, H2)
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    def net_u(self, t, X): # M x 1, M x D

        u = self.neural_net(tf.concat([t,X], 1), self.weights, self.biases) # M x 1
        Du = tf.gradients(u, X)[0] # M x D

        return u, Du

    def Dg_tf(self, X): # M x D
        return tf.gradients(self.g_tf(X), X)[0] # M x D

    def loss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        loss = 0
        X_list = []
        Y_list = []
        Z_list = []

        t0 = t[:,0,:]
        W0 = W[:,0,:]
        X0 = tf.tile(Xi,[self.M,1]) # M x D
        Y0, Z0 = self.net_u(t0,X0) # M x 1, M x D
        #Z0 = tf.squeeze(tf.matmul(tf.expand_dims(Z0_,axis=1), self.sigma_tf(t0,X0,Y0)))
        
        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)

        dt = self.T/self.N
        
        for n in range(0,self.N):
            t1 = t[:,n+1,:]
            W1 = W[:,n+1,:]
            X1 = X0 + self.mu_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.squeeze(tf.matmul(self.sigma_tf(t0,X0,Y0),tf.expand_dims(W1-W0,-1)), axis=[-1])
            Y1_tilde = Y0 + self.phi_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.reduce_sum(Z0*tf.squeeze(tf.matmul(self.sigma_tf(t0,X0,Y0),tf.expand_dims(W1-W0,-1))), axis=1, keepdims = True)
            Y1, Z1 = self.net_u(t1,X1)
            #Z1 = tf.squeeze(tf.matmul(tf.expand_dims(Z1_,axis=1), self.sigma_tf(t1,X1,Y1)))

            loss += tf.reduce_sum(tf.square(Y1 - Y1_tilde))*tf.exp(-self.alpha * dt*n / self.T)

            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)
        loss += tf.reduce_sum(tf.square(Y1 - self.g_tf(X1)))
        loss += tf.reduce_sum(tf.square(Z1 - self.Dg_tf(X1)))

        X = tf.stack(X_list,axis=1)
        Y = tf.stack(Y_list,axis=1)
        Z = tf.stack(Z_list,axis=1)

        return loss/self.N, X, Y, Y[0,0,0], Z

    def preloss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        """
        Before the Deep FBSDE algorithm finds a decent approximation to the problem via least squares
        and uses that to calculate the loss wrt the net, this way there is an initial good guess for the net
        and later that good guess will get improved via the train method

        This method supposes that the forward dynamics do not depend upon Y or Z, if they do unintended behaviour
        """
        loss = 0
        X_list = []

        t0 = t[:,0,:]
        W0 = W[:,0,:]
        X0 = tf.tile(Xi,[self.M,1]) # M x D
        Y0, Z0 = self.net_u(t0,X0) # M x 1, M x D
        #Y0,Z0 at the moment are garbage values, we keep them just for simplicity in the for loop
        X_list.append(X0)
        for n in range(0,self.N):
            t1 = t[:,n+1,:]
            W1 = W[:,n+1,:]
            X1 = X0 + self.mu_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.squeeze(tf.matmul(self.sigma_tf(t0,X0,Y0),tf.expand_dims(W1-W0,-1)), axis=[-1])
            X0 = X1
            t0 = t1
            W0 = W1
            X_list.append(X0)
        X = tf.stack(X_list,axis=1) # M x (N + 1) x D
        Y_list = [None] * (N+1)
        Z_list = [None] * (N)

        # ---- Terminal condition ----
        X_N = X[:, self.N, :]
        t_N = t[:,self.N,:]
        Y_hat = self.g_tf(X_N)   # M x 1
        Y_list[N] = Y_hat
        Z_hat = tf.zeros_like(X_N) # M x D
        
        Y_pred, Z_pred = self.net_u(t_N,X_N)
        loss += tf.reduce_sum(tf.square(Y_pred - Y_hat))
        loss += tf.reduce_sum(tf.square(Z_pred - self.Dg_tf(X_N)))
        
        for n in reversed(range(0,self.N)):
            X_n = X[:, n, :]          # M x D
            X_np1 = X[:, n+1, :]
            t_np1 = t[:, n+1, :]
            dW_n = W[:, n+1, :] - W[:, n, :]  # M x D
            dt = self.T / self.N
            phi_np1 = self.phi_tf(t_np1, X_np1, Y_list[n+1], Z_hat)
            Y_target = Y_list[n+1] - phi_np1 * dt  # M x 1
            basis = self.basis_functions_lin(X_n)  # M x K
            beta = tf.linalg.lstsq(basis, Y_target, fast=False)
            Y_hat = tf.matmul(basis, beta)
            Y_list[n] = Y_hat   #regression Y_n
            Z_target = Y_list[n+1] * dW_n / dt  # M x D
            beta_Z = tf.linalg.lstsq(basis, Z_target, fast=False)
            Z_hat = tf.matmul(basis, beta_Z)
            Z_list[n] = Z_hat   #regression Z_n

            Y_pred, Z_pred = self.net_u(t[:,n,:],X_n)
            loss += tf.reduce_sum(tf.square(Y_pred - Y_hat))*tf.exp(-self.alpha * dt*n / self.T) #3 means that at T e^-3\approx *0.05
            loss += tf.reduce_sum(tf.square(Z_pred - Z_hat))*tf.exp(-self.alpha * dt*n / self.T)

        Y = tf.stack(Y_list,axis=1)
        Z = tf.stack(Z_list,axis=1)

        return loss/self.N, X, Y, Y[0,0,0], Z

    def basis_functions_lin(self, X):

        # X: M x D
        ones = tf.ones([tf.shape(X)[0], 1])
        return tf.concat([ones, X], axis=1)  # Linear basis

        
    def basis_functions_quad(self, X):

        ones = tf.ones([self.M, 1], dtype=X.dtype)

        # Linear
        linear = X

        # Compute outer product for each sample
        X_exp = tf.expand_dims(X, 2)  # M x D x 1
        X_outer = tf.matmul(X_exp, X_exp, transpose_b=True)  # M x D x D

        # Extract upper triangular part (including diagonal)
        mask = tf.linalg.band_part(tf.ones([self.D, self.D]), 0, -1)  # upper triangle
        mask = tf.cast(mask, dtype=tf.bool)

        quadratic = tf.boolean_mask(X_outer, mask, axis=1)
        quadratic = tf.reshape(quadratic, [self.M, -1])

        basis = tf.concat([ones, linear, quadratic], axis=1)

        return basis

    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M,N+1,1)) # M x (N+1) x 1
        DW = np.zeros((M,N+1,D)) # M x (N+1) x D

        dt = T/N

        Dt[:,1:,:] = dt
        DW[:,1:,:] = np.sqrt(dt)*np.random.normal(size=(M,N,D))

        t = np.cumsum(Dt,axis=1) # M x (N+1) x 1
        W = np.cumsum(DW,axis=1) # M x (N+1) x D

        return t, W

    def train(self, N_Iter, learning_rate):

        start_time = time.time()
        for it in range(N_Iter):

            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D

            tf_dict = {self.Xi_tf: self.Xi, self.t_tf: t_batch, self.W_tf: W_batch, self.learning_rate: learning_rate}

            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.loss, self.Y0_pred, self.learning_rate], tf_dict)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()

    def pretrain(self, N_Iter, learning_rate):

        start_time = time.time()
        for it in range(N_Iter):

            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D

            tf_dict = {self.Xi_tf: self.Xi, self.t_tf: t_batch, self.W_tf: W_batch, self.learning_rate: learning_rate}

            self.sess.run(self.pretrain_op, tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.preloss, self.Y0_pred, self.learning_rate], tf_dict)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()

        
    def predict(self, Xi_star, t_star, W_star):

        tf_dict = {self.Xi_tf: Xi_star, self.t_tf: t_star, self.W_tf: W_star}

        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        Z_star = self.sess.run(self.Z_pred, tf_dict)

        return X_star, Y_star, Z_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def phi_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        pass # M x1

    @abstractmethod
    def g_tf(self, X): # M x D
        pass # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return np.zeros([M,D]) # M x D

    @abstractmethod
    def sigma_tf(self, t, X, Y): # M x 1, M x D, M x 1
        M = self.M
        D = self.D
        return tf.matrix_diag(tf.ones([M,D])) # M x D x D
    ###########################################################################
# Out:
# 2026-02-12 16:47:28.129502: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /usr/local/lib/python3.12/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class Toy2(FBSNN):
    def __init__(self, Xi, T, M, N, D, alpha, layers, parameters):
        # Assicurati che nel main il dizionario si chiami 'parameters' o cambia qui in 'params'
        self.mu1 = parameters['mu1']
        self.mu2 = parameters['mu2']
        self.mu3 = parameters['mu3']
        self.c1 = parameters['c1']
        self.c2 = parameters['c2']
        self.c3 = parameters['c3']
        self.s1 = parameters['s1']
        self.s2 = parameters['s2']
        self.s3 = parameters['s3']
        super().__init__(Xi, T, M, N, D, alpha, layers)

    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)

        mu1 = tf.cast(self.mu1, tf.float32)
        mu2 = tf.cast(self.mu2, tf.float32)
        mu3 = tf.cast(self.mu3, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        c2 = tf.cast(self.c2, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)

        dS = mu1 * (c1 - S)
        dH = mu2 * (c2 - H)
        dV = mu3 * (c3 - V)
        dX = V

        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        return X_state**2 + S * (V+H)

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        Z_S, Z_H, Z_V, _ = tf.split(Z, num_or_size_splits=4, axis=1)

        mu1 = tf.cast(self.mu1, tf.float32)
        mu2 = tf.cast(self.mu2, tf.float32)
        mu3 = tf.cast(self.mu3, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        c2 = tf.cast(self.c2, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        return (2*X_state*V + mu1 * (c1 - S) * Z_S / s1 + mu2*(c2-H) * Z_H / s2 + mu3 * (c3-V) * Z_V / s3)

    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        # Qui sigma1 è costante (moltiplica ones) perchè S è Ornstein-Uhlenbeck. Corretto.
        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)

        return tf.stack([r1, r2, r3, r4], axis=1)

    def u_exact(self,t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X = Xi_arr[:, 3:4]

        return X**2 + S * (V + H)

    def grad_u_exact(self,t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X = Xi_arr[:, 3:4]
        r1 = params['s1'] * (V + H)
        r2 = params['s2'] * S
        r3 = params['s3'] * S
        r4 = np.zeros_like(S)

        return np.stack([r1, r2, r3, r4], axis=1)

# %%
import matplotlib.pyplot as plt
import os

def plot_all(model,Xi,savedir,savename):
    # --- PLOTTING ---
    t_test, W_test = model.fetch_minibatch()
    X_pred, Y_pred, Z_pred = model.predict(Xi, t_test, W_test)
    Xi_reshaped = X_pred.reshape(-1, model.D)
    t_reshaped = t_test.reshape(-1, 1)

    # Calcolo soluzione esatta sui punti predetti
    Y_exact = model.u_exact(t_reshaped, Xi_reshaped).reshape(model.M, model.N+1, 1)
    Z_exact = model.grad_u_exact(t_reshaped, Xi_reshaped).reshape(model.M, model.N+1, model.D, 1)

    exact_Y0 = model.u_exact(np.array([[0.0]]), Xi)[0,0]
    
    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], Y_pred[0,:,0], 'b', label='Learned Y')
    plt.plot(t_test[0,:,0], Y_exact[0,:,0], 'r--', label='Exact Y')
        # Plot di altre traiettorie per vedere la varianza
    plt.plot(t_test[1:5,:,0].T, Y_pred[1:5,:,0].T, 'b')
    plt.plot(t_test[1:5,:,0].T, Y_exact[1:5,:,0].T, 'r--')
    plt.title("Soluzione Y")
    plt.xlabel("Tempo t")
    plt.ylabel("Y_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.savefig(f'{savedir}/Y_{savename}.png')
    
    #print(Z_pred.shape)
    
    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], np.mean(np.abs((Y_pred[:,:,0]-Y_exact[:,:,0])),axis=0), 'b', label='Mean Error of Y')
    plt.title("u abs error")
    plt.xlabel("Tempo t")
    plt.ylabel("Error")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.savefig(f'{savedir}/Y_absErr_{savename}.png')
    
    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], np.mean(np.abs((Y_pred[:,:,0]-Y_exact[:,:,0])),axis=0)/np.mean(np.abs(Y_exact[:,:,0]),axis=0), 'b', label='Mean Error of Y')
    plt.title("u rel error")
    plt.xlabel("Tempo t")
    plt.ylabel("Error")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.savefig(f'{savedir}/Y_relErr_{savename}.png')
    
    
    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], np.mean(np.abs((Z_pred[:,:,0]-Z_exact[:,:,0,0])),axis=0), 'b', label='Mean Error of Z_S')
    plt.plot(t_test[0,:,0], np.mean(np.abs((Z_pred[:,:,1]-Z_exact[:,:,1,0])),axis=0), 'g', label='Mean Error of Z_H')
    plt.plot(t_test[0,:,0], np.mean(np.abs((Z_pred[:,:,2]-Z_exact[:,:,2,0])),axis=0), 'r', label='Mean Error of Z_V')
    plt.title("Grad_u abs error")
    plt.xlabel("Tempo t")
    plt.ylabel("Error")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.savefig(f'{savedir}/Z_absErr_{savename}.png')
    
    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], np.mean(np.abs((Z_pred[:,:,0]-Z_exact[:,:,0,0])),axis=0)/np.mean(np.abs(Z_exact[:,:,0,0]),axis=0), 'b', label='Mean Error of Z_S')
    plt.plot(t_test[0,:,0], np.mean(np.abs((Z_pred[:,:,1]-Z_exact[:,:,1,0])),axis=0)/np.mean(np.abs(Z_exact[:,:,0,0]),axis=0), 'g', label='Mean Error of Z_H')
    plt.plot(t_test[0,:,0], np.mean(np.abs((Z_pred[:,:,2]-Z_exact[:,:,2,0])),axis=0)/np.mean(np.abs(Z_exact[:,:,0,0]),axis=0), 'r', label='Mean Error of Z_V')
    plt.title("Grad_u rel error")
    plt.xlabel("Tempo t")
    plt.ylabel("Error")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.savefig(f'{savedir}/Z_relErr_{savename}.png')

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770914851.990712    7520 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15244 MB memory:  -> device: 0, name: AMD Radeon RX 7800 XT, pci bus id: 0000:28:00.0

# %%
M = 512
N = 100
D = 4
T = 48.0
alpha = 4

params = {
        'mu1': np.float32(1.0),
        'mu2': np.float32(1.0),
        'mu3': np.float32(1.0),
        'c1': np.float32(1.0),
        'c2': np.float32(1.0),
        'c3': np.float32(1.0),
        's1': np.float32(1),
        's2': np.float32(1),
        's3': np.float32(1),
    }

Xi = np.array([1.5, 0.5, 0.5, 0.5]).reshape(1, D)

layers = [D+1] + 4*[256] + [1]

model = Toy2(Xi, T, M, N, D, alpha, layers, params)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: AMD Radeon RX 7800 XT, pci bus id: 0000:28:00.0
# I0000 00:00:1770914852.117928    7520 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15244 MB memory:  -> device: 0, name: AMD Radeon RX 7800 XT, pci bus id: 0000:28:00.0
# I0000 00:00:1770914888.819007    7520 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_1: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_1/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_1/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_1/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_1: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_2: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_2/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_3: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_3/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_2/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_2/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_4: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_4/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_5: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_5/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_3/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_3/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_3: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_6: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_6/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_7: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_7/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_4/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_4/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truncated_normal_4: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_8: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_8/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_8/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_9: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_9/Assign: (Assign): /job:localhost/replica:0/task:0/device:GPU:0
# Variable_9/read: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# Tile: (Tile): /job:localhost/replica:0/task:0/device:GPU:0
# concat: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_1: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_1: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_1: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_3: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_2: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_4: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_2: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_2: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_5: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_3: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_6: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_3: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_3: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_7: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_4: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_8: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_8_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_8_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_4_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_4_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Relu_3_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Sin_3_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Sin_3_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/AddN: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_6_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_6_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_3_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_3_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Relu_2_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Sin_2_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Sin_2_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/AddN_1: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_4_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_4_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_2_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_2_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Relu_1_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Sin_1_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Sin_1_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/AddN_2: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_2_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_2_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_1_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_1_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Relu_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Sin_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Sin_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/AddN_3: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/Add_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/concat_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/concat_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/concat_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# gradients/concat_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_2: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_3: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# split: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_1: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_2: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_2: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_3: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_3: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_9: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_1: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# ones_like: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# mul_4: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_2: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_5: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_3: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_6: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_4: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_5: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# stack: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# sub_4: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ExpandDims: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_5: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# Squeeze: (Squeeze): /job:localhost/replica:0/task:0/device:GPU:0
# add_10: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_2: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# split_3: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# mul_7: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_8: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_5: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_9: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_10: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_11: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_6: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_11: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_12: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_1: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_12: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_7: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_13: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_14: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_2: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_13: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_8: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_15: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_14: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_4: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# ones_like_1: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# mul_16: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_6: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_17: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_7: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_18: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_8: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_9: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# stack_1: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# sub_9: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ExpandDims_1: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_6: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# Squeeze_1: (Squeeze): /job:localhost/replica:0/task:0/device:GPU:0
# mul_19: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# add_15: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_10: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_7: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_16: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_4: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_4: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_17: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_8: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_18: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_5: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_5: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_19: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_9: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_20: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_6: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_6: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_21: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_10: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_22: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_7: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_7: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_23: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_11: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_24: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_24_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_24_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_11_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_11_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Relu_7_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Sin_7_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Sin_7_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/AddN: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_22_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_22_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_10_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_10_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Relu_6_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Sin_6_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Sin_6_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/AddN_1: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_20_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_20_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_9_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_9_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Relu_5_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Sin_5_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Sin_5_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/AddN_2: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_18_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_18_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_8_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_8_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Relu_4_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Sin_4_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Sin_4_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/AddN_3: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_16_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/Add_16_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_7_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/MatMul_7_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/concat_10_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/concat_10_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/concat_10_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_1/concat_10_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# sub_10: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# Square: (Square): /job:localhost/replica:0/task:0/device:GPU:0
# Sum_1: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# Exp: (Exp): /job:localhost/replica:0/task:0/device:GPU:0
# mul_20: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_25: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_4: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_5: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# split_5: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# sub_11: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_21: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_12: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_22: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_13: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_23: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_11: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_14: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_24: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_26: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_6: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# ones_like_2: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# mul_25: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_12: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_26: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_13: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_27: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_14: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_15: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# stack_2: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# sub_15: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ExpandDims_2: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_12: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# Squeeze_2: (Squeeze): /job:localhost/replica:0/task:0/device:GPU:0
# add_27: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_7: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# split_8: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# mul_28: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_29: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_16: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_30: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_31: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_3: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_28: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_17: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_32: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_33: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_4: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_29: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_18: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_34: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_35: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_5: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_30: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_19: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_36: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_31: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_9: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# ones_like_3: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# mul_37: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_16: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_38: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_17: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_39: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_18: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_19: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# stack_3: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# sub_20: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ExpandDims_3: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_13: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# Squeeze_3: (Squeeze): /job:localhost/replica:0/task:0/device:GPU:0
# mul_40: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# Sum_2: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# add_32: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_20: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_14: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_33: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_8: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_8: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_34: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_15: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_35: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_9: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_9: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_36: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_16: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_37: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_10: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_10: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_38: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_17: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_39: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_11: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_11: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_40: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_18: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_41: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_41_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_41_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_18_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_18_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Relu_11_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Sin_11_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Sin_11_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/AddN: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_39_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_39_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_17_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_17_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Relu_10_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Sin_10_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Sin_10_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/AddN_1: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_37_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_37_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_16_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_16_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Relu_9_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Sin_9_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Sin_9_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/AddN_2: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_35_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_35_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_15_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_15_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Relu_8_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Sin_8_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Sin_8_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/AddN_3: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_33_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/Add_33_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_14_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/MatMul_14_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/concat_20_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/concat_20_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/concat_20_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_2/concat_20_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# sub_21: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# Square_1: (Square): /job:localhost/replica:0/task:0/device:GPU:0
# Sum_3: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# Exp_1: (Exp): /job:localhost/replica:0/task:0/device:GPU:0
# mul_41: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_42: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_6: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_7: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# split_10: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# sub_22: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_42: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_23: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_43: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_24: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_44: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_21: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_25: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_45: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_43: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_11: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# ones_like_4: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# mul_46: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_22: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_47: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_23: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_48: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_24: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_25: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# stack_4: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# sub_26: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ExpandDims_4: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_19: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# Squeeze_4: (Squeeze): /job:localhost/replica:0/task:0/device:GPU:0
# add_44: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_12: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# split_13: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# mul_49: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_50: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_27: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_51: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_52: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_6: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_45: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_28: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_53: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_54: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_7: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_46: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_29: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_55: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_56: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_8: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_47: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_30: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_57: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_48: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_14: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# ones_like_5: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# mul_58: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_26: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_59: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_27: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_60: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_28: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_29: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# stack_5: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# sub_31: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ExpandDims_5: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_20: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# Squeeze_5: (Squeeze): /job:localhost/replica:0/task:0/device:GPU:0
# mul_61: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# Sum_4: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# add_49: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_30: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_21: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_50: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_12: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_12: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_51: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_22: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_52: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_13: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_13: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_53: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_23: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_54: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_14: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_14: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_55: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_24: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_56: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_15: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_15: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_57: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_25: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_58: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_58_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_58_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_25_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_25_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Relu_15_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Sin_15_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Sin_15_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/AddN: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_56_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_56_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_24_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_24_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Relu_14_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Sin_14_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Sin_14_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/AddN_1: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_54_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_54_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_23_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_23_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Relu_13_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Sin_13_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Sin_13_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/AddN_2: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_52_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_52_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_22_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_22_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Relu_12_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Sin_12_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Sin_12_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/AddN_3: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_50_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/Add_50_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_21_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/MatMul_21_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/concat_30_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/concat_30_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/concat_30_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_3/concat_30_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# sub_32: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# Square_2: (Square): /job:localhost/replica:0/task:0/device:GPU:0
# Sum_5: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# Exp_2: (Exp): /job:localhost/replica:0/task:0/device:GPU:0
# mul_62: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_59: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_8: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_9: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# split_15: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# sub_33: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_63: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_34: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_64: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_35: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_65: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_31: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_36: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_66: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_60: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_16: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# ones_like_6: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# mul_67: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_32: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_68: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_33: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_69: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_34: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_35: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# stack_6: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# sub_37: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ExpandDims_6: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_26: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# Squeeze_6: (Squeeze): /job:localhost/replica:0/task:0/device:GPU:0
# add_61: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_17: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# split_18: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# mul_70: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_71: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_38: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_72: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_73: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_9: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_62: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_39: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_74: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_75: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_10: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_63: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_40: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_76: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# mul_77: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# truediv_11: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# add_64: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# sub_41: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_78: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_65: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# split_19: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# ones_like_7: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# mul_79: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_36: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_80: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_37: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# mul_81: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# concat_38: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_39: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# stack_7: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# sub_42: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ExpandDims_7: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_27: (BatchMatMulV2): /job:localhost/replica:0/task:0/device:GPU:0
# Squeeze_7: (Squeeze): /job:localhost/replica:0/task:0/device:GPU:0
# mul_82: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# Sum_6: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# add_66: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# concat_40: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_28: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_67: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_16: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_16: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_68: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_29: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_69: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_17: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_17: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_70: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_30: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_71: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_18: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_18: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_72: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_31: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_73: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# Relu_19: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# Sin_19: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# Add_74: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul_32: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# Add_75: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_75_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_75_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_32_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_32_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Relu_19_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Sin_19_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Sin_19_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/AddN: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_73_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_73_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_31_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_31_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Relu_18_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Sin_18_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Sin_18_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/AddN_1: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_71_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_71_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_30_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_30_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Relu_17_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Sin_17_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Sin_17_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/AddN_2: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_69_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_69_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_29_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_29_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Relu_16_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Sin_16_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Sin_16_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/AddN_3: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_67_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/Add_67_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_28_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/MatMul_28_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/concat_40_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/concat_40_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/concat_40_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_4/concat_40_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:GPU:0
# sub_43: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# Square_3: (Square): /job:localhost/replica:0/task:0/device:GPU:0
# Sum_7: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# Exp_3: (Exp): /job:localhost/replica:0/task:0/device:GPU:0
# mul_83: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# add_76: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_10: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# strided_slice_11: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# split_20: (Split): /job:localhost/replica:0/task:0/device:GPU:0
# sub_44: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_84: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_45: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# mul_85: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# sub_46: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# ...
# gradients_205/mul_1805_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1805_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1805_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1805_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1805_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sum_173_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sum_173_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Square_87_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Square_87_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/sub_978_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/sub_978_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/sub_978_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/sub_978_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1528_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1528_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1528_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1544_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1544_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1544_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sum_180_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sum_180_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/AddN_13: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1554_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1554_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1554_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1554_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1554_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1926_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1926_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1926_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1926_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1926_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1930_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1930_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1930_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1930_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1930_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/MatMul_648_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/MatMul_648_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/MatMul_648_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/MatMul_648_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/MatMul_648_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1577_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1577_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1577_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1587_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1587_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1587_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1593_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1593_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1593_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/RealDiv_1: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/RealDiv_2: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_281_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sin_379_grad/Cos: (Cos): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sin_379_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1609_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1609_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1609_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/RealDiv_1: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/RealDiv_2: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_283_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1988_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1988_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1988_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1988_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1988_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/RealDiv_1: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/RealDiv_2: (RealDiv): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/truediv_285_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2007_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2007_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2007_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2007_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2007_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2026_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2026_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2026_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2026_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_2026_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/zeros_like_2: (ZerosLike): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/split_488_grad/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/AddN_14: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_98/concat_980_grad/Slice_1_grad/stack: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_98/concat_980_grad/Slice_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_98/concat_980_grad/Slice_1_grad/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_98/concat_980_grad/Slice_1_grad/sub_1: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_98/concat_980_grad/Slice_1_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_98/concat_980_grad/Slice_1_grad/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_98/concat_980_grad/Slice_1_grad/Pad: (Pad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_99/MatMul_693_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_99/MatMul_693_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_99/MatMul_693_grad/MatMul_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_99/MatMul_693_grad/MatMul_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_99/MatMul_693_grad/MatMul_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/AddN_15: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Relu_403_grad/ReluGrad: (ReluGrad): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/AddN_16: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_100/MatMul_704_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_100/MatMul_704_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_100/MatMul_704_grad/MatMul_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_100/MatMul_704_grad/MatMul_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_100/MatMul_704_grad/MatMul_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_100/Sin_403_grad/Cos_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_100/Sin_403_grad/Cos_grad/Sin: (Sin): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/gradients_100/Sin_403_grad/Cos_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1436_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1436_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1436_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1784_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1784_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1784_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1784_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/mul_1784_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sum_171_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sum_171_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Square_86_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Square_86_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/sub_967_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/sub_967_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/sub_967_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/sub_967_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1511_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1511_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1511_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1527_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1527_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/add_1527_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sum_178_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Sum_178_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/AddN_17: (AddN): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1537_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:GPU:0
# gradients_205/Add_1537_grad/
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
model.pretrain(N_Iter = 1000, learning_rate = 1e-3)
model.train(N_Iter = 2000, learning_rate = 1e-3)
dire = 'plots/Toy2/1000+2000/'
os.makedirs(dire, exist_ok=True)
plot_all(model,Xi,dire,'T=48_alpha=4')

model.train(N_Iter = 2000, learning_rate = 1e-3)
dire = 'plots/Toy2/1000+4000/'
os.makedirs(dire, exist_ok=True)
plot_all(model,Xi,dire,'T=48_alpha=4')
# Out:
# It: 0, Loss: 1.453e+08, Y0: 2.738, Time: 14.56, Learning Rate: 1.000e-03
# It: 10, Loss: 6.278e+07, Y0: 7.680, Time: 2.43, Learning Rate: 1.000e-03
# It: 20, Loss: 6.754e+07, Y0: -5.595, Time: 2.41, Learning Rate: 1.000e-03
# It: 30, Loss: 2.863e+07, Y0: 9.377, Time: 2.47, Learning Rate: 1.000e-03
# It: 40, Loss: 9.485e+07, Y0: 81.577, Time: 2.39, Learning Rate: 1.000e-03
# It: 50, Loss: 3.997e+07, Y0: -1.457, Time: 2.37, Learning Rate: 1.000e-03
# It: 60, Loss: 3.287e+07, Y0: -9.489, Time: 2.38, Learning Rate: 1.000e-03
# It: 70, Loss: 3.111e+07, Y0: -4.461, Time: 2.49, Learning Rate: 1.000e-03
# It: 80, Loss: 2.156e+07, Y0: -1.388, Time: 2.35, Learning Rate: 1.000e-03
# It: 90, Loss: 1.463e+07, Y0: -2.020, Time: 2.40, Learning Rate: 1.000e-03
# It: 100, Loss: 1.182e+07, Y0: -1.199, Time: 2.41, Learning Rate: 1.000e-03
# It: 110, Loss: 4.744e+06, Y0: -4.188, Time: 2.43, Learning Rate: 1.000e-03
# It: 120, Loss: 4.537e+07, Y0: -7.606, Time: 2.49, Learning Rate: 1.000e-03
# It: 130, Loss: 4.643e+06, Y0: -11.335, Time: 2.42, Learning Rate: 1.000e-03
# It: 140, Loss: 8.825e+06, Y0: -12.833, Time: 2.51, Learning Rate: 1.000e-03
# It: 150, Loss: 1.954e+07, Y0: -16.554, Time: 2.49, Learning Rate: 1.000e-03
# It: 160, Loss: 1.153e+07, Y0: -14.536, Time: 2.35, Learning Rate: 1.000e-03
# It: 170, Loss: 4.145e+07, Y0: -10.072, Time: 2.36, Learning Rate: 1.000e-03
# It: 180, Loss: 5.917e+07, Y0: -5.660, Time: 2.32, Learning Rate: 1.000e-03
# It: 190, Loss: 2.113e+07, Y0: -5.024, Time: 2.32, Learning Rate: 1.000e-03
# It: 200, Loss: 4.951e+06, Y0: -5.861, Time: 2.34, Learning Rate: 1.000e-03
# It: 210, Loss: 6.245e+07, Y0: -5.318, Time: 2.30, Learning Rate: 1.000e-03
# It: 220, Loss: 4.833e+06, Y0: -2.303, Time: 2.30, Learning Rate: 1.000e-03
# It: 230, Loss: 4.805e+07, Y0: -1.102, Time: 2.35, Learning Rate: 1.000e-03
# It: 240, Loss: 3.031e+07, Y0: -1.546, Time: 2.32, Learning Rate: 1.000e-03
# It: 250, Loss: 5.773e+06, Y0: -1.149, Time: 2.32, Learning Rate: 1.000e-03
# It: 260, Loss: 1.302e+07, Y0: -2.438, Time: 2.32, Learning Rate: 1.000e-03
# It: 270, Loss: 1.000e+07, Y0: -3.866, Time: 2.35, Learning Rate: 1.000e-03
# It: 280, Loss: 4.360e+06, Y0: -6.438, Time: 3.45, Learning Rate: 1.000e-03
# It: 290, Loss: 2.050e+07, Y0: -9.865, Time: 5.21, Learning Rate: 1.000e-03
# It: 300, Loss: 9.255e+07, Y0: -6.045, Time: 5.60, Learning Rate: 1.000e-03
# It: 310, Loss: 2.278e+07, Y0: -8.080, Time: 5.92, Learning Rate: 1.000e-03
# It: 320, Loss: 2.667e+07, Y0: -7.754, Time: 5.60, Learning Rate: 1.000e-03
# It: 330, Loss: 8.282e+06, Y0: -4.169, Time: 4.04, Learning Rate: 1.000e-03
# It: 340, Loss: 4.436e+07, Y0: -2.695, Time: 3.25, Learning Rate: 1.000e-03
# It: 350, Loss: 2.560e+08, Y0: -8.915, Time: 3.54, Learning Rate: 1.000e-03
# It: 360, Loss: 2.283e+07, Y0: 25.523, Time: 3.54, Learning Rate: 1.000e-03
# It: 370, Loss: 4.110e+07, Y0: -0.781, Time: 3.23, Learning Rate: 1.000e-03
# It: 380, Loss: 4.259e+06, Y0: -2.488, Time: 3.35, Learning Rate: 1.000e-03
# It: 390, Loss: 1.854e+07, Y0: -2.054, Time: 3.13, Learning Rate: 1.000e-03
# It: 400, Loss: 8.200e+06, Y0: 2.500, Time: 3.20, Learning Rate: 1.000e-03
# It: 410, Loss: 3.511e+07, Y0: 1.438, Time: 3.17, Learning Rate: 1.000e-03
# It: 420, Loss: 1.728e+07, Y0: 1.736, Time: 3.15, Learning Rate: 1.000e-03
# It: 430, Loss: 2.067e+07, Y0: 3.530, Time: 2.46, Learning Rate: 1.000e-03
# It: 440, Loss: 6.802e+06, Y0: 3.908, Time: 2.43, Learning Rate: 1.000e-03
# It: 450, Loss: 5.185e+07, Y0: 5.325, Time: 2.45, Learning Rate: 1.000e-03
# It: 460, Loss: 2.903e+07, Y0: 5.355, Time: 2.44, Learning Rate: 1.000e-03
# It: 470, Loss: 8.975e+06, Y0: 5.676, Time: 2.36, Learning Rate: 1.000e-03
# It: 480, Loss: 6.974e+07, Y0: 5.802, Time: 2.34, Learning Rate: 1.000e-03
# It: 490, Loss: 3.482e+07, Y0: 6.455, Time: 2.38, Learning Rate: 1.000e-03
# It: 500, Loss: 8.149e+06, Y0: 6.236, Time: 2.46, Learning Rate: 1.000e-03
# It: 510, Loss: 1.017e+07, Y0: 8.514, Time: 2.43, Learning Rate: 1.000e-03
# It: 520, Loss: 1.531e+07, Y0: 7.889, Time: 2.37, Learning Rate: 1.000e-03
# It: 530, Loss: 4.274e+07, Y0: 6.950, Time: 2.41, Learning Rate: 1.000e-03
# It: 540, Loss: 5.057e+08, Y0: 5.570, Time: 2.40, Learning Rate: 1.000e-03
# It: 550, Loss: 1.364e+07, Y0: 5.759, Time: 2.60, Learning Rate: 1.000e-03
# It: 560, Loss: 4.867e+06, Y0: 5.452, Time: 2.42, Learning Rate: 1.000e-03
# It: 570, Loss: 3.903e+07, Y0: 6.239, Time: 2.41, Learning Rate: 1.000e-03
# It: 580, Loss: 5.230e+06, Y0: 5.354, Time: 2.45, Learning Rate: 1.000e-03
# It: 590, Loss: 4.377e+07, Y0: 5.062, Time: 2.48, Learning Rate: 1.000e-03
# It: 600, Loss: 3.832e+07, Y0: 5.911, Time: 2.41, Learning Rate: 1.000e-03
# It: 610, Loss: 9.622e+07, Y0: 5.446, Time: 2.41, Learning Rate: 1.000e-03
# It: 620, Loss: 2.355e+07, Y0: 5.357, Time: 2.44, Learning Rate: 1.000e-03
# It: 630, Loss: 2.945e+06, Y0: 5.275, Time: 2.42, Learning Rate: 1.000e-03
# It: 640, Loss: 9.561e+06, Y0: 4.237, Time: 2.40, Learning Rate: 1.000e-03
# It: 650, Loss: 3.767e+07, Y0: 3.606, Time: 2.39, Learning Rate: 1.000e-03
# It: 660, Loss: 2.768e+07, Y0: 3.379, Time: 2.40, Learning Rate: 1.000e-03
# It: 670, Loss: 5.874e+07, Y0: 3.056, Time: 2.42, Learning Rate: 1.000e-03
# It: 680, Loss: 5.504e+06, Y0: 2.691, Time: 2.47, Learning Rate: 1.000e-03
# It: 690, Loss: 1.080e+08, Y0: 2.086, Time: 2.42, Learning Rate: 1.000e-03
# It: 700, Loss: 6.736e+07, Y0: 2.315, Time: 2.44, Learning Rate: 1.000e-03
# It: 710, Loss: 1.098e+08, Y0: 2.422, Time: 2.43, Learning Rate: 1.000e-03
# It: 720, Loss: 9.079e+06, Y0: 3.546, Time: 2.44, Learning Rate: 1.000e-03
# It: 730, Loss: 8.728e+06, Y0: 2.977, Time: 2.36, Learning Rate: 1.000e-03
# It: 740, Loss: 1.302e+08, Y0: 2.301, Time: 2.38, Learning Rate: 1.000e-03
# It: 750, Loss: 1.399e+07, Y0: 1.802, Time: 2.44, Learning Rate: 1.000e-03
# It: 760, Loss: 6.699e+07, Y0: 2.442, Time: 2.43, Learning Rate: 1.000e-03
# It: 770, Loss: 2.720e+07, Y0: 2.492, Time: 2.44, Learning Rate: 1.000e-03
# It: 780, Loss: 3.627e+07, Y0: 1.747, Time: 2.51, Learning Rate: 1.000e-03
# It: 790, Loss: 8.515e+07, Y0: 1.902, Time: 2.44, Learning Rate: 1.000e-03
# It: 800, Loss: 1.332e+07, Y0: 1.821, Time: 2.39, Learning Rate: 1.000e-03
# It: 810, Loss: 3.657e+07, Y0: 2.738, Time: 2.31, Learning Rate: 1.000e-03
# It: 820, Loss: 4.846e+07, Y0: 2.938, Time: 2.34, Learning Rate: 1.000e-03
# It: 830, Loss: 1.818e+08, Y0: 2.957, Time: 2.36, Learning Rate: 1.000e-03
# It: 840, Loss: 1.787e+07, Y0: 1.285, Time: 2.30, Learning Rate: 1.000e-03
# It: 850, Loss: 3.517e+07, Y0: 0.950, Time: 2.38, Learning Rate: 1.000e-03
# It: 860, Loss: 5.559e+06, Y0: 0.918, Time: 2.35, Learning Rate: 1.000e-03
# It: 870, Loss: 1.028e+07, Y0: 0.708, Time: 2.36, Learning Rate: 1.000e-03
# It: 880, Loss: 8.842e+07, Y0: 1.784, Time: 2.42, Learning Rate: 1.000e-03
# It: 890, Loss: 6.583e+07, Y0: 1.396, Time: 2.42, Learning Rate: 1.000e-03
# It: 900, Loss: 7.651e+06, Y0: 1.077, Time: 2.55, Learning Rate: 1.000e-03
# It: 910, Loss: 6.524e+07, Y0: 1.353, Time: 2.49, Learning Rate: 1.000e-03
# It: 920, Loss: 2.544e+07, Y0: 1.240, Time: 2.39, Learning Rate: 1.000e-03
# It: 930, Loss: 1.002e+08, Y0: 1.497, Time: 2.51, Learning Rate: 1.000e-03
# It: 940, Loss: 3.761e+06, Y0: 1.571, Time: 2.43, Learning Rate: 1.000e-03
# It: 950, Loss: 1.181e+07, Y0: 1.685, Time: 2.42, Learning Rate: 1.000e-03
# It: 960, Loss: 3.266e+07, Y0: 1.978, Time: 2.40, Learning Rate: 1.000e-03
# It: 970, Loss: 2.046e+07, Y0: 1.268, Time: 2.39, Learning Rate: 1.000e-03
# It: 980, Loss: 6.534e+07, Y0: 0.166, Time: 2.37, Learning Rate: 1.000e-03
# It: 990, Loss: 8.765e+06, Y0: -0.129, Time: 2.37, Learning Rate: 1.000e-03
# It: 0, Loss: 1.250e+05, Y0: 0.212, Time: 15.44, Learning Rate: 1.000e-03
# It: 10, Loss: 1.713e+06, Y0: -0.548, Time: 2.07, Learning Rate: 1.000e-03
# It: 20, Loss: 3.396e+05, Y0: -0.195, Time: 2.14, Learning Rate: 1.000e-03
# It: 30, Loss: 2.698e+05, Y0: 0.153, Time: 2.02, Learning Rate: 1.000e-03
# It: 40, Loss: 1.285e+05, Y0: 0.116, Time: 2.12, Learning Rate: 1.000e-03
# It: 50, Loss: 2.494e+05, Y0: -0.458, Time: 2.05, Learning Rate: 1.000e-03
# It: 60, Loss: 8.158e+04, Y0: -1.187, Time: 2.07, Learning Rate: 1.000e-03
# It: 70, Loss: 8.758e+04, Y0: -2.269, Time: 2.05, Learning Rate: 1.000e-03
# It: 80, Loss: 1.388e+05, Y0: -3.204, Time: 2.06, Learning Rate: 1.000e-03
# It: 90, Loss: 8.698e+04, Y0: -0.120, Time: 2.12, Learning Rate: 1.000e-03
# It: 100, Loss: 9.164e+04, Y0: -0.580, Time: 2.02, Learning Rate: 1.000e-03
# It: 110, Loss: 8.198e+04, Y0: 0.659, Time: 2.14, Learning Rate: 1.000e-03
# It: 120, Loss: 9.244e+04, Y0: 2.214, Time: 2.14, Learning Rate: 1.000e-03
# It: 130, Loss: 8.108e+04, Y0: 4.508, Time: 2.12, Learning Rate: 1.000e-03
# It: 140, Loss: 1.127e+05, Y0: 7.229, Time: 2.09, Learning Rate: 1.000e-03
# It: 150, Loss: 6.975e+04, Y0: 9.417, Time: 2.09, Learning Rate: 1.000e-03
# It: 160, Loss: 5.910e+04, Y0: 11.694, Time: 2.07, Learning Rate: 1.000e-03
# It: 170, Loss: 6.657e+04, Y0: 13.013, Time: 2.09, Learning Rate: 1.000e-03
# It: 180, Loss: 4.910e+04, Y0: 14.560, Time: 2.07, Learning Rate: 1.000e-03
# It: 190, Loss: 5.830e+04, Y0: 15.955, Time: 2.10, Learning Rate: 1.000e-03
# It: 200, Loss: 5.477e+04, Y0: 16.936, Time: 2.08, Learning Rate: 1.000e-03
# It: 210, Loss: 4.366e+04, Y0: 17.954, Time: 1.99, Learning Rate: 1.000e-03
# It: 220, Loss: 4.637e+04, Y0: 18.397, Time: 2.09, Learning Rate: 1.000e-03
# It: 230, Loss: 8.556e+04, Y0: 19.421, Time: 2.08, Learning Rate: 1.000e-03
# It: 240, Loss: 6.406e+04, Y0: 20.450, Time: 2.05, Learning Rate: 1.000e-03
# It: 250, Loss: 6.036e+04, Y0: 20.993, Time: 2.09, Learning Rate: 1.000e-03
# It: 260, Loss: 3.964e+04, Y0: 21.958, Time: 2.07, Learning Rate: 1.000e-03
# It: 270, Loss: 5.691e+04, Y0: 22.594, Time: 2.05, Learning Rate: 1.000e-03
# It: 280, Loss: 7.918e+04, Y0: 23.588, Time: 2.07, Learning Rate: 1.000e-03
# It: 290, Loss: 6.809e+04, Y0: 24.623, Time: 2.05, Learning Rate: 1.000e-03
# It: 300, Loss: 3.807e+04, Y0: 25.455, Time: 2.06, Learning Rate: 1.000e-03
# It: 310, Loss: 4.823e+04, Y0: 26.513, Time: 2.09, Learning Rate: 1.000e-03
# It: 320, Loss: 3.081e+04, Y0: 27.380, Time: 2.05, Learning Rate: 1.000e-03
# It: 330, Loss: 4.701e+04, Y0: 28.187, Time: 2.08, Learning Rate: 1.000e-03
# It: 340, Loss: 3.912e+04, Y0: 29.161, Time: 2.08, Learning Rate: 1.000e-03
# It: 350, Loss: 4.528e+04, Y0: 30.115, Time: 2.17, Learning Rate: 1.000e-03
# It: 360, Loss: 6.816e+04, Y0: 31.095, Time: 2.04, Learning Rate: 1.000e-03
# It: 370, Loss: 3.824e+04, Y0: 32.098, Time: 2.12, Learning Rate: 1.000e-03
# It: 380, Loss: 3.838e+04, Y0: 33.060, Time: 2.14, Learning Rate: 1.000e-03
# It: 390, Loss: 4.267e+04, Y0: 33.863, Time: 2.15, Learning Rate: 1.000e-03
# It: 400, Loss: 2.489e+04, Y0: 34.682, Time: 2.11, Learning Rate: 1.000e-03
# It: 410, Loss: 2.350e+04, Y0: 35.353, Time: 2.07, Learning Rate: 1.000e-03
# It: 420, Loss: 3.595e+04, Y0: 35.914, Time: 2.17, Learning Rate: 1.000e-03
# It: 430, Loss: 4.692e+04, Y0: 36.619, Time: 2.07, Learning Rate: 1.000e-03
# It: 440, Loss: 2.682e+04, Y0: 37.426, Time: 2.09, Learning Rate: 1.000e-03
# It: 450, Loss: 2.252e+04, Y0: 38.366, Time: 2.05, Learning Rate: 1.000e-03
# It: 460, Loss: 2.587e+04, Y0: 39.296, Time: 2.11, Learning Rate: 1.000e-03
# It: 470, Loss: 2.220e+04, Y0: 40.009, Time: 2.03, Learning Rate: 1.000e-03
# It: 480, Loss: 3.722e+04, Y0: 40.587, Time: 2.04, Learning Rate: 1.000e-03
# It: 490, Loss: 4.187e+04, Y0: 40.960, Time: 2.13, Learning Rate: 1.000e-03
# It: 500, Loss: 1.964e+04, Y0: 41.498, Time: 2.07, Learning Rate: 1.000e-03
# It: 510, Loss: 1.712e+04, Y0: 42.181, Time: 2.09, Learning Rate: 1.000e-03
# It: 520, Loss: 1.768e+04, Y0: 42.971, Time: 2.05, Learning Rate: 1.000e-03
# It: 530, Loss: 2.076e+04, Y0: 43.895, Time: 2.11, Learning Rate: 1.000e-03
# It: 540, Loss: 1.768e+04, Y0: 44.842, Time: 2.08, Learning Rate: 1.000e-03
# It: 550, Loss: 1.600e+04, Y0: 45.830, Time: 2.05, Learning Rate: 1.000e-03
# It: 560, Loss: 4.959e+04, Y0: 46.870, Time: 2.10, Learning Rate: 1.000e-03
# It: 570, Loss: 3.777e+04, Y0: 47.864, Time: 2.07, Learning Rate: 1.000e-03
# It: 580, Loss: 2.289e+04, Y0: 48.700, Time: 2.10, Learning Rate: 1.000e-03
# It: 590, Loss: 2.506e+04, Y0: 49.488, Time: 2.08, Learning Rate: 1.000e-03
# It: 600, Loss: 2.183e+04, Y0: 50.156, Time: 2.12, Learning Rate: 1.000e-03
# It: 610, Loss: 1.847e+04, Y0: 50.905, Time: 2.05, Learning Rate: 1.000e-03
# It: 620, Loss: 2.523e+04, Y0: 51.704, Time: 2.15, Learning Rate: 1.000e-03
# It: 630, Loss: 1.657e+04, Y0: 52.544, Time: 2.05, Learning Rate: 1.000e-03
# It: 640, Loss: 3.846e+04, Y0: 53.225, Time: 2.09, Learning Rate: 1.000e-03
# It: 650, Loss: 1.475e+04, Y0: 53.826, Time: 2.09, Learning Rate: 1.000e-03
# It: 660, Loss: 2.274e+04, Y0: 54.448, Time: 2.04, Learning Rate: 1.000e-03
# It: 670, Loss: 1.982e+04, Y0: 55.185, Time: 2.01, Learning Rate: 1.000e-03
# It: 680, Loss: 2.070e+04, Y0: 55.828, Time: 2.06, Learning Rate: 1.000e-03
# It: 690, Loss: 2.304e+04, Y0: 56.477, Time: 2.10, Learning Rate: 1.000e-03
# It: 700, Loss: 8.436e+03, Y0: 57.181, Time: 2.15, Learning Rate: 1.000e-03
# It: 710, Loss: 3.075e+04, Y0: 57.814, Time: 2.08, Learning Rate: 1.000e-03
# It: 720, Loss: 9.416e+03, Y0: 58.567, Time: 2.09, Learning Rate: 1.000e-03
# It: 730, Loss: 1.303e+04, Y0: 59.249, Time: 2.14, Learning Rate: 1.000e-03
# It: 740, Loss: 2.039e+04, Y0: 59.827, Time: 2.17, Learning Rate: 1.000e-03
# It: 750, Loss: 1.642e+04, Y0: 60.448, Time: 2.14, Learning Rate: 1.000e-03
# It: 760, Loss: 3.465e+04, Y0: 61.122, Time: 2.13, Learning Rate: 1.000e-03
# It: 770, Loss: 1.259e+04, Y0: 61.749, Time: 2.00, Learning Rate: 1.000e-03
# It: 780, Loss: 1.513e+04, Y0: 62.344, Time: 2.04, Learning Rate: 1.000e-03
# It: 790, Loss: 2.211e+04, Y0: 62.855, Time: 2.11, Learning Rate: 1.000e-03
# It: 800, Loss: 1.643e+04, Y0: 63.320, Time: 2.07, Learning Rate: 1.000e-03
# It: 810, Loss: 2.034e+04, Y0: 63.920, Time: 2.06, Learning Rate: 1.000e-03
# It: 820, Loss: 1.276e+04, Y0: 64.442, Time: 2.10, Learning Rate: 1.000e-03
# It: 830, Loss: 2.179e+04, Y0: 64.933, Time: 2.14, Learning Rate: 1.000e-03
# It: 840, Loss: 1.436e+04, Y0: 65.375, Time: 2.03, Learning Rate: 1.000e-03
# It: 850, Loss: 1.655e+04, Y0: 65.831, Time: 2.12, Learning Rate: 1.000e-03
# It: 860, Loss: 9.567e+03, Y0: 66.294, Time: 2.05, Learning Rate: 1.000e-03
# It: 870, Loss: 1.039e+04, Y0: 66.671, Time: 2.08, Learning Rate: 1.000e-03
# It: 880, Loss: 1.063e+04, Y0: 67.080, Time: 2.12, Learning Rate: 1.000e-03
# It: 890, Loss: 9.921e+03, Y0: 67.531, Time: 2.12, Learning Rate: 1.000e-03
# It: 900, Loss: 1.101e+04, Y0: 67.981, Time: 2.12, Learning Rate: 1.000e-03
# It: 910, Loss: 1.321e+04, Y0: 68.432, Time: 2.01, Learning Rate: 1.000e-03
# It: 920, Loss: 6.702e+03, Y0: 68.861, Time: 2.01, Learning Rate: 1.000e-03
# It: 930, Loss: 1.827e+04, Y0: 69.289, Time: 2.04, Learning Rate: 1.000e-03
# It: 940, Loss: 1.724e+04, Y0: 69.778, Time: 2.05, Learning Rate: 1.000e-03
# It: 950, Loss: 5.351e+03, Y0: 70.143, Time: 2.13, Learning Rate: 1.000e-03
# It: 960, Loss: 1.670e+04, Y0: 70.467, Time: 2.03, Learning Rate: 1.000e-03
# It: 970, Loss: 1.080e+04, Y0: 70.758, Time: 2.09, Learning Rate: 1.000e-03
# It: 980, Loss: 1.168e+04, Y0: 71.072, Time: 2.13, Learning Rate: 1.000e-03
# It: 990, Loss: 1.329e+04, Y0: 71.387, Time: 2.15, Learning Rate: 1.000e-03
# It: 1000, Loss: 5.216e+03, Y0: 71.680, Time: 2.15, Learning Rate: 1.000e-03
# It: 1010, Loss: 5.773e+03, Y0: 71.962, Time: 2.06, Learning Rate: 1.000e-03
# It: 1020, Loss: 1.178e+04, Y0: 72.219, Time: 2.11, Learning Rate: 1.000e-03
# It: 1030, Loss: 1.917e+04, Y0: 72.478, Time: 2.01, Learning Rate: 1.000e-03
# It: 1040, Loss: 6.965e+03, Y0: 72.666, Time: 2.08, Learning Rate: 1.000e-03
# It: 1050, Loss: 7.693e+03, Y0: 72.859, Time: 2.13, Learning Rate: 1.000e-03
# It: 1060, Loss: 5.499e+03, Y0: 73.040, Time: 2.08, Learning Rate: 1.000e-03
# It: 1070, Loss: 1.621e+04, Y0: 73.212, Time: 2.05, Learning Rate: 1.000e-03
# It: 1080, Loss: 6.511e+03, Y0: 73.436, Time: 2.03, Learning Rate: 1.000e-03
# It: 1090, Loss: 1.619e+04, Y0: 73.746, Time: 1.97, Learning Rate: 1.000e-03
# It: 1100, Loss: 9.363e+03, Y0: 73.948, Time: 2.08, Learning Rate: 1.000e-03
# It: 1110, Loss: 1.244e+04, Y0: 74.142, Time: 2.07, Learning Rate: 1.000e-03
# It: 1120, Loss: 2.499e+04, Y0: 74.273, Time: 2.12, Learning Rate: 1.000e-03
# It: 1130, Loss: 1.420e+04, Y0: 74.354, Time: 2.12, Learning Rate: 1.000e-03
# It: 1140, Loss: 4.793e+03, Y0: 74.443, Time: 2.06, Learning Rate: 1.000e-03
# It: 1150, Loss: 1.460e+04, Y0: 74.516, Time: 2.17, Learning Rate: 1.000e-03
# It: 1160, Loss: 9.052e+03, Y0: 74.597, Time: 2.04, Learning Rate: 1.000e-03
# It: 1170, Loss: 4.345e+03, Y0: 74.779, Time: 2.06, Learning Rate: 1.000e-03
# It: 1180, Loss: 6.378e+03, Y0: 74.928, Time: 2.07, Learning Rate: 1.000e-03
# It: 1190, Loss: 4.377e+03, Y0: 75.040, Time: 2.10, Learning Rate: 1.000e-03
# It: 1200, Loss: 3.769e+04, Y0: 75.124, Time: 2.05, Learning Rate: 1.000e-03
# It: 1210, Loss: 6.659e+03, Y0: 75.242, Time: 2.02, Learning Rate: 1.000e-03
# It: 1220, Loss: 1.193e+04, Y0: 75.359, Time: 2.12, Learning Rate: 1.000e-03
# It: 1230, Loss: 1.583e+04, Y0: 75.481, Time: 2.07, Learning Rate: 1.000e-03
# It: 1240, Loss: 7.391e+03, Y0: 75.626, Time: 2.05, Learning Rate: 1.000e-03
# It: 1250, Loss: 4.986e+03, Y0: 75.651, Time: 2.15, Learning Rate: 1.000e-03
# It: 1260, Loss: 1.462e+04, Y0: 75.667, Time: 1.98, Learning Rate: 1.000e-03
# It: 1270, Loss: 4.108e+03, Y0: 75.714, Time: 2.02, Learning Rate: 1.000e-03
# It: 1280, Loss: 6.443e+03, Y0: 75.729, Time: 2.09, Learning Rate: 1.000e-03
# It: 1290, Loss: 5.057e+03, Y0: 75.773, Time: 1.98, Learning Rate: 1.000e-03
# It: 1300, Loss: 4.733e+03, Y0: 75.888, Time: 2.00, Learning Rate: 1.000e-03
# It: 1310, Loss: 1.025e+04, Y0: 75.936, Time: 2.06, Learning Rate: 1.000e-03
# It: 1320, Loss: 4.505e+03, Y0: 76.042, Time: 2.05, Learning Rate: 1.000e-03
# It: 1330, Loss: 7.292e+03, Y0: 76.195, Time: 2.07, Learning Rate: 1.000e-03
# It: 1340, Loss: 5.217e+03, Y0: 76.365, Time: 2.08, Learning Rate: 1.000e-03
# It: 1350, Loss: 3.951e+03, Y0: 76.465, Time: 2.05, Learning Rate: 1.000e-03
# It: 1360, Loss: 1.499e+04, Y0: 76.609, Time: 2.02, Learning Rate: 1.000e-03
# It: 1370, Loss: 3.705e+03, Y0: 76.729, Time: 2.04, Learning Rate: 1.000e-03
# It: 1380, Loss: 3.407e+03, Y0: 76.730, Time: 2.10, Learning Rate: 1.000e-03
# It: 1390, Loss: 3.720e+03, Y0: 76.858, Time: 2.07, Learning Rate: 1.000e-03
# It: 1400, Loss: 3.470e+03, Y0: 76.964, Time: 2.14, Learning Rate: 1.000e-03
# It: 1410, Loss: 3.715e+03, Y0: 77.038, Time: 2.02, Learning Rate: 1.000e-03
# It: 1420, Loss: 3.962e+03, Y0: 77.112, Time: 2.00, Learning Rate: 1.000e-03
# It: 1430, Loss: 3.465e+03, Y0: 77.144, Time: 2.05, Learning Rate: 1.000e-03
# It: 1440, Loss: 1.427e+04, Y0: 77.187, Time: 2.06, Learning Rate: 1.000e-03
# It: 1450, Loss: 6.483e+03, Y0: 77.301, Time: 1.98, Learning Rate: 1.000e-03
# It: 1460, Loss: 3.204e+03, Y0: 77.321, Time: 2.00, Learning Rate: 1.000e-03
# It: 1470, Loss: 3.461e+03, Y0: 77.341, Time: 2.06, Learning Rate: 1.000e-03
# It: 1480, Loss: 9.333e+03, Y0: 77.388, Time: 2.07, Learning Rate: 1.000e-03
# It: 1490, Loss: 2.179e+04, Y0: 77.429, Time: 2.11, Learning Rate: 1.000e-03
# It: 1500, Loss: 3.977e+03, Y0: 77.505, Time: 2.12, Learning Rate: 1.000e-03
# It: 1510, Loss: 3.178e+03, Y0: 77.547, Time: 2.02, Learning Rate: 1.000e-03
# It: 1520, Loss: 7.795e+03, Y0: 77.557, Time: 2.04, Learning Rate: 1.000e-03
# It: 1530, Loss: 3.396e+03, Y0: 77.616, Time: 2.08, Learning Rate: 1.000e-03
# It: 1540, Loss: 5.545e+03, Y0: 77.670, Time: 2.05, Learning Rate: 1.000e-03
# It: 1550, Loss: 7.420e+03, Y0: 77.709, Time: 2.06, Learning Rate: 1.000e-03
# It: 1560, Loss: 3.539e+03, Y0: 77.739, Time: 2.00, Learning Rate: 1.000e-03
# It: 1570, Loss: 1.140e+04, Y0: 77.773, Time: 2.10, Learning Rate: 1.000e-03
# It: 1580, Loss: 3.559e+03, Y0: 77.875, Time: 2.05, Learning Rate: 1.000e-03
# It: 1590, Loss: 4.213e+03, Y0: 77.946, Time: 2.06, Learning Rate: 1.000e-03
# It: 1600, Loss: 1.869e+04, Y0: 78.023, Time: 2.05, Learning Rate: 1.000e-03
# It: 1610, Loss: 4.590e+03, Y0: 78.112, Time: 2.04, Learning Rate: 1.000e-03
# It: 1620, Loss: 1.165e+04, Y0: 78.184, Time: 2.10, Learning Rate: 1.000e-03
# It: 1630, Loss: 1.189e+04, Y0: 78.290, Time: 2.17, Learning Rate: 1.000e-03
# It: 1640, Loss: 4.352e+03, Y0: 78.350, Time: 2.07, Learning Rate: 1.000e-03
# It: 1650, Loss: 4.050e+03, Y0: 78.447, Time: 2.05, Learning Rate: 1.000e-03
# It: 1660, Loss: 8.796e+03, Y0: 78.479, Time: 2.07, Learning Rate: 1.000e-03
# It: 1670, Loss: 3.297e+03, Y0: 78.524, Time: 2.03, Learning Rate: 1.000e-03
# It: 1680, Loss: 6.409e+03, Y0: 78.580, Time: 2.06, Learning Rate: 1.000e-03
# It: 1690, Loss: 3.023e+03, Y0: 78.627, Time: 2.10, Learning Rate: 1.000e-03
# It: 1700, Loss: 1.147e+04, Y0: 78.648, Time: 2.01, Learning Rate: 1.000e-03
# It: 1710, Loss: 2.290e+03, Y0: 78.647, Time: 2.05, Learning Rate: 1.000e-03
# It: 1720, Loss: 4.293e+03, Y0: 78.684, Time: 2.09, Learning Rate: 1.000e-03
# It: 1730, Loss: 3.255e+03, Y0: 78.786, Time: 2.14, Learning Rate: 1.000e-03
# It: 1740, Loss: 2.238e+03, Y0: 78.883, Time: 2.06, Learning Rate: 1.000e-03
# It: 1750, Loss: 1.448e+04, Y0: 78.871, Time: 1.98, Learning Rate: 1.000e-03
# It: 1760, Loss: 3.280e+03, Y0: 78.895, Time: 2.00, Learning Rate: 1.000e-03
# It: 1770, Loss: 2.683e+03, Y0: 78.964, Time: 2.07, Learning Rate: 1.000e-03
# It: 1780, Loss: 2.737e+03, Y0: 79.013, Time: 2.03, Learning Rate: 1.000e-03
# It: 1790, Loss: 2.547e+03, Y0: 79.004, Time: 2.03, Learning Rate: 1.000e-03
# It: 1800, Loss: 2.791e+03, Y0: 78.990, Time: 2.07, Learning Rate: 1.000e-03
# It: 1810, Loss: 4.646e+03, Y0: 79.011, Time: 2.08, Learning Rate: 1.000e-03
# It: 1820, Loss: 2.579e+03, Y0: 79.099, Time: 2.00, Learning Rate: 1.000e-03
# It: 1830, Loss: 2.269e+03, Y0: 79.108, Time: 2.06, Learning Rate: 1.000e-03
# It: 1840, Loss: 2.430e+03, Y0: 79.058, Time: 2.06, Learning Rate: 1.000e-03
# It: 1850, Loss: 3.483e+03, Y0: 79.076, Time: 2.12, Learning Rate: 1.000e-03
# It: 1860, Loss: 3.837e+03, Y0: 79.129, Time: 2.00, Learning Rate: 1.000e-03
# It: 1870, Loss: 4.926e+03, Y0: 79.189, Time: 1.97, Learning Rate: 1.000e-03
# It: 1880, Loss: 7.205e+03, Y0: 79.231, Time: 2.01, Learning Rate: 1.000e-03
# It: 1890, Loss: 2.849e+03, Y0: 79.299, Time: 2.03, Learning Rate: 1.000e-03
# It: 1900, Loss: 4.138e+03, Y0: 79.315, Time: 2.10, Learning Rate: 1.000e-03
# It: 1910, Loss: 4.174e+03, Y0: 79.375, Time: 2.06, Learning Rate: 1.000e-03
# It: 1920, Loss: 9.867e+03, Y0: 79.450, Time: 2.08, Learning Rate: 1.000e-03
# It: 1930, Loss: 3.887e+03, Y0: 79.484, Time: 2.05, Learning Rate: 1.000e-03
# It: 1940, Loss: 3.370e+03, Y0: 79.478, Time: 1.99, Learning Rate: 1.000e-03
# It: 1950, Loss: 2.521e+03, Y0: 79.506, Time: 2.04, Learning Rate: 1.000e-03
# It: 1960, Loss: 2.577e+03, Y0: 79.470, Time: 1.98, Learning Rate: 1.000e-03
# It: 1970, Loss: 2.281e+03, Y0: 79.469, Time: 2.08, Learning Rate: 1.000e-03
# It: 1980, Loss: 5.008e+03, Y0: 79.475, Time: 2.06, Learning Rate: 1.000e-03
# It: 1990, Loss: 1.472e+04, Y0: 79.553, Time: 2.04, Learning Rate: 1.000e-03
# It: 0, Loss: 2.134e+03, Y0: 79.597, Time: 0.22, Learning Rate: 1.000e-03
# It: 10, Loss: 5.809e+03, Y0: 79.564, Time: 2.05, Learning Rate: 1.000e-03
# It: 20, Loss: 4.145e+03, Y0: 79.595, Time: 2.05, Learning Rate: 1.000e-03
# It: 30, Loss: 2.165e+03, Y0: 79.561, Time: 2.10, Learning Rate: 1.000e-03
# It: 40, Loss: 1.998e+03, Y0: 79.499, Time: 2.13, Learning Rate: 1.000e-03
# It: 50, Loss: 1.110e+04, Y0: 79.468, Time: 2.06, Learning Rate: 1.000e-03
# It: 60, Loss: 2.320e+03, Y0: 79.481, Time: 2.13, Learning Rate: 1.000e-03
# It: 70, Loss: 2.521e+03, Y0: 79.458, Time: 2.06, Learning Rate: 1.000e-03
# It: 80, Loss: 1.004e+04, Y0: 79.467, Time: 2.11, Learning Rate: 1.000e-03
# It: 90, Loss: 3.101e+03, Y0: 79.559, Time: 1.99, Learning Rate: 1.000e-03
# It: 100, Loss: 1.760e+03, Y0: 79.637, Time: 2.12, Learning Rate: 1.000e-03
# It: 110, Loss: 8.200e+03, Y0: 79.675, Time: 2.13, Learning Rate: 1.000e-03
# It: 120, Loss: 2.130e+03, Y0: 79.769, Time: 2.07, Learning Rate: 1.000e-03
# It: 130, Loss: 2.033e+03, Y0: 79.799, Time: 2.07, Learning Rate: 1.000e-03
# It: 140, Loss: 5.710e+03, Y0: 79.803, Time: 2.06, Learning Rate: 1.000e-03
# It: 150, Loss: 2.064e+03, Y0: 79.822, Time: 2.13, Learning Rate: 1.000e-03
# It: 160, Loss: 2.146e+03, Y0: 79.836, Time: 2.06, Learning Rate: 1.000e-03
# It: 170, Loss: 4.881e+03, Y0: 79.839, Time: 2.05, Learning Rate: 1.000e-03
# It: 180, Loss: 2.643e+03, Y0: 79.850, Time: 2.08, Learning Rate: 1.000e-03
# It: 190, Loss: 3.920e+03, Y0: 79.864, Time: 1.98, Learning Rate: 1.000e-03
# It: 200, Loss: 1.798e+03, Y0: 79.881, Time: 2.11, Learning Rate: 1.000e-03
# It: 210, Loss: 1.625e+03, Y0: 79.888, Time: 2.05, Learning Rate: 1.000e-03
# It: 220, Loss: 2.184e+03, Y0: 79.882, Time: 2.05, Learning Rate: 1.000e-03
# It: 230, Loss: 1.877e+03, Y0: 79.892, Time: 2.01, Learning Rate: 1.000e-03
# It: 240, Loss: 2.368e+03, Y0: 79.913, Time: 2.07, Learning Rate: 1.000e-03
# It: 250, Loss: 1.831e+03, Y0: 79.856, Time: 2.14, Learning Rate: 1.000e-03
# It: 260, Loss: 1.853e+03, Y0: 79.945, Time: 2.01, Learning Rate: 1.000e-03
# It: 270, Loss: 1.766e+03, Y0: 80.041, Time: 2.04, Learning Rate: 1.000e-03
# It: 280, Loss: 5.570e+03, Y0: 80.016, Time: 2.08, Learning Rate: 1.000e-03
# It: 290, Loss: 1.157e+04, Y0: 79.995, Time: 2.09, Learning Rate: 1.000e-03
# It: 300, Loss: 2.043e+03, Y0: 80.022, Time: 2.09, Learning Rate: 1.000e-03
# It: 310, Loss: 2.686e+03, Y0: 80.019, Time: 2.06, Learning Rate: 1.000e-03
# It: 320, Loss: 2.248e+03, Y0: 79.992, Time: 2.03, Learning Rate: 1.000e-03
# It: 330, Loss: 5.429e+03, Y0: 80.025, Time: 2.03, Learning Rate: 1.000e-03
# It: 340, Loss: 3.646e+03, Y0: 80.026, Time: 2.14, Learning Rate: 1.000e-03
# It: 350, Loss: 2.427e+03, Y0: 80.016, Time: 2.12, Learning Rate: 1.000e-03
# It: 360, Loss: 1.639e+03, Y0: 80.000, Time: 2.10, Learning Rate: 1.000e-03
# It: 370, Loss: 1.785e+03, Y0: 80.027, Time: 2.10, Learning Rate: 1.000e-03
# It: 380, Loss: 4.350e+03, Y0: 80.040, Time: 2.01, Learning Rate: 1.000e-03
# It: 390, Loss: 1.744e+03, Y0: 80.035, Time: 2.05, Learning Rate: 1.000e-03
# It: 400, Loss: 1.547e+03, Y0: 80.007, Time: 2.08, Learning Rate: 1.000e-03
# It: 410, Loss: 2.034e+03, Y0: 80.034, Time: 1.98, Learning Rate: 1.000e-03
# It: 420, Loss: 3.239e+03, Y0: 79.989, Time: 2.05, Learning Rate: 1.000e-03
# It: 430, Loss: 2.014e+03, Y0: 79.976, Time: 2.07, Learning Rate: 1.000e-03
# It: 440, Loss: 1.615e+03, Y0: 79.961, Time: 2.05, Learning Rate: 1.000e-03
# It: 450, Loss: 8.428e+03, Y0: 79.966, Time: 2.12, Learning Rate: 1.000e-03
# It: 460, Loss: 5.898e+03, Y0: 79.994, Time: 2.06, Learning Rate: 1.000e-03
# It: 470, Loss: 1.745e+03, Y0: 80.074, Time: 2.07, Learning Rate: 1.000e-03
# It: 480, Loss: 1.475e+03, Y0: 80.080, Time: 2.06, Learning Rate: 1.000e-03
# It: 490, Loss: 1.560e+03, Y0: 80.035, Time: 2.08, Learning Rate: 1.000e-03
# It: 500, Loss: 1.535e+03, Y0: 80.003, Time: 2.06, Learning Rate: 1.000e-03
# It: 510, Loss: 3.192e+03, Y0: 79.972, Time: 2.05, Learning Rate: 1.000e-03
# It: 520, Loss: 1.522e+03, Y0: 79.967, Time: 2.11, Learning Rate: 1.000e-03
# It: 530, Loss: 1.752e+03, Y0: 79.960, Time: 2.05, Learning Rate: 1.000e-03
# It: 540, Loss: 1.510e+03, Y0: 79.954, Time: 2.02, Learning Rate: 1.000e-03
# It: 550, Loss: 1.744e+03, Y0: 79.939, Time: 2.05, Learning Rate: 1.000e-03
# It: 560, Loss: 1.338e+03, Y0: 79.937, Time: 1.99, Learning Rate: 1.000e-03
# It: 570, Loss: 2.963e+03, Y0: 79.940, Time: 2.15, Learning Rate: 1.000e-03
# It: 580, Loss: 2.895e+03, Y0: 80.010, Time: 2.03, Learning Rate: 1.000e-03
# It: 590, Loss: 3.201e+03, Y0: 80.003, Time: 2.07, Learning Rate: 1.000e-03
# It: 600, Loss: 2.984e+03, Y0: 79.965, Time: 2.03, Learning Rate: 1.000e-03
# It: 610, Loss: 1.367e+03, Y0: 79.934, Time: 2.06, Learning Rate: 1.000e-03
# It: 620, Loss: 1.490e+03, Y0: 79.897, Time: 1.98, Learning Rate: 1.000e-03
# It: 630, Loss: 1.480e+03, Y0: 79.895, Time: 2.08, Learning Rate: 1.000e-03
# It: 640, Loss: 1.495e+03, Y0: 79.903, Time: 2.03, Learning Rate: 1.000e-03
# It: 650, Loss: 1.343e+03, Y0: 79.913, Time: 2.10, Learning Rate: 1.000e-03
# It: 660, Loss: 1.271e+03, Y0: 79.931, Time: 2.02, Learning Rate: 1.000e-03
# It: 670, Loss: 2.216e+03, Y0: 79.986, Time: 2.10, Learning Rate: 1.000e-03
# It: 680, Loss: 1.235e+03, Y0: 79.968, Time: 2.06, Learning Rate: 1.000e-03
# It: 690, Loss: 1.139e+03, Y0: 79.922, Time: 2.08, Learning Rate: 1.000e-03
# It: 700, Loss: 1.364e+03, Y0: 79.904, Time: 2.08, Learning Rate: 1.000e-03
# It: 710, Loss: 1.554e+03, Y0: 79.866, Time: 2.11, Learning Rate: 1.000e-03
# It: 720, Loss: 2.150e+03, Y0: 79.898, Time: 2.10, Learning Rate: 1.000e-03
# It: 730, Loss: 5.352e+03, Y0: 79.877, Time: 2.08, Learning Rate: 1.000e-03
# It: 740, Loss: 1.249e+03, Y0: 79.917, Time: 2.09, Learning Rate: 1.000e-03
# It: 750, Loss: 2.589e+03, Y0: 79.925, Time: 2.05, Learning Rate: 1.000e-03
# It: 760, Loss: 4.870e+03, Y0: 79.862, Time: 1.98, Learning Rate: 1.000e-03
# It: 770, Loss: 1.438e+03, Y0: 79.822, Time: 2.09, Learning Rate: 1.000e-03
# It: 780, Loss: 1.226e+03, Y0: 79.843, Time: 2.11, Learning Rate: 1.000e-03
# It: 790, Loss: 1.669e+03, Y0: 79.847, Time: 2.03, Learning Rate: 1.000e-03
# It: 800, Loss: 2.070e+03, Y0: 79.868, Time: 2.01, Learning Rate: 1.000e-03
# It: 810, Loss: 8.323e+03, Y0: 79.894, Time: 2.02, Learning Rate: 1.000e-03
# It: 820, Loss: 1.440e+03, Y0: 79.918, Time: 2.05, Learning Rate: 1.000e-03
# It: 830, Loss: 1.218e+03, Y0: 79.948, Time: 2.02, Learning Rate: 1.000e-03
# It: 840, Loss: 2.508e+03, Y0: 80.000, Time: 2.07, Learning Rate: 1.000e-03
# It: 850, Loss: 3.020e+03, Y0: 79.999, Time: 2.04, Learning Rate: 1.000e-03
# It: 860, Loss: 1.911e+03, Y0: 79.980, Time: 2.02, Learning Rate: 1.000e-03
# It: 870, Loss: 1.251e+03, Y0: 79.960, Time: 2.02, Learning Rate: 1.000e-03
# It: 880, Loss: 1.831e+04, Y0: 79.933, Time: 2.03, Learning Rate: 1.000e-03
# It: 890, Loss: 1.700e+03, Y0: 80.007, Time: 2.08, Learning Rate: 1.000e-03
# It: 900, Loss: 1.051e+03, Y0: 79.981, Time: 2.03, Learning Rate: 1.000e-03
# It: 910, Loss: 1.099e+03, Y0: 79.916, Time: 2.06, Learning Rate: 1.000e-03
# It: 920, Loss: 1.175e+03, Y0: 79.848, Time: 2.10, Learning Rate: 1.000e-03
# It: 930, Loss: 4.122e+03, Y0: 79.855, Time: 2.11, Learning Rate: 1.000e-03
# It: 940, Loss: 1.434e+03, Y0: 79.884, Time: 2.08, Learning Rate: 1.000e-03
# It: 950, Loss: 1.055e+03, Y0: 79.860, Time: 2.10, Learning Rate: 1.000e-03
# It: 960, Loss: 2.037e+03, Y0: 79.809, Time: 2.03, Learning Rate: 1.000e-03
# It: 970, Loss: 1.832e+03, Y0: 79.787, Time: 2.03, Learning Rate: 1.000e-03
# It: 980, Loss: 1.648e+03, Y0: 79.789, Time: 2.02, Learning Rate: 1.000e-03
# It: 990, Loss: 1.282e+03, Y0: 79.773, Time: 2.10, Learning Rate: 1.000e-03
# It: 1000, Loss: 3.856e+03, Y0: 79.746, Time: 2.06, Learning Rate: 1.000e-03
# It: 1010, Loss: 1.106e+03, Y0: 79.807, Time: 2.07, Learning Rate: 1.000e-03
# It: 1020, Loss: 9.735e+02, Y0: 79.797, Time: 2.07, Learning Rate: 1.000e-03
# It: 1030, Loss: 2.221e+03, Y0: 79.758, Time: 2.05, Learning Rate: 1.000e-03
# It: 1040, Loss: 1.120e+03, Y0: 79.726, Time: 2.08, Learning Rate: 1.000e-03
# It: 1050, Loss: 1.084e+03, Y0: 79.700, Time: 2.05, Learning Rate: 1.000e-03
# It: 1060, Loss: 1.035e+03, Y0: 79.703, Time: 2.01, Learning Rate: 1.000e-03
# It: 1070, Loss: 5.059e+03, Y0: 79.733, Time: 2.09, Learning Rate: 1.000e-03
# It: 1080, Loss: 1.023e+03, Y0: 79.719, Time: 2.09, Learning Rate: 1.000e-03
# It: 1090, Loss: 1.280e+03, Y0: 79.697, Time: 2.05, Learning Rate: 1.000e-03
# It: 1100, Loss: 1.055e+03, Y0: 79.694, Time: 2.04, Learning Rate: 1.000e-03
# It: 1110, Loss: 9.305e+02, Y0: 79.711, Time: 2.03, Learning Rate: 1.000e-03
# It: 1120, Loss: 9.533e+02, Y0: 79.688, Time: 2.03, Learning Rate: 1.000e-03
# It: 1130, Loss: 5.817e+03, Y0: 79.658, Time: 1.97, Learning Rate: 1.000e-03
# It: 1140, Loss: 9.435e+02, Y0: 79.659, Time: 2.07, Learning Rate: 1.000e-03
# It: 1150, Loss: 8.718e+02, Y0: 79.631, Time: 2.04, Learning Rate: 1.000e-03
# It: 1160, Loss: 6.814e+03, Y0: 79.620, Time: 2.04, Learning Rate: 1.000e-03
# It: 1170, Loss: 1.080e+03, Y0: 79.653, Time: 2.14, Learning Rate: 1.000e-03
# It: 1180, Loss: 1.225e+03, Y0: 79.619, Time: 2.16, Learning Rate: 1.000e-03
# It: 1190, Loss: 1.744e+03, Y0: 79.604, Time: 2.11, Learning Rate: 1.000e-03
# It: 1200, Loss: 9.026e+02, Y0: 79.619, Time: 2.06, Learning Rate: 1.000e-03
# It: 1210, Loss: 1.118e+03, Y0: 79.671, Time: 2.09, Learning Rate: 1.000e-03
# It: 1220, Loss: 1.089e+03, Y0: 79.695, Time: 2.05, Learning Rate: 1.000e-03
# It: 1230, Loss: 8.708e+02, Y0: 79.730, Time: 2.04, Learning Rate: 1.000e-03
# It: 1240, Loss: 1.151e+03, Y0: 79.696, Time: 2.11, Learning Rate: 1.000e-03
# It: 1250, Loss: 9.190e+02, Y0: 79.665, Time: 2.05, Learning Rate: 1.000e-03
# It: 1260, Loss: 1.080e+03, Y0: 79.693, Time: 2.02, Learning Rate: 1.000e-03
# It: 1270, Loss: 8.043e+02, Y0: 79.731, Time: 2.05, Learning Rate: 1.000e-03
# It: 1280, Loss: 3.202e+03, Y0: 79.759, Time: 2.05, Learning Rate: 1.000e-03
# It: 1290, Loss: 8.036e+02, Y0: 79.710, Time: 2.09, Learning Rate: 1.000e-03
# It: 1300, Loss: 1.038e+03, Y0: 79.665, Time: 2.08, Learning Rate: 1.000e-03
# It: 1310, Loss: 1.825e+03, Y0: 79.666, Time: 2.10, Learning Rate: 1.000e-03
# It: 1320, Loss: 1.147e+03, Y0: 79.722, Time: 2.05, Learning Rate: 1.000e-03
# It: 1330, Loss: 9.144e+02, Y0: 79.725, Time: 2.13, Learning Rate: 1.000e-03
# It: 1340, Loss: 8.790e+02, Y0: 79.677, Time: 2.06, Learning Rate: 1.000e-03
# It: 1350, Loss: 8.405e+02, Y0: 79.649, Time: 2.14, Learning Rate: 1.000e-03
# It: 1360, Loss: 3.700e+03, Y0: 79.617, Time: 2.14, Learning Rate: 1.000e-03
# It: 1370, Loss: 1.078e+03, Y0: 79.610, Time: 2.12, Learning Rate: 1.000e-03
# It: 1380, Loss: 9.664e+02, Y0: 79.582, Time: 2.06, Learning Rate: 1.000e-03
# It: 1390, Loss: 7.978e+02, Y0: 79.603, Time: 2.10, Learning Rate: 1.000e-03
# It: 1400, Loss: 3.230e+03, Y0: 79.616, Time: 2.07, Learning Rate: 1.000e-03
# It: 1410, Loss: 1.079e+03, Y0: 79.647, Time: 2.09, Learning Rate: 1.000e-03
# It: 1420, Loss: 8.297e+02, Y0: 79.665, Time: 2.11, Learning Rate: 1.000e-03
# It: 1430, Loss: 7.513e+02, Y0: 79.700, Time: 2.01, Learning Rate: 1.000e-03
# It: 1440, Loss: 1.093e+03, Y0: 79.728, Time: 1.99, Learning Rate: 1.000e-03
# It: 1450, Loss: 9.165e+02, Y0: 79.686, Time: 2.02, Learning Rate: 1.000e-03
# It: 1460, Loss: 1.673e+03, Y0: 79.714, Time: 2.04, Learning Rate: 1.000e-03
# It: 1470, Loss: 8.508e+02, Y0: 79.722, Time: 2.10, Learning Rate: 1.000e-03
# It: 1480, Loss: 8.539e+02, Y0: 79.729, Time: 2.06, Learning Rate: 1.000e-03
# It: 1490, Loss: 8.180e+02, Y0: 79.686, Time: 2.12, Learning Rate: 1.000e-03
# It: 1500, Loss: 1.706e+03, Y0: 79.698, Time: 2.05, Learning Rate: 1.000e-03
# It: 1510, Loss: 2.103e+03, Y0: 79.684, Time: 2.11, Learning Rate: 1.000e-03
# It: 1520, Loss: 6.348e+02, Y0: 79.660, Time: 2.02, Learning Rate: 1.000e-03
# It: 1530, Loss: 6.510e+02, Y0: 79.704, Time: 1.98, Learning Rate: 1.000e-03
# It: 1540, Loss: 1.599e+03, Y0: 79.766, Time: 2.07, Learning Rate: 1.000e-03
# It: 1550, Loss: 1.126e+03, Y0: 79.756, Time: 2.07, Learning Rate: 1.000e-03
# It: 1560, Loss: 1.298e+03, Y0: 79.748, Time: 2.02, Learning Rate: 1.000e-03
# It: 1570, Loss: 7.863e+02, Y0: 79.800, Time: 2.08, Learning Rate: 1.000e-03
# It: 1580, Loss: 7.086e+02, Y0: 79.789, Time: 2.03, Learning Rate: 1.000e-03
# It: 1590, Loss: 4.135e+03, Y0: 79.759, Time: 2.10, Learning Rate: 1.000e-03
# It: 1600, Loss: 7.825e+02, Y0: 79.807, Time: 2.04, Learning Rate: 1.000e-03
# It: 1610, Loss: 7.334e+02, Y0: 79.794, Time: 1.95, Learning Rate: 1.000e-03
# It: 1620, Loss: 7.431e+02, Y0: 79.781, Time: 1.96, Learning Rate: 1.000e-03
# It: 1630, Loss: 1.072e+03, Y0: 79.737, Time: 2.11, Learning Rate: 1.000e-03
# It: 1640, Loss: 8.516e+02, Y0: 79.775, Time: 1.96, Learning Rate: 1.000e-03
# It: 1650, Loss: 8.103e+02, Y0: 79.775, Time: 2.07, Learning Rate: 1.000e-03
# It: 1660, Loss: 5.831e+02, Y0: 79.796, Time: 2.05, Learning Rate: 1.000e-03
# It: 1670, Loss: 5.803e+03, Y0: 79.783, Time: 2.09, Learning Rate: 1.000e-03
# It: 1680, Loss: 6.424e+02, Y0: 79.779, Time: 2.04, Learning Rate: 1.000e-03
# It: 1690, Loss: 1.613e+03, Y0: 79.752, Time: 1.98, Learning Rate: 1.000e-03
# It: 1700, Loss: 7.339e+02, Y0: 79.735, Time: 2.11, Learning Rate: 1.000e-03
# It: 1710, Loss: 3.341e+03, Y0: 79.718, Time: 2.01, Learning Rate: 1.000e-03
# It: 1720, Loss: 1.096e+03, Y0: 79.691, Time: 2.01, Learning Rate: 1.000e-03
# It: 1730, Loss: 5.461e+02, Y0: 79.692, Time: 2.06, Learning Rate: 1.000e-03
# It: 1740, Loss: 7.139e+02, Y0: 79.691, Time: 1.95, Learning Rate: 1.000e-03
# It: 1750, Loss: 6.340e+02, Y0: 79.671, Time: 2.03, Learning Rate: 1.000e-03
# It: 1760, Loss: 1.166e+03, Y0: 79.666, Time: 2.05, Learning Rate: 1.000e-03
# It: 1770, Loss: 5.794e+02, Y0: 79.636, Time: 2.05, Learning Rate: 1.000e-03
# It: 1780, Loss: 6.057e+02, Y0: 79.602, Time: 2.05, Learning Rate: 1.000e-03
# It: 1790, Loss: 5.205e+02, Y0: 79.600, Time: 2.05, Learning Rate: 1.000e-03
# It: 1800, Loss: 6.214e+02, Y0: 79.619, Time: 2.04, Learning Rate: 1.000e-03
# It: 1810, Loss: 3.284e+03, Y0: 79.617, Time: 2.08, Learning Rate: 1.000e-03
# It: 1820, Loss: 5.882e+02, Y0: 79.631, Time: 2.04, Learning Rate: 1.000e-03
# It: 1830, Loss: 1.768e+03, Y0: 79.621, Time: 2.07, Learning Rate: 1.000e-03
# It: 1840, Loss: 5.881e+02, Y0: 79.580, Time: 1.99, Learning Rate: 1.000e-03
# It: 1850, Loss: 5.730e+02, Y0: 79.544, Time: 2.03, Learning Rate: 1.000e-03
# It: 1860, Loss: 6.330e+02, Y0: 79.532, Time: 1.96, Learning Rate: 1.000e-03
# It: 1870, Loss: 6.008e+02, Y0: 79.568, Time: 1.96, Learning Rate: 1.000e-03
# It: 1880, Loss: 4.808e+02, Y0: 79.589, Time: 2.10, Learning Rate: 1.000e-03
# It: 1890, Loss: 6.072e+02, Y0: 79.623, Time: 2.00, Learning Rate: 1.000e-03
# It: 1900, Loss: 5.971e+02, Y0: 79.577, Time: 2.03, Learning Rate: 1.000e-03
# It: 1910, Loss: 6.730e+02, Y0: 79.569, Time: 1.92, Learning Rate: 1.000e-03
# It: 1920, Loss: 1.797e+03, Y0: 79.594, Time: 1.98, Learning Rate: 1.000e-03
# It: 1930, Loss: 5.361e+02, Y0: 79.592, Time: 2.10, Learning Rate: 1.000e-03
# It: 1940, Loss: 5.921e+02, Y0: 79.655, Time: 2.07, Learning Rate: 1.000e-03
# It: 1950, Loss: 4.850e+02, Y0: 79.687, Time: 1.97, Learning Rate: 1.000e-03
# It: 1960, Loss: 1.472e+03, Y0: 79.700, Time: 1.98, Learning Rate: 1.000e-03
# It: 1970, Loss: 4.836e+02, Y0: 79.736, Time: 2.05, Learning Rate: 1.000e-03
# It: 1980, Loss: 5.614e+02, Y0: 79.741, Time: 2.00, Learning Rate: 1.000e-03
# It: 1990, Loss: 5.970e+02, Y0: 79.754, Time: 2.02, Learning Rate: 1.000e-03
