# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/bin/python

# %%
# %pip install --upgrade --force-reinstall numpy matplotlib
# Out:
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 2.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: pillow
# ...

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
print(np.__version__, matplotlib.__version__)
# Out:
# 2.4.2 3.10.8

# %%
# !python3 plot.py \
  --input-dir ../alessio/recursive1_outputs/heavy_from_zero \
  --mode models \
  --exact-solution quadratic_coupled \
  --eval-paths 1024 \
  --save-eval-bundle
# Out:
# [HeavyPlot] source_mode=models
# [HeavyPlot] recursive_dir=/Users/emanuelelippi/Library/Mobile Documents/com~apple~CloudDocs/Universita/Tirocinio/code/FBSDENN_Lippi/alessio/recursive1_outputs/heavy_from_zero/run_20260228_195830/recursive
# [HeavyPlot] output_dir=/Users/emanuelelippi/Library/Mobile Documents/com~apple~CloudDocs/Universita/Tirocinio/code/FBSDENN_Lippi/alessio/recursive1_outputs/heavy_from_zero/run_20260228_195830/recursive/plots/heavy_training_diagnostics
# [HeavyPlot] pass_ids=[1, 2, 3] -> pass_indices=[0, 1, 2]
# [HeavyPlot] loss_key=n/a (models-only)
# [HeavyPlot] selected_pass_index=None
# [HeavyPlot] has_exact_metrics=True
# [HeavyPlot] summary_csv=/Users/emanuelelippi/Library/Mobile Documents/com~apple~CloudDocs/Universita/Tirocinio/code/FBSDENN_Lippi/alessio/recursive1_outputs/heavy_from_zero/run_20260228_195830/recursive/plots/heavy_training_diagnostics/heavy_pass_summary.csv
# [HeavyPlot] exact_solution_name=quadratic_coupled
# ...
