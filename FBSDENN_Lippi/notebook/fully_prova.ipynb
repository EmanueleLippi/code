# %%
## Rete neurale con normalizzazione della loss

import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from abc import ABC, abstractmethod


class FBSNN(ABC): # Forward-Backward Stochastic Neural Network
    def __init__(self, Xi, T,
                       M, N, D,
                       layers,
                       clip_grad_norm=1.0, 
                       use_antithetic_sampling=True):
        self.Xi = Xi # initial point
        self.T = T # terminal time

        self.M = M # number of trajectories
        self.N = N # number of time snapshots
        self.D = D # number of dimensions

        # layers
        self.layers = layers # (D+1) --> 1

        # migliorie advanced richieste
        self.clip_grad_norm = clip_grad_norm
        self.use_antithetic_sampling = bool(use_antithetic_sampling)

        # initialize NN
        self.weights, self.biases = self.initialize_NN(layers)

        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))

        # tf placeholders and graph (training)
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.t_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, 1]) # M x (N+1) x 1
        self.W_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, self.D]) # M x (N+1) x D
        self.Xi_tf = tf.placeholder(tf.float32, shape=[M, D]) # M x D
        self.const_tf = tf.placeholder(tf.float32, shape=[])

        self.loss, self.X_pred, self.Y_pred, self.Y0_pred, self.Z_pred = self.loss_function(self.t_tf, self.W_tf, self.Xi_tf)

        # optimizer + gradient clipping
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        gradients_and_variables = self.optimizer.compute_gradients(self.loss)
        if self.clip_grad_norm is not None:
            non_null_grads_and_vars = [(g, v) for g, v in gradients_and_variables if g is not None]
            if non_null_grads_and_vars:
                gradients, variables = zip(*non_null_grads_and_vars)
                gradients, _ = tf.clip_by_global_norm(gradients, self.clip_grad_norm)
                clipped = list(zip(gradients, variables))
                untouched = [(g, v) for g, v in gradients_and_variables if g is None]
                gradients_and_variables = clipped + untouched
        self.train_op = self.optimizer.apply_gradients(gradients_and_variables)
        # initialize session and variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

        # lightweight in-memory checkpoint utilities for early stopping
        self._trainable_vars = tf.trainable_variables()
        self._snapshot_ph = [
            tf.placeholder(tf.float32, shape=v.shape, name=f"snapshot_ph_{i}")
            for i, v in enumerate(self._trainable_vars)
        ]
        self._restore_ops = [v.assign(ph) for v, ph in zip(self._trainable_vars, self._snapshot_ph)]

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = X
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    def net_u(self, t, X): # M x 1, M x D
        u = self.neural_net(tf.concat([t, X], 1), self.weights, self.biases) # M x 1
        Du = tf.gradients(u, X)[0] # M x D
        return u, Du

    def Dg_tf(self, X): # M x D
        return tf.gradients(self.g_tf(X), X)[0] # M x D

    def loss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        loss = 0
        X_list = []
        Y_list = []
        Z_list = []

        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        #X0 = tf.tile(Xi, [self.M, 1]) # M x D
        #Y0, Du0 = self.net_u(t0, X0) # M x 1, M x D
        X0 = Xi
        Y0, Du0 = self.net_u(t0, X0)
        sigma0 = self.sigma_tf(t0, X0, Y0)
        Z0 = tf.squeeze(tf.matmul(tf.expand_dims(Du0, 1), sigma0), axis=1)

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]

            dW = W1 - W0
            sigma_dW = tf.squeeze(tf.matmul(sigma0, tf.expand_dims(dW, -1)), axis=[-1])
            X1 = X0 + self.mu_tf(t0, X0, Y0, Z0) * (t1 - t0) + sigma_dW

            # Z = Du*sigma e nella backward compare Z*dW.
            Y1_tilde = Y0 + self.phi_tf(t0, X0, Y0, Z0) * (t1 - t0) + tf.reduce_sum(Z0 * dW, axis=1, keepdims=True)

            Y1, Du1 = self.net_u(t1, X1)
            sigma1 = self.sigma_tf(t1, X1, Y1)
            Z1 = tf.squeeze(tf.matmul(tf.expand_dims(Du1, 1), sigma1), axis=1)

            loss += tf.reduce_sum(tf.square(Y1 - Y1_tilde))

            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            sigma0 = sigma1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)

        loss += tf.reduce_sum(tf.square(Y1 - self.g_tf(X1)))

        Dg = self.Dg_tf(X1)
        Z_terminal = tf.squeeze(tf.matmul(tf.expand_dims(Dg, 1), sigma1), axis=1)
        loss += tf.reduce_sum(tf.square(Z1 - Z_terminal))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)

        return loss/self.N, X, Y, Y[0, 0, 0], Z

    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1)) # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D)) # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        if self.use_antithetic_sampling and M > 1:
            half_M = M // 2
            DW_half = np.sqrt(dt) * np.random.normal(size=(half_M, N, D))
            DW[:half_M, 1:, :] = DW_half
            DW[half_M:2 * half_M, 1:, :] = -DW_half
            if M % 2 == 1:
                DW[-1, 1:, :] = np.sqrt(dt) * np.random.normal(size=(N, D))
        else:
            DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1) # M x (N+1) x 1
        W = np.cumsum(DW, axis=1) # M x (N+1) x D

        return t, W
    def _get_snapshot(self):
        return self.sess.run(self._trainable_vars)

    def _restore_snapshot(self, weights):
        feed = {ph: w for ph, w in zip(self._snapshot_ph, weights)}
        self.sess.run(self._restore_ops, feed_dict=feed)

    def train(
        self,
        N_Iter,
        learning_rate,
        const_value=None,
        eval_every=25,
        val_batches=8,
        early_stopping_metric='loss',
        y0_target=None,
        patience=None,
        min_delta=1e-3,
        restore_best=False,
    ):
        start_time = time.time()
        last_loss = None
        last_y0 = None

        current_const = np.float32(self.const if const_value is None else const_value)

        best_score = np.inf
        best_iter = -1
        best_snapshot = None
        no_improve_iters = 0
        stopped_early = False

        for it in range(N_Iter):
            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D

            tf_dict = {
                self.Xi_tf: self.Xi,
                self.t_tf: t_batch,
                self.W_tf: W_batch,
                self.learning_rate: learning_rate,
                self.const_tf: current_const,
            }

            self.sess.run(self.train_op, tf_dict)

            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.loss, self.Y0_pred, self.learning_rate], tf_dict)
                last_loss = float(loss_value)
                last_y0 = float(Y0_value)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()

            if (it % eval_every == 0) or (it == N_Iter - 1):
                eval_stats = self.evaluate(const_value=current_const, n_batches=val_batches)

                if early_stopping_metric == 'y0_abs':
                    if y0_target is None:
                        raise ValueError("y0_target is required when early_stopping_metric='y0_abs'")
                    score = abs(eval_stats['mean_y0'] - float(y0_target))
                else:
                    score = eval_stats['mean_loss']

                if (best_score - score) > min_delta:
                    best_score = float(score)
                    best_iter = int(it)
                    best_snapshot = self._get_snapshot()
                    no_improve_iters = 0
                else:
                    no_improve_iters += eval_every

                if patience is not None and no_improve_iters >= patience:
                    print(f"[EarlyStop] it={it}, best_it={best_iter}, best_score={best_score:.6e}")
                    stopped_early = True
                    break

        if restore_best and best_snapshot is not None:
            self._restore_snapshot(best_snapshot)
            print(f"[RestoreBest] best_it={best_iter}, best_score={best_score:.6e}")

        return {
            'const': float(current_const),
            'learning_rate': float(learning_rate),
            'n_iter': int(N_Iter),
            'last_loss': last_loss,
            'last_y0': last_y0,
            'best_iter': int(best_iter),
            'best_score': float(best_score),
            'stopped_early': bool(stopped_early),
        }

    def evaluate(self, const_value=None, n_batches=5):
        current_const = np.float32(self.const if const_value is None else const_value)
        losses = []
        y0s = []

        for _ in range(n_batches):
            t_batch, W_batch = self.fetch_minibatch()
            tf_dict = {
                self.Xi_tf: self.Xi,
                self.t_tf: t_batch,
                self.W_tf: W_batch,
                self.const_tf: current_const,
            }
            loss_value, y0_value = self.sess.run([self.loss, self.Y0_pred], tf_dict)
            losses.append(float(loss_value))
            y0s.append(float(y0_value))

        return {
            'const': float(current_const),
            'mean_loss': float(np.mean(losses)),
            'std_loss': float(np.std(losses)),
            'mean_y0': float(np.mean(y0s)),
            'std_y0': float(np.std(y0s)),
            'n_batches': int(n_batches),
        }

    def predict(self, Xi_star, t_star, W_star, const_value=None):
        current_const = np.float32(self.const if const_value is None else const_value)
        tf_dict = {
            self.Xi_tf: Xi_star,
            self.t_tf: t_star,
            self.W_tf: W_star,
            self.const_tf: current_const,
        }

        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        Z_star = self.sess.run(self.Z_pred, tf_dict)

        return X_star, Y_star, Z_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def phi_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        pass # M x1

    @abstractmethod
    def g_tf(self, X): # M x D
        pass # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return np.zeros([M, D]) # M x D

    @abstractmethod
    def sigma_tf(self, t, X, Y): # M x 1, M x D, M x 1
        M = self.M
        D = self.D
        return tf.matrix_diag(tf.ones([M, D])) # M x D x D
    ###########################################################################


# backward compatibility
fbsde_NN = FBSNN
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class NN_Quadratic_Coupled(FBSNN):
    def __init__(self, Xi, T, M, N, D, layers, parameters):
        self.mu1 = parameters['mu1']
        self.mu2 = parameters['mu2']
        self.c1 = parameters['c1']
        self.c2 = parameters['c2']
        self.c3 = parameters['c3']
        self.c4 = parameters['c4']
        self.gamma = parameters['gamma']
        self.s1 = parameters['s1']
        self.s2 = parameters['s2']
        self.s3 = parameters['s3']
        self.x_max = parameters['x_max']
        self.v_min = parameters['v_min']
        self.v_max = parameters['v_max']
        self.d = parameters['d']
        self.const = parameters['const']
        super().__init__(Xi, T, M, N, D, layers)

    def psi(self,X_state):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     tf.minimum(X_state/self.d, (self.x_max - X_state)/self.d)
                     )
                 )
        return result

    def psi3(self,V):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     (self.v_max- V)/self.d
                     )
                 )
        return result
    
    def psi4(self,V):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     (V - self.v_min)/self.d
                     )
                 )
        return result

    def f(self,X,Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        Z_S, Z_H, Z_V, _ = tf.split(Z, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        gamma = tf.cast(self.gamma, tf.float32)
        exp_S = tf.exp(-S)
        return -0.5 * V * self.psi(- exp_S * Z_S /(gamma * s1))
    
    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu1 = tf.cast(self.mu1, tf.float32)
        mu2 = tf.cast(self.mu2, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        c2 = tf.cast(self.c2, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)
        c4 = tf.cast(self.c4, tf.float32)
        x_max = tf.cast(self.x_max, tf.float32)
        const = tf.cast(self.const_tf, tf.float32)
        dS = mu1 * (c1 - S)
        dH = mu2 * (c2 - H)
        dV = self.f(X,Z) * self.psi(X_state) + c3 * self.psi(-X_state)*self.psi3(V) - c4 * self.psi(X_state-x_max)*self.psi4(V)
        dX = V
        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        gamma = tf.cast(self.gamma, tf.float32)
        exp_S = tf.exp(S)
        return -gamma * exp_S * X_state + V**2 + V*X_state

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        Z_S, Z_H, Z_V, _ = tf.split(Z, num_or_size_splits=4, axis=1)
        
        mu1 = tf.cast(self.mu1, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)
        c4 = tf.cast(self.c4, tf.float32)
        x_max = tf.cast(self.x_max, tf.float32)
        gamma = tf.cast(self.gamma, tf.float32)
        const = tf.cast(self.const_tf, tf.float32)
        
        exp_S = tf.exp(S)

        term1 = -gamma * exp_S * X_state * mu1 * (c1-S)
        term2 = (2 * V + X_state) * (self.f(X,Z) * self.psi(X_state) + c3 * self.psi(-X_state)*self.psi3(V) - c4 * self.psi(X_state-x_max)*self.psi4(V))
        term3 = -gamma * exp_S * V + (0.5 * (Z_V/s3 - X_state))**2
        # V = 0.5 * (Z_V/s3 - X_state)
        term4 = -0.5 * gamma * exp_S * X_state * s1**2 + s3**2
        
        return term1 + term2 + term3 + term4
    
    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)

        return tf.stack([r1, r2, r3, r4], axis=1)

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    M = 2048 #se non basta vram abbassa a 1500
    N = 170 #da provare utilizzando piu iter e learning rate piu basso
    D = 4
    T = 24

    params = {
        'mu1': np.float32(1.0),
        'mu2': np.float32(1.0),
        'c1': np.float32(1.0),
        'c2': np.float32(1.0),
        'c3': np.float32(10.0),
        'c4': np.float32(10.0),
        'gamma': np.float32(1.0),
        'd': np.float32(1.0),
        'x_max': np.float32(10.0),
        'v_max': np.float32(2.0),
        'v_min': np.float32(-2.0),
        's1': np.float32(0.5),
        's2': np.float32(0.5),
        's3': np.float32(0.5),
        # Soft-init: partenza disaccoppiata
        'const': np.float32(0.0),
    }

# Generazione distribuita (M punti diversi)
# Creiamo una lista di 4 array lunghi M, poi li impiliamo come colonne
    Xi = np.stack([
        np.random.normal(1.0, 1.0, M),   # S
        np.random.normal(1.0, 1.0, M),   # H
        np.random.normal(0.0, 1.0, M),   # V
        np.random.uniform(1.0, 9.0, M)   # X
    ], axis=1).astype(np.float32)
    layers = [D+1] + 4*[256] + [1]
    
    model = NN_Quadratic_Coupled(Xi, T, M, N, D, layers, params)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9

# %%
# Curriculum sull'accoppiamento: const cresce gradualmente fino a 1.0
coupling_step = 1.0
coupling_levels = np.arange(1.0, 1.0 + coupling_step, coupling_step, dtype=np.float32)

stage_plan = [
    (6000, 1e-3),
    (4000, 5e-4),
    (4000, 1e-4),
]
stage_logs = []

for level in coupling_levels:
    model.const = np.float32(level)
    print(f"=== Coupling stage: const={float(level):.1f} ===")
    for n_iter, lr in stage_plan:
        t0 = time.time()
        train_stats = model.train(N_Iter=n_iter, learning_rate=lr, const_value=level)
        eval_stats = model.evaluate(const_value=level, n_batches=5)
        elapsed = time.time() - t0
        log_row = {
            'phase': 'curriculum',
            'const': float(level),
            'lr': float(lr),
            'n_iter': int(n_iter),
            'train_last_loss': train_stats['last_loss'],
            'train_last_y0': train_stats['last_y0'],
            'eval_mean_loss': eval_stats['mean_loss'],
            'eval_std_loss': eval_stats['std_loss'],
            'eval_mean_y0': eval_stats['mean_y0'],
            'eval_std_y0': eval_stats['std_y0'],
            'elapsed_sec': float(elapsed),
        }
        stage_logs.append(log_row)
        print(
            f"[StageSummary] const={level:.1f}, lr={lr:.1e}, iters={n_iter}, "
            f"eval_loss={eval_stats['mean_loss']:.3e}±{eval_stats['std_loss']:.2e}, "
            f"eval_Y0={eval_stats['mean_y0']:.3f}±{eval_stats['std_y0']:.3f}, "
            f"time={elapsed:.1f}s"
        )

# Fine-tuning finale fully coupled
model.const = np.float32(1.0)
print("=== Final fine-tuning at const=1.0 ===")

exact_y0 = float(
    -params['gamma'] * np.exp(Xi[0, 0]) * Xi[0, 3] + Xi[0, 2]**2 + Xi[0, 2] * Xi[0, 3]
)

# Punto 2: fermati a 1e-5
final_plan = [(3000, 1e-5)]
for n_iter, lr in final_plan:
    t0 = time.time()
    train_stats = model.train(
        N_Iter=n_iter,
        learning_rate=lr,
        const_value=1.0,
        eval_every=25,
        val_batches=8,
        early_stopping_metric='loss',
        y0_target=exact_y0,
        patience=500,
        min_delta=1e-3,
        restore_best=True,
    )
    eval_stats = model.evaluate(const_value=1.0, n_batches=8)
    elapsed = time.time() - t0
    log_row = {
        'phase': 'final_finetune',
        'const': 1.0,
        'lr': float(lr),
        'n_iter': int(n_iter),
        'train_last_loss': train_stats['last_loss'],
        'train_last_y0': train_stats['last_y0'],
        'best_iter': train_stats['best_iter'],
        'best_score': train_stats['best_score'],
        'stopped_early': train_stats['stopped_early'],
        'eval_mean_loss': eval_stats['mean_loss'],
        'eval_std_loss': eval_stats['std_loss'],
        'eval_mean_y0': eval_stats['mean_y0'],
        'eval_std_y0': eval_stats['std_y0'],
        'elapsed_sec': float(elapsed),
    }
    stage_logs.append(log_row)
    print(
        f"[FinalSummary] const=1.0, lr={lr:.1e}, iters={n_iter}, "
        f"best_it={train_stats['best_iter']}, best_score={train_stats['best_score']:.3e}, "
        f"eval_loss={eval_stats['mean_loss']:.3e}±{eval_stats['std_loss']:.2e}, "
        f"eval_Y0={eval_stats['mean_y0']:.3f}±{eval_stats['std_y0']:.3f}, "
        f"time={elapsed:.1f}s"
    )

print("=== Curriculum Log (compact) ===")
for row in stage_logs:
    print(
        f"phase={row['phase']}, const={row['const']:.1f}, lr={row['lr']:.1e}, iters={row['n_iter']}, "
        f"eval_loss={row['eval_mean_loss']:.3e}, eval_y0={row['eval_mean_y0']:.3f}, elapsed_sec={row['elapsed_sec']}"
    )
# Out:
# === Coupling stage: const=1.0 ===
# It: 0, Loss: 2.306e+04, Y0: -0.563, Time: 142.00, Learning Rate: 1.000e-03
# It: 10, Loss: 8.781e+03, Y0: -2.055, Time: 26.35, Learning Rate: 1.000e-03
# It: 20, Loss: 6.633e+03, Y0: -0.633, Time: 5.62, Learning Rate: 1.000e-03
# It: 30, Loss: 5.520e+03, Y0: -6.702, Time: 7.19, Learning Rate: 1.000e-03
# It: 40, Loss: 4.643e+03, Y0: 2.047, Time: 5.57, Learning Rate: 1.000e-03
# It: 50, Loss: 4.441e+03, Y0: 0.105, Time: 5.65, Learning Rate: 1.000e-03
# It: 60, Loss: 3.973e+03, Y0: 7.541, Time: 7.13, Learning Rate: 1.000e-03
# It: 70, Loss: 3.950e+03, Y0: 7.335, Time: 5.56, Learning Rate: 1.000e-03
# It: 80, Loss: 5.328e+03, Y0: -12.464, Time: 7.14, Learning Rate: 1.000e-03
# It: 90, Loss: 3.681e+03, Y0: -8.776, Time: 5.57, Learning Rate: 1.000e-03
# It: 100, Loss: 3.586e+03, Y0: 13.552, Time: 5.58, Learning Rate: 1.000e-03
# It: 110, Loss: 3.718e+03, Y0: -15.994, Time: 7.13, Learning Rate: 1.000e-03
# It: 120, Loss: 3.365e+03, Y0: 8.433, Time: 5.60, Learning Rate: 1.000e-03
# It: 130, Loss: 3.417e+03, Y0: 13.346, Time: 7.13, Learning Rate: 1.000e-03
# It: 140, Loss: 2.940e+03, Y0: 0.662, Time: 5.61, Learning Rate: 1.000e-03
# It: 150, Loss: 3.002e+03, Y0: 13.978, Time: 5.59, Learning Rate: 1.000e-03
# It: 160, Loss: 2.781e+03, Y0: -11.918, Time: 7.18, Learning Rate: 1.000e-03
# It: 170, Loss: 2.988e+03, Y0: 16.474, Time: 5.60, Learning Rate: 1.000e-03
# It: 180, Loss: 2.810e+03, Y0: -5.884, Time: 7.12, Learning Rate: 1.000e-03
# It: 190, Loss: 2.858e+03, Y0: 16.547, Time: 5.57, Learning Rate: 1.000e-03
# It: 200, Loss: 2.953e+03, Y0: 2.521, Time: 5.55, Learning Rate: 1.000e-03
# It: 210, Loss: 2.913e+03, Y0: 12.752, Time: 7.18, Learning Rate: 1.000e-03
# It: 220, Loss: 2.950e+03, Y0: -3.115, Time: 5.56, Learning Rate: 1.000e-03
# It: 230, Loss: 2.680e+03, Y0: 17.726, Time: 7.19, Learning Rate: 1.000e-03
# It: 240, Loss: 2.786e+03, Y0: 6.830, Time: 5.59, Learning Rate: 1.000e-03
# It: 250, Loss: 2.857e+03, Y0: -1.082, Time: 5.59, Learning Rate: 1.000e-03
# It: 260, Loss: 2.988e+03, Y0: 20.601, Time: 7.19, Learning Rate: 1.000e-03
# It: 270, Loss: 2.689e+03, Y0: -1.996, Time: 5.56, Learning Rate: 1.000e-03
# It: 280, Loss: 2.457e+03, Y0: 20.707, Time: 7.18, Learning Rate: 1.000e-03
# It: 290, Loss: 2.629e+03, Y0: 13.497, Time: 5.66, Learning Rate: 1.000e-03
# It: 300, Loss: 2.294e+03, Y0: 6.039, Time: 5.64, Learning Rate: 1.000e-03
# It: 310, Loss: 2.358e+03, Y0: -7.756, Time: 7.18, Learning Rate: 1.000e-03
# It: 320, Loss: 2.467e+03, Y0: 8.182, Time: 5.59, Learning Rate: 1.000e-03
# It: 330, Loss: 2.240e+03, Y0: 6.845, Time: 7.18, Learning Rate: 1.000e-03
# It: 340, Loss: 2.071e+03, Y0: 9.839, Time: 5.61, Learning Rate: 1.000e-03
# It: 350, Loss: 2.140e+03, Y0: 6.953, Time: 5.64, Learning Rate: 1.000e-03
# It: 360, Loss: 2.161e+03, Y0: 8.644, Time: 7.19, Learning Rate: 1.000e-03
# It: 370, Loss: 1.788e+03, Y0: 12.721, Time: 5.61, Learning Rate: 1.000e-03
# It: 380, Loss: 1.872e+03, Y0: 16.625, Time: 7.19, Learning Rate: 1.000e-03
# It: 390, Loss: 1.831e+03, Y0: 12.044, Time: 5.58, Learning Rate: 1.000e-03
# It: 400, Loss: 1.858e+03, Y0: 14.921, Time: 5.58, Learning Rate: 1.000e-03
# It: 410, Loss: 1.847e+03, Y0: 8.591, Time: 7.15, Learning Rate: 1.000e-03
# It: 420, Loss: 2.012e+03, Y0: 7.219, Time: 5.62, Learning Rate: 1.000e-03
# It: 430, Loss: 1.831e+03, Y0: 2.177, Time: 7.13, Learning Rate: 1.000e-03
# It: 440, Loss: 1.736e+03, Y0: 14.536, Time: 5.55, Learning Rate: 1.000e-03
# It: 450, Loss: 1.879e+03, Y0: 8.969, Time: 5.60, Learning Rate: 1.000e-03
# It: 460, Loss: 1.869e+03, Y0: 5.242, Time: 7.16, Learning Rate: 1.000e-03
# It: 470, Loss: 2.053e+03, Y0: 12.868, Time: 5.59, Learning Rate: 1.000e-03
# It: 480, Loss: 1.856e+03, Y0: -4.128, Time: 7.18, Learning Rate: 1.000e-03
# It: 490, Loss: 1.770e+03, Y0: 16.114, Time: 5.63, Learning Rate: 1.000e-03
# It: 500, Loss: 1.699e+03, Y0: 10.196, Time: 5.57, Learning Rate: 1.000e-03
# It: 510, Loss: 1.841e+03, Y0: 10.202, Time: 7.13, Learning Rate: 1.000e-03
# It: 520, Loss: 1.740e+03, Y0: 7.557, Time: 5.55, Learning Rate: 1.000e-03
# It: 530, Loss: 1.717e+03, Y0: 8.619, Time: 7.17, Learning Rate: 1.000e-03
# It: 540, Loss: 1.667e+03, Y0: 16.269, Time: 5.61, Learning Rate: 1.000e-03
# It: 550, Loss: 1.614e+03, Y0: 9.353, Time: 5.61, Learning Rate: 1.000e-03
# It: 560, Loss: 1.670e+03, Y0: 15.726, Time: 7.20, Learning Rate: 1.000e-03
# It: 570, Loss: 1.631e+03, Y0: 15.048, Time: 5.57, Learning Rate: 1.000e-03
# It: 580, Loss: 1.525e+03, Y0: 15.948, Time: 7.15, Learning Rate: 1.000e-03
# It: 590, Loss: 1.506e+03, Y0: 19.346, Time: 5.56, Learning Rate: 1.000e-03
# It: 600, Loss: 1.531e+03, Y0: 14.120, Time: 5.60, Learning Rate: 1.000e-03
# It: 610, Loss: 1.659e+03, Y0: 12.342, Time: 7.18, Learning Rate: 1.000e-03
# It: 620, Loss: 1.458e+03, Y0: 17.025, Time: 5.61, Learning Rate: 1.000e-03
# It: 630, Loss: 1.616e+03, Y0: 13.160, Time: 7.18, Learning Rate: 1.000e-03
# It: 640, Loss: 1.476e+03, Y0: 8.638, Time: 5.57, Learning Rate: 1.000e-03
# It: 650, Loss: 1.568e+03, Y0: 13.245, Time: 5.63, Learning Rate: 1.000e-03
# It: 660, Loss: 1.497e+03, Y0: 7.225, Time: 7.15, Learning Rate: 1.000e-03
# It: 670, Loss: 1.558e+03, Y0: 15.979, Time: 5.57, Learning Rate: 1.000e-03
# It: 680, Loss: 1.631e+03, Y0: 11.198, Time: 7.17, Learning Rate: 1.000e-03
# It: 690, Loss: 1.597e+03, Y0: 1.762, Time: 5.59, Learning Rate: 1.000e-03
# It: 700, Loss: 1.573e+03, Y0: 12.735, Time: 5.58, Learning Rate: 1.000e-03
# It: 710, Loss: 1.584e+03, Y0: 14.247, Time: 7.17, Learning Rate: 1.000e-03
# It: 720, Loss: 1.672e+03, Y0: 15.211, Time: 5.59, Learning Rate: 1.000e-03
# It: 730, Loss: 1.527e+03, Y0: 8.714, Time: 7.18, Learning Rate: 1.000e-03
# It: 740, Loss: 1.405e+03, Y0: 14.964, Time: 5.62, Learning Rate: 1.000e-03
# It: 750, Loss: 1.496e+03, Y0: 7.767, Time: 5.56, Learning Rate: 1.000e-03
# It: 760, Loss: 1.529e+03, Y0: 7.695, Time: 7.17, Learning Rate: 1.000e-03
# It: 770, Loss: 1.311e+03, Y0: 9.013, Time: 5.57, Learning Rate: 1.000e-03
# It: 780, Loss: 1.627e+03, Y0: 3.291, Time: 7.13, Learning Rate: 1.000e-03
# It: 790, Loss: 1.505e+03, Y0: 6.496, Time: 5.59, Learning Rate: 1.000e-03
# It: 800, Loss: 1.248e+03, Y0: 7.560, Time: 5.59, Learning Rate: 1.000e-03
# It: 810, Loss: 1.526e+03, Y0: 8.302, Time: 7.17, Learning Rate: 1.000e-03
# It: 820, Loss: 1.363e+03, Y0: 9.267, Time: 5.58, Learning Rate: 1.000e-03
# It: 830, Loss: 1.334e+03, Y0: 5.959, Time: 7.15, Learning Rate: 1.000e-03
# It: 840, Loss: 1.504e+03, Y0: 14.704, Time: 5.57, Learning Rate: 1.000e-03
# It: 850, Loss: 1.336e+03, Y0: 1.334, Time: 5.56, Learning Rate: 1.000e-03
# It: 860, Loss: 1.333e+03, Y0: 0.945, Time: 7.17, Learning Rate: 1.000e-03
# It: 870, Loss: 1.282e+03, Y0: 11.405, Time: 5.56, Learning Rate: 1.000e-03
# It: 880, Loss: 1.404e+03, Y0: -1.957, Time: 7.16, Learning Rate: 1.000e-03
# It: 890, Loss: 1.430e+03, Y0: 0.869, Time: 5.56, Learning Rate: 1.000e-03
# It: 900, Loss: 1.302e+03, Y0: 3.649, Time: 5.58, Learning Rate: 1.000e-03
# It: 910, Loss: 1.221e+03, Y0: 4.515, Time: 7.12, Learning Rate: 1.000e-03
# It: 920, Loss: 1.187e+03, Y0: 0.689, Time: 5.58, Learning Rate: 1.000e-03
# It: 930, Loss: 1.285e+03, Y0: 2.817, Time: 7.15, Learning Rate: 1.000e-03
# It: 940, Loss: 1.248e+03, Y0: -3.695, Time: 5.60, Learning Rate: 1.000e-03
# It: 950, Loss: 1.314e+03, Y0: -9.209, Time: 5.61, Learning Rate: 1.000e-03
# It: 960, Loss: 1.251e+03, Y0: -1.547, Time: 7.14, Learning Rate: 1.000e-03
# It: 970, Loss: 1.362e+03, Y0: 2.512, Time: 5.56, Learning Rate: 1.000e-03
# It: 980, Loss: 1.361e+03, Y0: 5.925, Time: 7.14, Learning Rate: 1.000e-03
# It: 990, Loss: 1.246e+03, Y0: 1.940, Time: 5.63, Learning Rate: 1.000e-03
# It: 1000, Loss: 1.456e+03, Y0: -7.389, Time: 5.58, Learning Rate: 1.000e-03
# It: 1010, Loss: 1.252e+03, Y0: 4.946, Time: 7.17, Learning Rate: 1.000e-03
# It: 1020, Loss: 1.222e+03, Y0: -1.295, Time: 5.58, Learning Rate: 1.000e-03
# It: 1030, Loss: 1.221e+03, Y0: -8.654, Time: 7.16, Learning Rate: 1.000e-03
# It: 1040, Loss: 1.254e+03, Y0: -0.772, Time: 5.59, Learning Rate: 1.000e-03
# It: 1050, Loss: 1.202e+03, Y0: 1.361, Time: 5.55, Learning Rate: 1.000e-03
# It: 1060, Loss: 1.161e+03, Y0: 4.879, Time: 7.12, Learning Rate: 1.000e-03
# It: 1070, Loss: 1.062e+03, Y0: -5.328, Time: 5.54, Learning Rate: 1.000e-03
# It: 1080, Loss: 1.267e+03, Y0: -1.007, Time: 7.16, Learning Rate: 1.000e-03
# It: 1090, Loss: 1.181e+03, Y0: -3.260, Time: 5.58, Learning Rate: 1.000e-03
# It: 1100, Loss: 1.225e+03, Y0: -6.496, Time: 5.53, Learning Rate: 1.000e-03
# It: 1110, Loss: 1.221e+03, Y0: 2.945, Time: 7.15, Learning Rate: 1.000e-03
# It: 1120, Loss: 1.231e+03, Y0: -3.243, Time: 5.56, Learning Rate: 1.000e-03
# It: 1130, Loss: 1.139e+03, Y0: -1.064, Time: 7.17, Learning Rate: 1.000e-03
# It: 1140, Loss: 1.196e+03, Y0: -6.571, Time: 5.60, Learning Rate: 1.000e-03
# It: 1150, Loss: 1.300e+03, Y0: 6.375, Time: 5.56, Learning Rate: 1.000e-03
# It: 1160, Loss: 1.297e+03, Y0: -6.957, Time: 7.15, Learning Rate: 1.000e-03
# It: 1170, Loss: 1.160e+03, Y0: -1.798, Time: 5.57, Learning Rate: 1.000e-03
# It: 1180, Loss: 1.134e+03, Y0: -7.329, Time: 7.19, Learning Rate: 1.000e-03
# It: 1190, Loss: 1.148e+03, Y0: -2.664, Time: 5.58, Learning Rate: 1.000e-03
# It: 1200, Loss: 1.102e+03, Y0: -3.960, Time: 5.62, Learning Rate: 1.000e-03
# It: 1210, Loss: 1.116e+03, Y0: -9.926, Time: 7.18, Learning Rate: 1.000e-03
# It: 1220, Loss: 1.066e+03, Y0: -2.033, Time: 5.59, Learning Rate: 1.000e-03
# It: 1230, Loss: 1.143e+03, Y0: -3.090, Time: 7.14, Learning Rate: 1.000e-03
# It: 1240, Loss: 1.106e+03, Y0: -4.997, Time: 5.60, Learning Rate: 1.000e-03
# It: 1250, Loss: 1.095e+03, Y0: -5.177, Time: 5.60, Learning Rate: 1.000e-03
# It: 1260, Loss: 1.215e+03, Y0: 3.260, Time: 7.18, Learning Rate: 1.000e-03
# It: 1270, Loss: 1.141e+03, Y0: -14.170, Time: 5.61, Learning Rate: 1.000e-03
# It: 1280, Loss: 1.112e+03, Y0: -8.983, Time: 7.15, Learning Rate: 1.000e-03
# It: 1290, Loss: 1.043e+03, Y0: -13.157, Time: 5.58, Learning Rate: 1.000e-03
# It: 1300, Loss: 1.091e+03, Y0: -7.081, Time: 5.57, Learning Rate: 1.000e-03
# It: 1310, Loss: 1.125e+03, Y0: -11.085, Time: 7.18, Learning Rate: 1.000e-03
# It: 1320, Loss: 1.159e+03, Y0: -10.903, Time: 5.60, Learning Rate: 1.000e-03
# It: 1330, Loss: 1.157e+03, Y0: -7.109, Time: 7.15, Learning Rate: 1.000e-03
# It: 1340, Loss: 1.056e+03, Y0: -10.470, Time: 5.58, Learning Rate: 1.000e-03
# It: 1350, Loss: 1.017e+03, Y0: -13.893, Time: 5.58, Learning Rate: 1.000e-03
# It: 1360, Loss: 1.170e+03, Y0: -7.453, Time: 7.18, Learning Rate: 1.000e-03
# It: 1370, Loss: 1.042e+03, Y0: -11.071, Time: 5.58, Learning Rate: 1.000e-03
# It: 1380, Loss: 1.033e+03, Y0: -8.779, Time: 7.19, Learning Rate: 1.000e-03
# It: 1390, Loss: 1.071e+03, Y0: -11.787, Time: 5.59, Learning Rate: 1.000e-03
# It: 1400, Loss: 1.214e+03, Y0: -16.527, Time: 5.58, Learning Rate: 1.000e-03
# It: 1410, Loss: 1.172e+03, Y0: -10.742, Time: 7.21, Learning Rate: 1.000e-03
# It: 1420, Loss: 1.016e+03, Y0: -10.888, Time: 5.62, Learning Rate: 1.000e-03
# It: 1430, Loss: 1.022e+03, Y0: -11.540, Time: 7.20, Learning Rate: 1.000e-03
# It: 1440, Loss: 9.727e+02, Y0: -11.241, Time: 5.59, Learning Rate: 1.000e-03
# It: 1450, Loss: 1.090e+03, Y0: -12.089, Time: 5.65, Learning Rate: 1.000e-03
# It: 1460, Loss: 1.192e+03, Y0: -5.354, Time: 7.17, Learning Rate: 1.000e-03
# It: 1470, Loss: 1.022e+03, Y0: -10.804, Time: 5.60, Learning Rate: 1.000e-03
# It: 1480, Loss: 1.031e+03, Y0: -12.627, Time: 7.20, Learning Rate: 1.000e-03
# It: 1490, Loss: 1.271e+03, Y0: -14.543, Time: 5.60, Learning Rate: 1.000e-03
# It: 1500, Loss: 1.047e+03, Y0: -14.823, Time: 5.62, Learning Rate: 1.000e-03
# It: 1510, Loss: 1.131e+03, Y0: -12.275, Time: 7.14, Learning Rate: 1.000e-03
# It: 1520, Loss: 9.359e+02, Y0: -13.805, Time: 5.61, Learning Rate: 1.000e-03
# It: 1530, Loss: 1.138e+03, Y0: -12.746, Time: 7.15, Learning Rate: 1.000e-03
# It: 1540, Loss: 1.048e+03, Y0: -14.603, Time: 5.63, Learning Rate: 1.000e-03
# It: 1550, Loss: 1.130e+03, Y0: -13.911, Time: 5.59, Learning Rate: 1.000e-03
# It: 1560, Loss: 8.933e+02, Y0: -14.500, Time: 7.18, Learning Rate: 1.000e-03
# It: 1570, Loss: 1.024e+03, Y0: -9.701, Time: 5.64, Learning Rate: 1.000e-03
# It: 1580, Loss: 1.024e+03, Y0: -21.655, Time: 7.14, Learning Rate: 1.000e-03
# It: 1590, Loss: 9.118e+02, Y0: -18.605, Time: 5.64, Learning Rate: 1.000e-03
# It: 1600, Loss: 9.218e+02, Y0: -19.201, Time: 5.57, Learning Rate: 1.000e-03
# It: 1610, Loss: 9.680e+02, Y0: -16.113, Time: 7.19, Learning Rate: 1.000e-03
# It: 1620, Loss: 9.294e+02, Y0: -14.982, Time: 5.57, Learning Rate: 1.000e-03
# It: 1630, Loss: 1.014e+03, Y0: -19.840, Time: 7.18, Learning Rate: 1.000e-03
# It: 1640, Loss: 9.153e+02, Y0: -14.415, Time: 5.60, Learning Rate: 1.000e-03
# It: 1650, Loss: 9.158e+02, Y0: -20.171, Time: 5.63, Learning Rate: 1.000e-03
# It: 1660, Loss: 9.748e+02, Y0: -16.598, Time: 7.19, Learning Rate: 1.000e-03
# It: 1670, Loss: 1.176e+03, Y0: -19.054, Time: 5.57, Learning Rate: 1.000e-03
# It: 1680, Loss: 8.257e+02, Y0: -13.979, Time: 7.17, Learning Rate: 1.000e-03
# It: 1690, Loss: 1.024e+03, Y0: -20.992, Time: 5.59, Learning Rate: 1.000e-03
# It: 1700, Loss: 9.643e+02, Y0: -18.326, Time: 5.63, Learning Rate: 1.000e-03
# It: 1710, Loss: 1.013e+03, Y0: -21.749, Time: 7.17, Learning Rate: 1.000e-03
# It: 1720, Loss: 1.065e+03, Y0: -10.950, Time: 5.56, Learning Rate: 1.000e-03
# It: 1730, Loss: 1.030e+03, Y0: -16.990, Time: 7.16, Learning Rate: 1.000e-03
# It: 1740, Loss: 9.408e+02, Y0: -14.877, Time: 5.57, Learning Rate: 1.000e-03
# It: 1750, Loss: 8.893e+02, Y0: -22.015, Time: 5.57, Learning Rate: 1.000e-03
# It: 1760, Loss: 9.355e+02, Y0: -15.875, Time: 7.17, Learning Rate: 1.000e-03
# It: 1770, Loss: 9.678e+02, Y0: -15.144, Time: 5.56, Learning Rate: 1.000e-03
# It: 1780, Loss: 8.189e+02, Y0: -22.086, Time: 7.15, Learning Rate: 1.000e-03
# It: 1790, Loss: 9.372e+02, Y0: -15.695, Time: 5.58, Learning Rate: 1.000e-03
# It: 1800, Loss: 8.423e+02, Y0: -24.269, Time: 5.60, Learning Rate: 1.000e-03
# It: 1810, Loss: 9.665e+02, Y0: -13.977, Time: 7.16, Learning Rate: 1.000e-03
# It: 1820, Loss: 7.150e+02, Y0: -19.806, Time: 5.57, Learning Rate: 1.000e-03
# It: 1830, Loss: 9.721e+02, Y0: -28.045, Time: 7.13, Learning Rate: 1.000e-03
# It: 1840, Loss: 9.163e+02, Y0: -20.328, Time: 5.56, Learning Rate: 1.000e-03
# It: 1850, Loss: 8.992e+02, Y0: -21.019, Time: 5.57, Learning Rate: 1.000e-03
# It: 1860, Loss: 9.416e+02, Y0: -17.898, Time: 7.19, Learning Rate: 1.000e-03
# It: 1870, Loss: 8.452e+02, Y0: -18.395, Time: 5.59, Learning Rate: 1.000e-03
# It: 1880, Loss: 9.276e+02, Y0: -19.342, Time: 7.18, Learning Rate: 1.000e-03
# It: 1890, Loss: 9.489e+02, Y0: -22.621, Time: 5.61, Learning Rate: 1.000e-03
# It: 1900, Loss: 9.054e+02, Y0: -20.736, Time: 5.63, Learning Rate: 1.000e-03
# It: 1910, Loss: 8.723e+02, Y0: -18.598, Time: 7.21, Learning Rate: 1.000e-03
# It: 1920, Loss: 8.985e+02, Y0: -22.029, Time: 5.58, Learning Rate: 1.000e-03
# It: 1930, Loss: 9.698e+02, Y0: -22.833, Time: 7.17, Learning Rate: 1.000e-03
# It: 1940, Loss: 8.386e+02, Y0: -27.684, Time: 5.58, Learning Rate: 1.000e-03
# It: 1950, Loss: 9.582e+02, Y0: -18.075, Time: 5.57, Learning Rate: 1.000e-03
# It: 1960, Loss: 8.791e+02, Y0: -24.461, Time: 7.18, Learning Rate: 1.000e-03
# It: 1970, Loss: 9.196e+02, Y0: -21.304, Time: 5.62, Learning Rate: 1.000e-03
# It: 1980, Loss: 8.763e+02, Y0: -20.750, Time: 7.16, Learning Rate: 1.000e-03
# It: 1990, Loss: 8.825e+02, Y0: -24.243, Time: 5.60, Learning Rate: 1.000e-03
# It: 2000, Loss: 8.397e+02, Y0: -30.514, Time: 5.59, Learning Rate: 1.000e-03
# It: 2010, Loss: 1.122e+03, Y0: -29.597, Time: 7.15, Learning Rate: 1.000e-03
# It: 2020, Loss: 8.470e+02, Y0: -20.878, Time: 5.63, Learning Rate: 1.000e-03
# It: 2030, Loss: 7.919e+02, Y0: -24.081, Time: 7.16, Learning Rate: 1.000e-03
# It: 2040, Loss: 7.789e+02, Y0: -21.245, Time: 5.57, Learning Rate: 1.000e-03
# It: 2050, Loss: 7.682e+02, Y0: -28.953, Time: 5.62, Learning Rate: 1.000e-03
# It: 2060, Loss: 7.842e+02, Y0: -26.835, Time: 7.17, Learning Rate: 1.000e-03
# It: 2070, Loss: 8.281e+02, Y0: -26.134, Time: 5.58, Learning Rate: 1.000e-03
# It: 2080, Loss: 9.209e+02, Y0: -27.691, Time: 7.14, Learning Rate: 1.000e-03
# It: 2090, Loss: 8.338e+02, Y0: -21.141, Time: 5.59, Learning Rate: 1.000e-03
# It: 2100, Loss: 7.644e+02, Y0: -29.539, Time: 5.56, Learning Rate: 1.000e-03
# It: 2110, Loss: 7.898e+02, Y0: -20.290, Time: 7.17, Learning Rate: 1.000e-03
# It: 2120, Loss: 6.944e+02, Y0: -29.061, Time: 5.60, Learning Rate: 1.000e-03
# It: 2130, Loss: 7.333e+02, Y0: -25.178, Time: 7.14, Learning Rate: 1.000e-03
# It: 2140, Loss: 7.814e+02, Y0: -29.213, Time: 5.63, Learning Rate: 1.000e-03
# It: 2150, Loss: 8.279e+02, Y0: -27.739, Time: 5.62, Learning Rate: 1.000e-03
# It: 2160, Loss: 7.051e+02, Y0: -27.934, Time: 7.19, Learning Rate: 1.000e-03
# It: 2170, Loss: 8.402e+02, Y0: -21.496, Time: 5.55, Learning Rate: 1.000e-03
# It: 2180, Loss: 8.343e+02, Y0: -25.284, Time: 7.17, Learning Rate: 1.000e-03
# It: 2190, Loss: 7.633e+02, Y0: -27.858, Time: 5.57, Learning Rate: 1.000e-03
# It: 2200, Loss: 7.630e+02, Y0: -29.389, Time: 5.56, Learning Rate: 1.000e-03
# It: 2210, Loss: 7.124e+02, Y0: -27.065, Time: 7.16, Learning Rate: 1.000e-03
# It: 2220, Loss: 7.207e+02, Y0: -33.766, Time: 5.57, Learning Rate: 1.000e-03
# It: 2230, Loss: 8.833e+02, Y0: -31.137, Time: 7.22, Learning Rate: 1.000e-03
# It: 2240, Loss: 8.340e+02, Y0: -22.465, Time: 5.58, Learning Rate: 1.000e-03
# It: 2250, Loss: 8.135e+02, Y0: -27.868, Time: 5.64, Learning Rate: 1.000e-03
# It: 2260, Loss: 8.662e+02, Y0: -25.680, Time: 7.17, Learning Rate: 1.000e-03
# It: 2270, Loss: 7.510e+02, Y0: -25.371, Time: 5.61, Learning Rate: 1.000e-03
# It: 2280, Loss: 8.277e+02, Y0: -31.867, Time: 7.19, Learning Rate: 1.000e-03
# It: 2290, Loss: 7.333e+02, Y0: -38.087, Time: 5.56, Learning Rate: 1.000e-03
# It: 2300, Loss: 7.185e+02, Y0: -31.718, Time: 5.58, Learning Rate: 1.000e-03
# It: 2310, Loss: 8.212e+02, Y0: -29.182, Time: 7.14, Learning Rate: 1.000e-03
# It: 2320, Loss: 8.576e+02, Y0: -33.568, Time: 5.64, Learning Rate: 1.000e-03
# It: 2330, Loss: 7.714e+02, Y0: -27.739, Time: 7.21, Learning Rate: 1.000e-03
# It: 2340, Loss: 8.312e+02, Y0: -27.420, Time: 5.59, Learning Rate: 1.000e-03
# It: 2350, Loss: 7.921e+02, Y0: -29.628, Time: 5.63, Learning Rate: 1.000e-03
# It: 2360, Loss: 6.988e+02, Y0: -30.736, Time: 7.19, Learning Rate: 1.000e-03
# It: 2370, Loss: 7.322e+02, Y0: -30.263, Time: 5.63, Learning Rate: 1.000e-03
# It: 2380, Loss: 7.769e+02, Y0: -25.674, Time: 7.19, Learning Rate: 1.000e-03
# It: 2390, Loss: 7.935e+02, Y0: -29.382, Time: 5.65, Learning Rate: 1.000e-03
# It: 2400, Loss: 6.532e+02, Y0: -31.330, Time: 5.61, Learning Rate: 1.000e-03
# It: 2410, Loss: 8.201e+02, Y0: -33.590, Time: 7.23, Learning Rate: 1.000e-03
# It: 2420, Loss: 7.058e+02, Y0: -25.766, Time: 5.63, Learning Rate: 1.000e-03
# It: 2430, Loss: 6.351e+02, Y0: -31.493, Time: 7.16, Learning Rate: 1.000e-03
# It: 2440, Loss: 7.172e+02, Y0: -28.751, Time: 5.64, Learning Rate: 1.000e-03
# It: 2450, Loss: 8.147e+02, Y0: -27.184, Time: 5.57, Learning Rate: 1.000e-03
# It: 2460, Loss: 6.251e+02, Y0: -34.806, Time: 7.21, Learning Rate: 1.000e-03
# It: 2470, Loss: 8.040e+02, Y0: -32.518, Time: 5.60, Learning Rate: 1.000e-03
# It: 2480, Loss: 7.739e+02, Y0: -23.799, Time: 7.18, Learning Rate: 1.000e-03
# It: 2490, Loss: 8.519e+02, Y0: -32.843, Time: 5.60, Learning Rate: 1.000e-03
# It: 2500, Loss: 6.934e+02, Y0: -32.088, Time: 5.58, Learning Rate: 1.000e-03
# It: 2510, Loss: 7.779e+02, Y0: -26.157, Time: 7.15, Learning Rate: 1.000e-03
# It: 2520, Loss: 8.756e+02, Y0: -33.003, Time: 5.55, Learning Rate: 1.000e-03
# It: 2530, Loss: 6.976e+02, Y0: -32.063, Time: 7.16, Learning Rate: 1.000e-03
# It: 2540, Loss: 7.591e+02, Y0: -31.529, Time: 5.55, Learning Rate: 1.000e-03
# It: 2550, Loss: 8.124e+02, Y0: -37.790, Time: 5.61, Learning Rate: 1.000e-03
# It: 2560, Loss: 6.771e+02, Y0: -31.073, Time: 7.14, Learning Rate: 1.000e-03
# It: 2570, Loss: 6.697e+02, Y0: -31.007, Time: 5.57, Learning Rate: 1.000e-03
# It: 2580, Loss: 8.833e+02, Y0: -32.711, Time: 7.15, Learning Rate: 1.000e-03
# It: 2590, Loss: 6.816e+02, Y0: -34.995, Time: 5.57, Learning Rate: 1.000e-03
# It: 2600, Loss: 7.952e+02, Y0: -38.399, Time: 5.58, Learning Rate: 1.000e-03
# It: 2610, Loss: 7.021e+02, Y0: -34.731, Time: 7.17, Learning Rate: 1.000e-03
# It: 2620, Loss: 5.908e+02, Y0: -39.186, Time: 5.62, Learning Rate: 1.000e-03
# It: 2630, Loss: 8.591e+02, Y0: -39.696, Time: 7.19, Learning Rate: 1.000e-03
# It: 2640, Loss: 7.455e+02, Y0: -30.107, Time: 5.56, Learning Rate: 1.000e-03
# It: 2650, Loss: 6.714e+02, Y0: -33.888, Time: 5.58, Learning Rate: 1.000e-03
# It: 2660, Loss: 8.562e+02, Y0: -34.161, Time: 7.20, Learning Rate: 1.000e-03
# It: 2670, Loss: 6.230e+02, Y0: -40.686, Time: 5.61, Learning Rate: 1.000e-03
# It: 2680, Loss: 8.177e+02, Y0: -30.898, Time: 7.17, Learning Rate: 1.000e-03
# It: 2690, Loss: 6.774e+02, Y0: -34.055, Time: 5.57, Learning Rate: 1.000e-03
# It: 2700, Loss: 7.946e+02, Y0: -44.075, Time: 5.54, Learning Rate: 1.000e-03
# It: 2710, Loss: 6.915e+02, Y0: -32.546, Time: 7.14, Learning Rate: 1.000e-03
# It: 2720, Loss: 6.509e+02, Y0: -29.362, Time: 5.58, Learning Rate: 1.000e-03
# It: 2730, Loss: 6.925e+02, Y0: -34.081, Time: 7.13, Learning Rate: 1.000e-03
# It: 2740, Loss: 6.704e+02, Y0: -44.611, Time: 5.63, Learning Rate: 1.000e-03
# It: 2750, Loss: 6.868e+02, Y0: -28.289, Time: 5.62, Learning Rate: 1.000e-03
# It: 2760, Loss: 7.511e+02, Y0: -38.582, Time: 7.18, Learning Rate: 1.000e-03
# It: 2770, Loss: 6.222e+02, Y0: -44.117, Time: 5.56, Learning Rate: 1.000e-03
# It: 2780, Loss: 5.911e+02, Y0: -36.048, Time: 7.16, Learning Rate: 1.000e-03
# It: 2790, Loss: 6.739e+02, Y0: -39.241, Time: 5.56, Learning Rate: 1.000e-03
# It: 2800, Loss: 6.302e+02, Y0: -32.824, Time: 5.56, Learning Rate: 1.000e-03
# It: 2810, Loss: 6.386e+02, Y0: -43.300, Time: 7.14, Learning Rate: 1.000e-03
# It: 2820, Loss: 6.278e+02, Y0: -37.461, Time: 5.59, Learning Rate: 1.000e-03
# It: 2830, Loss: 9.135e+02, Y0: -32.480, Time: 7.16, Learning Rate: 1.000e-03
# It: 2840, Loss: 8.266e+02, Y0: -39.017, Time: 5.55, Learning Rate: 1.000e-03
# It: 2850, Loss: 6.917e+02, Y0: -37.032, Time: 5.55, Learning Rate: 1.000e-03
# It: 2860, Loss: 5.631e+02, Y0: -42.983, Time: 7.16, Learning Rate: 1.000e-03
# It: 2870, Loss: 6.472e+02, Y0: -41.418, Time: 5.58, Learning Rate: 1.000e-03
# It: 2880, Loss: 6.991e+02, Y0: -31.265, Time: 7.17, Learning Rate: 1.000e-03
# It: 2890, Loss: 6.539e+02, Y0: -37.506, Time: 5.58, Learning Rate: 1.000e-03
# It: 2900, Loss: 6.531e+02, Y0: -45.718, Time: 5.61, Learning Rate: 1.000e-03
# It: 2910, Loss: 6.164e+02, Y0: -35.312, Time: 7.13, Learning Rate: 1.000e-03
# It: 2920, Loss: 6.295e+02, Y0: -41.685, Time: 5.61, Learning Rate: 1.000e-03
# It: 2930, Loss: 7.157e+02, Y0: -37.212, Time: 7.13, Learning Rate: 1.000e-03
# It: 2940, Loss: 6.655e+02, Y0: -34.278, Time: 5.61, Learning Rate: 1.000e-03
# It: 2950, Loss: 6.363e+02, Y0: -36.608, Time: 5.56, Learning Rate: 1.000e-03
# It: 2960, Loss: 6.804e+02, Y0: -40.119, Time: 7.18, Learning Rate: 1.000e-03
# It: 2970, Loss: 5.838e+02, Y0: -37.196, Time: 5.59, Learning Rate: 1.000e-03
# It: 2980, Loss: 5.759e+02, Y0: -40.728, Time: 7.17, Learning Rate: 1.000e-03
# It: 2990, Loss: 5.593e+02, Y0: -40.590, Time: 5.60, Learning Rate: 1.000e-03
# It: 3000, Loss: 7.373e+02, Y0: -40.959, Time: 5.58, Learning Rate: 1.000e-03
# It: 3010, Loss: 6.124e+02, Y0: -34.796, Time: 7.19, Learning Rate: 1.000e-03
# It: 3020, Loss: 5.790e+02, Y0: -39.990, Time: 5.60, Learning Rate: 1.000e-03
# It: 3030, Loss: 6.462e+02, Y0: -44.028, Time: 7.21, Learning Rate: 1.000e-03
# It: 3040, Loss: 5.528e+02, Y0: -44.080, Time: 5.60, Learning Rate: 1.000e-03
# It: 3050, Loss: 6.128e+02, Y0: -40.671, Time: 5.58, Learning Rate: 1.000e-03
# It: 3060, Loss: 6.291e+02, Y0: -42.283, Time: 7.17, Learning Rate: 1.000e-03
# It: 3070, Loss: 5.969e+02, Y0: -47.841, Time: 5.58, Learning Rate: 1.000e-03
# It: 3080, Loss: 7.146e+02, Y0: -42.264, Time: 7.17, Learning Rate: 1.000e-03
# It: 3090, Loss: 6.540e+02, Y0: -43.176, Time: 5.58, Learning Rate: 1.000e-03
# It: 3100, Loss: 6.903e+02, Y0: -42.387, Time: 5.60, Learning Rate: 1.000e-03
# It: 3110, Loss: 6.585e+02, Y0: -39.960, Time: 7.22, Learning Rate: 1.000e-03
# It: 3120, Loss: 6.081e+02, Y0: -52.351, Time: 5.58, Learning Rate: 1.000e-03
# It: 3130, Loss: 6.595e+02, Y0: -41.050, Time: 7.20, Learning Rate: 1.000e-03
# It: 3140, Loss: 5.327e+02, Y0: -41.022, Time: 5.58, Learning Rate: 1.000e-03
# It: 3150, Loss: 6.044e+02, Y0: -49.414, Time: 5.58, Learning Rate: 1.000e-03
# It: 3160, Loss: 6.171e+02, Y0: -43.693, Time: 7.15, Learning Rate: 1.000e-03
# It: 3170, Loss: 5.674e+02, Y0: -42.033, Time: 5.55, Learning Rate: 1.000e-03
# It: 3180, Loss: 7.931e+02, Y0: -41.206, Time: 7.15, Learning Rate: 1.000e-03
# It: 3190, Loss: 6.102e+02, Y0: -48.433, Time: 5.58, Learning Rate: 1.000e-03
# It: 3200, Loss: 6.344e+02, Y0: -43.127, Time: 5.55, Learning Rate: 1.000e-03
# It: 3210, Loss: 5.520e+02, Y0: -42.049, Time: 7.17, Learning Rate: 1.000e-03
# It: 3220, Loss: 5.794e+02, Y0: -39.062, Time: 5.63, Learning Rate: 1.000e-03
# It: 3230, Loss: 5.333e+02, Y0: -41.247, Time: 7.14, Learning Rate: 1.000e-03
# It: 3240, Loss: 6.609e+02, Y0: -44.879, Time: 5.60, Learning Rate: 1.000e-03
# It: 3250, Loss: 6.208e+02, Y0: -41.262, Time: 5.56, Learning Rate: 1.000e-03
# It: 3260, Loss: 6.446e+02, Y0: -38.836, Time: 7.12, Learning Rate: 1.000e-03
# It: 3270, Loss: 6.615e+02, Y0: -40.122, Time: 5.56, Learning Rate: 1.000e-03
# It: 3280, Loss: 5.666e+02, Y0: -48.291, Time: 7.19, Learning Rate: 1.000e-03
# It: 3290, Loss: 5.709e+02, Y0: -43.107, Time: 5.56, Learning Rate: 1.000e-03
# It: 3300, Loss: 6.732e+02, Y0: -48.947, Time: 5.60, Learning Rate: 1.000e-03
# It: 3310, Loss: 7.013e+02, Y0: -42.322, Time: 7.12, Learning Rate: 1.000e-03
# It: 3320, Loss: 5.485e+02, Y0: -42.130, Time: 5.54, Learning Rate: 1.000e-03
# It: 3330, Loss: 5.380e+02, Y0: -47.234, Time: 7.15, Learning Rate: 1.000e-03
# It: 3340, Loss: 5.632e+02, Y0: -48.190, Time: 5.56, Learning Rate: 1.000e-03
# It: 3350, Loss: 6.203e+02, Y0: -42.638, Time: 5.57, Learning Rate: 1.000e-03
# It: 3360, Loss: 5.226e+02, Y0: -41.965, Time: 7.13, Learning Rate: 1.000e-03
# It: 3370, Loss: 5.642e+02, Y0: -44.630, Time: 5.60, Learning Rate: 1.000e-03
# It: 3380, Loss: 5.825e+02, Y0: -43.337, Time: 7.15, Learning Rate: 1.000e-03
# It: 3390, Loss: 5.748e+02, Y0: -50.064, Time: 5.58, Learning Rate: 1.000e-03
# It: 3400, Loss: 6.031e+02, Y0: -40.922, Time: 5.60, Learning Rate: 1.000e-03
# It: 3410, Loss: 6.253e+02, Y0: -45.080, Time: 7.15, Learning Rate: 1.000e-03
# It: 3420, Loss: 5.557e+02, Y0: -40.547, Time: 5.59, Learning Rate: 1.000e-03
# It: 3430, Loss: 5.324e+02, Y0: -37.674, Time: 7.13, Learning Rate: 1.000e-03
# It: 3440, Loss: 5.765e+02, Y0: -45.361, Time: 5.55, Learning Rate: 1.000e-03
# It: 3450, Loss: 7.111e+02, Y0: -44.730, Time: 5.57, Learning Rate: 1.000e-03
# It: 3460, Loss: 6.077e+02, Y0: -43.775, Time: 7.15, Learning Rate: 1.000e-03
# It: 3470, Loss: 6.285e+02, Y0: -47.167, Time: 5.61, Learning Rate: 1.000e-03
# It: 3480, Loss: 5.292e+02, Y0: -42.601, Time: 7.11, Learning Rate: 1.000e-03
# It: 3490, Loss: 6.119e+02, Y0: -43.456, Time: 5.61, Learning Rate: 1.000e-03
# It: 3500, Loss: 5.711e+02, Y0: -48.610, Time: 5.58, Learning Rate: 1.000e-03
# It: 3510, Loss: 5.490e+02, Y0: -40.753, Time: 7.15, Learning Rate: 1.000e-03
# It: 3520, Loss: 5.864e+02, Y0: -45.459, Time: 5.57, Learning Rate: 1.000e-03
# It: 3530, Loss: 5.464e+02, Y0: -51.316, Time: 7.13, Learning Rate: 1.000e-03
# It: 3540, Loss: 6.224e+02, Y0: -46.077, Time: 5.61, Learning Rate: 1.000e-03
# It: 3550, Loss: 5.458e+02, Y0: -50.894, Time: 5.60, Learning Rate: 1.000e-03
# It: 3560, Loss: 6.952e+02, Y0: -45.120, Time: 7.18, Learning Rate: 1.000e-03
# It: 3570, Loss: 6.241e+02, Y0: -44.611, Time: 5.60, Learning Rate: 1.000e-03
# It: 3580, Loss: 5.887e+02, Y0: -43.438, Time: 7.11, Learning Rate: 1.000e-03
# It: 3590, Loss: 5.389e+02, Y0: -51.419, Time: 5.57, Learning Rate: 1.000e-03
# It: 3600, Loss: 5.366e+02, Y0: -45.224, Time: 5.54, Learning Rate: 1.000e-03
# It: 3610, Loss: 6.642e+02, Y0: -36.062, Time: 7.13, Learning Rate: 1.000e-03
# It: 3620, Loss: 4.997e+02, Y0: -54.792, Time: 5.55, Learning Rate: 1.000e-03
# It: 3630, Loss: 5.817e+02, Y0: -50.151, Time: 7.14, Learning Rate: 1.000e-03
# It: 3640, Loss: 5.468e+02, Y0: -45.369, Time: 5.57, Learning Rate: 1.000e-03
# It: 3650, Loss: 7.850e+02, Y0: -44.537, Time: 5.56, Learning Rate: 1.000e-03
# It: 3660, Loss: 6.086e+02, Y0: -46.949, Time: 7.12, Learning Rate: 1.000e-03
# It: 3670, Loss: 5.588e+02, Y0: -48.115, Time: 5.60, Learning Rate: 1.000e-03
# It: 3680, Loss: 5.483e+02, Y0: -51.343, Time: 7.17, Learning Rate: 1.000e-03
# It: 3690, Loss: 5.338e+02, Y0: -50.359, Time: 5.59, Learning Rate: 1.000e-03
# It: 3700, Loss: 5.694e+02, Y0: -45.979, Time: 5.55, Learning Rate: 1.000e-03
# It: 3710, Loss: 5.171e+02, Y0: -51.261, Time: 7.13, Learning Rate: 1.000e-03
# It: 3720, Loss: 6.017e+02, Y0: -50.135, Time: 5.56, Learning Rate: 1.000e-03
# It: 3730, Loss: 5.790e+02, Y0: -46.452, Time: 7.13, Learning Rate: 1.000e-03
# It: 3740, Loss: 4.630e+02, Y0: -54.548, Time: 5.58, Learning Rate: 1.000e-03
# It: 3750, Loss: 4.908e+02, Y0: -51.500, Time: 5.57, Learning Rate: 1.000e-03
# It: 3760, Loss: 4.890e+02, Y0: -46.835, Time: 7.16, Learning Rate: 1.000e-03
# It: 3770, Loss: 4.872e+02, Y0: -48.139, Time: 5.59, Learning Rate: 1.000e-03
# It: 3780, Loss: 4.897e+02, Y0: -51.389, Time: 7.17, Learning Rate: 1.000e-03
# It: 3790, Loss: 5.490e+02, Y0: -46.372, Time: 5.59, Learning Rate: 1.000e-03
# It: 3800, Loss: 4.900e+02, Y0: -45.271, Time: 5.58, Learning Rate: 1.000e-03
# It: 3810, Loss: 5.764e+02, Y0: -49.339, Time: 7.20, Learning Rate: 1.000e-03
# It: 3820, Loss: 5.319e+02, Y0: -48.515, Time: 5.59, Learning Rate: 1.000e-03
# It: 3830, Loss: 6.202e+02, Y0: -48.978, Time: 7.19, Learning Rate: 1.000e-03
# It: 3840, Loss: 5.363e+02, Y0: -53.867, Time: 5.56, Learning Rate: 1.000e-03
# It: 3850, Loss: 5.235e+02, Y0: -52.434, Time: 5.59, Learning Rate: 1.000e-03
# It: 3860, Loss: 6.385e+02, Y0: -47.887, Time: 7.13, Learning Rate: 1.000e-03
# It: 3870, Loss: 5.037e+02, Y0: -53.812, Time: 5.60, Learning Rate: 1.000e-03
# It: 3880, Loss: 6.723e+02, Y0: -67.838, Time: 7.14, Learning Rate: 1.000e-03
# It: 3890, Loss: 5.594e+02, Y0: -47.272, Time: 5.56, Learning Rate: 1.000e-03
# It: 3900, Loss: 5.922e+02, Y0: -55.768, Time: 5.60, Learning Rate: 1.000e-03
# It: 3910, Loss: 5.943e+02, Y0: -52.694, Time: 7.14, Learning Rate: 1.000e-03
# It: 3920, Loss: 5.387e+02, Y0: -52.805, Time: 5.61, Learning Rate: 1.000e-03
# It: 3930, Loss: 5.464e+02, Y0: -39.453, Time: 7.20, Learning Rate: 1.000e-03
# It: 3940, Loss: 5.861e+02, Y0: -47.292, Time: 5.59, Learning Rate: 1.000e-03
# It: 3950, Loss: 5.486e+02, Y0: -53.447, Time: 5.61, Learning Rate: 1.000e-03
# It: 3960, Loss: 6.627e+02, Y0: -52.695, Time: 7.14, Learning Rate: 1.000e-03
# It: 3970, Loss: 5.356e+02, Y0: -52.610, Time: 5.61, Learning Rate: 1.000e-03
# It: 3980, Loss: 4.525e+02, Y0: -49.952, Time: 7.16, Learning Rate: 1.000e-03
# It: 3990, Loss: 4.359e+02, Y0: -47.960, Time: 5.58, Learning Rate: 1.000e-03
# It: 4000, Loss: 5.466e+02, Y0: -51.031, Time: 5.54, Learning Rate: 1.000e-03
# It: 4010, Loss: 6.033e+02, Y0: -57.412, Time: 7.17, Learning Rate: 1.000e-03
# It: 4020, Loss: 6.460e+02, Y0: -52.518, Time: 5.58, Learning Rate: 1.000e-03
# It: 4030, Loss: 5.322e+02, Y0: -51.577, Time: 7.15, Learning Rate: 1.000e-03
# It: 4040, Loss: 4.695e+02, Y0: -58.893, Time: 5.64, Learning Rate: 1.000e-03
# It: 4050, Loss: 5.647e+02, Y0: -44.964, Time: 5.58, Learning Rate: 1.000e-03
# It: 4060, Loss: 4.930e+02, Y0: -50.557, Time: 7.15, Learning Rate: 1.000e-03
# It: 4070, Loss: 4.774e+02, Y0: -60.603, Time: 5.56, Learning Rate: 1.000e-03
# It: 4080, Loss: 5.485e+02, Y0: -48.230, Time: 7.15, Learning Rate: 1.000e-03
# It: 4090, Loss: 5.942e+02, Y0: -55.110, Time: 5.57, Learning Rate: 1.000e-03
# It: 4100, Loss: 4.598e+02, Y0: -53.192, Time: 5.57, Learning Rate: 1.000e-03
# It: 4110, Loss: 5.752e+02, Y0: -52.120, Time: 7.12, Learning Rate: 1.000e-03
# It: 4120, Loss: 5.548e+02, Y0: -59.756, Time: 5.56, Learning Rate: 1.000e-03
# It: 4130, Loss: 5.545e+02, Y0: -58.463, Time: 7.17, Learning Rate: 1.000e-03
# It: 4140, Loss: 6.035e+02, Y0: -58.218, Time: 5.54, Learning Rate: 1.000e-03
# It: 4150, Loss: 4.666e+02, Y0: -50.282, Time: 5.56, Learning Rate: 1.000e-03
# It: 4160, Loss: 4.562e+02, Y0: -51.916, Time: 7.14, Learning Rate: 1.000e-03
# It: 4170, Loss: 5.849e+02, Y0: -54.357, Time: 5.54, Learning Rate: 1.000e-03
# It: 4180, Loss: 5.743e+02, Y0: -53.714, Time: 7.15, Learning Rate: 1.000e-03
# It: 4190, Loss: 5.828e+02, Y0: -54.841, Time: 5.54, Learning Rate: 1.000e-03
# It: 4200, Loss: 4.809e+02, Y0: -58.011, Time: 5.55, Learning Rate: 1.000e-03
# It: 4210, Loss: 5.488e+02, Y0: -57.239, Time: 7.14, Learning Rate: 1.000e-03
# It: 4220, Loss: 4.633e+02, Y0: -52.022, Time: 5.63, Learning Rate: 1.000e-03
# It: 4230, Loss: 5.377e+02, Y0: -57.769, Time: 7.13, Learning Rate: 1.000e-03
# It: 4240, Loss: 5.117e+02, Y0: -51.760, Time: 5.55, Learning Rate: 1.000e-03
# It: 4250, Loss: 4.731e+02, Y0: -51.395, Time: 5.56, Learning Rate: 1.000e-03
# It: 4260, Loss: 5.894e+02, Y0: -52.275, Time: 7.16, Learning Rate: 1.000e-03
# It: 4270, Loss: 4.918e+02, Y0: -52.149, Time: 5.61, Learning Rate: 1.000e-03
# It: 4280, Loss: 6.306e+02, Y0: -58.393, Time: 7.11, Learning Rate: 1.000e-03
# It: 4290, Loss: 6.889e+02, Y0: -55.476, Time: 5.59, Learning Rate: 1.000e-03
# It: 4300, Loss: 5.502e+02, Y0: -49.825, Time: 5.53, Learning Rate: 1.000e-03
# It: 4310, Loss: 5.056e+02, Y0: -53.935, Time: 7.13, Learning Rate: 1.000e-03
# It: 4320, Loss: 5.074e+02, Y0: -46.589, Time: 5.54, Learning Rate: 1.000e-03
# It: 4330, Loss: 5.149e+02, Y0: -52.276, Time: 7.13, Learning Rate: 1.000e-03
# It: 4340, Loss: 5.038e+02, Y0: -55.968, Time: 5.59, Learning Rate: 1.000e-03
# It: 4350, Loss: 4.824e+02, Y0: -56.620, Time: 5.54, Learning Rate: 1.000e-03
# It: 4360, Loss: 5.108e+02, Y0: -59.916, Time: 7.16, Learning Rate: 1.000e-03
# It: 4370, Loss: 5.271e+02, Y0: -57.072, Time: 5.58, Learning Rate: 1.000e-03
# It: 4380, Loss: 4.882e+02, Y0: -54.168, Time: 7.15, Learning Rate: 1.000e-03
# It: 4390, Loss: 6.843e+02, Y0: -54.622, Time: 5.54, Learning Rate: 1.000e-03
# It: 4400, Loss: 4.947e+02, Y0: -59.956, Time: 5.58, Learning Rate: 1.000e-03
# It: 4410, Loss: 5.059e+02, Y0: -59.203, Time: 7.12, Learning Rate: 1.000e-03
# It: 4420, Loss: 5.142e+02, Y0: -54.048, Time: 5.57, Learning Rate: 1.000e-03
# It: 4430, Loss: 5.908e+02, Y0: -62.561, Time: 7.14, Learning Rate: 1.000e-03
# It: 4440, Loss: 5.687e+02, Y0: -48.257, Time: 5.55, Learning Rate: 1.000e-03
# It: 4450, Loss: 6.438e+02, Y0: -57.069, Time: 5.55, Learning Rate: 1.000e-03
# It: 4460, Loss: 5.052e+02, Y0: -55.613, Time: 7.14, Learning Rate: 1.000e-03
# It: 4470, Loss: 4.725e+02, Y0: -53.471, Time: 5.53, Learning Rate: 1.000e-03
# It: 4480, Loss: 4.782e+02, Y0: -55.927, Time: 7.14, Learning Rate: 1.000e-03
# It: 4490, Loss: 3.956e+02, Y0: -56.920, Time: 5.59, Learning Rate: 1.000e-03
# It: 4500, Loss: 5.334e+02, Y0: -56.421, Time: 5.59, Learning Rate: 1.000e-03
# It: 4510, Loss: 5.582e+02, Y0: -53.800, Time: 7.15, Learning Rate: 1.000e-03
# It: 4520, Loss: 4.791e+02, Y0: -52.087, Time: 5.55, Learning Rate: 1.000e-03
# It: 4530, Loss: 5.174e+02, Y0: -61.604, Time: 7.14, Learning Rate: 1.000e-03
# It: 4540, Loss: 5.181e+02, Y0: -58.045, Time: 5.62, Learning Rate: 1.000e-03
# It: 4550, Loss: 4.730e+02, Y0: -59.590, Time: 5.56, Learning Rate: 1.000e-03
# It: 4560, Loss: 4.736e+02, Y0: -61.566, Time: 7.14, Learning Rate: 1.000e-03
# It: 4570, Loss: 4.773e+02, Y0: -60.876, Time: 5.58, Learning Rate: 1.000e-03
# It: 4580, Loss: 5.873e+02, Y0: -57.576, Time: 7.12, Learning Rate: 1.000e-03
# It: 4590, Loss: 4.634e+02, Y0: -49.954, Time: 5.57, Learning Rate: 1.000e-03
# It: 4600, Loss: 4.641e+02, Y0: -56.927, Time: 5.55, Learning Rate: 1.000e-03
# It: 4610, Loss: 4.402e+02, Y0: -54.847, Time: 7.16, Learning Rate: 1.000e-03
# It: 4620, Loss: 4.544e+02, Y0: -59.654, Time: 5.55, Learning Rate: 1.000e-03
# It: 4630, Loss: 5.627e+02, Y0: -50.126, Time: 7.14, Learning Rate: 1.000e-03
# It: 4640, Loss: 4.409e+02, Y0: -59.138, Time: 5.55, Learning Rate: 1.000e-03
# It: 4650, Loss: 6.429e+02, Y0: -56.004, Time: 5.57, Learning Rate: 1.000e-03
# It: 4660, Loss: 5.062e+02, Y0: -52.463, Time: 7.12, Learning Rate: 1.000e-03
# It: 4670, Loss: 4.471e+02, Y0: -59.376, Time: 5.58, Learning Rate: 1.000e-03
# It: 4680, Loss: 5.266e+02, Y0: -58.300, Time: 7.19, Learning Rate: 1.000e-03
# It: 4690, Loss: 4.537e+02, Y0: -58.860, Time: 5.58, Learning Rate: 1.000e-03
# It: 4700, Loss: 5.983e+02, Y0: -52.239, Time: 5.58, Learning Rate: 1.000e-03
# It: 4710, Loss: 4.960e+02, Y0: -54.494, Time: 7.15, Learning Rate: 1.000e-03
# It: 4720, Loss: 4.736e+02, Y0: -62.343, Time: 5.57, Learning Rate: 1.000e-03
# It: 4730, Loss: 4.616e+02, Y0: -56.550, Time: 7.17, Learning Rate: 1.000e-03
# It: 4740, Loss: 5.478e+02, Y0: -56.866, Time: 5.60, Learning Rate: 1.000e-03
# It: 4750, Loss: 4.244e+02, Y0: -60.370, Time: 5.61, Learning Rate: 1.000e-03
# It: 4760, Loss: 4.124e+02, Y0: -60.990, Time: 7.14, Learning Rate: 1.000e-03
# It: 4770, Loss: 4.759e+02, Y0: -63.386, Time: 5.59, Learning Rate: 1.000e-03
# It: 4780, Loss: 5.536e+02, Y0: -53.429, Time: 7.11, Learning Rate: 1.000e-03
# It: 4790, Loss: 5.330e+02, Y0: -51.881, Time: 5.59, Learning Rate: 1.000e-03
# It: 4800, Loss: 5.525e+02, Y0: -54.297, Time: 5.56, Learning Rate: 1.000e-03
# It: 4810, Loss: 4.611e+02, Y0: -54.724, Time: 7.12, Learning Rate: 1.000e-03
# It: 4820, Loss: 4.669e+02, Y0: -57.412, Time: 5.60, Learning Rate: 1.000e-03
# It: 4830, Loss: 4.776e+02, Y0: -58.009, Time: 7.14, Learning Rate: 1.000e-03
# It: 4840, Loss: 4.771e+02, Y0: -60.810, Time: 5.58, Learning Rate: 1.000e-03
# It: 4850, Loss: 4.391e+02, Y0: -59.407, Time: 5.58, Learning Rate: 1.000e-03
# It: 4860, Loss: 5.520e+02, Y0: -58.288, Time: 7.18, Learning Rate: 1.000e-03
# It: 4870, Loss: 4.240e+02, Y0: -60.959, Time: 5.57, Learning Rate: 1.000e-03
# It: 4880, Loss: 4.750e+02, Y0: -59.881, Time: 7.15, Learning Rate: 1.000e-03
# It: 4890, Loss: 6.331e+02, Y0: -59.299, Time: 5.55, Learning Rate: 1.000e-03
# It: 4900, Loss: 5.045e+02, Y0: -58.238, Time: 5.56, Learning Rate: 1.000e-03
# It: 4910, Loss: 5.020e+02, Y0: -54.536, Time: 7.15, Learning Rate: 1.000e-03
# It: 4920, Loss: 4.504e+02, Y0: -63.457, Time: 5.58, Learning Rate: 1.000e-03
# It: 4930, Loss: 4.351e+02, Y0: -62.233, Time: 7.15, Learning Rate: 1.000e-03
# It: 4940, Loss: 5.718e+02, Y0: -60.929, Time: 5.58, Learning Rate: 1.000e-03
# It: 4950, Loss: 4.765e+02, Y0: -61.471, Time: 5.61, Learning Rate: 1.000e-03
# It: 4960, Loss: 4.153e+02, Y0: -64.151, Time: 7.18, Learning Rate: 1.000e-03
# It: 4970, Loss: 4.584e+02, Y0: -54.491, Time: 5.61, Learning Rate: 1.000e-03
# It: 4980, Loss: 4.356e+02, Y0: -62.985, Time: 7.18, Learning Rate: 1.000e-03
# It: 4990, Loss: 4.423e+02, Y0: -64.829, Time: 5.59, Learning Rate: 1.000e-03
# It: 5000, Loss: 4.638e+02, Y0: -59.036, Time: 5.60, Learning Rate: 1.000e-03
# It: 5010, Loss: 5.408e+02, Y0: -58.178, Time: 7.18, Learning Rate: 1.000e-03
# It: 5020, Loss: 4.879e+02, Y0: -62.464, Time: 5.61, Learning Rate: 1.000e-03
# It: 5030, Loss: 4.599e+02, Y0: -61.552, Time: 7.17, Learning Rate: 1.000e-03
# It: 5040, Loss: 5.374e+02, Y0: -61.128, Time: 5.59, Learning Rate: 1.000e-03
# It: 5050, Loss: 4.948e+02, Y0: -56.724, Time: 5.56, Learning Rate: 1.000e-03
# It: 5060, Loss: 4.741e+02, Y0: -64.563, Time: 7.20, Learning Rate: 1.000e-03
# It: 5070, Loss: 4.219e+02, Y0: -60.242, Time: 5.64, Learning Rate: 1.000e-03
# It: 5080, Loss: 4.478e+02, Y0: -57.127, Time: 7.16, Learning Rate: 1.000e-03
# It: 5090, Loss: 4.874e+02, Y0: -64.086, Time: 5.58, Learning Rate: 1.000e-03
# It: 5100, Loss: 4.567e+02, Y0: -59.106, Time: 5.59, Learning Rate: 1.000e-03
# It: 5110, Loss: 4.563e+02, Y0: -60.892, Time: 7.22, Learning Rate: 1.000e-03
# It: 5120, Loss: 4.994e+02, Y0: -60.387, Time: 5.57, Learning Rate: 1.000e-03
# It: 5130, Loss: 4.547e+02, Y0: -64.216, Time: 7.17, Learning Rate: 1.000e-03
# It: 5140, Loss: 4.301e+02, Y0: -62.393, Time: 5.59, Learning Rate: 1.000e-03
# It: 5150, Loss: 4.471e+02, Y0: -54.255, Time: 5.58, Learning Rate: 1.000e-03
# It: 5160, Loss: 4.766e+02, Y0: -62.897, Time: 7.19, Learning Rate: 1.000e-03
# It: 5170, Loss: 5.227e+02, Y0: -59.188, Time: 5.58, Learning Rate: 1.000e-03
# It: 5180, Loss: 5.067e+02, Y0: -59.102, Time: 7.14, Learning Rate: 1.000e-03
# It: 5190, Loss: 4.411e+02, Y0: -64.095, Time: 5.54, Learning Rate: 1.000e-03
# It: 5200, Loss: 5.236e+02, Y0: -59.406, Time: 5.63, Learning Rate: 1.000e-03
# It: 5210, Loss: 4.074e+02, Y0: -59.513, Time: 7.14, Learning Rate: 1.000e-03
# It: 5220, Loss: 4.096e+02, Y0: -60.355, Time: 5.56, Learning Rate: 1.000e-03
# It: 5230, Loss: 4.518e+02, Y0: -58.919, Time: 7.17, Learning Rate: 1.000e-03
# It: 5240, Loss: 4.241e+02, Y0: -60.153, Time: 5.56, Learning Rate: 1.000e-03
# It: 5250, Loss: 4.551e+02, Y0: -61.240, Time: 5.58, Learning Rate: 1.000e-03
# It: 5260, Loss: 4.527e+02, Y0: -62.890, Time: 7.17, Learning Rate: 1.000e-03
# It: 5270, Loss: 4.391e+02, Y0: -58.448, Time: 5.58, Learning Rate: 1.000e-03
# It: 5280, Loss: 4.833e+02, Y0: -70.373, Time: 7.15, Learning Rate: 1.000e-03
# It: 5290, Loss: 4.574e+02, Y0: -58.518, Time: 5.55, Learning Rate: 1.000e-03
# It: 5300, Loss: 4.950e+02, Y0: -62.164, Time: 5.63, Learning Rate: 1.000e-03
# It: 5310, Loss: 5.025e+02, Y0: -60.273, Time: 7.13, Learning Rate: 1.000e-03
# It: 5320, Loss: 5.978e+02, Y0: -60.688, Time: 5.62, Learning Rate: 1.000e-03
# It: 5330, Loss: 4.516e+02, Y0: -66.394, Time: 7.16, Learning Rate: 1.000e-03
# It: 5340, Loss: 4.249e+02, Y0: -59.841, Time: 5.63, Learning Rate: 1.000e-03
# It: 5350, Loss: 4.403e+02, Y0: -60.605, Time: 5.59, Learning Rate: 1.000e-03
# It: 5360, Loss: 4.625e+02, Y0: -60.731, Time: 7.14, Learning Rate: 1.000e-03
# It: 5370, Loss: 4.405e+02, Y0: -62.778, Time: 5.57, Learning Rate: 1.000e-03
# It: 5380, Loss: 5.945e+02, Y0: -66.577, Time: 7.16, Learning Rate: 1.000e-03
# It: 5390, Loss: 4.977e+02, Y0: -57.509, Time: 5.60, Learning Rate: 1.000e-03
# It: 5400, Loss: 4.347e+02, Y0: -64.550, Time: 5.56, Learning Rate: 1.000e-03
# It: 5410, Loss: 4.006e+02, Y0: -63.684, Time: 7.26, Learning Rate: 1.000e-03
# It: 5420, Loss: 4.085e+02, Y0: -63.583, Time: 5.56, Learning Rate: 1.000e-03
# It: 5430, Loss: 4.611e+02, Y0: -69.813, Time: 7.15, Learning Rate: 1.000e-03
# It: 5440, Loss: 4.638e+02, Y0: -56.489, Time: 5.61, Learning Rate: 1.000e-03
# It: 5450, Loss: 3.957e+02, Y0: -62.704, Time: 5.58, Learning Rate: 1.000e-03
# It: 5460, Loss: 4.736e+02, Y0: -60.600, Time: 7.21, Learning Rate: 1.000e-03
# It: 5470, Loss: 5.031e+02, Y0: -64.327, Time: 5.61, Learning Rate: 1.000e-03
# It: 5480, Loss: 4.735e+02, Y0: -59.779, Time: 7.18, Learning Rate: 1.000e-03
# It: 5490, Loss: 3.881e+02, Y0: -59.142, Time: 5.57, Learning Rate: 1.000e-03
# It: 5500, Loss: 4.364e+02, Y0: -60.808, Time: 5.61, Learning Rate: 1.000e-03
# It: 5510, Loss: 5.398e+02, Y0: -50.904, Time: 7.18, Learning Rate: 1.000e-03
# It: 5520, Loss: 4.138e+02, Y0: -64.116, Time: 5.62, Learning Rate: 1.000e-03
# It: 5530, Loss: 4.774e+02, Y0: -62.263, Time: 7.18, Learning Rate: 1.000e-03
# It: 5540, Loss: 5.151e+02, Y0: -68.465, Time: 5.57, Learning Rate: 1.000e-03
# It: 5550, Loss: 4.701e+02, Y0: -61.229, Time: 5.59, Learning Rate: 1.000e-03
# It: 5560, Loss: 4.409e+02, Y0: -63.183, Time: 7.13, Learning Rate: 1.000e-03
# It: 5570, Loss: 4.499e+02, Y0: -57.566, Time: 5.57, Learning Rate: 1.000e-03
# It: 5580, Loss: 4.599e+02, Y0: -62.026, Time: 7.19, Learning Rate: 1.000e-03
# It: 5590, Loss: 3.839e+02, Y0: -64.654, Time: 5.61, Learning Rate: 1.000e-03
# It: 5600, Loss: 4.407e+02, Y0: -66.722, Time: 5.61, Learning Rate: 1.000e-03
# It: 5610, Loss: 4.450e+02, Y0: -61.510, Time: 7.18, Learning Rate: 1.000e-03
# It: 5620, Loss: 4.113e+02, Y0: -70.003, Time: 5.66, Learning Rate: 1.000e-03
# It: 5630, Loss: 4.848e+02, Y0: -64.434, Time: 7.14, Learning Rate: 1.000e-03
# It: 5640, Loss: 5.603e+02, Y0: -59.102, Time: 5.63, Learning Rate: 1.000e-03
# It: 5650, Loss: 4.763e+02, Y0: -60.893, Time: 5.59, Learning Rate: 1.000e-03
# It: 5660, Loss: 4.664e+02, Y0: -60.801, Time: 7.16, Learning Rate: 1.000e-03
# It: 5670, Loss: 6.122e+02, Y0: -56.709, Time: 5.62, Learning Rate: 1.000e-03
# It: 5680, Loss: 4.698e+02, Y0: -60.619, Time: 7.22, Learning Rate: 1.000e-03
# It: 5690, Loss: 4.125e+02, Y0: -65.302, Time: 5.63, Learning Rate: 1.000e-03
# It: 5700, Loss: 4.805e+02, Y0: -55.139, Time: 5.59, Learning Rate: 1.000e-03
# It: 5710, Loss: 4.429e+02, Y0: -64.758, Time: 7.20, Learning Rate: 1.000e-03
# It: 5720, Loss: 4.821e+02, Y0: -65.693, Time: 5.66, Learning Rate: 1.000e-03
# It: 5730, Loss: 5.078e+02, Y0: -63.044, Time: 7.18, Learning Rate: 1.000e-03
# It: 5740, Loss: 4.306e+02, Y0: -61.599, Time: 5.61, Learning Rate: 1.000e-03
# It: 5750, Loss: 4.956e+02, Y0: -78.015, Time: 5.64, Learning Rate: 1.000e-03
# It: 5760, Loss: 4.632e+02, Y0: -60.267, Time: 7.19, Learning Rate: 1.000e-03
# It: 5770, Loss: 3.825e+02, Y0: -66.450, Time: 5.57, Learning Rate: 1.000e-03
# It: 5780, Loss: 4.493e+02, Y0: -63.037, Time: 7.19, Learning Rate: 1.000e-03
# It: 5790, Loss: 5.228e+02, Y0: -53.830, Time: 5.65, Learning Rate: 1.000e-03
# It: 5800, Loss: 4.066e+02, Y0: -66.820, Time: 5.59, Learning Rate: 1.000e-03
# It: 5810, Loss: 4.158e+02, Y0: -64.777, Time: 7.21, Learning Rate: 1.000e-03
# It: 5820, Loss: 6.541e+02, Y0: -63.470, Time: 5.57, Learning Rate: 1.000e-03
# It: 5830, Loss: 4.640e+02, Y0: -65.706, Time: 7.23, Learning Rate: 1.000e-03
# It: 5840, Loss: 3.918e+02, Y0: -64.288, Time: 5.63, Learning Rate: 1.000e-03
# It: 5850, Loss: 4.750e+02, Y0: -65.867, Time: 5.61, Learning Rate: 1.000e-03
# It: 5860, Loss: 4.523e+02, Y0: -65.574, Time: 7.13, Learning Rate: 1.000e-03
# It: 5870, Loss: 4.618e+02, Y0: -59.645, Time: 5.61, Learning Rate: 1.000e-03
# It: 5880, Loss: 4.782e+02, Y0: -55.731, Time: 7.19, Learning Rate: 1.000e-03
# It: 5890, Loss: 3.898e+02, Y0: -72.369, Time: 5.60, Learning Rate: 1.000e-03
# It: 5900, Loss: 4.954e+02, Y0: -65.709, Time: 5.60, Learning Rate: 1.000e-03
# It: 5910, Loss: 4.451e+02, Y0: -65.114, Time: 7.17, Learning Rate: 1.000e-03
# It: 5920, Loss: 3.622e+02, Y0: -65.950, Time: 5.63, Learning Rate: 1.000e-03
# It: 5930, Loss: 3.999e+02, Y0: -65.248, Time: 7.18, Learning Rate: 1.000e-03
# It: 5940, Loss: 3.873e+02, Y0: -62.807, Time: 5.62, Learning Rate: 1.000e-03
# It: 5950, Loss: 4.204e+02, Y0: -65.822, Time: 5.59, Learning Rate: 1.000e-03
# It: 5960, Loss: 4.522e+02, Y0: -57.707, Time: 7.20, Learning Rate: 1.000e-03
# It: 5970, Loss: 4.185e+02, Y0: -62.391, Time: 5.63, Learning Rate: 1.000e-03
# It: 5980, Loss: 4.380e+02, Y0: -62.518, Time: 7.22, Learning Rate: 1.000e-03
# It: 5990, Loss: 4.352e+02, Y0: -64.400, Time: 5.61, Learning Rate: 1.000e-03
# [StageSummary] const=1.0, lr=1.0e-03, iters=6000, eval_loss=4.497e+02±4.89e+01, eval_Y0=-66.171±0.000, time=4010.5s
# It: 0, Loss: 4.185e+02, Y0: -66.711, Time: 0.57, Learning Rate: 5.000e-04
# It: 10, Loss: 4.217e+02, Y0: -65.700, Time: 7.23, Learning Rate: 5.000e-04
# It: 20, Loss: 3.466e+02, Y0: -63.517, Time: 5.62, Learning Rate: 5.000e-04
# It: 30, Loss: 4.010e+02, Y0: -66.309, Time: 7.16, Learning Rate: 5.000e-04
# It: 40, Loss: 4.326e+02, Y0: -63.728, Time: 5.61, Learning Rate: 5.000e-04
# It: 50, Loss: 3.698e+02, Y0: -70.222, Time: 5.54, Learning Rate: 5.000e-04
# It: 60, Loss: 3.958e+02, Y0: -69.093, Time: 7.16, Learning Rate: 5.000e-04
# It: 70, Loss: 3.689e+02, Y0: -65.376, Time: 5.59, Learning Rate: 5.000e-04
# It: 80, Loss: 4.085e+02, Y0: -66.727, Time: 7.17, Learning Rate: 5.000e-04
# It: 90, Loss: 4.119e+02, Y0: -59.010, Time: 5.61, Learning Rate: 5.000e-04
# It: 100, Loss: 3.684e+02, Y0: -65.747, Time: 5.56, Learning Rate: 5.000e-04
# It: 110, Loss: 3.836e+02, Y0: -64.380, Time: 7.18, Learning Rate: 5.000e-04
# It: 120, Loss: 3.857e+02, Y0: -64.066, Time: 5.63, Learning Rate: 5.000e-04
# It: 130, Loss: 3.602e+02, Y0: -64.393, Time: 7.19, Learning Rate: 5.000e-04
# It: 140, Loss: 3.391e+02, Y0: -65.586, Time: 5.63, Learning Rate: 5.000e-04
# It: 150, Loss: 4.041e+02, Y0: -67.278, Time: 5.61, Learning Rate: 5.000e-04
# It: 160, Loss: 4.064e+02, Y0: -64.277, Time: 7.18, Learning Rate: 5.000e-04
# It: 170, Loss: 3.792e+02, Y0: -67.653, Time: 5.61, Learning Rate: 5.000e-04
# It: 180, Loss: 3.986e+02, Y0: -66.213, Time: 7.19, Learning Rate: 5.000e-04
# It: 190, Loss: 5.277e+02, Y0: -67.287, Time: 5.63, Learning Rate: 5.000e-04
# It: 200, Loss: 3.799e+02, Y0: -62.578, Time: 5.68, Learning Rate: 5.000e-04
# It: 210, Loss: 4.441e+02, Y0: -68.854, Time: 7.17, Learning Rate: 5.000e-04
# It: 220, Loss: 3.897e+02, Y0: -64.033, Time: 5.62, Learning Rate: 5.000e-04
# It: 230, Loss: 4.028e+02, Y0: -68.943, Time: 7.17, Learning Rate: 5.000e-04
# It: 240, Loss: 4.005e+02, Y0: -66.223, Time: 5.56, Learning Rate: 5.000e-04
# It: 250, Loss: 4.407e+02, Y0: -69.819, Time: 5.58, Learning Rate: 5.000e-04
# It: 260, Loss: 4.042e+02, Y0: -69.566, Time: 7.14, Learning Rate: 5.000e-04
# It: 270, Loss: 4.297e+02, Y0: -71.947, Time: 5.58, Learning Rate: 5.000e-04
# It: 280, Loss: 5.041e+02, Y0: -61.202, Time: 7.14, Learning Rate: 5.000e-04
# It: 290, Loss: 4.714e+02, Y0: -68.779, Time: 5.59, Learning Rate: 5.000e-04
# It: 300, Loss: 3.715e+02, Y0: -67.029, Time: 5.57, Learning Rate: 5.000e-04
# It: 310, Loss: 3.840e+02, Y0: -68.518, Time: 7.17, Learning Rate: 5.000e-04
# It: 320, Loss: 4.056e+02, Y0: -60.808, Time: 5.57, Learning Rate: 5.000e-04
# It: 330, Loss: 4.158e+02, Y0: -69.453, Time: 7.15, Learning Rate: 5.000e-04
# It: 340, Loss: 4.524e+02, Y0: -72.785, Time: 5.61, Learning Rate: 5.000e-04
# It: 350, Loss: 4.752e+02, Y0: -62.459, Time: 5.54, Learning Rate: 5.000e-04
# It: 360, Loss: 4.520e+02, Y0: -67.839, Time: 7.16, Learning Rate: 5.000e-04
# It: 370, Loss: 3.759e+02, Y0: -65.334, Time: 5.58, Learning Rate: 5.000e-04
# It: 380, Loss: 4.060e+02, Y0: -69.138, Time: 7.16, Learning Rate: 5.000e-04
# It: 390, Loss: 3.880e+02, Y0: -67.904, Time: 5.60, Learning Rate: 5.000e-04
# It: 400, Loss: 4.024e+02, Y0: -69.021, Time: 5.56, Learning Rate: 5.000e-04
# It: 410, Loss: 3.446e+02, Y0: -71.549, Time: 7.14, Learning Rate: 5.000e-04
# It: 420, Loss: 4.151e+02, Y0: -65.953, Time: 5.57, Learning Rate: 5.000e-04
# It: 430, Loss: 3.605e+02, Y0: -68.083, Time: 7.21, Learning Rate: 5.000e-04
# It: 440, Loss: 4.242e+02, Y0: -57.453, Time: 5.59, Learning Rate: 5.000e-04
# It: 450, Loss: 3.895e+02, Y0: -71.651, Time: 5.61, Learning Rate: 5.000e-04
# It: 460, Loss: 4.636e+02, Y0: -70.063, Time: 7.16, Learning Rate: 5.000e-04
# It: 470, Loss: 3.913e+02, Y0: -72.191, Time: 5.56, Learning Rate: 5.000e-04
# It: 480, Loss: 3.975e+02, Y0: -63.152, Time: 7.18, Learning Rate: 5.000e-04
# It: 490, Loss: 4.686e+02, Y0: -63.590, Time: 5.58, Learning Rate: 5.000e-04
# It: 500, Loss: 3.893e+02, Y0: -65.369, Time: 5.58, Learning Rate: 5.000e-04

# %%
# --- PLOTTING ---
t_test, W_test = model.fetch_minibatch()
X_pred, Y_pred, Z_pred = model.predict(Xi, t_test, W_test)

def u_exact(t, Xi_arr):
    S = Xi_arr[:, 0:1]
    H = Xi_arr[:, 1:2]
    V = Xi_arr[:, 2:3]
    X_state = Xi_arr[:, 3:4]
    return -params['gamma'] * np.exp(S)*X_state + V**2 + V*X_state

def z_exact(t, Xi_arr):
    S = Xi_arr[:, 0:1]
    H = Xi_arr[:, 1:2]
    V = Xi_arr[:, 2:3]
    X_state = Xi_arr[:, 3:4]

    s1 = params['s1']
    s2 = params['s2']
    s3 = params['s3']

    common = np.exp(-t)
    z_s = -params['gamma'] * np.exp(S)*X_state * s1
    z_h = np.zeros_like(z_s)
    z_v = (2 * V + X_state) * s3
    z_x = np.zeros_like(z_s)

    return np.concatenate([z_s, z_h, z_v, z_x], axis=1)

Xi_reshaped = X_pred.reshape(-1, D)
t_reshaped = t_test.reshape(-1, 1)

Y_exact = u_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, 1)
Z_exact = z_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, D)

exact_Y0 = u_exact(np.array([[0.0]]), Xi)[0, 0]
print(f"\nPredicted Y0: {Y_pred[0,0,0]:.4f}")
print(f"Exact Y0:     {exact_Y0:.4f}")

# Calcoliamo Y esatto per TUTTO il batch di test
Y_exact_full = u_exact(t_test[:,0:1,:], X_pred[:,0,:]) # Usa lo stato iniziale predetto o Xi
# Oppure meglio, ricalcoliamolo sui dati di input:
# Ricorda: Xi_test deve essere quello usato per generare X_pred.
# Nel tuo codice `X_pred` al tempo 0 è praticamente Xi.

Y0_pred_mean = np.mean(Y_pred[:, 0, 0])
# Calcoliamo la Y0 esatta per ogni punto del batch Xi e facciamo la media
# Nota: Xi ha shape (M, D)
Y0_exact_batch_values = -params['gamma'] * np.exp(Xi[:, 0]) * Xi[:, 3] + Xi[:, 2]**2 + Xi[:, 2] * Xi[:, 3]
Y0_exact_mean = np.mean(Y0_exact_batch_values)

print(f"\n--- Risultati Medi su {M} traiettorie ---")
print(f"Predicted Mean Y0: {Y0_pred_mean:.4f}")
print(f"Exact Mean Y0:     {Y0_exact_mean:.4f}")
print(f"Differenza:        {abs(Y0_pred_mean - Y0_exact_mean):.4f}")

plt.figure(figsize=(10,6))
plt.plot(t_test[0,:,0], X_pred[0,:,0], 'b', label='S trajectory')
plt.plot(t_test[0,:,0], X_pred[0,:,1], 'r', label='H trajectory')
plt.plot(t_test[0,:,0], X_pred[0,:,2], 'y', label='V trajectory')
plt.plot(t_test[0,:,0], X_pred[0,:,3], 'g', label='X trajectory')
plt.title("Soluzione Sistema Pienamente Accoppiato 4D")
plt.xlabel("Tempo t")
plt.ylabel("A_t")
plt.legend()
plt.grid(True, alpha=0.3)
#plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_FSDE.png")

plt.figure(figsize=(10,6))
plt.plot(t_test[0,:,0], Y_pred[0,:,0], 'b', label='Learned Y')
plt.plot(t_test[0,:,0], Y_exact[0,:,0], 'r--', label='Exact Y')
plt.plot(t_test[1:5,:,0].T, Y_pred[1:5,:,0].T, 'b')
plt.plot(t_test[1:5,:,0].T, Y_exact[1:5,:,0].T, 'r--')
plt.title("Soluzione Sistema Pienamente Accoppiato 4D")
plt.xlabel("Tempo t")
plt.ylabel("Y_t")
plt.legend()
plt.grid(True, alpha=0.3)
#plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_Y.png")

# Errore relativo medio sui componenti di Z (stile log_z, ma corretto per ogni componente)
eps = 1e-8
rel_err_Z = np.abs((Z_pred - Z_exact) / (np.abs(Z_exact) + eps))
mean_rel_err_Z = np.mean(rel_err_Z, axis=0)  # (N+1, D)

labels = ['Z_S', 'Z_H', 'Z_V', 'Z_X']
colors = ['b', 'g', 'r', 'm']

plt.figure(figsize=(10,6))
for d in range(D):
    plt.plot(t_test[0,:,0], mean_rel_err_Z[:, d], colors[d], label=f'Mean Rel Error {labels[d]}')
plt.yscale('log')
plt.title('Errore relativo medio di Z (scala log)')
plt.xlabel('Tempo t')
plt.ylabel('Errore relativo medio')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
#plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_Z.png")
# Out:
# Predicted Y0: -13.2782
# Exact Y0:     -50.6331
