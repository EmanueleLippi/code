# %% [markdown]
# # T48_v2
# Versione robusta per orizzonte lungo (`T=48`) con: gradient clipping, antithetic sampling, loss pesata e training ricorsivo con batch-pool multi-scenario.

# %%
import time
from abc import ABC, abstractmethod

import matplotlib.pyplot as plt
import numpy as np
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()


class FBSNN(ABC):
    def __init__(
        self,
        Xi,
        T,
        M,
        N,
        D,
        layers,
        t_start=0.0,
        activation="sin",
        clip_grad_norm=1.0,
        use_antithetic_sampling=True,
        path_loss_weight=1.0,
        terminal_y_loss_weight=10.0,
        terminal_z_loss_weight=1.0,
    ):
        self.T = float(T)
        self.t_start = np.float32(t_start)
        self.M = int(M)
        self.N = int(N)
        self.D = int(D)
        self.layers = layers

        self.activation = activation
        self.clip_grad_norm = clip_grad_norm
        self.use_antithetic_sampling = bool(use_antithetic_sampling)
        self.path_loss_weight = float(path_loss_weight)
        self.terminal_y_loss_weight = float(terminal_y_loss_weight)
        self.terminal_z_loss_weight = float(terminal_z_loss_weight)

        self.Xi = self._prepare_Xi(Xi)

        self.weights, self.biases = self.initialize_NN(layers)

        self.sess = tf.Session(
            config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
        )

        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.t_tf = tf.placeholder(tf.float32, shape=[self.M, self.N + 1, 1])
        self.W_tf = tf.placeholder(tf.float32, shape=[self.M, self.N + 1, self.D])
        self.Xi_tf = tf.placeholder(tf.float32, shape=[self.M, self.D])
        self.const_tf = tf.placeholder(tf.float32, shape=[])

        self.use_external_terminal_tf = tf.placeholder_with_default(np.float32(0.0), shape=[])
        self.Y_terminal_tf = tf.placeholder_with_default(
            tf.zeros([self.M, 1], dtype=tf.float32), shape=[self.M, 1]
        )
        self.Z_terminal_tf = tf.placeholder_with_default(
            tf.zeros([self.M, self.D], dtype=tf.float32), shape=[self.M, self.D]
        )

        self.loss, self.X_pred, self.Y_pred, self.Y0_pred, self.Z_pred = self.loss_function(
            self.t_tf, self.W_tf, self.Xi_tf
        )

        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        grads_and_vars = self.optimizer.compute_gradients(self.loss)
        if self.clip_grad_norm is not None:
            non_null = [(g, v) for g, v in grads_and_vars if g is not None]
            if non_null:
                grads, vars_ = zip(*non_null)
                clipped_grads, _ = tf.clip_by_global_norm(grads, self.clip_grad_norm)
                clipped = list(zip(clipped_grads, vars_))
                untouched = [(g, v) for g, v in grads_and_vars if g is None]
                grads_and_vars = clipped + untouched
        self.train_op = self.optimizer.apply_gradients(grads_and_vars)

        self.sess.run(tf.global_variables_initializer())

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2.0 / (in_dim + out_dim))
        return tf.Variable(
            tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32
        )

    def _prepare_Xi(self, Xi_in):
        Xi_arr = np.asarray(Xi_in, dtype=np.float32)
        if Xi_arr.ndim == 1:
            Xi_arr = Xi_arr.reshape(1, -1)

        if Xi_arr.shape == (1, self.D):
            Xi_arr = np.repeat(Xi_arr, self.M, axis=0)
        elif Xi_arr.shape != (self.M, self.D):
            raise ValueError(
                f"Xi must have shape (1,{self.D}) or ({self.M},{self.D}), got {Xi_arr.shape}"
            )
        return Xi_arr

    def _prepare_terminal_targets(self, Y_terminal, Z_terminal):
        Y_arr = np.asarray(Y_terminal, dtype=np.float32)
        Z_arr = np.asarray(Z_terminal, dtype=np.float32)

        if Y_arr.ndim == 1:
            Y_arr = Y_arr.reshape(-1, 1)
        if Z_arr.ndim == 1:
            Z_arr = Z_arr.reshape(1, -1)

        if Y_arr.shape != (self.M, 1):
            raise ValueError(f"Y_terminal must have shape ({self.M},1), got {Y_arr.shape}")
        if Z_arr.shape != (self.M, self.D):
            raise ValueError(f"Z_terminal must have shape ({self.M},{self.D}), got {Z_arr.shape}")

        return Y_arr, Z_arr

    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = X
        for l in range(num_layers - 2):
            W = weights[l]
            b = biases[l]
            pre = tf.add(tf.matmul(H, W), b)
            if self.activation == "sin":
                H = tf.sin(pre)
            elif self.activation == "tanh":
                H = tf.tanh(pre)
            elif self.activation == "swish":
                H = pre * tf.sigmoid(pre)
            else:
                raise ValueError(
                    f"Unsupported activation '{self.activation}'. Use: sin, tanh, swish"
                )

        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    def net_u(self, t, X):
        u = self.neural_net(tf.concat([t, X], 1), self.weights, self.biases)
        Du = tf.gradients(u, X)[0]
        return u, Du

    def Dg_tf(self, X):
        return tf.gradients(self.g_tf(X), X)[0]

    def loss_function(self, t, W, Xi):
        path_loss = 0.0
        X_list = []
        Y_list = []
        Z_list = []

        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        X0 = Xi
        Y0, Du0 = self.net_u(t0, X0)
        sigma0 = self.sigma_tf(t0, X0, Y0)
        Z0 = tf.squeeze(tf.matmul(tf.expand_dims(Du0, 1), sigma0), axis=1)

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)

        for n in range(self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]

            dW = W1 - W0
            sigma_dW = tf.squeeze(tf.matmul(sigma0, tf.expand_dims(dW, -1)), axis=[-1])
            X1 = X0 + self.mu_tf(t0, X0, Y0, Z0) * (t1 - t0) + sigma_dW

            Y1_tilde = Y0 + self.phi_tf(t0, X0, Y0, Z0) * (t1 - t0) + tf.reduce_sum(
                Z0 * dW, axis=1, keepdims=True
            )

            Y1, Du1 = self.net_u(t1, X1)
            sigma1 = self.sigma_tf(t1, X1, Y1)
            Z1 = tf.squeeze(tf.matmul(tf.expand_dims(Du1, 1), sigma1), axis=1)

            path_loss += tf.reduce_mean(tf.square(Y1 - Y1_tilde))

            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            sigma0 = sigma1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)

        path_loss = path_loss / float(max(1, self.N))

        Y_terminal_default = self.g_tf(X1)
        Dg = self.Dg_tf(X1)
        Z_terminal_default = tf.squeeze(tf.matmul(tf.expand_dims(Dg, 1), sigma1), axis=1)

        alpha = tf.cast(self.use_external_terminal_tf, tf.float32)
        Y_terminal_target = (1.0 - alpha) * Y_terminal_default + alpha * self.Y_terminal_tf
        Z_terminal_target = (1.0 - alpha) * Z_terminal_default + alpha * self.Z_terminal_tf

        terminal_y_loss = tf.reduce_mean(tf.square(Y1 - Y_terminal_target))
        terminal_z_loss = tf.reduce_mean(tf.square(Z1 - Z_terminal_target))

        loss = (
            self.path_loss_weight * path_loss
            + self.terminal_y_loss_weight * terminal_y_loss
            + self.terminal_z_loss_weight * terminal_z_loss
        )

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)
        return loss, X, Y, Y[:, 0, :], Z

    def fetch_minibatch(self):
        Dt = np.zeros((self.M, self.N + 1, 1), dtype=np.float32)
        DW = np.zeros((self.M, self.N + 1, self.D), dtype=np.float32)

        dt = float(self.T / self.N)
        Dt[:, 1:, :] = dt

        if self.use_antithetic_sampling and self.M > 1:
            half_M = self.M // 2
            DW_half = np.sqrt(dt) * np.random.normal(size=(half_M, self.N, self.D)).astype(np.float32)
            DW[:half_M, 1:, :] = DW_half
            DW[half_M : 2 * half_M, 1:, :] = -DW_half
            if self.M % 2 == 1:
                DW[-1, 1:, :] = (
                    np.sqrt(dt) * np.random.normal(size=(self.N, self.D)).astype(np.float32)
                )
        else:
            DW[:, 1:, :] = (
                np.sqrt(dt) * np.random.normal(size=(self.M, self.N, self.D)).astype(np.float32)
            )

        t = self.t_start + np.cumsum(Dt, axis=1)
        W = np.cumsum(DW, axis=1)
        return t.astype(np.float32), W.astype(np.float32)

    def _check_batch_entry(self, entry):
        Xi_entry = self._prepare_Xi(entry["Xi"])
        t_entry = np.asarray(entry["t"], dtype=np.float32)
        W_entry = np.asarray(entry["W"], dtype=np.float32)
        if t_entry.shape != (self.M, self.N + 1, 1):
            raise ValueError(
                f"t_batch must have shape ({self.M},{self.N+1},1), got {t_entry.shape}"
            )
        if W_entry.shape != (self.M, self.N + 1, self.D):
            raise ValueError(
                f"W_batch must have shape ({self.M},{self.N+1},{self.D}), got {W_entry.shape}"
            )
        term = entry.get("terminal_targets", None)
        return Xi_entry, t_entry, W_entry, term

    def _build_feed_dict(
        self,
        Xi_feed,
        t_batch,
        W_batch,
        learning_rate,
        current_const,
        terminal_targets,
    ):
        use_external_terminal = np.float32(0.0)
        Y_terminal_feed = np.zeros((self.M, 1), dtype=np.float32)
        Z_terminal_feed = np.zeros((self.M, self.D), dtype=np.float32)

        if terminal_targets is not None:
            use_external_terminal = np.float32(1.0)
            Y_terminal_feed, Z_terminal_feed = self._prepare_terminal_targets(
                terminal_targets[0], terminal_targets[1]
            )

        tf_dict = {
            self.Xi_tf: Xi_feed,
            self.t_tf: t_batch,
            self.W_tf: W_batch,
            self.learning_rate: learning_rate,
            self.const_tf: current_const,
            self.use_external_terminal_tf: use_external_terminal,
            self.Y_terminal_tf: Y_terminal_feed,
            self.Z_terminal_tf: Z_terminal_feed,
        }
        return tf_dict

    def train(
        self,
        N_Iter,
        learning_rate,
        const_value=None,
        Xi_batch=None,
        fixed_batch=None,
        terminal_targets=None,
        batch_pool=None,
    ):
        Xi_feed_default = self.Xi if Xi_batch is None else self._prepare_Xi(Xi_batch)

        fixed_t = None
        fixed_W = None
        if fixed_batch is not None:
            fixed_t = np.asarray(fixed_batch[0], dtype=np.float32)
            fixed_W = np.asarray(fixed_batch[1], dtype=np.float32)
            if fixed_t.shape != (self.M, self.N + 1, 1):
                raise ValueError(
                    f"t_batch must have shape ({self.M},{self.N+1},1), got {fixed_t.shape}"
                )
            if fixed_W.shape != (self.M, self.N + 1, self.D):
                raise ValueError(
                    f"W_batch must have shape ({self.M},{self.N+1},{self.D}), got {fixed_W.shape}"
                )

        checked_pool = None
        if batch_pool is not None:
            if len(batch_pool) == 0:
                raise ValueError("batch_pool cannot be empty")
            checked_pool = [self._check_batch_entry(entry) for entry in batch_pool]

        start_time = time.time()
        last_loss = None
        last_y0 = None
        current_const = np.float32(self.const if const_value is None else const_value)

        for it in range(int(N_Iter)):
            if checked_pool is not None:
                idx = np.random.randint(len(checked_pool))
                Xi_feed, t_batch, W_batch, term = checked_pool[idx]
                term_use = term
            else:
                Xi_feed = Xi_feed_default
                if fixed_t is None:
                    t_batch, W_batch = self.fetch_minibatch()
                else:
                    t_batch, W_batch = fixed_t, fixed_W
                term_use = terminal_targets

            tf_dict = self._build_feed_dict(
                Xi_feed=Xi_feed,
                t_batch=t_batch,
                W_batch=W_batch,
                learning_rate=learning_rate,
                current_const=current_const,
                terminal_targets=term_use,
            )

            self.sess.run(self.train_op, tf_dict)

            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, y0_value = self.sess.run([self.loss, self.Y0_pred], tf_dict)
                y0_mean = float(np.mean(y0_value))
                y0_std = float(np.std(y0_value))
                last_loss = float(loss_value)
                last_y0 = y0_mean
                print(
                    "It: %d, Loss: %.3e, Y0_mean: %.3f, Y0_std: %.3f, Time: %.2f, Learning Rate: %.3e"
                    % (it, loss_value, y0_mean, y0_std, elapsed, learning_rate)
                )
                start_time = time.time()

        return {
            "const": float(current_const),
            "learning_rate": float(learning_rate),
            "n_iter": int(N_Iter),
            "last_loss": last_loss,
            "last_y0": last_y0,
            "used_batch_pool": checked_pool is not None,
        }

    def evaluate(
        self,
        const_value=None,
        n_batches=5,
        Xi_batch=None,
        fixed_batch=None,
        terminal_targets=None,
        batch_pool=None,
    ):
        current_const = np.float32(self.const if const_value is None else const_value)
        Xi_feed_default = self.Xi if Xi_batch is None else self._prepare_Xi(Xi_batch)

        fixed_t = None
        fixed_W = None
        if fixed_batch is not None:
            fixed_t = np.asarray(fixed_batch[0], dtype=np.float32)
            fixed_W = np.asarray(fixed_batch[1], dtype=np.float32)

        checked_pool = None
        if batch_pool is not None:
            if len(batch_pool) == 0:
                raise ValueError("batch_pool cannot be empty")
            checked_pool = [self._check_batch_entry(entry) for entry in batch_pool]

        losses = []
        y0s = []

        if checked_pool is not None:
            iterable = checked_pool
        else:
            iterable = range(int(n_batches))

        for item in iterable:
            if checked_pool is not None:
                Xi_feed, t_batch, W_batch, term = item
                term_use = term
            else:
                Xi_feed = Xi_feed_default
                if fixed_t is None:
                    t_batch, W_batch = self.fetch_minibatch()
                else:
                    t_batch, W_batch = fixed_t, fixed_W
                term_use = terminal_targets

            tf_dict = self._build_feed_dict(
                Xi_feed=Xi_feed,
                t_batch=t_batch,
                W_batch=W_batch,
                learning_rate=0.0,
                current_const=current_const,
                terminal_targets=term_use,
            )
            tf_dict.pop(self.learning_rate)

            loss_value, y0_value = self.sess.run([self.loss, self.Y0_pred], tf_dict)
            losses.append(float(loss_value))
            y0s.append(float(np.mean(y0_value)))

        return {
            "const": float(current_const),
            "mean_loss": float(np.mean(losses)),
            "std_loss": float(np.std(losses)),
            "mean_y0": float(np.mean(y0s)),
            "std_y0": float(np.std(y0s)),
            "n_batches": int(len(losses)),
            "used_batch_pool": checked_pool is not None,
        }

    def predict(self, Xi_star, t_star, W_star, const_value=None):
        current_const = np.float32(self.const if const_value is None else const_value)
        Xi_star = self._prepare_Xi(Xi_star)

        tf_dict = {
            self.Xi_tf: Xi_star,
            self.t_tf: np.asarray(t_star, dtype=np.float32),
            self.W_tf: np.asarray(W_star, dtype=np.float32),
            self.const_tf: current_const,
            self.use_external_terminal_tf: np.float32(0.0),
        }

        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        Z_star = self.sess.run(self.Z_pred, tf_dict)
        return X_star, Y_star, Z_star

    def export_parameters(self):
        return self.sess.run(self.weights + self.biases)

    def import_parameters(self, values):
        if len(values) != len(self.weights) + len(self.biases):
            raise ValueError("Invalid number of tensors for import_parameters")
        vars_all = self.weights + self.biases
        assign_ops = [var.assign(val) for var, val in zip(vars_all, values)]
        self.sess.run(assign_ops)

    @abstractmethod
    def phi_tf(self, t, X, Y, Z):
        pass

    @abstractmethod
    def g_tf(self, X):
        pass

    @abstractmethod
    def mu_tf(self, t, X, Y, Z):
        pass

    @abstractmethod
    def sigma_tf(self, t, X, Y):
        pass


class NN(FBSNN):
    def __init__(self, Xi, T, M, N, D, layers, parameters, t_start=0.0, **kwargs):
        self.mu1 = parameters["mu1"]
        self.mu2 = parameters["mu2"]
        self.c1 = parameters["c1"]
        self.c2 = parameters["c2"]
        self.c3 = parameters["c3"]
        self.c4 = parameters["c4"]
        self.gamma = parameters["gamma"]
        self.s1 = parameters["s1"]
        self.s2 = parameters["s2"]
        self.s3 = parameters["s3"]
        self.x_max = parameters["x_max"]
        self.d = parameters["d"]
        self.const = parameters["const"]
        super().__init__(Xi, T, M, N, D, layers, t_start=t_start, **kwargs)

    def psi(self, X_state):
        return tf.maximum(
            0.0,
            tf.minimum(1.0, tf.minimum(X_state / self.d, (self.x_max - X_state) / self.d)),
        )

    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu1 = tf.cast(self.mu1, tf.float32)
        mu2 = tf.cast(self.mu2, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        c2 = tf.cast(self.c2, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)
        c4 = tf.cast(self.c4, tf.float32)
        x_max = tf.cast(self.x_max, tf.float32)

        dS = mu1 * (c1 - S)
        dH = mu2 * (c2 - H)
        dV = c3 * self.psi(-X_state) - c4 * self.psi(X_state - x_max)
        dX = V
        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        gamma = tf.cast(self.gamma, tf.float32)
        exp_S = tf.exp(S)
        return -gamma * exp_S * X_state

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu1 = tf.cast(self.mu1, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        gamma = tf.cast(self.gamma, tf.float32)

        exp_S = tf.exp(S)
        return -gamma * exp_S * (X_state * mu1 * (c1 - S) + V + 0.5 * X_state * s1**2)

    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)
        return tf.stack([r1, r2, r3, r4], axis=1)


def psi_np(x_state, d, x_max):
    return np.maximum(0.0, np.minimum(1.0, np.minimum(x_state / d, (x_max - x_state) / d)))


def make_antithetic_dW(rng, M, N, D, dt, use_antithetic=True):
    dW = np.zeros((M, N, D), dtype=np.float32)
    if use_antithetic and M > 1:
        half = M // 2
        half_w = (np.sqrt(dt) * rng.normal(size=(half, N, D))).astype(np.float32)
        dW[:half] = half_w
        dW[half : 2 * half] = -half_w
        if M % 2 == 1:
            dW[-1] = (np.sqrt(dt) * rng.normal(size=(N, D))).astype(np.float32)
    else:
        dW[:, :, :] = (np.sqrt(dt) * rng.normal(size=(M, N, D))).astype(np.float32)
    return dW


def simulate_forward_paths_np(
    Xi_batch,
    params_local,
    T_total,
    N_total,
    seed=1234,
    use_antithetic=True,
):
    rng = np.random.RandomState(seed)

    M_local, D_local = Xi_batch.shape
    dt = T_total / N_total

    t_grid = np.linspace(0.0, T_total, N_total + 1, dtype=np.float32)
    dW = make_antithetic_dW(rng, M_local, N_total, D_local, dt, use_antithetic)

    X_paths = np.zeros((M_local, N_total + 1, D_local), dtype=np.float32)
    X_paths[:, 0, :] = Xi_batch.astype(np.float32)

    mu1 = float(params_local["mu1"])
    mu2 = float(params_local["mu2"])
    c1 = float(params_local["c1"])
    c2 = float(params_local["c2"])
    c3 = float(params_local["c3"])
    c4 = float(params_local["c4"])
    d_par = float(params_local["d"])
    x_max = float(params_local["x_max"])
    s1 = float(params_local["s1"])
    s2 = float(params_local["s2"])
    s3 = float(params_local["s3"])

    for n in range(N_total):
        Xn = X_paths[:, n, :]
        S = Xn[:, 0:1]
        H = Xn[:, 1:2]
        V = Xn[:, 2:3]
        X_state = Xn[:, 3:4]

        dS = mu1 * (c1 - S)
        dH = mu2 * (c2 - H)
        dV = c3 * psi_np(-X_state, d_par, x_max) - c4 * psi_np(X_state - x_max, d_par, x_max)
        dX = V
        drift = np.concatenate([dS, dH, dV, dX], axis=1)

        diffusion = np.zeros_like(Xn)
        diffusion[:, 0:1] = s1 * dW[:, n, 0:1]
        diffusion[:, 1:2] = s2 * dW[:, n, 1:2]
        diffusion[:, 2:3] = s3 * dW[:, n, 2:3]
        diffusion[:, 3:4] = 0.0

        X_paths[:, n + 1, :] = Xn + drift * dt + diffusion

    return t_grid, dW, X_paths


def build_block_batch_from_forward(t_grid, dW, i0, i1):
    M_local = dW.shape[0]
    D_local = dW.shape[2]
    n_steps = i1 - i0

    t_block = np.zeros((M_local, n_steps + 1, 1), dtype=np.float32)
    W_block = np.zeros((M_local, n_steps + 1, D_local), dtype=np.float32)

    t_block[:, :, 0] = t_grid[i0 : i1 + 1][None, :]
    W_block[:, 1:, :] = np.cumsum(dW[:, i0:i1, :], axis=1)
    return t_block, W_block


def build_dummy_batch_for_model(model_local):
    t_dummy = np.zeros((model_local.M, model_local.N + 1, 1), dtype=np.float32)
    local_grid = np.linspace(
        float(model_local.t_start),
        float(model_local.t_start + model_local.T),
        model_local.N + 1,
        dtype=np.float32,
    )
    t_dummy[:, :, 0] = local_grid[None, :]
    W_dummy = np.zeros((model_local.M, model_local.N + 1, model_local.D), dtype=np.float32)
    return t_dummy, W_dummy


def build_forward_scenarios(
    Xi_batch,
    params,
    T_total,
    N_total,
    base_seed,
    n_scenarios,
    use_antithetic=True,
):
    scenarios = []
    for k in range(int(n_scenarios)):
        seed_k = int(base_seed + 7919 * k)
        t_grid, dW, X_paths = simulate_forward_paths_np(
            Xi_batch,
            params,
            T_total,
            N_total,
            seed=seed_k,
            use_antithetic=use_antithetic,
        )
        scenarios.append(
            {
                "seed": seed_k,
                "t_grid": t_grid,
                "dW": dW,
                "X_paths": X_paths,
            }
        )
    return scenarios


def build_block_pool(scenarios, i0, i1, next_model):
    pool = []
    for sc in scenarios:
        Xi_block = sc["X_paths"][:, i0, :]
        X_terminal = sc["X_paths"][:, i1, :]
        t_block, W_block = build_block_batch_from_forward(sc["t_grid"], sc["dW"], i0, i1)

        terminal_targets = None
        if next_model is not None:
            t_dummy_next, W_dummy_next = build_dummy_batch_for_model(next_model)
            _, Y_next, Z_next = next_model.predict(
                X_terminal, t_dummy_next, W_dummy_next, const_value=1.0
            )
            terminal_targets = (Y_next[:, 0, :], Z_next[:, 0, :])

        pool.append(
            {
                "Xi": Xi_block,
                "t": t_block,
                "W": W_block,
                "terminal_targets": terminal_targets,
            }
        )
    return pool


def partition_blocks(N_total, cfg):
    min_steps = int(cfg.get("min_steps_per_block", 1))
    requested_blocks = int(cfg["n_blocks"])

    target_block_steps = int(cfg.get("target_block_steps", 0))
    if target_block_steps > 0:
        requested_blocks = max(requested_blocks, int(np.ceil(N_total / target_block_steps)))

    max_blocks_from_steps = max(1, N_total // max(1, min_steps))
    max_blocks_cfg = int(cfg.get("max_blocks", max_blocks_from_steps))
    effective_blocks = min(requested_blocks, max_blocks_from_steps, max_blocks_cfg)

    terminal_min_steps = int(cfg.get("terminal_min_steps", min_steps))

    base = N_total // effective_blocks
    rem = N_total % effective_blocks
    steps = [base + (1 if i < rem else 0) for i in range(effective_blocks)]

    deficit = max(0, terminal_min_steps - steps[-1])
    i_donor = 0
    while deficit > 0 and i_donor < effective_blocks - 1:
        spare = max(0, steps[i_donor] - min_steps)
        take = min(spare, deficit)
        steps[i_donor] -= take
        steps[-1] += take
        deficit -= take
        i_donor += 1

    block_edges = np.zeros(effective_blocks + 1, dtype=int)
    for i_step in range(effective_blocks):
        block_edges[i_step + 1] = block_edges[i_step] + steps[i_step]

    if block_edges[-1] != N_total:
        raise ValueError(
            f"invalid block partition: last edge {block_edges[-1]} != N_total {N_total}"
        )

    return {
        "requested_blocks": requested_blocks,
        "effective_blocks": effective_blocks,
        "steps": steps,
        "block_edges": block_edges,
        "min_steps": min_steps,
        "terminal_min_steps": terminal_min_steps,
    }


def run_recursive_experiment(Xi_seed, N_total, T_total, cfg, label, params, M, D, layers):
    Xi_batch_local = np.repeat(Xi_seed.astype(np.float32), M, axis=0)

    n_train_scen = int(cfg.get("n_forward_train", 1))
    n_eval_scen = int(cfg.get("n_forward_eval", 1))
    forward_seed = int(cfg.get("seed_forward", 1234))

    train_scenarios = build_forward_scenarios(
        Xi_batch=Xi_batch_local,
        params=params,
        T_total=T_total,
        N_total=N_total,
        base_seed=forward_seed,
        n_scenarios=n_train_scen,
        use_antithetic=bool(cfg.get("use_antithetic_forward", True)),
    )
    eval_scenarios = build_forward_scenarios(
        Xi_batch=Xi_batch_local,
        params=params,
        T_total=T_total,
        N_total=N_total,
        base_seed=forward_seed + 100000,
        n_scenarios=n_eval_scen,
        use_antithetic=bool(cfg.get("use_antithetic_forward", True)),
    )

    part = partition_blocks(N_total=N_total, cfg=cfg)
    block_edges = part["block_edges"]
    steps = part["steps"]
    effective_blocks = part["effective_blocks"]

    print(
        f"[RecursiveConfig] label={label}, N_total={N_total}, n_blocks={effective_blocks} (req={part['requested_blocks']}), "
        f"min_steps_per_block={part['min_steps']}, terminal_min_steps={part['terminal_min_steps']}, "
        f"iters_per_block={cfg['iters_per_block']}, lr={cfg['lr_per_block']:.1e}, warm_start={cfg['use_warm_start']}, "
        f"train_scen={n_train_scen}, eval_scen={n_eval_scen}"
    )
    print(f"[RecursivePartition] label={label}, steps={steps}")

    next_model = None
    next_params = None
    local_logs = []
    local_models = []

    for b in range(effective_blocks - 1, -1, -1):
        i0 = int(block_edges[b])
        i1 = int(block_edges[b + 1])
        n_steps_block = i1 - i0

        t_grid_ref = train_scenarios[0]["t_grid"]
        T_block = float(t_grid_ref[i1] - t_grid_ref[i0])
        t_start_block = float(t_grid_ref[i0])

        Xi_block_ref = train_scenarios[0]["X_paths"][:, i0, :]

        block_model = NN(
            Xi=Xi_block_ref,
            T=T_block,
            M=M,
            N=n_steps_block,
            D=D,
            layers=layers,
            parameters=params,
            t_start=t_start_block,
            activation=cfg.get("activation", "sin"),
            clip_grad_norm=cfg.get("clip_grad_norm", 1.0),
            use_antithetic_sampling=cfg.get("use_antithetic_sampling", True),
            path_loss_weight=cfg.get("path_loss_weight", 1.0),
            terminal_y_loss_weight=cfg.get("terminal_y_loss_weight", 10.0),
            terminal_z_loss_weight=cfg.get("terminal_z_loss_weight", 1.0),
        )

        if cfg["use_warm_start"] and (next_params is not None):
            block_model.import_parameters(next_params)

        train_pool = build_block_pool(train_scenarios, i0, i1, next_model)
        eval_pool = build_block_pool(eval_scenarios, i0, i1, next_model)

        is_terminal_block = train_pool[0]["terminal_targets"] is None

        block_iters = int(cfg["iters_per_block"])
        block_lr = float(cfg["lr_per_block"])
        if is_terminal_block:
            block_iters = int(max(1, round(block_iters * float(cfg.get("terminal_iters_multiplier", 1.0)))))
            block_lr = float(block_lr * float(cfg.get("terminal_lr_multiplier", 1.0)))

        print(
            f"[RecursiveBlock] {label} b={b}, idx=[{i0},{i1}], steps={n_steps_block}, "
            f"terminal={'external' if not is_terminal_block else 'g'}, iters={block_iters}, lr={block_lr:.1e}"
        )

        if is_terminal_block and bool(cfg.get("terminal_two_stage", False)):
            stage1_frac = float(cfg.get("terminal_stage1_frac", 0.3))
            stage1_iters = int(max(1, round(block_iters * stage1_frac)))
            stage2_iters = int(max(1, block_iters - stage1_iters))
            stage1_lr = float(block_lr * float(cfg.get("terminal_stage1_lr_boost", 1.0)))
            stage2_lr = float(block_lr)

            print(
                f"[TerminalSchedule] {label} b={b}: "
                f"stage1(iters={stage1_iters}, lr={stage1_lr:.1e}), "
                f"stage2(iters={stage2_iters}, lr={stage2_lr:.1e})"
            )

            block_model.train(
                N_Iter=stage1_iters,
                learning_rate=stage1_lr,
                const_value=1.0,
                batch_pool=train_pool,
            )
            train_stats_block = block_model.train(
                N_Iter=stage2_iters,
                learning_rate=stage2_lr,
                const_value=1.0,
                batch_pool=train_pool,
            )
        else:
            train_stats_block = block_model.train(
                N_Iter=block_iters,
                learning_rate=block_lr,
                const_value=1.0,
                batch_pool=train_pool,
            )

        eval_stats_block = block_model.evaluate(
            const_value=1.0,
            batch_pool=eval_pool,
        )

        exact_y0_block = float(
            np.mean(
                -params["gamma"]
                * np.exp(eval_scenarios[0]["X_paths"][:, i0, 0:1])
                * eval_scenarios[0]["X_paths"][:, i0, 3:4]
            )
        )

        local_logs.append(
            {
                "block": int(b),
                "i0": int(i0),
                "i1": int(i1),
                "steps": int(n_steps_block),
                "train_last_loss": train_stats_block["last_loss"],
                "eval_loss": eval_stats_block["mean_loss"],
                "eval_y0": eval_stats_block["mean_y0"],
                "exact_eval_y0": exact_y0_block,
                "terminal_mode": "external" if not is_terminal_block else "g",
                "train_iters": int(block_iters),
                "train_lr": float(block_lr),
            }
        )

        local_models.append(block_model)
        next_model = block_model
        next_params = block_model.export_parameters()

    model_t0 = local_models[-1]
    ordered_logs = sorted(local_logs, key=lambda x: x["block"])

    terminal_losses = [r["eval_loss"] for r in ordered_logs if r["terminal_mode"] == "g"]
    non_terminal_losses = [
        r["eval_loss"] for r in ordered_logs if r["terminal_mode"] != "g"
    ]

    summary = {
        "label": label,
        "N_total": int(N_total),
        "mean_eval_loss": float(np.mean([r["eval_loss"] for r in ordered_logs])),
        "std_eval_loss": float(np.std([r["eval_loss"] for r in ordered_logs])),
        "mean_eval_loss_nonterminal": float(np.mean(non_terminal_losses))
        if len(non_terminal_losses) > 0
        else float("nan"),
        "terminal_eval_loss": float(np.mean(terminal_losses))
        if len(terminal_losses) > 0
        else float("nan"),
        "block0_eval_y0": float(ordered_logs[0]["eval_y0"]),
        "block0_exact_y0": float(ordered_logs[0]["exact_eval_y0"]),
        "n_blocks": int(len(ordered_logs)),
    }

    for m in local_models[:-1]:
        m.sess.close()

    return summary, ordered_logs, model_t0


def u_exact_np(params, X):
    S = X[:, 0:1]
    X_state = X[:, 3:4]
    return -params["gamma"] * np.exp(S) * X_state


def z_exact_np(params, X):
    S = X[:, 0:1]
    X_state = X[:, 3:4]
    s1 = params["s1"]
    z_s = -params["gamma"] * np.exp(S) * X_state * s1
    z_h = np.zeros_like(z_s)
    z_v = np.zeros_like(z_s)
    z_x = np.zeros_like(z_s)
    return np.concatenate([z_s, z_h, z_v, z_x], axis=1)


if __name__ == "__main__":
    M = 2048
    D = 4

    T = 48.0
    target_dt = 0.1
    N = int(max(10, round(T / target_dt)))

    params = {
        "mu1": np.float32(1.0),
        "mu2": np.float32(1.0),
        "c1": np.float32(1.0),
        "c2": np.float32(1.0),
        "c3": np.float32(1.0),
        "c4": np.float32(1.0),
        "gamma": np.float32(1.0),
        "d": np.float32(1.0),
        "x_max": np.float32(1.0),
        "s1": np.float32(0.5),
        "s2": np.float32(0.5),
        "s3": np.float32(0.5),
        "const": np.float32(0.0),
    }

    Xi = np.array([np.log(4.0), 0.5, 0.5, 2.0]).reshape(1, D)
    layers = [D + 1] + 4 * [256] + [1]

    recursive_profile = "stable"  # 'quick' oppure 'stable'

    if recursive_profile == "quick":
        recursive_cfg = {
            "n_blocks": 12,
            "target_block_steps": 20,
            "max_blocks": 32,
            "iters_per_block": 120,
            "lr_per_block": 2.0e-4,
            "seed_forward": 1234,
            "use_warm_start": True,
            "min_steps_per_block": 12,
            "terminal_iters_multiplier": 4.0,
            "terminal_lr_multiplier": 0.5,
            "terminal_two_stage": True,
            "terminal_stage1_frac": 0.35,
            "terminal_stage1_lr_boost": 2.0,
            "terminal_min_steps": 24,
            "n_forward_train": 3,
            "n_forward_eval": 1,
            "use_antithetic_forward": True,
            "activation": "sin",
            "clip_grad_norm": 1.0,
            "use_antithetic_sampling": True,
            "path_loss_weight": 1.0,
            "terminal_y_loss_weight": 12.0,
            "terminal_z_loss_weight": 0.5,
        }
    elif recursive_profile == "stable":
        recursive_cfg = {
            "n_blocks": 16,
            "target_block_steps": 16,
            "max_blocks": 40,
            "iters_per_block": 220,
            "lr_per_block": 1.2e-4,
            "seed_forward": 1234,
            "use_warm_start": True,
            "min_steps_per_block": 10,
            "terminal_iters_multiplier": 6.0,
            "terminal_lr_multiplier": 0.4,
            "terminal_two_stage": True,
            "terminal_stage1_frac": 0.40,
            "terminal_stage1_lr_boost": 2.0,
            "terminal_min_steps": 24,
            "n_forward_train": 4,
            "n_forward_eval": 2,
            "use_antithetic_forward": True,
            "activation": "sin",
            "clip_grad_norm": 1.0,
            "use_antithetic_sampling": True,
            "path_loss_weight": 1.0,
            "terminal_y_loss_weight": 15.0,
            "terminal_z_loss_weight": 0.25,
        }
    else:
        raise ValueError("recursive_profile must be 'quick' or 'stable'")

    print("\n=== Recursive training (backward in time) ===")
    main_summary, recursive_logs, recursive_model_t0 = run_recursive_experiment(
        Xi_seed=Xi,
        N_total=N,
        T_total=T,
        cfg=recursive_cfg,
        label=f"main:{recursive_profile}",
        params=params,
        M=M,
        D=D,
        layers=layers,
    )

    print("=== Recursive Log (compact) ===")
    for row in recursive_logs:
        print(
            f"block={row['block']}, idx=[{row['i0']},{row['i1']}], steps={row['steps']}, "
            f"terminal={row['terminal_mode']}, eval_loss={row['eval_loss']:.3e}, "
            f"eval_y0={row['eval_y0']:.3f}, exact_y0={row['exact_eval_y0']:.3f}, "
            f"delta={row['eval_y0'] - row['exact_eval_y0']:.3f}"
        )

    model = recursive_model_t0

    M_plot = model.M
    N_plot = model.N

    t_test, W_test = model.fetch_minibatch()
    X_pred, Y_pred, Z_pred = model.predict(model.Xi, t_test, W_test, const_value=1.0)

    Xi_reshaped = X_pred.reshape(-1, D)
    Y_exact = u_exact_np(params, Xi_reshaped).reshape(M_plot, N_plot + 1, 1)
    Z_exact = z_exact_np(params, Xi_reshaped).reshape(M_plot, N_plot + 1, D)

    pred_y0_mean = float(np.mean(Y_pred[:, 0, 0]))
    pred_y0_std = float(np.std(Y_pred[:, 0, 0]))
    exact_y0 = float(u_exact_np(params, model.Xi[:1])[0, 0])

    print(f"\nPredicted Y0 mean: {pred_y0_mean:.4f} (std {pred_y0_std:.4f})")
    print(f"Predicted Y0 path0: {Y_pred[0,0,0]:.4f}")
    print(f"Exact Y0:           {exact_y0:.4f}")

    n_show = min(5, M_plot)
    plt.figure(figsize=(10, 6))
    plt.plot(t_test[0, :, 0], Y_pred[0, :, 0], "b", label="Learned Y")
    plt.plot(t_test[0, :, 0], Y_exact[0, :, 0], "r--", label="Exact Y")
    if n_show > 1:
        plt.plot(t_test[1:n_show, :, 0].T, Y_pred[1:n_show, :, 0].T, "b", alpha=0.7)
        plt.plot(t_test[1:n_show, :, 0].T, Y_exact[1:n_show, :, 0].T, "r--", alpha=0.7)
    plt.title(f"Soluzione 4D - blocco iniziale modello (N={N_plot})")
    plt.xlabel("Tempo t")
    plt.ylabel("Y_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    eps = 1e-8
    rel_err_Z = np.abs((Z_pred - Z_exact) / (np.abs(Z_exact) + eps))
    abs_err_Z = np.abs(Z_pred - Z_exact)

    mean_rel_err_Z = np.mean(rel_err_Z, axis=0)
    mean_abs_err_Z = np.mean(abs_err_Z, axis=0)

    z_scale = np.mean(np.abs(Z_exact), axis=(0, 1))
    near_zero_target = z_scale < 1e-5

    labels = ["Z_S", "Z_H", "Z_V", "Z_X"]
    colors = ["b", "g", "r", "m"]

    plt.figure(figsize=(10, 6))
    for d_idx in range(D):
        if near_zero_target[d_idx]:
            plt.plot(
                t_test[0, :, 0],
                mean_abs_err_Z[:, d_idx],
                colors[d_idx],
                label=f"Mean Abs Error {labels[d_idx]}",
            )
        else:
            plt.plot(
                t_test[0, :, 0],
                mean_rel_err_Z[:, d_idx],
                colors[d_idx],
                label=f"Mean Rel Error {labels[d_idx]}",
            )
    plt.yscale("log")
    plt.title("Errore medio di Z (metrica mista rel/abs, scala log)")
    plt.xlabel("Tempo t")
    plt.ylabel("Errore medio")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # Consiglio pratico: se il terminal block resta dominante, alza terminal_y_loss_weight
    # e terminal_iters_multiplier nel profilo scelto.
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# === Recursive training (backward in time) ===
# [RecursiveConfig] label=main:stable, N_total=480, n_blocks=30 (req=30), min_steps_per_block=10, terminal_min_steps=24, iters_per_block=220, lr=1.2e-04, warm_start=True, train_scen=4, eval_scen=2
# [RecursivePartition] label=main:stable, steps=[10, 14, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 24]
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=29, idx=[456,480], steps=24, terminal=g, iters=1320, lr=4.8e-05
# [TerminalSchedule] main:stable b=29: stage1(iters=528, lr=9.6e-05), stage2(iters=792, lr=4.8e-05)
# It: 0, Loss: 1.439e+06, Y0_mean: -0.062, Y0_std: 0.503, Time: 4.77, Learning Rate: 9.600e-05
# It: 10, Loss: 1.490e+06, Y0_mean: -0.500, Y0_std: 1.073, Time: 0.45, Learning Rate: 9.600e-05
# It: 20, Loss: 1.425e+06, Y0_mean: -1.036, Y0_std: 2.005, Time: 0.45, Learning Rate: 9.600e-05
# It: 30, Loss: 1.471e+06, Y0_mean: -1.678, Y0_std: 3.268, Time: 0.45, Learning Rate: 9.600e-05
# It: 40, Loss: 1.459e+06, Y0_mean: -2.410, Y0_std: 5.078, Time: 0.44, Learning Rate: 9.600e-05
# It: 50, Loss: 1.347e+06, Y0_mean: -3.157, Y0_std: 7.108, Time: 0.44, Learning Rate: 9.600e-05
# It: 60, Loss: 1.422e+06, Y0_mean: -3.425, Y0_std: 9.739, Time: 0.44, Learning Rate: 9.600e-05
# It: 70, Loss: 1.406e+06, Y0_mean: -3.360, Y0_std: 12.077, Time: 0.44, Learning Rate: 9.600e-05
# It: 80, Loss: 1.396e+06, Y0_mean: -3.172, Y0_std: 13.929, Time: 0.46, Learning Rate: 9.600e-05
# It: 90, Loss: 1.389e+06, Y0_mean: -3.065, Y0_std: 15.175, Time: 0.44, Learning Rate: 9.600e-05
# It: 100, Loss: 1.325e+06, Y0_mean: -3.186, Y0_std: 16.036, Time: 0.44, Learning Rate: 9.600e-05
# It: 110, Loss: 1.322e+06, Y0_mean: -3.244, Y0_std: 16.600, Time: 0.45, Learning Rate: 9.600e-05
# It: 120, Loss: 1.378e+06, Y0_mean: -3.191, Y0_std: 17.004, Time: 0.46, Learning Rate: 9.600e-05
# It: 130, Loss: 1.373e+06, Y0_mean: -3.622, Y0_std: 17.330, Time: 0.46, Learning Rate: 9.600e-05
# It: 140, Loss: 1.281e+06, Y0_mean: -3.947, Y0_std: 17.634, Time: 0.45, Learning Rate: 9.600e-05
# It: 150, Loss: 1.368e+06, Y0_mean: -3.797, Y0_std: 18.064, Time: 0.45, Learning Rate: 9.600e-05
# It: 160, Loss: 1.276e+06, Y0_mean: -4.111, Y0_std: 18.334, Time: 0.44, Learning Rate: 9.600e-05
# It: 170, Loss: 1.274e+06, Y0_mean: -4.179, Y0_std: 18.667, Time: 0.45, Learning Rate: 9.600e-05
# It: 180, Loss: 1.305e+06, Y0_mean: -3.769, Y0_std: 19.215, Time: 0.45, Learning Rate: 9.600e-05
# It: 190, Loss: 1.361e+06, Y0_mean: -3.652, Y0_std: 19.474, Time: 0.45, Learning Rate: 9.600e-05
# It: 200, Loss: 1.300e+06, Y0_mean: -3.896, Y0_std: 19.841, Time: 0.44, Learning Rate: 9.600e-05
# It: 210, Loss: 1.298e+06, Y0_mean: -3.958, Y0_std: 20.145, Time: 0.45, Learning Rate: 9.600e-05
# It: 220, Loss: 1.264e+06, Y0_mean: -4.523, Y0_std: 20.206, Time: 0.46, Learning Rate: 9.600e-05
# It: 230, Loss: 1.352e+06, Y0_mean: -4.320, Y0_std: 20.578, Time: 0.45, Learning Rate: 9.600e-05
# It: 240, Loss: 1.351e+06, Y0_mean: -3.941, Y0_std: 20.966, Time: 0.45, Learning Rate: 9.600e-05
# It: 250, Loss: 1.291e+06, Y0_mean: -4.179, Y0_std: 21.317, Time: 0.45, Learning Rate: 9.600e-05
# It: 260, Loss: 1.257e+06, Y0_mean: -4.770, Y0_std: 21.351, Time: 0.46, Learning Rate: 9.600e-05
# It: 270, Loss: 1.255e+06, Y0_mean: -4.842, Y0_std: 21.626, Time: 0.45, Learning Rate: 9.600e-05
# It: 280, Loss: 1.253e+06, Y0_mean: -4.906, Y0_std: 21.900, Time: 0.45, Learning Rate: 9.600e-05
# It: 290, Loss: 1.342e+06, Y0_mean: -4.211, Y0_std: 22.362, Time: 0.45, Learning Rate: 9.600e-05
# It: 300, Loss: 1.250e+06, Y0_mean: -5.014, Y0_std: 22.447, Time: 0.45, Learning Rate: 9.600e-05
# It: 310, Loss: 1.248e+06, Y0_mean: -5.074, Y0_std: 22.716, Time: 0.46, Learning Rate: 9.600e-05
# It: 320, Loss: 1.337e+06, Y0_mean: -4.357, Y0_std: 23.176, Time: 0.45, Learning Rate: 9.600e-05
# It: 330, Loss: 1.244e+06, Y0_mean: -5.211, Y0_std: 23.239, Time: 0.44, Learning Rate: 9.600e-05
# It: 340, Loss: 1.333e+06, Y0_mean: -4.458, Y0_std: 23.704, Time: 0.44, Learning Rate: 9.600e-05
# It: 350, Loss: 1.330e+06, Y0_mean: -5.010, Y0_std: 23.856, Time: 0.45, Learning Rate: 9.600e-05
# It: 360, Loss: 1.239e+06, Y0_mean: -5.377, Y0_std: 24.021, Time: 0.45, Learning Rate: 9.600e-05
# It: 370, Loss: 1.238e+06, Y0_mean: -5.445, Y0_std: 24.276, Time: 0.45, Learning Rate: 9.600e-05
# It: 380, Loss: 1.326e+06, Y0_mean: -4.669, Y0_std: 24.738, Time: 0.44, Learning Rate: 9.600e-05
# It: 390, Loss: 1.324e+06, Y0_mean: -4.724, Y0_std: 24.993, Time: 0.46, Learning Rate: 9.600e-05
# It: 400, Loss: 1.321e+06, Y0_mean: -5.291, Y0_std: 25.135, Time: 0.44, Learning Rate: 9.600e-05
# It: 410, Loss: 1.231e+06, Y0_mean: -5.666, Y0_std: 25.292, Time: 0.44, Learning Rate: 9.600e-05
# It: 420, Loss: 1.261e+06, Y0_mean: -5.109, Y0_std: 25.834, Time: 0.44, Learning Rate: 9.600e-05
# It: 430, Loss: 1.259e+06, Y0_mean: -5.156, Y0_std: 26.083, Time: 0.45, Learning Rate: 9.600e-05
# It: 440, Loss: 1.226e+06, Y0_mean: -5.843, Y0_std: 26.024, Time: 0.44, Learning Rate: 9.600e-05
# It: 450, Loss: 1.313e+06, Y0_mean: -5.577, Y0_std: 26.369, Time: 0.44, Learning Rate: 9.600e-05
# It: 460, Loss: 1.254e+06, Y0_mean: -5.308, Y0_std: 26.828, Time: 0.44, Learning Rate: 9.600e-05
# It: 470, Loss: 1.252e+06, Y0_mean: -5.321, Y0_std: 27.088, Time: 0.44, Learning Rate: 9.600e-05
# It: 480, Loss: 1.220e+06, Y0_mean: -6.056, Y0_std: 27.006, Time: 0.45, Learning Rate: 9.600e-05
# It: 490, Loss: 1.249e+06, Y0_mean: -5.449, Y0_std: 27.573, Time: 0.44, Learning Rate: 9.600e-05
# It: 500, Loss: 1.247e+06, Y0_mean: -5.512, Y0_std: 27.812, Time: 0.46, Learning Rate: 9.600e-05
# It: 510, Loss: 1.246e+06, Y0_mean: -5.559, Y0_std: 28.050, Time: 0.45, Learning Rate: 9.600e-05
# It: 520, Loss: 1.213e+06, Y0_mean: -6.262, Y0_std: 27.966, Time: 0.45, Learning Rate: 9.600e-05
# It: 0, Loss: 1.301e+06, Y0_mean: -5.393, Y0_std: 28.378, Time: 0.04, Learning Rate: 4.800e-05
# It: 10, Loss: 1.301e+06, Y0_mean: -5.430, Y0_std: 28.493, Time: 0.45, Learning Rate: 4.800e-05
# It: 20, Loss: 1.211e+06, Y0_mean: -6.394, Y0_std: 28.374, Time: 0.44, Learning Rate: 4.800e-05
# It: 30, Loss: 1.210e+06, Y0_mean: -6.415, Y0_std: 28.491, Time: 0.46, Learning Rate: 4.800e-05
# It: 40, Loss: 1.240e+06, Y0_mean: -5.743, Y0_std: 28.955, Time: 0.44, Learning Rate: 4.800e-05
# It: 50, Loss: 1.297e+06, Y0_mean: -5.534, Y0_std: 28.960, Time: 0.44, Learning Rate: 4.800e-05
# It: 60, Loss: 1.238e+06, Y0_mean: -5.794, Y0_std: 29.194, Time: 0.45, Learning Rate: 4.800e-05
# It: 70, Loss: 1.296e+06, Y0_mean: -5.584, Y0_std: 29.199, Time: 0.45, Learning Rate: 4.800e-05
# It: 80, Loss: 1.206e+06, Y0_mean: -6.543, Y0_std: 29.076, Time: 0.45, Learning Rate: 4.800e-05
# It: 90, Loss: 1.294e+06, Y0_mean: -5.631, Y0_std: 29.434, Time: 0.45, Learning Rate: 4.800e-05
# It: 100, Loss: 1.204e+06, Y0_mean: -6.597, Y0_std: 29.314, Time: 0.45, Learning Rate: 4.800e-05
# It: 110, Loss: 1.292e+06, Y0_mean: -6.239, Y0_std: 29.549, Time: 0.45, Learning Rate: 4.800e-05
# It: 120, Loss: 1.291e+06, Y0_mean: -6.276, Y0_std: 29.663, Time: 0.44, Learning Rate: 4.800e-05
# It: 130, Loss: 1.291e+06, Y0_mean: -5.731, Y0_std: 29.902, Time: 0.44, Learning Rate: 4.800e-05
# It: 140, Loss: 1.232e+06, Y0_mean: -5.982, Y0_std: 30.142, Time: 0.44, Learning Rate: 4.800e-05
# It: 150, Loss: 1.201e+06, Y0_mean: -6.714, Y0_std: 29.891, Time: 0.45, Learning Rate: 4.800e-05
# It: 160, Loss: 1.200e+06, Y0_mean: -6.754, Y0_std: 30.002, Time: 0.44, Learning Rate: 4.800e-05
# It: 170, Loss: 1.288e+06, Y0_mean: -5.826, Y0_std: 30.363, Time: 0.45, Learning Rate: 4.800e-05
# It: 180, Loss: 1.287e+06, Y0_mean: -5.849, Y0_std: 30.481, Time: 0.44, Learning Rate: 4.800e-05
# It: 190, Loss: 1.198e+06, Y0_mean: -6.832, Y0_std: 30.349, Time: 0.44, Learning Rate: 4.800e-05
# It: 200, Loss: 1.197e+06, Y0_mean: -6.841, Y0_std: 30.470, Time: 0.44, Learning Rate: 4.800e-05
# It: 210, Loss: 1.226e+06, Y0_mean: -6.159, Y0_std: 30.960, Time: 0.45, Learning Rate: 4.800e-05
# It: 220, Loss: 1.284e+06, Y0_mean: -5.961, Y0_std: 30.936, Time: 0.45, Learning Rate: 4.800e-05
# It: 230, Loss: 1.282e+06, Y0_mean: -6.540, Y0_std: 30.931, Time: 0.44, Learning Rate: 4.800e-05
# It: 240, Loss: 1.194e+06, Y0_mean: -6.963, Y0_std: 30.920, Time: 0.44, Learning Rate: 4.800e-05
# It: 250, Loss: 1.281e+06, Y0_mean: -6.600, Y0_std: 31.156, Time: 0.44, Learning Rate: 4.800e-05
# It: 260, Loss: 1.192e+06, Y0_mean: -7.035, Y0_std: 31.138, Time: 0.46, Learning Rate: 4.800e-05
# It: 270, Loss: 1.279e+06, Y0_mean: -6.646, Y0_std: 31.384, Time: 0.44, Learning Rate: 4.800e-05
# It: 280, Loss: 1.278e+06, Y0_mean: -6.684, Y0_std: 31.495, Time: 0.45, Learning Rate: 4.800e-05
# It: 290, Loss: 1.278e+06, Y0_mean: -6.133, Y0_std: 31.733, Time: 0.45, Learning Rate: 4.800e-05
# It: 300, Loss: 1.219e+06, Y0_mean: -6.373, Y0_std: 31.994, Time: 0.44, Learning Rate: 4.800e-05
# It: 310, Loss: 1.276e+06, Y0_mean: -6.733, Y0_std: 31.838, Time: 0.44, Learning Rate: 4.800e-05
# It: 320, Loss: 1.218e+06, Y0_mean: -6.430, Y0_std: 32.224, Time: 0.45, Learning Rate: 4.800e-05
# It: 330, Loss: 1.275e+06, Y0_mean: -6.226, Y0_std: 32.186, Time: 0.45, Learning Rate: 4.800e-05
# It: 340, Loss: 1.186e+06, Y0_mean: -7.228, Y0_std: 32.045, Time: 0.45, Learning Rate: 4.800e-05
# It: 350, Loss: 1.186e+06, Y0_mean: -7.276, Y0_std: 32.154, Time: 0.44, Learning Rate: 4.800e-05
# It: 360, Loss: 1.185e+06, Y0_mean: -7.278, Y0_std: 32.276, Time: 0.45, Learning Rate: 4.800e-05
# It: 370, Loss: 1.271e+06, Y0_mean: -6.882, Y0_std: 32.525, Time: 0.45, Learning Rate: 4.800e-05
# It: 380, Loss: 1.271e+06, Y0_mean: -6.906, Y0_std: 32.634, Time: 0.44, Learning Rate: 4.800e-05
# It: 390, Loss: 1.183e+06, Y0_mean: -7.344, Y0_std: 32.610, Time: 0.44, Learning Rate: 4.800e-05
# It: 400, Loss: 1.211e+06, Y0_mean: -6.632, Y0_std: 33.140, Time: 0.44, Learning Rate: 4.800e-05
# It: 410, Loss: 1.269e+06, Y0_mean: -6.424, Y0_std: 33.092, Time: 0.45, Learning Rate: 4.800e-05
# It: 420, Loss: 1.210e+06, Y0_mean: -6.655, Y0_std: 33.367, Time: 0.45, Learning Rate: 4.800e-05
# It: 430, Loss: 1.180e+06, Y0_mean: -7.475, Y0_std: 33.051, Time: 0.45, Learning Rate: 4.800e-05
# It: 440, Loss: 1.266e+06, Y0_mean: -7.027, Y0_std: 33.322, Time: 0.44, Learning Rate: 4.800e-05
# It: 450, Loss: 1.178e+06, Y0_mean: -7.498, Y0_std: 33.292, Time: 0.44, Learning Rate: 4.800e-05
# It: 460, Loss: 1.207e+06, Y0_mean: -6.746, Y0_std: 33.840, Time: 0.45, Learning Rate: 4.800e-05
# It: 470, Loss: 1.177e+06, Y0_mean: -7.575, Y0_std: 33.506, Time: 0.45, Learning Rate: 4.800e-05
# It: 480, Loss: 1.205e+06, Y0_mean: -6.782, Y0_std: 34.068, Time: 0.45, Learning Rate: 4.800e-05
# It: 490, Loss: 1.205e+06, Y0_mean: -6.823, Y0_std: 34.174, Time: 0.45, Learning Rate: 4.800e-05
# It: 500, Loss: 1.262e+06, Y0_mean: -6.646, Y0_std: 34.108, Time: 0.44, Learning Rate: 4.800e-05
# It: 510, Loss: 1.203e+06, Y0_mean: -6.854, Y0_std: 34.411, Time: 0.44, Learning Rate: 4.800e-05
# It: 520, Loss: 1.260e+06, Y0_mean: -7.256, Y0_std: 34.217, Time: 0.45, Learning Rate: 4.800e-05
# It: 530, Loss: 1.260e+06, Y0_mean: -6.721, Y0_std: 34.443, Time: 0.44, Learning Rate: 4.800e-05
# It: 540, Loss: 1.172e+06, Y0_mean: -7.709, Y0_std: 34.301, Time: 0.44, Learning Rate: 4.800e-05
# It: 550, Loss: 1.258e+06, Y0_mean: -6.739, Y0_std: 34.693, Time: 0.45, Learning Rate: 4.800e-05
# It: 560, Loss: 1.199e+06, Y0_mean: -6.990, Y0_std: 34.978, Time: 0.45, Learning Rate: 4.800e-05
# It: 570, Loss: 1.199e+06, Y0_mean: -6.998, Y0_std: 35.090, Time: 0.45, Learning Rate: 4.800e-05
# It: 580, Loss: 1.256e+06, Y0_mean: -6.821, Y0_std: 35.009, Time: 0.44, Learning Rate: 4.800e-05
# It: 590, Loss: 1.197e+06, Y0_mean: -7.041, Y0_std: 35.313, Time: 0.44, Learning Rate: 4.800e-05
# It: 600, Loss: 1.254e+06, Y0_mean: -7.434, Y0_std: 35.117, Time: 0.44, Learning Rate: 4.800e-05
# It: 610, Loss: 1.196e+06, Y0_mean: -7.083, Y0_std: 35.544, Time: 0.44, Learning Rate: 4.800e-05
# It: 620, Loss: 1.252e+06, Y0_mean: -7.463, Y0_std: 35.344, Time: 0.44, Learning Rate: 4.800e-05
# It: 630, Loss: 1.252e+06, Y0_mean: -6.946, Y0_std: 35.582, Time: 0.44, Learning Rate: 4.800e-05
# It: 640, Loss: 1.164e+06, Y0_mean: -7.977, Y0_std: 35.416, Time: 0.44, Learning Rate: 4.800e-05
# It: 650, Loss: 1.251e+06, Y0_mean: -6.991, Y0_std: 35.798, Time: 0.44, Learning Rate: 4.800e-05
# It: 660, Loss: 1.163e+06, Y0_mean: -8.035, Y0_std: 35.630, Time: 0.44, Learning Rate: 4.800e-05
# It: 670, Loss: 1.249e+06, Y0_mean: -7.001, Y0_std: 36.038, Time: 0.44, Learning Rate: 4.800e-05
# It: 680, Loss: 1.249e+06, Y0_mean: -7.043, Y0_std: 36.150, Time: 0.44, Learning Rate: 4.800e-05
# It: 690, Loss: 1.190e+06, Y0_mean: -7.288, Y0_std: 36.455, Time: 0.45, Learning Rate: 4.800e-05
# It: 700, Loss: 1.189e+06, Y0_mean: -7.322, Y0_std: 36.558, Time: 0.44, Learning Rate: 4.800e-05
# It: 710, Loss: 1.246e+06, Y0_mean: -7.152, Y0_std: 36.457, Time: 0.44, Learning Rate: 4.800e-05
# It: 720, Loss: 1.187e+06, Y0_mean: -7.327, Y0_std: 36.788, Time: 0.44, Learning Rate: 4.800e-05
# It: 730, Loss: 1.244e+06, Y0_mean: -7.738, Y0_std: 36.567, Time: 0.44, Learning Rate: 4.800e-05
# It: 740, Loss: 1.157e+06, Y0_mean: -8.238, Y0_std: 36.506, Time: 0.44, Learning Rate: 4.800e-05
# It: 750, Loss: 1.185e+06, Y0_mean: -7.441, Y0_std: 37.113, Time: 0.44, Learning Rate: 4.800e-05
# It: 760, Loss: 1.242e+06, Y0_mean: -7.782, Y0_std: 36.896, Time: 0.44, Learning Rate: 4.800e-05
# It: 770, Loss: 1.242e+06, Y0_mean: -7.244, Y0_std: 37.131, Time: 0.45, Learning Rate: 4.800e-05
# It: 780, Loss: 1.183e+06, Y0_mean: -7.505, Y0_std: 37.452, Time: 0.46, Learning Rate: 4.800e-05
# It: 790, Loss: 1.182e+06, Y0_mean: -7.544, Y0_std: 37.560, Time: 0.44, Learning Rate: 4.800e-05
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=28, idx=[440,456], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 1.189e+02, Y0_mean: -7.625, Y0_std: 36.917, Time: 2.91, Learning Rate: 1.200e-04
# It: 10, Loss: 1.176e+02, Y0_mean: -7.799, Y0_std: 37.137, Time: 0.30, Learning Rate: 1.200e-04
# It: 20, Loss: 1.065e+02, Y0_mean: -8.559, Y0_std: 36.708, Time: 0.30, Learning Rate: 1.200e-04
# It: 30, Loss: 1.063e+02, Y0_mean: -8.711, Y0_std: 36.739, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 1.068e+02, Y0_mean: -8.725, Y0_std: 36.658, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 1.166e+02, Y0_mean: -7.483, Y0_std: 37.105, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 1.165e+02, Y0_mean: -7.626, Y0_std: 37.292, Time: 0.30, Learning Rate: 1.200e-04
# It: 70, Loss: 1.060e+02, Y0_mean: -8.653, Y0_std: 36.747, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 1.174e+02, Y0_mean: -7.986, Y0_std: 37.031, Time: 0.30, Learning Rate: 1.200e-04
# It: 90, Loss: 1.176e+02, Y0_mean: -7.976, Y0_std: 36.948, Time: 0.30, Learning Rate: 1.200e-04
# It: 100, Loss: 1.178e+02, Y0_mean: -8.029, Y0_std: 36.898, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 1.163e+02, Y0_mean: -7.545, Y0_std: 36.991, Time: 0.31, Learning Rate: 1.200e-04
# It: 120, Loss: 1.176e+02, Y0_mean: -7.925, Y0_std: 36.962, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 1.060e+02, Y0_mean: -8.587, Y0_std: 36.698, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 1.165e+02, Y0_mean: -7.732, Y0_std: 37.257, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 1.161e+02, Y0_mean: -7.537, Y0_std: 37.031, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 1.173e+02, Y0_mean: -7.927, Y0_std: 37.003, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 1.064e+02, Y0_mean: -8.632, Y0_std: 36.596, Time: 0.31, Learning Rate: 1.200e-04
# It: 180, Loss: 1.177e+02, Y0_mean: -8.006, Y0_std: 36.899, Time: 0.30, Learning Rate: 1.200e-04
# It: 190, Loss: 1.070e+02, Y0_mean: -8.580, Y0_std: 36.574, Time: 0.31, Learning Rate: 1.200e-04
# It: 200, Loss: 1.165e+02, Y0_mean: -7.491, Y0_std: 37.006, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 1.176e+02, Y0_mean: -7.970, Y0_std: 36.897, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=27, idx=[424,440], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 9.443e+01, Y0_mean: -7.829, Y0_std: 36.306, Time: 2.96, Learning Rate: 1.200e-04
# It: 10, Loss: 9.289e+01, Y0_mean: -8.668, Y0_std: 36.255, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 9.015e+01, Y0_mean: -8.793, Y0_std: 36.148, Time: 0.30, Learning Rate: 1.200e-04
# It: 30, Loss: 9.326e+01, Y0_mean: -7.899, Y0_std: 36.505, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 9.031e+01, Y0_mean: -8.936, Y0_std: 36.110, Time: 0.31, Learning Rate: 1.200e-04
# It: 50, Loss: 9.829e+01, Y0_mean: -7.774, Y0_std: 36.755, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 9.203e+01, Y0_mean: -7.750, Y0_std: 36.548, Time: 0.30, Learning Rate: 1.200e-04
# It: 70, Loss: 9.875e+01, Y0_mean: -7.966, Y0_std: 36.705, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 9.777e+01, Y0_mean: -7.895, Y0_std: 36.706, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 9.439e+01, Y0_mean: -7.978, Y0_std: 36.549, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 9.366e+01, Y0_mean: -8.037, Y0_std: 36.544, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 9.845e+01, Y0_mean: -7.946, Y0_std: 36.719, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 9.365e+01, Y0_mean: -8.106, Y0_std: 36.497, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 9.115e+01, Y0_mean: -8.739, Y0_std: 36.140, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 9.012e+01, Y0_mean: -8.809, Y0_std: 36.097, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 9.451e+01, Y0_mean: -8.171, Y0_std: 36.497, Time: 0.31, Learning Rate: 1.200e-04
# It: 160, Loss: 9.217e+01, Y0_mean: -7.800, Y0_std: 36.559, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 9.452e+01, Y0_mean: -7.966, Y0_std: 36.511, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 9.802e+01, Y0_mean: -7.813, Y0_std: 36.623, Time: 0.31, Learning Rate: 1.200e-04
# It: 190, Loss: 9.405e+01, Y0_mean: -8.083, Y0_std: 36.630, Time: 0.31, Learning Rate: 1.200e-04
# It: 200, Loss: 9.780e+01, Y0_mean: -7.893, Y0_std: 36.712, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 9.773e+01, Y0_mean: -7.824, Y0_std: 36.762, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=26, idx=[408,424], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 1.073e+02, Y0_mean: -8.050, Y0_std: 35.545, Time: 3.00, Learning Rate: 1.200e-04
# It: 10, Loss: 1.053e+02, Y0_mean: -8.103, Y0_std: 36.012, Time: 0.30, Learning Rate: 1.200e-04
# It: 20, Loss: 8.402e+01, Y0_mean: -9.192, Y0_std: 35.372, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 7.333e+01, Y0_mean: -8.181, Y0_std: 35.656, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 8.777e+01, Y0_mean: -8.081, Y0_std: 35.669, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 1.045e+02, Y0_mean: -8.057, Y0_std: 35.942, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 7.363e+01, Y0_mean: -8.170, Y0_std: 35.730, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 1.045e+02, Y0_mean: -8.049, Y0_std: 35.889, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 7.325e+01, Y0_mean: -8.284, Y0_std: 35.657, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 8.808e+01, Y0_mean: -7.982, Y0_std: 35.723, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 1.045e+02, Y0_mean: -8.053, Y0_std: 35.892, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 8.784e+01, Y0_mean: -8.092, Y0_std: 35.685, Time: 0.31, Learning Rate: 1.200e-04
# It: 120, Loss: 7.350e+01, Y0_mean: -8.170, Y0_std: 35.694, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 1.045e+02, Y0_mean: -8.045, Y0_std: 35.873, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 8.786e+01, Y0_mean: -8.095, Y0_std: 35.688, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 8.804e+01, Y0_mean: -7.980, Y0_std: 35.689, Time: 0.31, Learning Rate: 1.200e-04
# It: 160, Loss: 1.045e+02, Y0_mean: -8.052, Y0_std: 35.895, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 7.326e+01, Y0_mean: -8.285, Y0_std: 35.641, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 8.411e+01, Y0_mean: -9.028, Y0_std: 35.247, Time: 0.31, Learning Rate: 1.200e-04
# It: 190, Loss: 8.381e+01, Y0_mean: -9.140, Y0_std: 35.226, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 8.388e+01, Y0_mean: -9.154, Y0_std: 35.210, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 7.343e+01, Y0_mean: -8.159, Y0_std: 35.643, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=25, idx=[392,408], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 7.509e+01, Y0_mean: -8.436, Y0_std: 33.665, Time: 3.06, Learning Rate: 1.200e-04
# It: 10, Loss: 8.002e+01, Y0_mean: -9.282, Y0_std: 33.869, Time: 0.30, Learning Rate: 1.200e-04
# It: 20, Loss: 7.895e+01, Y0_mean: -9.347, Y0_std: 33.815, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 7.913e+01, Y0_mean: -9.475, Y0_std: 33.748, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 8.555e+01, Y0_mean: -8.313, Y0_std: 34.444, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 7.917e+01, Y0_mean: -9.320, Y0_std: 33.803, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 8.557e+01, Y0_mean: -8.311, Y0_std: 34.368, Time: 0.30, Learning Rate: 1.200e-04
# It: 70, Loss: 7.895e+01, Y0_mean: -9.463, Y0_std: 33.781, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 7.913e+01, Y0_mean: -9.308, Y0_std: 33.778, Time: 0.30, Learning Rate: 1.200e-04
# It: 90, Loss: 8.553e+01, Y0_mean: -8.297, Y0_std: 34.368, Time: 0.30, Learning Rate: 1.200e-04
# It: 100, Loss: 9.395e+01, Y0_mean: -8.415, Y0_std: 34.224, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 7.183e+01, Y0_mean: -8.369, Y0_std: 34.180, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 8.553e+01, Y0_mean: -8.288, Y0_std: 34.333, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 8.558e+01, Y0_mean: -8.300, Y0_std: 34.355, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 9.416e+01, Y0_mean: -8.268, Y0_std: 34.269, Time: 0.31, Learning Rate: 1.200e-04
# It: 150, Loss: 9.388e+01, Y0_mean: -8.373, Y0_std: 34.141, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 9.389e+01, Y0_mean: -8.396, Y0_std: 34.198, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 8.549e+01, Y0_mean: -8.264, Y0_std: 34.388, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 9.412e+01, Y0_mean: -8.339, Y0_std: 34.369, Time: 0.31, Learning Rate: 1.200e-04
# It: 190, Loss: 7.871e+01, Y0_mean: -9.364, Y0_std: 33.732, Time: 0.31, Learning Rate: 1.200e-04
# It: 200, Loss: 7.154e+01, Y0_mean: -8.434, Y0_std: 34.047, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 7.876e+01, Y0_mean: -9.363, Y0_std: 33.661, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=24, idx=[376,392], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 7.358e+01, Y0_mean: -9.277, Y0_std: 30.988, Time: 3.10, Learning Rate: 1.200e-04
# It: 10, Loss: 7.312e+01, Y0_mean: -8.446, Y0_std: 31.939, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 6.781e+01, Y0_mean: -9.474, Y0_std: 31.593, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 6.641e+01, Y0_mean: -8.367, Y0_std: 32.157, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 6.784e+01, Y0_mean: -9.367, Y0_std: 31.468, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 7.302e+01, Y0_mean: -8.489, Y0_std: 32.221, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 8.509e+01, Y0_mean: -8.388, Y0_std: 32.006, Time: 0.30, Learning Rate: 1.200e-04
# It: 70, Loss: 8.498e+01, Y0_mean: -8.464, Y0_std: 31.935, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 7.290e+01, Y0_mean: -8.383, Y0_std: 32.116, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 7.278e+01, Y0_mean: -8.463, Y0_std: 32.055, Time: 0.30, Learning Rate: 1.200e-04
# It: 100, Loss: 6.769e+01, Y0_mean: -9.386, Y0_std: 31.534, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 6.636e+01, Y0_mean: -8.384, Y0_std: 32.028, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 6.768e+01, Y0_mean: -9.377, Y0_std: 31.505, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 8.500e+01, Y0_mean: -8.453, Y0_std: 31.880, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 6.636e+01, Y0_mean: -8.271, Y0_std: 32.042, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 6.768e+01, Y0_mean: -9.466, Y0_std: 31.485, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 6.773e+01, Y0_mean: -9.343, Y0_std: 31.462, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 6.770e+01, Y0_mean: -9.464, Y0_std: 31.459, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 6.767e+01, Y0_mean: -9.355, Y0_std: 31.470, Time: 0.30, Learning Rate: 1.200e-04
# It: 190, Loss: 7.279e+01, Y0_mean: -8.420, Y0_std: 31.955, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 6.634e+01, Y0_mean: -8.232, Y0_std: 32.003, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 6.636e+01, Y0_mean: -8.326, Y0_std: 31.929, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=23, idx=[360,376], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 7.864e+01, Y0_mean: -7.891, Y0_std: 28.248, Time: 3.19, Learning Rate: 1.200e-04
# It: 10, Loss: 6.243e+01, Y0_mean: -9.123, Y0_std: 28.138, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 6.435e+01, Y0_mean: -8.186, Y0_std: 28.629, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 5.885e+01, Y0_mean: -8.214, Y0_std: 28.722, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 7.420e+01, Y0_mean: -8.151, Y0_std: 28.645, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 5.868e+01, Y0_mean: -8.122, Y0_std: 28.798, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 6.176e+01, Y0_mean: -9.208, Y0_std: 28.239, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 7.418e+01, Y0_mean: -8.189, Y0_std: 28.542, Time: 0.30, Learning Rate: 1.200e-04
# It: 80, Loss: 5.867e+01, Y0_mean: -8.120, Y0_std: 28.719, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 7.410e+01, Y0_mean: -8.140, Y0_std: 28.568, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 7.418e+01, Y0_mean: -8.097, Y0_std: 28.652, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 5.876e+01, Y0_mean: -8.222, Y0_std: 28.838, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 6.186e+01, Y0_mean: -9.108, Y0_std: 28.376, Time: 0.31, Learning Rate: 1.200e-04
# It: 130, Loss: 7.431e+01, Y0_mean: -8.133, Y0_std: 28.772, Time: 0.31, Learning Rate: 1.200e-04
# It: 140, Loss: 7.476e+01, Y0_mean: -8.071, Y0_std: 28.707, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 6.451e+01, Y0_mean: -8.122, Y0_std: 28.501, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 5.872e+01, Y0_mean: -8.253, Y0_std: 28.807, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 6.412e+01, Y0_mean: -8.150, Y0_std: 28.790, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 7.406e+01, Y0_mean: -8.166, Y0_std: 28.689, Time: 0.32, Learning Rate: 1.200e-04
# It: 190, Loss: 7.469e+01, Y0_mean: -8.202, Y0_std: 28.460, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 6.189e+01, Y0_mean: -9.242, Y0_std: 28.265, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 7.425e+01, Y0_mean: -8.028, Y0_std: 28.519, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=22, idx=[344,360], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 6.783e+01, Y0_mean: -7.466, Y0_std: 24.475, Time: 3.17, Learning Rate: 1.200e-04
# It: 10, Loss: 5.591e+01, Y0_mean: -7.765, Y0_std: 24.390, Time: 0.30, Learning Rate: 1.200e-04
# It: 20, Loss: 6.375e+01, Y0_mean: -7.787, Y0_std: 24.511, Time: 0.30, Learning Rate: 1.200e-04
# It: 30, Loss: 4.689e+01, Y0_mean: -7.918, Y0_std: 24.428, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 6.389e+01, Y0_mean: -7.700, Y0_std: 24.618, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 6.137e+01, Y0_mean: -8.717, Y0_std: 24.090, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 4.686e+01, Y0_mean: -7.817, Y0_std: 24.589, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 5.554e+01, Y0_mean: -7.856, Y0_std: 24.458, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 6.396e+01, Y0_mean: -7.695, Y0_std: 24.696, Time: 0.30, Learning Rate: 1.200e-04
# It: 90, Loss: 6.108e+01, Y0_mean: -8.702, Y0_std: 24.178, Time: 0.30, Learning Rate: 1.200e-04
# It: 100, Loss: 4.682e+01, Y0_mean: -7.974, Y0_std: 24.391, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 6.172e+01, Y0_mean: -8.630, Y0_std: 24.045, Time: 0.31, Learning Rate: 1.200e-04
# It: 120, Loss: 4.663e+01, Y0_mean: -7.955, Y0_std: 24.443, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 4.650e+01, Y0_mean: -7.949, Y0_std: 24.531, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 4.654e+01, Y0_mean: -7.939, Y0_std: 24.450, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 5.551e+01, Y0_mean: -7.849, Y0_std: 24.422, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 5.547e+01, Y0_mean: -7.753, Y0_std: 24.433, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 5.559e+01, Y0_mean: -7.860, Y0_std: 24.368, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 5.583e+01, Y0_mean: -7.678, Y0_std: 24.518, Time: 0.30, Learning Rate: 1.200e-04
# It: 190, Loss: 6.136e+01, Y0_mean: -8.574, Y0_std: 24.069, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 4.832e+01, Y0_mean: -8.186, Y0_std: 24.576, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 5.601e+01, Y0_mean: -7.779, Y0_std: 24.519, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=21, idx=[328,344], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 5.172e+01, Y0_mean: -7.195, Y0_std: 19.807, Time: 3.32, Learning Rate: 1.200e-04
# It: 10, Loss: 5.096e+01, Y0_mean: -7.144, Y0_std: 19.790, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 5.359e+01, Y0_mean: -7.861, Y0_std: 19.325, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 5.049e+01, Y0_mean: -7.191, Y0_std: 19.631, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 4.545e+01, Y0_mean: -7.023, Y0_std: 19.822, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 5.334e+01, Y0_mean: -7.894, Y0_std: 19.465, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 4.568e+01, Y0_mean: -6.981, Y0_std: 19.758, Time: 0.30, Learning Rate: 1.200e-04
# It: 70, Loss: 5.109e+01, Y0_mean: -7.243, Y0_std: 19.923, Time: 0.30, Learning Rate: 1.200e-04
# It: 80, Loss: 4.823e+01, Y0_mean: -7.261, Y0_std: 19.880, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 5.042e+01, Y0_mean: -7.202, Y0_std: 19.809, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 5.037e+01, Y0_mean: -7.184, Y0_std: 19.824, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 5.319e+01, Y0_mean: -7.810, Y0_std: 19.444, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 5.325e+01, Y0_mean: -7.824, Y0_std: 19.539, Time: 0.31, Learning Rate: 1.200e-04
# It: 130, Loss: 4.805e+01, Y0_mean: -7.317, Y0_std: 19.770, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 4.566e+01, Y0_mean: -6.974, Y0_std: 19.922, Time: 0.31, Learning Rate: 1.200e-04
# It: 150, Loss: 5.360e+01, Y0_mean: -7.933, Y0_std: 19.508, Time: 0.31, Learning Rate: 1.200e-04
# It: 160, Loss: 5.349e+01, Y0_mean: -7.827, Y0_std: 19.601, Time: 0.31, Learning Rate: 1.200e-04
# It: 170, Loss: 4.549e+01, Y0_mean: -7.036, Y0_std: 19.779, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 4.554e+01, Y0_mean: -7.040, Y0_std: 19.890, Time: 0.30, Learning Rate: 1.200e-04
# It: 190, Loss: 4.742e+01, Y0_mean: -7.337, Y0_std: 19.719, Time: 0.31, Learning Rate: 1.200e-04
# It: 200, Loss: 5.509e+01, Y0_mean: -7.834, Y0_std: 19.217, Time: 0.31, Learning Rate: 1.200e-04
# It: 210, Loss: 4.601e+01, Y0_mean: -7.190, Y0_std: 19.885, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=20, idx=[312,328], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 4.337e+01, Y0_mean: -6.223, Y0_std: 14.899, Time: 3.31, Learning Rate: 1.200e-04
# It: 10, Loss: 4.187e+01, Y0_mean: -5.926, Y0_std: 14.764, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 3.998e+01, Y0_mean: -5.900, Y0_std: 14.642, Time: 0.30, Learning Rate: 1.200e-04
# It: 30, Loss: 4.074e+01, Y0_mean: -5.889, Y0_std: 14.789, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 4.171e+01, Y0_mean: -6.623, Y0_std: 14.747, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 4.081e+01, Y0_mean: -6.214, Y0_std: 14.884, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 4.035e+01, Y0_mean: -6.188, Y0_std: 14.762, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 3.978e+01, Y0_mean: -5.965, Y0_std: 15.018, Time: 0.30, Learning Rate: 1.200e-04
# It: 80, Loss: 4.036e+01, Y0_mean: -6.459, Y0_std: 14.921, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 3.976e+01, Y0_mean: -6.201, Y0_std: 14.921, Time: 0.30, Learning Rate: 1.200e-04
# It: 100, Loss: 4.069e+01, Y0_mean: -6.180, Y0_std: 14.991, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 3.988e+01, Y0_mean: -6.126, Y0_std: 14.790, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 4.028e+01, Y0_mean: -6.378, Y0_std: 14.930, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 3.955e+01, Y0_mean: -6.171, Y0_std: 14.905, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 3.983e+01, Y0_mean: -6.205, Y0_std: 14.892, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 4.009e+01, Y0_mean: -5.853, Y0_std: 14.886, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 4.012e+01, Y0_mean: -6.021, Y0_std: 14.951, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 3.920e+01, Y0_mean: -6.659, Y0_std: 14.762, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 4.028e+01, Y0_mean: -6.307, Y0_std: 14.937, Time: 0.30, Learning Rate: 1.200e-04
# It: 190, Loss: 3.915e+01, Y0_mean: -6.738, Y0_std: 14.867, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 3.912e+01, Y0_mean: -6.825, Y0_std: 14.800, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 3.940e+01, Y0_mean: -5.954, Y0_std: 14.912, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=19, idx=[296,312], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 4.299e+01, Y0_mean: -5.752, Y0_std: 10.408, Time: 3.39, Learning Rate: 1.200e-04
# It: 10, Loss: 3.488e+01, Y0_mean: -5.421, Y0_std: 10.423, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 3.409e+01, Y0_mean: -5.762, Y0_std: 10.325, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 3.531e+01, Y0_mean: -5.575, Y0_std: 10.508, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 3.549e+01, Y0_mean: -5.624, Y0_std: 10.443, Time: 0.31, Learning Rate: 1.200e-04
# It: 50, Loss: 3.351e+01, Y0_mean: -5.692, Y0_std: 10.546, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 3.350e+01, Y0_mean: -5.701, Y0_std: 10.588, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 3.506e+01, Y0_mean: -5.413, Y0_std: 10.635, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 3.356e+01, Y0_mean: -5.825, Y0_std: 10.591, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 3.365e+01, Y0_mean: -5.641, Y0_std: 10.651, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 3.333e+01, Y0_mean: -5.846, Y0_std: 10.675, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 3.351e+01, Y0_mean: -5.363, Y0_std: 10.635, Time: 0.31, Learning Rate: 1.200e-04
# It: 120, Loss: 3.478e+01, Y0_mean: -5.610, Y0_std: 10.646, Time: 0.31, Learning Rate: 1.200e-04
# It: 130, Loss: 3.481e+01, Y0_mean: -5.420, Y0_std: 10.646, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 3.987e+01, Y0_mean: -5.381, Y0_std: 10.696, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 3.333e+01, Y0_mean: -5.704, Y0_std: 10.621, Time: 0.31, Learning Rate: 1.200e-04
# It: 160, Loss: 3.342e+01, Y0_mean: -5.539, Y0_std: 10.622, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 3.995e+01, Y0_mean: -5.139, Y0_std: 10.721, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 3.326e+01, Y0_mean: -5.876, Y0_std: 10.616, Time: 0.30, Learning Rate: 1.200e-04
# It: 190, Loss: 3.484e+01, Y0_mean: -5.410, Y0_std: 10.662, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 3.489e+01, Y0_mean: -5.633, Y0_std: 10.641, Time: 0.31, Learning Rate: 1.200e-04
# It: 210, Loss: 3.482e+01, Y0_mean: -5.400, Y0_std: 10.672, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=18, idx=[280,296], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 3.430e+01, Y0_mean: -5.023, Y0_std: 8.165, Time: 3.44, Learning Rate: 1.200e-04
# It: 10, Loss: 3.534e+01, Y0_mean: -4.862, Y0_std: 8.459, Time: 0.30, Learning Rate: 1.200e-04
# It: 20, Loss: 2.809e+01, Y0_mean: -4.779, Y0_std: 8.146, Time: 0.32, Learning Rate: 1.200e-04
# It: 30, Loss: 2.824e+01, Y0_mean: -4.516, Y0_std: 8.095, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 2.790e+01, Y0_mean: -4.509, Y0_std: 8.135, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 3.329e+01, Y0_mean: -4.865, Y0_std: 8.353, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 2.747e+01, Y0_mean: -4.629, Y0_std: 8.106, Time: 0.30, Learning Rate: 1.200e-04
# It: 70, Loss: 3.378e+01, Y0_mean: -4.676, Y0_std: 8.276, Time: 0.30, Learning Rate: 1.200e-04
# It: 80, Loss: 2.818e+01, Y0_mean: -4.814, Y0_std: 8.272, Time: 0.30, Learning Rate: 1.200e-04
# It: 90, Loss: 3.310e+01, Y0_mean: -4.345, Y0_std: 8.592, Time: 0.30, Learning Rate: 1.200e-04
# It: 100, Loss: 2.802e+01, Y0_mean: -4.697, Y0_std: 8.350, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 2.771e+01, Y0_mean: -4.628, Y0_std: 8.075, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 2.751e+01, Y0_mean: -4.733, Y0_std: 8.137, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 3.275e+01, Y0_mean: -4.283, Y0_std: 8.458, Time: 0.31, Learning Rate: 1.200e-04
# It: 140, Loss: 2.752e+01, Y0_mean: -4.731, Y0_std: 8.150, Time: 0.31, Learning Rate: 1.200e-04
# It: 150, Loss: 2.796e+01, Y0_mean: -4.811, Y0_std: 8.482, Time: 0.31, Learning Rate: 1.200e-04
# It: 160, Loss: 3.242e+01, Y0_mean: -4.460, Y0_std: 8.536, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 2.803e+01, Y0_mean: -4.671, Y0_std: 8.378, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 3.394e+01, Y0_mean: -4.868, Y0_std: 8.208, Time: 0.30, Learning Rate: 1.200e-04
# It: 190, Loss: 2.844e+01, Y0_mean: -4.704, Y0_std: 8.423, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 2.818e+01, Y0_mean: -4.755, Y0_std: 8.630, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 2.900e+01, Y0_mean: -4.675, Y0_std: 8.241, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=17, idx=[264,280], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 3.517e+01, Y0_mean: -4.382, Y0_std: 8.076, Time: 3.51, Learning Rate: 1.200e-04
# It: 10, Loss: 3.610e+01, Y0_mean: -4.462, Y0_std: 8.232, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 3.020e+01, Y0_mean: -4.627, Y0_std: 8.510, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 2.828e+01, Y0_mean: -4.486, Y0_std: 8.530, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 2.665e+01, Y0_mean: -4.003, Y0_std: 7.785, Time: 0.30, Learning Rate: 1.200e-04
# It: 50, Loss: 2.714e+01, Y0_mean: -4.135, Y0_std: 8.355, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 2.506e+01, Y0_mean: -4.222, Y0_std: 7.767, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 2.488e+01, Y0_mean: -4.161, Y0_std: 8.483, Time: 0.30, Learning Rate: 1.200e-04
# It: 80, Loss: 3.131e+01, Y0_mean: -4.066, Y0_std: 8.174, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 3.161e+01, Y0_mean: -4.111, Y0_std: 8.284, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 2.476e+01, Y0_mean: -4.152, Y0_std: 8.464, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 2.613e+01, Y0_mean: -4.069, Y0_std: 7.593, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 2.528e+01, Y0_mean: -4.209, Y0_std: 8.267, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 3.197e+01, Y0_mean: -4.013, Y0_std: 8.192, Time: 0.31, Learning Rate: 1.200e-04
# It: 140, Loss: 2.550e+01, Y0_mean: -4.361, Y0_std: 8.452, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 2.479e+01, Y0_mean: -4.192, Y0_std: 7.669, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 2.513e+01, Y0_mean: -4.245, Y0_std: 8.227, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 3.218e+01, Y0_mean: -3.814, Y0_std: 8.123, Time: 0.31, Learning Rate: 1.200e-04
# It: 180, Loss: 3.218e+01, Y0_mean: -4.274, Y0_std: 8.326, Time: 0.31, Learning Rate: 1.200e-04
# It: 190, Loss: 2.572e+01, Y0_mean: -4.076, Y0_std: 7.555, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 2.529e+01, Y0_mean: -4.266, Y0_std: 8.608, Time: 0.31, Learning Rate: 1.200e-04
# It: 210, Loss: 2.526e+01, Y0_mean: -4.384, Y0_std: 7.601, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=16, idx=[248,264], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 2.595e+01, Y0_mean: -4.062, Y0_std: 9.044, Time: 3.57, Learning Rate: 1.200e-04
# It: 10, Loss: 2.261e+01, Y0_mean: -3.640, Y0_std: 10.041, Time: 0.30, Learning Rate: 1.200e-04
# It: 20, Loss: 2.179e+01, Y0_mean: -3.895, Y0_std: 9.293, Time: 0.30, Learning Rate: 1.200e-04
# It: 30, Loss: 2.009e+01, Y0_mean: -3.712, Y0_std: 9.813, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 2.245e+01, Y0_mean: -3.646, Y0_std: 9.636, Time: 0.31, Learning Rate: 1.200e-04
# It: 50, Loss: 2.207e+01, Y0_mean: -3.791, Y0_std: 9.950, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 2.027e+01, Y0_mean: -3.937, Y0_std: 9.740, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 2.261e+01, Y0_mean: -3.750, Y0_std: 9.506, Time: 0.30, Learning Rate: 1.200e-04
# It: 80, Loss: 2.024e+01, Y0_mean: -3.862, Y0_std: 9.788, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 2.245e+01, Y0_mean: -3.756, Y0_std: 9.595, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 2.177e+01, Y0_mean: -3.989, Y0_std: 9.093, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 2.318e+01, Y0_mean: -3.447, Y0_std: 9.550, Time: 0.31, Learning Rate: 1.200e-04
# It: 120, Loss: 2.025e+01, Y0_mean: -3.674, Y0_std: 9.786, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 2.224e+01, Y0_mean: -4.059, Y0_std: 9.073, Time: 0.31, Learning Rate: 1.200e-04
# It: 140, Loss: 2.186e+01, Y0_mean: -3.688, Y0_std: 9.809, Time: 0.31, Learning Rate: 1.200e-04
# It: 150, Loss: 2.206e+01, Y0_mean: -3.680, Y0_std: 9.852, Time: 0.31, Learning Rate: 1.200e-04
# It: 160, Loss: 2.207e+01, Y0_mean: -4.044, Y0_std: 9.065, Time: 0.31, Learning Rate: 1.200e-04
# It: 170, Loss: 2.013e+01, Y0_mean: -3.672, Y0_std: 9.709, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 2.197e+01, Y0_mean: -3.698, Y0_std: 9.836, Time: 0.31, Learning Rate: 1.200e-04
# It: 190, Loss: 2.263e+01, Y0_mean: -4.077, Y0_std: 9.747, Time: 0.31, Learning Rate: 1.200e-04
# It: 200, Loss: 2.199e+01, Y0_mean: -3.692, Y0_std: 9.795, Time: 0.31, Learning Rate: 1.200e-04
# It: 210, Loss: 2.204e+01, Y0_mean: -3.691, Y0_std: 9.828, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=15, idx=[232,248], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 2.471e+01, Y0_mean: -4.091, Y0_std: 10.552, Time: 3.61, Learning Rate: 1.200e-04
# It: 10, Loss: 1.870e+01, Y0_mean: -3.584, Y0_std: 10.884, Time: 0.30, Learning Rate: 1.200e-04
# It: 20, Loss: 1.920e+01, Y0_mean: -3.636, Y0_std: 11.246, Time: 0.30, Learning Rate: 1.200e-04
# It: 30, Loss: 1.895e+01, Y0_mean: -3.796, Y0_std: 10.983, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 1.778e+01, Y0_mean: -3.757, Y0_std: 11.255, Time: 0.31, Learning Rate: 1.200e-04
# It: 50, Loss: 1.847e+01, Y0_mean: -3.710, Y0_std: 10.883, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 1.529e+01, Y0_mean: -3.643, Y0_std: 10.993, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 1.755e+01, Y0_mean: -3.637, Y0_std: 11.185, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 1.885e+01, Y0_mean: -3.885, Y0_std: 10.734, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 1.829e+01, Y0_mean: -3.559, Y0_std: 11.175, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 1.806e+01, Y0_mean: -3.905, Y0_std: 10.996, Time: 0.30, Learning Rate: 1.200e-04
# It: 110, Loss: 1.842e+01, Y0_mean: -3.529, Y0_std: 11.236, Time: 0.30, Learning Rate: 1.200e-04
# It: 120, Loss: 1.835e+01, Y0_mean: -3.585, Y0_std: 10.742, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 1.743e+01, Y0_mean: -3.653, Y0_std: 11.135, Time: 0.30, Learning Rate: 1.200e-04
# It: 140, Loss: 1.518e+01, Y0_mean: -3.702, Y0_std: 11.082, Time: 0.30, Learning Rate: 1.200e-04
# It: 150, Loss: 1.768e+01, Y0_mean: -3.761, Y0_std: 11.168, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 1.740e+01, Y0_mean: -3.695, Y0_std: 11.077, Time: 0.30, Learning Rate: 1.200e-04
# It: 170, Loss: 1.848e+01, Y0_mean: -3.741, Y0_std: 10.878, Time: 0.31, Learning Rate: 1.200e-04
# It: 180, Loss: 1.511e+01, Y0_mean: -3.524, Y0_std: 11.038, Time: 0.31, Learning Rate: 1.200e-04
# It: 190, Loss: 1.777e+01, Y0_mean: -3.896, Y0_std: 11.099, Time: 0.30, Learning Rate: 1.200e-04
# It: 200, Loss: 1.766e+01, Y0_mean: -3.701, Y0_std: 11.123, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 1.762e+01, Y0_mean: -3.764, Y0_std: 11.067, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=14, idx=[216,232], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 1.794e+01, Y0_mean: -3.900, Y0_std: 12.221, Time: 3.70, Learning Rate: 1.200e-04
# It: 10, Loss: 1.581e+01, Y0_mean: -3.707, Y0_std: 12.430, Time: 0.30, Learning Rate: 1.200e-04
# It: 20, Loss: 1.588e+01, Y0_mean: -3.853, Y0_std: 12.249, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 1.491e+01, Y0_mean: -3.702, Y0_std: 12.346, Time: 0.30, Learning Rate: 1.200e-04
# It: 40, Loss: 1.530e+01, Y0_mean: -3.706, Y0_std: 12.447, Time: 0.31, Learning Rate: 1.200e-04
# It: 50, Loss: 1.656e+01, Y0_mean: -3.506, Y0_std: 12.256, Time: 0.30, Learning Rate: 1.200e-04
# It: 60, Loss: 1.625e+01, Y0_mean: -3.634, Y0_std: 12.227, Time: 0.30, Learning Rate: 1.200e-04
# It: 70, Loss: 1.541e+01, Y0_mean: -3.553, Y0_std: 12.193, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 1.528e+01, Y0_mean: -3.526, Y0_std: 12.056, Time: 0.30, Learning Rate: 1.200e-04
# It: 90, Loss: 1.485e+01, Y0_mean: -3.592, Y0_std: 12.306, Time: 0.30, Learning Rate: 1.200e-04
# It: 100, Loss: 1.461e+01, Y0_mean: -3.695, Y0_std: 12.249, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 1.548e+01, Y0_mean: -3.659, Y0_std: 12.208, Time: 0.31, Learning Rate: 1.200e-04
# ...
# It: 150, Loss: 1.299e+00, Y0_mean: -2.785, Y0_std: 11.087, Time: 0.31, Learning Rate: 1.200e-04
# It: 160, Loss: 1.171e+00, Y0_mean: -2.945, Y0_std: 10.993, Time: 0.31, Learning Rate: 1.200e-04
# It: 170, Loss: 1.264e+00, Y0_mean: -2.795, Y0_std: 11.086, Time: 0.31, Learning Rate: 1.200e-04
# It: 180, Loss: 1.231e+00, Y0_mean: -2.960, Y0_std: 10.983, Time: 0.31, Learning Rate: 1.200e-04
# It: 190, Loss: 1.088e+00, Y0_mean: -2.844, Y0_std: 11.218, Time: 0.32, Learning Rate: 1.200e-04
# It: 200, Loss: 1.277e+00, Y0_mean: -2.969, Y0_std: 10.988, Time: 0.31, Learning Rate: 1.200e-04
# It: 210, Loss: 1.036e+00, Y0_mean: -2.782, Y0_std: 10.923, Time: 0.30, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=4, idx=[56,72], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 1.361e+01, Y0_mean: -2.719, Y0_std: 9.059, Time: 4.17, Learning Rate: 1.200e-04
# It: 10, Loss: 4.548e+00, Y0_mean: -1.949, Y0_std: 9.421, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 2.027e+00, Y0_mean: -1.885, Y0_std: 9.584, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 9.445e-01, Y0_mean: -2.107, Y0_std: 9.500, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 7.944e-01, Y0_mean: -1.921, Y0_std: 9.622, Time: 0.31, Learning Rate: 1.200e-04
# It: 50, Loss: 9.867e-01, Y0_mean: -2.211, Y0_std: 9.773, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 2.017e+00, Y0_mean: -2.310, Y0_std: 9.722, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 6.295e-01, Y0_mean: -2.030, Y0_std: 9.581, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 2.262e+00, Y0_mean: -1.816, Y0_std: 9.451, Time: 0.32, Learning Rate: 1.200e-04
# It: 90, Loss: 2.529e+00, Y0_mean: -2.368, Y0_std: 9.578, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 1.330e+00, Y0_mean: -2.227, Y0_std: 9.615, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 7.750e-01, Y0_mean: -1.943, Y0_std: 9.648, Time: 0.31, Learning Rate: 1.200e-04
# It: 120, Loss: 6.233e-01, Y0_mean: -2.035, Y0_std: 9.597, Time: 0.31, Learning Rate: 1.200e-04
# It: 130, Loss: 3.130e+00, Y0_mean: -2.412, Y0_std: 9.617, Time: 0.31, Learning Rate: 1.200e-04
# It: 140, Loss: 1.156e+00, Y0_mean: -2.211, Y0_std: 9.694, Time: 0.31, Learning Rate: 1.200e-04
# It: 150, Loss: 1.979e+00, Y0_mean: -1.940, Y0_std: 9.528, Time: 0.31, Learning Rate: 1.200e-04
# It: 160, Loss: 1.140e+00, Y0_mean: -2.083, Y0_std: 9.901, Time: 0.31, Learning Rate: 1.200e-04
# It: 170, Loss: 6.586e-01, Y0_mean: -2.016, Y0_std: 9.653, Time: 0.31, Learning Rate: 1.200e-04
# It: 180, Loss: 8.618e-01, Y0_mean: -2.138, Y0_std: 9.711, Time: 0.32, Learning Rate: 1.200e-04
# It: 190, Loss: 7.441e-01, Y0_mean: -1.917, Y0_std: 9.592, Time: 0.32, Learning Rate: 1.200e-04
# It: 200, Loss: 8.118e-01, Y0_mean: -2.180, Y0_std: 9.780, Time: 0.31, Learning Rate: 1.200e-04
# It: 210, Loss: 9.058e-01, Y0_mean: -1.875, Y0_std: 9.639, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=3, idx=[40,56], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 1.974e+01, Y0_mean: -1.554, Y0_std: 7.276, Time: 4.31, Learning Rate: 1.200e-04
# It: 10, Loss: 6.236e+00, Y0_mean: -0.108, Y0_std: 8.054, Time: 0.31, Learning Rate: 1.200e-04
# It: 20, Loss: 1.281e+00, Y0_mean: -0.612, Y0_std: 7.916, Time: 0.31, Learning Rate: 1.200e-04
# It: 30, Loss: 6.646e-01, Y0_mean: -0.569, Y0_std: 7.627, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 1.653e+00, Y0_mean: -0.779, Y0_std: 7.632, Time: 0.31, Learning Rate: 1.200e-04
# It: 50, Loss: 6.120e-01, Y0_mean: -0.559, Y0_std: 7.630, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 7.550e-01, Y0_mean: -0.619, Y0_std: 8.033, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 1.384e+00, Y0_mean: -0.784, Y0_std: 7.854, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 6.051e-01, Y0_mean: -0.516, Y0_std: 7.798, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 9.329e-01, Y0_mean: -0.402, Y0_std: 7.781, Time: 0.31, Learning Rate: 1.200e-04
# It: 100, Loss: 9.710e-01, Y0_mean: -0.735, Y0_std: 7.791, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 9.223e-01, Y0_mean: -0.383, Y0_std: 7.738, Time: 0.31, Learning Rate: 1.200e-04
# It: 120, Loss: 1.043e+00, Y0_mean: -0.378, Y0_std: 7.754, Time: 0.31, Learning Rate: 1.200e-04
# It: 130, Loss: 1.111e+00, Y0_mean: -0.741, Y0_std: 7.672, Time: 0.31, Learning Rate: 1.200e-04
# It: 140, Loss: 7.475e-01, Y0_mean: -0.424, Y0_std: 7.744, Time: 0.31, Learning Rate: 1.200e-04
# It: 150, Loss: 9.023e-01, Y0_mean: -0.473, Y0_std: 7.968, Time: 0.32, Learning Rate: 1.200e-04
# It: 160, Loss: 1.310e+00, Y0_mean: -0.848, Y0_std: 7.882, Time: 0.31, Learning Rate: 1.200e-04
# It: 170, Loss: 6.453e-01, Y0_mean: -0.532, Y0_std: 7.955, Time: 0.31, Learning Rate: 1.200e-04
# It: 180, Loss: 7.488e-01, Y0_mean: -0.431, Y0_std: 7.746, Time: 0.31, Learning Rate: 1.200e-04
# It: 190, Loss: 1.514e+00, Y0_mean: -0.804, Y0_std: 7.666, Time: 0.31, Learning Rate: 1.200e-04
# It: 200, Loss: 5.496e-01, Y0_mean: -0.489, Y0_std: 7.736, Time: 0.31, Learning Rate: 1.200e-04
# It: 210, Loss: 6.055e-01, Y0_mean: -0.481, Y0_std: 7.748, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=2, idx=[24,40], steps=16, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 1.804e+01, Y0_mean: -0.136, Y0_std: 4.699, Time: 4.31, Learning Rate: 1.200e-04
# It: 10, Loss: 4.105e+00, Y0_mean: 1.065, Y0_std: 5.367, Time: 0.32, Learning Rate: 1.200e-04
# It: 20, Loss: 9.703e-01, Y0_mean: 0.893, Y0_std: 5.302, Time: 0.32, Learning Rate: 1.200e-04
# It: 30, Loss: 1.059e+00, Y0_mean: 1.008, Y0_std: 5.073, Time: 0.31, Learning Rate: 1.200e-04
# It: 40, Loss: 1.854e+00, Y0_mean: 0.600, Y0_std: 4.921, Time: 0.31, Learning Rate: 1.200e-04
# It: 50, Loss: 4.938e-01, Y0_mean: 0.753, Y0_std: 4.997, Time: 0.31, Learning Rate: 1.200e-04
# It: 60, Loss: 2.589e+00, Y0_mean: 1.161, Y0_std: 5.112, Time: 0.31, Learning Rate: 1.200e-04
# It: 70, Loss: 8.215e-01, Y0_mean: 0.973, Y0_std: 5.057, Time: 0.31, Learning Rate: 1.200e-04
# It: 80, Loss: 1.660e+00, Y0_mean: 0.548, Y0_std: 5.057, Time: 0.31, Learning Rate: 1.200e-04
# It: 90, Loss: 4.232e-01, Y0_mean: 0.701, Y0_std: 5.185, Time: 0.30, Learning Rate: 1.200e-04
# It: 100, Loss: 2.393e+00, Y0_mean: 1.108, Y0_std: 5.134, Time: 0.31, Learning Rate: 1.200e-04
# It: 110, Loss: 5.545e-01, Y0_mean: 0.909, Y0_std: 5.062, Time: 0.31, Learning Rate: 1.200e-04
# It: 120, Loss: 2.121e+00, Y0_mean: 0.475, Y0_std: 5.147, Time: 0.30, Learning Rate: 1.200e-04
# It: 130, Loss: 5.421e-01, Y0_mean: 0.679, Y0_std: 5.074, Time: 0.31, Learning Rate: 1.200e-04
# It: 140, Loss: 1.933e+00, Y0_mean: 1.042, Y0_std: 5.231, Time: 0.32, Learning Rate: 1.200e-04
# It: 150, Loss: 4.417e-01, Y0_mean: 0.842, Y0_std: 5.203, Time: 0.30, Learning Rate: 1.200e-04
# It: 160, Loss: 2.476e+00, Y0_mean: 0.454, Y0_std: 5.022, Time: 0.31, Learning Rate: 1.200e-04
# It: 170, Loss: 7.012e-01, Y0_mean: 0.646, Y0_std: 5.032, Time: 0.30, Learning Rate: 1.200e-04
# It: 180, Loss: 1.538e+00, Y0_mean: 0.996, Y0_std: 5.227, Time: 0.32, Learning Rate: 1.200e-04
# It: 190, Loss: 3.374e-01, Y0_mean: 0.820, Y0_std: 5.096, Time: 0.31, Learning Rate: 1.200e-04
# It: 200, Loss: 2.919e+00, Y0_mean: 0.400, Y0_std: 5.144, Time: 0.30, Learning Rate: 1.200e-04
# It: 210, Loss: 9.506e-01, Y0_mean: 0.574, Y0_std: 5.171, Time: 0.31, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=1, idx=[10,24], steps=14, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 1.293e+01, Y0_mean: 0.989, Y0_std: 2.619, Time: 4.11, Learning Rate: 1.200e-04
# It: 10, Loss: 7.615e-01, Y0_mean: 1.666, Y0_std: 2.732, Time: 0.27, Learning Rate: 1.200e-04
# It: 20, Loss: 6.217e-01, Y0_mean: 1.762, Y0_std: 2.635, Time: 0.28, Learning Rate: 1.200e-04
# It: 30, Loss: 8.774e-01, Y0_mean: 1.562, Y0_std: 2.693, Time: 0.27, Learning Rate: 1.200e-04
# It: 40, Loss: 2.441e-01, Y0_mean: 1.843, Y0_std: 2.775, Time: 0.27, Learning Rate: 1.200e-04
# It: 50, Loss: 4.795e-01, Y0_mean: 1.926, Y0_std: 2.733, Time: 0.27, Learning Rate: 1.200e-04
# It: 60, Loss: 4.349e-01, Y0_mean: 1.695, Y0_std: 2.692, Time: 0.27, Learning Rate: 1.200e-04
# It: 70, Loss: 3.989e-01, Y0_mean: 1.855, Y0_std: 2.569, Time: 0.27, Learning Rate: 1.200e-04
# It: 80, Loss: 3.717e-01, Y0_mean: 1.860, Y0_std: 2.781, Time: 0.27, Learning Rate: 1.200e-04
# It: 90, Loss: 7.506e-01, Y0_mean: 1.632, Y0_std: 2.721, Time: 0.27, Learning Rate: 1.200e-04
# It: 100, Loss: 2.424e-01, Y0_mean: 1.818, Y0_std: 2.575, Time: 0.27, Learning Rate: 1.200e-04
# It: 110, Loss: 2.934e-01, Y0_mean: 1.840, Y0_std: 2.544, Time: 0.28, Learning Rate: 1.200e-04
# It: 120, Loss: 7.687e-01, Y0_mean: 1.626, Y0_std: 2.571, Time: 0.27, Learning Rate: 1.200e-04
# It: 130, Loss: 2.381e-01, Y0_mean: 1.819, Y0_std: 2.727, Time: 0.28, Learning Rate: 1.200e-04
# It: 140, Loss: 2.814e-01, Y0_mean: 1.841, Y0_std: 2.557, Time: 0.28, Learning Rate: 1.200e-04
# It: 150, Loss: 7.567e-01, Y0_mean: 1.630, Y0_std: 2.544, Time: 0.27, Learning Rate: 1.200e-04
# It: 160, Loss: 2.313e-01, Y0_mean: 1.813, Y0_std: 2.720, Time: 0.27, Learning Rate: 1.200e-04
# It: 170, Loss: 2.793e-01, Y0_mean: 1.829, Y0_std: 2.760, Time: 0.27, Learning Rate: 1.200e-04
# It: 180, Loss: 7.782e-01, Y0_mean: 1.623, Y0_std: 2.539, Time: 0.27, Learning Rate: 1.200e-04
# It: 190, Loss: 2.183e-01, Y0_mean: 1.807, Y0_std: 2.766, Time: 0.27, Learning Rate: 1.200e-04
# It: 200, Loss: 2.634e-01, Y0_mean: 1.827, Y0_std: 2.772, Time: 0.28, Learning Rate: 1.200e-04
# It: 210, Loss: 8.114e-01, Y0_mean: 1.623, Y0_std: 2.547, Time: 0.27, Learning Rate: 1.200e-04
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9
#
# [RecursiveBlock] main:stable b=0, idx=[0,10], steps=10, terminal=external, iters=220, lr=1.2e-04
# It: 0, Loss: 7.605e+00, Y0_mean: 0.985, Y0_std: 0.000, Time: 3.68, Learning Rate: 1.200e-04
# It: 10, Loss: 6.315e-01, Y0_mean: 1.571, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 20, Loss: 1.095e-01, Y0_mean: 1.525, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 30, Loss: 8.846e-02, Y0_mean: 1.444, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 40, Loss: 7.550e-02, Y0_mean: 1.462, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 50, Loss: 7.968e-02, Y0_mean: 1.466, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 60, Loss: 8.522e-02, Y0_mean: 1.427, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 70, Loss: 9.416e-02, Y0_mean: 1.409, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 80, Loss: 9.615e-02, Y0_mean: 1.399, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 90, Loss: 1.021e-01, Y0_mean: 1.383, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 100, Loss: 1.115e-01, Y0_mean: 1.368, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 110, Loss: 1.178e-01, Y0_mean: 1.355, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 120, Loss: 1.308e-01, Y0_mean: 1.343, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 130, Loss: 1.302e-01, Y0_mean: 1.330, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 140, Loss: 1.528e-01, Y0_mean: 1.319, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 150, Loss: 1.550e-01, Y0_mean: 1.310, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 160, Loss: 1.763e-01, Y0_mean: 1.301, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 170, Loss: 1.784e-01, Y0_mean: 1.293, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 180, Loss: 1.946e-01, Y0_mean: 1.287, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 190, Loss: 2.071e-01, Y0_mean: 1.280, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# It: 200, Loss: 2.250e-01, Y0_mean: 1.278, Y0_std: 0.000, Time: 0.20, Learning Rate: 1.200e-04
# It: 210, Loss: 2.464e-01, Y0_mean: 1.276, Y0_std: 0.000, Time: 0.19, Learning Rate: 1.200e-04
# === Recursive Log (compact) ===
# block=0, idx=[0,10], steps=10, terminal=external, eval_loss=1.008e+00, eval_y0=1.175, exact_y0=-8.000, delta=9.175
# block=1, idx=[10,24], steps=14, terminal=external, eval_loss=3.909e-01, eval_y0=1.861, exact_y0=-8.237, delta=10.098
# block=2, idx=[24,40], steps=16, terminal=external, eval_loss=4.529e-01, eval_y0=0.867, exact_y0=-9.513, delta=10.380
# block=3, idx=[40,56], steps=16, terminal=external, eval_loss=1.112e+00, eval_y0=-0.769, exact_y0=-11.373, delta=10.605
# block=4, idx=[56,72], steps=16, terminal=external, eval_loss=8.989e-01, eval_y0=-1.894, exact_y0=-13.213, delta=11.319
# block=5, idx=[72,88], steps=16, terminal=external, eval_loss=1.330e+00, eval_y0=-3.015, exact_y0=-15.717, delta=12.701
# block=6, idx=[88,104], steps=16, terminal=external, eval_loss=1.588e+00, eval_y0=-3.505, exact_y0=-17.565, delta=14.060
# block=7, idx=[104,120], steps=16, terminal=external, eval_loss=2.173e+00, eval_y0=-3.942, exact_y0=-19.374, delta=15.432
# block=8, idx=[120,136], steps=16, terminal=external, eval_loss=4.087e+00, eval_y0=-4.041, exact_y0=-22.100, delta=18.059
# block=9, idx=[136,152], steps=16, terminal=external, eval_loss=5.345e+00, eval_y0=-4.071, exact_y0=-24.977, delta=20.905
# block=10, idx=[152,168], steps=16, terminal=external, eval_loss=6.322e+00, eval_y0=-4.065, exact_y0=-26.057, delta=21.992
# block=11, idx=[168,184], steps=16, terminal=external, eval_loss=7.380e+00, eval_y0=-3.660, exact_y0=-27.820, delta=24.159
# block=12, idx=[184,200], steps=16, terminal=external, eval_loss=8.888e+00, eval_y0=-3.331, exact_y0=-30.091, delta=26.760
# block=13, idx=[200,216], steps=16, terminal=external, eval_loss=1.147e+01, eval_y0=-3.458, exact_y0=-32.672, delta=29.214
# block=14, idx=[216,232], steps=16, terminal=external, eval_loss=1.305e+01, eval_y0=-3.605, exact_y0=-34.635, delta=31.030
# block=15, idx=[232,248], steps=16, terminal=external, eval_loss=1.790e+01, eval_y0=-3.914, exact_y0=-37.054, delta=33.141
# block=16, idx=[248,264], steps=16, terminal=external, eval_loss=1.992e+01, eval_y0=-4.203, exact_y0=-37.392, delta=33.189
# block=17, idx=[264,280], steps=16, terminal=external, eval_loss=2.460e+01, eval_y0=-4.458, exact_y0=-39.053, delta=34.595
# block=18, idx=[280,296], steps=16, terminal=external, eval_loss=3.003e+01, eval_y0=-5.116, exact_y0=-43.044, delta=37.928
# block=19, idx=[296,312], steps=16, terminal=external, eval_loss=3.645e+01, eval_y0=-5.837, exact_y0=-42.455, delta=36.619
# block=20, idx=[312,328], steps=16, terminal=external, eval_loss=3.468e+01, eval_y0=-6.797, exact_y0=-48.008, delta=41.211
# block=21, idx=[328,344], steps=16, terminal=external, eval_loss=5.000e+01, eval_y0=-7.566, exact_y0=-49.092, delta=41.526
# block=22, idx=[344,360], steps=16, terminal=external, eval_loss=4.810e+01, eval_y0=-8.499, exact_y0=-49.672, delta=41.173
# block=23, idx=[360,376], steps=16, terminal=external, eval_loss=5.460e+01, eval_y0=-9.065, exact_y0=-55.536, delta=46.471
# block=24, idx=[376,392], steps=16, terminal=external, eval_loss=6.377e+01, eval_y0=-9.148, exact_y0=-53.206, delta=44.059
# block=25, idx=[392,408], steps=16, terminal=external, eval_loss=7.477e+01, eval_y0=-9.098, exact_y0=-60.756, delta=51.658
# block=26, idx=[408,424], steps=16, terminal=external, eval_loss=8.714e+01, eval_y0=-8.907, exact_y0=-60.664, delta=51.757
# block=27, idx=[424,440], steps=16, terminal=external, eval_loss=8.976e+01, eval_y0=-8.625, exact_y0=-66.823, delta=58.198
# block=28, idx=[440,456], steps=16, terminal=external, eval_loss=1.012e+02, eval_y0=-8.416, exact_y0=-64.449, delta=56.034
# block=29, idx=[456,480], steps=24, terminal=g, eval_loss=1.085e+06, eval_y0=-8.244, exact_y0=-64.879, delta=56.635
#
# Predicted Y0 mean: 1.1754 (std 0.0000)
# Predicted Y0 path0: 1.1754
# Exact Y0:           -8.0000
