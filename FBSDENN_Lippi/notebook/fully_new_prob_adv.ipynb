# %% [markdown]
# ### Sistema Fully Coupled (Girsanov)
# $$
# \begin{cases}
# dS_t =\mu_1(c_1-S_t)dt + \sigma_1dW^1_t\\
# dH_t = \mu_2(c_2-H_t)dt + \sigma_2 dW^2_t\\
# dV_t = b_V(A_t)dt +\sigma_3 dW^3_t\\
# dX_t = V_t dt
# \end{cases}
# $$
# where
# $$
# b_V(A)=f(A)\Psi(X) + (c_3\Psi(-X)-c_4\Psi(X-10))\Psi(5(V+1))
# $$
# with
# $$\Psi(x)=\max(0,\min(1,x/d,(x_{max}-x)/d))$$ and $f$ a function that we will later choose with care, for now $f=0$$.

# %% [markdown]
# ### Soluzione
# $$
#     u(t,s,h,v,x) = -\gamma e^s x
# $$

# %% [markdown]
# ### Equazione backward
# $$
#  dY_t = -\gamma e^{S_t}\left( X_t \mu_1(c_1-S_t)+V_t +0.5\sigma_1^2X_t \right)dt + Z_t dW_t,
# $$
# where in the final solution $Z_t = (-\gamma e^{S_t}X_t\sigma_1,0,0,0)$.

# %% [markdown]
# ### Secondo Modello
# Qui si fissa $f(A)=-0.5 V \Psi(X)$ e con $X=-\frac{Z^S e^{-S_t}}{\gamma\sigma_1}$ (che viene sostituito solo dentro $f$)
# ### Terzo Modello
# La $X$ viene sostituita come sopra anche nel drift backward

# %%
## Rete neurale con normalizzazione della loss

import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from abc import ABC, abstractmethod


class FBSNN(ABC): # Forward-Backward Stochastic Neural Network
    def __init__(self, Xi, T,
                       M, N, D,
                       layers,
                       clip_grad_norm=1.0, 
                       use_antithetic_sampling=True):
        self.Xi = Xi # initial point
        self.T = T # terminal time

        self.M = M # number of trajectories
        self.N = N # number of time snapshots
        self.D = D # number of dimensions

        # layers
        self.layers = layers # (D+1) --> 1

        # migliorie advanced richieste
        self.clip_grad_norm = clip_grad_norm
        self.use_antithetic_sampling = bool(use_antithetic_sampling)

        # initialize NN
        self.weights, self.biases = self.initialize_NN(layers)

        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))

        # tf placeholders and graph (training)
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.t_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, 1]) # M x (N+1) x 1
        self.W_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, self.D]) # M x (N+1) x D
        self.Xi_tf = tf.placeholder(tf.float32, shape=[1, D]) # 1 x D
        self.const_tf = tf.placeholder(tf.float32, shape=[])

        self.loss, self.X_pred, self.Y_pred, self.Y0_pred, self.Z_pred = self.loss_function(self.t_tf, self.W_tf, self.Xi_tf)

        # optimizer + gradient clipping
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        gradients_and_variables = self.optimizer.compute_gradients(self.loss)
        if self.clip_grad_norm is not None:
            non_null_grads_and_vars = [(g, v) for g, v in gradients_and_variables if g is not None]
            if non_null_grads_and_vars:
                gradients, variables = zip(*non_null_grads_and_vars)
                gradients, _ = tf.clip_by_global_norm(gradients, self.clip_grad_norm)
                clipped = list(zip(gradients, variables))
                untouched = [(g, v) for g, v in gradients_and_variables if g is None]
                gradients_and_variables = clipped + untouched
        self.train_op = self.optimizer.apply_gradients(gradients_and_variables)

        # initialize session and variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = X
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    def net_u(self, t, X): # M x 1, M x D
        u = self.neural_net(tf.concat([t, X], 1), self.weights, self.biases) # M x 1
        Du = tf.gradients(u, X)[0] # M x D
        return u, Du

    def Dg_tf(self, X): # M x D
        return tf.gradients(self.g_tf(X), X)[0] # M x D

    def loss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        loss = 0
        X_list = []
        Y_list = []
        Z_list = []

        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        X0 = tf.tile(Xi, [self.M, 1]) # M x D
        Y0, Du0 = self.net_u(t0, X0) # M x 1, M x D
        sigma0 = self.sigma_tf(t0, X0, Y0)
        Z0 = tf.squeeze(tf.matmul(tf.expand_dims(Du0, 1), sigma0), axis=1)

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]

            dW = W1 - W0
            sigma_dW = tf.squeeze(tf.matmul(sigma0, tf.expand_dims(dW, -1)), axis=[-1])
            X1 = X0 + self.mu_tf(t0, X0, Y0, Z0) * (t1 - t0) + sigma_dW

            # Z = Du*sigma e nella backward compare Z*dW.
            Y1_tilde = Y0 + self.phi_tf(t0, X0, Y0, Z0) * (t1 - t0) + tf.reduce_sum(Z0 * dW, axis=1, keepdims=True)

            Y1, Du1 = self.net_u(t1, X1)
            sigma1 = self.sigma_tf(t1, X1, Y1)
            Z1 = tf.squeeze(tf.matmul(tf.expand_dims(Du1, 1), sigma1), axis=1)

            loss += tf.reduce_sum(tf.square(Y1 - Y1_tilde))

            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            sigma0 = sigma1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)

        loss += tf.reduce_sum(tf.square(Y1 - self.g_tf(X1)))

        Dg = self.Dg_tf(X1)
        Z_terminal = tf.squeeze(tf.matmul(tf.expand_dims(Dg, 1), sigma1), axis=1)
        loss += tf.reduce_sum(tf.square(Z1 - Z_terminal))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)

        return loss/self.N, X, Y, Y[0, 0, 0], Z

    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1)) # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D)) # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        if self.use_antithetic_sampling and M > 1:
            half_M = M // 2
            DW_half = np.sqrt(dt) * np.random.normal(size=(half_M, N, D))
            DW[:half_M, 1:, :] = DW_half
            DW[half_M:2 * half_M, 1:, :] = -DW_half
            if M % 2 == 1:
                DW[-1, 1:, :] = np.sqrt(dt) * np.random.normal(size=(N, D))
        else:
            DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1) # M x (N+1) x 1
        W = np.cumsum(DW, axis=1) # M x (N+1) x D

        return t, W

    def train(self, N_Iter, learning_rate, const_value=None):
        start_time = time.time()
        last_loss = None
        last_y0 = None

        current_const = np.float32(self.const if const_value is None else const_value)
        for it in range(N_Iter):
            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D

            tf_dict = {
                self.Xi_tf: self.Xi,
                self.t_tf: t_batch,
                self.W_tf: W_batch,
                self.learning_rate: learning_rate,
                self.const_tf: current_const,
            }

            self.sess.run(self.train_op, tf_dict)

            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.loss, self.Y0_pred, self.learning_rate], tf_dict)
                last_loss = float(loss_value)
                last_y0 = float(Y0_value)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()

        return {
            'const': float(current_const),
            'learning_rate': float(learning_rate),
            'n_iter': int(N_Iter),
            'last_loss': last_loss,
            'last_y0': last_y0,
        }

    def evaluate(self, const_value=None, n_batches=5):
        current_const = np.float32(self.const if const_value is None else const_value)
        losses = []
        y0s = []

        for _ in range(n_batches):
            t_batch, W_batch = self.fetch_minibatch()
            tf_dict = {
                self.Xi_tf: self.Xi,
                self.t_tf: t_batch,
                self.W_tf: W_batch,
                self.const_tf: current_const,
            }
            loss_value, y0_value = self.sess.run([self.loss, self.Y0_pred], tf_dict)
            losses.append(float(loss_value))
            y0s.append(float(y0_value))

        return {
            'const': float(current_const),
            'mean_loss': float(np.mean(losses)),
            'std_loss': float(np.std(losses)),
            'mean_y0': float(np.mean(y0s)),
            'std_y0': float(np.std(y0s)),
            'n_batches': int(n_batches),
        }

    def predict(self, Xi_star, t_star, W_star, const_value=None):
        current_const = np.float32(self.const if const_value is None else const_value)
        tf_dict = {
            self.Xi_tf: Xi_star,
            self.t_tf: t_star,
            self.W_tf: W_star,
            self.const_tf: current_const,
        }

        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        Z_star = self.sess.run(self.Z_pred, tf_dict)

        return X_star, Y_star, Z_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def phi_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        pass # M x1

    @abstractmethod
    def g_tf(self, X): # M x D
        pass # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return np.zeros([M, D]) # M x D

    @abstractmethod
    def sigma_tf(self, t, X, Y): # M x 1, M x D, M x 1
        M = self.M
        D = self.D
        return tf.matrix_diag(tf.ones([M, D])) # M x D x D
    ###########################################################################


# backward compatibility
fbsde_NN = FBSNN

# %%
class NN_Quadratic_Coupled(FBSNN):
    def __init__(self, Xi, T, M, N, D, layers, parameters):
        self.mu1 = parameters['mu1']
        self.mu2 = parameters['mu2']
        self.c1 = parameters['c1']
        self.c2 = parameters['c2']
        self.c3 = parameters['c3']
        self.c4 = parameters['c4']
        self.gamma = parameters['gamma']
        self.s1 = parameters['s1']
        self.s2 = parameters['s2']
        self.s3 = parameters['s3']
        self.x_max = parameters['x_max']
        self.v_min = parameters['v_min']
        self.v_max = parameters['v_max']
        self.d = parameters['d']
        self.const = parameters['const']
        super().__init__(Xi, T, M, N, D, layers)

    def psi(self,X_state):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     tf.minimum(X_state/self.d, (self.x_max - X_state)/self.d)
                     )
                 )
        return result

    def psi3(self,V):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     (self.v_max- V)/self.d
                     )
                 )
        return result
    
    def psi4(self,V):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     (V - self.v_min)/self.d
                     )
                 )
        return result

    def f(self,X,Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        Z_S, Z_H, Z_V, _ = tf.split(Z, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        gamma = tf.cast(self.gamma, tf.float32)
        exp_S = tf.exp(-S)
        return -0.5 * V * self.psi(- exp_S * Z_S /(gamma * s1))
    
    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu1 = tf.cast(self.mu1, tf.float32)
        mu2 = tf.cast(self.mu2, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        c2 = tf.cast(self.c2, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)
        c4 = tf.cast(self.c4, tf.float32)
        x_max = tf.cast(self.x_max, tf.float32)
        const = tf.cast(self.const_tf, tf.float32)
        dS = mu1 * (c1 - S)
        dH = mu2 * (c2 - H)
        dV = self.f(X,Z) * self.psi(X_state) + c3 * self.psi(-X_state)*self.psi3(V) - c4 * self.psi(X_state-x_max)*self.psi4(V)
        dX = V
        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        gamma = tf.cast(self.gamma, tf.float32)
        exp_S = tf.exp(S)
        return -gamma * exp_S * X_state + V**2 + V*X_state

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        Z_S, Z_H, Z_V, _ = tf.split(Z, num_or_size_splits=4, axis=1)
        
        mu1 = tf.cast(self.mu1, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)
        c4 = tf.cast(self.c4, tf.float32)
        x_max = tf.cast(self.x_max, tf.float32)
        gamma = tf.cast(self.gamma, tf.float32)
        const = tf.cast(self.const_tf, tf.float32)
        
        exp_S = tf.exp(S)

        term1 = -gamma * exp_S * X_state * mu1 * (c1-S)
        term2 = (2 * V + X_state) * (self.f(X,Z) * self.psi(X_state) + c3 * self.psi(-X_state)*self.psi3(V) - c4 * self.psi(X_state-x_max)*self.psi4(V))
        term3 = -gamma * exp_S * V + (0.5 * (Z_V/s3 - X_state))**2
        # V = 0.5 * (Z_V/s3 - X_state)
        term4 = -0.5 * gamma * exp_S * X_state * s1**2 + s3**2
        
        return term1 + term2 + term3 + term4
    
    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)

        return tf.stack([r1, r2, r3, r4], axis=1)

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    M = 2048 #se non basta vram abbassa a 1500
    N = 250
    D = 4
    T = 24

    params = {
        'mu1': np.float32(1.0),
        'mu2': np.float32(1.0),
        'c1': np.float32(1.0),
        'c2': np.float32(1.0),
        'c3': np.float32(10.0),
        'c4': np.float32(10.0),
        'gamma': np.float32(1.0),
        'd': np.float32(1.0),
        'x_max': np.float32(10.0),
        'v_max': np.float32(2.0),
        'v_min': np.float32(-2.0),
        's1': np.float32(0.5),
        's2': np.float32(0.5),
        's3': np.float32(0.5),
        # Soft-init: partenza disaccoppiata
        'const': np.float32(0.0),
    }

    Xi = np.array([np.log(4), 0.5, 0.5, 2.0]).reshape(1, D)

    layers = [D+1] + 4*[256] + [1]
    
    model = NN_Quadratic_Coupled(Xi, T, M, N, D, layers, params)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9

# %%
    # Curriculum sull'accoppiamento: const cresce gradualmente fino a 1.0
    coupling_step = 1.0
    coupling_levels = np.arange(1.0, 1.0 + coupling_step, coupling_step, dtype=np.float32)

    stage_plan = [
        (700, 1e-3),
        (700, 5e-4),
        (700, 1e-4)
        #(700, 5e-5)
    ]
    stage_logs = []

    for level in coupling_levels:
        model.const = np.float32(level)
        print(f"=== Coupling stage: const={float(level):.1f} ===")
        for n_iter, lr in stage_plan:
            t0 = time.time()
            train_stats = model.train(N_Iter=n_iter, learning_rate=lr, const_value=level)
            eval_stats = model.evaluate(const_value=level, n_batches=5)
            elapsed = time.time() - t0
            log_row = {
                'phase': 'curriculum',
                'const': float(level),
                'lr': float(lr),
                'n_iter': int(n_iter),
                'train_last_loss': train_stats['last_loss'],
                'train_last_y0': train_stats['last_y0'],
                'eval_mean_loss': eval_stats['mean_loss'],
                'eval_std_loss': eval_stats['std_loss'],
                'eval_mean_y0': eval_stats['mean_y0'],
                'eval_std_y0': eval_stats['std_y0'],
                'elapsed_sec': float(elapsed),
            }
            stage_logs.append(log_row)
            print(
                f"[StageSummary] const={level:.1f}, lr={lr:.1e}, iters={n_iter}, "
                f"eval_loss={eval_stats['mean_loss']:.3e}±{eval_stats['std_loss']:.2e}, "
                f"eval_Y0={eval_stats['mean_y0']:.3f}±{eval_stats['std_y0']:.3f}, "
                f"time={elapsed:.1f}s"
            )

    # Fine-tuning finale fully coupled
    model.const = np.float32(1.0)
    print("=== Final fine-tuning at const=1.0 ===")
    final_plan = [(700, 1e-5), (500, 5e-6) ,(300, 1e-6)]
    for n_iter, lr in final_plan:
        t0 = time.time()
        train_stats = model.train(N_Iter=n_iter, learning_rate=lr, const_value=1.0)
        eval_stats = model.evaluate(const_value=1.0, n_batches=5)
        elapsed = time.time() - t0
        log_row = {
            'phase': 'final_finetune',
            'const': 1.0,
            'lr': float(lr),
            'n_iter': int(n_iter),
            'train_last_loss': train_stats['last_loss'],
            'train_last_y0': train_stats['last_y0'],
            'eval_mean_loss': eval_stats['mean_loss'],
            'eval_std_loss': eval_stats['std_loss'],
            'eval_mean_y0': eval_stats['mean_y0'],
            'eval_std_y0': eval_stats['std_y0'],
            'elapsed_sec': float(elapsed),
        }
        stage_logs.append(log_row)
        print(
            f"[FinalSummary] const=1.0, lr={lr:.1e}, iters={n_iter}, "
            f"eval_loss={eval_stats['mean_loss']:.3e}±{eval_stats['std_loss']:.2e}, "
            f"eval_Y0={eval_stats['mean_y0']:.3f}±{eval_stats['std_y0']:.3f}, "
            f"time={elapsed:.1f}s"
        )

    print("=== Curriculum Log (compact) ===")
    for row in stage_logs:
        print(
            f"phase={row['phase']}, const={row['const']:.1f}, lr={row['lr']:.1e}, iters={row['n_iter']}, "
            f"eval_loss={row['eval_mean_loss']:.3e}, eval_y0={row['eval_mean_y0']:.3f}, elapsed_sec={row['elapsed_sec']}"
        )
# Out:
# === Coupling stage: const=1.0 ===
# It: 0, Loss: 8.338e+03, Y0: -0.014, Time: 187.50, Learning Rate: 1.000e-03
# It: 10, Loss: 1.530e+03, Y0: -6.216, Time: 8.05, Learning Rate: 1.000e-03
# It: 20, Loss: 1.463e+03, Y0: -15.738, Time: 8.18, Learning Rate: 1.000e-03
# It: 30, Loss: 1.081e+03, Y0: -14.332, Time: 8.11, Learning Rate: 1.000e-03
# It: 40, Loss: 9.333e+02, Y0: -10.977, Time: 8.05, Learning Rate: 1.000e-03
# It: 50, Loss: 8.808e+02, Y0: -14.951, Time: 8.09, Learning Rate: 1.000e-03
# It: 60, Loss: 7.485e+02, Y0: -13.856, Time: 8.10, Learning Rate: 1.000e-03
# It: 70, Loss: 6.216e+02, Y0: -10.311, Time: 8.00, Learning Rate: 1.000e-03
# It: 80, Loss: 4.254e+02, Y0: -7.703, Time: 8.06, Learning Rate: 1.000e-03
# It: 90, Loss: 4.098e+02, Y0: -3.864, Time: 8.07, Learning Rate: 1.000e-03
# It: 100, Loss: 3.544e+02, Y0: -2.783, Time: 8.07, Learning Rate: 1.000e-03
# It: 110, Loss: 4.142e+02, Y0: -2.055, Time: 8.15, Learning Rate: 1.000e-03
# It: 120, Loss: 3.377e+02, Y0: -0.057, Time: 8.07, Learning Rate: 1.000e-03
# It: 130, Loss: 3.742e+02, Y0: -1.426, Time: 8.23, Learning Rate: 1.000e-03
# It: 140, Loss: 3.067e+02, Y0: 0.271, Time: 8.31, Learning Rate: 1.000e-03
# It: 150, Loss: 3.405e+02, Y0: -0.546, Time: 8.14, Learning Rate: 1.000e-03
# It: 160, Loss: 3.084e+02, Y0: 2.995, Time: 8.04, Learning Rate: 1.000e-03
# It: 170, Loss: 3.485e+02, Y0: 4.106, Time: 8.09, Learning Rate: 1.000e-03
# It: 180, Loss: 3.211e+02, Y0: -0.401, Time: 8.17, Learning Rate: 1.000e-03
# It: 190, Loss: 2.747e+02, Y0: 1.780, Time: 8.20, Learning Rate: 1.000e-03
# It: 200, Loss: 3.275e+02, Y0: 2.715, Time: 8.06, Learning Rate: 1.000e-03
# It: 210, Loss: 3.910e+02, Y0: 5.513, Time: 8.14, Learning Rate: 1.000e-03
# It: 220, Loss: 2.619e+02, Y0: 4.937, Time: 8.04, Learning Rate: 1.000e-03
# It: 230, Loss: 2.373e+02, Y0: 2.878, Time: 8.14, Learning Rate: 1.000e-03
# It: 240, Loss: 2.590e+02, Y0: 4.000, Time: 8.05, Learning Rate: 1.000e-03
# It: 250, Loss: 2.709e+02, Y0: 2.694, Time: 8.14, Learning Rate: 1.000e-03
# It: 260, Loss: 2.640e+02, Y0: 4.028, Time: 8.07, Learning Rate: 1.000e-03
# It: 270, Loss: 2.224e+02, Y0: 3.404, Time: 8.00, Learning Rate: 1.000e-03
# It: 280, Loss: 2.277e+02, Y0: 2.435, Time: 8.10, Learning Rate: 1.000e-03
# It: 290, Loss: 2.261e+02, Y0: 3.498, Time: 8.13, Learning Rate: 1.000e-03
# It: 300, Loss: 2.583e+02, Y0: 3.484, Time: 8.15, Learning Rate: 1.000e-03
# It: 310, Loss: 1.962e+02, Y0: 2.064, Time: 8.14, Learning Rate: 1.000e-03
# It: 320, Loss: 1.674e+02, Y0: 1.268, Time: 8.05, Learning Rate: 1.000e-03
# It: 330, Loss: 1.932e+02, Y0: -0.263, Time: 8.02, Learning Rate: 1.000e-03
# It: 340, Loss: 2.062e+02, Y0: 1.406, Time: 8.18, Learning Rate: 1.000e-03
# It: 350, Loss: 1.928e+02, Y0: 2.250, Time: 7.99, Learning Rate: 1.000e-03
# It: 360, Loss: 1.930e+02, Y0: 2.038, Time: 8.06, Learning Rate: 1.000e-03
# It: 370, Loss: 2.270e+02, Y0: -6.885, Time: 8.20, Learning Rate: 1.000e-03
# It: 380, Loss: 2.893e+02, Y0: -5.078, Time: 8.24, Learning Rate: 1.000e-03
# It: 390, Loss: 4.180e+02, Y0: 4.043, Time: 8.21, Learning Rate: 1.000e-03
# It: 400, Loss: 2.587e+02, Y0: -5.964, Time: 8.23, Learning Rate: 1.000e-03
# It: 410, Loss: 1.710e+02, Y0: -3.190, Time: 8.08, Learning Rate: 1.000e-03
# It: 420, Loss: 1.843e+02, Y0: -3.101, Time: 8.09, Learning Rate: 1.000e-03
# It: 430, Loss: 2.738e+02, Y0: -1.303, Time: 8.04, Learning Rate: 1.000e-03
# It: 440, Loss: 2.128e+02, Y0: 0.506, Time: 8.13, Learning Rate: 1.000e-03
# It: 450, Loss: 2.091e+02, Y0: -2.058, Time: 8.05, Learning Rate: 1.000e-03
# It: 460, Loss: 3.852e+02, Y0: -2.861, Time: 8.08, Learning Rate: 1.000e-03
# It: 470, Loss: 2.839e+02, Y0: -3.277, Time: 8.07, Learning Rate: 1.000e-03
# It: 480, Loss: 1.559e+02, Y0: -4.814, Time: 8.10, Learning Rate: 1.000e-03
# It: 490, Loss: 1.636e+02, Y0: -5.187, Time: 8.17, Learning Rate: 1.000e-03
# It: 500, Loss: 1.610e+02, Y0: -2.803, Time: 8.24, Learning Rate: 1.000e-03
# It: 510, Loss: 1.631e+02, Y0: -3.076, Time: 8.08, Learning Rate: 1.000e-03
# It: 520, Loss: 1.454e+02, Y0: -6.270, Time: 8.10, Learning Rate: 1.000e-03
# It: 530, Loss: 1.386e+02, Y0: -1.479, Time: 8.16, Learning Rate: 1.000e-03
# It: 540, Loss: 1.410e+02, Y0: -4.407, Time: 8.25, Learning Rate: 1.000e-03
# It: 550, Loss: 1.322e+02, Y0: -5.120, Time: 8.13, Learning Rate: 1.000e-03
# It: 560, Loss: 1.443e+02, Y0: -4.628, Time: 8.29, Learning Rate: 1.000e-03
# It: 570, Loss: 1.932e+02, Y0: -8.507, Time: 8.02, Learning Rate: 1.000e-03
# It: 580, Loss: 1.966e+02, Y0: -4.590, Time: 8.10, Learning Rate: 1.000e-03
# It: 590, Loss: 1.696e+02, Y0: -2.823, Time: 8.09, Learning Rate: 1.000e-03
# It: 600, Loss: 1.880e+02, Y0: -3.965, Time: 8.15, Learning Rate: 1.000e-03
# It: 610, Loss: 1.173e+02, Y0: -4.927, Time: 8.09, Learning Rate: 1.000e-03
# It: 620, Loss: 1.449e+02, Y0: -4.730, Time: 8.53, Learning Rate: 1.000e-03
# It: 630, Loss: 1.726e+02, Y0: -3.615, Time: 8.22, Learning Rate: 1.000e-03
# It: 640, Loss: 1.519e+02, Y0: -2.550, Time: 8.12, Learning Rate: 1.000e-03
# It: 650, Loss: 2.408e+02, Y0: -13.286, Time: 8.08, Learning Rate: 1.000e-03
# It: 660, Loss: 1.460e+02, Y0: -8.198, Time: 8.11, Learning Rate: 1.000e-03
# It: 670, Loss: 1.446e+02, Y0: -3.768, Time: 8.24, Learning Rate: 1.000e-03
# It: 680, Loss: 1.146e+02, Y0: -6.790, Time: 7.95, Learning Rate: 1.000e-03
# It: 690, Loss: 5.066e+02, Y0: -10.784, Time: 8.08, Learning Rate: 1.000e-03
# [StageSummary] const=1.0, lr=1.0e-03, iters=700, eval_loss=2.251e+02±1.10e+01, eval_Y0=-7.938±0.000, time=828.7s
# It: 0, Loss: 1.894e+02, Y0: -7.743, Time: 0.81, Learning Rate: 5.000e-04
# It: 10, Loss: 1.439e+02, Y0: -8.669, Time: 8.20, Learning Rate: 5.000e-04
# It: 20, Loss: 1.236e+02, Y0: -6.598, Time: 8.23, Learning Rate: 5.000e-04
# It: 30, Loss: 1.027e+02, Y0: -6.197, Time: 8.08, Learning Rate: 5.000e-04
# It: 40, Loss: 1.032e+02, Y0: -4.779, Time: 8.27, Learning Rate: 5.000e-04
# It: 50, Loss: 1.152e+02, Y0: -0.718, Time: 8.00, Learning Rate: 5.000e-04
# It: 60, Loss: 9.765e+01, Y0: -4.122, Time: 7.99, Learning Rate: 5.000e-04
# It: 70, Loss: 1.092e+02, Y0: -3.089, Time: 8.02, Learning Rate: 5.000e-04
# It: 80, Loss: 1.214e+02, Y0: -1.715, Time: 8.22, Learning Rate: 5.000e-04
# It: 90, Loss: 8.636e+01, Y0: -2.299, Time: 8.26, Learning Rate: 5.000e-04
# It: 100, Loss: 1.229e+02, Y0: -3.367, Time: 8.16, Learning Rate: 5.000e-04
# It: 110, Loss: 9.253e+01, Y0: -2.745, Time: 7.98, Learning Rate: 5.000e-04
# It: 120, Loss: 1.111e+02, Y0: -5.182, Time: 8.13, Learning Rate: 5.000e-04
# It: 130, Loss: 1.059e+02, Y0: -4.946, Time: 8.09, Learning Rate: 5.000e-04
# It: 140, Loss: 8.878e+01, Y0: -5.174, Time: 8.10, Learning Rate: 5.000e-04
# It: 150, Loss: 9.984e+01, Y0: -4.220, Time: 8.11, Learning Rate: 5.000e-04
# It: 160, Loss: 1.080e+02, Y0: -4.187, Time: 8.03, Learning Rate: 5.000e-04
# It: 170, Loss: 7.834e+01, Y0: -4.676, Time: 8.03, Learning Rate: 5.000e-04
# It: 180, Loss: 1.235e+02, Y0: -3.681, Time: 8.02, Learning Rate: 5.000e-04
# It: 190, Loss: 8.381e+01, Y0: -5.851, Time: 8.08, Learning Rate: 5.000e-04
# It: 200, Loss: 1.521e+02, Y0: -7.815, Time: 8.07, Learning Rate: 5.000e-04
# It: 210, Loss: 1.697e+02, Y0: -8.269, Time: 8.09, Learning Rate: 5.000e-04
# It: 220, Loss: 1.085e+02, Y0: -0.979, Time: 8.10, Learning Rate: 5.000e-04
# It: 230, Loss: 1.192e+02, Y0: -5.972, Time: 8.21, Learning Rate: 5.000e-04
# It: 240, Loss: 1.198e+02, Y0: -6.747, Time: 8.20, Learning Rate: 5.000e-04
# It: 250, Loss: 1.152e+02, Y0: -3.072, Time: 8.10, Learning Rate: 5.000e-04
# It: 260, Loss: 8.688e+01, Y0: -5.428, Time: 7.99, Learning Rate: 5.000e-04
# It: 270, Loss: 8.324e+01, Y0: -2.752, Time: 8.00, Learning Rate: 5.000e-04
# It: 280, Loss: 1.259e+02, Y0: -8.030, Time: 8.21, Learning Rate: 5.000e-04
# It: 290, Loss: 9.953e+01, Y0: -4.608, Time: 8.04, Learning Rate: 5.000e-04
# It: 300, Loss: 8.106e+01, Y0: -5.002, Time: 8.15, Learning Rate: 5.000e-04
# It: 310, Loss: 9.432e+01, Y0: -5.892, Time: 8.18, Learning Rate: 5.000e-04
# It: 320, Loss: 8.051e+01, Y0: -5.771, Time: 8.15, Learning Rate: 5.000e-04
# It: 330, Loss: 7.507e+01, Y0: -4.466, Time: 8.16, Learning Rate: 5.000e-04
# It: 340, Loss: 1.068e+02, Y0: -5.332, Time: 8.17, Learning Rate: 5.000e-04
# It: 350, Loss: 1.017e+02, Y0: -6.360, Time: 8.03, Learning Rate: 5.000e-04
# It: 360, Loss: 9.247e+01, Y0: -4.470, Time: 8.12, Learning Rate: 5.000e-04
# It: 370, Loss: 9.350e+01, Y0: -4.604, Time: 8.12, Learning Rate: 5.000e-04
# It: 380, Loss: 1.025e+02, Y0: -5.063, Time: 8.03, Learning Rate: 5.000e-04
# It: 390, Loss: 9.602e+01, Y0: -6.007, Time: 8.02, Learning Rate: 5.000e-04
# It: 400, Loss: 8.927e+01, Y0: -7.098, Time: 8.09, Learning Rate: 5.000e-04
# It: 410, Loss: 9.328e+01, Y0: -5.099, Time: 8.04, Learning Rate: 5.000e-04
# It: 420, Loss: 9.150e+01, Y0: -7.148, Time: 8.30, Learning Rate: 5.000e-04
# It: 430, Loss: 8.609e+01, Y0: -7.196, Time: 8.13, Learning Rate: 5.000e-04
# It: 440, Loss: 8.279e+01, Y0: -5.364, Time: 7.96, Learning Rate: 5.000e-04
# It: 450, Loss: 7.802e+01, Y0: -4.245, Time: 8.06, Learning Rate: 5.000e-04
# It: 460, Loss: 8.920e+01, Y0: -6.429, Time: 8.15, Learning Rate: 5.000e-04
# It: 470, Loss: 7.089e+01, Y0: -5.301, Time: 8.26, Learning Rate: 5.000e-04
# It: 480, Loss: 8.331e+01, Y0: -4.610, Time: 8.09, Learning Rate: 5.000e-04
# It: 490, Loss: 8.984e+01, Y0: -6.834, Time: 8.06, Learning Rate: 5.000e-04
# It: 500, Loss: 8.003e+01, Y0: -6.535, Time: 8.03, Learning Rate: 5.000e-04
# It: 510, Loss: 1.116e+02, Y0: -5.569, Time: 8.15, Learning Rate: 5.000e-04
# It: 520, Loss: 8.263e+01, Y0: -4.230, Time: 8.09, Learning Rate: 5.000e-04
# It: 530, Loss: 7.884e+01, Y0: -5.974, Time: 8.09, Learning Rate: 5.000e-04
# It: 540, Loss: 8.199e+01, Y0: -6.931, Time: 8.26, Learning Rate: 5.000e-04
# It: 550, Loss: 7.209e+01, Y0: -5.980, Time: 8.06, Learning Rate: 5.000e-04
# It: 560, Loss: 7.217e+01, Y0: -5.582, Time: 8.06, Learning Rate: 5.000e-04
# It: 570, Loss: 9.145e+01, Y0: -6.909, Time: 8.18, Learning Rate: 5.000e-04
# It: 580, Loss: 8.650e+01, Y0: -4.815, Time: 8.11, Learning Rate: 5.000e-04
# It: 590, Loss: 7.417e+01, Y0: -7.431, Time: 8.07, Learning Rate: 5.000e-04
# It: 600, Loss: 7.623e+01, Y0: -7.296, Time: 8.06, Learning Rate: 5.000e-04
# It: 610, Loss: 8.339e+01, Y0: -6.247, Time: 8.06, Learning Rate: 5.000e-04
# It: 620, Loss: 9.458e+01, Y0: -8.884, Time: 8.23, Learning Rate: 5.000e-04
# It: 630, Loss: 7.641e+01, Y0: -7.532, Time: 8.11, Learning Rate: 5.000e-04
# It: 640, Loss: 1.127e+02, Y0: -6.740, Time: 8.10, Learning Rate: 5.000e-04
# It: 650, Loss: 1.123e+02, Y0: -7.380, Time: 8.25, Learning Rate: 5.000e-04
# It: 660, Loss: 9.343e+01, Y0: -5.791, Time: 8.22, Learning Rate: 5.000e-04
# It: 670, Loss: 1.003e+02, Y0: -5.972, Time: 8.27, Learning Rate: 5.000e-04
# It: 680, Loss: 9.907e+01, Y0: -6.486, Time: 8.09, Learning Rate: 5.000e-04
# It: 690, Loss: 7.960e+01, Y0: -5.929, Time: 8.21, Learning Rate: 5.000e-04
# [StageSummary] const=1.0, lr=5.0e-04, iters=700, eval_loss=8.371e+01±4.69e+00, eval_Y0=-6.051±0.000, time=586.1s
# It: 0, Loss: 8.135e+01, Y0: -6.034, Time: 0.79, Learning Rate: 1.000e-04
# It: 10, Loss: 7.199e+01, Y0: -5.440, Time: 8.15, Learning Rate: 1.000e-04
# It: 20, Loss: 6.789e+01, Y0: -5.858, Time: 8.03, Learning Rate: 1.000e-04
# It: 30, Loss: 7.508e+01, Y0: -5.826, Time: 8.12, Learning Rate: 1.000e-04
# It: 40, Loss: 6.387e+01, Y0: -5.724, Time: 8.11, Learning Rate: 1.000e-04
# It: 50, Loss: 8.048e+01, Y0: -6.302, Time: 8.15, Learning Rate: 1.000e-04
# It: 60, Loss: 7.120e+01, Y0: -6.261, Time: 8.13, Learning Rate: 1.000e-04
# It: 70, Loss: 7.523e+01, Y0: -6.027, Time: 8.10, Learning Rate: 1.000e-04
# It: 80, Loss: 7.326e+01, Y0: -6.145, Time: 8.11, Learning Rate: 1.000e-04
# It: 90, Loss: 8.379e+01, Y0: -5.902, Time: 8.27, Learning Rate: 1.000e-04
# It: 100, Loss: 9.106e+01, Y0: -6.531, Time: 8.11, Learning Rate: 1.000e-04
# It: 110, Loss: 7.092e+01, Y0: -6.021, Time: 8.03, Learning Rate: 1.000e-04
# It: 120, Loss: 7.610e+01, Y0: -6.343, Time: 8.15, Learning Rate: 1.000e-04
# It: 130, Loss: 8.735e+01, Y0: -6.447, Time: 8.10, Learning Rate: 1.000e-04
# It: 140, Loss: 6.475e+01, Y0: -6.419, Time: 8.12, Learning Rate: 1.000e-04
# It: 150, Loss: 6.560e+01, Y0: -6.282, Time: 8.18, Learning Rate: 1.000e-04
# It: 160, Loss: 6.963e+01, Y0: -6.575, Time: 8.10, Learning Rate: 1.000e-04
# It: 170, Loss: 6.636e+01, Y0: -6.383, Time: 8.22, Learning Rate: 1.000e-04
# It: 180, Loss: 7.523e+01, Y0: -6.186, Time: 8.12, Learning Rate: 1.000e-04
# It: 190, Loss: 6.526e+01, Y0: -6.098, Time: 8.11, Learning Rate: 1.000e-04
# It: 200, Loss: 7.341e+01, Y0: -6.496, Time: 8.11, Learning Rate: 1.000e-04
# It: 210, Loss: 7.809e+01, Y0: -6.258, Time: 8.09, Learning Rate: 1.000e-04
# It: 220, Loss: 7.139e+01, Y0: -6.456, Time: 8.09, Learning Rate: 1.000e-04
# It: 230, Loss: 6.615e+01, Y0: -6.946, Time: 8.11, Learning Rate: 1.000e-04
# It: 240, Loss: 6.832e+01, Y0: -6.667, Time: 8.10, Learning Rate: 1.000e-04
# It: 250, Loss: 7.164e+01, Y0: -6.267, Time: 8.09, Learning Rate: 1.000e-04
# It: 260, Loss: 7.913e+01, Y0: -6.396, Time: 8.06, Learning Rate: 1.000e-04
# It: 270, Loss: 6.231e+01, Y0: -6.988, Time: 8.14, Learning Rate: 1.000e-04
# It: 280, Loss: 6.394e+01, Y0: -6.478, Time: 8.15, Learning Rate: 1.000e-04
# It: 290, Loss: 8.387e+01, Y0: -6.614, Time: 8.02, Learning Rate: 1.000e-04
# It: 300, Loss: 6.489e+01, Y0: -6.925, Time: 8.16, Learning Rate: 1.000e-04
# It: 310, Loss: 6.708e+01, Y0: -6.773, Time: 8.10, Learning Rate: 1.000e-04
# It: 320, Loss: 6.704e+01, Y0: -6.082, Time: 8.27, Learning Rate: 1.000e-04
# It: 330, Loss: 7.875e+01, Y0: -6.947, Time: 8.21, Learning Rate: 1.000e-04
# It: 340, Loss: 7.046e+01, Y0: -6.897, Time: 8.04, Learning Rate: 1.000e-04
# It: 350, Loss: 7.307e+01, Y0: -6.446, Time: 8.11, Learning Rate: 1.000e-04
# It: 360, Loss: 6.459e+01, Y0: -6.714, Time: 8.16, Learning Rate: 1.000e-04
# It: 370, Loss: 6.790e+01, Y0: -6.832, Time: 7.98, Learning Rate: 1.000e-04
# It: 380, Loss: 8.071e+01, Y0: -7.076, Time: 8.08, Learning Rate: 1.000e-04
# It: 390, Loss: 7.001e+01, Y0: -7.072, Time: 8.19, Learning Rate: 1.000e-04
# It: 400, Loss: 6.921e+01, Y0: -6.659, Time: 8.06, Learning Rate: 1.000e-04
# It: 410, Loss: 6.597e+01, Y0: -7.239, Time: 8.01, Learning Rate: 1.000e-04
# It: 420, Loss: 6.864e+01, Y0: -6.377, Time: 8.16, Learning Rate: 1.000e-04
# It: 430, Loss: 6.770e+01, Y0: -6.719, Time: 8.07, Learning Rate: 1.000e-04
# It: 440, Loss: 7.103e+01, Y0: -7.042, Time: 8.05, Learning Rate: 1.000e-04
# It: 450, Loss: 6.480e+01, Y0: -8.131, Time: 8.16, Learning Rate: 1.000e-04
# It: 460, Loss: 7.045e+01, Y0: -7.868, Time: 8.14, Learning Rate: 1.000e-04
# It: 470, Loss: 6.986e+01, Y0: -6.910, Time: 8.05, Learning Rate: 1.000e-04
# It: 480, Loss: 6.583e+01, Y0: -6.812, Time: 8.15, Learning Rate: 1.000e-04
# It: 490, Loss: 6.816e+01, Y0: -7.019, Time: 8.06, Learning Rate: 1.000e-04
# It: 500, Loss: 7.766e+01, Y0: -6.775, Time: 8.11, Learning Rate: 1.000e-04
# It: 510, Loss: 6.605e+01, Y0: -7.220, Time: 8.04, Learning Rate: 1.000e-04
# It: 520, Loss: 6.237e+01, Y0: -7.264, Time: 8.25, Learning Rate: 1.000e-04
# It: 530, Loss: 6.805e+01, Y0: -7.169, Time: 8.11, Learning Rate: 1.000e-04
# It: 540, Loss: 6.965e+01, Y0: -7.120, Time: 8.03, Learning Rate: 1.000e-04
# It: 550, Loss: 6.429e+01, Y0: -7.500, Time: 8.02, Learning Rate: 1.000e-04
# It: 560, Loss: 6.653e+01, Y0: -7.731, Time: 8.20, Learning Rate: 1.000e-04
# It: 570, Loss: 8.427e+01, Y0: -7.141, Time: 8.09, Learning Rate: 1.000e-04
# It: 580, Loss: 6.462e+01, Y0: -6.584, Time: 8.15, Learning Rate: 1.000e-04
# It: 590, Loss: 6.691e+01, Y0: -6.950, Time: 8.09, Learning Rate: 1.000e-04
# It: 600, Loss: 7.115e+01, Y0: -6.550, Time: 8.19, Learning Rate: 1.000e-04
# It: 610, Loss: 7.141e+01, Y0: -6.208, Time: 8.10, Learning Rate: 1.000e-04
# It: 620, Loss: 6.752e+01, Y0: -7.672, Time: 8.01, Learning Rate: 1.000e-04
# It: 630, Loss: 6.613e+01, Y0: -7.436, Time: 8.03, Learning Rate: 1.000e-04
# It: 640, Loss: 6.715e+01, Y0: -6.802, Time: 8.05, Learning Rate: 1.000e-04
# It: 650, Loss: 6.795e+01, Y0: -7.570, Time: 8.17, Learning Rate: 1.000e-04
# It: 660, Loss: 7.668e+01, Y0: -6.934, Time: 8.03, Learning Rate: 1.000e-04
# It: 670, Loss: 6.748e+01, Y0: -6.851, Time: 8.12, Learning Rate: 1.000e-04
# It: 680, Loss: 6.738e+01, Y0: -6.975, Time: 8.01, Learning Rate: 1.000e-04
# It: 690, Loss: 6.706e+01, Y0: -7.348, Time: 8.12, Learning Rate: 1.000e-04
# [StageSummary] const=1.0, lr=1.0e-04, iters=700, eval_loss=6.809e+01±4.34e+00, eval_Y0=-7.262±0.000, time=585.6s
# === Final fine-tuning at const=1.0 ===
# It: 0, Loss: 6.850e+01, Y0: -7.257, Time: 0.84, Learning Rate: 1.000e-05
# It: 10, Loss: 6.941e+01, Y0: -7.238, Time: 8.05, Learning Rate: 1.000e-05
# It: 20, Loss: 6.557e+01, Y0: -7.239, Time: 8.05, Learning Rate: 1.000e-05
# It: 30, Loss: 6.686e+01, Y0: -7.305, Time: 8.04, Learning Rate: 1.000e-05
# It: 40, Loss: 6.131e+01, Y0: -7.292, Time: 8.11, Learning Rate: 1.000e-05
# It: 50, Loss: 6.316e+01, Y0: -7.356, Time: 8.17, Learning Rate: 1.000e-05
# It: 60, Loss: 5.989e+01, Y0: -7.403, Time: 8.35, Learning Rate: 1.000e-05
# It: 70, Loss: 6.568e+01, Y0: -7.329, Time: 8.06, Learning Rate: 1.000e-05
# It: 80, Loss: 6.605e+01, Y0: -7.273, Time: 8.20, Learning Rate: 1.000e-05
# It: 90, Loss: 6.638e+01, Y0: -7.211, Time: 8.05, Learning Rate: 1.000e-05
# It: 100, Loss: 9.542e+01, Y0: -7.295, Time: 8.11, Learning Rate: 1.000e-05
# It: 110, Loss: 7.175e+01, Y0: -7.435, Time: 8.18, Learning Rate: 1.000e-05
# It: 120, Loss: 6.863e+01, Y0: -7.391, Time: 8.12, Learning Rate: 1.000e-05
# It: 130, Loss: 6.481e+01, Y0: -7.356, Time: 8.10, Learning Rate: 1.000e-05
# It: 140, Loss: 6.821e+01, Y0: -7.432, Time: 8.06, Learning Rate: 1.000e-05
# It: 150, Loss: 6.729e+01, Y0: -7.403, Time: 8.12, Learning Rate: 1.000e-05
# It: 160, Loss: 6.938e+01, Y0: -7.331, Time: 8.20, Learning Rate: 1.000e-05
# It: 170, Loss: 6.751e+01, Y0: -7.241, Time: 8.24, Learning Rate: 1.000e-05
# It: 180, Loss: 7.448e+01, Y0: -7.316, Time: 8.02, Learning Rate: 1.000e-05
# It: 190, Loss: 6.279e+01, Y0: -7.371, Time: 7.97, Learning Rate: 1.000e-05
# It: 200, Loss: 6.384e+01, Y0: -7.362, Time: 8.06, Learning Rate: 1.000e-05
# It: 210, Loss: 6.735e+01, Y0: -7.244, Time: 8.16, Learning Rate: 1.000e-05
# It: 220, Loss: 5.873e+01, Y0: -7.177, Time: 8.19, Learning Rate: 1.000e-05
# It: 230, Loss: 6.137e+01, Y0: -7.268, Time: 8.03, Learning Rate: 1.000e-05
# It: 240, Loss: 6.489e+01, Y0: -7.389, Time: 8.05, Learning Rate: 1.000e-05
# It: 250, Loss: 6.737e+01, Y0: -7.401, Time: 8.17, Learning Rate: 1.000e-05
# It: 260, Loss: 7.998e+01, Y0: -7.489, Time: 8.01, Learning Rate: 1.000e-05
# It: 270, Loss: 6.523e+01, Y0: -7.470, Time: 8.11, Learning Rate: 1.000e-05
# It: 280, Loss: 6.169e+01, Y0: -7.388, Time: 8.01, Learning Rate: 1.000e-05
# It: 290, Loss: 9.357e+01, Y0: -7.250, Time: 8.08, Learning Rate: 1.000e-05
# It: 300, Loss: 6.643e+01, Y0: -7.273, Time: 7.94, Learning Rate: 1.000e-05
# It: 310, Loss: 7.620e+01, Y0: -7.273, Time: 8.24, Learning Rate: 1.000e-05
# It: 320, Loss: 7.584e+01, Y0: -7.240, Time: 8.02, Learning Rate: 1.000e-05
# It: 330, Loss: 6.424e+01, Y0: -7.302, Time: 8.15, Learning Rate: 1.000e-05
# It: 340, Loss: 6.414e+01, Y0: -7.387, Time: 8.04, Learning Rate: 1.000e-05
# It: 350, Loss: 6.350e+01, Y0: -7.368, Time: 8.14, Learning Rate: 1.000e-05
# It: 360, Loss: 6.669e+01, Y0: -7.285, Time: 8.02, Learning Rate: 1.000e-05
# It: 370, Loss: 6.321e+01, Y0: -7.221, Time: 8.17, Learning Rate: 1.000e-05
# It: 380, Loss: 6.397e+01, Y0: -7.268, Time: 8.17, Learning Rate: 1.000e-05
# It: 390, Loss: 6.698e+01, Y0: -7.282, Time: 8.16, Learning Rate: 1.000e-05
# It: 400, Loss: 6.162e+01, Y0: -7.286, Time: 8.04, Learning Rate: 1.000e-05
# It: 410, Loss: 7.189e+01, Y0: -7.228, Time: 8.15, Learning Rate: 1.000e-05
# It: 420, Loss: 6.294e+01, Y0: -7.163, Time: 8.41, Learning Rate: 1.000e-05
# It: 430, Loss: 6.375e+01, Y0: -7.302, Time: 8.13, Learning Rate: 1.000e-05
# It: 440, Loss: 6.347e+01, Y0: -7.408, Time: 8.15, Learning Rate: 1.000e-05
# It: 450, Loss: 6.310e+01, Y0: -7.442, Time: 8.22, Learning Rate: 1.000e-05
# It: 460, Loss: 6.369e+01, Y0: -7.346, Time: 8.13, Learning Rate: 1.000e-05
# It: 470, Loss: 6.950e+01, Y0: -7.304, Time: 8.13, Learning Rate: 1.000e-05
# It: 480, Loss: 6.543e+01, Y0: -7.376, Time: 8.03, Learning Rate: 1.000e-05
# It: 490, Loss: 6.261e+01, Y0: -7.507, Time: 8.04, Learning Rate: 1.000e-05
# It: 500, Loss: 6.632e+01, Y0: -7.455, Time: 8.31, Learning Rate: 1.000e-05
# It: 510, Loss: 6.424e+01, Y0: -7.325, Time: 8.07, Learning Rate: 1.000e-05
# It: 520, Loss: 7.412e+01, Y0: -7.297, Time: 8.11, Learning Rate: 1.000e-05
# It: 530, Loss: 6.392e+01, Y0: -7.289, Time: 8.26, Learning Rate: 1.000e-05
# It: 540, Loss: 6.247e+01, Y0: -7.236, Time: 8.18, Learning Rate: 1.000e-05
# It: 550, Loss: 6.765e+01, Y0: -7.243, Time: 8.06, Learning Rate: 1.000e-05
# It: 560, Loss: 6.750e+01, Y0: -7.349, Time: 8.14, Learning Rate: 1.000e-05
# It: 570, Loss: 7.741e+01, Y0: -7.408, Time: 8.07, Learning Rate: 1.000e-05
# It: 580, Loss: 6.284e+01, Y0: -7.384, Time: 8.19, Learning Rate: 1.000e-05
# It: 590, Loss: 6.890e+01, Y0: -7.325, Time: 8.15, Learning Rate: 1.000e-05
# It: 600, Loss: 6.940e+01, Y0: -7.201, Time: 8.07, Learning Rate: 1.000e-05
# It: 610, Loss: 7.303e+01, Y0: -7.310, Time: 8.15, Learning Rate: 1.000e-05
# It: 620, Loss: 6.414e+01, Y0: -7.369, Time: 8.20, Learning Rate: 1.000e-05
# It: 630, Loss: 6.666e+01, Y0: -7.280, Time: 8.03, Learning Rate: 1.000e-05
# It: 640, Loss: 6.103e+01, Y0: -7.312, Time: 8.04, Learning Rate: 1.000e-05
# It: 650, Loss: 6.349e+01, Y0: -7.388, Time: 8.14, Learning Rate: 1.000e-05
# It: 660, Loss: 6.525e+01, Y0: -7.389, Time: 8.25, Learning Rate: 1.000e-05
# It: 670, Loss: 6.393e+01, Y0: -7.466, Time: 8.16, Learning Rate: 1.000e-05
# It: 680, Loss: 6.497e+01, Y0: -7.426, Time: 8.11, Learning Rate: 1.000e-05
# It: 690, Loss: 6.516e+01, Y0: -7.352, Time: 8.23, Learning Rate: 1.000e-05
# [FinalSummary] const=1.0, lr=1.0e-05, iters=700, eval_loss=7.166e+01±1.26e+01, eval_Y0=-7.176±0.000, time=587.1s
# It: 0, Loss: 6.491e+01, Y0: -7.178, Time: 0.80, Learning Rate: 5.000e-06
# It: 10, Loss: 6.270e+01, Y0: -7.184, Time: 8.05, Learning Rate: 5.000e-06
# It: 20, Loss: 6.802e+01, Y0: -7.249, Time: 8.11, Learning Rate: 5.000e-06
# It: 30, Loss: 6.724e+01, Y0: -7.322, Time: 8.12, Learning Rate: 5.000e-06
# It: 40, Loss: 6.542e+01, Y0: -7.314, Time: 8.04, Learning Rate: 5.000e-06
# It: 50, Loss: 6.744e+01, Y0: -7.305, Time: 8.10, Learning Rate: 5.000e-06
# It: 60, Loss: 6.052e+01, Y0: -7.329, Time: 8.03, Learning Rate: 5.000e-06
# It: 70, Loss: 6.639e+01, Y0: -7.305, Time: 8.11, Learning Rate: 5.000e-06
# It: 80, Loss: 6.389e+01, Y0: -7.262, Time: 8.29, Learning Rate: 5.000e-06
# It: 90, Loss: 6.131e+01, Y0: -7.217, Time: 8.04, Learning Rate: 5.000e-06
# It: 100, Loss: 6.486e+01, Y0: -7.254, Time: 7.98, Learning Rate: 5.000e-06
# It: 110, Loss: 7.963e+01, Y0: -7.316, Time: 8.31, Learning Rate: 5.000e-06
# It: 120, Loss: 6.558e+01, Y0: -7.398, Time: 8.13, Learning Rate: 5.000e-06
# It: 130, Loss: 6.508e+01, Y0: -7.409, Time: 8.13, Learning Rate: 5.000e-06
# It: 140, Loss: 6.684e+01, Y0: -7.398, Time: 8.03, Learning Rate: 5.000e-06
# It: 150, Loss: 6.210e+01, Y0: -7.362, Time: 8.15, Learning Rate: 5.000e-06
# It: 160, Loss: 6.321e+01, Y0: -7.294, Time: 8.07, Learning Rate: 5.000e-06
# It: 170, Loss: 5.944e+01, Y0: -7.312, Time: 8.07, Learning Rate: 5.000e-06
# It: 180, Loss: 6.660e+01, Y0: -7.383, Time: 8.25, Learning Rate: 5.000e-06
# It: 190, Loss: 6.402e+01, Y0: -7.385, Time: 8.17, Learning Rate: 5.000e-06
# It: 200, Loss: 6.416e+01, Y0: -7.331, Time: 8.10, Learning Rate: 5.000e-06
# It: 210, Loss: 6.084e+01, Y0: -7.310, Time: 8.07, Learning Rate: 5.000e-06
# It: 220, Loss: 6.211e+01, Y0: -7.320, Time: 8.05, Learning Rate: 5.000e-06
# It: 230, Loss: 6.782e+01, Y0: -7.328, Time: 8.08, Learning Rate: 5.000e-06
# It: 240, Loss: 6.752e+01, Y0: -7.337, Time: 8.04, Learning Rate: 5.000e-06
# It: 250, Loss: 6.416e+01, Y0: -7.300, Time: 8.12, Learning Rate: 5.000e-06
# It: 260, Loss: 6.205e+01, Y0: -7.258, Time: 8.03, Learning Rate: 5.000e-06
# It: 270, Loss: 6.363e+01, Y0: -7.243, Time: 8.14, Learning Rate: 5.000e-06
# It: 280, Loss: 6.598e+01, Y0: -7.267, Time: 8.12, Learning Rate: 5.000e-06
# It: 290, Loss: 6.559e+01, Y0: -7.353, Time: 8.17, Learning Rate: 5.000e-06
# It: 300, Loss: 8.670e+01, Y0: -7.357, Time: 8.07, Learning Rate: 5.000e-06
# It: 310, Loss: 6.224e+01, Y0: -7.324, Time: 7.98, Learning Rate: 5.000e-06
# It: 320, Loss: 6.571e+01, Y0: -7.288, Time: 8.16, Learning Rate: 5.000e-06
# It: 330, Loss: 6.386e+01, Y0: -7.275, Time: 8.22, Learning Rate: 5.000e-06
# It: 340, Loss: 5.972e+01, Y0: -7.280, Time: 8.19, Learning Rate: 5.000e-06
# It: 350, Loss: 7.756e+01, Y0: -7.277, Time: 8.23, Learning Rate: 5.000e-06
# It: 360, Loss: 7.239e+01, Y0: -7.272, Time: 8.09, Learning Rate: 5.000e-06
# It: 370, Loss: 6.191e+01, Y0: -7.276, Time: 8.14, Learning Rate: 5.000e-06
# It: 380, Loss: 6.207e+01, Y0: -7.298, Time: 8.15, Learning Rate: 5.000e-06
# It: 390, Loss: 7.476e+01, Y0: -7.308, Time: 8.06, Learning Rate: 5.000e-06
# It: 400, Loss: 6.616e+01, Y0: -7.303, Time: 8.09, Learning Rate: 5.000e-06
# It: 410, Loss: 7.032e+01, Y0: -7.267, Time: 8.21, Learning Rate: 5.000e-06
# It: 420, Loss: 6.104e+01, Y0: -7.271, Time: 8.10, Learning Rate: 5.000e-06
# It: 430, Loss: 8.013e+01, Y0: -7.325, Time: 8.08, Learning Rate: 5.000e-06
# It: 440, Loss: 6.619e+01, Y0: -7.318, Time: 8.04, Learning Rate: 5.000e-06
# It: 450, Loss: 7.601e+01, Y0: -7.282, Time: 8.11, Learning Rate: 5.000e-06
# It: 460, Loss: 6.369e+01, Y0: -7.213, Time: 8.05, Learning Rate: 5.000e-06
# It: 470, Loss: 6.535e+01, Y0: -7.223, Time: 8.11, Learning Rate: 5.000e-06
# It: 480, Loss: 7.075e+01, Y0: -7.250, Time: 8.11, Learning Rate: 5.000e-06
# It: 490, Loss: 6.415e+01, Y0: -7.259, Time: 8.09, Learning Rate: 5.000e-06
# [FinalSummary] const=1.0, lr=5.0e-06, iters=500, eval_loss=6.848e+01±4.18e+00, eval_Y0=-7.254±0.000, time=418.7s
# It: 0, Loss: 6.946e+01, Y0: -7.253, Time: 0.79, Learning Rate: 1.000e-06
# It: 10, Loss: 6.248e+01, Y0: -7.250, Time: 8.20, Learning Rate: 1.000e-06
# It: 20, Loss: 6.610e+01, Y0: -7.262, Time: 8.04, Learning Rate: 1.000e-06
# It: 30, Loss: 6.488e+01, Y0: -7.265, Time: 8.04, Learning Rate: 1.000e-06
# It: 40, Loss: 6.571e+01, Y0: -7.270, Time: 8.16, Learning Rate: 1.000e-06
# It: 50, Loss: 6.807e+01, Y0: -7.273, Time: 8.01, Learning Rate: 1.000e-06
# It: 60, Loss: 6.416e+01, Y0: -7.270, Time: 8.19, Learning Rate: 1.000e-06
# It: 70, Loss: 6.470e+01, Y0: -7.262, Time: 8.04, Learning Rate: 1.000e-06
# It: 80, Loss: 6.259e+01, Y0: -7.250, Time: 8.17, Learning Rate: 1.000e-06
# It: 90, Loss: 6.203e+01, Y0: -7.242, Time: 8.24, Learning Rate: 1.000e-06
# It: 100, Loss: 6.512e+01, Y0: -7.249, Time: 8.15, Learning Rate: 1.000e-06
# It: 110, Loss: 6.098e+01, Y0: -7.258, Time: 8.07, Learning Rate: 1.000e-06
# It: 120, Loss: 6.875e+01, Y0: -7.269, Time: 8.21, Learning Rate: 1.000e-06
# It: 130, Loss: 6.603e+01, Y0: -7.282, Time: 8.23, Learning Rate: 1.000e-06
# It: 140, Loss: 6.822e+01, Y0: -7.293, Time: 8.05, Learning Rate: 1.000e-06
# It: 150, Loss: 6.036e+01, Y0: -7.295, Time: 7.98, Learning Rate: 1.000e-06
# It: 160, Loss: 6.201e+01, Y0: -7.297, Time: 8.10, Learning Rate: 1.000e-06
# It: 170, Loss: 6.404e+01, Y0: -7.299, Time: 8.02, Learning Rate: 1.000e-06
# It: 180, Loss: 6.041e+01, Y0: -7.302, Time: 8.05, Learning Rate: 1.000e-06
# It: 190, Loss: 6.367e+01, Y0: -7.300, Time: 8.13, Learning Rate: 1.000e-06
# It: 200, Loss: 6.844e+01, Y0: -7.306, Time: 8.18, Learning Rate: 1.000e-06
# It: 210, Loss: 6.321e+01, Y0: -7.306, Time: 8.07, Learning Rate: 1.000e-06
# It: 220, Loss: 7.433e+01, Y0: -7.302, Time: 8.16, Learning Rate: 1.000e-06
# It: 230, Loss: 6.616e+01, Y0: -7.297, Time: 8.02, Learning Rate: 1.000e-06
# It: 240, Loss: 6.429e+01, Y0: -7.300, Time: 8.11, Learning Rate: 1.000e-06
# It: 250, Loss: 6.550e+01, Y0: -7.296, Time: 8.22, Learning Rate: 1.000e-06
# It: 260, Loss: 6.481e+01, Y0: -7.290, Time: 8.10, Learning Rate: 1.000e-06
# It: 270, Loss: 6.106e+01, Y0: -7.296, Time: 8.07, Learning Rate: 1.000e-06
# It: 280, Loss: 7.182e+01, Y0: -7.298, Time: 8.28, Learning Rate: 1.000e-06
# It: 290, Loss: 7.353e+01, Y0: -7.300, Time: 8.13, Learning Rate: 1.000e-06
# [FinalSummary] const=1.0, lr=1.0e-06, iters=300, eval_loss=6.617e+01±3.67e+00, eval_Y0=-7.310±0.000, time=252.1s
# === Curriculum Log (compact) ===
# phase=curriculum, const=1.0, lr=1.0e-03, iters=700, eval_loss=2.251e+02, eval_y0=-7.938, elapsed_sec=828.6946697235107
# phase=curriculum, const=1.0, lr=5.0e-04, iters=700, eval_loss=8.371e+01, eval_y0=-6.051, elapsed_sec=586.1357762813568
# phase=curriculum, const=1.0, lr=1.0e-04, iters=700, eval_loss=6.809e+01, eval_y0=-7.262, elapsed_sec=585.5851876735687
# phase=final_finetune, const=1.0, lr=1.0e-05, iters=700, eval_loss=7.166e+01, eval_y0=-7.176, elapsed_sec=587.0627255439758
# phase=final_finetune, const=1.0, lr=5.0e-06, iters=500, eval_loss=6.848e+01, eval_y0=-7.254, elapsed_sec=418.7218134403229
# phase=final_finetune, const=1.0, lr=1.0e-06, iters=300, eval_loss=6.617e+01, eval_y0=-7.310, elapsed_sec=252.07915592193604

# %%
    # --- PLOTTING ---
    t_test, W_test = model.fetch_minibatch()
    X_pred, Y_pred, Z_pred = model.predict(Xi, t_test, W_test)

    def u_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X_state = Xi_arr[:, 3:4]
        return -params['gamma'] * np.exp(S)*X_state + V**2 + V*X_state

    def z_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X_state = Xi_arr[:, 3:4]

        s1 = params['s1']
        s2 = params['s2']
        s3 = params['s3']

        common = np.exp(-t)
        z_s = -params['gamma'] * np.exp(S)*X_state * s1
        z_h = np.zeros_like(z_s)
        z_v = (2 * V + X_state) * s3
        z_x = np.zeros_like(z_s)

        return np.concatenate([z_s, z_h, z_v, z_x], axis=1)

    Xi_reshaped = X_pred.reshape(-1, D)
    t_reshaped = t_test.reshape(-1, 1)

    Y_exact = u_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, 1)
    Z_exact = z_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, D)

    exact_Y0 = u_exact(np.array([[0.0]]), Xi)[0, 0]
    print(f"\nPredicted Y0: {Y_pred[0,0,0]:.4f}")
    print(f"Exact Y0:     {exact_Y0:.4f}")

    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], X_pred[0,:,0], 'b', label='S trajectory')
    plt.plot(t_test[0,:,0], X_pred[0,:,1], 'r', label='H trajectory')
    plt.plot(t_test[0,:,0], X_pred[0,:,2], 'y', label='V trajectory')
    plt.plot(t_test[0,:,0], X_pred[0,:,3], 'g', label='X trajectory')
    plt.title("Soluzione Sistema Pienamente Accoppiato 4D")
    plt.xlabel("Tempo t")
    plt.ylabel("A_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    #plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_FSDE.png")

    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], Y_pred[0,:,0], 'b', label='Learned Y')
    plt.plot(t_test[0,:,0], Y_exact[0,:,0], 'r--', label='Exact Y')
    plt.plot(t_test[1:5,:,0].T, Y_pred[1:5,:,0].T, 'b')
    plt.plot(t_test[1:5,:,0].T, Y_exact[1:5,:,0].T, 'r--')
    plt.title("Soluzione Sistema Pienamente Accoppiato 4D")
    plt.xlabel("Tempo t")
    plt.ylabel("Y_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    #plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_Y.png")

    # Errore relativo medio sui componenti di Z (stile log_z, ma corretto per ogni componente)
    eps = 1e-8
    rel_err_Z = np.abs((Z_pred - Z_exact) / (np.abs(Z_exact) + eps))
    mean_rel_err_Z = np.mean(rel_err_Z, axis=0)  # (N+1, D)

    labels = ['Z_S', 'Z_H', 'Z_V', 'Z_X']
    colors = ['b', 'g', 'r', 'm']

    plt.figure(figsize=(10,6))
    for d in range(D):
        plt.plot(t_test[0,:,0], mean_rel_err_Z[:, d], colors[d], label=f'Mean Rel Error {labels[d]}')
    plt.yscale('log')
    plt.title('Errore relativo medio di Z (scala log)')
    plt.xlabel('Tempo t')
    plt.ylabel('Errore relativo medio')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
    #plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_Z.png")
# Out:
# Predicted Y0: -7.3104
# Exact Y0:     -6.7500
