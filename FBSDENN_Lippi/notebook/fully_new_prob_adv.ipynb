# %% [markdown]
# ### Sistema Fully Coupled (Girsanov)
# $$
# \begin{cases}
# dS_t =\mu_1(c_1-S_t)dt + \sigma_1dW^1_t\\
# dH_t = \mu_2(c_2-H_t)dt + \sigma_2 dW^2_t\\
# dV_t = b_V(A_t)dt +\sigma_3 dW^3_t\\
# dX_t = V_t dt
# \end{cases}
# $$
# where
# $$
# b_V(A)=f(A)\Psi(X) + (c_3\Psi(-X)-c_4\Psi(X-10))\Psi(5(V+1))
# $$
# with
# $$\Psi(x)=\max(0,\min(1,x/d,(x_{max}-x)/d))$$ and $f$ a function that we will later choose with care, for now $f=0$$.

# %% [markdown]
# ### Soluzione
# $$
#     u(t,s,h,v,x) = -\gamma e^s x
# $$

# %% [markdown]
# ### Equazione backward
# $$
#  dY_t = -\gamma e^{S_t}\left( X_t \mu_1(c_1-S_t)+V_t +0.5\sigma_1^2X_t \right)dt + Z_t dW_t,
# $$
# where in the final solution $Z_t = (-\gamma e^{S_t}X_t\sigma_1,0,0,0)$.

# %% [markdown]
# ### Secondo Modello
# Qui si fissa $f(A)=-0.5 V \Psi(X)$ e con $X=-\frac{Z^S e^{-S_t}}{\gamma\sigma_1}$ (che viene sostituito solo dentro $f$)
# ### Terzo Modello
# La $X$ viene sostituita come sopra anche nel drift backward

# %%
## Rete neurale con normalizzazione della loss

import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from abc import ABC, abstractmethod


class FBSNN(ABC): # Forward-Backward Stochastic Neural Network
    def __init__(self, Xi, T,
                       M, N, D,
                       layers,
                       clip_grad_norm=1.0, 
                       use_antithetic_sampling=True):
        self.Xi = Xi # initial point
        self.T = T # terminal time

        self.M = M # number of trajectories
        self.N = N # number of time snapshots
        self.D = D # number of dimensions

        # layers
        self.layers = layers # (D+1) --> 1

        # migliorie advanced richieste
        self.clip_grad_norm = clip_grad_norm
        self.use_antithetic_sampling = bool(use_antithetic_sampling)

        # initialize NN
        self.weights, self.biases = self.initialize_NN(layers)

        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))

        # tf placeholders and graph (training)
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.t_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, 1]) # M x (N+1) x 1
        self.W_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, self.D]) # M x (N+1) x D
        self.Xi_tf = tf.placeholder(tf.float32, shape=[1, D]) # 1 x D
        self.const_tf = tf.placeholder(tf.float32, shape=[])

        self.loss, self.X_pred, self.Y_pred, self.Y0_pred, self.Z_pred = self.loss_function(self.t_tf, self.W_tf, self.Xi_tf)

        # optimizer + gradient clipping
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        gradients_and_variables = self.optimizer.compute_gradients(self.loss)
        if self.clip_grad_norm is not None:
            non_null_grads_and_vars = [(g, v) for g, v in gradients_and_variables if g is not None]
            if non_null_grads_and_vars:
                gradients, variables = zip(*non_null_grads_and_vars)
                gradients, _ = tf.clip_by_global_norm(gradients, self.clip_grad_norm)
                clipped = list(zip(gradients, variables))
                untouched = [(g, v) for g, v in gradients_and_variables if g is None]
                gradients_and_variables = clipped + untouched
        self.train_op = self.optimizer.apply_gradients(gradients_and_variables)

        # initialize session and variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = X
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    def net_u(self, t, X): # M x 1, M x D
        u = self.neural_net(tf.concat([t, X], 1), self.weights, self.biases) # M x 1
        Du = tf.gradients(u, X)[0] # M x D
        return u, Du

    def Dg_tf(self, X): # M x D
        return tf.gradients(self.g_tf(X), X)[0] # M x D

    def loss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        loss = 0
        X_list = []
        Y_list = []
        Z_list = []

        t0 = t[:, 0, :]
        W0 = W[:, 0, :]
        X0 = tf.tile(Xi, [self.M, 1]) # M x D
        Y0, Du0 = self.net_u(t0, X0) # M x 1, M x D
        sigma0 = self.sigma_tf(t0, X0, Y0)
        Z0 = tf.squeeze(tf.matmul(tf.expand_dims(Du0, 1), sigma0), axis=1)

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)

        for n in range(0, self.N):
            t1 = t[:, n + 1, :]
            W1 = W[:, n + 1, :]

            dW = W1 - W0
            sigma_dW = tf.squeeze(tf.matmul(sigma0, tf.expand_dims(dW, -1)), axis=[-1])
            X1 = X0 + self.mu_tf(t0, X0, Y0, Z0) * (t1 - t0) + sigma_dW

            # Z = Du*sigma e nella backward compare Z*dW.
            Y1_tilde = Y0 + self.phi_tf(t0, X0, Y0, Z0) * (t1 - t0) + tf.reduce_sum(Z0 * dW, axis=1, keepdims=True)

            Y1, Du1 = self.net_u(t1, X1)
            sigma1 = self.sigma_tf(t1, X1, Y1)
            Z1 = tf.squeeze(tf.matmul(tf.expand_dims(Du1, 1), sigma1), axis=1)

            loss += tf.reduce_sum(tf.square(Y1 - Y1_tilde))

            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            sigma0 = sigma1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)

        loss += tf.reduce_sum(tf.square(Y1 - self.g_tf(X1)))

        Dg = self.Dg_tf(X1)
        Z_terminal = tf.squeeze(tf.matmul(tf.expand_dims(Dg, 1), sigma1), axis=1)
        loss += tf.reduce_sum(tf.square(Z1 - Z_terminal))

        X = tf.stack(X_list, axis=1)
        Y = tf.stack(Y_list, axis=1)
        Z = tf.stack(Z_list, axis=1)

        return loss/self.N, X, Y, Y[0, 0, 0], Z

    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M, N + 1, 1)) # M x (N+1) x 1
        DW = np.zeros((M, N + 1, D)) # M x (N+1) x D

        dt = T / N

        Dt[:, 1:, :] = dt
        if self.use_antithetic_sampling and M > 1:
            half_M = M // 2
            DW_half = np.sqrt(dt) * np.random.normal(size=(half_M, N, D))
            DW[:half_M, 1:, :] = DW_half
            DW[half_M:2 * half_M, 1:, :] = -DW_half
            if M % 2 == 1:
                DW[-1, 1:, :] = np.sqrt(dt) * np.random.normal(size=(N, D))
        else:
            DW[:, 1:, :] = np.sqrt(dt) * np.random.normal(size=(M, N, D))

        t = np.cumsum(Dt, axis=1) # M x (N+1) x 1
        W = np.cumsum(DW, axis=1) # M x (N+1) x D

        return t, W

    def train(self, N_Iter, learning_rate, const_value=None):
        start_time = time.time()
        last_loss = None
        last_y0 = None

        current_const = np.float32(self.const if const_value is None else const_value)
        for it in range(N_Iter):
            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D

            tf_dict = {
                self.Xi_tf: self.Xi,
                self.t_tf: t_batch,
                self.W_tf: W_batch,
                self.learning_rate: learning_rate,
                self.const_tf: current_const,
            }

            self.sess.run(self.train_op, tf_dict)

            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.loss, self.Y0_pred, self.learning_rate], tf_dict)
                last_loss = float(loss_value)
                last_y0 = float(Y0_value)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()

        return {
            'const': float(current_const),
            'learning_rate': float(learning_rate),
            'n_iter': int(N_Iter),
            'last_loss': last_loss,
            'last_y0': last_y0,
        }

    def evaluate(self, const_value=None, n_batches=5):
        current_const = np.float32(self.const if const_value is None else const_value)
        losses = []
        y0s = []

        for _ in range(n_batches):
            t_batch, W_batch = self.fetch_minibatch()
            tf_dict = {
                self.Xi_tf: self.Xi,
                self.t_tf: t_batch,
                self.W_tf: W_batch,
                self.const_tf: current_const,
            }
            loss_value, y0_value = self.sess.run([self.loss, self.Y0_pred], tf_dict)
            losses.append(float(loss_value))
            y0s.append(float(y0_value))

        return {
            'const': float(current_const),
            'mean_loss': float(np.mean(losses)),
            'std_loss': float(np.std(losses)),
            'mean_y0': float(np.mean(y0s)),
            'std_y0': float(np.std(y0s)),
            'n_batches': int(n_batches),
        }

    def predict(self, Xi_star, t_star, W_star, const_value=None):
        current_const = np.float32(self.const if const_value is None else const_value)
        tf_dict = {
            self.Xi_tf: Xi_star,
            self.t_tf: t_star,
            self.W_tf: W_star,
            self.const_tf: current_const,
        }

        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        Z_star = self.sess.run(self.Z_pred, tf_dict)

        return X_star, Y_star, Z_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def phi_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        pass # M x1

    @abstractmethod
    def g_tf(self, X): # M x D
        pass # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return np.zeros([M, D]) # M x D

    @abstractmethod
    def sigma_tf(self, t, X, Y): # M x 1, M x D, M x 1
        M = self.M
        D = self.D
        return tf.matrix_diag(tf.ones([M, D])) # M x D x D
    ###########################################################################


# backward compatibility
fbsde_NN = FBSNN
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class NN_Quadratic_Coupled(FBSNN):
    def __init__(self, Xi, T, M, N, D, layers, parameters):
        self.mu1 = parameters['mu1']
        self.mu2 = parameters['mu2']
        self.c1 = parameters['c1']
        self.c2 = parameters['c2']
        self.c3 = parameters['c3']
        self.c4 = parameters['c4']
        self.gamma = parameters['gamma']
        self.s1 = parameters['s1']
        self.s2 = parameters['s2']
        self.s3 = parameters['s3']
        self.x_max = parameters['x_max']
        self.v_min = parameters['v_min']
        self.v_max = parameters['v_max']
        self.d = parameters['d']
        self.const = parameters['const']
        super().__init__(Xi, T, M, N, D, layers)

    def psi(self,X_state):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     tf.minimum(X_state/self.d, (self.x_max - X_state)/self.d)
                     )
                 )
        return result

    def psi3(self,V):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     (self.v_max- V)/self.d
                     )
                 )
        return result
    
    def psi4(self,V):
        #S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        result = tf.maximum(0.0,
                   tf.minimum(
                     1.0,
                     (V - self.v_min)/self.d
                     )
                 )
        return result

    def f(self,X,Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        Z_S, Z_H, Z_V, _ = tf.split(Z, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        gamma = tf.cast(self.gamma, tf.float32)
        exp_S = tf.exp(-S)
        return -0.5 * V * self.psi(- exp_S * Z_S /(gamma * s1))
    
    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu1 = tf.cast(self.mu1, tf.float32)
        mu2 = tf.cast(self.mu2, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        c2 = tf.cast(self.c2, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)
        c4 = tf.cast(self.c4, tf.float32)
        x_max = tf.cast(self.x_max, tf.float32)
        const = tf.cast(self.const_tf, tf.float32)
        dS = mu1 * (c1 - S)
        dH = mu2 * (c2 - H)
        dV = self.f(X,Z) * self.psi(X_state) + c3 * self.psi(-X_state)*self.psi3(V) - c4 * self.psi(X_state-x_max)*self.psi4(V)
        dX = V
        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        gamma = tf.cast(self.gamma, tf.float32)
        exp_S = tf.exp(S)
        return -gamma * exp_S * X_state + V**2 + V*X_state

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        Z_S, Z_H, Z_V, _ = tf.split(Z, num_or_size_splits=4, axis=1)
        
        mu1 = tf.cast(self.mu1, tf.float32)
        c1 = tf.cast(self.c1, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        c3 = tf.cast(self.c3, tf.float32)
        c4 = tf.cast(self.c4, tf.float32)
        x_max = tf.cast(self.x_max, tf.float32)
        gamma = tf.cast(self.gamma, tf.float32)
        const = tf.cast(self.const_tf, tf.float32)
        
        exp_S = tf.exp(S)

        term1 = -gamma * exp_S * X_state * mu1 * (c1-S)
        term2 = (2 * V + X_state) * (self.f(X,Z) * self.psi(X_state) + c3 * self.psi(-X_state)*self.psi3(V) - c4 * self.psi(X_state-x_max)*self.psi4(V))
        term3 = -gamma * exp_S * V + (0.5 * (Z_V/s3 - X_state))**2
        # V = 0.5 * (Z_V/s3 - X_state)
        term4 = -0.5 * gamma * exp_S * X_state * s1**2 + s3**2
        
        return term1 + term2 + term3 + term4
    
    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)

        return tf.stack([r1, r2, r3, r4], axis=1)

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    M = 2048 #se non basta vram abbassa a 1500
    N = 250
    D = 4
    T = 24

    params = {
        'mu1': np.float32(1.0),
        'mu2': np.float32(1.0),
        'c1': np.float32(1.0),
        'c2': np.float32(1.0),
        'c3': np.float32(10.0),
        'c4': np.float32(10.0),
        'gamma': np.float32(1.0),
        'd': np.float32(1.0),
        'x_max': np.float32(10.0),
        'v_max': np.float32(2.0),
        'v_min': np.float32(-2.0),
        's1': np.float32(0.5),
        's2': np.float32(0.5),
        's3': np.float32(0.5),
        # Soft-init: partenza disaccoppiata
        'const': np.float32(0.0),
    }

    Xi = np.array([np.log(4), 0.5, 0.5, 2.0]).reshape(1, D)

    layers = [D+1] + 4*[256] + [1]
    
    model = NN_Quadratic_Coupled(Xi, T, M, N, D, layers, params)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9

# %%
    # Curriculum sull'accoppiamento: const cresce gradualmente fino a 1.0
    coupling_step = 1.0
    coupling_levels = np.arange(1.0, 1.0 + coupling_step, coupling_step, dtype=np.float32)

    stage_plan = [
        (700, 1e-3),
        (700, 5e-4),
        (700, 1e-4),
        (700, 5e-5)
    ]
    stage_logs = []

    for level in coupling_levels:
        model.const = np.float32(level)
        print(f"=== Coupling stage: const={float(level):.1f} ===")
        for n_iter, lr in stage_plan:
            t0 = time.time()
            train_stats = model.train(N_Iter=n_iter, learning_rate=lr, const_value=level)
            eval_stats = model.evaluate(const_value=level, n_batches=5)
            elapsed = time.time() - t0
            log_row = {
                'phase': 'curriculum',
                'const': float(level),
                'lr': float(lr),
                'n_iter': int(n_iter),
                'train_last_loss': train_stats['last_loss'],
                'train_last_y0': train_stats['last_y0'],
                'eval_mean_loss': eval_stats['mean_loss'],
                'eval_std_loss': eval_stats['std_loss'],
                'eval_mean_y0': eval_stats['mean_y0'],
                'eval_std_y0': eval_stats['std_y0'],
                'elapsed_sec': float(elapsed),
            }
            stage_logs.append(log_row)
            print(
                f"[StageSummary] const={level:.1f}, lr={lr:.1e}, iters={n_iter}, "
                f"eval_loss={eval_stats['mean_loss']:.3e}±{eval_stats['std_loss']:.2e}, "
                f"eval_Y0={eval_stats['mean_y0']:.3f}±{eval_stats['std_y0']:.3f}, "
                f"time={elapsed:.1f}s"
            )

    # Fine-tuning finale fully coupled
    model.const = np.float32(1.0)
    print("=== Final fine-tuning at const=1.0 ===")
    final_plan = [(700, 1e-5), (700, 5e-6) ,(700, 1e-6)]
    for n_iter, lr in final_plan:
        t0 = time.time()
        train_stats = model.train(N_Iter=n_iter, learning_rate=lr, const_value=1.0)
        eval_stats = model.evaluate(const_value=1.0, n_batches=5)
        elapsed = time.time() - t0
        log_row = {
            'phase': 'final_finetune',
            'const': 1.0,
            'lr': float(lr),
            'n_iter': int(n_iter),
            'train_last_loss': train_stats['last_loss'],
            'train_last_y0': train_stats['last_y0'],
            'eval_mean_loss': eval_stats['mean_loss'],
            'eval_std_loss': eval_stats['std_loss'],
            'eval_mean_y0': eval_stats['mean_y0'],
            'eval_std_y0': eval_stats['std_y0'],
            'elapsed_sec': float(elapsed),
        }
        stage_logs.append(log_row)
        print(
            f"[FinalSummary] const=1.0, lr={lr:.1e}, iters={n_iter}, "
            f"eval_loss={eval_stats['mean_loss']:.3e}±{eval_stats['std_loss']:.2e}, "
            f"eval_Y0={eval_stats['mean_y0']:.3f}±{eval_stats['std_y0']:.3f}, "
            f"time={elapsed:.1f}s"
        )

    print("=== Curriculum Log (compact) ===")
    for row in stage_logs:
        print(
            f"phase={row['phase']}, const={row['const']:.1f}, lr={row['lr']:.1e}, iters={row['n_iter']}, "
            f"eval_loss={row['eval_mean_loss']:.3e}, eval_y0={row['eval_mean_y0']:.3f}, elapsed_sec={row['elapsed_sec']}"
        )
# Out:
# === Coupling stage: const=1.0 ===
# It: 0, Loss: 7.569e+03, Y0: -0.255, Time: 186.61, Learning Rate: 1.000e-03
# It: 10, Loss: 1.534e+03, Y0: -3.892, Time: 8.15, Learning Rate: 1.000e-03
# It: 20, Loss: 1.278e+03, Y0: -16.855, Time: 8.12, Learning Rate: 1.000e-03
# It: 30, Loss: 1.075e+03, Y0: -17.841, Time: 7.98, Learning Rate: 1.000e-03
# It: 40, Loss: 8.088e+02, Y0: -16.615, Time: 8.13, Learning Rate: 1.000e-03
# It: 50, Loss: 7.832e+02, Y0: -17.201, Time: 8.13, Learning Rate: 1.000e-03
# It: 60, Loss: 7.010e+02, Y0: -17.382, Time: 7.96, Learning Rate: 1.000e-03
# It: 70, Loss: 6.290e+02, Y0: -17.818, Time: 7.99, Learning Rate: 1.000e-03
# It: 80, Loss: 5.446e+02, Y0: -18.117, Time: 8.07, Learning Rate: 1.000e-03
# It: 90, Loss: 5.795e+02, Y0: -15.959, Time: 8.04, Learning Rate: 1.000e-03
# It: 100, Loss: 4.075e+02, Y0: -14.331, Time: 8.23, Learning Rate: 1.000e-03
# It: 110, Loss: 4.289e+02, Y0: -14.787, Time: 7.98, Learning Rate: 1.000e-03
# It: 120, Loss: 5.192e+02, Y0: -10.452, Time: 8.11, Learning Rate: 1.000e-03
# It: 130, Loss: 6.847e+02, Y0: -12.035, Time: 8.06, Learning Rate: 1.000e-03
# It: 140, Loss: 4.730e+02, Y0: -7.452, Time: 8.03, Learning Rate: 1.000e-03
# It: 150, Loss: 4.831e+02, Y0: -7.535, Time: 8.01, Learning Rate: 1.000e-03
# It: 160, Loss: 3.023e+02, Y0: -7.990, Time: 8.12, Learning Rate: 1.000e-03
# It: 170, Loss: 4.951e+02, Y0: -10.171, Time: 8.12, Learning Rate: 1.000e-03
# It: 180, Loss: 3.420e+02, Y0: -8.302, Time: 7.94, Learning Rate: 1.000e-03
# It: 190, Loss: 3.620e+02, Y0: -8.618, Time: 7.97, Learning Rate: 1.000e-03
# It: 200, Loss: 2.579e+02, Y0: -7.099, Time: 8.05, Learning Rate: 1.000e-03
# It: 210, Loss: 2.307e+02, Y0: -7.498, Time: 8.04, Learning Rate: 1.000e-03
# It: 220, Loss: 2.274e+02, Y0: -9.406, Time: 7.98, Learning Rate: 1.000e-03
# It: 230, Loss: 2.584e+02, Y0: -4.914, Time: 7.98, Learning Rate: 1.000e-03
# It: 240, Loss: 1.918e+02, Y0: -6.468, Time: 8.08, Learning Rate: 1.000e-03
# It: 250, Loss: 2.340e+02, Y0: -6.618, Time: 7.94, Learning Rate: 1.000e-03
# It: 260, Loss: 2.614e+02, Y0: -8.313, Time: 8.08, Learning Rate: 1.000e-03
# It: 270, Loss: 2.689e+02, Y0: -2.094, Time: 8.08, Learning Rate: 1.000e-03
# It: 280, Loss: 1.713e+02, Y0: -2.640, Time: 8.05, Learning Rate: 1.000e-03
# It: 290, Loss: 1.649e+02, Y0: -2.747, Time: 8.01, Learning Rate: 1.000e-03
# It: 300, Loss: 2.169e+02, Y0: -4.647, Time: 8.10, Learning Rate: 1.000e-03
# It: 310, Loss: 2.015e+02, Y0: -1.328, Time: 8.13, Learning Rate: 1.000e-03
# It: 320, Loss: 1.867e+02, Y0: -3.793, Time: 8.07, Learning Rate: 1.000e-03
# It: 330, Loss: 1.716e+02, Y0: -3.737, Time: 8.09, Learning Rate: 1.000e-03
# It: 340, Loss: 2.218e+02, Y0: -7.102, Time: 8.06, Learning Rate: 1.000e-03
# It: 350, Loss: 2.191e+02, Y0: -3.098, Time: 8.06, Learning Rate: 1.000e-03
# It: 360, Loss: 1.917e+02, Y0: -2.042, Time: 8.06, Learning Rate: 1.000e-03
# It: 370, Loss: 1.923e+02, Y0: -3.023, Time: 7.97, Learning Rate: 1.000e-03
# It: 380, Loss: 1.610e+02, Y0: -2.861, Time: 8.07, Learning Rate: 1.000e-03
# It: 390, Loss: 2.199e+02, Y0: -1.045, Time: 8.05, Learning Rate: 1.000e-03
# It: 400, Loss: 1.948e+02, Y0: 1.378, Time: 8.05, Learning Rate: 1.000e-03
# It: 410, Loss: 1.598e+02, Y0: -2.461, Time: 7.99, Learning Rate: 1.000e-03
# It: 420, Loss: 1.719e+02, Y0: -2.377, Time: 8.03, Learning Rate: 1.000e-03
# It: 430, Loss: 1.671e+02, Y0: -0.193, Time: 8.04, Learning Rate: 1.000e-03
# It: 440, Loss: 2.035e+02, Y0: -1.150, Time: 8.07, Learning Rate: 1.000e-03
# It: 450, Loss: 5.454e+02, Y0: -3.068, Time: 8.00, Learning Rate: 1.000e-03
# It: 460, Loss: 2.097e+02, Y0: 0.420, Time: 8.09, Learning Rate: 1.000e-03
# It: 470, Loss: 2.493e+02, Y0: 5.006, Time: 8.00, Learning Rate: 1.000e-03
# It: 480, Loss: 1.984e+02, Y0: -0.271, Time: 7.96, Learning Rate: 1.000e-03
# It: 490, Loss: 1.487e+02, Y0: -3.722, Time: 7.99, Learning Rate: 1.000e-03
# It: 500, Loss: 1.915e+02, Y0: -0.840, Time: 8.04, Learning Rate: 1.000e-03
# It: 510, Loss: 2.886e+02, Y0: 1.036, Time: 8.00, Learning Rate: 1.000e-03
# It: 520, Loss: 1.320e+02, Y0: -0.890, Time: 7.98, Learning Rate: 1.000e-03
# It: 530, Loss: 1.177e+02, Y0: -2.965, Time: 8.00, Learning Rate: 1.000e-03
# It: 540, Loss: 1.286e+02, Y0: -0.906, Time: 8.00, Learning Rate: 1.000e-03
# It: 550, Loss: 1.229e+02, Y0: -0.884, Time: 7.97, Learning Rate: 1.000e-03
# It: 560, Loss: 1.172e+02, Y0: -2.391, Time: 8.02, Learning Rate: 1.000e-03
# It: 570, Loss: 1.832e+02, Y0: -3.286, Time: 8.02, Learning Rate: 1.000e-03
# It: 580, Loss: 1.238e+02, Y0: -3.638, Time: 8.07, Learning Rate: 1.000e-03
# It: 590, Loss: 1.511e+02, Y0: -3.601, Time: 7.95, Learning Rate: 1.000e-03
# It: 600, Loss: 1.411e+02, Y0: -3.340, Time: 8.09, Learning Rate: 1.000e-03
# It: 610, Loss: 1.410e+02, Y0: -4.180, Time: 7.99, Learning Rate: 1.000e-03
# It: 620, Loss: 1.263e+02, Y0: -3.222, Time: 8.10, Learning Rate: 1.000e-03
# It: 630, Loss: 1.087e+02, Y0: -4.547, Time: 8.01, Learning Rate: 1.000e-03
# It: 640, Loss: 2.458e+02, Y0: -4.804, Time: 8.00, Learning Rate: 1.000e-03
# It: 650, Loss: 2.162e+02, Y0: -5.508, Time: 7.93, Learning Rate: 1.000e-03
# It: 660, Loss: 9.289e+01, Y0: -4.404, Time: 7.95, Learning Rate: 1.000e-03
# It: 670, Loss: 9.382e+01, Y0: -2.725, Time: 8.04, Learning Rate: 1.000e-03
# It: 680, Loss: 9.669e+01, Y0: -3.518, Time: 8.03, Learning Rate: 1.000e-03
# It: 690, Loss: 9.883e+01, Y0: -5.572, Time: 8.12, Learning Rate: 1.000e-03
# [StageSummary] const=1.0, lr=1.0e-03, iters=700, eval_loss=2.247e+02±1.47e+01, eval_Y0=-4.221±0.000, time=816.1s
# It: 0, Loss: 1.879e+02, Y0: -4.215, Time: 0.80, Learning Rate: 5.000e-04
# It: 10, Loss: 1.315e+02, Y0: -7.251, Time: 8.01, Learning Rate: 5.000e-04
# It: 20, Loss: 9.904e+01, Y0: -7.056, Time: 7.99, Learning Rate: 5.000e-04
# It: 30, Loss: 1.040e+02, Y0: -3.841, Time: 7.95, Learning Rate: 5.000e-04
# It: 40, Loss: 9.285e+01, Y0: -4.736, Time: 7.98, Learning Rate: 5.000e-04
# It: 50, Loss: 1.039e+02, Y0: -5.174, Time: 8.03, Learning Rate: 5.000e-04
# It: 60, Loss: 8.712e+01, Y0: -4.101, Time: 8.03, Learning Rate: 5.000e-04
# It: 70, Loss: 8.522e+01, Y0: -5.373, Time: 8.00, Learning Rate: 5.000e-04
# It: 80, Loss: 1.210e+02, Y0: -5.519, Time: 8.06, Learning Rate: 5.000e-04
# It: 90, Loss: 1.628e+02, Y0: -7.584, Time: 7.95, Learning Rate: 5.000e-04
# It: 100, Loss: 1.121e+02, Y0: -4.430, Time: 8.05, Learning Rate: 5.000e-04
# It: 110, Loss: 8.755e+01, Y0: -5.977, Time: 8.00, Learning Rate: 5.000e-04
# It: 120, Loss: 1.018e+02, Y0: -4.720, Time: 8.07, Learning Rate: 5.000e-04
# It: 130, Loss: 8.724e+01, Y0: -5.091, Time: 8.09, Learning Rate: 5.000e-04
# It: 140, Loss: 1.096e+02, Y0: -5.272, Time: 8.11, Learning Rate: 5.000e-04
# It: 150, Loss: 8.879e+01, Y0: -4.969, Time: 8.16, Learning Rate: 5.000e-04
# It: 160, Loss: 1.048e+02, Y0: -5.707, Time: 7.98, Learning Rate: 5.000e-04
# It: 170, Loss: 8.323e+01, Y0: -3.169, Time: 7.97, Learning Rate: 5.000e-04
# It: 180, Loss: 8.052e+01, Y0: -3.240, Time: 8.06, Learning Rate: 5.000e-04
# It: 190, Loss: 9.810e+01, Y0: -4.920, Time: 8.02, Learning Rate: 5.000e-04
# It: 200, Loss: 8.141e+01, Y0: -3.720, Time: 8.00, Learning Rate: 5.000e-04
# It: 210, Loss: 9.571e+01, Y0: -7.023, Time: 8.09, Learning Rate: 5.000e-04
# It: 220, Loss: 1.012e+02, Y0: -4.129, Time: 8.03, Learning Rate: 5.000e-04
# It: 230, Loss: 8.059e+01, Y0: -7.398, Time: 7.98, Learning Rate: 5.000e-04
# It: 240, Loss: 1.137e+02, Y0: -5.978, Time: 7.96, Learning Rate: 5.000e-04
# It: 250, Loss: 8.351e+01, Y0: -5.304, Time: 8.00, Learning Rate: 5.000e-04
# It: 260, Loss: 7.591e+01, Y0: -7.256, Time: 8.04, Learning Rate: 5.000e-04
# It: 270, Loss: 8.459e+01, Y0: -3.761, Time: 8.09, Learning Rate: 5.000e-04
# It: 280, Loss: 1.515e+02, Y0: -9.070, Time: 8.07, Learning Rate: 5.000e-04
# It: 290, Loss: 8.152e+01, Y0: -6.309, Time: 8.13, Learning Rate: 5.000e-04
# It: 300, Loss: 1.056e+02, Y0: -4.245, Time: 8.04, Learning Rate: 5.000e-04
# It: 310, Loss: 1.048e+02, Y0: -3.178, Time: 7.99, Learning Rate: 5.000e-04
# It: 320, Loss: 8.381e+01, Y0: -8.238, Time: 8.01, Learning Rate: 5.000e-04
# It: 330, Loss: 8.479e+01, Y0: -7.490, Time: 8.07, Learning Rate: 5.000e-04
# It: 340, Loss: 9.257e+01, Y0: -5.810, Time: 8.01, Learning Rate: 5.000e-04
# It: 350, Loss: 8.232e+01, Y0: -7.515, Time: 8.03, Learning Rate: 5.000e-04
# It: 360, Loss: 8.101e+01, Y0: -5.661, Time: 8.10, Learning Rate: 5.000e-04
# It: 370, Loss: 8.192e+01, Y0: -8.117, Time: 8.03, Learning Rate: 5.000e-04
# It: 380, Loss: 9.824e+01, Y0: -5.988, Time: 8.00, Learning Rate: 5.000e-04
# It: 390, Loss: 1.011e+02, Y0: -4.932, Time: 8.06, Learning Rate: 5.000e-04
# It: 400, Loss: 9.375e+01, Y0: -8.094, Time: 8.00, Learning Rate: 5.000e-04
# It: 410, Loss: 8.351e+01, Y0: -6.608, Time: 7.98, Learning Rate: 5.000e-04
# It: 420, Loss: 1.571e+02, Y0: -4.801, Time: 8.03, Learning Rate: 5.000e-04
# It: 430, Loss: 8.379e+01, Y0: -4.801, Time: 7.94, Learning Rate: 5.000e-04
# It: 440, Loss: 9.757e+01, Y0: -6.310, Time: 8.02, Learning Rate: 5.000e-04
# It: 450, Loss: 8.944e+01, Y0: -8.856, Time: 8.01, Learning Rate: 5.000e-04
# It: 460, Loss: 7.860e+01, Y0: -4.419, Time: 7.98, Learning Rate: 5.000e-04
# It: 470, Loss: 9.030e+01, Y0: -3.192, Time: 7.99, Learning Rate: 5.000e-04
# It: 480, Loss: 8.126e+01, Y0: -6.137, Time: 8.09, Learning Rate: 5.000e-04
# It: 490, Loss: 7.520e+01, Y0: -6.035, Time: 7.97, Learning Rate: 5.000e-04
# It: 500, Loss: 7.503e+01, Y0: -6.327, Time: 8.05, Learning Rate: 5.000e-04
# It: 510, Loss: 8.953e+01, Y0: -6.609, Time: 8.04, Learning Rate: 5.000e-04
# It: 520, Loss: 8.388e+01, Y0: -7.117, Time: 8.04, Learning Rate: 5.000e-04
# It: 530, Loss: 8.652e+01, Y0: -5.734, Time: 8.00, Learning Rate: 5.000e-04
# It: 540, Loss: 9.024e+01, Y0: -6.820, Time: 7.98, Learning Rate: 5.000e-04
# It: 550, Loss: 7.488e+01, Y0: -5.903, Time: 7.95, Learning Rate: 5.000e-04
# It: 560, Loss: 6.888e+01, Y0: -6.404, Time: 8.09, Learning Rate: 5.000e-04
# It: 570, Loss: 7.147e+01, Y0: -6.625, Time: 8.03, Learning Rate: 5.000e-04
# It: 580, Loss: 9.044e+01, Y0: -6.391, Time: 8.02, Learning Rate: 5.000e-04
# It: 590, Loss: 7.679e+01, Y0: -7.519, Time: 8.06, Learning Rate: 5.000e-04
# It: 600, Loss: 7.586e+01, Y0: -7.055, Time: 8.02, Learning Rate: 5.000e-04
# It: 610, Loss: 8.674e+01, Y0: -6.949, Time: 7.97, Learning Rate: 5.000e-04
# It: 620, Loss: 7.436e+01, Y0: -6.667, Time: 8.05, Learning Rate: 5.000e-04
# It: 630, Loss: 7.240e+01, Y0: -7.462, Time: 8.10, Learning Rate: 5.000e-04
# It: 640, Loss: 7.296e+01, Y0: -6.792, Time: 8.05, Learning Rate: 5.000e-04
# It: 650, Loss: 1.004e+02, Y0: -7.046, Time: 7.99, Learning Rate: 5.000e-04
# It: 660, Loss: 7.225e+01, Y0: -7.364, Time: 7.98, Learning Rate: 5.000e-04
# It: 670, Loss: 7.894e+01, Y0: -7.010, Time: 8.04, Learning Rate: 5.000e-04
# It: 680, Loss: 7.119e+01, Y0: -5.711, Time: 7.96, Learning Rate: 5.000e-04
# It: 690, Loss: 7.958e+01, Y0: -6.970, Time: 8.02, Learning Rate: 5.000e-04
# [StageSummary] const=1.0, lr=5.0e-04, iters=700, eval_loss=8.130e+01±9.05e+00, eval_Y0=-5.862±0.000, time=579.7s
# It: 0, Loss: 8.042e+01, Y0: -5.838, Time: 0.79, Learning Rate: 1.000e-04
# It: 10, Loss: 8.390e+01, Y0: -6.276, Time: 8.04, Learning Rate: 1.000e-04
# It: 20, Loss: 6.542e+01, Y0: -6.530, Time: 8.00, Learning Rate: 1.000e-04
# It: 30, Loss: 6.964e+01, Y0: -5.940, Time: 8.03, Learning Rate: 1.000e-04
# It: 40, Loss: 6.851e+01, Y0: -6.426, Time: 8.01, Learning Rate: 1.000e-04
# It: 50, Loss: 6.612e+01, Y0: -6.404, Time: 8.02, Learning Rate: 1.000e-04
# It: 60, Loss: 7.107e+01, Y0: -6.389, Time: 8.13, Learning Rate: 1.000e-04
# It: 70, Loss: 6.862e+01, Y0: -6.831, Time: 8.01, Learning Rate: 1.000e-04
# It: 80, Loss: 6.754e+01, Y0: -6.403, Time: 8.10, Learning Rate: 1.000e-04
# It: 90, Loss: 6.685e+01, Y0: -6.840, Time: 8.06, Learning Rate: 1.000e-04
# It: 100, Loss: 7.176e+01, Y0: -6.828, Time: 8.11, Learning Rate: 1.000e-04
# It: 110, Loss: 6.521e+01, Y0: -6.726, Time: 7.98, Learning Rate: 1.000e-04
# It: 120, Loss: 6.401e+01, Y0: -6.971, Time: 8.01, Learning Rate: 1.000e-04
# It: 130, Loss: 6.427e+01, Y0: -6.980, Time: 8.02, Learning Rate: 1.000e-04
# It: 140, Loss: 6.315e+01, Y0: -7.658, Time: 8.02, Learning Rate: 1.000e-04
# It: 150, Loss: 6.493e+01, Y0: -7.765, Time: 8.02, Learning Rate: 1.000e-04
# It: 160, Loss: 6.153e+01, Y0: -6.745, Time: 8.08, Learning Rate: 1.000e-04
# It: 170, Loss: 7.336e+01, Y0: -6.935, Time: 8.01, Learning Rate: 1.000e-04
# It: 180, Loss: 7.115e+01, Y0: -7.234, Time: 8.08, Learning Rate: 1.000e-04
# It: 190, Loss: 6.668e+01, Y0: -7.575, Time: 8.01, Learning Rate: 1.000e-04
# It: 200, Loss: 8.221e+01, Y0: -7.181, Time: 8.05, Learning Rate: 1.000e-04
# It: 210, Loss: 6.440e+01, Y0: -7.079, Time: 8.05, Learning Rate: 1.000e-04
# It: 220, Loss: 9.537e+01, Y0: -7.334, Time: 8.13, Learning Rate: 1.000e-04
# It: 230, Loss: 7.293e+01, Y0: -7.174, Time: 7.99, Learning Rate: 1.000e-04
# It: 240, Loss: 6.649e+01, Y0: -7.363, Time: 8.05, Learning Rate: 1.000e-04
# It: 250, Loss: 6.967e+01, Y0: -6.636, Time: 8.03, Learning Rate: 1.000e-04
# It: 260, Loss: 6.566e+01, Y0: -7.677, Time: 8.05, Learning Rate: 1.000e-04
# It: 270, Loss: 6.357e+01, Y0: -8.092, Time: 8.09, Learning Rate: 1.000e-04
# It: 280, Loss: 6.192e+01, Y0: -7.030, Time: 8.01, Learning Rate: 1.000e-04
# It: 290, Loss: 6.879e+01, Y0: -7.569, Time: 8.05, Learning Rate: 1.000e-04
# It: 300, Loss: 7.171e+01, Y0: -6.996, Time: 7.99, Learning Rate: 1.000e-04
# It: 310, Loss: 7.695e+01, Y0: -7.291, Time: 7.99, Learning Rate: 1.000e-04
# It: 320, Loss: 6.576e+01, Y0: -6.618, Time: 7.95, Learning Rate: 1.000e-04
# It: 330, Loss: 6.729e+01, Y0: -7.152, Time: 8.02, Learning Rate: 1.000e-04
# It: 340, Loss: 6.493e+01, Y0: -7.477, Time: 8.01, Learning Rate: 1.000e-04
# It: 350, Loss: 6.934e+01, Y0: -6.498, Time: 8.05, Learning Rate: 1.000e-04
# It: 360, Loss: 6.923e+01, Y0: -7.374, Time: 8.07, Learning Rate: 1.000e-04
# It: 370, Loss: 8.181e+01, Y0: -7.038, Time: 8.06, Learning Rate: 1.000e-04
# It: 380, Loss: 6.816e+01, Y0: -6.737, Time: 8.09, Learning Rate: 1.000e-04
# It: 390, Loss: 8.140e+01, Y0: -6.875, Time: 7.93, Learning Rate: 1.000e-04
# It: 400, Loss: 6.418e+01, Y0: -6.412, Time: 8.05, Learning Rate: 1.000e-04
# It: 410, Loss: 7.344e+01, Y0: -6.582, Time: 8.05, Learning Rate: 1.000e-04
# It: 420, Loss: 7.323e+01, Y0: -7.276, Time: 8.04, Learning Rate: 1.000e-04
# It: 430, Loss: 6.799e+01, Y0: -6.218, Time: 8.01, Learning Rate: 1.000e-04
# It: 440, Loss: 6.892e+01, Y0: -6.638, Time: 7.99, Learning Rate: 1.000e-04
# It: 450, Loss: 6.761e+01, Y0: -7.365, Time: 8.02, Learning Rate: 1.000e-04
# It: 460, Loss: 9.852e+01, Y0: -7.096, Time: 8.00, Learning Rate: 1.000e-04
# It: 470, Loss: 6.520e+01, Y0: -6.830, Time: 8.04, Learning Rate: 1.000e-04
# It: 480, Loss: 7.494e+01, Y0: -7.101, Time: 8.07, Learning Rate: 1.000e-04
# It: 490, Loss: 7.630e+01, Y0: -6.459, Time: 7.99, Learning Rate: 1.000e-04
# It: 500, Loss: 7.285e+01, Y0: -7.286, Time: 7.99, Learning Rate: 1.000e-04
# It: 510, Loss: 6.831e+01, Y0: -7.055, Time: 8.04, Learning Rate: 1.000e-04
# It: 520, Loss: 6.459e+01, Y0: -7.478, Time: 8.07, Learning Rate: 1.000e-04
# It: 530, Loss: 6.942e+01, Y0: -6.867, Time: 8.11, Learning Rate: 1.000e-04
# It: 540, Loss: 6.933e+01, Y0: -7.600, Time: 7.94, Learning Rate: 1.000e-04
# It: 550, Loss: 6.098e+01, Y0: -7.573, Time: 8.03, Learning Rate: 1.000e-04
# It: 560, Loss: 6.607e+01, Y0: -7.154, Time: 8.02, Learning Rate: 1.000e-04
# It: 570, Loss: 6.514e+01, Y0: -8.151, Time: 8.11, Learning Rate: 1.000e-04
# It: 580, Loss: 7.204e+01, Y0: -8.240, Time: 7.97, Learning Rate: 1.000e-04
# It: 590, Loss: 7.337e+01, Y0: -9.164, Time: 8.07, Learning Rate: 1.000e-04
# It: 600, Loss: 6.517e+01, Y0: -6.632, Time: 8.03, Learning Rate: 1.000e-04
# It: 610, Loss: 6.442e+01, Y0: -6.975, Time: 7.99, Learning Rate: 1.000e-04
# It: 620, Loss: 8.612e+01, Y0: -6.725, Time: 8.03, Learning Rate: 1.000e-04
# It: 630, Loss: 6.654e+01, Y0: -6.614, Time: 8.01, Learning Rate: 1.000e-04
# It: 640, Loss: 6.029e+01, Y0: -7.025, Time: 7.99, Learning Rate: 1.000e-04
# It: 650, Loss: 6.603e+01, Y0: -7.218, Time: 7.95, Learning Rate: 1.000e-04
# It: 660, Loss: 8.113e+01, Y0: -7.008, Time: 7.97, Learning Rate: 1.000e-04
# It: 670, Loss: 6.615e+01, Y0: -7.089, Time: 8.09, Learning Rate: 1.000e-04
# It: 680, Loss: 7.151e+01, Y0: -6.969, Time: 7.95, Learning Rate: 1.000e-04
# It: 690, Loss: 7.185e+01, Y0: -6.848, Time: 7.99, Learning Rate: 1.000e-04
# [StageSummary] const=1.0, lr=1.0e-04, iters=700, eval_loss=6.925e+01±3.47e+00, eval_Y0=-6.819±0.000, time=579.8s
# It: 0, Loss: 6.472e+01, Y0: -6.895, Time: 0.79, Learning Rate: 5.000e-05
# It: 10, Loss: 6.675e+01, Y0: -7.862, Time: 8.07, Learning Rate: 5.000e-05
# It: 20, Loss: 6.444e+01, Y0: -7.491, Time: 8.04, Learning Rate: 5.000e-05
# It: 30, Loss: 6.744e+01, Y0: -6.808, Time: 8.01, Learning Rate: 5.000e-05
# It: 40, Loss: 6.598e+01, Y0: -7.270, Time: 8.07, Learning Rate: 5.000e-05
# It: 50, Loss: 6.860e+01, Y0: -7.550, Time: 7.97, Learning Rate: 5.000e-05
# It: 60, Loss: 7.220e+01, Y0: -7.395, Time: 8.05, Learning Rate: 5.000e-05
# It: 70, Loss: 7.322e+01, Y0: -6.964, Time: 8.00, Learning Rate: 5.000e-05
# It: 80, Loss: 6.684e+01, Y0: -7.206, Time: 8.03, Learning Rate: 5.000e-05
# It: 90, Loss: 7.078e+01, Y0: -7.233, Time: 8.06, Learning Rate: 5.000e-05
# It: 100, Loss: 5.958e+01, Y0: -7.529, Time: 8.03, Learning Rate: 5.000e-05
# It: 110, Loss: 6.823e+01, Y0: -7.392, Time: 7.99, Learning Rate: 5.000e-05
# It: 120, Loss: 6.394e+01, Y0: -7.462, Time: 8.06, Learning Rate: 5.000e-05
# It: 130, Loss: 8.280e+01, Y0: -7.258, Time: 7.98, Learning Rate: 5.000e-05
# It: 140, Loss: 7.358e+01, Y0: -7.329, Time: 8.02, Learning Rate: 5.000e-05
# It: 150, Loss: 6.263e+01, Y0: -7.205, Time: 8.06, Learning Rate: 5.000e-05
# It: 160, Loss: 6.506e+01, Y0: -7.556, Time: 8.01, Learning Rate: 5.000e-05
# It: 170, Loss: 7.000e+01, Y0: -7.418, Time: 7.94, Learning Rate: 5.000e-05
# It: 180, Loss: 6.940e+01, Y0: -7.233, Time: 8.06, Learning Rate: 5.000e-05
# It: 190, Loss: 7.001e+01, Y0: -7.723, Time: 8.04, Learning Rate: 5.000e-05
# It: 200, Loss: 7.326e+01, Y0: -7.217, Time: 7.97, Learning Rate: 5.000e-05
# It: 210, Loss: 5.956e+01, Y0: -7.354, Time: 7.97, Learning Rate: 5.000e-05
# It: 220, Loss: 6.196e+01, Y0: -7.615, Time: 8.04, Learning Rate: 5.000e-05
# It: 230, Loss: 6.218e+01, Y0: -7.518, Time: 8.00, Learning Rate: 5.000e-05
# It: 240, Loss: 6.482e+01, Y0: -7.018, Time: 8.04, Learning Rate: 5.000e-05
# It: 250, Loss: 6.417e+01, Y0: -7.493, Time: 7.97, Learning Rate: 5.000e-05
# It: 260, Loss: 6.400e+01, Y0: -7.594, Time: 7.99, Learning Rate: 5.000e-05
# It: 270, Loss: 6.525e+01, Y0: -7.296, Time: 7.95, Learning Rate: 5.000e-05
# It: 280, Loss: 6.511e+01, Y0: -7.707, Time: 8.08, Learning Rate: 5.000e-05
# It: 290, Loss: 6.757e+01, Y0: -7.569, Time: 8.02, Learning Rate: 5.000e-05
# It: 300, Loss: 6.639e+01, Y0: -7.585, Time: 8.02, Learning Rate: 5.000e-05
# It: 310, Loss: 6.447e+01, Y0: -7.322, Time: 8.08, Learning Rate: 5.000e-05
# It: 320, Loss: 7.133e+01, Y0: -7.579, Time: 8.08, Learning Rate: 5.000e-05
# It: 330, Loss: 6.536e+01, Y0: -7.498, Time: 8.03, Learning Rate: 5.000e-05
# It: 340, Loss: 7.777e+01, Y0: -7.946, Time: 8.00, Learning Rate: 5.000e-05
# It: 350, Loss: 6.113e+01, Y0: -7.658, Time: 8.11, Learning Rate: 5.000e-05
# It: 360, Loss: 6.430e+01, Y0: -7.067, Time: 8.02, Learning Rate: 5.000e-05
# It: 370, Loss: 6.420e+01, Y0: -7.272, Time: 8.13, Learning Rate: 5.000e-05
# It: 380, Loss: 6.929e+01, Y0: -7.648, Time: 8.06, Learning Rate: 5.000e-05
# It: 390, Loss: 6.685e+01, Y0: -7.683, Time: 8.00, Learning Rate: 5.000e-05
# It: 400, Loss: 7.427e+01, Y0: -7.638, Time: 7.99, Learning Rate: 5.000e-05
# It: 410, Loss: 6.329e+01, Y0: -7.361, Time: 8.07, Learning Rate: 5.000e-05
# It: 420, Loss: 6.417e+01, Y0: -7.380, Time: 7.99, Learning Rate: 5.000e-05
# It: 430, Loss: 6.834e+01, Y0: -7.400, Time: 8.06, Learning Rate: 5.000e-05
# It: 440, Loss: 7.526e+01, Y0: -7.248, Time: 7.99, Learning Rate: 5.000e-05
# It: 450, Loss: 6.850e+01, Y0: -7.483, Time: 8.11, Learning Rate: 5.000e-05
# It: 460, Loss: 6.442e+01, Y0: -7.691, Time: 8.05, Learning Rate: 5.000e-05
# It: 470, Loss: 6.135e+01, Y0: -7.359, Time: 8.04, Learning Rate: 5.000e-05
# It: 480, Loss: 7.210e+01, Y0: -7.440, Time: 8.06, Learning Rate: 5.000e-05
# It: 490, Loss: 6.793e+01, Y0: -7.882, Time: 8.06, Learning Rate: 5.000e-05
# It: 500, Loss: 6.669e+01, Y0: -7.552, Time: 7.98, Learning Rate: 5.000e-05
# It: 510, Loss: 6.104e+01, Y0: -7.821, Time: 8.03, Learning Rate: 5.000e-05
# It: 520, Loss: 6.504e+01, Y0: -7.950, Time: 8.05, Learning Rate: 5.000e-05
# It: 530, Loss: 6.682e+01, Y0: -8.139, Time: 8.05, Learning Rate: 5.000e-05
# It: 540, Loss: 7.044e+01, Y0: -7.871, Time: 8.09, Learning Rate: 5.000e-05
# It: 550, Loss: 6.415e+01, Y0: -7.466, Time: 8.10, Learning Rate: 5.000e-05
# It: 560, Loss: 6.230e+01, Y0: -7.789, Time: 8.05, Learning Rate: 5.000e-05
# It: 570, Loss: 6.448e+01, Y0: -7.543, Time: 8.16, Learning Rate: 5.000e-05
# It: 580, Loss: 6.729e+01, Y0: -7.542, Time: 8.05, Learning Rate: 5.000e-05
# It: 590, Loss: 6.487e+01, Y0: -7.820, Time: 8.04, Learning Rate: 5.000e-05
# It: 600, Loss: 6.815e+01, Y0: -7.625, Time: 8.03, Learning Rate: 5.000e-05
# It: 610, Loss: 6.138e+01, Y0: -7.604, Time: 7.99, Learning Rate: 5.000e-05
# It: 620, Loss: 6.059e+01, Y0: -7.933, Time: 7.96, Learning Rate: 5.000e-05
# It: 630, Loss: 8.165e+01, Y0: -7.947, Time: 8.10, Learning Rate: 5.000e-05
# It: 640, Loss: 6.442e+01, Y0: -7.674, Time: 8.17, Learning Rate: 5.000e-05
# It: 650, Loss: 6.139e+01, Y0: -7.718, Time: 8.13, Learning Rate: 5.000e-05
# It: 660, Loss: 6.715e+01, Y0: -7.479, Time: 8.13, Learning Rate: 5.000e-05
# It: 670, Loss: 6.512e+01, Y0: -7.984, Time: 8.06, Learning Rate: 5.000e-05
# It: 680, Loss: 6.980e+01, Y0: -7.330, Time: 8.16, Learning Rate: 5.000e-05
# It: 690, Loss: 7.716e+01, Y0: -7.197, Time: 8.11, Learning Rate: 5.000e-05
# [StageSummary] const=1.0, lr=5.0e-05, iters=700, eval_loss=6.882e+01±5.00e+00, eval_Y0=-7.576±0.000, time=581.0s
# === Final fine-tuning at const=1.0 ===
# It: 0, Loss: 6.308e+01, Y0: -7.570, Time: 0.83, Learning Rate: 1.000e-05
# It: 10, Loss: 6.110e+01, Y0: -7.502, Time: 8.06, Learning Rate: 1.000e-05
# It: 20, Loss: 6.260e+01, Y0: -7.313, Time: 8.02, Learning Rate: 1.000e-05
# It: 30, Loss: 6.609e+01, Y0: -7.339, Time: 7.98, Learning Rate: 1.000e-05
# It: 40, Loss: 6.750e+01, Y0: -7.499, Time: 8.00, Learning Rate: 1.000e-05
# It: 50, Loss: 6.321e+01, Y0: -7.469, Time: 8.04, Learning Rate: 1.000e-05
# It: 60, Loss: 7.033e+01, Y0: -7.429, Time: 8.06, Learning Rate: 1.000e-05
# It: 70, Loss: 6.199e+01, Y0: -7.478, Time: 8.10, Learning Rate: 1.000e-05
# It: 80, Loss: 6.312e+01, Y0: -7.497, Time: 8.03, Learning Rate: 1.000e-05
# It: 90, Loss: 6.753e+01, Y0: -7.556, Time: 7.99, Learning Rate: 1.000e-05
# It: 100, Loss: 6.795e+01, Y0: -7.602, Time: 7.99, Learning Rate: 1.000e-05
# It: 110, Loss: 6.380e+01, Y0: -7.543, Time: 8.00, Learning Rate: 1.000e-05
# It: 120, Loss: 6.955e+01, Y0: -7.408, Time: 8.00, Learning Rate: 1.000e-05
# It: 130, Loss: 6.098e+01, Y0: -7.453, Time: 7.98, Learning Rate: 1.000e-05
# It: 140, Loss: 6.139e+01, Y0: -7.498, Time: 8.04, Learning Rate: 1.000e-05
# It: 150, Loss: 7.006e+01, Y0: -7.544, Time: 8.10, Learning Rate: 1.000e-05
# It: 160, Loss: 6.235e+01, Y0: -7.419, Time: 8.06, Learning Rate: 1.000e-05
# It: 170, Loss: 7.030e+01, Y0: -7.368, Time: 7.92, Learning Rate: 1.000e-05
# It: 180, Loss: 6.590e+01, Y0: -7.514, Time: 8.05, Learning Rate: 1.000e-05
# It: 190, Loss: 6.308e+01, Y0: -7.493, Time: 7.98, Learning Rate: 1.000e-05
# It: 200, Loss: 6.448e+01, Y0: -7.451, Time: 8.00, Learning Rate: 1.000e-05
# It: 210, Loss: 6.514e+01, Y0: -7.580, Time: 8.02, Learning Rate: 1.000e-05
# It: 220, Loss: 7.040e+01, Y0: -7.538, Time: 8.02, Learning Rate: 1.000e-05
# It: 230, Loss: 6.301e+01, Y0: -7.489, Time: 8.01, Learning Rate: 1.000e-05
# It: 240, Loss: 6.514e+01, Y0: -7.618, Time: 8.01, Learning Rate: 1.000e-05
# It: 250, Loss: 6.273e+01, Y0: -7.528, Time: 8.08, Learning Rate: 1.000e-05
# It: 260, Loss: 6.347e+01, Y0: -7.424, Time: 8.00, Learning Rate: 1.000e-05
# It: 270, Loss: 6.993e+01, Y0: -7.398, Time: 8.04, Learning Rate: 1.000e-05
# It: 280, Loss: 5.991e+01, Y0: -7.436, Time: 8.04, Learning Rate: 1.000e-05
# It: 290, Loss: 6.187e+01, Y0: -7.413, Time: 8.00, Learning Rate: 1.000e-05
# It: 300, Loss: 6.685e+01, Y0: -7.302, Time: 8.01, Learning Rate: 1.000e-05
# It: 310, Loss: 6.233e+01, Y0: -7.274, Time: 8.01, Learning Rate: 1.000e-05
# It: 320, Loss: 6.428e+01, Y0: -7.294, Time: 8.06, Learning Rate: 1.000e-05
# It: 330, Loss: 6.428e+01, Y0: -7.440, Time: 8.05, Learning Rate: 1.000e-05
# It: 340, Loss: 5.994e+01, Y0: -7.513, Time: 8.08, Learning Rate: 1.000e-05
# It: 350, Loss: 6.078e+01, Y0: -7.424, Time: 8.11, Learning Rate: 1.000e-05
# It: 360, Loss: 6.420e+01, Y0: -7.385, Time: 8.04, Learning Rate: 1.000e-05
# It: 370, Loss: 6.268e+01, Y0: -7.420, Time: 8.11, Learning Rate: 1.000e-05
# It: 380, Loss: 6.381e+01, Y0: -7.580, Time: 8.05, Learning Rate: 1.000e-05
# It: 390, Loss: 6.469e+01, Y0: -7.560, Time: 8.01, Learning Rate: 1.000e-05
# It: 400, Loss: 6.944e+01, Y0: -7.439, Time: 8.04, Learning Rate: 1.000e-05
# It: 410, Loss: 7.413e+01, Y0: -7.395, Time: 7.98, Learning Rate: 1.000e-05
# It: 420, Loss: 6.200e+01, Y0: -7.467, Time: 8.00, Learning Rate: 1.000e-05
# It: 430, Loss: 6.176e+01, Y0: -7.501, Time: 8.03, Learning Rate: 1.000e-05
# It: 440, Loss: 6.252e+01, Y0: -7.512, Time: 7.99, Learning Rate: 1.000e-05
# It: 450, Loss: 6.246e+01, Y0: -7.546, Time: 8.06, Learning Rate: 1.000e-05
# It: 460, Loss: 7.328e+01, Y0: -7.599, Time: 7.99, Learning Rate: 1.000e-05
# It: 470, Loss: 6.315e+01, Y0: -7.680, Time: 8.00, Learning Rate: 1.000e-05
# It: 480, Loss: 6.387e+01, Y0: -7.615, Time: 8.13, Learning Rate: 1.000e-05
# It: 490, Loss: 6.412e+01, Y0: -7.596, Time: 7.98, Learning Rate: 1.000e-05
# It: 500, Loss: 6.090e+01, Y0: -7.632, Time: 8.01, Learning Rate: 1.000e-05
# It: 510, Loss: 6.051e+01, Y0: -7.461, Time: 8.01, Learning Rate: 1.000e-05
# It: 520, Loss: 6.588e+01, Y0: -7.357, Time: 7.99, Learning Rate: 1.000e-05
# It: 530, Loss: 6.289e+01, Y0: -7.408, Time: 8.01, Learning Rate: 1.000e-05
# It: 540, Loss: 6.404e+01, Y0: -7.550, Time: 8.01, Learning Rate: 1.000e-05
# It: 550, Loss: 6.065e+01, Y0: -7.590, Time: 8.09, Learning Rate: 1.000e-05
# It: 560, Loss: 6.148e+01, Y0: -7.628, Time: 7.99, Learning Rate: 1.000e-05
# It: 570, Loss: 7.436e+01, Y0: -7.514, Time: 7.97, Learning Rate: 1.000e-05
# It: 580, Loss: 6.921e+01, Y0: -7.505, Time: 8.04, Learning Rate: 1.000e-05
# It: 590, Loss: 6.514e+01, Y0: -7.577, Time: 8.03, Learning Rate: 1.000e-05
# It: 600, Loss: 6.169e+01, Y0: -7.680, Time: 8.01, Learning Rate: 1.000e-05
# It: 610, Loss: 6.908e+01, Y0: -7.661, Time: 8.01, Learning Rate: 1.000e-05
# It: 620, Loss: 7.247e+01, Y0: -7.560, Time: 7.98, Learning Rate: 1.000e-05
# It: 630, Loss: 6.377e+01, Y0: -7.463, Time: 7.94, Learning Rate: 1.000e-05
# It: 640, Loss: 6.790e+01, Y0: -7.583, Time: 8.07, Learning Rate: 1.000e-05
# It: 650, Loss: 6.401e+01, Y0: -7.604, Time: 8.07, Learning Rate: 1.000e-05
# It: 660, Loss: 7.072e+01, Y0: -7.491, Time: 8.05, Learning Rate: 1.000e-05
# It: 670, Loss: 7.057e+01, Y0: -7.452, Time: 8.11, Learning Rate: 1.000e-05
# It: 680, Loss: 6.246e+01, Y0: -7.505, Time: 8.04, Learning Rate: 1.000e-05
# It: 690, Loss: 6.874e+01, Y0: -7.472, Time: 8.12, Learning Rate: 1.000e-05
# [FinalSummary] const=1.0, lr=1.0e-05, iters=700, eval_loss=6.574e+01±3.13e+00, eval_Y0=-7.431±0.000, time=579.9s
# It: 0, Loss: 6.639e+01, Y0: -7.431, Time: 0.80, Learning Rate: 5.000e-06
# It: 10, Loss: 6.959e+01, Y0: -7.488, Time: 8.03, Learning Rate: 5.000e-06
# It: 20, Loss: 6.113e+01, Y0: -7.547, Time: 8.09, Learning Rate: 5.000e-06
# It: 30, Loss: 6.223e+01, Y0: -7.645, Time: 8.12, Learning Rate: 5.000e-06
# It: 40, Loss: 6.817e+01, Y0: -7.644, Time: 8.12, Learning Rate: 5.000e-06
# It: 50, Loss: 6.621e+01, Y0: -7.621, Time: 8.01, Learning Rate: 5.000e-06
# It: 60, Loss: 7.260e+01, Y0: -7.613, Time: 8.16, Learning Rate: 5.000e-06
# It: 70, Loss: 6.536e+01, Y0: -7.603, Time: 8.06, Learning Rate: 5.000e-06
# It: 80, Loss: 7.451e+01, Y0: -7.566, Time: 8.09, Learning Rate: 5.000e-06
# It: 90, Loss: 6.267e+01, Y0: -7.489, Time: 8.04, Learning Rate: 5.000e-06
# It: 100, Loss: 6.569e+01, Y0: -7.487, Time: 8.04, Learning Rate: 5.000e-06
# It: 110, Loss: 6.091e+01, Y0: -7.481, Time: 8.03, Learning Rate: 5.000e-06
# It: 120, Loss: 6.402e+01, Y0: -7.505, Time: 7.96, Learning Rate: 5.000e-06
# It: 130, Loss: 6.638e+01, Y0: -7.554, Time: 8.04, Learning Rate: 5.000e-06
# It: 140, Loss: 7.005e+01, Y0: -7.549, Time: 8.13, Learning Rate: 5.000e-06
# It: 150, Loss: 6.708e+01, Y0: -7.515, Time: 8.04, Learning Rate: 5.000e-06
# It: 160, Loss: 6.706e+01, Y0: -7.498, Time: 7.97, Learning Rate: 5.000e-06
# It: 170, Loss: 6.074e+01, Y0: -7.459, Time: 7.99, Learning Rate: 5.000e-06
# It: 180, Loss: 6.359e+01, Y0: -7.510, Time: 8.06, Learning Rate: 5.000e-06
# It: 190, Loss: 6.930e+01, Y0: -7.631, Time: 8.01, Learning Rate: 5.000e-06
# It: 200, Loss: 6.527e+01, Y0: -7.646, Time: 7.98, Learning Rate: 5.000e-06
# It: 210, Loss: 7.417e+01, Y0: -7.617, Time: 8.04, Learning Rate: 5.000e-06
# It: 220, Loss: 6.310e+01, Y0: -7.564, Time: 8.00, Learning Rate: 5.000e-06
# It: 230, Loss: 6.467e+01, Y0: -7.582, Time: 8.02, Learning Rate: 5.000e-06
# It: 240, Loss: 6.363e+01, Y0: -7.577, Time: 8.06, Learning Rate: 5.000e-06
# It: 250, Loss: 6.426e+01, Y0: -7.574, Time: 8.00, Learning Rate: 5.000e-06
# It: 260, Loss: 7.410e+01, Y0: -7.537, Time: 8.08, Learning Rate: 5.000e-06
# It: 270, Loss: 6.384e+01, Y0: -7.538, Time: 7.99, Learning Rate: 5.000e-06
# It: 280, Loss: 6.323e+01, Y0: -7.553, Time: 7.98, Learning Rate: 5.000e-06
# It: 290, Loss: 6.637e+01, Y0: -7.593, Time: 8.02, Learning Rate: 5.000e-06
# It: 300, Loss: 6.447e+01, Y0: -7.588, Time: 7.99, Learning Rate: 5.000e-06
# It: 310, Loss: 6.329e+01, Y0: -7.587, Time: 8.08, Learning Rate: 5.000e-06
# It: 320, Loss: 6.126e+01, Y0: -7.611, Time: 8.05, Learning Rate: 5.000e-06
# It: 330, Loss: 6.145e+01, Y0: -7.615, Time: 8.17, Learning Rate: 5.000e-06
# It: 340, Loss: 6.622e+01, Y0: -7.610, Time: 8.03, Learning Rate: 5.000e-06
# It: 350, Loss: 6.032e+01, Y0: -7.658, Time: 7.99, Learning Rate: 5.000e-06
# It: 360, Loss: 6.885e+01, Y0: -7.654, Time: 8.06, Learning Rate: 5.000e-06
# It: 370, Loss: 6.276e+01, Y0: -7.597, Time: 8.03, Learning Rate: 5.000e-06
# It: 380, Loss: 6.208e+01, Y0: -7.521, Time: 8.01, Learning Rate: 5.000e-06
# It: 390, Loss: 6.240e+01, Y0: -7.486, Time: 7.95, Learning Rate: 5.000e-06
# It: 400, Loss: 6.035e+01, Y0: -7.500, Time: 8.05, Learning Rate: 5.000e-06
# It: 410, Loss: 6.440e+01, Y0: -7.562, Time: 8.09, Learning Rate: 5.000e-06
# It: 420, Loss: 7.239e+01, Y0: -7.629, Time: 7.98, Learning Rate: 5.000e-06
# It: 430, Loss: 6.083e+01, Y0: -7.636, Time: 8.06, Learning Rate: 5.000e-06
# It: 440, Loss: 5.855e+01, Y0: -7.573, Time: 8.03, Learning Rate: 5.000e-06
# It: 450, Loss: 6.436e+01, Y0: -7.502, Time: 8.04, Learning Rate: 5.000e-06
# It: 460, Loss: 7.867e+01, Y0: -7.456, Time: 7.97, Learning Rate: 5.000e-06
# It: 470, Loss: 6.218e+01, Y0: -7.484, Time: 8.04, Learning Rate: 5.000e-06
# It: 480, Loss: 6.131e+01, Y0: -7.519, Time: 8.02, Learning Rate: 5.000e-06
# It: 490, Loss: 6.387e+01, Y0: -7.541, Time: 7.99, Learning Rate: 5.000e-06
# It: 500, Loss: 6.198e+01, Y0: -7.568, Time: 7.98, Learning Rate: 5.000e-06
# It: 510, Loss: 6.469e+01, Y0: -7.530, Time: 8.02, Learning Rate: 5.000e-06
# It: 520, Loss: 6.165e+01, Y0: -7.508, Time: 7.97, Learning Rate: 5.000e-06
# It: 530, Loss: 6.090e+01, Y0: -7.497, Time: 8.05, Learning Rate: 5.000e-06
# It: 540, Loss: 6.456e+01, Y0: -7.497, Time: 8.07, Learning Rate: 5.000e-06
# It: 550, Loss: 6.674e+01, Y0: -7.503, Time: 8.07, Learning Rate: 5.000e-06
# It: 560, Loss: 6.782e+01, Y0: -7.531, Time: 8.05, Learning Rate: 5.000e-06
# It: 570, Loss: 5.927e+01, Y0: -7.581, Time: 7.98, Learning Rate: 5.000e-06
# It: 580, Loss: 6.280e+01, Y0: -7.572, Time: 8.09, Learning Rate: 5.000e-06
# It: 590, Loss: 5.853e+01, Y0: -7.574, Time: 8.03, Learning Rate: 5.000e-06
# It: 600, Loss: 6.440e+01, Y0: -7.556, Time: 7.93, Learning Rate: 5.000e-06
# It: 610, Loss: 6.128e+01, Y0: -7.533, Time: 8.03, Learning Rate: 5.000e-06
# It: 620, Loss: 6.543e+01, Y0: -7.494, Time: 8.04, Learning Rate: 5.000e-06
# It: 630, Loss: 6.156e+01, Y0: -7.432, Time: 8.03, Learning Rate: 5.000e-06
# It: 640, Loss: 6.465e+01, Y0: -7.412, Time: 8.06, Learning Rate: 5.000e-06
# It: 650, Loss: 6.939e+01, Y0: -7.448, Time: 8.00, Learning Rate: 5.000e-06
# It: 660, Loss: 6.308e+01, Y0: -7.554, Time: 8.02, Learning Rate: 5.000e-06
# It: 670, Loss: 6.145e+01, Y0: -7.602, Time: 8.02, Learning Rate: 5.000e-06
# It: 680, Loss: 7.169e+01, Y0: -7.600, Time: 7.92, Learning Rate: 5.000e-06
# It: 690, Loss: 6.146e+01, Y0: -7.548, Time: 8.04, Learning Rate: 5.000e-06
# [FinalSummary] const=1.0, lr=5.0e-06, iters=700, eval_loss=6.491e+01±4.39e+00, eval_Y0=-7.541±0.000, time=580.1s
# It: 0, Loss: 6.641e+01, Y0: -7.541, Time: 0.79, Learning Rate: 1.000e-06
# It: 10, Loss: 6.582e+01, Y0: -7.526, Time: 8.02, Learning Rate: 1.000e-06
# It: 20, Loss: 6.133e+01, Y0: -7.514, Time: 8.04, Learning Rate: 1.000e-06
# It: 30, Loss: 6.482e+01, Y0: -7.513, Time: 8.01, Learning Rate: 1.000e-06
# It: 40, Loss: 8.577e+01, Y0: -7.507, Time: 7.96, Learning Rate: 1.000e-06
# It: 50, Loss: 6.330e+01, Y0: -7.496, Time: 8.04, Learning Rate: 1.000e-06
# It: 60, Loss: 6.105e+01, Y0: -7.483, Time: 8.00, Learning Rate: 1.000e-06
# It: 70, Loss: 6.082e+01, Y0: -7.471, Time: 7.97, Learning Rate: 1.000e-06
# It: 80, Loss: 8.162e+01, Y0: -7.456, Time: 8.03, Learning Rate: 1.000e-06
# It: 90, Loss: 6.205e+01, Y0: -7.447, Time: 8.00, Learning Rate: 1.000e-06
# It: 100, Loss: 6.072e+01, Y0: -7.455, Time: 7.99, Learning Rate: 1.000e-06
# It: 110, Loss: 6.039e+01, Y0: -7.464, Time: 7.97, Learning Rate: 1.000e-06
# It: 120, Loss: 6.478e+01, Y0: -7.464, Time: 7.92, Learning Rate: 1.000e-06
# It: 130, Loss: 7.817e+01, Y0: -7.472, Time: 7.94, Learning Rate: 1.000e-06
# It: 140, Loss: 7.135e+01, Y0: -7.478, Time: 8.09, Learning Rate: 1.000e-06
# It: 150, Loss: 5.970e+01, Y0: -7.461, Time: 8.00, Learning Rate: 1.000e-06
# It: 160, Loss: 6.261e+01, Y0: -7.456, Time: 8.02, Learning Rate: 1.000e-06
# It: 170, Loss: 6.183e+01, Y0: -7.461, Time: 7.94, Learning Rate: 1.000e-06
# It: 180, Loss: 6.735e+01, Y0: -7.475, Time: 8.06, Learning Rate: 1.000e-06
# It: 190, Loss: 6.642e+01, Y0: -7.472, Time: 8.03, Learning Rate: 1.000e-06
# It: 200, Loss: 6.216e+01, Y0: -7.487, Time: 7.98, Learning Rate: 1.000e-06
# It: 210, Loss: 7.011e+01, Y0: -7.504, Time: 8.02, Learning Rate: 1.000e-06
# It: 220, Loss: 6.351e+01, Y0: -7.517, Time: 8.04, Learning Rate: 1.000e-06
# It: 230, Loss: 6.057e+01, Y0: -7.518, Time: 8.05, Learning Rate: 1.000e-06
# It: 240, Loss: 7.500e+01, Y0: -7.522, Time: 8.03, Learning Rate: 1.000e-06
# It: 250, Loss: 6.571e+01, Y0: -7.532, Time: 7.98, Learning Rate: 1.000e-06
# It: 260, Loss: 6.077e+01, Y0: -7.547, Time: 8.06, Learning Rate: 1.000e-06
# It: 270, Loss: 5.907e+01, Y0: -7.541, Time: 7.96, Learning Rate: 1.000e-06
# It: 280, Loss: 6.531e+01, Y0: -7.543, Time: 7.97, Learning Rate: 1.000e-06
# It: 290, Loss: 6.261e+01, Y0: -7.539, Time: 8.03, Learning Rate: 1.000e-06
# It: 300, Loss: 6.109e+01, Y0: -7.544, Time: 8.15, Learning Rate: 1.000e-06
# It: 310, Loss: 6.689e+01, Y0: -7.541, Time: 7.96, Learning Rate: 1.000e-06
# It: 320, Loss: 7.813e+01, Y0: -7.545, Time: 7.98, Learning Rate: 1.000e-06
# It: 330, Loss: 6.113e+01, Y0: -7.543, Time: 8.04, Learning Rate: 1.000e-06
# It: 340, Loss: 6.363e+01, Y0: -7.547, Time: 8.03, Learning Rate: 1.000e-06
# It: 350, Loss: 6.504e+01, Y0: -7.545, Time: 8.03, Learning Rate: 1.000e-06
# It: 360, Loss: 6.580e+01, Y0: -7.550, Time: 7.99, Learning Rate: 1.000e-06
# It: 370, Loss: 6.135e+01, Y0: -7.552, Time: 8.00, Learning Rate: 1.000e-06
# It: 380, Loss: 8.156e+01, Y0: -7.567, Time: 8.07, Learning Rate: 1.000e-06
# It: 390, Loss: 6.319e+01, Y0: -7.576, Time: 7.96, Learning Rate: 1.000e-06
# It: 400, Loss: 6.614e+01, Y0: -7.591, Time: 7.94, Learning Rate: 1.000e-06
# It: 410, Loss: 6.813e+01, Y0: -7.589, Time: 7.94, Learning Rate: 1.000e-06
# It: 420, Loss: 6.918e+01, Y0: -7.589, Time: 7.99, Learning Rate: 1.000e-06
# It: 430, Loss: 6.060e+01, Y0: -7.581, Time: 8.02, Learning Rate: 1.000e-06
# It: 440, Loss: 6.390e+01, Y0: -7.579, Time: 7.96, Learning Rate: 1.000e-06
# It: 450, Loss: 6.211e+01, Y0: -7.574, Time: 7.99, Learning Rate: 1.000e-06
# It: 460, Loss: 6.275e+01, Y0: -7.584, Time: 7.99, Learning Rate: 1.000e-06
# It: 470, Loss: 6.166e+01, Y0: -7.585, Time: 7.97, Learning Rate: 1.000e-06
# It: 480, Loss: 6.307e+01, Y0: -7.594, Time: 8.02, Learning Rate: 1.000e-06
# It: 490, Loss: 6.089e+01, Y0: -7.603, Time: 7.93, Learning Rate: 1.000e-06
# It: 500, Loss: 7.676e+01, Y0: -7.597, Time: 8.09, Learning Rate: 1.000e-06
# It: 510, Loss: 6.307e+01, Y0: -7.597, Time: 7.94, Learning Rate: 1.000e-06
# It: 520, Loss: 6.497e+01, Y0: -7.580, Time: 7.93, Learning Rate: 1.000e-06
# It: 530, Loss: 6.282e+01, Y0: -7.570, Time: 8.00, Learning Rate: 1.000e-06
# It: 540, Loss: 6.083e+01, Y0: -7.561, Time: 8.01, Learning Rate: 1.000e-06
# It: 550, Loss: 6.097e+01, Y0: -7.558, Time: 7.95, Learning Rate: 1.000e-06
# It: 560, Loss: 6.746e+01, Y0: -7.548, Time: 8.03, Learning Rate: 1.000e-06
# It: 570, Loss: 7.020e+01, Y0: -7.543, Time: 7.97, Learning Rate: 1.000e-06
# It: 580, Loss: 6.310e+01, Y0: -7.545, Time: 7.98, Learning Rate: 1.000e-06
# It: 590, Loss: 6.641e+01, Y0: -7.545, Time: 8.06, Learning Rate: 1.000e-06
# It: 600, Loss: 6.231e+01, Y0: -7.555, Time: 7.99, Learning Rate: 1.000e-06
# It: 610, Loss: 6.529e+01, Y0: -7.546, Time: 7.94, Learning Rate: 1.000e-06
# It: 620, Loss: 6.021e+01, Y0: -7.550, Time: 7.97, Learning Rate: 1.000e-06
# It: 630, Loss: 6.450e+01, Y0: -7.558, Time: 7.95, Learning Rate: 1.000e-06
# It: 640, Loss: 6.188e+01, Y0: -7.550, Time: 8.00, Learning Rate: 1.000e-06
# It: 650, Loss: 6.482e+01, Y0: -7.561, Time: 7.96, Learning Rate: 1.000e-06
# It: 660, Loss: 6.236e+01, Y0: -7.562, Time: 8.00, Learning Rate: 1.000e-06
# It: 670, Loss: 7.472e+01, Y0: -7.557, Time: 7.98, Learning Rate: 1.000e-06
# It: 680, Loss: 6.503e+01, Y0: -7.545, Time: 7.99, Learning Rate: 1.000e-06
# It: 690, Loss: 6.416e+01, Y0: -7.541, Time: 7.94, Learning Rate: 1.000e-06
# [FinalSummary] const=1.0, lr=1.0e-06, iters=700, eval_loss=6.229e+01±1.39e+00, eval_Y0=-7.533±0.000, time=577.7s
# === Curriculum Log (compact) ===
# phase=curriculum, const=1.0, lr=1.0e-03, iters=700, eval_loss=2.247e+02, eval_y0=-4.221, elapsed_sec=816.0863900184631
# phase=curriculum, const=1.0, lr=5.0e-04, iters=700, eval_loss=8.130e+01, eval_y0=-5.862, elapsed_sec=579.6754195690155
# phase=curriculum, const=1.0, lr=1.0e-04, iters=700, eval_loss=6.925e+01, eval_y0=-6.819, elapsed_sec=579.8063805103302
# phase=curriculum, const=1.0, lr=5.0e-05, iters=700, eval_loss=6.882e+01, eval_y0=-7.576, elapsed_sec=580.9745194911957
# phase=final_finetune, const=1.0, lr=1.0e-05, iters=700, eval_loss=6.574e+01, eval_y0=-7.431, elapsed_sec=579.8549728393555
# phase=final_finetune, const=1.0, lr=5.0e-06, iters=700, eval_loss=6.491e+01, eval_y0=-7.541, elapsed_sec=580.0558767318726
# phase=final_finetune, const=1.0, lr=1.0e-06, iters=700, eval_loss=6.229e+01, eval_y0=-7.533, elapsed_sec=577.7141990661621

# %%
    # --- PLOTTING ---
    t_test, W_test = model.fetch_minibatch()
    X_pred, Y_pred, Z_pred = model.predict(Xi, t_test, W_test)

    def u_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X_state = Xi_arr[:, 3:4]
        return -params['gamma'] * np.exp(S)*X_state + V**2 + V*X_state

    def z_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X_state = Xi_arr[:, 3:4]

        s1 = params['s1']
        s2 = params['s2']
        s3 = params['s3']

        common = np.exp(-t)
        z_s = -params['gamma'] * np.exp(S)*X_state * s1
        z_h = np.zeros_like(z_s)
        z_v = (2 * V + X_state) * s3
        z_x = np.zeros_like(z_s)

        return np.concatenate([z_s, z_h, z_v, z_x], axis=1)

    Xi_reshaped = X_pred.reshape(-1, D)
    t_reshaped = t_test.reshape(-1, 1)

    Y_exact = u_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, 1)
    Z_exact = z_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, D)

    exact_Y0 = u_exact(np.array([[0.0]]), Xi)[0, 0]
    print(f"\nPredicted Y0: {Y_pred[0,0,0]:.4f}")
    print(f"Exact Y0:     {exact_Y0:.4f}")

    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], X_pred[0,:,0], 'b', label='S trajectory')
    plt.plot(t_test[0,:,0], X_pred[0,:,1], 'r', label='H trajectory')
    plt.plot(t_test[0,:,0], X_pred[0,:,2], 'y', label='V trajectory')
    plt.plot(t_test[0,:,0], X_pred[0,:,3], 'g', label='X trajectory')
    plt.title("Soluzione Sistema Pienamente Accoppiato 4D")
    plt.xlabel("Tempo t")
    plt.ylabel("A_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    #plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_FSDE.png")

    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], Y_pred[0,:,0], 'b', label='Learned Y')
    plt.plot(t_test[0,:,0], Y_exact[0,:,0], 'r--', label='Exact Y')
    plt.plot(t_test[1:5,:,0].T, Y_pred[1:5,:,0].T, 'b')
    plt.plot(t_test[1:5,:,0].T, Y_exact[1:5,:,0].T, 'r--')
    plt.title("Soluzione Sistema Pienamente Accoppiato 4D")
    plt.xlabel("Tempo t")
    plt.ylabel("Y_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    #plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_Y.png")

    # Errore relativo medio sui componenti di Z (stile log_z, ma corretto per ogni componente)
    eps = 1e-8
    rel_err_Z = np.abs((Z_pred - Z_exact) / (np.abs(Z_exact) + eps))
    mean_rel_err_Z = np.mean(rel_err_Z, axis=0)  # (N+1, D)

    labels = ['Z_S', 'Z_H', 'Z_V', 'Z_X']
    colors = ['b', 'g', 'r', 'm']

    plt.figure(figsize=(10,6))
    for d in range(D):
        plt.plot(t_test[0,:,0], mean_rel_err_Z[:, d], colors[d], label=f'Mean Rel Error {labels[d]}')
    plt.yscale('log')
    plt.title('Errore relativo medio di Z (scala log)')
    plt.xlabel('Tempo t')
    plt.ylabel('Errore relativo medio')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
    #plt.savefig(f"quadratic_coupled_plots/T_{T}_N_{N}_M_{M}_train_{stage_plan * len(coupling_levels) + final_plan}_Z.png")
# Out:
# Predicted Y0: -7.5327
# Exact Y0:     -6.7500
