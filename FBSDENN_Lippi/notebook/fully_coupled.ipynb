# %% [markdown]
# ### Sistema Fully Coupled
# $$
# \begin{cases}
# dS_t =\mu(c-S_t)dt + \sigma_1dW^1_t\\
#
# dH_t = \mu(c-H_t)dt + \sigma_2 dW^2_t\\
#
# dV_t = a(X^2_t+bH_t+c e^{t}(Z^3_t\sigma_3^{-1}-X_t)/2)dt + \sigma_3 dW^3_t\\
#
# dX_t = V_t dt
#
# \end{cases}
# $$

# %% [markdown]
# ### Soluzione
# $$
#     u(t,s,h,v,x) = e^{-t}(e^s + e^{s}h + v^2 + xv)
# $$

# %%
## Rete neurale con normalizzazione della loss
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from abc import ABC, abstractmethod

class FBSNN(ABC): # Forward-Backward Stochastic Neural Network
    def __init__(self, Xi, T,
                       M, N, D,
                       layers):
        
        self.Xi = Xi # initial point
        self.T = T # terminal time
        
        self.M = M # number of trajectories
        self.N = N # number of time snapshots
        self.D = D # number of dimensions
        
        # layers
        self.layers = layers # (D+1) --> 1
        
        # initialize NN
        self.weights, self.biases = self.initialize_NN(layers)
        
        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        # tf placeholders and graph (training)
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.t_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, 1]) # M x (N+1) x 1
        self.W_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, self.D]) # M x (N+1) x D
        self.Xi_tf = tf.placeholder(tf.float32, shape=[1, D]) # 1 x D

        self.loss, self.X_pred, self.Y_pred, self.Y0_pred = self.loss_function(self.t_tf, self.W_tf, self.Xi_tf)
                
        # optimizers
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.learning_rate)
        self.train_op = self.optimizer.minimize(self.loss)
        
        # initialize session and variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
    
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases
        
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim],
                                               stddev=xavier_stddev), dtype=tf.float32)
    
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1
        
        H = X
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
    def net_u(self, t, X): # M x 1, M x D
        
        u = self.neural_net(tf.concat([t,X], 1), self.weights, self.biases) # M x 1
        Du = tf.gradients(u, X)[0] # M x D
        
        return u, Du

    def Dg_tf(self, X): # M x D
        return tf.gradients(self.g_tf(X), X)[0] # M x D
        
    def loss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        loss = 0
        X_list = []
        Y_list = []
        
        t0 = t[:,0,:]
        W0 = W[:,0,:]
        X0 = tf.tile(Xi,[self.M,1]) # M x D
        Y0, Du0 = self.net_u(t0,X0) # M x 1, M x D
        #Aggiornamento codice
        sigma0 = self.sigma_tf(t0, X0, Y0)
        Z0 = tf.squeeze(tf.matmul(tf.expand_dims(Du0, 1), sigma0), axis=1)
        
        X_list.append(X0)
        Y_list.append(Y0)
        
        for n in range(0,self.N):
            t1 = t[:,n+1,:]
            W1 = W[:,n+1,:]
            dW = W1 - W0
            sigma_dW = tf.squeeze(tf.matmul(self.sigma_tf(t0,X0,Y0), tf.expand_dims(dW,-1)), axis=[-1])
            X1 = X0 + self.mu_tf(t0,X0,Y0,Z0)*(t1-t0) + sigma_dW
            # Se Z = Du*sigma e nella backward compare solo Z, il termine stocastico e' Z * dW.
            Y1_tilde = Y0 + self.phi_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.reduce_sum(Z0*dW, axis=1, keepdims = True)
            #Modifica
            Y1, Du1 = self.net_u(t1,X1)
            sigma1 = self.sigma_tf(t1, X1, Y1)

            Z1 = tf.squeeze(tf.matmul(tf.expand_dims(Du1, 1), sigma1), axis=1)

            loss += tf.reduce_sum(tf.square(Y1 - Y1_tilde))
            
            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            
            X_list.append(X0)
            Y_list.append(Y0)
        
        #Modifica loss finale che deve paragonare anche Z target con Dg*sigma
        loss += tf.reduce_sum(tf.square(Y1 - self.g_tf(X1)))
        Dg = self.Dg_tf(X1)
        Z_terminal = tf.squeeze(tf.matmul(tf.expand_dims(Dg, 1), sigma1), axis=1)
        loss += tf.reduce_sum(tf.square(Z1 - Z_terminal))

        X = tf.stack(X_list,axis=1)
        Y = tf.stack(Y_list,axis=1)
        
        return loss/self.N, X, Y, Y[0,0,0]

    def fetch_minibatch(self):
        T = self.T
        
        M = self.M
        N = self.N
        D = self.D
        
        Dt = np.zeros((M,N+1,1)) # M x (N+1) x 1
        DW = np.zeros((M,N+1,D)) # M x (N+1) x D
        
        dt = T/N
        
        Dt[:,1:,:] = dt
        DW[:,1:,:] = np.sqrt(dt)*np.random.normal(size=(M,N,D))
        
        t = np.cumsum(Dt,axis=1) # M x (N+1) x 1
        W = np.cumsum(DW,axis=1) # M x (N+1) x D
        
        return t, W
    
    def train(self, N_Iter, learning_rate):
        
        start_time = time.time()
        for it in range(N_Iter):
            
            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D
            
            tf_dict = {self.Xi_tf: self.Xi, self.t_tf: t_batch, self.W_tf: W_batch, self.learning_rate: learning_rate}
            
            self.sess.run(self.train_op, tf_dict)
            
            # Print
            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.loss, self.Y0_pred, self.learning_rate], tf_dict)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' % 
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()
                
    
    def predict(self, Xi_star, t_star, W_star):
        
        tf_dict = {self.Xi_tf: Xi_star, self.t_tf: t_star, self.W_tf: W_star}
        
        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        
        return X_star, Y_star
    @abstractmethod
    def phi_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        pass # M x1
    
    @abstractmethod
    def g_tf(self, X): # M x D
        pass # M x 1
    
    @abstractmethod
    def mu_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return np.zeros([M,D]) # M x D
    
    @abstractmethod
    def sigma_tf(self, t, X, Y): # M x 1, M x D, M x 1
        M = self.M
        D = self.D
        return tf.matrix_diag(tf.ones([M,D])) # M x D x D
    ###########################################################################
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class NN(FBSNN):
    def __init__(self, Xi, T, M, N, D, layers, parameters):
        self.mu = parameters['mu']
        self.c = parameters['c']
        self.b = parameters['b']
        self.a = parameters['a']
        self.s1 = parameters['s1']
        self.s2 = parameters['s2']
        self.s3 = parameters['s3']
        super().__init__(Xi, T, M, N, D, layers)
    
    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu = tf.cast(self.mu, tf.float32)
        c = tf.cast(self.c, tf.float32)
        a = tf.cast(self.a, tf.float32)
        b = tf.cast(self.b, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        #Accoppiamento
        #Z ha dimensione [M, D]. Le colonne sono nella forma
        #[Z_S, Z_H, Z_V, Z_X]
        Z_V = Z[:, 2:3]
        exp_t = tf.exp(t)
        V_from_Z = 0.5 * ((exp_t * Z_V / s3) - X_state)
        dS = mu * (c - S)
        dH = mu * (c - H)
        dV = self.a * (X_state**2 + b*H + c*V_from_Z)
        dX = V
        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        exp_T = tf.exp(-self.T)
        exp_S = tf.exp(S)
        val = exp_S + (exp_S * H) + (V**2) + (X_state*V)
        return exp_T * val

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        
        mu = tf.cast(self.mu, tf.float32)
        c = tf.cast(self.c, tf.float32)
        a = tf.cast(self.a, tf.float32)
        b = tf.cast(self.b, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        
        exp_t = tf.exp(-t)
        exp_S = tf.exp(S)

        term1 = (1.0 + H) * (mu * (c - S) * exp_S)
        term2 = mu * (c - H) * exp_S
        term3 = (2.0 * V + X_state) * (a * (X_state**2 + b * H + c * V))
        term4 = V**2 + s3**2
        term5 = 0.5 * exp_S * (s1**2) * (1.0 + H)
        
        equation = term1 + term2 + term3 + term4 + term5
        equation = tf.cast(equation, tf.float32)
        
        return -(Y - (exp_t * equation))
    
    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)

        return tf.stack([r1, r2, r3, r4], axis=1)

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    M = 1024      
    N = 200      
    D = 4
    T = 1.0

    params = {
        'mu': np.float32(1.0),
        'c': np.float32(1.0),
        'b': np.float32(1.0),
        'a': np.float32(1.0),
        's1': np.float32(0.5),
        's2': np.float32(0.5),
        's3': np.float32(0.5),        
    }

    Xi = np.array([1.5, 0.5, 0.5, 0.5]).reshape(1, D)
    
    layers = [D+1] + 4*[256] + [1]
    
    model = NN(Xi, T, M, N, D, layers, params)

    print("===WARMUP===")
    model.train(N_Iter = 500, learning_rate=1e-4)
    
    print("=== Avvio training (High Precision) ===")
    # Strategia di training a step
    model.train(N_Iter = 3000, learning_rate = 1e-3)
    model.train(N_Iter = 5000, learning_rate = 1e-4)
    model.train(N_Iter = 5000, learning_rate = 1e-5) 
    model.train(N_Iter = 3000, learning_rate = 1e-6) 

    # --- PLOTTING ---
    t_test, W_test = model.fetch_minibatch()
    X_pred, Y_pred = model.predict(Xi, t_test, W_test)

    def u_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X = Xi_arr[:, 3:4]
        # u = e^-t * (e^S + e^S*H + V^2 + X*V)
        return np.exp(-t) * (np.exp(S) + np.exp(S)*H + V**2 + X*V)
    
    Xi_reshaped = X_pred.reshape(-1, D)
    t_reshaped = t_test.reshape(-1, 1)
    
    # Calcolo soluzione esatta sui punti predetti
    Y_exact = u_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, 1)
    
    exact_Y0 = u_exact(np.array([[0.0]]), Xi)[0,0]
    print(f"\nPredicted Y0: {Y_pred[0,0,0]:.4f}")
    print(f"Exact Y0:     {exact_Y0:.4f}")
    
    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], Y_pred[0,:,0], 'b', label='Learned Y')
    plt.plot(t_test[0,:,0], Y_exact[0,:,0], 'r--', label='Exact Y')
    # Plot di altre traiettorie per vedere la varianza
    plt.plot(t_test[1:5,:,0].T, Y_pred[1:5,:,0].T, 'b')
    plt.plot(t_test[1:5,:,0].T, Y_exact[1:5,:,0].T, 'r--')
    plt.title("Soluzione Sistema Pienamente Accoppiato 4D")
    plt.xlabel("Tempo t")
    plt.ylabel("Y_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
#
# ===WARMUP===
# It: 0, Loss: 1.220e+02, Y0: 0.053, Time: 42.48, Learning Rate: 1.000e-04
# It: 10, Loss: 6.093e+01, Y0: 0.782, Time: 2.78, Learning Rate: 1.000e-04
# It: 20, Loss: 2.300e+01, Y0: 1.688, Time: 2.74, Learning Rate: 1.000e-04
# It: 30, Loss: 1.868e+01, Y0: 2.576, Time: 2.76, Learning Rate: 1.000e-04
# It: 40, Loss: 1.843e+01, Y0: 2.715, Time: 3.26, Learning Rate: 1.000e-04
# It: 50, Loss: 1.674e+01, Y0: 2.519, Time: 2.79, Learning Rate: 1.000e-04
# It: 60, Loss: 1.674e+01, Y0: 2.565, Time: 2.78, Learning Rate: 1.000e-04
# It: 70, Loss: 1.508e+01, Y0: 2.783, Time: 2.73, Learning Rate: 1.000e-04
# It: 80, Loss: 1.575e+01, Y0: 2.912, Time: 3.24, Learning Rate: 1.000e-04
# It: 90, Loss: 1.497e+01, Y0: 2.972, Time: 2.81, Learning Rate: 1.000e-04
# It: 100, Loss: 1.458e+01, Y0: 3.045, Time: 2.74, Learning Rate: 1.000e-04
# It: 110, Loss: 1.365e+01, Y0: 3.134, Time: 2.77, Learning Rate: 1.000e-04
# It: 120, Loss: 1.362e+01, Y0: 3.242, Time: 3.27, Learning Rate: 1.000e-04
# It: 130, Loss: 1.334e+01, Y0: 3.371, Time: 2.79, Learning Rate: 1.000e-04
# It: 140, Loss: 1.262e+01, Y0: 3.476, Time: 2.80, Learning Rate: 1.000e-04
# It: 150, Loss: 1.255e+01, Y0: 3.590, Time: 2.79, Learning Rate: 1.000e-04
# It: 160, Loss: 1.181e+01, Y0: 3.754, Time: 3.27, Learning Rate: 1.000e-04
# It: 170, Loss: 1.149e+01, Y0: 3.883, Time: 2.79, Learning Rate: 1.000e-04
# It: 180, Loss: 1.080e+01, Y0: 4.011, Time: 2.79, Learning Rate: 1.000e-04
# It: 190, Loss: 1.077e+01, Y0: 4.178, Time: 2.77, Learning Rate: 1.000e-04
# It: 200, Loss: 1.076e+01, Y0: 4.286, Time: 3.24, Learning Rate: 1.000e-04
# It: 210, Loss: 9.903e+00, Y0: 4.393, Time: 2.80, Learning Rate: 1.000e-04
# It: 220, Loss: 9.979e+00, Y0: 4.509, Time: 2.81, Learning Rate: 1.000e-04
# It: 230, Loss: 9.888e+00, Y0: 4.533, Time: 2.79, Learning Rate: 1.000e-04
# It: 240, Loss: 1.011e+01, Y0: 4.592, Time: 3.27, Learning Rate: 1.000e-04
# It: 250, Loss: 9.808e+00, Y0: 4.631, Time: 2.81, Learning Rate: 1.000e-04
# It: 260, Loss: 9.940e+00, Y0: 4.640, Time: 2.80, Learning Rate: 1.000e-04
# It: 270, Loss: 1.023e+01, Y0: 4.646, Time: 2.81, Learning Rate: 1.000e-04
# It: 280, Loss: 9.697e+00, Y0: 4.643, Time: 3.24, Learning Rate: 1.000e-04
# It: 290, Loss: 9.749e+00, Y0: 4.654, Time: 2.82, Learning Rate: 1.000e-04
# It: 300, Loss: 1.037e+01, Y0: 4.666, Time: 2.80, Learning Rate: 1.000e-04
# It: 310, Loss: 1.051e+01, Y0: 4.600, Time: 2.83, Learning Rate: 1.000e-04
# It: 320, Loss: 1.020e+01, Y0: 4.584, Time: 3.20, Learning Rate: 1.000e-04
# It: 330, Loss: 1.060e+01, Y0: 4.615, Time: 2.81, Learning Rate: 1.000e-04
# It: 340, Loss: 1.030e+01, Y0: 4.592, Time: 2.81, Learning Rate: 1.000e-04
# It: 350, Loss: 9.779e+00, Y0: 4.568, Time: 2.91, Learning Rate: 1.000e-04
# It: 360, Loss: 9.779e+00, Y0: 4.548, Time: 3.15, Learning Rate: 1.000e-04
# It: 370, Loss: 9.453e+00, Y0: 4.559, Time: 2.82, Learning Rate: 1.000e-04
# It: 380, Loss: 1.022e+01, Y0: 4.553, Time: 2.83, Learning Rate: 1.000e-04
# It: 390, Loss: 9.521e+00, Y0: 4.544, Time: 3.02, Learning Rate: 1.000e-04
# It: 400, Loss: 9.342e+00, Y0: 4.543, Time: 3.08, Learning Rate: 1.000e-04
# It: 410, Loss: 9.623e+00, Y0: 4.491, Time: 2.84, Learning Rate: 1.000e-04
# It: 420, Loss: 9.649e+00, Y0: 4.454, Time: 2.84, Learning Rate: 1.000e-04
# It: 430, Loss: 9.226e+00, Y0: 4.447, Time: 3.09, Learning Rate: 1.000e-04
# It: 440, Loss: 9.329e+00, Y0: 4.425, Time: 3.01, Learning Rate: 1.000e-04
# It: 450, Loss: 9.143e+00, Y0: 4.342, Time: 2.84, Learning Rate: 1.000e-04
# It: 460, Loss: 9.254e+00, Y0: 4.271, Time: 2.79, Learning Rate: 1.000e-04
# It: 470, Loss: 8.981e+00, Y0: 4.227, Time: 3.19, Learning Rate: 1.000e-04
# It: 480, Loss: 8.876e+00, Y0: 4.208, Time: 2.90, Learning Rate: 1.000e-04
# It: 490, Loss: 8.664e+00, Y0: 4.139, Time: 2.82, Learning Rate: 1.000e-04
# === Avvio training (High Precision) ===
# It: 0, Loss: 8.609e+00, Y0: 4.009, Time: 0.28, Learning Rate: 1.000e-03
# It: 10, Loss: 8.439e+00, Y0: 3.682, Time: 3.30, Learning Rate: 1.000e-03
# It: 20, Loss: 8.207e+00, Y0: 3.622, Time: 2.82, Learning Rate: 1.000e-03
# It: 30, Loss: 8.269e+00, Y0: 3.634, Time: 2.83, Learning Rate: 1.000e-03
# It: 40, Loss: 8.148e+00, Y0: 3.555, Time: 2.79, Learning Rate: 1.000e-03
# It: 50, Loss: 8.251e+00, Y0: 3.556, Time: 3.29, Learning Rate: 1.000e-03
# It: 60, Loss: 8.403e+00, Y0: 3.490, Time: 2.83, Learning Rate: 1.000e-03
# It: 70, Loss: 7.943e+00, Y0: 3.322, Time: 2.80, Learning Rate: 1.000e-03
# It: 80, Loss: 8.036e+00, Y0: 3.327, Time: 2.81, Learning Rate: 1.000e-03
# It: 90, Loss: 8.255e+00, Y0: 3.314, Time: 3.31, Learning Rate: 1.000e-03
# It: 100, Loss: 7.907e+00, Y0: 3.252, Time: 2.80, Learning Rate: 1.000e-03
# It: 110, Loss: 8.653e+00, Y0: 3.310, Time: 2.82, Learning Rate: 1.000e-03
# It: 120, Loss: 8.228e+00, Y0: 3.181, Time: 2.79, Learning Rate: 1.000e-03
# It: 130, Loss: 8.075e+00, Y0: 3.196, Time: 3.31, Learning Rate: 1.000e-03
# It: 140, Loss: 8.243e+00, Y0: 3.252, Time: 2.82, Learning Rate: 1.000e-03
# It: 150, Loss: 7.821e+00, Y0: 3.025, Time: 2.85, Learning Rate: 1.000e-03
# It: 160, Loss: 7.864e+00, Y0: 2.984, Time: 2.83, Learning Rate: 1.000e-03
# It: 170, Loss: 7.962e+00, Y0: 3.040, Time: 3.26, Learning Rate: 1.000e-03
# It: 180, Loss: 8.055e+00, Y0: 2.948, Time: 2.83, Learning Rate: 1.000e-03
# It: 190, Loss: 8.502e+00, Y0: 2.888, Time: 2.84, Learning Rate: 1.000e-03
# It: 200, Loss: 7.686e+00, Y0: 2.575, Time: 2.83, Learning Rate: 1.000e-03
# It: 210, Loss: 7.965e+00, Y0: 2.531, Time: 3.25, Learning Rate: 1.000e-03
# It: 220, Loss: 7.838e+00, Y0: 2.465, Time: 2.82, Learning Rate: 1.000e-03
# It: 230, Loss: 7.812e+00, Y0: 2.458, Time: 2.81, Learning Rate: 1.000e-03
# It: 240, Loss: 7.445e+00, Y0: 2.439, Time: 2.81, Learning Rate: 1.000e-03
# It: 250, Loss: 7.974e+00, Y0: 2.387, Time: 3.24, Learning Rate: 1.000e-03
# It: 260, Loss: 7.776e+00, Y0: 2.442, Time: 2.83, Learning Rate: 1.000e-03
# It: 270, Loss: 7.992e+00, Y0: 2.426, Time: 2.81, Learning Rate: 1.000e-03
# It: 280, Loss: 7.753e+00, Y0: 2.499, Time: 2.90, Learning Rate: 1.000e-03
# It: 290, Loss: 7.767e+00, Y0: 2.441, Time: 3.24, Learning Rate: 1.000e-03
# It: 300, Loss: 7.684e+00, Y0: 2.600, Time: 2.81, Learning Rate: 1.000e-03
# It: 310, Loss: 7.543e+00, Y0: 2.542, Time: 2.82, Learning Rate: 1.000e-03
# It: 320, Loss: 7.235e+00, Y0: 2.532, Time: 3.03, Learning Rate: 1.000e-03
# It: 330, Loss: 7.606e+00, Y0: 2.644, Time: 3.08, Learning Rate: 1.000e-03
# It: 340, Loss: 7.570e+00, Y0: 2.545, Time: 2.81, Learning Rate: 1.000e-03
# It: 350, Loss: 7.848e+00, Y0: 2.680, Time: 2.82, Learning Rate: 1.000e-03
# It: 360, Loss: 7.523e+00, Y0: 2.504, Time: 3.08, Learning Rate: 1.000e-03
# It: 370, Loss: 7.256e+00, Y0: 2.665, Time: 2.98, Learning Rate: 1.000e-03
# It: 380, Loss: 7.782e+00, Y0: 2.608, Time: 2.80, Learning Rate: 1.000e-03
# It: 390, Loss: 7.595e+00, Y0: 2.664, Time: 2.82, Learning Rate: 1.000e-03
# It: 400, Loss: 7.001e+00, Y0: 2.511, Time: 3.17, Learning Rate: 1.000e-03
# It: 410, Loss: 7.277e+00, Y0: 1.898, Time: 2.92, Learning Rate: 1.000e-03
# It: 420, Loss: 6.791e+00, Y0: 2.221, Time: 2.85, Learning Rate: 1.000e-03
# It: 430, Loss: 6.972e+00, Y0: 2.258, Time: 2.85, Learning Rate: 1.000e-03
# It: 440, Loss: 7.107e+00, Y0: 2.268, Time: 3.35, Learning Rate: 1.000e-03
# It: 450, Loss: 7.262e+00, Y0: 2.391, Time: 2.88, Learning Rate: 1.000e-03
# It: 460, Loss: 7.027e+00, Y0: 2.478, Time: 2.83, Learning Rate: 1.000e-03
# It: 470, Loss: 7.063e+00, Y0: 2.559, Time: 2.82, Learning Rate: 1.000e-03
# It: 480, Loss: 6.668e+00, Y0: 2.396, Time: 3.32, Learning Rate: 1.000e-03
# It: 490, Loss: 6.729e+00, Y0: 2.456, Time: 2.83, Learning Rate: 1.000e-03
# It: 500, Loss: 7.011e+00, Y0: 2.758, Time: 2.80, Learning Rate: 1.000e-03
# It: 510, Loss: 6.726e+00, Y0: 2.702, Time: 2.85, Learning Rate: 1.000e-03
# It: 520, Loss: 6.984e+00, Y0: 2.707, Time: 3.29, Learning Rate: 1.000e-03
# It: 530, Loss: 6.729e+00, Y0: 2.971, Time: 2.80, Learning Rate: 1.000e-03
# It: 540, Loss: 6.925e+00, Y0: 3.086, Time: 2.79, Learning Rate: 1.000e-03
# It: 550, Loss: 6.961e+00, Y0: 3.079, Time: 2.82, Learning Rate: 1.000e-03
# It: 560, Loss: 6.583e+00, Y0: 3.060, Time: 3.28, Learning Rate: 1.000e-03
# It: 570, Loss: 6.736e+00, Y0: 3.195, Time: 2.79, Learning Rate: 1.000e-03
# It: 580, Loss: 6.464e+00, Y0: 3.232, Time: 2.82, Learning Rate: 1.000e-03
# It: 590, Loss: 6.637e+00, Y0: 3.171, Time: 2.83, Learning Rate: 1.000e-03
# It: 600, Loss: 6.471e+00, Y0: 3.248, Time: 3.28, Learning Rate: 1.000e-03
# It: 610, Loss: 6.407e+00, Y0: 3.237, Time: 2.87, Learning Rate: 1.000e-03
# It: 620, Loss: 6.747e+00, Y0: 3.446, Time: 2.79, Learning Rate: 1.000e-03
# It: 630, Loss: 6.574e+00, Y0: 3.429, Time: 2.80, Learning Rate: 1.000e-03
# It: 640, Loss: 6.826e+00, Y0: 3.472, Time: 3.31, Learning Rate: 1.000e-03
# It: 650, Loss: 6.837e+00, Y0: 3.507, Time: 2.80, Learning Rate: 1.000e-03
# It: 660, Loss: 6.299e+00, Y0: 3.528, Time: 2.84, Learning Rate: 1.000e-03
# It: 670, Loss: 6.628e+00, Y0: 3.532, Time: 2.85, Learning Rate: 1.000e-03
# It: 680, Loss: 6.434e+00, Y0: 3.552, Time: 3.24, Learning Rate: 1.000e-03
# It: 690, Loss: 6.516e+00, Y0: 3.575, Time: 2.80, Learning Rate: 1.000e-03
# It: 700, Loss: 6.597e+00, Y0: 3.674, Time: 2.82, Learning Rate: 1.000e-03
# It: 710, Loss: 6.556e+00, Y0: 3.647, Time: 2.93, Learning Rate: 1.000e-03
# It: 720, Loss: 6.563e+00, Y0: 3.441, Time: 3.15, Learning Rate: 1.000e-03
# It: 730, Loss: 7.101e+00, Y0: 3.719, Time: 2.82, Learning Rate: 1.000e-03
# It: 740, Loss: 6.480e+00, Y0: 3.460, Time: 2.84, Learning Rate: 1.000e-03
# It: 750, Loss: 6.345e+00, Y0: 3.392, Time: 3.01, Learning Rate: 1.000e-03
# It: 760, Loss: 6.395e+00, Y0: 3.477, Time: 3.08, Learning Rate: 1.000e-03
# It: 770, Loss: 6.413e+00, Y0: 3.403, Time: 2.80, Learning Rate: 1.000e-03
# It: 780, Loss: 6.280e+00, Y0: 3.427, Time: 2.81, Learning Rate: 1.000e-03
# It: 790, Loss: 6.440e+00, Y0: 3.475, Time: 3.09, Learning Rate: 1.000e-03
# It: 800, Loss: 6.491e+00, Y0: 3.454, Time: 2.97, Learning Rate: 1.000e-03
# It: 810, Loss: 6.630e+00, Y0: 3.314, Time: 2.85, Learning Rate: 1.000e-03
# It: 820, Loss: 6.821e+00, Y0: 3.251, Time: 2.81, Learning Rate: 1.000e-03
# It: 830, Loss: 6.503e+00, Y0: 3.393, Time: 3.19, Learning Rate: 1.000e-03
# It: 840, Loss: 6.407e+00, Y0: 3.262, Time: 2.88, Learning Rate: 1.000e-03
# It: 850, Loss: 6.870e+00, Y0: 3.510, Time: 2.82, Learning Rate: 1.000e-03
# It: 860, Loss: 6.249e+00, Y0: 3.185, Time: 2.81, Learning Rate: 1.000e-03
# It: 870, Loss: 6.381e+00, Y0: 3.148, Time: 3.30, Learning Rate: 1.000e-03
# It: 880, Loss: 6.494e+00, Y0: 3.214, Time: 2.86, Learning Rate: 1.000e-03
# It: 890, Loss: 6.705e+00, Y0: 3.225, Time: 2.80, Learning Rate: 1.000e-03
# It: 900, Loss: 6.707e+00, Y0: 3.229, Time: 2.80, Learning Rate: 1.000e-03
# It: 910, Loss: 6.610e+00, Y0: 3.109, Time: 3.30, Learning Rate: 1.000e-03
# It: 920, Loss: 6.712e+00, Y0: 3.254, Time: 2.83, Learning Rate: 1.000e-03
# It: 930, Loss: 6.516e+00, Y0: 3.014, Time: 2.81, Learning Rate: 1.000e-03
# It: 940, Loss: 6.575e+00, Y0: 3.153, Time: 2.81, Learning Rate: 1.000e-03
# It: 950, Loss: 6.577e+00, Y0: 3.101, Time: 3.28, Learning Rate: 1.000e-03
# It: 960, Loss: 6.617e+00, Y0: 3.177, Time: 2.84, Learning Rate: 1.000e-03
# It: 970, Loss: 6.458e+00, Y0: 3.088, Time: 2.78, Learning Rate: 1.000e-03
# It: 980, Loss: 6.440e+00, Y0: 2.916, Time: 2.83, Learning Rate: 1.000e-03
# It: 990, Loss: 6.484e+00, Y0: 3.091, Time: 3.31, Learning Rate: 1.000e-03
# It: 1000, Loss: 6.319e+00, Y0: 2.935, Time: 2.82, Learning Rate: 1.000e-03
# It: 1010, Loss: 6.542e+00, Y0: 2.933, Time: 2.82, Learning Rate: 1.000e-03
# It: 1020, Loss: 6.617e+00, Y0: 3.031, Time: 2.81, Learning Rate: 1.000e-03
# It: 1030, Loss: 6.527e+00, Y0: 3.005, Time: 3.30, Learning Rate: 1.000e-03
# It: 1040, Loss: 6.365e+00, Y0: 2.937, Time: 2.79, Learning Rate: 1.000e-03
# It: 1050, Loss: 6.736e+00, Y0: 3.003, Time: 2.80, Learning Rate: 1.000e-03
# It: 1060, Loss: 6.515e+00, Y0: 2.775, Time: 2.85, Learning Rate: 1.000e-03
# It: 1070, Loss: 6.260e+00, Y0: 2.782, Time: 3.29, Learning Rate: 1.000e-03
# It: 1080, Loss: 6.354e+00, Y0: 2.940, Time: 2.85, Learning Rate: 1.000e-03
# It: 1090, Loss: 6.398e+00, Y0: 2.749, Time: 2.79, Learning Rate: 1.000e-03
# It: 1100, Loss: 6.139e+00, Y0: 2.746, Time: 2.91, Learning Rate: 1.000e-03
# It: 1110, Loss: 6.372e+00, Y0: 2.739, Time: 3.17, Learning Rate: 1.000e-03
# It: 1120, Loss: 6.764e+00, Y0: 2.973, Time: 2.80, Learning Rate: 1.000e-03
# It: 1130, Loss: 6.644e+00, Y0: 2.789, Time: 2.84, Learning Rate: 1.000e-03
# It: 1140, Loss: 6.655e+00, Y0: 2.853, Time: 2.97, Learning Rate: 1.000e-03
# It: 1150, Loss: 6.398e+00, Y0: 2.763, Time: 3.09, Learning Rate: 1.000e-03
# It: 1160, Loss: 6.682e+00, Y0: 2.821, Time: 2.83, Learning Rate: 1.000e-03
# It: 1170, Loss: 6.425e+00, Y0: 2.785, Time: 2.83, Learning Rate: 1.000e-03
# It: 1180, Loss: 6.306e+00, Y0: 2.847, Time: 3.12, Learning Rate: 1.000e-03
# It: 1190, Loss: 6.740e+00, Y0: 2.847, Time: 3.01, Learning Rate: 1.000e-03
# It: 1200, Loss: 6.847e+00, Y0: 2.645, Time: 2.81, Learning Rate: 1.000e-03
# It: 1210, Loss: 6.626e+00, Y0: 2.838, Time: 2.81, Learning Rate: 1.000e-03
# It: 1220, Loss: 6.758e+00, Y0: 2.861, Time: 3.15, Learning Rate: 1.000e-03
# It: 1230, Loss: 6.345e+00, Y0: 2.813, Time: 2.96, Learning Rate: 1.000e-03
# It: 1240, Loss: 6.545e+00, Y0: 2.905, Time: 2.82, Learning Rate: 1.000e-03
# It: 1250, Loss: 6.258e+00, Y0: 2.750, Time: 2.86, Learning Rate: 1.000e-03
# It: 1260, Loss: 6.288e+00, Y0: 2.679, Time: 3.27, Learning Rate: 1.000e-03
# It: 1270, Loss: 6.299e+00, Y0: 2.740, Time: 2.82, Learning Rate: 1.000e-03
# It: 1280, Loss: 6.658e+00, Y0: 2.888, Time: 2.87, Learning Rate: 1.000e-03
# It: 1290, Loss: 6.191e+00, Y0: 2.835, Time: 2.81, Learning Rate: 1.000e-03
# It: 1300, Loss: 6.281e+00, Y0: 2.818, Time: 3.34, Learning Rate: 1.000e-03
# It: 1310, Loss: 6.274e+00, Y0: 2.938, Time: 2.83, Learning Rate: 1.000e-03
# It: 1320, Loss: 6.424e+00, Y0: 2.839, Time: 2.81, Learning Rate: 1.000e-03
# It: 1330, Loss: 6.527e+00, Y0: 2.858, Time: 2.84, Learning Rate: 1.000e-03
# It: 1340, Loss: 6.131e+00, Y0: 2.902, Time: 3.26, Learning Rate: 1.000e-03
# It: 1350, Loss: 6.488e+00, Y0: 2.953, Time: 2.81, Learning Rate: 1.000e-03
# It: 1360, Loss: 6.389e+00, Y0: 2.963, Time: 2.83, Learning Rate: 1.000e-03
# It: 1370, Loss: 6.411e+00, Y0: 2.918, Time: 2.85, Learning Rate: 1.000e-03
# It: 1380, Loss: 6.300e+00, Y0: 3.022, Time: 3.34, Learning Rate: 1.000e-03
# It: 1390, Loss: 6.143e+00, Y0: 2.988, Time: 2.84, Learning Rate: 1.000e-03
# It: 1400, Loss: 6.350e+00, Y0: 2.854, Time: 2.86, Learning Rate: 1.000e-03
# It: 1410, Loss: 6.497e+00, Y0: 3.071, Time: 2.81, Learning Rate: 1.000e-03
# It: 1420, Loss: 6.275e+00, Y0: 2.979, Time: 3.26, Learning Rate: 1.000e-03
# It: 1430, Loss: 6.547e+00, Y0: 2.960, Time: 2.81, Learning Rate: 1.000e-03
# It: 1440, Loss: 6.321e+00, Y0: 2.980, Time: 2.84, Learning Rate: 1.000e-03
# It: 1450, Loss: 6.115e+00, Y0: 2.908, Time: 2.86, Learning Rate: 1.000e-03
# It: 1460, Loss: 6.332e+00, Y0: 2.901, Time: 3.29, Learning Rate: 1.000e-03
# It: 1470, Loss: 6.146e+00, Y0: 2.889, Time: 2.86, Learning Rate: 1.000e-03
# It: 1480, Loss: 6.640e+00, Y0: 3.003, Time: 2.84, Learning Rate: 1.000e-03
# It: 1490, Loss: 6.479e+00, Y0: 3.041, Time: 2.95, Learning Rate: 1.000e-03
# It: 1500, Loss: 6.059e+00, Y0: 2.782, Time: 3.11, Learning Rate: 1.000e-03
# It: 1510, Loss: 6.165e+00, Y0: 2.909, Time: 2.82, Learning Rate: 1.000e-03
# It: 1520, Loss: 6.195e+00, Y0: 2.740, Time: 2.78, Learning Rate: 1.000e-03
# It: 1530, Loss: 6.169e+00, Y0: 2.814, Time: 3.01, Learning Rate: 1.000e-03
# It: 1540, Loss: 6.239e+00, Y0: 2.835, Time: 3.07, Learning Rate: 1.000e-03
# It: 1550, Loss: 6.547e+00, Y0: 2.912, Time: 2.82, Learning Rate: 1.000e-03
# It: 1560, Loss: 5.967e+00, Y0: 2.752, Time: 2.83, Learning Rate: 1.000e-03
# It: 1570, Loss: 6.283e+00, Y0: 2.831, Time: 3.11, Learning Rate: 1.000e-03
# It: 1580, Loss: 6.268e+00, Y0: 2.998, Time: 3.00, Learning Rate: 1.000e-03
# It: 1590, Loss: 6.386e+00, Y0: 2.855, Time: 2.84, Learning Rate: 1.000e-03
# It: 1600, Loss: 6.053e+00, Y0: 2.760, Time: 2.81, Learning Rate: 1.000e-03
# It: 1610, Loss: 6.047e+00, Y0: 2.800, Time: 3.21, Learning Rate: 1.000e-03
# It: 1620, Loss: 6.698e+00, Y0: 2.731, Time: 2.86, Learning Rate: 1.000e-03
# It: 1630, Loss: 6.163e+00, Y0: 2.795, Time: 2.84, Learning Rate: 1.000e-03
# It: 1640, Loss: 6.226e+00, Y0: 2.765, Time: 2.83, Learning Rate: 1.000e-03
# It: 1650, Loss: 6.224e+00, Y0: 2.769, Time: 3.31, Learning Rate: 1.000e-03
# It: 1660, Loss: 6.099e+00, Y0: 2.852, Time: 2.88, Learning Rate: 1.000e-03
# It: 1670, Loss: 6.221e+00, Y0: 2.690, Time: 2.86, Learning Rate: 1.000e-03
# It: 1680, Loss: 6.461e+00, Y0: 2.855, Time: 2.82, Learning Rate: 1.000e-03
# It: 1690, Loss: 6.164e+00, Y0: 2.770, Time: 3.29, Learning Rate: 1.000e-03
# It: 1700, Loss: 6.577e+00, Y0: 2.886, Time: 2.82, Learning Rate: 1.000e-03
# It: 1710, Loss: 6.260e+00, Y0: 2.878, Time: 2.83, Learning Rate: 1.000e-03
# It: 1720, Loss: 6.184e+00, Y0: 2.717, Time: 2.82, Learning Rate: 1.000e-03
# It: 1730, Loss: 6.071e+00, Y0: 2.845, Time: 3.28, Learning Rate: 1.000e-03
# It: 1740, Loss: 6.114e+00, Y0: 2.769, Time: 2.80, Learning Rate: 1.000e-03
# It: 1750, Loss: 6.109e+00, Y0: 2.797, Time: 2.84, Learning Rate: 1.000e-03
# It: 1760, Loss: 6.244e+00, Y0: 2.736, Time: 2.81, Learning Rate: 1.000e-03
# It: 1770, Loss: 6.398e+00, Y0: 2.713, Time: 3.31, Learning Rate: 1.000e-03
# It: 1780, Loss: 6.436e+00, Y0: 2.841, Time: 2.83, Learning Rate: 1.000e-03
# It: 1790, Loss: 6.356e+00, Y0: 2.654, Time: 2.79, Learning Rate: 1.000e-03
# It: 1800, Loss: 6.261e+00, Y0: 2.608, Time: 2.85, Learning Rate: 1.000e-03
# It: 1810, Loss: 6.232e+00, Y0: 2.608, Time: 3.32, Learning Rate: 1.000e-03
# It: 1820, Loss: 6.291e+00, Y0: 2.730, Time: 2.83, Learning Rate: 1.000e-03
# It: 1830, Loss: 6.466e+00, Y0: 2.677, Time: 2.83, Learning Rate: 1.000e-03
# It: 1840, Loss: 6.265e+00, Y0: 2.698, Time: 2.93, Learning Rate: 1.000e-03
# It: 1850, Loss: 6.169e+00, Y0: 2.610, Time: 3.16, Learning Rate: 1.000e-03
# It: 1860, Loss: 6.204e+00, Y0: 2.675, Time: 2.84, Learning Rate: 1.000e-03
# It: 1870, Loss: 6.164e+00, Y0: 2.647, Time: 2.82, Learning Rate: 1.000e-03
# It: 1880, Loss: 6.445e+00, Y0: 2.698, Time: 3.05, Learning Rate: 1.000e-03
# It: 1890, Loss: 6.046e+00, Y0: 2.548, Time: 3.06, Learning Rate: 1.000e-03
# It: 1900, Loss: 6.112e+00, Y0: 2.524, Time: 2.80, Learning Rate: 1.000e-03
# It: 1910, Loss: 5.981e+00, Y0: 2.463, Time: 2.81, Learning Rate: 1.000e-03
# It: 1920, Loss: 6.329e+00, Y0: 2.642, Time: 3.10, Learning Rate: 1.000e-03
# It: 1930, Loss: 6.446e+00, Y0: 2.522, Time: 3.04, Learning Rate: 1.000e-03
# It: 1940, Loss: 6.092e+00, Y0: 2.563, Time: 2.84, Learning Rate: 1.000e-03
# It: 1950, Loss: 5.955e+00, Y0: 2.509, Time: 2.84, Learning Rate: 1.000e-03
# It: 1960, Loss: 6.260e+00, Y0: 2.555, Time: 3.20, Learning Rate: 1.000e-03
# It: 1970, Loss: 6.034e+00, Y0: 2.559, Time: 2.95, Learning Rate: 1.000e-03
# It: 1980, Loss: 6.344e+00, Y0: 2.530, Time: 2.82, Learning Rate: 1.000e-03
# It: 1990, Loss: 6.328e+00, Y0: 2.521, Time: 2.84, Learning Rate: 1.000e-03
# It: 2000, Loss: 6.030e+00, Y0: 2.420, Time: 3.29, Learning Rate: 1.000e-03
# It: 2010, Loss: 6.442e+00, Y0: 2.550, Time: 2.81, Learning Rate: 1.000e-03
# It: 2020, Loss: 6.053e+00, Y0: 2.525, Time: 2.80, Learning Rate: 1.000e-03
# It: 2030, Loss: 6.411e+00, Y0: 2.565, Time: 2.88, Learning Rate: 1.000e-03
# It: 2040, Loss: 6.146e+00, Y0: 2.513, Time: 3.31, Learning Rate: 1.000e-03
# It: 2050, Loss: 6.429e+00, Y0: 2.413, Time: 2.83, Learning Rate: 1.000e-03
# It: 2060, Loss: 6.035e+00, Y0: 2.409, Time: 2.84, Learning Rate: 1.000e-03
# It: 2070, Loss: 6.096e+00, Y0: 2.411, Time: 2.87, Learning Rate: 1.000e-03
# It: 2080, Loss: 6.390e+00, Y0: 2.553, Time: 3.26, Learning Rate: 1.000e-03
# It: 2090, Loss: 6.102e+00, Y0: 2.509, Time: 2.85, Learning Rate: 1.000e-03
# It: 2100, Loss: 6.060e+00, Y0: 2.447, Time: 2.82, Learning Rate: 1.000e-03
# It: 2110, Loss: 6.167e+00, Y0: 2.389, Time: 2.84, Learning Rate: 1.000e-03
# It: 2120, Loss: 6.333e+00, Y0: 2.361, Time: 3.30, Learning Rate: 1.000e-03
# It: 2130, Loss: 6.127e+00, Y0: 2.304, Time: 2.80, Learning Rate: 1.000e-03
# It: 2140, Loss: 5.960e+00, Y0: 2.392, Time: 2.84, Learning Rate: 1.000e-03
# It: 2150, Loss: 6.182e+00, Y0: 2.470, Time: 2.81, Learning Rate: 1.000e-03
# It: 2160, Loss: 6.239e+00, Y0: 2.303, Time: 3.26, Learning Rate: 1.000e-03
# It: 2170, Loss: 6.045e+00, Y0: 2.312, Time: 2.87, Learning Rate: 1.000e-03
# It: 2180, Loss: 6.334e+00, Y0: 2.321, Time: 2.81, Learning Rate: 1.000e-03
# It: 2190, Loss: 6.044e+00, Y0: 2.254, Time: 2.87, Learning Rate: 1.000e-03
# It: 2200, Loss: 6.001e+00, Y0: 2.422, Time: 3.17, Learning Rate: 1.000e-03
# It: 2210, Loss: 6.331e+00, Y0: 2.482, Time: 2.84, Learning Rate: 1.000e-03
# It: 2220, Loss: 6.118e+00, Y0: 2.420, Time: 2.82, Learning Rate: 1.000e-03
# It: 2230, Loss: 6.045e+00, Y0: 2.421, Time: 2.98, Learning Rate: 1.000e-03
# It: 2240, Loss: 6.282e+00, Y0: 2.497, Time: 3.11, Learning Rate: 1.000e-03
# It: 2250, Loss: 6.131e+00, Y0: 2.395, Time: 2.81, Learning Rate: 1.000e-03
# It: 2260, Loss: 6.326e+00, Y0: 2.453, Time: 2.81, Learning Rate: 1.000e-03
# It: 2270, Loss: 6.040e+00, Y0: 2.518, Time: 3.10, Learning Rate: 1.000e-03
# It: 2280, Loss: 6.160e+00, Y0: 2.483, Time: 2.98, Learning Rate: 1.000e-03
# It: 2290, Loss: 6.103e+00, Y0: 2.476, Time: 2.81, Learning Rate: 1.000e-03
# It: 2300, Loss: 6.104e+00, Y0: 2.400, Time: 2.81, Learning Rate: 1.000e-03
# It: 2310, Loss: 6.037e+00, Y0: 2.385, Time: 3.14, Learning Rate: 1.000e-03
# It: 2320, Loss: 6.112e+00, Y0: 2.408, Time: 2.91, Learning Rate: 1.000e-03
# It: 2330, Loss: 6.223e+00, Y0: 2.443, Time: 2.80, Learning Rate: 1.000e-03
# It: 2340, Loss: 6.108e+00, Y0: 2.445, Time: 2.80, Learning Rate: 1.000e-03
# It: 2350, Loss: 6.251e+00, Y0: 2.365, Time: 3.30, Learning Rate: 1.000e-03
# It: 2360, Loss: 6.065e+00, Y0: 2.480, Time: 2.84, Learning Rate: 1.000e-03
# It: 2370, Loss: 5.947e+00, Y0: 2.444, Time: 2.85, Learning Rate: 1.000e-03
# It: 2380, Loss: 6.130e+00, Y0: 2.442, Time: 2.84, Learning Rate: 1.000e-03
# It: 2390, Loss: 5.976e+00, Y0: 2.420, Time: 3.30, Learning Rate: 1.000e-03
# It: 2400, Loss: 5.825e+00, Y0: 2.327, Time: 2.84, Learning Rate: 1.000e-03
# It: 2410, Loss: 6.004e+00, Y0: 2.505, Time: 2.82, Learning Rate: 1.000e-03
# It: 2420, Loss: 6.192e+00, Y0: 2.533, Time: 2.84, Learning Rate: 1.000e-03
# It: 2430, Loss: 6.199e+00, Y0: 2.438, Time: 3.33, Learning Rate: 1.000e-03
# It: 2440, Loss: 6.508e+00, Y0: 2.409, Time: 2.86, Learning Rate: 1.000e-03
# It: 2450, Loss: 5.794e+00, Y0: 2.520, Time: 2.84, Learning Rate: 1.000e-03
# It: 2460, Loss: 6.031e+00, Y0: 2.442, Time: 2.88, Learning Rate: 1.000e-03
# It: 2470, Loss: 5.976e+00, Y0: 2.321, Time: 3.32, Learning Rate: 1.000e-03
# It: 2480, Loss: 5.926e+00, Y0: 2.397, Time: 2.82, Learning Rate: 1.000e-03
# It: 2490, Loss: 5.976e+00, Y0: 2.497, Time: 2.97, Learning Rate: 1.000e-03
# It: 2500, Loss: 5.893e+00, Y0: 2.474, Time: 2.86, Learning Rate: 1.000e-03
# It: 2510, Loss: 5.948e+00, Y0: 2.345, Time: 3.26, Learning Rate: 1.000e-03
# It: 2520, Loss: 5.933e+00, Y0: 2.503, Time: 2.80, Learning Rate: 1.000e-03
# It: 2530, Loss: 5.891e+00, Y0: 2.300, Time: 2.78, Learning Rate: 1.000e-03
# It: 2540, Loss: 6.119e+00, Y0: 2.559, Time: 2.96, Learning Rate: 1.000e-03
# It: 2550, Loss: 6.092e+00, Y0: 2.443, Time: 3.16, Learning Rate: 1.000e-03
# It: 2560, Loss: 6.237e+00, Y0: 2.459, Time: 2.87, Learning Rate: 1.000e-03
# It: 2570, Loss: 6.155e+00, Y0: 2.514, Time: 2.85, Learning Rate: 1.000e-03
# It: 2580, Loss: 6.198e+00, Y0: 2.219, Time: 3.05, Learning Rate: 1.000e-03
# It: 2590, Loss: 5.894e+00, Y0: 2.378, Time: 3.06, Learning Rate: 1.000e-03
# It: 2600, Loss: 5.906e+00, Y0: 2.489, Time: 2.83, Learning Rate: 1.000e-03
# It: 2610, Loss: 6.490e+00, Y0: 2.429, Time: 2.82, Learning Rate: 1.000e-03
# It: 2620, Loss: 6.373e+00, Y0: 2.439, Time: 3.21, Learning Rate: 1.000e-03
# It: 2630, Loss: 5.900e+00, Y0: 2.424, Time: 2.94, Learning Rate: 1.000e-03
# It: 2640, Loss: 6.019e+00, Y0: 2.480, Time: 2.82, Learning Rate: 1.000e-03
# It: 2650, Loss: 5.935e+00, Y0: 2.516, Time: 2.83, Learning Rate: 1.000e-03
# It: 2660, Loss: 5.901e+00, Y0: 2.364, Time: 3.26, Learning Rate: 1.000e-03
# It: 2670, Loss: 5.955e+00, Y0: 2.421, Time: 2.83, Learning Rate: 1.000e-03
# It: 2680, Loss: 6.119e+00, Y0: 2.539, Time: 2.81, Learning Rate: 1.000e-03
# It: 2690, Loss: 5.883e+00, Y0: 2.436, Time: 2.86, Learning Rate: 1.000e-03
# It: 2700, Loss: 6.068e+00, Y0: 2.403, Time: 3.34, Learning Rate: 1.000e-03
# It: 2710, Loss: 5.912e+00, Y0: 2.471, Time: 2.81, Learning Rate: 1.000e-03
# It: 2720, Loss: 5.891e+00, Y0: 2.462, Time: 2.80, Learning Rate: 1.000e-03
# It: 2730, Loss: 6.129e+00, Y0: 2.394, Time: 2.81, Learning Rate: 1.000e-03
# It: 2740, Loss: 5.879e+00, Y0: 2.341, Time: 3.30, Learning Rate: 1.000e-03
# It: 2750, Loss: 6.089e+00, Y0: 2.315, Time: 2.83, Learning Rate: 1.000e-03
# It: 2760, Loss: 5.936e+00, Y0: 2.366, Time: 2.86, Learning Rate: 1.000e-03
# It: 2770, Loss: 5.949e+00, Y0: 2.353, Time: 2.83, Learning Rate: 1.000e-03
# It: 2780, Loss: 5.871e+00, Y0: 2.341, Time: 3.35, Learning Rate: 1.000e-03
# It: 2790, Loss: 5.961e+00, Y0: 2.416, Time: 2.83, Learning Rate: 1.000e-03
# It: 2800, Loss: 6.003e+00, Y0: 2.373, Time: 2.88, Learning Rate: 1.000e-03
# It: 2810, Loss: 6.039e+00, Y0: 2.394, Time: 2.84, Learning Rate: 1.000e-03
# It: 2820, Loss: 5.987e+00, Y0: 2.448, Time: 3.31, Learning Rate: 1.000e-03
# It: 2830, Loss: 6.195e+00, Y0: 2.409, Time: 2.83, Learning Rate: 1.000e-03
# It: 2840, Loss: 6.032e+00, Y0: 2.500, Time: 2.83, Learning Rate: 1.000e-03
# It: 2850, Loss: 6.130e+00, Y0: 2.428, Time: 2.81, Learning Rate: 1.000e-03
# It: 2860, Loss: 5.958e+00, Y0: 2.448, Time: 3.34, Learning Rate: 1.000e-03
# It: 2870, Loss: 5.855e+00, Y0: 2.442, Time: 2.86, Learning Rate: 1.000e-03
# It: 2880, Loss: 5.996e+00, Y0: 2.476, Time: 2.79, Learning Rate: 1.000e-03
# It: 2890, Loss: 6.027e+00, Y0: 2.538, Time: 2.86, Learning Rate: 1.000e-03
# It: 2900, Loss: 5.936e+00, Y0: 2.368, Time: 3.27, Learning Rate: 1.000e-03
# It: 2910, Loss: 6.055e+00, Y0: 2.385, Time: 2.82, Learning Rate: 1.000e-03
# It: 2920, Loss: 5.855e+00, Y0: 2.297, Time: 2.83, Learning Rate: 1.000e-03
# It: 2930, Loss: 5.608e+00, Y0: 2.330, Time: 2.93, Learning Rate: 1.000e-03
# It: 2940, Loss: 5.815e+00, Y0: 2.425, Time: 3.15, Learning Rate: 1.000e-03
# It: 2950, Loss: 6.221e+00, Y0: 2.436, Time: 2.83, Learning Rate: 1.000e-03
# It: 2960, Loss: 5.683e+00, Y0: 2.301, Time: 2.86, Learning Rate: 1.000e-03
# It: 2970, Loss: 6.233e+00, Y0: 2.491, Time: 3.05, Learning Rate: 1.000e-03
# It: 2980, Loss: 5.957e+00, Y0: 2.400, Time: 3.06, Learning Rate: 1.000e-03
# It: 2990, Loss: 6.050e+00, Y0: 2.375, Time: 2.83, Learning Rate: 1.000e-03
# It: 0, Loss: 5.987e+00, Y0: 2.421, Time: 0.28, Learning Rate: 1.000e-04
# It: 10, Loss: 5.864e+00, Y0: 2.340, Time: 3.13, Learning Rate: 1.000e-04
# It: 20, Loss: 5.950e+00, Y0: 2.367, Time: 2.96, Learning Rate: 1.000e-04
# It: 30, Loss: 5.948e+00, Y0: 2.365, Time: 2.79, Learning Rate: 1.000e-04
# It: 40, Loss: 5.851e+00, Y0: 2.363, Time: 2.81, Learning Rate: 1.000e-04
# It: 50, Loss: 6.020e+00, Y0: 2.350, Time: 3.25, Learning Rate: 1.000e-04
# It: 60, Loss: 5.961e+00, Y0: 2.357, Time: 2.83, Learning Rate: 1.000e-04
# It: 70, Loss: 5.984e+00, Y0: 2.396, Time: 2.83, Learning Rate: 1.000e-04
# It: 80, Loss: 5.895e+00, Y0: 2.382, Time: 2.80, Learning Rate: 1.000e-04
# It: 90, Loss: 5.839e+00, Y0: 2.369, Time: 3.33, Learning Rate: 1.000e-04
# It: 100, Loss: 5.956e+00, Y0: 2.392, Time: 2.86, Learning Rate: 1.000e-04
# It: 110, Loss: 5.749e+00, Y0: 2.379, Time: 2.81, Learning Rate: 1.000e-04
# It: 120, Loss: 5.858e+00, Y0: 2.394, Time: 2.80, Learning Rate: 1.000e-04
# It: 130, Loss: 5.783e+00, Y0: 2.415, Time: 3.31, Learning Rate: 1.000e-04
# It: 140, Loss: 5.960e+00, Y0: 2.401, Time: 2.85, Learning Rate: 1.000e-04
# It: 150, Loss: 5.879e+00, Y0: 2.401, Time: 2.84, Learning Rate: 1.000e-04
# It: 160, Loss: 5.951e+00, Y0: 2.369, Time: 2.84, Learning Rate: 1.000e-04
# It: 170, Loss: 5.984e+00, Y0: 2.408, Time: 3.30, Learning Rate: 1.000e-04
# It: 180, Loss: 5.980e+00, Y0: 2.404, Time: 2.86, Learning Rate: 1.000e-04
# It: 190, Loss: 6.234e+00, Y0: 2.399, Time: 2.84, Learning Rate: 1.000e-04
# It: 200, Loss: 5.931e+00, Y0: 2.400, Time: 2.80, Learning Rate: 1.000e-04
# It: 210, Loss: 6.036e+00, Y0: 2.372, Time: 3.31, Learning Rate: 1.000e-04
# It: 220, Loss: 5.870e+00, Y0: 2.390, Time: 2.83, Learning Rate: 1.000e-04
# It: 230, Loss: 5.938e+00, Y0: 2.375, Time: 2.80, Learning Rate: 1.000e-04
# It: 240, Loss: 5.718e+00, Y0: 2.402, Time: 2.81, Learning Rate: 1.000e-04
# It: 250, Loss: 6.030e+00, Y0: 2.414, Time: 3.32, Learning Rate: 1.000e-04
# It: 260, Loss: 5.934e+00, Y0: 2.407, Time: 2.85, Learning Rate: 1.000e-04
# It: 270, Loss: 5.782e+00, Y0: 2.385, Time: 2.82, Learning Rate: 1.000e-04
# It: 280, Loss: 5.964e+00, Y0: 2.376, Time: 2.90, Learning Rate: 1.000e-04
# It: 290, Loss: 5.917e+00, Y0: 2.395, Time: 3.17, Learning Rate: 1.000e-04
# It: 300, Loss: 5.695e+00, Y0: 2.408, Time: 2.84, Learning Rate: 1.000e-04
# It: 310, Loss: 5.801e+00, Y0: 2.391, Time: 2.81, Learning Rate: 1.000e-04
# It: 320, Loss: 5.952e+00, Y0: 2.390, Time: 3.05, Learning Rate: 1.000e-04
# It: 330, Loss: 5.918e+00, Y0: 2.388, Time: 3.06, Learning Rate: 1.000e-04
# It: 340, Loss: 5.991e+00, Y0: 2.407, Time: 2.82, Learning Rate: 1.000e-04
# It: 350, Loss: 5.905e+00, Y0: 2.401, Time: 2.85, Learning Rate: 1.000e-04
# It: 360, Loss: 5.895e+00, Y0: 2.400, Time: 3.13, Learning Rate: 1.000e-04
# It: 370, Loss: 5.836e+00, Y0: 2.435, Time: 2.94, Learning Rate: 1.000e-04
# It: 380, Loss: 5.916e+00, Y0: 2.413, Time: 2.78, Learning Rate: 1.000e-04
# It: 390, Loss: 5.938e+00, Y0: 2.399, Time: 2.78, Learning Rate: 1.000e-04
# It: 400, Loss: 5.934e+00, Y0: 2.412, Time: 3.17, Learning Rate: 1.000e-04
# It: 410, Loss: 6.156e+00, Y0: 2.441, Time: 2.89, Learning Rate: 1.000e-04
# It: 420, Loss: 5.795e+00, Y0: 2.398, Time: 2.83, Learning Rate: 1.000e-04
# It: 430, Loss: 5.872e+00, Y0: 2.424, Time: 2.80, Learning Rate: 1.000e-04
# It: 440, Loss: 6.007e+00, Y0: 2.431, Time: 3.33, Learning Rate: 1.000e-04
# It: 450, Loss: 5.730e+00, Y0: 2.388, Time: 2.87, Learning Rate: 1.000e-04
# It: 460, Loss: 5.842e+00, Y0: 2.387, Time: 2.79, Learning Rate: 1.000e-04
# It: 470, Loss: 6.094e+00, Y0: 2.407, Time: 2.81, Learning Rate: 1.000e-04
# It: 480, Loss: 5.679e+00, Y0: 2.379, Time: 3.27, Learning Rate: 1.000e-04
# It: 490, Loss: 5.745e+00, Y0: 2.428, Time: 2.84, Learning Rate: 1.000e-04
# It: 500, Loss: 5.890e+00, Y0: 2.404, Time: 2.78, Learning Rate: 1.000e-04
# It: 510, Loss: 5.909e+00, Y0: 2.375, Time: 2.85, Learning Rate: 1.000e-04
# It: 520, Loss: 6.099e+00, Y0: 2.417, Time: 3.27, Learning Rate: 1.000e-04
# It: 530, Loss: 5.981e+00, Y0: 2.397, Time: 2.86, Learning Rate: 1.000e-04
# It: 540, Loss: 5.579e+00, Y0: 2.435, Time: 2.80, Learning Rate: 1.000e-04
# It: 550, Loss: 5.924e+00, Y0: 2.405, Time: 2.86, Learning Rate: 1.000e-04
# It: 560, Loss: 5.888e+00, Y0: 2.394, Time: 3.29, Learning Rate: 1.000e-04
# It: 570, Loss: 5.804e+00, Y0: 2.382, Time: 2.84, Learning Rate: 1.000e-04
# It: 580, Loss: 6.084e+00, Y0: 2.405, Time: 2.82, Learning Rate: 1.000e-04
# It: 590, Loss: 5.939e+00, Y0: 2.396, Time: 2.78, Learning Rate: 1.000e-04
# It: 600, Loss: 5.749e+00, Y0: 2.436, Time: 3.28, Learning Rate: 1.000e-04
# It: 610, Loss: 6.063e+00, Y0: 2.395, Time: 2.79, Learning Rate: 1.000e-04
# It: 620, Loss: 5.818e+00, Y0: 2.420, Time: 2.85, Learning Rate: 1.000e-04
# It: 630, Loss: 6.219e+00, Y0: 2.415, Time: 2.83, Learning Rate: 1.000e-04
# It: 640, Loss: 6.042e+00, Y0: 2.374, Time: 3.28, Learning Rate: 1.000e-04
# It: 650, Loss: 5.917e+00, Y0: 2.383, Time: 2.83, Learning Rate: 1.000e-04
# It: 660, Loss: 5.727e+00, Y0: 2.420, Time: 2.82, Learning Rate: 1.000e-04
# It: 670, Loss: 5.822e+00, Y0: 2.370, Time: 2.86, Learning Rate: 1.000e-04
# It: 680, Loss: 5.899e+00, Y0: 2.386, Time: 3.18, Learning Rate: 1.000e-04
# It: 690, Loss: 5.589e+00, Y0: 2.450, Time: 2.81, Learning Rate: 1.000e-04
# It: 700, Loss: 6.118e+00, Y0: 2.377, Time: 2.81, Learning Rate: 1.000e-04
# It: 710, Loss: 5.907e+00, Y0: 2.392, Time: 2.96, Learning Rate: 1.000e-04
# It: 720, Loss: 5.941e+00, Y0: 2.428, Time: 3.11, Learning Rate: 1.000e-04
# It: 730, Loss: 5.847e+00, Y0: 2.388, Time: 2.79, Learning Rate: 1.000e-04
# It: 740, Loss: 5.728e+00, Y0: 2.385, Time: 2.81, Learning Rate: 1.000e-04
# It: 750, Loss: 5.994e+00, Y0: 2.408, Time: 3.12, Learning Rate: 1.000e-04
# It: 760, Loss: 6.031e+00, Y0: 2.432, Time: 3.02, Learning Rate: 1.000e-04
# It: 770, Loss: 6.077e+00, Y0: 2.406, Time: 2.79, Learning Rate: 1.000e-04
# It: 780, Loss: 5.969e+00, Y0: 2.399, Time: 2.81, Learning Rate: 1.000e-04
# It: 790, Loss: 5.833e+00, Y0: 2.431, Time: 3.12, Learning Rate: 1.000e-04
# It: 800, Loss: 6.162e+00, Y0: 2.403, Time: 2.97, Learning Rate: 1.000e-04
# It: 810, Loss: 6.042e+00, Y0: 2.403, Time: 2.83, Learning Rate: 1.000e-04
# It: 820, Loss: 6.259e+00, Y0: 2.412, Time: 2.81, Learning Rate: 1.000e-04
# It: 830, Loss: 5.870e+00, Y0: 2.430, Time: 3.24, Learning Rate: 1.000e-04
# It: 840, Loss: 6.320e+00, Y0: 2.390, Time: 2.86, Learning Rate: 1.000e-04
# It: 850, Loss: 5.995e+00, Y0: 2.429, Time: 2.83, Learning Rate: 1.000e-04
# It: 860, Loss: 5.822e+00, Y0: 2.394, Time: 2.87, Learning Rate: 1.000e-04
# It: 870, Loss: 6.022e+00, Y0: 2.471, Time: 3.32, Learning Rate: 1.000e-04
# It: 880, Loss: 5.723e+00, Y0: 2.449, Time: 2.81, Learning Rate: 1.000e-04
# It: 890, Loss: 5.794e+00, Y0: 2.398, Time: 2.85, Learning Rate: 1.000e-04
# It: 900, Loss: 5.851e+00, Y0: 2.396, Time: 2.79, Learning Rate: 1.000e-04
# It: 910, Loss: 6.056e+00, Y0: 2.437, Time: 3.31, Learning Rate: 1.000e-04
# It: 920, Loss: 6.002e+00, Y0: 2.441, Time: 2.82, Learning Rate: 1.000e-04
# It: 930, Loss: 5.940e+00, Y0: 2.423, Time: 2.82, Learning Rate: 1.000e-04
# It: 940, Loss: 5.978e+00, Y0: 2.454, Time: 2.82, Learning Rate: 1.000e-04
# It: 950, Loss: 5.956e+00, Y0: 2.403, Time: 3.30, Learning Rate: 1.000e-04
# It: 960, Loss: 5.732e+00, Y0: 2.384, Time: 2.79, Learning Rate: 1.000e-04
# It: 970, Loss: 5.760e+00, Y0: 2.412, Time: 2.83, Learning Rate: 1.000e-04
# It: 980, Loss: 5.974e+00, Y0: 2.414, Time: 2.83, Learning Rate: 1.000e-04
# It: 990, Loss: 5.946e+00, Y0: 2.386, Time: 3.28, Learning Rate: 1.000e-04
# It: 1000, Loss: 6.035e+00, Y0: 2.400, Time: 2.80, Learning Rate: 1.000e-04
# It: 1010, Loss: 5.900e+00, Y0: 2.366, Time: 2.83, Learning Rate: 1.000e-04
# It: 1020, Loss: 6.172e+00, Y0: 2.405, Time: 2.81, Learning Rate: 1.000e-04
# It: 1030, Loss: 6.003e+00, Y0: 2.445, Time: 3.28, Learning Rate: 1.000e-04
# It: 1040, Loss: 5.990e+00, Y0: 2.389, Time: 2.83, Learning Rate: 1.000e-04
# It: 1050, Loss: 6.037e+00, Y0: 2.373, Time: 2.81, Learning Rate: 1.000e-04
# It: 1060, Loss: 5.872e+00, Y0: 2.421, Time: 2.81, Learning Rate: 1.000e-04
# It: 1070, Loss: 5.903e+00, Y0: 2.391, Time: 3.29, Learning Rate: 1.000e-04
# It: 1080, Loss: 5.908e+00, Y0: 2.402, Time: 2.79, Learning Rate: 1.000e-04
# It: 1090, Loss: 5.999e+00, Y0: 2.373, Time: 2.83, Learning Rate: 1.000e-04
# It: 1100, Loss: 5.780e+00, Y0: 2.371, Time: 2.95, Learning Rate: 1.000e-04
# It: 1110, Loss: 5.902e+00, Y0: 2.375, Time: 3.15, Learning Rate: 1.000e-04
# It: 1120, Loss: 6.000e+00, Y0: 2.400, Time: 2.80, Learning Rate: 1.000e-04
# It: 1130, Loss: 6.143e+00, Y0: 2.404, Time: 2.79, Learning Rate: 1.000e-04
# It: 1140, Loss: 6.128e+00, Y0: 2.406, Time: 3.06, Learning Rate: 1.000e-04
# It: 1150, Loss: 5.879e+00, Y0: 2.394, Time: 3.07, Learning Rate: 1.000e-04
# It: 1160, Loss: 6.107e+00, Y0: 2.386, Time: 2.83, Learning Rate: 1.000e-04
# It: 1170, Loss: 6.022e+00, Y0: 2.423, Time: 2.83, Learning Rate: 1.000e-04
# It: 1180, Loss: 5.882e+00, Y0: 2.380, Time: 3.13, Learning Rate: 1.000e-04
# It: 1190, Loss: 5.878e+00, Y0: 2.396, Time: 2.98, Learning Rate: 1.000e-04
# It: 1200, Loss: 6.162e+00, Y0: 2.364, Time: 2.85, Learning Rate: 1.000e-04
# It: 1210, Loss: 5.758e+00, Y0: 2.427, Time: 2.82, Learning Rate: 1.000e-04
# It: 1220, Loss: 5.687e+00, Y0: 2.424, Time: 3.24, Learning Rate: 1.000e-04
# It: 1230, Loss: 5.739e+00, Y0: 2.409, Time: 2.82, Learning Rate: 1.000e-04
# It: 1240, Loss: 5.748e+00, Y0: 2.368, Time: 2.80, Learning Rate: 1.000e-04
# It: 1250, Loss: 5.963e+00, Y0: 2.404, Time: 2.87, Learning Rate: 1.000e-04
# It: 1260, Loss: 5.918e+00, Y0: 2.396, Time: 3.28, Learning Rate: 1.000e-04
# It: 1270, Loss: 5.989e+00, Y0: 2.398, Time: 2.80, Learning Rate: 1.000e-04
# It: 1280, Loss: 6.140e+00, Y0: 2.437, Time: 2.83, Learning Rate: 1.000e-04
# It: 1290, Loss: 6.030e+00, Y0: 2.376, Time: 2.85, Learning Rate: 1.000e-04
# It: 1300, Loss: 5.880e+00, Y0: 2.411, Time: 3.32, Learning Rate: 1.000e-04
# It: 1310, Loss: 5.880e+00, Y0: 2.397, Time: 2.81, Learning Rate: 1.000e-04
# It: 1320, Loss: 5.717e+00, Y0: 2.362, Time: 2.82, Learning Rate: 1.000e-04
# It: 1330, Loss: 5.858e+00, Y0: 2.407, Time: 2.84, Learning Rate: 1.000e-04
# It: 1340, Loss: 5.812e+00, Y0: 2.409, Time: 3.35, Learning Rate: 1.000e-04
# It: 1350, Loss: 5.792e+00, Y0: 2.402, Time: 2.82, Learning Rate: 1.000e-04
# It: 1360, Loss: 5.725e+00, Y0: 2.372, Time: 2.83, Learning Rate: 1.000e-04
# It: 1370, Loss: 5.985e+00, Y0: 2.410, Time: 2.80, Learning Rate: 1.000e-04
# It: 1380, Loss: 5.783e+00, Y0: 2.369, Time: 3.29, Learning Rate: 1.000e-04
# It: 1390, Loss: 5.866e+00, Y0: 2.405, Time: 2.83, Learning Rate: 1.000e-04
# It: 1400, Loss: 5.923e+00, Y0: 2.434, Time: 2.83, Learning Rate: 1.000e-04
# It: 1410, Loss: 5.945e+00, Y0: 2.436, Time: 2.81, Learning Rate: 1.000e-04
# It: 1420, Loss: 5.849e+00, Y0: 2.375, Time: 3.27, Learning Rate: 1.000e-04
# It: 1430, Loss: 6.053e+00, Y0: 2.378, Time: 2.83, Learning Rate: 1.000e-04
# It: 1440, Loss: 5.950e+00, Y0: 2.396, Time: 2.84, Learning Rate: 1.000e-04
# It: 1450, Loss: 5.954e+00, Y0: 2.401, Time: 2.86, Learning Rate: 1.000e-04
# It: 1460, Loss: 5.717e+00, Y0: 2.377, Time: 3.17, Learning Rate: 1.000e-04
# It: 1470, Loss: 5.826e+00, Y0: 2.407, Time: 2.86, Learning Rate: 1.000e-04
# It: 1480, Loss: 5.955e+00, Y0: 2.422, Time: 2.81, Learning Rate: 1.000e-04
# It: 1490, Loss: 5.667e+00, Y0: 2.408, Time: 2.91, Learning Rate: 1.000e-04
# It: 1500, Loss: 5.849e+00, Y0: 2.396, Time: 3.17, Learning Rate: 1.000e-04
# It: 1510, Loss: 5.985e+00, Y0: 2.396, Time: 2.83, Learning Rate: 1.000e-04
# It: 1520, Loss: 5.909e+00, Y0: 2.405, Time: 2.84, Learning Rate: 1.000e-04
# It: 1530, Loss: 5.801e+00, Y0: 2.395, Time: 3.13, Learning Rate: 1.000e-04
# It: 1540, Loss: 6.121e+00, Y0: 2.426, Time: 3.06, Learning Rate: 1.000e-04
# It: 1550, Loss: 5.745e+00, Y0: 2.390, Time: 2.86, Learning Rate: 1.000e-04
# It: 1560, Loss: 5.836e+00, Y0: 2.367, Time: 2.78, Learning Rate: 1.000e-04
# It: 1570, Loss: 5.918e+00, Y0: 2.394, Time: 3.19, Learning Rate: 1.000e-04
# It: 1580, Loss: 5.857e+00, Y0: 2.398, Time: 2.91, Learning Rate: 1.000e-04
# It: 1590, Loss: 6.224e+00, Y0: 2.382, Time: 2.80, Learning Rate: 1.000e-04
# It: 1600, Loss: 5.927e+00, Y0: 2.344, Time: 2.83, Learning Rate: 1.000e-04
# It: 1610, Loss: 5.749e+00, Y0: 2.387, Time: 3.28, Learning Rate: 1.000e-04
# It: 1620, Loss: 6.146e+00, Y0: 2.408, Time: 2.82, Learning Rate: 1.000e-04
# It: 1630, Loss: 5.833e+00, Y0: 2.439, Time: 2.85, Learning Rate: 1.000e-04
# It: 1640, Loss: 5.812e+00, Y0: 2.389, Time: 2.85, Learning Rate: 1.000e-04
# It: 1650, Loss: 5.634e+00, Y0: 2.408, Time: 3.28, Learning Rate: 1.000e-04
# It: 1660, Loss: 5.998e+00, Y0: 2.364, Time: 2.84, Learning Rate: 1.000e-04
# It: 1670, Loss: 5.952e+00, Y0: 2.398, Time: 2.82, Learning Rate: 1.000e-04
# It: 1680, Loss: 6.040e+00, Y0: 2.402, Time: 2.83, Learning Rate: 1.000e-04
# It: 1690, Loss: 5.995e+00, Y0: 2.383, Time: 3.29, Learning Rate: 1.000e-04
# It: 1700, Loss: 5.827e+00, Y0: 2.387, Time: 2.83, Learning Rate: 1.000e-04
# It: 1710, Loss: 5.606e+00, Y0: 2.402, Time: 2.82, Learning Rate: 1.000e-04
# It: 1720, Loss: 5.763e+00, Y0: 2.435, Time: 2.82, Learning Rate: 1.000e-04
# It: 1730, Loss: 5.860e+00, Y0: 2.424, Time: 3.36, Learning Rate: 1.000e-04
# It: 1740, Loss: 6.032e+00, Y0: 2.407, Time: 2.86, Learning Rate: 1.000e-04
# It: 1750, Loss: 5.852e+00, Y0: 2.402, Time: 2.79, Learning Rate: 1.000e-04
# It: 1760, Loss: 5.847e+00, Y0: 2.379, Time: 2.81, Learning Rate: 1.000e-04
# It: 1770, Loss: 5.747e+00, Y0: 2.451, Time: 3.31, Learning Rate: 1.000e-04
# It: 1780, Loss: 5.914e+00, Y0: 2.394, Time: 2.83, Learning Rate: 1.000e-04
# It: 1790, Loss: 5.714e+00, Y0: 2.390, Time: 2.82, Learning Rate: 1.000e-04
# It: 1800, Loss: 5.910e+00, Y0: 2.414, Time: 2.84, Learning Rate: 1.000e-04
# It: 1810, Loss: 5.974e+00, Y0: 2.454, Time: 3.24, Learning Rate: 1.000e-04
# It: 1820, Loss: 5.912e+00, Y0: 2.424, Time: 2.80, Learning Rate: 1.000e-04
# It: 1830, Loss: 6.158e+00, Y0: 2.430, Time: 2.80, Learning Rate: 1.000e-04
# It: 1840, Loss: 6.044e+00, Y0: 2.433, Time: 2.95, Learning Rate: 1.000e-04
# It: 1850, Loss: 5.956e+00, Y0: 2.368, Time: 3.14, Learning Rate: 1.000e-04
# It: 1860, Loss: 5.811e+00, Y0: 2.355, Time: 2.82, Learning Rate: 1.000e-04
# It: 1870, Loss: 5.719e+00, Y0: 2.408, Time: 2.81, Learning Rate: 1.000e-04
# It: 1880, Loss: 5.910e+00, Y0: 2.441, Time: 3.03, Learning Rate: 1.000e-04
# It: 1890, Loss: 5.711e+00, Y0: 2.428, Time: 3.09, Learning Rate: 1.000e-04
# It: 1900, Loss: 5.971e+00, Y0: 2.382, Time: 2.83, Learning Rate: 1.000e-04
# It: 1910, Loss: 5.824e+00, Y0: 2.425, Time: 2.82, Learning Rate: 1.000e-04
# It: 1920, Loss: 5.740e+00, Y0: 2.438, Time: 3.09, Learning Rate: 1.000e-04
# It: 1930, Loss: 5.738e+00, Y0: 2.397, Time: 3.04, Learning Rate: 1.000e-04
# It: 1940, Loss: 5.792e+00, Y0: 2.441, Time: 2.85, Learning Rate: 1.000e-04
# It: 1950, Loss: 5.857e+00, Y0: 2.414, Time: 2.84, Learning Rate: 1.000e-04
# It: 1960, Loss: 5.820e+00, Y0: 2.405, Time: 3.22, Learning Rate: 1.000e-04
# It: 1970, Loss: 6.083e+00, Y0: 2.473, Time: 2.85, Learning Rate: 1.000e-04
# It: 1980, Loss: 5.972e+00, Y0: 2.407, Time: 2.82, Learning Rate: 1.000e-04
# It: 1990, Loss: 5.928e+00, Y0: 2.417, Time: 2.82, Learning Rate: 1.000e-04
# It: 2000, Loss: 5.812e+00, Y0: 2.412, Time: 3.26, Learning Rate: 1.000e-04
# It: 2010, Loss: 6.018e+00, Y0: 2.406, Time: 2.84, Learning Rate: 1.000e-04
# It: 2020, Loss: 6.004e+00, Y0: 2.403, Time: 2.81, Learning Rate: 1.000e-04
# It: 2030, Loss: 5.760e+00, Y0: 2.428, Time: 2.81, Learning Rate: 1.000e-04
# It: 2040, Loss: 5.891e+00, Y0: 2.370, Time: 3.27, Learning Rate: 1.000e-04
# It: 2050, Loss: 5.811e+00, Y0: 2.381, Time: 2.81, Learning Rate: 1.000e-04
# It: 2060, Loss: 5.886e+00, Y0: 2.391, Time: 2.80, Learning Rate: 1.000e-04
# It: 2070, Loss: 6.278e+00, Y0: 2.389, Time: 2.79, Learning Rate: 1.000e-04
# It: 2080, Loss: 6.076e+00, Y0: 2.418, Time: 3.28, Learning Rate: 1.000e-04
# It: 2090, Loss: 5.983e+00, Y0: 2.371, Time: 2.81, Learning Rate: 1.000e-04
# It: 2100, Loss: 6.055e+00, Y0: 2.392, Time: 2.84, Learning Rate: 1.000e-04
# It: 2110, Loss: 5.898e+00, Y0: 2.383, Time: 2.86, Learning Rate: 1.000e-04
# It: 2120, Loss: 5.599e+00, Y0: 2.407, Time: 3.34, Learning Rate: 1.000e-04
# It: 2130, Loss: 5.801e+00, Y0: 2.375, Time: 2.83, Learning Rate: 1.000e-04
# It: 2140, Loss: 5.944e+00, Y0: 2.431, Time: 2.83, Learning Rate: 1.000e-04
# It: 2150, Loss: 6.021e+00, Y0: 2.379, Time: 2.82, Learning Rate: 1.000e-04
# It: 2160, Loss: 6.021e+00, Y0: 2.416, Time: 3.31, Learning Rate: 1.000e-04
# It: 2170, Loss: 5.806e+00, Y0: 2.403, Time: 2.85, Learning Rate: 1.000e-04
# It: 2180, Loss: 5.752e+00, Y0: 2.378, Time: 2.82, Learning Rate: 1.000e-04
# It: 2190, Loss: 5.849e+00, Y0: 2.465, Time: 2.84, Learning Rate: 1.000e-04
# It: 2200, Loss: 5.805e+00, Y0: 2.404, Time: 3.25, Learning Rate: 1.000e-04
# It: 2210, Loss: 5.772e+00, Y0: 2.430, Time: 2.83, Learning Rate: 1.000e-04
# It: 2220, Loss: 5.890e+00, Y0: 2.442, Time: 2.83, Learning Rate: 1.000e-04
# It: 2230, Loss: 5.844e+00, Y0: 2.453, Time: 2.92, Learning Rate: 1.000e-04
# It: 2240, Loss: 6.060e+00, Y0: 2.447, Time: 3.13, Learning Rate: 1.000e-04
# It: 2250, Loss: 5.868e+00, Y0: 2.354, Time: 2.79, Learning Rate: 1.000e-04
# It: 2260, Loss: 5.693e+00, Y0: 2.363, Time: 2.81, Learning Rate: 1.000e-04
# It: 2270, Loss: 5.811e+00, Y0: 2.361, Time: 3.00, Learning Rate: 1.000e-04
# It: 2280, Loss: 5.803e+00, Y0: 2.368, Time: 3.11, Learning Rate: 1.000e-04
# It: 2290, Loss: 5.880e+00, Y0: 2.433, Time: 2.85, Learning Rate: 1.000e-04
# It: 2300, Loss: 5.975e+00, Y0: 2.455, Time: 2.80, Learning Rate: 1.000e-04
# It: 2310, Loss: 5.592e+00, Y0: 2.388, Time: 3.11, Learning Rate: 1.000e-04
# It: 2320, Loss: 5.886e+00, Y0: 2.395, Time: 3.01, Learning Rate: 1.000e-04
# It: 2330, Loss: 5.789e+00, Y0: 2.427, Time: 2.84, Learning Rate: 1.000e-04
# It: 2340, Loss: 6.037e+00, Y0: 2.467, Time: 2.82, Learning Rate: 1.000e-04
# It: 2350, Loss: 5.774e+00, Y0: 2.385, Time: 3.21, Learning Rate: 1.000e-04
# It: 2360, Loss: 5.662e+00, Y0: 2.383, Time: 2.83, Learning Rate: 1.000e-04
# It: 2370, Loss: 6.124e+00, Y0: 2.428, Time: 2.82, Learning Rate: 1.000e-04
# It: 2380, Loss: 5.899e+00, Y0: 2.392, Time: 2.83, Learning Rate: 1.000e-04
# It: 2390, Loss: 5.848e+00, Y0: 2.409, Time: 3.32, Learning Rate: 1.000e-04
# It: 2400, Loss: 5.832e+00, Y0: 2.418, Time: 2.83, Learning Rate: 1.000e-04
# It: 2410, Loss: 5.772e+00, Y0: 2.437, Time: 2.79, Learning Rate: 1.000e-04
# It: 2420, Loss: 5.855e+00, Y0: 2.440, Time: 2.83, Learning Rate: 1.000e-04
# It: 2430, Loss: 5.633e+00, Y0: 2.408, Time: 3.34, Learning Rate: 1.000e-04
# It: 2440, Loss: 5.776e+00, Y0: 2.429, Time: 2.82, Learning Rate: 1.000e-04
# It: 2450, Loss: 5.879e+00, Y0: 2.380, Time: 2.79, Learning Rate: 1.000e-04
# It: 2460, Loss: 6.170e+00, Y0: 2.411, Time: 2.81, Learning Rate: 1.000e-04
# It: 2470, Loss: 5.868e+00, Y0: 2.410, Time: 3.29, Learning Rate: 1.000e-04
# It: 2480, Loss: 5.593e+00, Y0: 2.375, Time: 2.81, Learning Rate: 1.000e-04
# It: 2490, Loss: 5.850e+00, Y0: 2.433, Time: 2.81, Learning Rate: 1.000e-04
# It: 2500, Loss: 5.802e+00, Y0: 2.385, Time: 2.80, Learning Rate: 1.000e-04
# It: 2510, Loss: 5.668e+00, Y0: 2.378, Time: 3.30, Learning Rate: 1.000e-04
# It: 2520, Loss: 5.527e+00, Y0: 2.378, Time: 2.84, Learning Rate: 1.000e-04
# It: 2530, Loss: 6.012e+00, Y0: 2.396, Time: 2.85, Learning Rate: 1.000e-04
# It: 2540, Loss: 5.996e+00, Y0: 2.446, Time: 2.83, Learning Rate: 1.000e-04
# It: 2550, Loss: 5.957e+00, Y0: 2.425, Time: 3.37, Learning Rate: 1.000e-04
# It: 2560, Loss: 5.787e+00, Y0: 2.423, Time: 2.84, Learning Rate: 1.000e-04
# It: 2570, Loss: 5.884e+00, Y0: 2.460, Time: 2.81, Learning Rate: 1.000e-04
# It: 2580, Loss: 5.758e+00, Y0: 2.415, Time: 2.85, Learning Rate: 1.000e-04
# It: 2590, Loss: 5.595e+00, Y0: 2.397, Time: 3.23, Learning Rate: 1.000e-04
# It: 2600, Loss: 5.800e+00, Y0: 2.400, Time: 2.82, Learning Rate: 1.000e-04
# It: 2610, Loss: 5.992e+00, Y0: 2.412, Time: 2.81, Learning Rate: 1.000e-04
# It: 2620, Loss: 5.728e+00, Y0: 2.390, Time: 2.93, Learning Rate: 1.000e-04
# It: 2630, Loss: 5.773e+00, Y0: 2.396, Time: 3.17, Learning Rate: 1.000e-04
# It: 2640, Loss: 5.602e+00, Y0: 2.377, Time: 2.85, Learning Rate: 1.000e-04
# It: 2650, Loss: 5.647e+00, Y0: 2.372, Time: 2.81, Learning Rate: 1.000e-04
# It: 2660, Loss: 5.745e+00, Y0: 2.409, Time: 3.00, Learning Rate: 1.000e-04
# It: 2670, Loss: 5.927e+00, Y0: 2.384, Time: 3.08, Learning Rate: 1.000e-04
# It: 2680, Loss: 5.936e+00, Y0: 2.405, Time: 2.81, Learning Rate: 1.000e-04
# It: 2690, Loss: 5.665e+00, Y0: 2.369, Time: 2.84, Learning Rate: 1.000e-04
# It: 2700, Loss: 5.821e+00, Y0: 2.391, Time: 3.09, Learning Rate: 1.000e-04
# It: 2710, Loss: 6.001e+00, Y0: 2.416, Time: 2.96, Learning Rate: 1.000e-04
# It: 2720, Loss: 5.862e+00, Y0: 2.414, Time: 2.78, Learning Rate: 1.000e-04
# It: 2730, Loss: 6.298e+00, Y0: 2.448, Time: 2.83, Learning Rate: 1.000e-04
# It: 2740, Loss: 5.702e+00, Y0: 2.405, Time: 3.18, Learning Rate: 1.000e-04
# It: 2750, Loss: 5.955e+00, Y0: 2.469, Time: 2.89, Learning Rate: 1.000e-04
# It: 2760, Loss: 6.287e+00, Y0: 2.430, Time: 2.83, Learning Rate: 1.000e-04
# It: 2770, Loss: 6.003e+00, Y0: 2.398, Time: 2.83, Learning Rate: 1.000e-04
# It: 2780, Loss: 5.864e+00, Y0: 2.427, Time: 3.34, Learning Rate: 1.000e-04
# It: 2790, Loss: 5.825e+00, Y0: 2.431, Time: 2.79, Learning Rate: 1.000e-04
# It: 2800, Loss: 5.758e+00, Y0: 2.425, Time: 2.80, Learning Rate: 1.000e-04
# It: 2810, Loss: 6.085e+00, Y0: 2.385, Time: 2.85, Learning Rate: 1.000e-04
# It: 2820, Loss: 6.159e+00, Y0: 2.395, Time: 3.34, Learning Rate: 1.000e-04
# It: 2830, Loss: 5.840e+00, Y0: 2.403, Time: 2.81, Learning Rate: 1.000e-04
# It: 2840, Loss: 5.994e+00, Y0: 2.382, Time: 2.82, Learning Rate: 1.000e-04
# It: 2850, Loss: 5.773e+00, Y0: 2.395, Time: 2.79, Learning Rate: 1.000e-04
# It: 2860, Loss: 5.851e+00, Y0: 2.416, Time: 3.31, Learning Rate: 1.000e-04
# It: 2870, Loss: 5.965e+00, Y0: 2.371, Time: 2.81, Learning Rate: 1.000e-04
# It: 2880, Loss: 6.047e+00, Y0: 2.354, Time: 2.81, Learning Rate: 1.000e-04
# It: 2890, Loss: 5.975e+00, Y0: 2.398, Time: 2.80, Learning Rate: 1.000e-04
# It: 2900, Loss: 5.950e+00, Y0: 2.427, Time: 3.29, Learning Rate: 1.000e-04
# ...
# It: 880, Loss: 5.729e+00, Y0: 2.437, Time: 2.84, Learning Rate: 1.000e-06
# It: 890, Loss: 5.860e+00, Y0: 2.443, Time: 2.80, Learning Rate: 1.000e-06
# It: 900, Loss: 5.592e+00, Y0: 2.445, Time: 3.17, Learning Rate: 1.000e-06
# It: 910, Loss: 5.855e+00, Y0: 2.441, Time: 2.82, Learning Rate: 1.000e-06
# It: 920, Loss: 5.944e+00, Y0: 2.439, Time: 2.76, Learning Rate: 1.000e-06
# It: 930, Loss: 5.939e+00, Y0: 2.439, Time: 2.92, Learning Rate: 1.000e-06
# It: 940, Loss: 5.857e+00, Y0: 2.438, Time: 3.14, Learning Rate: 1.000e-06
# It: 950, Loss: 5.707e+00, Y0: 2.439, Time: 2.80, Learning Rate: 1.000e-06
# It: 960, Loss: 5.557e+00, Y0: 2.438, Time: 2.83, Learning Rate: 1.000e-06
# It: 970, Loss: 5.535e+00, Y0: 2.434, Time: 2.98, Learning Rate: 1.000e-06
# It: 980, Loss: 5.889e+00, Y0: 2.431, Time: 3.08, Learning Rate: 1.000e-06
# It: 990, Loss: 5.662e+00, Y0: 2.431, Time: 2.82, Learning Rate: 1.000e-06
# It: 1000, Loss: 5.708e+00, Y0: 2.431, Time: 2.82, Learning Rate: 1.000e-06
# It: 1010, Loss: 5.767e+00, Y0: 2.437, Time: 3.11, Learning Rate: 1.000e-06
# It: 1020, Loss: 5.732e+00, Y0: 2.440, Time: 2.95, Learning Rate: 1.000e-06
# It: 1030, Loss: 5.558e+00, Y0: 2.437, Time: 2.81, Learning Rate: 1.000e-06
# It: 1040, Loss: 5.582e+00, Y0: 2.432, Time: 2.79, Learning Rate: 1.000e-06
# It: 1050, Loss: 5.763e+00, Y0: 2.436, Time: 3.21, Learning Rate: 1.000e-06
# It: 1060, Loss: 5.735e+00, Y0: 2.439, Time: 2.85, Learning Rate: 1.000e-06
# It: 1070, Loss: 5.933e+00, Y0: 2.440, Time: 2.81, Learning Rate: 1.000e-06
# It: 1080, Loss: 5.560e+00, Y0: 2.436, Time: 2.80, Learning Rate: 1.000e-06
# It: 1090, Loss: 5.660e+00, Y0: 2.427, Time: 3.28, Learning Rate: 1.000e-06
# It: 1100, Loss: 5.738e+00, Y0: 2.429, Time: 2.83, Learning Rate: 1.000e-06
# It: 1110, Loss: 5.924e+00, Y0: 2.433, Time: 2.83, Learning Rate: 1.000e-06
# It: 1120, Loss: 5.800e+00, Y0: 2.438, Time: 2.79, Learning Rate: 1.000e-06
# It: 1130, Loss: 5.715e+00, Y0: 2.437, Time: 3.28, Learning Rate: 1.000e-06
# It: 1140, Loss: 6.082e+00, Y0: 2.440, Time: 2.81, Learning Rate: 1.000e-06
# It: 1150, Loss: 5.702e+00, Y0: 2.439, Time: 2.81, Learning Rate: 1.000e-06
# It: 1160, Loss: 5.645e+00, Y0: 2.432, Time: 2.86, Learning Rate: 1.000e-06
# It: 1170, Loss: 5.851e+00, Y0: 2.430, Time: 3.24, Learning Rate: 1.000e-06
# It: 1180, Loss: 5.797e+00, Y0: 2.433, Time: 2.81, Learning Rate: 1.000e-06
# It: 1190, Loss: 5.590e+00, Y0: 2.436, Time: 2.78, Learning Rate: 1.000e-06
# It: 1200, Loss: 5.776e+00, Y0: 2.437, Time: 2.80, Learning Rate: 1.000e-06
# It: 1210, Loss: 5.975e+00, Y0: 2.441, Time: 3.30, Learning Rate: 1.000e-06
# It: 1220, Loss: 5.634e+00, Y0: 2.439, Time: 2.80, Learning Rate: 1.000e-06
# It: 1230, Loss: 5.888e+00, Y0: 2.438, Time: 2.85, Learning Rate: 1.000e-06
# It: 1240, Loss: 5.834e+00, Y0: 2.439, Time: 2.83, Learning Rate: 1.000e-06
# It: 1250, Loss: 5.758e+00, Y0: 2.440, Time: 3.29, Learning Rate: 1.000e-06
# It: 1260, Loss: 5.708e+00, Y0: 2.439, Time: 2.83, Learning Rate: 1.000e-06
# It: 1270, Loss: 5.703e+00, Y0: 2.435, Time: 2.83, Learning Rate: 1.000e-06
# It: 1280, Loss: 5.685e+00, Y0: 2.427, Time: 2.87, Learning Rate: 1.000e-06
# It: 1290, Loss: 5.792e+00, Y0: 2.426, Time: 3.21, Learning Rate: 1.000e-06
# It: 1300, Loss: 5.634e+00, Y0: 2.433, Time: 2.86, Learning Rate: 1.000e-06
# It: 1310, Loss: 5.511e+00, Y0: 2.435, Time: 2.81, Learning Rate: 1.000e-06
# It: 1320, Loss: 5.755e+00, Y0: 2.435, Time: 3.01, Learning Rate: 1.000e-06
# It: 1330, Loss: 5.460e+00, Y0: 2.438, Time: 3.11, Learning Rate: 1.000e-06
# It: 1340, Loss: 5.710e+00, Y0: 2.434, Time: 2.82, Learning Rate: 1.000e-06
# It: 1350, Loss: 5.930e+00, Y0: 2.431, Time: 2.80, Learning Rate: 1.000e-06
# It: 1360, Loss: 5.544e+00, Y0: 2.428, Time: 3.03, Learning Rate: 1.000e-06
# It: 1370, Loss: 5.801e+00, Y0: 2.433, Time: 3.05, Learning Rate: 1.000e-06
# It: 1380, Loss: 5.843e+00, Y0: 2.432, Time: 2.81, Learning Rate: 1.000e-06
# It: 1390, Loss: 5.729e+00, Y0: 2.434, Time: 2.85, Learning Rate: 1.000e-06
# It: 1400, Loss: 5.604e+00, Y0: 2.436, Time: 3.19, Learning Rate: 1.000e-06
# It: 1410, Loss: 5.740e+00, Y0: 2.440, Time: 2.91, Learning Rate: 1.000e-06
# It: 1420, Loss: 5.893e+00, Y0: 2.443, Time: 2.83, Learning Rate: 1.000e-06
# It: 1430, Loss: 5.773e+00, Y0: 2.438, Time: 2.82, Learning Rate: 1.000e-06
# It: 1440, Loss: 5.872e+00, Y0: 2.433, Time: 3.26, Learning Rate: 1.000e-06
# It: 1450, Loss: 5.715e+00, Y0: 2.434, Time: 2.84, Learning Rate: 1.000e-06
# It: 1460, Loss: 5.698e+00, Y0: 2.435, Time: 2.85, Learning Rate: 1.000e-06
# It: 1470, Loss: 5.816e+00, Y0: 2.438, Time: 2.84, Learning Rate: 1.000e-06
# It: 1480, Loss: 5.628e+00, Y0: 2.433, Time: 3.26, Learning Rate: 1.000e-06
# It: 1490, Loss: 5.477e+00, Y0: 2.436, Time: 2.83, Learning Rate: 1.000e-06
# It: 1500, Loss: 6.022e+00, Y0: 2.438, Time: 2.84, Learning Rate: 1.000e-06
# It: 1510, Loss: 5.761e+00, Y0: 2.440, Time: 2.82, Learning Rate: 1.000e-06
# It: 1520, Loss: 5.885e+00, Y0: 2.443, Time: 3.33, Learning Rate: 1.000e-06
# It: 1530, Loss: 5.600e+00, Y0: 2.440, Time: 2.82, Learning Rate: 1.000e-06
# It: 1540, Loss: 5.905e+00, Y0: 2.438, Time: 2.81, Learning Rate: 1.000e-06
# It: 1550, Loss: 5.671e+00, Y0: 2.438, Time: 2.90, Learning Rate: 1.000e-06
# It: 1560, Loss: 5.639e+00, Y0: 2.431, Time: 3.32, Learning Rate: 1.000e-06
# It: 1570, Loss: 5.734e+00, Y0: 2.428, Time: 2.85, Learning Rate: 1.000e-06
# It: 1580, Loss: 6.107e+00, Y0: 2.432, Time: 2.84, Learning Rate: 1.000e-06
# It: 1590, Loss: 5.681e+00, Y0: 2.439, Time: 2.85, Learning Rate: 1.000e-06
# It: 1600, Loss: 5.784e+00, Y0: 2.438, Time: 3.27, Learning Rate: 1.000e-06
# It: 1610, Loss: 5.761e+00, Y0: 2.432, Time: 2.89, Learning Rate: 1.000e-06
# It: 1620, Loss: 5.635e+00, Y0: 2.430, Time: 2.81, Learning Rate: 1.000e-06
# It: 1630, Loss: 5.734e+00, Y0: 2.429, Time: 2.93, Learning Rate: 1.000e-06
# It: 1640, Loss: 5.576e+00, Y0: 2.428, Time: 3.11, Learning Rate: 1.000e-06
# It: 1650, Loss: 5.901e+00, Y0: 2.428, Time: 2.85, Learning Rate: 1.000e-06
# It: 1660, Loss: 5.716e+00, Y0: 2.433, Time: 2.83, Learning Rate: 1.000e-06
# It: 1670, Loss: 5.744e+00, Y0: 2.433, Time: 3.08, Learning Rate: 1.000e-06
# It: 1680, Loss: 5.584e+00, Y0: 2.432, Time: 3.01, Learning Rate: 1.000e-06
# It: 1690, Loss: 5.690e+00, Y0: 2.428, Time: 2.82, Learning Rate: 1.000e-06
# It: 1700, Loss: 5.923e+00, Y0: 2.429, Time: 2.85, Learning Rate: 1.000e-06
# It: 1710, Loss: 6.023e+00, Y0: 2.428, Time: 3.17, Learning Rate: 1.000e-06
# It: 1720, Loss: 5.753e+00, Y0: 2.433, Time: 2.90, Learning Rate: 1.000e-06
# It: 1730, Loss: 5.746e+00, Y0: 2.431, Time: 2.83, Learning Rate: 1.000e-06
# It: 1740, Loss: 5.720e+00, Y0: 2.430, Time: 2.80, Learning Rate: 1.000e-06
# It: 1750, Loss: 5.654e+00, Y0: 2.430, Time: 3.35, Learning Rate: 1.000e-06
# It: 1760, Loss: 5.950e+00, Y0: 2.431, Time: 2.81, Learning Rate: 1.000e-06
# It: 1770, Loss: 5.794e+00, Y0: 2.434, Time: 2.82, Learning Rate: 1.000e-06
# It: 1780, Loss: 5.685e+00, Y0: 2.435, Time: 2.82, Learning Rate: 1.000e-06
# It: 1790, Loss: 5.836e+00, Y0: 2.438, Time: 3.28, Learning Rate: 1.000e-06
# It: 1800, Loss: 6.070e+00, Y0: 2.438, Time: 2.82, Learning Rate: 1.000e-06
# It: 1810, Loss: 5.602e+00, Y0: 2.443, Time: 2.81, Learning Rate: 1.000e-06
# It: 1820, Loss: 5.920e+00, Y0: 2.438, Time: 2.81, Learning Rate: 1.000e-06
# It: 1830, Loss: 5.678e+00, Y0: 2.435, Time: 3.29, Learning Rate: 1.000e-06
# It: 1840, Loss: 5.600e+00, Y0: 2.430, Time: 2.79, Learning Rate: 1.000e-06
# It: 1850, Loss: 5.965e+00, Y0: 2.430, Time: 2.85, Learning Rate: 1.000e-06
# It: 1860, Loss: 5.712e+00, Y0: 2.429, Time: 2.85, Learning Rate: 1.000e-06
# It: 1870, Loss: 5.884e+00, Y0: 2.431, Time: 3.24, Learning Rate: 1.000e-06
# It: 1880, Loss: 5.678e+00, Y0: 2.437, Time: 2.80, Learning Rate: 1.000e-06
# It: 1890, Loss: 5.928e+00, Y0: 2.439, Time: 2.80, Learning Rate: 1.000e-06
# It: 1900, Loss: 5.956e+00, Y0: 2.442, Time: 2.85, Learning Rate: 1.000e-06
# It: 1910, Loss: 5.693e+00, Y0: 2.438, Time: 3.29, Learning Rate: 1.000e-06
# It: 1920, Loss: 5.738e+00, Y0: 2.434, Time: 2.80, Learning Rate: 1.000e-06
# It: 1930, Loss: 5.753e+00, Y0: 2.430, Time: 2.80, Learning Rate: 1.000e-06
# It: 1940, Loss: 5.864e+00, Y0: 2.432, Time: 2.80, Learning Rate: 1.000e-06
# It: 1950, Loss: 6.006e+00, Y0: 2.432, Time: 3.27, Learning Rate: 1.000e-06
# It: 1960, Loss: 5.723e+00, Y0: 2.431, Time: 2.81, Learning Rate: 1.000e-06
# It: 1970, Loss: 5.702e+00, Y0: 2.426, Time: 2.77, Learning Rate: 1.000e-06
# It: 1980, Loss: 5.674e+00, Y0: 2.428, Time: 2.89, Learning Rate: 1.000e-06
# It: 1990, Loss: 5.548e+00, Y0: 2.428, Time: 3.18, Learning Rate: 1.000e-06
# It: 2000, Loss: 5.734e+00, Y0: 2.426, Time: 2.81, Learning Rate: 1.000e-06
# It: 2010, Loss: 5.854e+00, Y0: 2.430, Time: 2.83, Learning Rate: 1.000e-06
# It: 2020, Loss: 5.823e+00, Y0: 2.434, Time: 3.01, Learning Rate: 1.000e-06
# It: 2030, Loss: 5.759e+00, Y0: 2.436, Time: 3.07, Learning Rate: 1.000e-06
# It: 2040, Loss: 5.707e+00, Y0: 2.432, Time: 2.82, Learning Rate: 1.000e-06
# It: 2050, Loss: 5.754e+00, Y0: 2.431, Time: 2.88, Learning Rate: 1.000e-06
# It: 2060, Loss: 5.722e+00, Y0: 2.432, Time: 3.08, Learning Rate: 1.000e-06
# It: 2070, Loss: 5.649e+00, Y0: 2.434, Time: 2.94, Learning Rate: 1.000e-06
# It: 2080, Loss: 5.642e+00, Y0: 2.431, Time: 2.79, Learning Rate: 1.000e-06
# It: 2090, Loss: 5.806e+00, Y0: 2.428, Time: 2.79, Learning Rate: 1.000e-06
# It: 2100, Loss: 5.874e+00, Y0: 2.429, Time: 3.20, Learning Rate: 1.000e-06
# It: 2110, Loss: 5.730e+00, Y0: 2.436, Time: 2.84, Learning Rate: 1.000e-06
# It: 2120, Loss: 5.571e+00, Y0: 2.436, Time: 2.82, Learning Rate: 1.000e-06
# It: 2130, Loss: 5.604e+00, Y0: 2.435, Time: 2.81, Learning Rate: 1.000e-06
# It: 2140, Loss: 5.722e+00, Y0: 2.432, Time: 3.26, Learning Rate: 1.000e-06
# It: 2150, Loss: 5.715e+00, Y0: 2.434, Time: 2.80, Learning Rate: 1.000e-06
# It: 2160, Loss: 5.860e+00, Y0: 2.430, Time: 2.81, Learning Rate: 1.000e-06
# It: 2170, Loss: 5.985e+00, Y0: 2.431, Time: 2.79, Learning Rate: 1.000e-06
# It: 2180, Loss: 5.903e+00, Y0: 2.436, Time: 3.28, Learning Rate: 1.000e-06
# It: 2190, Loss: 5.843e+00, Y0: 2.442, Time: 2.79, Learning Rate: 1.000e-06
# It: 2200, Loss: 5.728e+00, Y0: 2.444, Time: 2.82, Learning Rate: 1.000e-06
# It: 2210, Loss: 5.748e+00, Y0: 2.439, Time: 2.80, Learning Rate: 1.000e-06
# It: 2220, Loss: 5.752e+00, Y0: 2.438, Time: 3.29, Learning Rate: 1.000e-06
# It: 2230, Loss: 5.708e+00, Y0: 2.434, Time: 2.80, Learning Rate: 1.000e-06
# It: 2240, Loss: 5.941e+00, Y0: 2.432, Time: 2.81, Learning Rate: 1.000e-06
# It: 2250, Loss: 5.597e+00, Y0: 2.427, Time: 2.80, Learning Rate: 1.000e-06
# It: 2260, Loss: 5.971e+00, Y0: 2.429, Time: 3.28, Learning Rate: 1.000e-06
# It: 2270, Loss: 5.935e+00, Y0: 2.437, Time: 2.80, Learning Rate: 1.000e-06
# It: 2280, Loss: 5.977e+00, Y0: 2.444, Time: 2.83, Learning Rate: 1.000e-06
# It: 2290, Loss: 5.696e+00, Y0: 2.446, Time: 2.81, Learning Rate: 1.000e-06
# It: 2300, Loss: 5.809e+00, Y0: 2.447, Time: 3.26, Learning Rate: 1.000e-06
# It: 2310, Loss: 5.802e+00, Y0: 2.446, Time: 2.79, Learning Rate: 1.000e-06
# It: 2320, Loss: 5.535e+00, Y0: 2.440, Time: 2.79, Learning Rate: 1.000e-06
# It: 2330, Loss: 5.692e+00, Y0: 2.437, Time: 2.80, Learning Rate: 1.000e-06
# It: 2340, Loss: 5.879e+00, Y0: 2.434, Time: 3.26, Learning Rate: 1.000e-06
# It: 2350, Loss: 5.504e+00, Y0: 2.435, Time: 2.79, Learning Rate: 1.000e-06
# It: 2360, Loss: 5.679e+00, Y0: 2.435, Time: 2.81, Learning Rate: 1.000e-06
# It: 2370, Loss: 5.928e+00, Y0: 2.437, Time: 2.80, Learning Rate: 1.000e-06
# It: 2380, Loss: 5.709e+00, Y0: 2.439, Time: 3.21, Learning Rate: 1.000e-06
# It: 2390, Loss: 5.652e+00, Y0: 2.437, Time: 2.81, Learning Rate: 1.000e-06
# It: 2400, Loss: 5.730e+00, Y0: 2.439, Time: 2.80, Learning Rate: 1.000e-06
# It: 2410, Loss: 5.742e+00, Y0: 2.438, Time: 2.91, Learning Rate: 1.000e-06
# It: 2420, Loss: 5.856e+00, Y0: 2.434, Time: 3.11, Learning Rate: 1.000e-06
# It: 2430, Loss: 5.805e+00, Y0: 2.433, Time: 2.79, Learning Rate: 1.000e-06
# It: 2440, Loss: 5.744e+00, Y0: 2.439, Time: 2.81, Learning Rate: 1.000e-06
# It: 2450, Loss: 5.712e+00, Y0: 2.443, Time: 2.96, Learning Rate: 1.000e-06
# It: 2460, Loss: 5.951e+00, Y0: 2.439, Time: 3.08, Learning Rate: 1.000e-06
# It: 2470, Loss: 5.903e+00, Y0: 2.432, Time: 2.79, Learning Rate: 1.000e-06
# It: 2480, Loss: 5.796e+00, Y0: 2.431, Time: 2.80, Learning Rate: 1.000e-06
# It: 2490, Loss: 5.673e+00, Y0: 2.431, Time: 3.04, Learning Rate: 1.000e-06
# It: 2500, Loss: 5.770e+00, Y0: 2.432, Time: 2.99, Learning Rate: 1.000e-06
# It: 2510, Loss: 5.833e+00, Y0: 2.436, Time: 2.80, Learning Rate: 1.000e-06
# It: 2520, Loss: 5.544e+00, Y0: 2.436, Time: 2.79, Learning Rate: 1.000e-06
# It: 2530, Loss: 5.965e+00, Y0: 2.436, Time: 3.09, Learning Rate: 1.000e-06
# It: 2540, Loss: 5.709e+00, Y0: 2.436, Time: 2.94, Learning Rate: 1.000e-06
# It: 2550, Loss: 5.909e+00, Y0: 2.437, Time: 2.80, Learning Rate: 1.000e-06
# It: 2560, Loss: 5.639e+00, Y0: 2.440, Time: 2.80, Learning Rate: 1.000e-06
# It: 2570, Loss: 5.713e+00, Y0: 2.439, Time: 3.18, Learning Rate: 1.000e-06
# It: 2580, Loss: 6.015e+00, Y0: 2.437, Time: 2.80, Learning Rate: 1.000e-06
# It: 2590, Loss: 5.956e+00, Y0: 2.436, Time: 2.81, Learning Rate: 1.000e-06
# It: 2600, Loss: 6.029e+00, Y0: 2.433, Time: 2.80, Learning Rate: 1.000e-06
# It: 2610, Loss: 5.812e+00, Y0: 2.432, Time: 3.25, Learning Rate: 1.000e-06
# It: 2620, Loss: 5.810e+00, Y0: 2.435, Time: 2.83, Learning Rate: 1.000e-06
# It: 2630, Loss: 5.964e+00, Y0: 2.433, Time: 2.80, Learning Rate: 1.000e-06
# It: 2640, Loss: 6.057e+00, Y0: 2.434, Time: 2.80, Learning Rate: 1.000e-06
# It: 2650, Loss: 5.767e+00, Y0: 2.437, Time: 3.26, Learning Rate: 1.000e-06
# It: 2660, Loss: 5.602e+00, Y0: 2.436, Time: 2.80, Learning Rate: 1.000e-06
# It: 2670, Loss: 5.623e+00, Y0: 2.435, Time: 2.78, Learning Rate: 1.000e-06
# It: 2680, Loss: 5.766e+00, Y0: 2.437, Time: 2.78, Learning Rate: 1.000e-06
# It: 2690, Loss: 6.034e+00, Y0: 2.439, Time: 3.28, Learning Rate: 1.000e-06
# It: 2700, Loss: 6.041e+00, Y0: 2.441, Time: 2.79, Learning Rate: 1.000e-06
# It: 2710, Loss: 5.349e+00, Y0: 2.440, Time: 2.77, Learning Rate: 1.000e-06
# It: 2720, Loss: 5.695e+00, Y0: 2.438, Time: 2.78, Learning Rate: 1.000e-06
# It: 2730, Loss: 5.390e+00, Y0: 2.434, Time: 3.25, Learning Rate: 1.000e-06
# It: 2740, Loss: 5.825e+00, Y0: 2.433, Time: 2.85, Learning Rate: 1.000e-06
# It: 2750, Loss: 5.783e+00, Y0: 2.435, Time: 2.78, Learning Rate: 1.000e-06
# It: 2760, Loss: 5.557e+00, Y0: 2.439, Time: 2.80, Learning Rate: 1.000e-06
# It: 2770, Loss: 5.705e+00, Y0: 2.441, Time: 3.25, Learning Rate: 1.000e-06
# It: 2780, Loss: 5.710e+00, Y0: 2.436, Time: 2.81, Learning Rate: 1.000e-06
# It: 2790, Loss: 5.739e+00, Y0: 2.434, Time: 2.79, Learning Rate: 1.000e-06
# It: 2800, Loss: 5.796e+00, Y0: 2.438, Time: 2.81, Learning Rate: 1.000e-06
# It: 2810, Loss: 5.764e+00, Y0: 2.437, Time: 3.26, Learning Rate: 1.000e-06
# It: 2820, Loss: 5.685e+00, Y0: 2.434, Time: 2.81, Learning Rate: 1.000e-06
# It: 2830, Loss: 5.717e+00, Y0: 2.433, Time: 2.80, Learning Rate: 1.000e-06
# It: 2840, Loss: 5.858e+00, Y0: 2.435, Time: 2.84, Learning Rate: 1.000e-06
# It: 2850, Loss: 5.841e+00, Y0: 2.434, Time: 3.23, Learning Rate: 1.000e-06
# It: 2860, Loss: 5.581e+00, Y0: 2.430, Time: 2.78, Learning Rate: 1.000e-06
# It: 2870, Loss: 5.935e+00, Y0: 2.429, Time: 2.78, Learning Rate: 1.000e-06
# It: 2880, Loss: 5.690e+00, Y0: 2.430, Time: 2.88, Learning Rate: 1.000e-06
# It: 2890, Loss: 5.726e+00, Y0: 2.432, Time: 3.18, Learning Rate: 1.000e-06
# It: 2900, Loss: 5.774e+00, Y0: 2.437, Time: 2.80, Learning Rate: 1.000e-06
# It: 2910, Loss: 5.664e+00, Y0: 2.439, Time: 2.80, Learning Rate: 1.000e-06
# It: 2920, Loss: 5.858e+00, Y0: 2.437, Time: 2.96, Learning Rate: 1.000e-06
# It: 2930, Loss: 5.818e+00, Y0: 2.433, Time: 3.05, Learning Rate: 1.000e-06
# It: 2940, Loss: 5.637e+00, Y0: 2.430, Time: 2.78, Learning Rate: 1.000e-06
# It: 2950, Loss: 5.876e+00, Y0: 2.436, Time: 2.77, Learning Rate: 1.000e-06
# It: 2960, Loss: 5.918e+00, Y0: 2.440, Time: 2.98, Learning Rate: 1.000e-06
# It: 2970, Loss: 5.468e+00, Y0: 2.439, Time: 3.03, Learning Rate: 1.000e-06
# It: 2980, Loss: 5.879e+00, Y0: 2.437, Time: 2.79, Learning Rate: 1.000e-06
# It: 2990, Loss: 5.840e+00, Y0: 2.431, Time: 2.80, Learning Rate: 1.000e-06
#
# Predicted Y0: 2.4315
# Exact Y0:     7.2225
