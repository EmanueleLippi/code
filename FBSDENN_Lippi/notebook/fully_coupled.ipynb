# %% [markdown]
# ### Sistema Fully Coupled
# $$
# \begin{cases}
# dS_t =\mu(c-S_t)dt + \sigma_1dW^1_t\\
#
# dH_t = \mu(c-H_t)dt + \sigma_2 dW^2_t\\
#
# dV_t = a(X^2_t+bH_t+c e^{t}(Z^3_t\sigma_3^{-1}-X_t)/2)dt + \sigma_3 dW^3_t\\
#
# dX_t = V_t dt
#
# \end{cases}
# $$

# %% [markdown]
# ### Soluzione
# $$
#     u(t,s,h,v,x) = e^{-t}(e^s + e^{s}h + v^2 + xv)
# $$

# %%
## Rete neurale con normalizzazione della loss
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import time
from abc import ABC, abstractmethod

class FBSNN(ABC): # Forward-Backward Stochastic Neural Network
    def __init__(self, Xi, T,
                       M, N, D,
                       layers):

        self.Xi = Xi # initial point
        self.T = T # terminal time

        self.M = M # number of trajectories
        self.N = N # number of time snapshots
        self.D = D # number of dimensions

        # layers
        self.layers = layers # (D+1) --> 1

        # initialize NN
        self.weights, self.biases = self.initialize_NN(layers)

        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))

        # tf placeholders and graph (training)
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.t_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, 1]) # M x (N+1) x 1
        self.W_tf = tf.placeholder(tf.float32, shape=[M, self.N+1, self.D]) # M x (N+1) x D
        self.Xi_tf = tf.placeholder(tf.float32, shape=[1, D]) # 1 x D

        self.loss, self.X_pred, self.Y_pred, self.Y0_pred, self.Z_pred = self.loss_function(self.t_tf, self.W_tf, self.Xi_tf)

        # optimizers
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.learning_rate)
        self.train_op = self.optimizer.minimize(self.loss)

        # initialize session and variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim],
                                               stddev=xavier_stddev), dtype=tf.float32)

    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1

        H = X
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    def net_u(self, t, X): # M x 1, M x D

        u = self.neural_net(tf.concat([t,X], 1), self.weights, self.biases) # M x 1
        Du = tf.gradients(u, X)[0] # M x D

        return u, Du

    def Dg_tf(self, X): # M x D
        return tf.gradients(self.g_tf(X), X)[0] # M x D

    def loss_function(self, t, W, Xi): # M x (N+1) x 1, M x (N+1) x D, 1 x D
        loss = 0
        X_list = []
        Y_list = []
        Z_list = []

        t0 = t[:,0,:]
        W0 = W[:,0,:]
        X0 = tf.tile(Xi,[self.M,1]) # M x D
        Y0, Du0 = self.net_u(t0,X0) # M x 1, M x D
        sigma0 = self.sigma_tf(t0, X0, Y0)
        Z0 = tf.squeeze(tf.matmul(tf.expand_dims(Du0, 1), sigma0), axis=1)

        X_list.append(X0)
        Y_list.append(Y0)
        Z_list.append(Z0)

        for n in range(0,self.N):
            t1 = t[:,n+1,:]
            W1 = W[:,n+1,:]
            dW = W1 - W0
            sigma_dW = tf.squeeze(tf.matmul(sigma0, tf.expand_dims(dW,-1)), axis=[-1])
            X1 = X0 + self.mu_tf(t0,X0,Y0,Z0)*(t1-t0) + sigma_dW
            # Z = Du*sigma e nella backward compare Z*dW.
            Y1_tilde = Y0 + self.phi_tf(t0,X0,Y0,Z0)*(t1-t0) + tf.reduce_sum(Z0*dW, axis=1, keepdims = True)
            Y1, Du1 = self.net_u(t1,X1)
            sigma1 = self.sigma_tf(t1, X1, Y1)
            Z1 = tf.squeeze(tf.matmul(tf.expand_dims(Du1, 1), sigma1), axis=1)

            loss += tf.reduce_sum(tf.square(Y1 - Y1_tilde))

            t0 = t1
            W0 = W1
            X0 = X1
            Y0 = Y1
            Z0 = Z1
            sigma0 = sigma1

            X_list.append(X0)
            Y_list.append(Y0)
            Z_list.append(Z0)

        loss += tf.reduce_sum(tf.square(Y1 - self.g_tf(X1)))
        Dg = self.Dg_tf(X1)
        Z_terminal = tf.squeeze(tf.matmul(tf.expand_dims(Dg, 1), sigma1), axis=1)
        loss += tf.reduce_sum(tf.square(Z1 - Z_terminal))

        X = tf.stack(X_list,axis=1)
        Y = tf.stack(Y_list,axis=1)
        Z = tf.stack(Z_list,axis=1)

        return loss/self.N, X, Y, Y[0,0,0], Z

    def fetch_minibatch(self):
        T = self.T

        M = self.M
        N = self.N
        D = self.D

        Dt = np.zeros((M,N+1,1)) # M x (N+1) x 1
        DW = np.zeros((M,N+1,D)) # M x (N+1) x D

        dt = T/N

        Dt[:,1:,:] = dt
        DW[:,1:,:] = np.sqrt(dt)*np.random.normal(size=(M,N,D))

        t = np.cumsum(Dt,axis=1) # M x (N+1) x 1
        W = np.cumsum(DW,axis=1) # M x (N+1) x D

        return t, W

    def train(self, N_Iter, learning_rate):

        start_time = time.time()
        for it in range(N_Iter):

            t_batch, W_batch = self.fetch_minibatch() # M x (N+1) x 1, M x (N+1) x D

            tf_dict = {self.Xi_tf: self.Xi, self.t_tf: t_batch, self.W_tf: W_batch, self.learning_rate: learning_rate}

            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value, Y0_value, learning_rate_value = self.sess.run([self.loss, self.Y0_pred, self.learning_rate], tf_dict)
                print('It: %d, Loss: %.3e, Y0: %.3f, Time: %.2f, Learning Rate: %.3e' %
                      (it, loss_value, Y0_value, elapsed, learning_rate_value))
                start_time = time.time()


    def predict(self, Xi_star, t_star, W_star):

        tf_dict = {self.Xi_tf: Xi_star, self.t_tf: t_star, self.W_tf: W_star}

        X_star = self.sess.run(self.X_pred, tf_dict)
        Y_star = self.sess.run(self.Y_pred, tf_dict)
        Z_star = self.sess.run(self.Z_pred, tf_dict)

        return X_star, Y_star, Z_star

    ###########################################################################
    ############################# Change Here! ################################
    ###########################################################################
    @abstractmethod
    def phi_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        pass # M x1

    @abstractmethod
    def g_tf(self, X): # M x D
        pass # M x 1

    @abstractmethod
    def mu_tf(self, t, X, Y, Z): # M x 1, M x D, M x 1, M x D
        M = self.M
        D = self.D
        return np.zeros([M,D]) # M x D

    @abstractmethod
    def sigma_tf(self, t, X, Y): # M x 1, M x D, M x 1
        M = self.M
        D = self.D
        return tf.matrix_diag(tf.ones([M,D])) # M x D x D
    ###########################################################################
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class NN(FBSNN):
    def __init__(self, Xi, T, M, N, D, layers, parameters):
        self.mu = parameters['mu']
        self.c = parameters['c']
        self.b = parameters['b']
        self.a = parameters['a']
        self.s1 = parameters['s1']
        self.s2 = parameters['s2']
        self.s3 = parameters['s3']
        super().__init__(Xi, T, M, N, D, layers)
    
    def mu_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        mu = tf.cast(self.mu, tf.float32)
        c = tf.cast(self.c, tf.float32)
        a = tf.cast(self.a, tf.float32)
        b = tf.cast(self.b, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        #Accoppiamento
        #Z ha dimensione [M, D]. Le colonne sono nella forma
        #[Z_S, Z_H, Z_V, Z_X]
        Z_V = Z[:, 2:3]
        exp_t = tf.exp(t)
        V_from_Z = 0.5 * ((exp_t * Z_V / s3) - X_state)
        dS = mu * (c - S)
        dH = mu * (c - H)
        dV = self.a * (X_state**2 + b*H + c*V_from_Z)
        dX = V
        return tf.concat([dS, dH, dV, dX], axis=1)

    def g_tf(self, X):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        exp_T = tf.exp(-self.T)
        exp_S = tf.exp(S)
        val = exp_S + (exp_S * H) + (V**2) + (X_state*V)
        return exp_T * val

    def phi_tf(self, t, X, Y, Z):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        
        mu = tf.cast(self.mu, tf.float32)
        c = tf.cast(self.c, tf.float32)
        a = tf.cast(self.a, tf.float32)
        b = tf.cast(self.b, tf.float32)
        s1 = tf.cast(self.s1, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)
        
        exp_t = tf.exp(-t)
        exp_S = tf.exp(S)

        term1 = (1.0 + H) * (mu * (c - S) * exp_S)
        term2 = mu * (c - H) * exp_S
        Z_V = Z[:, 2:3]
        V_from_Z = 0.5 * ((tf.exp(t) * Z_V / s3) - X_state)
        term3 = (2.0 * V + X_state) * (a * (X_state**2 + b * H + c * V_from_Z))
        term4 = V**2 + s3**2
        term5 = 0.5 * exp_S * (s1**2) * (1.0 + H)
        
        equation = term1 + term2 + term3 + term4 + term5
        equation = tf.cast(equation, tf.float32)
        
        return -(Y - (exp_t * equation))
    
    def sigma_tf(self, t, X, Y):
        S, H, V, X_state = tf.split(X, num_or_size_splits=4, axis=1)
        s1 = tf.cast(self.s1, tf.float32)
        s2 = tf.cast(self.s2, tf.float32)
        s3 = tf.cast(self.s3, tf.float32)

        zeros = tf.zeros_like(S)
        ones = tf.ones_like(S)

        r1 = tf.concat([s1 * ones, zeros, zeros, zeros], axis=1)
        r2 = tf.concat([zeros, s2 * ones, zeros, zeros], axis=1)
        r3 = tf.concat([zeros, zeros, s3 * ones, zeros], axis=1)
        r4 = tf.concat([zeros, zeros, zeros, zeros], axis=1)

        return tf.stack([r1, r2, r3, r4], axis=1)

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt

    M = 1024
    N = 200
    D = 4
    T = 1.0

    params = {
        'mu': np.float32(1.0),
        'c': np.float32(1.0),
        'b': np.float32(1.0),
        'a': np.float32(1.0),
        's1': np.float32(0.5),
        's2': np.float32(0.5),
        's3': np.float32(0.5),
    }

    Xi = np.array([1.5, 0.5, 0.5, 0.5]).reshape(1, D)

    layers = [D+1] + 4*[256] + [1]

    model = NN(Xi, T, M, N, D, layers, params)

    print("===WARMUP===")
    model.train(N_Iter=500, learning_rate=1e-4)

    print("=== Avvio training (High Precision) ===")
    model.train(N_Iter=3000, learning_rate=1e-3)
    model.train(N_Iter=5000, learning_rate=1e-4)
    model.train(N_Iter=5000, learning_rate=1e-5)
    model.train(N_Iter=3000, learning_rate=1e-6)

    # --- PLOTTING ---
    t_test, W_test = model.fetch_minibatch()
    X_pred, Y_pred, Z_pred = model.predict(Xi, t_test, W_test)

    def u_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X_state = Xi_arr[:, 3:4]
        return np.exp(-t) * (np.exp(S) + np.exp(S)*H + V**2 + X_state*V)

    def z_exact(t, Xi_arr):
        S = Xi_arr[:, 0:1]
        H = Xi_arr[:, 1:2]
        V = Xi_arr[:, 2:3]
        X_state = Xi_arr[:, 3:4]

        s1 = params['s1']
        s2 = params['s2']
        s3 = params['s3']

        common = np.exp(-t)
        z_s = common * np.exp(S) * (1.0 + H) * s1
        z_h = common * np.exp(S) * s2
        z_v = common * (2.0 * V + X_state) * s3
        z_x = np.zeros_like(z_s)

        return np.concatenate([z_s, z_h, z_v, z_x], axis=1)

    Xi_reshaped = X_pred.reshape(-1, D)
    t_reshaped = t_test.reshape(-1, 1)

    Y_exact = u_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, 1)
    Z_exact = z_exact(t_reshaped, Xi_reshaped).reshape(M, N+1, D)

    exact_Y0 = u_exact(np.array([[0.0]]), Xi)[0, 0]
    print(f"\nPredicted Y0: {Y_pred[0,0,0]:.4f}")
    print(f"Exact Y0:     {exact_Y0:.4f}")

    plt.figure(figsize=(10,6))
    plt.plot(t_test[0,:,0], Y_pred[0,:,0], 'b', label='Learned Y')
    plt.plot(t_test[0,:,0], Y_exact[0,:,0], 'r--', label='Exact Y')
    plt.plot(t_test[1:5,:,0].T, Y_pred[1:5,:,0].T, 'b')
    plt.plot(t_test[1:5,:,0].T, Y_exact[1:5,:,0].T, 'r--')
    plt.title("Soluzione Sistema Pienamente Accoppiato 4D")
    plt.xlabel("Tempo t")
    plt.ylabel("Y_t")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # Errore relativo medio sui componenti di Z (stile log_z, ma corretto per ogni componente)
    eps = 1e-8
    rel_err_Z = np.abs((Z_pred - Z_exact) / (np.abs(Z_exact) + eps))
    mean_rel_err_Z = np.mean(rel_err_Z, axis=0)  # (N+1, D)

    labels = ['Z_S', 'Z_H', 'Z_V', 'Z_X']
    colors = ['b', 'g', 'r', 'm']

    plt.figure(figsize=(10,6))
    for d in range(D):
        plt.plot(t_test[0,:,0], mean_rel_err_Z[:, d], colors[d], label=f'Mean Rel Error {labels[d]}')
    plt.yscale('log')
    plt.title('Errore relativo medio di Z (scala log)')
    plt.xlabel('Tempo t')
    plt.ylabel('Errore relativo medio')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
#
# ===WARMUP===
# It: 0, Loss: 1.346e+02, Y0: 0.032, Time: 56.45, Learning Rate: 1.000e-04
# It: 10, Loss: 6.907e+01, Y0: 0.854, Time: 4.36, Learning Rate: 1.000e-04
# It: 20, Loss: 2.823e+01, Y0: 1.840, Time: 4.08, Learning Rate: 1.000e-04
# It: 30, Loss: 1.757e+01, Y0: 2.866, Time: 4.48, Learning Rate: 1.000e-04
# It: 40, Loss: 1.881e+01, Y0: 3.124, Time: 4.08, Learning Rate: 1.000e-04
# It: 50, Loss: 1.526e+01, Y0: 2.838, Time: 4.06, Learning Rate: 1.000e-04
# It: 60, Loss: 1.594e+01, Y0: 2.788, Time: 4.42, Learning Rate: 1.000e-04
# It: 70, Loss: 1.482e+01, Y0: 2.968, Time: 4.10, Learning Rate: 1.000e-04
# It: 80, Loss: 1.479e+01, Y0: 3.106, Time: 4.09, Learning Rate: 1.000e-04
# It: 90, Loss: 1.535e+01, Y0: 3.160, Time: 4.47, Learning Rate: 1.000e-04
# It: 100, Loss: 1.285e+01, Y0: 3.258, Time: 4.10, Learning Rate: 1.000e-04
# It: 110, Loss: 1.267e+01, Y0: 3.374, Time: 4.31, Learning Rate: 1.000e-04
# It: 120, Loss: 1.330e+01, Y0: 3.472, Time: 4.22, Learning Rate: 1.000e-04
# It: 130, Loss: 1.292e+01, Y0: 3.613, Time: 4.09, Learning Rate: 1.000e-04
# It: 140, Loss: 1.106e+01, Y0: 3.716, Time: 4.46, Learning Rate: 1.000e-04
# It: 150, Loss: 9.770e+00, Y0: 3.827, Time: 4.10, Learning Rate: 1.000e-04
# It: 160, Loss: 1.044e+01, Y0: 3.989, Time: 4.11, Learning Rate: 1.000e-04
# It: 170, Loss: 9.703e+00, Y0: 4.148, Time: 4.52, Learning Rate: 1.000e-04
# It: 180, Loss: 9.173e+00, Y0: 4.280, Time: 4.12, Learning Rate: 1.000e-04
# It: 190, Loss: 8.356e+00, Y0: 4.430, Time: 4.25, Learning Rate: 1.000e-04
# It: 200, Loss: 8.514e+00, Y0: 4.580, Time: 4.37, Learning Rate: 1.000e-04
# It: 210, Loss: 8.353e+00, Y0: 4.713, Time: 4.11, Learning Rate: 1.000e-04
# It: 220, Loss: 8.107e+00, Y0: 4.821, Time: 4.54, Learning Rate: 1.000e-04
# It: 230, Loss: 8.566e+00, Y0: 4.904, Time: 4.11, Learning Rate: 1.000e-04
# It: 240, Loss: 8.214e+00, Y0: 4.992, Time: 4.13, Learning Rate: 1.000e-04
# It: 250, Loss: 8.840e+00, Y0: 5.048, Time: 4.54, Learning Rate: 1.000e-04
# It: 260, Loss: 8.068e+00, Y0: 5.056, Time: 4.13, Learning Rate: 1.000e-04
# It: 270, Loss: 8.309e+00, Y0: 5.098, Time: 4.15, Learning Rate: 1.000e-04
# It: 280, Loss: 8.279e+00, Y0: 5.136, Time: 4.45, Learning Rate: 1.000e-04
# It: 290, Loss: 8.172e+00, Y0: 5.175, Time: 4.12, Learning Rate: 1.000e-04
# It: 300, Loss: 8.003e+00, Y0: 5.144, Time: 4.43, Learning Rate: 1.000e-04
# It: 310, Loss: 8.067e+00, Y0: 5.157, Time: 4.15, Learning Rate: 1.000e-04
# It: 320, Loss: 8.008e+00, Y0: 5.180, Time: 4.16, Learning Rate: 1.000e-04
# It: 330, Loss: 8.096e+00, Y0: 5.212, Time: 4.51, Learning Rate: 1.000e-04
# It: 340, Loss: 8.246e+00, Y0: 5.225, Time: 4.19, Learning Rate: 1.000e-04
# It: 350, Loss: 7.826e+00, Y0: 5.201, Time: 4.18, Learning Rate: 1.000e-04
# It: 360, Loss: 8.001e+00, Y0: 5.246, Time: 4.56, Learning Rate: 1.000e-04
# It: 370, Loss: 8.176e+00, Y0: 5.246, Time: 4.19, Learning Rate: 1.000e-04
# It: 380, Loss: 7.769e+00, Y0: 5.243, Time: 4.45, Learning Rate: 1.000e-04
# It: 390, Loss: 7.719e+00, Y0: 5.238, Time: 4.19, Learning Rate: 1.000e-04
# It: 400, Loss: 7.928e+00, Y0: 5.250, Time: 4.17, Learning Rate: 1.000e-04
# It: 410, Loss: 7.765e+00, Y0: 5.243, Time: 4.53, Learning Rate: 1.000e-04
# It: 420, Loss: 7.733e+00, Y0: 5.254, Time: 4.19, Learning Rate: 1.000e-04
# It: 430, Loss: 7.602e+00, Y0: 5.314, Time: 4.18, Learning Rate: 1.000e-04
# It: 440, Loss: 8.064e+00, Y0: 5.346, Time: 4.61, Learning Rate: 1.000e-04
# It: 450, Loss: 7.859e+00, Y0: 5.346, Time: 4.20, Learning Rate: 1.000e-04
# It: 460, Loss: 7.266e+00, Y0: 5.361, Time: 4.46, Learning Rate: 1.000e-04
# It: 470, Loss: 7.404e+00, Y0: 5.349, Time: 4.20, Learning Rate: 1.000e-04
# It: 480, Loss: 7.627e+00, Y0: 5.399, Time: 4.18, Learning Rate: 1.000e-04
# It: 490, Loss: 7.249e+00, Y0: 5.450, Time: 4.56, Learning Rate: 1.000e-04
# === Avvio training (High Precision) ===
# It: 0, Loss: 6.873e+00, Y0: 5.471, Time: 0.42, Learning Rate: 1.000e-03
# It: 10, Loss: 5.518e+00, Y0: 4.745, Time: 4.20, Learning Rate: 1.000e-03
# It: 20, Loss: 4.778e+00, Y0: 5.402, Time: 4.53, Learning Rate: 1.000e-03
# It: 30, Loss: 2.714e+00, Y0: 5.439, Time: 4.22, Learning Rate: 1.000e-03
# It: 40, Loss: 1.935e+00, Y0: 6.022, Time: 4.57, Learning Rate: 1.000e-03
# It: 50, Loss: 1.750e+00, Y0: 5.772, Time: 4.19, Learning Rate: 1.000e-03
# It: 60, Loss: 1.101e+00, Y0: 5.693, Time: 4.22, Learning Rate: 1.000e-03
# It: 70, Loss: 9.532e-01, Y0: 6.415, Time: 4.57, Learning Rate: 1.000e-03
# It: 80, Loss: 8.569e-01, Y0: 7.013, Time: 4.19, Learning Rate: 1.000e-03
# It: 90, Loss: 8.103e-01, Y0: 7.267, Time: 4.30, Learning Rate: 1.000e-03
# It: 100, Loss: 7.567e-01, Y0: 7.398, Time: 4.55, Learning Rate: 1.000e-03
# It: 110, Loss: 7.274e-01, Y0: 7.622, Time: 4.22, Learning Rate: 1.000e-03
# It: 120, Loss: 5.922e-01, Y0: 7.823, Time: 4.61, Learning Rate: 1.000e-03
# It: 130, Loss: 5.777e-01, Y0: 7.928, Time: 4.22, Learning Rate: 1.000e-03
# It: 140, Loss: 4.978e-01, Y0: 8.183, Time: 4.19, Learning Rate: 1.000e-03
# It: 150, Loss: 5.319e-01, Y0: 8.210, Time: 4.59, Learning Rate: 1.000e-03
# It: 160, Loss: 5.251e-01, Y0: 8.355, Time: 4.22, Learning Rate: 1.000e-03
# It: 170, Loss: 5.520e-01, Y0: 8.321, Time: 4.37, Learning Rate: 1.000e-03
# It: 180, Loss: 4.096e-01, Y0: 8.411, Time: 4.44, Learning Rate: 1.000e-03
# It: 190, Loss: 6.078e-01, Y0: 8.414, Time: 4.21, Learning Rate: 1.000e-03
# It: 200, Loss: 5.577e-01, Y0: 8.351, Time: 4.57, Learning Rate: 1.000e-03
# It: 210, Loss: 3.974e-01, Y0: 8.283, Time: 4.25, Learning Rate: 1.000e-03
# It: 220, Loss: 3.462e-01, Y0: 8.265, Time: 4.23, Learning Rate: 1.000e-03
# It: 230, Loss: 3.056e-01, Y0: 8.245, Time: 4.62, Learning Rate: 1.000e-03
# It: 240, Loss: 3.012e-01, Y0: 8.238, Time: 4.21, Learning Rate: 1.000e-03
# It: 250, Loss: 3.596e-01, Y0: 8.264, Time: 4.40, Learning Rate: 1.000e-03
# It: 260, Loss: 3.439e-01, Y0: 8.281, Time: 4.34, Learning Rate: 1.000e-03
# It: 270, Loss: 3.242e-01, Y0: 8.220, Time: 4.21, Learning Rate: 1.000e-03
# It: 280, Loss: 2.663e-01, Y0: 8.081, Time: 4.65, Learning Rate: 1.000e-03
# It: 290, Loss: 2.517e-01, Y0: 8.120, Time: 4.21, Learning Rate: 1.000e-03
# It: 300, Loss: 2.100e-01, Y0: 8.011, Time: 4.24, Learning Rate: 1.000e-03
# It: 310, Loss: 2.929e-01, Y0: 7.942, Time: 4.63, Learning Rate: 1.000e-03
# It: 320, Loss: 1.778e-01, Y0: 7.825, Time: 4.25, Learning Rate: 1.000e-03
# It: 330, Loss: 1.618e-01, Y0: 7.702, Time: 4.50, Learning Rate: 1.000e-03
# It: 340, Loss: 1.780e-01, Y0: 7.672, Time: 4.21, Learning Rate: 1.000e-03
# It: 350, Loss: 2.213e-01, Y0: 7.636, Time: 4.22, Learning Rate: 1.000e-03
# It: 360, Loss: 1.932e-01, Y0: 7.580, Time: 4.63, Learning Rate: 1.000e-03
# It: 370, Loss: 2.088e-01, Y0: 7.506, Time: 4.24, Learning Rate: 1.000e-03
# It: 380, Loss: 1.980e-01, Y0: 7.425, Time: 4.23, Learning Rate: 1.000e-03
# It: 390, Loss: 1.276e-01, Y0: 7.424, Time: 4.56, Learning Rate: 1.000e-03
# It: 400, Loss: 1.263e-01, Y0: 7.422, Time: 4.24, Learning Rate: 1.000e-03
# It: 410, Loss: 1.296e-01, Y0: 7.403, Time: 4.60, Learning Rate: 1.000e-03
# It: 420, Loss: 4.250e-01, Y0: 7.484, Time: 4.21, Learning Rate: 1.000e-03
# It: 430, Loss: 1.459e-01, Y0: 7.256, Time: 4.25, Learning Rate: 1.000e-03
# It: 440, Loss: 2.178e-01, Y0: 7.141, Time: 4.62, Learning Rate: 1.000e-03
# It: 450, Loss: 1.003e-01, Y0: 7.164, Time: 4.30, Learning Rate: 1.000e-03
# It: 460, Loss: 1.125e-01, Y0: 7.252, Time: 4.38, Learning Rate: 1.000e-03
# It: 470, Loss: 1.202e-01, Y0: 7.256, Time: 4.43, Learning Rate: 1.000e-03
# It: 480, Loss: 1.133e-01, Y0: 7.189, Time: 4.23, Learning Rate: 1.000e-03
# It: 490, Loss: 1.058e-01, Y0: 7.224, Time: 4.57, Learning Rate: 1.000e-03
# It: 500, Loss: 9.417e-02, Y0: 7.247, Time: 4.25, Learning Rate: 1.000e-03
# It: 510, Loss: 9.300e-02, Y0: 7.180, Time: 4.26, Learning Rate: 1.000e-03
# It: 520, Loss: 1.169e-01, Y0: 7.142, Time: 4.64, Learning Rate: 1.000e-03
# It: 530, Loss: 1.291e-01, Y0: 7.125, Time: 4.26, Learning Rate: 1.000e-03
# It: 540, Loss: 1.818e-01, Y0: 7.049, Time: 4.51, Learning Rate: 1.000e-03
# It: 550, Loss: 1.348e-01, Y0: 7.182, Time: 4.29, Learning Rate: 1.000e-03
# It: 560, Loss: 9.457e-02, Y0: 7.145, Time: 4.21, Learning Rate: 1.000e-03
# It: 570, Loss: 9.347e-02, Y0: 7.133, Time: 4.55, Learning Rate: 1.000e-03
# It: 580, Loss: 1.336e-01, Y0: 7.122, Time: 4.26, Learning Rate: 1.000e-03
# It: 590, Loss: 9.045e-02, Y0: 7.067, Time: 4.20, Learning Rate: 1.000e-03
# It: 600, Loss: 9.349e-02, Y0: 7.110, Time: 4.53, Learning Rate: 1.000e-03
# It: 610, Loss: 1.675e-01, Y0: 7.240, Time: 4.27, Learning Rate: 1.000e-03
# It: 620, Loss: 9.263e-02, Y0: 7.079, Time: 4.69, Learning Rate: 1.000e-03
# It: 630, Loss: 1.003e-01, Y0: 7.079, Time: 4.26, Learning Rate: 1.000e-03
# It: 640, Loss: 1.241e-01, Y0: 7.046, Time: 4.25, Learning Rate: 1.000e-03
# It: 650, Loss: 9.344e-02, Y0: 7.101, Time: 4.65, Learning Rate: 1.000e-03
# It: 660, Loss: 8.495e-02, Y0: 7.034, Time: 4.25, Learning Rate: 1.000e-03
# It: 670, Loss: 1.288e-01, Y0: 7.005, Time: 4.36, Learning Rate: 1.000e-03
# It: 680, Loss: 1.209e-01, Y0: 7.013, Time: 4.48, Learning Rate: 1.000e-03
# It: 690, Loss: 1.066e-01, Y0: 7.135, Time: 4.29, Learning Rate: 1.000e-03
# It: 700, Loss: 8.200e-02, Y0: 7.067, Time: 4.56, Learning Rate: 1.000e-03
# It: 710, Loss: 7.744e-02, Y0: 7.030, Time: 4.22, Learning Rate: 1.000e-03
# It: 720, Loss: 3.242e-01, Y0: 6.914, Time: 4.27, Learning Rate: 1.000e-03
# It: 730, Loss: 1.977e-01, Y0: 7.005, Time: 4.58, Learning Rate: 1.000e-03
# It: 740, Loss: 1.274e-01, Y0: 7.038, Time: 4.22, Learning Rate: 1.000e-03
# It: 750, Loss: 1.139e-01, Y0: 7.092, Time: 4.44, Learning Rate: 1.000e-03
# It: 760, Loss: 1.153e-01, Y0: 7.061, Time: 4.32, Learning Rate: 1.000e-03
# It: 770, Loss: 8.219e-02, Y0: 7.107, Time: 4.21, Learning Rate: 1.000e-03
# It: 780, Loss: 7.377e-02, Y0: 7.051, Time: 4.63, Learning Rate: 1.000e-03
# It: 790, Loss: 7.707e-02, Y0: 7.106, Time: 4.29, Learning Rate: 1.000e-03
# It: 800, Loss: 8.126e-02, Y0: 7.105, Time: 4.23, Learning Rate: 1.000e-03
# It: 810, Loss: 6.883e-02, Y0: 7.101, Time: 4.59, Learning Rate: 1.000e-03
# It: 820, Loss: 2.344e-01, Y0: 6.978, Time: 4.29, Learning Rate: 1.000e-03
# It: 830, Loss: 1.804e-01, Y0: 7.104, Time: 4.64, Learning Rate: 1.000e-03
# It: 840, Loss: 7.463e-02, Y0: 7.082, Time: 4.25, Learning Rate: 1.000e-03
# It: 850, Loss: 1.137e-01, Y0: 7.061, Time: 4.25, Learning Rate: 1.000e-03
# It: 860, Loss: 8.551e-02, Y0: 7.142, Time: 4.58, Learning Rate: 1.000e-03
# It: 870, Loss: 7.738e-02, Y0: 7.105, Time: 4.25, Learning Rate: 1.000e-03
# It: 880, Loss: 7.644e-02, Y0: 7.102, Time: 4.34, Learning Rate: 1.000e-03
# It: 890, Loss: 9.431e-02, Y0: 7.146, Time: 4.50, Learning Rate: 1.000e-03
# It: 900, Loss: 2.852e-01, Y0: 7.221, Time: 4.26, Learning Rate: 1.000e-03
# It: 910, Loss: 1.212e-01, Y0: 7.098, Time: 4.62, Learning Rate: 1.000e-03
# It: 920, Loss: 1.581e-01, Y0: 7.062, Time: 4.24, Learning Rate: 1.000e-03
# It: 930, Loss: 6.856e-02, Y0: 7.034, Time: 4.22, Learning Rate: 1.000e-03
# It: 940, Loss: 9.955e-02, Y0: 7.033, Time: 4.58, Learning Rate: 1.000e-03
# It: 950, Loss: 9.271e-02, Y0: 7.028, Time: 4.21, Learning Rate: 1.000e-03
# It: 960, Loss: 7.273e-02, Y0: 7.100, Time: 4.45, Learning Rate: 1.000e-03
# It: 970, Loss: 7.047e-02, Y0: 7.101, Time: 4.39, Learning Rate: 1.000e-03
# It: 980, Loss: 6.727e-02, Y0: 7.095, Time: 4.24, Learning Rate: 1.000e-03
# It: 990, Loss: 9.001e-02, Y0: 7.032, Time: 4.65, Learning Rate: 1.000e-03
# It: 1000, Loss: 6.677e-02, Y0: 7.112, Time: 4.24, Learning Rate: 1.000e-03
# It: 1010, Loss: 7.852e-02, Y0: 7.081, Time: 4.23, Learning Rate: 1.000e-03
# It: 1020, Loss: 7.803e-02, Y0: 7.085, Time: 4.64, Learning Rate: 1.000e-03
# It: 1030, Loss: 6.306e-02, Y0: 7.067, Time: 4.31, Learning Rate: 1.000e-03
# It: 1040, Loss: 7.452e-02, Y0: 7.124, Time: 4.66, Learning Rate: 1.000e-03
# It: 1050, Loss: 6.442e-02, Y0: 7.127, Time: 4.29, Learning Rate: 1.000e-03
# It: 1060, Loss: 2.619e-01, Y0: 7.016, Time: 4.26, Learning Rate: 1.000e-03
# It: 1070, Loss: 1.046e-01, Y0: 7.102, Time: 4.63, Learning Rate: 1.000e-03
# It: 1080, Loss: 1.067e-01, Y0: 7.125, Time: 4.23, Learning Rate: 1.000e-03
# It: 1090, Loss: 7.232e-02, Y0: 7.105, Time: 4.36, Learning Rate: 1.000e-03
# It: 1100, Loss: 7.168e-02, Y0: 7.086, Time: 4.45, Learning Rate: 1.000e-03
# It: 1110, Loss: 1.233e-01, Y0: 7.094, Time: 4.26, Learning Rate: 1.000e-03
# It: 1120, Loss: 6.261e-02, Y0: 7.087, Time: 4.59, Learning Rate: 1.000e-03
# It: 1130, Loss: 6.071e-02, Y0: 7.144, Time: 4.24, Learning Rate: 1.000e-03
# It: 1140, Loss: 8.586e-02, Y0: 7.150, Time: 4.25, Learning Rate: 1.000e-03
# It: 1150, Loss: 1.008e-01, Y0: 7.085, Time: 4.62, Learning Rate: 1.000e-03
# It: 1160, Loss: 7.616e-02, Y0: 7.057, Time: 4.27, Learning Rate: 1.000e-03
# It: 1170, Loss: 1.005e-01, Y0: 7.117, Time: 4.39, Learning Rate: 1.000e-03
# It: 1180, Loss: 7.873e-02, Y0: 7.027, Time: 4.35, Learning Rate: 1.000e-03
# It: 1190, Loss: 6.991e-02, Y0: 7.065, Time: 4.26, Learning Rate: 1.000e-03
# It: 1200, Loss: 5.387e-02, Y0: 7.066, Time: 4.59, Learning Rate: 1.000e-03
# It: 1210, Loss: 6.515e-02, Y0: 7.143, Time: 4.23, Learning Rate: 1.000e-03
# It: 1220, Loss: 1.067e-01, Y0: 7.202, Time: 4.25, Learning Rate: 1.000e-03
# It: 1230, Loss: 9.231e-02, Y0: 7.015, Time: 4.57, Learning Rate: 1.000e-03
# It: 1240, Loss: 1.340e-01, Y0: 6.967, Time: 4.23, Learning Rate: 1.000e-03
# It: 1250, Loss: 7.730e-02, Y0: 7.029, Time: 4.67, Learning Rate: 1.000e-03
# It: 1260, Loss: 7.273e-02, Y0: 7.042, Time: 4.24, Learning Rate: 1.000e-03
# It: 1270, Loss: 5.926e-02, Y0: 7.153, Time: 4.24, Learning Rate: 1.000e-03
# It: 1280, Loss: 6.860e-02, Y0: 7.100, Time: 4.64, Learning Rate: 1.000e-03
# It: 1290, Loss: 6.086e-02, Y0: 7.021, Time: 4.22, Learning Rate: 1.000e-03
# It: 1300, Loss: 5.897e-02, Y0: 7.099, Time: 4.36, Learning Rate: 1.000e-03
# It: 1310, Loss: 6.278e-02, Y0: 7.193, Time: 4.43, Learning Rate: 1.000e-03
# It: 1320, Loss: 2.206e-01, Y0: 7.248, Time: 4.28, Learning Rate: 1.000e-03
# It: 1330, Loss: 5.683e-02, Y0: 7.063, Time: 4.64, Learning Rate: 1.000e-03
# It: 1340, Loss: 6.328e-02, Y0: 7.078, Time: 4.27, Learning Rate: 1.000e-03
# It: 1350, Loss: 5.328e-02, Y0: 7.095, Time: 4.23, Learning Rate: 1.000e-03
# It: 1360, Loss: 7.471e-02, Y0: 7.099, Time: 4.59, Learning Rate: 1.000e-03
# It: 1370, Loss: 8.342e-02, Y0: 7.239, Time: 4.25, Learning Rate: 1.000e-03
# It: 1380, Loss: 1.388e-01, Y0: 7.076, Time: 4.50, Learning Rate: 1.000e-03
# It: 1390, Loss: 1.310e-01, Y0: 7.036, Time: 4.32, Learning Rate: 1.000e-03
# It: 1400, Loss: 7.766e-02, Y0: 7.073, Time: 4.24, Learning Rate: 1.000e-03
# It: 1410, Loss: 5.521e-02, Y0: 7.058, Time: 4.61, Learning Rate: 1.000e-03
# It: 1420, Loss: 7.341e-02, Y0: 7.076, Time: 4.26, Learning Rate: 1.000e-03
# It: 1430, Loss: 6.465e-02, Y0: 7.127, Time: 4.26, Learning Rate: 1.000e-03
# It: 1440, Loss: 7.804e-02, Y0: 7.190, Time: 4.59, Learning Rate: 1.000e-03
# It: 1450, Loss: 5.788e-02, Y0: 7.146, Time: 4.30, Learning Rate: 1.000e-03
# It: 1460, Loss: 6.757e-02, Y0: 7.167, Time: 4.60, Learning Rate: 1.000e-03
# It: 1470, Loss: 1.802e-01, Y0: 6.963, Time: 4.23, Learning Rate: 1.000e-03
# It: 1480, Loss: 5.881e-02, Y0: 7.073, Time: 4.24, Learning Rate: 1.000e-03
# It: 1490, Loss: 1.151e-01, Y0: 7.059, Time: 4.64, Learning Rate: 1.000e-03
# It: 1500, Loss: 6.298e-02, Y0: 7.004, Time: 4.25, Learning Rate: 1.000e-03
# It: 1510, Loss: 5.871e-02, Y0: 7.021, Time: 4.39, Learning Rate: 1.000e-03
# It: 1520, Loss: 5.045e-02, Y0: 7.108, Time: 4.50, Learning Rate: 1.000e-03
# It: 1530, Loss: 6.228e-02, Y0: 7.142, Time: 4.22, Learning Rate: 1.000e-03
# It: 1540, Loss: 5.758e-02, Y0: 7.158, Time: 4.59, Learning Rate: 1.000e-03
# It: 1550, Loss: 6.414e-02, Y0: 7.156, Time: 4.27, Learning Rate: 1.000e-03
# It: 1560, Loss: 5.650e-02, Y0: 7.245, Time: 4.30, Learning Rate: 1.000e-03
# It: 1570, Loss: 7.407e-02, Y0: 7.159, Time: 4.61, Learning Rate: 1.000e-03
# It: 1580, Loss: 5.923e-02, Y0: 7.113, Time: 4.29, Learning Rate: 1.000e-03
# It: 1590, Loss: 8.394e-02, Y0: 7.229, Time: 4.56, Learning Rate: 1.000e-03
# It: 1600, Loss: 1.525e-01, Y0: 6.858, Time: 4.25, Learning Rate: 1.000e-03
# It: 1610, Loss: 8.496e-02, Y0: 6.982, Time: 4.23, Learning Rate: 1.000e-03
# It: 1620, Loss: 5.119e-02, Y0: 7.030, Time: 4.63, Learning Rate: 1.000e-03
# It: 1630, Loss: 5.556e-02, Y0: 7.014, Time: 4.26, Learning Rate: 1.000e-03
# It: 1640, Loss: 4.597e-02, Y0: 7.089, Time: 4.29, Learning Rate: 1.000e-03
# It: 1650, Loss: 4.778e-02, Y0: 7.176, Time: 4.48, Learning Rate: 1.000e-03
# It: 1660, Loss: 4.847e-02, Y0: 7.131, Time: 4.21, Learning Rate: 1.000e-03
# It: 1670, Loss: 6.404e-02, Y0: 7.189, Time: 4.55, Learning Rate: 1.000e-03
# It: 1680, Loss: 7.474e-02, Y0: 7.161, Time: 4.27, Learning Rate: 1.000e-03
# It: 1690, Loss: 1.083e-01, Y0: 7.084, Time: 4.27, Learning Rate: 1.000e-03
# It: 1700, Loss: 5.661e-02, Y0: 7.090, Time: 4.59, Learning Rate: 1.000e-03
# It: 1710, Loss: 5.941e-02, Y0: 7.077, Time: 4.23, Learning Rate: 1.000e-03
# It: 1720, Loss: 6.267e-02, Y0: 7.114, Time: 4.48, Learning Rate: 1.000e-03
# It: 1730, Loss: 5.081e-02, Y0: 7.125, Time: 4.38, Learning Rate: 1.000e-03
# It: 1740, Loss: 7.478e-02, Y0: 7.181, Time: 4.25, Learning Rate: 1.000e-03
# It: 1750, Loss: 5.413e-02, Y0: 7.230, Time: 4.64, Learning Rate: 1.000e-03
# It: 1760, Loss: 9.295e-02, Y0: 7.109, Time: 4.26, Learning Rate: 1.000e-03
# It: 1770, Loss: 1.018e-01, Y0: 7.050, Time: 4.22, Learning Rate: 1.000e-03
# It: 1780, Loss: 6.835e-02, Y0: 7.027, Time: 4.58, Learning Rate: 1.000e-03
# It: 1790, Loss: 5.139e-02, Y0: 6.969, Time: 4.23, Learning Rate: 1.000e-03
# It: 1800, Loss: 5.698e-02, Y0: 7.078, Time: 4.54, Learning Rate: 1.000e-03
# It: 1810, Loss: 5.489e-02, Y0: 7.174, Time: 4.32, Learning Rate: 1.000e-03
# It: 1820, Loss: 4.895e-02, Y0: 7.159, Time: 4.23, Learning Rate: 1.000e-03
# It: 1830, Loss: 4.557e-02, Y0: 7.228, Time: 4.59, Learning Rate: 1.000e-03
# It: 1840, Loss: 1.900e-01, Y0: 7.082, Time: 4.22, Learning Rate: 1.000e-03
# It: 1850, Loss: 8.841e-02, Y0: 6.999, Time: 4.25, Learning Rate: 1.000e-03
# It: 1860, Loss: 7.626e-02, Y0: 7.059, Time: 4.56, Learning Rate: 1.000e-03
# It: 1870, Loss: 7.819e-02, Y0: 7.105, Time: 4.25, Learning Rate: 1.000e-03
# It: 1880, Loss: 5.433e-02, Y0: 7.071, Time: 4.63, Learning Rate: 1.000e-03
# It: 1890, Loss: 1.163e-01, Y0: 7.126, Time: 4.25, Learning Rate: 1.000e-03
# It: 1900, Loss: 4.476e-02, Y0: 7.261, Time: 4.26, Learning Rate: 1.000e-03
# It: 1910, Loss: 4.662e-02, Y0: 7.265, Time: 4.68, Learning Rate: 1.000e-03
# It: 1920, Loss: 4.953e-02, Y0: 7.184, Time: 4.26, Learning Rate: 1.000e-03
# It: 1930, Loss: 8.806e-02, Y0: 7.196, Time: 4.36, Learning Rate: 1.000e-03
# It: 1940, Loss: 5.498e-02, Y0: 7.153, Time: 4.44, Learning Rate: 1.000e-03
# It: 1950, Loss: 5.510e-02, Y0: 7.234, Time: 4.26, Learning Rate: 1.000e-03
# It: 1960, Loss: 4.441e-02, Y0: 7.138, Time: 4.56, Learning Rate: 1.000e-03
# It: 1970, Loss: 4.333e-02, Y0: 7.137, Time: 4.22, Learning Rate: 1.000e-03
# It: 1980, Loss: 3.096e-01, Y0: 7.239, Time: 4.25, Learning Rate: 1.000e-03
# It: 1990, Loss: 1.158e-01, Y0: 7.091, Time: 4.65, Learning Rate: 1.000e-03
# It: 2000, Loss: 5.794e-02, Y0: 7.105, Time: 4.26, Learning Rate: 1.000e-03
# It: 2010, Loss: 4.858e-02, Y0: 6.951, Time: 4.44, Learning Rate: 1.000e-03
# It: 2020, Loss: 3.993e-02, Y0: 7.040, Time: 4.41, Learning Rate: 1.000e-03
# It: 2030, Loss: 4.120e-02, Y0: 7.091, Time: 4.23, Learning Rate: 1.000e-03
# It: 2040, Loss: 4.043e-02, Y0: 7.197, Time: 4.58, Learning Rate: 1.000e-03
# It: 2050, Loss: 4.718e-02, Y0: 7.239, Time: 4.24, Learning Rate: 1.000e-03
# It: 2060, Loss: 5.942e-02, Y0: 7.230, Time: 4.31, Learning Rate: 1.000e-03
# It: 2070, Loss: 6.387e-02, Y0: 7.316, Time: 4.55, Learning Rate: 1.000e-03
# It: 2080, Loss: 4.369e-02, Y0: 7.218, Time: 4.24, Learning Rate: 1.000e-03
# It: 2090, Loss: 4.110e-01, Y0: 7.184, Time: 4.63, Learning Rate: 1.000e-03
# It: 2100, Loss: 1.856e-01, Y0: 6.979, Time: 4.27, Learning Rate: 1.000e-03
# It: 2110, Loss: 1.162e-01, Y0: 7.037, Time: 4.23, Learning Rate: 1.000e-03
# It: 2120, Loss: 7.671e-02, Y0: 6.952, Time: 4.65, Learning Rate: 1.000e-03
# It: 2130, Loss: 4.441e-02, Y0: 7.064, Time: 4.28, Learning Rate: 1.000e-03
# It: 2140, Loss: 4.289e-02, Y0: 7.110, Time: 4.36, Learning Rate: 1.000e-03
# It: 2150, Loss: 4.909e-02, Y0: 7.197, Time: 4.47, Learning Rate: 1.000e-03
# It: 2160, Loss: 5.290e-02, Y0: 7.201, Time: 4.25, Learning Rate: 1.000e-03
# It: 2170, Loss: 8.646e-02, Y0: 7.215, Time: 4.60, Learning Rate: 1.000e-03
# It: 2180, Loss: 4.818e-02, Y0: 7.298, Time: 4.23, Learning Rate: 1.000e-03
# It: 2190, Loss: 4.481e-02, Y0: 7.295, Time: 4.26, Learning Rate: 1.000e-03
# It: 2200, Loss: 3.837e-02, Y0: 7.151, Time: 4.59, Learning Rate: 1.000e-03
# It: 2210, Loss: 4.354e-02, Y0: 7.166, Time: 4.23, Learning Rate: 1.000e-03
# It: 2220, Loss: 4.349e-02, Y0: 7.223, Time: 4.41, Learning Rate: 1.000e-03
# It: 2230, Loss: 5.269e-02, Y0: 7.226, Time: 4.36, Learning Rate: 1.000e-03
# It: 2240, Loss: 4.826e-02, Y0: 7.248, Time: 4.26, Learning Rate: 1.000e-03
# It: 2250, Loss: 1.859e-01, Y0: 6.983, Time: 4.57, Learning Rate: 1.000e-03
# It: 2260, Loss: 6.170e-02, Y0: 7.067, Time: 4.24, Learning Rate: 1.000e-03
# It: 2270, Loss: 6.167e-02, Y0: 6.976, Time: 4.28, Learning Rate: 1.000e-03
# It: 2280, Loss: 5.131e-02, Y0: 7.018, Time: 4.61, Learning Rate: 1.000e-03
# It: 2290, Loss: 5.841e-02, Y0: 7.154, Time: 4.29, Learning Rate: 1.000e-03
# It: 2300, Loss: 4.048e-02, Y0: 7.246, Time: 4.65, Learning Rate: 1.000e-03
# It: 2310, Loss: 3.867e-02, Y0: 7.308, Time: 4.22, Learning Rate: 1.000e-03
# It: 2320, Loss: 4.564e-02, Y0: 7.191, Time: 4.25, Learning Rate: 1.000e-03
# It: 2330, Loss: 7.865e-02, Y0: 7.081, Time: 4.62, Learning Rate: 1.000e-03
# It: 2340, Loss: 6.309e-02, Y0: 7.164, Time: 4.23, Learning Rate: 1.000e-03
# It: 2350, Loss: 5.732e-02, Y0: 7.042, Time: 4.35, Learning Rate: 1.000e-03
# It: 2360, Loss: 4.058e-02, Y0: 7.062, Time: 4.43, Learning Rate: 1.000e-03
# It: 2370, Loss: 3.751e-02, Y0: 7.134, Time: 4.23, Learning Rate: 1.000e-03
# It: 2380, Loss: 4.046e-02, Y0: 7.168, Time: 4.60, Learning Rate: 1.000e-03
# It: 2390, Loss: 4.977e-02, Y0: 7.395, Time: 4.22, Learning Rate: 1.000e-03
# It: 2400, Loss: 7.046e-02, Y0: 7.204, Time: 4.20, Learning Rate: 1.000e-03
# It: 2410, Loss: 5.502e-02, Y0: 7.083, Time: 4.69, Learning Rate: 1.000e-03
# It: 2420, Loss: 4.473e-02, Y0: 7.089, Time: 4.25, Learning Rate: 1.000e-03
# It: 2430, Loss: 4.166e-02, Y0: 7.131, Time: 4.44, Learning Rate: 1.000e-03
# It: 2440, Loss: 4.204e-02, Y0: 7.178, Time: 4.33, Learning Rate: 1.000e-03
# It: 2450, Loss: 5.424e-02, Y0: 7.161, Time: 4.25, Learning Rate: 1.000e-03
# It: 2460, Loss: 6.176e-02, Y0: 7.334, Time: 4.57, Learning Rate: 1.000e-03
# It: 2470, Loss: 4.786e-02, Y0: 7.144, Time: 4.24, Learning Rate: 1.000e-03
# It: 2480, Loss: 6.020e-02, Y0: 7.072, Time: 4.24, Learning Rate: 1.000e-03
# It: 2490, Loss: 9.044e-02, Y0: 7.073, Time: 4.59, Learning Rate: 1.000e-03
# It: 2500, Loss: 6.969e-02, Y0: 7.156, Time: 4.25, Learning Rate: 1.000e-03
# It: 2510, Loss: 5.091e-02, Y0: 7.071, Time: 4.59, Learning Rate: 1.000e-03
# It: 2520, Loss: 5.344e-02, Y0: 7.356, Time: 4.27, Learning Rate: 1.000e-03
# It: 2530, Loss: 5.313e-02, Y0: 7.228, Time: 4.23, Learning Rate: 1.000e-03
# It: 2540, Loss: 3.538e-02, Y0: 7.101, Time: 4.61, Learning Rate: 1.000e-03
# It: 2550, Loss: 5.027e-01, Y0: 7.103, Time: 4.24, Learning Rate: 1.000e-03
# It: 2560, Loss: 1.397e-01, Y0: 6.717, Time: 4.30, Learning Rate: 1.000e-03
# It: 2570, Loss: 8.285e-02, Y0: 7.017, Time: 4.50, Learning Rate: 1.000e-03
# It: 2580, Loss: 6.573e-02, Y0: 6.930, Time: 4.21, Learning Rate: 1.000e-03
# It: 2590, Loss: 3.974e-02, Y0: 7.114, Time: 4.66, Learning Rate: 1.000e-03
# It: 2600, Loss: 4.319e-02, Y0: 7.269, Time: 4.23, Learning Rate: 1.000e-03
# It: 2610, Loss: 3.669e-02, Y0: 7.370, Time: 4.23, Learning Rate: 1.000e-03
# It: 2620, Loss: 3.405e-02, Y0: 7.126, Time: 4.64, Learning Rate: 1.000e-03
# It: 2630, Loss: 4.418e-02, Y0: 7.237, Time: 4.25, Learning Rate: 1.000e-03
# It: 2640, Loss: 6.320e-02, Y0: 7.437, Time: 4.41, Learning Rate: 1.000e-03
# It: 2650, Loss: 3.644e-02, Y0: 7.162, Time: 4.37, Learning Rate: 1.000e-03
# It: 2660, Loss: 3.408e-01, Y0: 6.888, Time: 4.26, Learning Rate: 1.000e-03
# It: 2670, Loss: 1.162e-01, Y0: 6.923, Time: 4.59, Learning Rate: 1.000e-03
# It: 2680, Loss: 7.517e-02, Y0: 6.938, Time: 4.25, Learning Rate: 1.000e-03
# It: 2690, Loss: 5.393e-02, Y0: 6.952, Time: 4.24, Learning Rate: 1.000e-03
# It: 2700, Loss: 5.589e-02, Y0: 7.103, Time: 4.60, Learning Rate: 1.000e-03
# It: 2710, Loss: 4.610e-02, Y0: 7.266, Time: 4.23, Learning Rate: 1.000e-03
# It: 2720, Loss: 3.883e-02, Y0: 7.344, Time: 4.61, Learning Rate: 1.000e-03
# It: 2730, Loss: 3.526e-02, Y0: 7.219, Time: 4.21, Learning Rate: 1.000e-03
# It: 2740, Loss: 3.818e-02, Y0: 7.249, Time: 4.20, Learning Rate: 1.000e-03
# It: 2750, Loss: 3.758e-02, Y0: 7.291, Time: 4.59, Learning Rate: 1.000e-03
# It: 2760, Loss: 7.196e-02, Y0: 7.297, Time: 4.23, Learning Rate: 1.000e-03
# It: 2770, Loss: 1.443e-01, Y0: 6.867, Time: 4.31, Learning Rate: 1.000e-03
# It: 2780, Loss: 9.819e-02, Y0: 6.960, Time: 4.56, Learning Rate: 1.000e-03
# It: 2790, Loss: 5.258e-02, Y0: 7.034, Time: 4.24, Learning Rate: 1.000e-03
# It: 2800, Loss: 4.261e-02, Y0: 7.111, Time: 4.57, Learning Rate: 1.000e-03
# It: 2810, Loss: 4.005e-02, Y0: 7.259, Time: 4.25, Learning Rate: 1.000e-03
# It: 2820, Loss: 3.898e-02, Y0: 7.310, Time: 4.20, Learning Rate: 1.000e-03
# It: 2830, Loss: 3.321e-02, Y0: 7.287, Time: 4.57, Learning Rate: 1.000e-03
# It: 2840, Loss: 3.441e-02, Y0: 7.239, Time: 4.24, Learning Rate: 1.000e-03
# It: 2850, Loss: 3.178e-02, Y0: 7.227, Time: 4.40, Learning Rate: 1.000e-03
# It: 2860, Loss: 6.751e-02, Y0: 7.143, Time: 4.49, Learning Rate: 1.000e-03
# It: 2870, Loss: 6.093e-02, Y0: 7.216, Time: 4.22, Learning Rate: 1.000e-03
# It: 2880, Loss: 4.700e-02, Y0: 7.107, Time: 4.62, Learning Rate: 1.000e-03
# It: 2890, Loss: 3.734e-02, Y0: 7.059, Time: 4.23, Learning Rate: 1.000e-03
# It: 2900, Loss: 3.644e-02, Y0: 7.169, Time: 4.23, Learning Rate: 1.000e-03
# It: 2910, Loss: 4.369e-02, Y0: 7.390, Time: 4.69, Learning Rate: 1.000e-03
# It: 2920, Loss: 3.467e-02, Y0: 7.280, Time: 4.25, Learning Rate: 1.000e-03
# It: 2930, Loss: 4.069e-02, Y0: 7.231, Time: 4.47, Learning Rate: 1.000e-03
# It: 2940, Loss: 1.353e-01, Y0: 6.880, Time: 4.41, Learning Rate: 1.000e-03
# It: 2950, Loss: 6.884e-02, Y0: 7.038, Time: 4.30, Learning Rate: 1.000e-03
# It: 2960, Loss: 5.237e-02, Y0: 7.005, Time: 4.62, Learning Rate: 1.000e-03
# It: 2970, Loss: 4.027e-02, Y0: 7.096, Time: 4.27, Learning Rate: 1.000e-03
# It: 2980, Loss: 3.886e-02, Y0: 7.255, Time: 4.22, Learning Rate: 1.000e-03
# It: 2990, Loss: 4.334e-02, Y0: 7.425, Time: 4.56, Learning Rate: 1.000e-03
# It: 0, Loss: 3.316e-02, Y0: 7.236, Time: 0.43, Learning Rate: 1.000e-04
# It: 10, Loss: 3.253e-02, Y0: 7.228, Time: 4.65, Learning Rate: 1.000e-04
# It: 20, Loss: 3.423e-02, Y0: 7.229, Time: 4.23, Learning Rate: 1.000e-04
# It: 30, Loss: 3.248e-02, Y0: 7.240, Time: 4.26, Learning Rate: 1.000e-04
# It: 40, Loss: 3.233e-02, Y0: 7.253, Time: 4.64, Learning Rate: 1.000e-04
# It: 50, Loss: 3.292e-02, Y0: 7.253, Time: 4.25, Learning Rate: 1.000e-04
# It: 60, Loss: 3.687e-02, Y0: 7.263, Time: 4.42, Learning Rate: 1.000e-04
# It: 70, Loss: 3.142e-02, Y0: 7.263, Time: 4.45, Learning Rate: 1.000e-04
# It: 80, Loss: 3.198e-02, Y0: 7.268, Time: 4.28, Learning Rate: 1.000e-04
# It: 90, Loss: 3.086e-02, Y0: 7.271, Time: 4.53, Learning Rate: 1.000e-04
# It: 100, Loss: 3.149e-02, Y0: 7.270, Time: 4.24, Learning Rate: 1.000e-04
# It: 110, Loss: 3.253e-02, Y0: 7.264, Time: 4.26, Learning Rate: 1.000e-04
# It: 120, Loss: 3.102e-02, Y0: 7.260, Time: 4.60, Learning Rate: 1.000e-04
# It: 130, Loss: 3.388e-02, Y0: 7.269, Time: 4.27, Learning Rate: 1.000e-04
# It: 140, Loss: 3.168e-02, Y0: 7.271, Time: 4.42, Learning Rate: 1.000e-04
# It: 150, Loss: 3.309e-02, Y0: 7.273, Time: 4.31, Learning Rate: 1.000e-04
# It: 160, Loss: 3.170e-02, Y0: 7.272, Time: 4.26, Learning Rate: 1.000e-04
# It: 170, Loss: 3.231e-02, Y0: 7.268, Time: 4.55, Learning Rate: 1.000e-04
# It: 180, Loss: 3.602e-02, Y0: 7.279, Time: 4.26, Learning Rate: 1.000e-04
# It: 190, Loss: 3.133e-02, Y0: 7.289, Time: 4.28, Learning Rate: 1.000e-04
# It: 200, Loss: 3.740e-02, Y0: 7.278, Time: 4.54, Learning Rate: 1.000e-04
# It: 210, Loss: 3.332e-02, Y0: 7.273, Time: 4.20, Learning Rate: 1.000e-04
# It: 220, Loss: 3.445e-02, Y0: 7.273, Time: 4.65, Learning Rate: 1.000e-04
# It: 230, Loss: 3.215e-02, Y0: 7.282, Time: 4.25, Learning Rate: 1.000e-04
# It: 240, Loss: 2.950e-02, Y0: 7.284, Time: 4.24, Learning Rate: 1.000e-04
# It: 250, Loss: 2.954e-02, Y0: 7.276, Time: 4.68, Learning Rate: 1.000e-04
# It: 260, Loss: 3.041e-02, Y0: 7.272, Time: 4.25, Learning Rate: 1.000e-04
# It: 270, Loss: 3.191e-02, Y0: 7.274, Time: 4.33, Learning Rate: 1.000e-04
# It: 280, Loss: 3.118e-02, Y0: 7.269, Time: 4.45, Learning Rate: 1.000e-04
# It: 290, Loss: 3.313e-02, Y0: 7.278, Time: 4.25, Learning Rate: 1.000e-04
# It: 300, Loss: 2.906e-02, Y0: 7.283, Time: 4.63, Learning Rate: 1.000e-04
# It: 310, Loss: 3.084e-02, Y0: 7.281, Time: 4.22, Learning Rate: 1.000e-04
# It: 320, Loss: 3.897e-02, Y0: 7.280, Time: 4.25, Learning Rate: 1.000e-04
# It: 330, Loss: 3.015e-02, Y0: 7.274, Time: 4.66, Learning Rate: 1.000e-04
# It: 340, Loss: 4.338e-02, Y0: 7.279, Time: 4.25, Learning Rate: 1.000e-04
# It: 350, Loss: 3.006e-02, Y0: 7.280, Time: 4.46, Learning Rate: 1.000e-04
# It: 360, Loss: 2.915e-02, Y0: 7.270, Time: 4.33, Learning Rate: 1.000e-04
# It: 370, Loss: 3.111e-02, Y0: 7.272, Time: 4.24, Learning Rate: 1.000e-04
# It: 380, Loss: 3.063e-02, Y0: 7.264, Time: 4.56, Learning Rate: 1.000e-04
# It: 390, Loss: 4.096e-02, Y0: 7.281, Time: 4.29, Learning Rate: 1.000e-04
# It: 400, Loss: 3.233e-02, Y0: 7.274, Time: 4.23, Learning Rate: 1.000e-04
# It: 410, Loss: 3.383e-02, Y0: 7.272, Time: 4.59, Learning Rate: 1.000e-04
# It: 420, Loss: 4.592e-02, Y0: 7.286, Time: 4.21, Learning Rate: 1.000e-04
# It: 430, Loss: 2.947e-02, Y0: 7.279, Time: 4.57, Learning Rate: 1.000e-04
# It: 440, Loss: 4.256e-02, Y0: 7.282, Time: 4.26, Learning Rate: 1.000e-04
# It: 450, Loss: 3.172e-02, Y0: 7.300, Time: 4.24, Learning Rate: 1.000e-04
# It: 460, Loss: 3.072e-02, Y0: 7.312, Time: 4.66, Learning Rate: 1.000e-04
# It: 470, Loss: 3.148e-02, Y0: 7.303, Time: 4.27, Learning Rate: 1.000e-04
# It: 480, Loss: 3.402e-02, Y0: 7.280, Time: 4.32, Learning Rate: 1.000e-04
# It: 490, Loss: 3.100e-02, Y0: 7.272, Time: 4.50, Learning Rate: 1.000e-04
# It: 500, Loss: 3.580e-02, Y0: 7.268, Time: 4.23, Learning Rate: 1.000e-04
# It: 510, Loss: 3.237e-02, Y0: 7.278, Time: 4.60, Learning Rate: 1.000e-04
# It: 520, Loss: 3.653e-02, Y0: 7.282, Time: 4.23, Learning Rate: 1.000e-04
# It: 530, Loss: 3.509e-02, Y0: 7.286, Time: 4.25, Learning Rate: 1.000e-04
# It: 540, Loss: 3.245e-02, Y0: 7.283, Time: 4.65, Learning Rate: 1.000e-04
# It: 550, Loss: 3.296e-02, Y0: 7.293, Time: 4.25, Learning Rate: 1.000e-04
# It: 560, Loss: 3.028e-02, Y0: 7.297, Time: 4.42, Learning Rate: 1.000e-04
# It: 570, Loss: 3.270e-02, Y0: 7.284, Time: 4.37, Learning Rate: 1.000e-04
# It: 580, Loss: 3.114e-02, Y0: 7.272, Time: 4.24, Learning Rate: 1.000e-04
# It: 590, Loss: 3.203e-02, Y0: 7.273, Time: 4.65, Learning Rate: 1.000e-04
# It: 600, Loss: 3.263e-02, Y0: 7.275, Time: 4.20, Learning Rate: 1.000e-04
# It: 610, Loss: 2.727e-02, Y0: 7.270, Time: 4.26, Learning Rate: 1.000e-04
# It: 620, Loss: 3.119e-02, Y0: 7.268, Time: 4.58, Learning Rate: 1.000e-04
# It: 630, Loss: 3.066e-02, Y0: 7.264, Time: 4.25, Learning Rate: 1.000e-04
# It: 640, Loss: 3.057e-02, Y0: 7.265, Time: 4.70, Learning Rate: 1.000e-04
# It: 650, Loss: 3.069e-02, Y0: 7.279, Time: 4.25, Learning Rate: 1.000e-04
# It: 660, Loss: 3.835e-02, Y0: 7.292, Time: 4.27, Learning Rate: 1.000e-04
# It: 670, Loss: 2.877e-02, Y0: 7.295, Time: 4.66, Learning Rate: 1.000e-04
# It: 680, Loss: 3.859e-02, Y0: 7.293, Time: 4.21, Learning Rate: 1.000e-04
# It: 690, Loss: 4.385e-02, Y0: 7.290, Time: 4.36, Learning Rate: 1.000e-04
# It: 700, Loss: 3.049e-02, Y0: 7.280, Time: 4.43, Learning Rate: 1.000e-04
# It: 710, Loss: 3.068e-02, Y0: 7.287, Time: 4.26, Learning Rate: 1.000e-04
# It: 720, Loss: 3.499e-02, Y0: 7.293, Time: 4.63, Learning Rate: 1.000e-04
# It: 730, Loss: 2.854e-02, Y0: 7.288, Time: 4.25, Learning Rate: 1.000e-04
# It: 740, Loss: 3.245e-02, Y0: 7.277, Time: 4.24, Learning Rate: 1.000e-04
# It: 750, Loss: 1.377e-01, Y0: 7.276, Time: 4.66, Learning Rate: 1.000e-04
# It: 760, Loss: 2.974e-02, Y0: 7.275, Time: 4.23, Learning Rate: 1.000e-04
# It: 770, Loss: 3.029e-02, Y0: 7.281, Time: 4.44, Learning Rate: 1.000e-04
# It: 780, Loss: 3.299e-02, Y0: 7.294, Time: 4.33, Learning Rate: 1.000e-04
# It: 790, Loss: 3.707e-02, Y0: 7.284, Time: 4.25, Learning Rate: 1.000e-04
# It: 800, Loss: 3.061e-02, Y0: 7.272, Time: 4.59, Learning Rate: 1.000e-04
# It: 810, Loss: 3.149e-02, Y0: 7.268, Time: 4.24, Learning Rate: 1.000e-04
# It: 820, Loss: 2.887e-02, Y0: 7.263, Time: 4.24, Learning Rate: 1.000e-04
# It: 830, Loss: 2.988e-02, Y0: 7.257, Time: 4.64, Learning Rate: 1.000e-04
# It: 840, Loss: 4.112e-02, Y0: 7.253, Time: 4.25, Learning Rate: 1.000e-04
# It: 850, Loss: 2.956e-02, Y0: 7.262, Time: 4.61, Learning Rate: 1.000e-04
# It: 860, Loss: 2.875e-02, Y0: 7.262, Time: 4.25, Learning Rate: 1.000e-04
# It: 870, Loss: 2.928e-02, Y0: 7.274, Time: 4.26, Learning Rate: 1.000e-04
# It: 880, Loss: 2.990e-02, Y0: 7.283, Time: 4.60, Learning Rate: 1.000e-04
# It: 890, Loss: 3.231e-02, Y0: 7.288, Time: 4.21, Learning Rate: 1.000e-04
# It: 900, Loss: 5.055e-02, Y0: 7.287, Time: 4.35, Learning Rate: 1.000e-04
# It: 910, Loss: 3.222e-02, Y0: 7.276, Time: 4.46, Learning Rate: 1.000e-04
# It: 920, Loss: 3.144e-02, Y0: 7.287, Time: 4.25, Learning Rate: 1.000e-04
# It: 930, Loss: 2.967e-02, Y0: 7.296, Time: 4.66, Learning Rate: 1.000e-04
# It: 940, Loss: 2.981e-02, Y0: 7.291, Time: 4.26, Learning Rate: 1.000e-04
# It: 950, Loss: 3.381e-02, Y0: 7.273, Time: 4.25, Learning Rate: 1.000e-04
# It: 960, Loss: 3.525e-02, Y0: 7.279, Time: 4.65, Learning Rate: 1.000e-04
# It: 970, Loss: 3.220e-02, Y0: 7.275, Time: 4.29, Learning Rate: 1.000e-04
# It: 980, Loss: 3.057e-02, Y0: 7.274, Time: 4.42, Learning Rate: 1.000e-04
# It: 990, Loss: 2.741e-02, Y0: 7.283, Time: 4.38, Learning Rate: 1.000e-04
# It: 1000, Loss: 3.994e-02, Y0: 7.284, Time: 4.26, Learning Rate: 1.000e-04
# It: 1010, Loss: 3.130e-02, Y0: 7.275, Time: 4.55, Learning Rate: 1.000e-04
# It: 1020, Loss: 3.206e-02, Y0: 7.270, Time: 4.25, Learning Rate: 1.000e-04
# It: 1030, Loss: 2.827e-02, Y0: 7.262, Time: 4.26, Learning Rate: 1.000e-04
# It: 1040, Loss: 2.836e-02, Y0: 7.271, Time: 4.59, Learning Rate: 1.000e-04
# It: 1050, Loss: 4.105e-02, Y0: 7.271, Time: 4.22, Learning Rate: 1.000e-04
# It: 1060, Loss: 2.828e-02, Y0: 7.263, Time: 4.62, Learning Rate: 1.000e-04
# It: 1070, Loss: 2.818e-02, Y0: 7.267, Time: 4.21, Learning Rate: 1.000e-04
# It: 1080, Loss: 3.110e-02, Y0: 7.273, Time: 4.22, Learning Rate: 1.000e-04
# It: 1090, Loss: 4.300e-02, Y0: 7.272, Time: 4.59, Learning Rate: 1.000e-04
# It: 1100, Loss: 3.033e-02, Y0: 7.269, Time: 4.26, Learning Rate: 1.000e-04
# It: 1110, Loss: 2.929e-02, Y0: 7.282, Time: 4.34, Learning Rate: 1.000e-04
# It: 1120, Loss: 3.480e-02, Y0: 7.290, Time: 4.46, Learning Rate: 1.000e-04
# It: 1130, Loss: 3.014e-02, Y0: 7.277, Time: 4.22, Learning Rate: 1.000e-04
# It: 1140, Loss: 3.693e-02, Y0: 7.287, Time: 4.66, Learning Rate: 1.000e-04
# It: 1150, Loss: 3.018e-02, Y0: 7.280, Time: 4.21, Learning Rate: 1.000e-04
# It: 1160, Loss: 2.974e-02, Y0: 7.275, Time: 4.22, Learning Rate: 1.000e-04
# It: 1170, Loss: 2.776e-02, Y0: 7.269, Time: 4.64, Learning Rate: 1.000e-04
# It: 1180, Loss: 2.990e-02, Y0: 7.269, Time: 4.23, Learning Rate: 1.000e-04
# It: 1190, Loss: 3.363e-02, Y0: 7.273, Time: 4.39, Learning Rate: 1.000e-04
# It: 1200, Loss: 3.155e-02, Y0: 7.287, Time: 4.37, Learning Rate: 1.000e-04
# It: 1210, Loss: 2.951e-02, Y0: 7.281, Time: 4.23, Learning Rate: 1.000e-04
# It: 1220, Loss: 3.106e-02, Y0: 7.279, Time: 4.67, Learning Rate: 1.000e-04
# It: 1230, Loss: 3.466e-02, Y0: 7.275, Time: 4.24, Learning Rate: 1.000e-04
# It: 1240, Loss: 2.917e-02, Y0: 7.285, Time: 4.27, Learning Rate: 1.000e-04
# It: 1250, Loss: 3.002e-02, Y0: 7.276, Time: 4.64, Learning Rate: 1.000e-04
# It: 1260, Loss: 2.874e-02, Y0: 7.271, Time: 4.24, Learning Rate: 1.000e-04
# It: 1270, Loss: 2.695e-02, Y0: 7.243, Time: 4.56, Learning Rate: 1.000e-04
# It: 1280, Loss: 3.013e-02, Y0: 7.268, Time: 4.23, Learning Rate: 1.000e-04
# It: 1290, Loss: 3.219e-02, Y0: 7.283, Time: 4.24, Learning Rate: 1.000e-04
# It: 1300, Loss: 2.974e-02, Y0: 7.261, Time: 4.61, Learning Rate: 1.000e-04
# It: 1310, Loss: 2.857e-02, Y0: 7.247, Time: 4.28, Learning Rate: 1.000e-04
# It: 1320, Loss: 3.434e-02, Y0: 7.272, Time: 4.36, Learning Rate: 1.000e-04
# It: 1330, Loss: 3.232e-02, Y0: 7.277, Time: 4.55, Learning Rate: 1.000e-04
# It: 1340, Loss: 3.065e-02, Y0: 7.286, Time: 4.24, Learning Rate: 1.000e-04
# It: 1350, Loss: 3.141e-02, Y0: 7.276, Time: 4.55, Learning Rate: 1.000e-04
# It: 1360, Loss: 3.028e-02, Y0: 7.281, Time: 4.22, Learning Rate: 1.000e-04
# It: 1370, Loss: 3.150e-02, Y0: 7.267, Time: 4.26, Learning Rate: 1.000e-04
# It: 1380, Loss: 4.421e-02, Y0: 7.275, Time: 4.63, Learning Rate: 1.000e-04
# It: 1390, Loss: 3.028e-02, Y0: 7.289, Time: 4.25, Learning Rate: 1.000e-04
# It: 1400, Loss: 3.429e-02, Y0: 7.278, Time: 4.41, Learning Rate: 1.000e-04
# It: 1410, Loss: 3.100e-02, Y0: 7.267, Time: 4.38, Learning Rate: 1.000e-04
# It: 1420, Loss: 2.763e-02, Y0: 7.268, Time: 4.24, Learning Rate: 1.000e-04
# It: 1430, Loss: 2.803e-02, Y0: 7.274, Time: 4.63, Learning Rate: 1.000e-04
# It: 1440, Loss: 2.931e-02, Y0: 7.273, Time: 4.23, Learning Rate: 1.000e-04
# It: 1450, Loss: 3.816e-02, Y0: 7.268, Time: 4.22, Learning Rate: 1.000e-04
# It: 1460, Loss: 3.392e-02, Y0: 7.267, Time: 4.60, Learning Rate: 1.000e-04
# It: 1470, Loss: 2.896e-02, Y0: 7.272, Time: 4.23, Learning Rate: 1.000e-04
# It: 1480, Loss: 2.812e-02, Y0: 7.267, Time: 4.50, Learning Rate: 1.000e-04
# It: 1490, Loss: 3.001e-02, Y0: 7.268, Time: 4.25, Learning Rate: 1.000e-04
# It: 1500, Loss: 2.753e-02, Y0: 7.272, Time: 4.22, Learning Rate: 1.000e-04
# It: 1510, Loss: 2.950e-02, Y0: 7.273, Time: 4.65, Learning Rate: 1.000e-04
# It: 1520, Loss: 3.101e-02, Y0: 7.274, Time: 4.22, Learning Rate: 1.000e-04
# It: 1530, Loss: 3.559e-02, Y0: 7.293, Time: 4.22, Learning Rate: 1.000e-04
# It: 1540, Loss: 2.905e-02, Y0: 7.289, Time: 4.56, Learning Rate: 1.000e-04
# It: 1550, Loss: 2.802e-02, Y0: 7.282, Time: 4.22, Learning Rate: 1.000e-04
# It: 1560, Loss: 3.055e-02, Y0: 7.270, Time: 4.63, Learning Rate: 1.000e-04
# It: 1570, Loss: 3.035e-02, Y0: 7.273, Time: 4.27, Learning Rate: 1.000e-04
# It: 1580, Loss: 3.191e-02, Y0: 7.270, Time: 4.21, Learning Rate: 1.000e-04
# It: 1590, Loss: 2.690e-02, Y0: 7.272, Time: 4.64, Learning Rate: 1.000e-04
# It: 1600, Loss: 2.900e-02, Y0: 7.274, Time: 4.24, Learning Rate: 1.000e-04
# It: 1610, Loss: 2.648e-02, Y0: 7.271, Time: 4.32, Learning Rate: 1.000e-04
# It: 1620, Loss: 2.659e-02, Y0: 7.251, Time: 4.46, Learning Rate: 1.000e-04
# It: 1630, Loss: 3.117e-02, Y0: 7.280, Time: 4.24, Learning Rate: 1.000e-04
# It: 1640, Loss: 2.640e-02, Y0: 7.298, Time: 4.65, Learning Rate: 1.000e-04
# It: 1650, Loss: 2.667e-02, Y0: 7.286, Time: 4.26, Learning Rate: 1.000e-04
# It: 1660, Loss: 2.616e-02, Y0: 7.276, Time: 4.24, Learning Rate: 1.000e-04
# It: 1670, Loss: 3.715e-02, Y0: 7.271, Time: 4.67, Learning Rate: 1.000e-04
# It: 1680, Loss: 2.722e-02, Y0: 7.266, Time: 4.24, Learning Rate: 1.000e-04
# It: 1690, Loss: 2.867e-02, Y0: 7.294, Time: 4.42, Learning Rate: 1.000e-04
# It: 1700, Loss: 2.614e-02, Y0: 7.295, Time: 4.39, Learning Rate: 1.000e-04
# It: 1710, Loss: 2.774e-02, Y0: 7.279, Time: 4.24, Learning Rate: 1.000e-04
# It: 1720, Loss: 3.247e-02, Y0: 7.261, Time: 4.56, Learning Rate: 1.000e-04
# It: 1730, Loss: 2.657e-02, Y0: 7.270, Time: 4.23, Learning Rate: 1.000e-04
# It: 1740, Loss: 2.729e-02, Y0: 7.261, Time: 4.26, Learning Rate: 1.000e-04
# It: 1750, Loss: 2.941e-02, Y0: 7.268, Time: 4.64, Learning Rate: 1.000e-04
# It: 1760, Loss: 2.744e-02, Y0: 7.267, Time: 4.22, Learning Rate: 1.000e-04
# It: 1770, Loss: 2.805e-02, Y0: 7.257, Time: 4.63, Learning Rate: 1.000e-04
# It: 1780, Loss: 2.837e-02, Y0: 7.271, Time: 4.22, Learning Rate: 1.000e-04
# It: 1790, Loss: 2.749e-02, Y0: 7.289, Time: 4.27, Learning Rate: 1.000e-04
# It: 1800, Loss: 2.818e-02, Y0: 7.282, Time: 4.58, Learning Rate: 1.000e-04
# It: 1810, Loss: 2.699e-02, Y0: 7.264, Time: 4.25, Learning Rate: 1.000e-04
# It: 1820, Loss: 3.087e-02, Y0: 7.269, Time: 4.33, Learning Rate: 1.000e-04
# It: 1830, Loss: 2.852e-02, Y0: 7.268, Time: 4.46, Learning Rate: 1.000e-04
# It: 1840, Loss: 3.089e-02, Y0: 7.240, Time: 4.27, Learning Rate: 1.000e-04
# It: 1850, Loss: 2.918e-02, Y0: 7.266, Time: 4.63, Learning Rate: 1.000e-04
# It: 1860, Loss: 3.127e-02, Y0: 7.304, Time: 4.24, Learning Rate: 1.000e-04
# It: 1870, Loss: 2.856e-02, Y0: 7.273, Time: 4.23, Learning Rate: 1.000e-04
# It: 1880, Loss: 2.717e-02, Y0: 7.252, Time: 4.62, Learning Rate: 1.000e-04
# It: 1890, Loss: 3.007e-02, Y0: 7.265, Time: 4.24, Learning Rate: 1.000e-04
# It: 1900, Loss: 2.718e-02, Y0: 7.261, Time: 4.43, Learning Rate: 1.000e-04
# It: 1910, Loss: 2.816e-02, Y0: 7.265, Time: 4.39, Learning Rate: 1.000e-04
# It: 1920, Loss: 2.816e-02, Y0: 7.293, Time: 4.32, Learning Rate: 1.000e-04
# It: 1930, Loss: 2.720e-02, Y0: 7.272, Time: 4.56, Learning Rate: 1.000e-04
# It: 1940, Loss: 2.876e-02, Y0: 7.249, Time: 4.25, Learning Rate: 1.000e-04
# It: 1950, Loss: 2.757e-02, Y0: 7.256, Time: 4.25, Learning Rate: 1.000e-04
# It: 1960, Loss: 2.655e-02, Y0: 7.256, Time: 4.61, Learning Rate: 1.000e-04
# It: 1970, Loss: 3.353e-02, Y0: 7.260, Time: 4.20, Learning Rate: 1.000e-04
# It: 1980, Loss: 2.793e-02, Y0: 7.284, Time: 4.58, Learning Rate: 1.000e-04
# It: 1990, Loss: 3.265e-02, Y0: 7.268, Time: 4.24, Learning Rate: 1.000e-04
# It: 2000, Loss: 2.816e-02, Y0: 7.259, Time: 4.27, Learning Rate: 1.000e-04
# It: 2010, Loss: 6.559e-02, Y0: 7.273, Time: 4.57, Learning Rate: 1.000e-04
# It: 2020, Loss: 3.022e-02, Y0: 7.301, Time: 4.27, Learning Rate: 1.000e-04
# It: 2030, Loss: 2.724e-02, Y0: 7.315, Time: 4.33, Learning Rate: 1.000e-04
# It: 2040, Loss: 2.785e-02, Y0: 7.264, Time: 4.49, Learning Rate: 1.000e-04
# It: 2050, Loss: 2.815e-02, Y0: 7.249, Time: 4.24, Learning Rate: 1.000e-04
# It: 2060, Loss: 2.862e-02, Y0: 7.244, Time: 4.68, Learning Rate: 1.000e-04
# It: 2070, Loss: 2.730e-02, Y0: 7.257, Time: 4.24, Learning Rate: 1.000e-04
# It: 2080, Loss: 2.780e-02, Y0: 7.265, Time: 4.22, Learning Rate: 1.000e-04
# It: 2090, Loss: 3.076e-02, Y0: 7.262, Time: 4.61, Learning Rate: 1.000e-04
# It: 2100, Loss: 2.622e-02, Y0: 7.292, Time: 4.26, Learning Rate: 1.000e-04
# It: 2110, Loss: 3.046e-02, Y0: 7.270, Time: 4.41, Learning Rate: 1.000e-04
# It: 2120, Loss: 3.065e-02, Y0: 7.249, Time: 4.37, Learning Rate: 1.000e-04
# It: 2130, Loss: 2.787e-02, Y0: 7.269, Time: 4.25, Learning Rate: 1.000e-04
# It: 2140, Loss: 2.637e-02, Y0: 7.276, Time: 4.63, Learning Rate: 1.000e-04
# It: 2150, Loss: 2.574e-02, Y0: 7.257, Time: 4.23, Learning Rate: 1.000e-04
# It: 2160, Loss: 2.688e-02, Y0: 7.250, Time: 4.21, Learning Rate: 1.000e-04
# It: 2170, Loss: 2.802e-02, Y0: 7.276, Time: 4.60, Learning Rate: 1.000e-04
# It: 2180, Loss: 2.891e-02, Y0: 7.265, Time: 4.20, Learning Rate: 1.000e-04
# It: 2190, Loss: 2.912e-02, Y0: 7.274, Time: 4.56, Learning Rate: 1.000e-04
# It: 2200, Loss: 2.513e-02, Y0: 7.263, Time: 4.23, Learning Rate: 1.000e-04
# It: 2210, Loss: 2.665e-02, Y0: 7.252, Time: 4.28, Learning Rate: 1.000e-04
# It: 2220, Loss: 2.660e-02, Y0: 7.252, Time: 4.66, Learning Rate: 1.000e-04
# It: 2230, Loss: 3.110e-02, Y0: 7.274, Time: 4.23, Learning Rate: 1.000e-04
# It: 2240, Loss: 3.230e-02, Y0: 7.277, Time: 4.23, Learning Rate: 1.000e-04
# It: 2250, Loss: 2.611e-02, Y0: 7.284, Time: 4.54, Learning Rate: 1.000e-04
# It: 2260, Loss: 2.829e-02, Y0: 7.243, Time: 4.25, Learning Rate: 1.000e-04
# It: 2270, Loss: 2.624e-02, Y0: 7.234, Time: 4.58, Learning Rate: 1.000e-04
# It: 2280, Loss: 2.704e-02, Y0: 7.240, Time: 4.26, Learning Rate: 1.000e-04
# It: 2290, Loss: 2.659e-02, Y0: 7.267, Time: 4.21, Learning Rate: 1.000e-04
# It: 2300, Loss: 3.191e-02, Y0: 7.270, Time: 4.64, Learning Rate: 1.000e-04
# It: 2310, Loss: 2.971e-02, Y0: 7.280, Time: 4.24, Learning Rate: 1.000e-04
# It: 2320, Loss: 2.719e-02, Y0: 7.264, Time: 4.29, Learning Rate: 1.000e-04
# It: 2330, Loss: 2.555e-02, Y0: 7.276, Time: 4.47, Learning Rate: 1.000e-04
# It: 2340, Loss: 2.912e-02, Y0: 7.253, Time: 4.26, Learning Rate: 1.000e-04
# It: 2350, Loss: 2.735e-02, Y0: 7.293, Time: 4.61, Learning Rate: 1.000e-04
# It: 2360, Loss: 2.894e-02, Y0: 7.273, Time: 4.25, Learning Rate: 1.000e-04
# It: 2370, Loss: 2.743e-02, Y0: 7.267, Time: 4.25, Learning Rate: 1.000e-04
# It: 2380, Loss: 3.189e-02, Y0: 7.264, Time: 4.62, Learning Rate: 1.000e-04
# It: 2390, Loss: 2.670e-02, Y0: 7.261, Time: 4.25, Learning Rate: 1.000e-04
# It: 2400, Loss: 2.843e-02, Y0: 7.242, Time: 4.46, Learning Rate: 1.000e-04
# It: 2410, Loss: 2.710e-02, Y0: 7.292, Time: 4.34, Learning Rate: 1.000e-04
# It: 2420, Loss: 2.912e-02, Y0: 7.281, Time: 4.24, Learning Rate: 1.000e-04
# It: 2430, Loss: 2.692e-02, Y0: 7.246, Time: 4.57, Learning Rate: 1.000e-04
# It: 2440, Loss: 2.772e-02, Y0: 7.269, Time: 4.23, Learning Rate: 1.000e-04
# It: 2450, Loss: 2.596e-02, Y0: 7.281, Time: 4.25, Learning Rate: 1.000e-04
# It: 2460, Loss: 3.090e-02, Y0: 7.262, Time: 4.61, Learning Rate: 1.000e-04
# It: 2470, Loss: 3.708e-02, Y0: 7.275, Time: 4.24, Learning Rate: 1.000e-04
# It: 2480, Loss: 2.716e-02, Y0: 7.290, Time: 4.62, Learning Rate: 1.000e-04
# It: 2490, Loss: 2.442e-02, Y0: 7.253, Time: 4.28, Learning Rate: 1.000e-04
# It: 2500, Loss: 2.846e-02, Y0: 7.234, Time: 4.24, Learning Rate: 1.000e-04
# It: 2510, Loss: 2.510e-02, Y0: 7.244, Time: 4.57, Learning Rate: 1.000e-04
# It: 2520, Loss: 2.879e-02, Y0: 7.263, Time: 4.27, Learning Rate: 1.000e-04
# It: 2530, Loss: 2.567e-02, Y0: 7.290, Time: 4.34, Learning Rate: 1.000e-04
# It: 2540, Loss: 2.564e-02, Y0: 7.259, Time: 4.45, Learning Rate: 1.000e-04
# It: 2550, Loss: 2.530e-02, Y0: 7.257, Time: 4.22, Learning Rate: 1.000e-04
# It: 2560, Loss: 2.601e-02, Y0: 7.275, Time: 4.67, Learning Rate: 1.000e-04
# It: 2570, Loss: 3.139e-02, Y0: 7.259, Time: 4.26, Learning Rate: 1.000e-04
# It: 2580, Loss: 2.517e-02, Y0: 7.249, Time: 4.22, Learning Rate: 1.000e-04
# It: 2590, Loss: 2.755e-02, Y0: 7.262, Time: 4.58, Learning Rate: 1.000e-04
# It: 2600, Loss: 3.421e-02, Y0: 7.260, Time: 4.22, Learning Rate: 1.000e-04
# It: 2610, Loss: 2.613e-02, Y0: 7.270, Time: 4.40, Learning Rate: 1.000e-04
# It: 2620, Loss: 2.611e-02, Y0: 7.260, Time: 4.38, Learning Rate: 1.000e-04
# It: 2630, Loss: 2.827e-02, Y0: 7.266, Time: 4.28, Learning Rate: 1.000e-04
# It: 2640, Loss: 2.743e-02, Y0: 7.255, Time: 4.76, Learning Rate: 1.000e-04
# It: 2650, Loss: 2.710e-02, Y0: 7.276, Time: 4.33, Learning Rate: 1.000e-04
# It: 2660, Loss: 2.746e-02, Y0: 7.305, Time: 4.42, Learning Rate: 1.000e-04
# It: 2670, Loss: 2.767e-02, Y0: 7.239, Time: 4.75, Learning Rate: 1.000e-04
# It: 2680, Loss: 2.599e-02, Y0: 7.223, Time: 4.32, Learning Rate: 1.000e-04
# It: 2690, Loss: 2.463e-02, Y0: 7.258, Time: 4.76, Learning Rate: 1.000e-04
# It: 2700, Loss: 2.458e-02, Y0: 7.262, Time: 4.28, Learning Rate: 1.000e-04
# It: 2710, Loss: 2.754e-02, Y0: 7.283, Time: 4.31, Learning Rate: 1.000e-04
# It: 2720, Loss: 2.597e-02, Y0: 7.273, Time: 4.58, Learning Rate: 1.000e-04
# It: 2730, Loss: 2.487e-02, Y0: 7.244, Time: 4.24, Learning Rate: 1.000e-04
# It: 2740, Loss: 2.776e-02, Y0: 7.236, Time: 4.47, Learning Rate: 1.000e-04
# It: 2750, Loss: 2.654e-02, Y0: 7.245, Time: 4.36, Learning Rate: 1.000e-04
# It: 2760, Loss: 2.585e-02, Y0: 7.276, Time: 4.25, Learning Rate: 1.000e-04
# It: 2770, Loss: 2.632e-02, Y0: 7.267, Time: 4.61, Learning Rate: 1.000e-04
# It: 2780, Loss: 2.639e-02, Y0: 7.256, Time: 4.24, Learning Rate: 1.000e-04
# It: 2790, Loss: 2.537e-02, Y0: 7.251, Time: 4.26, Learning Rate: 1.000e-04
# It: 2800, Loss: 2.913e-02, Y0: 7.241, Time: 4.63, Learning Rate: 1.000e-04
# It: 2810, Loss: 2.537e-02, Y0: 7.244, Time: 4.23, Learning Rate: 1.000e-04
# It: 2820, Loss: 2.620e-02, Y0: 7.257, Time: 4.53, Learning Rate: 1.000e-04
# It: 2830, Loss: 2.635e-02, Y0: 7.264, Time: 4.26, Learning Rate: 1.000e-04
# It: 2840, Loss: 2.668e-02, Y0: 7.251, Time: 4.24, Learning Rate: 1.000e-04
# It: 2850, Loss: 2.397e-02, Y0: 7.268, Time: 4.64, Learning Rate: 1.000e-04
# It: 2860, Loss: 2.392e-02, Y0: 7.271, Time: 4.25, Learning Rate: 1.000e-04
# It: 2870, Loss: 3.744e-02, Y0: 7.288, Time: 4.28, Learning Rate: 1.000e-04
# It: 2880, Loss: 2.679e-02, Y0: 7.285, Time: 4.54, Learning Rate: 1.000e-04
# It: 2890, Loss: 3.195e-02, Y0: 7.258, Time: 4.30, Learning Rate: 1.000e-04
# It: 2900, Loss: 2.653e-02, Y0: 7.236, Time: 4.61, Learning Rate: 1.000e-04
# ...
# It: 880, Loss: 2.046e-02, Y0: 7.244, Time: 4.68, Learning Rate: 1.000e-06
# It: 890, Loss: 2.173e-02, Y0: 7.244, Time: 4.29, Learning Rate: 1.000e-06
# It: 900, Loss: 2.675e-02, Y0: 7.245, Time: 4.24, Learning Rate: 1.000e-06
# It: 910, Loss: 1.990e-02, Y0: 7.245, Time: 4.60, Learning Rate: 1.000e-06
# It: 920, Loss: 2.025e-02, Y0: 7.245, Time: 4.25, Learning Rate: 1.000e-06
# It: 930, Loss: 1.914e-02, Y0: 7.244, Time: 4.45, Learning Rate: 1.000e-06
# It: 940, Loss: 2.042e-02, Y0: 7.241, Time: 4.33, Learning Rate: 1.000e-06
# It: 950, Loss: 2.130e-02, Y0: 7.241, Time: 4.26, Learning Rate: 1.000e-06
# It: 960, Loss: 2.072e-02, Y0: 7.241, Time: 4.59, Learning Rate: 1.000e-06
# It: 970, Loss: 2.058e-02, Y0: 7.244, Time: 4.23, Learning Rate: 1.000e-06
# It: 980, Loss: 2.176e-02, Y0: 7.244, Time: 4.27, Learning Rate: 1.000e-06
# It: 990, Loss: 1.983e-02, Y0: 7.245, Time: 4.56, Learning Rate: 1.000e-06
# It: 1000, Loss: 2.160e-02, Y0: 7.245, Time: 4.22, Learning Rate: 1.000e-06
# It: 1010, Loss: 2.483e-02, Y0: 7.245, Time: 4.60, Learning Rate: 1.000e-06
# It: 1020, Loss: 1.980e-02, Y0: 7.246, Time: 4.26, Learning Rate: 1.000e-06
# It: 1030, Loss: 2.116e-02, Y0: 7.248, Time: 4.23, Learning Rate: 1.000e-06
# It: 1040, Loss: 2.226e-02, Y0: 7.252, Time: 4.63, Learning Rate: 1.000e-06
# It: 1050, Loss: 2.285e-02, Y0: 7.251, Time: 4.25, Learning Rate: 1.000e-06
# It: 1060, Loss: 1.952e-02, Y0: 7.250, Time: 4.38, Learning Rate: 1.000e-06
# It: 1070, Loss: 2.104e-02, Y0: 7.248, Time: 4.46, Learning Rate: 1.000e-06
# It: 1080, Loss: 2.099e-02, Y0: 7.247, Time: 4.21, Learning Rate: 1.000e-06
# It: 1090, Loss: 1.999e-02, Y0: 7.246, Time: 4.54, Learning Rate: 1.000e-06
# It: 1100, Loss: 2.034e-02, Y0: 7.247, Time: 4.22, Learning Rate: 1.000e-06
# It: 1110, Loss: 2.164e-02, Y0: 7.247, Time: 4.26, Learning Rate: 1.000e-06
# It: 1120, Loss: 2.712e-02, Y0: 7.247, Time: 4.60, Learning Rate: 1.000e-06
# It: 1130, Loss: 1.990e-02, Y0: 7.248, Time: 4.25, Learning Rate: 1.000e-06
# It: 1140, Loss: 2.086e-02, Y0: 7.248, Time: 4.45, Learning Rate: 1.000e-06
# It: 1150, Loss: 2.051e-02, Y0: 7.249, Time: 4.33, Learning Rate: 1.000e-06
# It: 1160, Loss: 2.063e-02, Y0: 7.248, Time: 4.24, Learning Rate: 1.000e-06
# It: 1170, Loss: 2.045e-02, Y0: 7.248, Time: 4.60, Learning Rate: 1.000e-06
# It: 1180, Loss: 1.966e-02, Y0: 7.250, Time: 4.25, Learning Rate: 1.000e-06
# It: 1190, Loss: 2.098e-02, Y0: 7.248, Time: 4.23, Learning Rate: 1.000e-06
# It: 1200, Loss: 2.228e-02, Y0: 7.249, Time: 4.51, Learning Rate: 1.000e-06
# It: 1210, Loss: 2.165e-02, Y0: 7.251, Time: 4.21, Learning Rate: 1.000e-06
# It: 1220, Loss: 1.852e-02, Y0: 7.249, Time: 4.61, Learning Rate: 1.000e-06
# It: 1230, Loss: 1.968e-02, Y0: 7.247, Time: 4.23, Learning Rate: 1.000e-06
# It: 1240, Loss: 2.075e-02, Y0: 7.246, Time: 4.21, Learning Rate: 1.000e-06
# It: 1250, Loss: 2.365e-02, Y0: 7.247, Time: 4.64, Learning Rate: 1.000e-06
# It: 1260, Loss: 1.992e-02, Y0: 7.247, Time: 4.25, Learning Rate: 1.000e-06
# It: 1270, Loss: 1.958e-02, Y0: 7.248, Time: 4.36, Learning Rate: 1.000e-06
# It: 1280, Loss: 1.921e-02, Y0: 7.249, Time: 4.43, Learning Rate: 1.000e-06
# It: 1290, Loss: 2.029e-02, Y0: 7.249, Time: 4.24, Learning Rate: 1.000e-06
# It: 1300, Loss: 2.010e-02, Y0: 7.245, Time: 4.55, Learning Rate: 1.000e-06
# It: 1310, Loss: 2.633e-02, Y0: 7.245, Time: 4.24, Learning Rate: 1.000e-06
# It: 1320, Loss: 1.928e-02, Y0: 7.246, Time: 4.23, Learning Rate: 1.000e-06
# It: 1330, Loss: 2.211e-02, Y0: 7.245, Time: 4.54, Learning Rate: 1.000e-06
# It: 1340, Loss: 2.066e-02, Y0: 7.245, Time: 4.22, Learning Rate: 1.000e-06
# It: 1350, Loss: 2.102e-02, Y0: 7.245, Time: 4.49, Learning Rate: 1.000e-06
# It: 1360, Loss: 2.049e-02, Y0: 7.244, Time: 4.33, Learning Rate: 1.000e-06
# It: 1370, Loss: 2.052e-02, Y0: 7.245, Time: 4.25, Learning Rate: 1.000e-06
# It: 1380, Loss: 1.976e-02, Y0: 7.246, Time: 4.66, Learning Rate: 1.000e-06
# It: 1390, Loss: 1.845e-02, Y0: 7.243, Time: 4.25, Learning Rate: 1.000e-06
# It: 1400, Loss: 2.237e-02, Y0: 7.243, Time: 4.21, Learning Rate: 1.000e-06
# It: 1410, Loss: 2.065e-02, Y0: 7.243, Time: 4.50, Learning Rate: 1.000e-06
# It: 1420, Loss: 1.967e-02, Y0: 7.243, Time: 4.27, Learning Rate: 1.000e-06
# It: 1430, Loss: 2.218e-02, Y0: 7.242, Time: 4.55, Learning Rate: 1.000e-06
# It: 1440, Loss: 3.202e-02, Y0: 7.242, Time: 4.24, Learning Rate: 1.000e-06
# It: 1450, Loss: 2.303e-02, Y0: 7.244, Time: 4.21, Learning Rate: 1.000e-06
# It: 1460, Loss: 2.021e-02, Y0: 7.249, Time: 4.62, Learning Rate: 1.000e-06
# It: 1470, Loss: 1.964e-02, Y0: 7.247, Time: 4.22, Learning Rate: 1.000e-06
# It: 1480, Loss: 2.013e-02, Y0: 7.248, Time: 4.38, Learning Rate: 1.000e-06
# It: 1490, Loss: 1.941e-02, Y0: 7.248, Time: 4.42, Learning Rate: 1.000e-06
# It: 1500, Loss: 2.139e-02, Y0: 7.244, Time: 4.24, Learning Rate: 1.000e-06
# It: 1510, Loss: 1.996e-02, Y0: 7.245, Time: 4.55, Learning Rate: 1.000e-06
# It: 1520, Loss: 2.791e-02, Y0: 7.245, Time: 4.24, Learning Rate: 1.000e-06
# It: 1530, Loss: 2.370e-02, Y0: 7.246, Time: 4.25, Learning Rate: 1.000e-06
# It: 1540, Loss: 1.957e-02, Y0: 7.247, Time: 4.58, Learning Rate: 1.000e-06
# It: 1550, Loss: 1.920e-02, Y0: 7.245, Time: 4.26, Learning Rate: 1.000e-06
# It: 1560, Loss: 1.942e-02, Y0: 7.244, Time: 4.48, Learning Rate: 1.000e-06
# It: 1570, Loss: 2.049e-02, Y0: 7.245, Time: 4.29, Learning Rate: 1.000e-06
# It: 1580, Loss: 2.024e-02, Y0: 7.245, Time: 4.23, Learning Rate: 1.000e-06
# It: 1590, Loss: 2.055e-02, Y0: 7.241, Time: 4.54, Learning Rate: 1.000e-06
# It: 1600, Loss: 1.956e-02, Y0: 7.241, Time: 4.22, Learning Rate: 1.000e-06
# It: 1610, Loss: 2.158e-02, Y0: 7.241, Time: 4.21, Learning Rate: 1.000e-06
# It: 1620, Loss: 2.212e-02, Y0: 7.244, Time: 4.58, Learning Rate: 1.000e-06
# It: 1630, Loss: 2.106e-02, Y0: 7.246, Time: 4.25, Learning Rate: 1.000e-06
# It: 1640, Loss: 1.975e-02, Y0: 7.248, Time: 4.60, Learning Rate: 1.000e-06
# It: 1650, Loss: 2.349e-02, Y0: 7.248, Time: 4.26, Learning Rate: 1.000e-06
# It: 1660, Loss: 1.999e-02, Y0: 7.246, Time: 4.24, Learning Rate: 1.000e-06
# It: 1670, Loss: 1.965e-02, Y0: 7.247, Time: 4.64, Learning Rate: 1.000e-06
# It: 1680, Loss: 2.308e-02, Y0: 7.243, Time: 4.25, Learning Rate: 1.000e-06
# It: 1690, Loss: 2.120e-02, Y0: 7.238, Time: 4.40, Learning Rate: 1.000e-06
# It: 1700, Loss: 2.116e-02, Y0: 7.240, Time: 4.40, Learning Rate: 1.000e-06
# It: 1710, Loss: 2.068e-02, Y0: 7.244, Time: 4.24, Learning Rate: 1.000e-06
# It: 1720, Loss: 2.147e-02, Y0: 7.246, Time: 4.52, Learning Rate: 1.000e-06
# It: 1730, Loss: 1.934e-02, Y0: 7.246, Time: 4.22, Learning Rate: 1.000e-06
# It: 1740, Loss: 2.150e-02, Y0: 7.245, Time: 4.22, Learning Rate: 1.000e-06
# It: 1750, Loss: 1.982e-02, Y0: 7.247, Time: 4.65, Learning Rate: 1.000e-06
# It: 1760, Loss: 2.284e-02, Y0: 7.249, Time: 4.22, Learning Rate: 1.000e-06
# It: 1770, Loss: 1.906e-02, Y0: 7.249, Time: 4.51, Learning Rate: 1.000e-06
# It: 1780, Loss: 2.172e-02, Y0: 7.247, Time: 4.34, Learning Rate: 1.000e-06
# It: 1790, Loss: 2.174e-02, Y0: 7.245, Time: 4.24, Learning Rate: 1.000e-06
# It: 1800, Loss: 2.121e-02, Y0: 7.245, Time: 4.58, Learning Rate: 1.000e-06
# It: 1810, Loss: 2.040e-02, Y0: 7.246, Time: 4.23, Learning Rate: 1.000e-06
# It: 1820, Loss: 2.019e-02, Y0: 7.245, Time: 4.26, Learning Rate: 1.000e-06
# It: 1830, Loss: 2.079e-02, Y0: 7.245, Time: 4.50, Learning Rate: 1.000e-06
# It: 1840, Loss: 2.018e-02, Y0: 7.244, Time: 4.23, Learning Rate: 1.000e-06
# It: 1850, Loss: 1.924e-02, Y0: 7.243, Time: 4.56, Learning Rate: 1.000e-06
# It: 1860, Loss: 2.251e-02, Y0: 7.241, Time: 4.24, Learning Rate: 1.000e-06
# It: 1870, Loss: 2.104e-02, Y0: 7.240, Time: 4.24, Learning Rate: 1.000e-06
# It: 1880, Loss: 2.129e-02, Y0: 7.241, Time: 4.62, Learning Rate: 1.000e-06
# It: 1890, Loss: 2.024e-02, Y0: 7.240, Time: 4.24, Learning Rate: 1.000e-06
# It: 1900, Loss: 2.057e-02, Y0: 7.243, Time: 4.33, Learning Rate: 1.000e-06
# It: 1910, Loss: 2.006e-02, Y0: 7.244, Time: 4.45, Learning Rate: 1.000e-06
# It: 1920, Loss: 2.108e-02, Y0: 7.245, Time: 4.22, Learning Rate: 1.000e-06
# It: 1930, Loss: 2.046e-02, Y0: 7.243, Time: 4.55, Learning Rate: 1.000e-06
# It: 1940, Loss: 2.111e-02, Y0: 7.243, Time: 4.22, Learning Rate: 1.000e-06
# It: 1950, Loss: 1.911e-02, Y0: 7.241, Time: 4.22, Learning Rate: 1.000e-06
# It: 1960, Loss: 2.159e-02, Y0: 7.242, Time: 4.65, Learning Rate: 1.000e-06
# It: 1970, Loss: 2.368e-02, Y0: 7.238, Time: 4.22, Learning Rate: 1.000e-06
# It: 1980, Loss: 2.056e-02, Y0: 7.238, Time: 4.37, Learning Rate: 1.000e-06
# It: 1990, Loss: 1.914e-02, Y0: 7.241, Time: 4.33, Learning Rate: 1.000e-06
# It: 2000, Loss: 2.071e-02, Y0: 7.243, Time: 4.23, Learning Rate: 1.000e-06
# It: 2010, Loss: 2.025e-02, Y0: 7.245, Time: 4.59, Learning Rate: 1.000e-06
# It: 2020, Loss: 2.656e-02, Y0: 7.243, Time: 4.26, Learning Rate: 1.000e-06
# It: 2030, Loss: 2.034e-02, Y0: 7.243, Time: 4.25, Learning Rate: 1.000e-06
# It: 2040, Loss: 2.014e-02, Y0: 7.246, Time: 4.60, Learning Rate: 1.000e-06
# It: 2050, Loss: 1.996e-02, Y0: 7.247, Time: 4.24, Learning Rate: 1.000e-06
# It: 2060, Loss: 4.055e-02, Y0: 7.246, Time: 4.62, Learning Rate: 1.000e-06
# It: 2070, Loss: 2.043e-02, Y0: 7.245, Time: 4.22, Learning Rate: 1.000e-06
# It: 2080, Loss: 1.997e-02, Y0: 7.247, Time: 4.24, Learning Rate: 1.000e-06
# It: 2090, Loss: 2.074e-02, Y0: 7.247, Time: 4.66, Learning Rate: 1.000e-06
# It: 2100, Loss: 2.345e-02, Y0: 7.247, Time: 4.22, Learning Rate: 1.000e-06
# It: 2110, Loss: 1.946e-02, Y0: 7.246, Time: 4.33, Learning Rate: 1.000e-06
# It: 2120, Loss: 2.050e-02, Y0: 7.242, Time: 4.39, Learning Rate: 1.000e-06
# It: 2130, Loss: 2.161e-02, Y0: 7.241, Time: 4.23, Learning Rate: 1.000e-06
# It: 2140, Loss: 2.162e-02, Y0: 7.244, Time: 4.69, Learning Rate: 1.000e-06
# It: 2150, Loss: 2.070e-02, Y0: 7.246, Time: 4.24, Learning Rate: 1.000e-06
# It: 2160, Loss: 1.964e-02, Y0: 7.247, Time: 4.23, Learning Rate: 1.000e-06
# It: 2170, Loss: 1.905e-02, Y0: 7.248, Time: 4.66, Learning Rate: 1.000e-06
# It: 2180, Loss: 2.112e-02, Y0: 7.249, Time: 4.22, Learning Rate: 1.000e-06
# It: 2190, Loss: 2.155e-02, Y0: 7.249, Time: 4.45, Learning Rate: 1.000e-06
# It: 2200, Loss: 1.994e-02, Y0: 7.248, Time: 4.31, Learning Rate: 1.000e-06
# It: 2210, Loss: 2.094e-02, Y0: 7.248, Time: 4.24, Learning Rate: 1.000e-06
# It: 2220, Loss: 2.048e-02, Y0: 7.248, Time: 4.56, Learning Rate: 1.000e-06
# It: 2230, Loss: 1.968e-02, Y0: 7.249, Time: 4.24, Learning Rate: 1.000e-06
# It: 2240, Loss: 1.904e-02, Y0: 7.249, Time: 4.21, Learning Rate: 1.000e-06
# It: 2250, Loss: 2.202e-02, Y0: 7.248, Time: 4.59, Learning Rate: 1.000e-06
# It: 2260, Loss: 2.014e-02, Y0: 7.247, Time: 4.22, Learning Rate: 1.000e-06
# It: 2270, Loss: 2.184e-02, Y0: 7.248, Time: 4.49, Learning Rate: 1.000e-06
# It: 2280, Loss: 1.955e-02, Y0: 7.248, Time: 4.22, Learning Rate: 1.000e-06
# It: 2290, Loss: 2.050e-02, Y0: 7.248, Time: 4.25, Learning Rate: 1.000e-06
# It: 2300, Loss: 1.912e-02, Y0: 7.248, Time: 4.57, Learning Rate: 1.000e-06
# It: 2310, Loss: 3.088e-02, Y0: 7.251, Time: 4.22, Learning Rate: 1.000e-06
# It: 2320, Loss: 2.015e-02, Y0: 7.256, Time: 4.29, Learning Rate: 1.000e-06
# It: 2330, Loss: 3.383e-02, Y0: 7.256, Time: 4.51, Learning Rate: 1.000e-06
# It: 2340, Loss: 2.385e-02, Y0: 7.256, Time: 4.24, Learning Rate: 1.000e-06
# It: 2350, Loss: 1.917e-02, Y0: 7.255, Time: 4.58, Learning Rate: 1.000e-06
# It: 2360, Loss: 2.017e-02, Y0: 7.250, Time: 4.28, Learning Rate: 1.000e-06
# It: 2370, Loss: 2.315e-02, Y0: 7.250, Time: 4.26, Learning Rate: 1.000e-06
# It: 2380, Loss: 2.056e-02, Y0: 7.253, Time: 4.53, Learning Rate: 1.000e-06
# It: 2390, Loss: 2.019e-02, Y0: 7.251, Time: 4.24, Learning Rate: 1.000e-06
# It: 2400, Loss: 2.124e-02, Y0: 7.251, Time: 4.40, Learning Rate: 1.000e-06
# It: 2410, Loss: 2.015e-02, Y0: 7.254, Time: 4.32, Learning Rate: 1.000e-06
# It: 2420, Loss: 1.969e-02, Y0: 7.251, Time: 4.27, Learning Rate: 1.000e-06
# It: 2430, Loss: 2.085e-02, Y0: 7.252, Time: 4.62, Learning Rate: 1.000e-06
# It: 2440, Loss: 2.180e-02, Y0: 7.253, Time: 4.23, Learning Rate: 1.000e-06
# It: 2450, Loss: 2.231e-02, Y0: 7.257, Time: 4.21, Learning Rate: 1.000e-06
# It: 2460, Loss: 2.073e-02, Y0: 7.256, Time: 4.62, Learning Rate: 1.000e-06
# It: 2470, Loss: 2.047e-02, Y0: 7.255, Time: 4.20, Learning Rate: 1.000e-06
# It: 2480, Loss: 2.077e-02, Y0: 7.255, Time: 4.55, Learning Rate: 1.000e-06
# It: 2490, Loss: 2.492e-02, Y0: 7.255, Time: 4.23, Learning Rate: 1.000e-06
# It: 2500, Loss: 2.091e-02, Y0: 7.256, Time: 4.25, Learning Rate: 1.000e-06
# It: 2510, Loss: 2.246e-02, Y0: 7.256, Time: 4.58, Learning Rate: 1.000e-06
# It: 2520, Loss: 2.055e-02, Y0: 7.257, Time: 4.25, Learning Rate: 1.000e-06
# It: 2530, Loss: 1.903e-02, Y0: 7.256, Time: 4.27, Learning Rate: 1.000e-06
# It: 2540, Loss: 1.991e-02, Y0: 7.252, Time: 4.49, Learning Rate: 1.000e-06
# It: 2550, Loss: 2.127e-02, Y0: 7.250, Time: 4.26, Learning Rate: 1.000e-06
# It: 2560, Loss: 2.217e-02, Y0: 7.251, Time: 4.60, Learning Rate: 1.000e-06
# It: 2570, Loss: 2.008e-02, Y0: 7.251, Time: 4.26, Learning Rate: 1.000e-06
# It: 2580, Loss: 1.880e-02, Y0: 7.250, Time: 4.25, Learning Rate: 1.000e-06
# It: 2590, Loss: 2.064e-02, Y0: 7.249, Time: 4.56, Learning Rate: 1.000e-06
# It: 2600, Loss: 2.230e-02, Y0: 7.251, Time: 4.19, Learning Rate: 1.000e-06
# It: 2610, Loss: 2.149e-02, Y0: 7.247, Time: 4.43, Learning Rate: 1.000e-06
# It: 2620, Loss: 2.164e-02, Y0: 7.248, Time: 4.37, Learning Rate: 1.000e-06
# It: 2630, Loss: 2.385e-02, Y0: 7.250, Time: 4.21, Learning Rate: 1.000e-06
# It: 2640, Loss: 2.179e-02, Y0: 7.253, Time: 4.60, Learning Rate: 1.000e-06
# It: 2650, Loss: 2.022e-02, Y0: 7.253, Time: 4.23, Learning Rate: 1.000e-06
# It: 2660, Loss: 2.202e-02, Y0: 7.257, Time: 4.22, Learning Rate: 1.000e-06
# It: 2670, Loss: 1.912e-02, Y0: 7.254, Time: 4.57, Learning Rate: 1.000e-06
# It: 2680, Loss: 2.219e-02, Y0: 7.251, Time: 4.27, Learning Rate: 1.000e-06
# It: 2690, Loss: 2.049e-02, Y0: 7.243, Time: 4.48, Learning Rate: 1.000e-06
# It: 2700, Loss: 2.061e-02, Y0: 7.242, Time: 4.22, Learning Rate: 1.000e-06
# It: 2710, Loss: 2.039e-02, Y0: 7.245, Time: 4.19, Learning Rate: 1.000e-06
# It: 2720, Loss: 2.145e-02, Y0: 7.247, Time: 4.60, Learning Rate: 1.000e-06
# It: 2730, Loss: 1.986e-02, Y0: 7.254, Time: 4.24, Learning Rate: 1.000e-06
# It: 2740, Loss: 1.912e-02, Y0: 7.256, Time: 4.22, Learning Rate: 1.000e-06
# It: 2750, Loss: 1.947e-02, Y0: 7.254, Time: 4.51, Learning Rate: 1.000e-06
# It: 2760, Loss: 2.228e-02, Y0: 7.251, Time: 4.29, Learning Rate: 1.000e-06
# It: 2770, Loss: 2.484e-02, Y0: 7.249, Time: 4.52, Learning Rate: 1.000e-06
# It: 2780, Loss: 2.051e-02, Y0: 7.247, Time: 4.24, Learning Rate: 1.000e-06
# It: 2790, Loss: 2.532e-02, Y0: 7.243, Time: 4.24, Learning Rate: 1.000e-06
# It: 2800, Loss: 2.508e-02, Y0: 7.244, Time: 4.56, Learning Rate: 1.000e-06
# It: 2810, Loss: 2.213e-02, Y0: 7.246, Time: 4.21, Learning Rate: 1.000e-06
# It: 2820, Loss: 2.032e-02, Y0: 7.247, Time: 4.35, Learning Rate: 1.000e-06
# It: 2830, Loss: 1.920e-02, Y0: 7.248, Time: 4.40, Learning Rate: 1.000e-06
# It: 2840, Loss: 2.098e-02, Y0: 7.249, Time: 4.23, Learning Rate: 1.000e-06
# It: 2850, Loss: 2.110e-02, Y0: 7.250, Time: 4.57, Learning Rate: 1.000e-06
# It: 2860, Loss: 2.119e-02, Y0: 7.250, Time: 4.28, Learning Rate: 1.000e-06
# It: 2870, Loss: 2.013e-02, Y0: 7.248, Time: 4.24, Learning Rate: 1.000e-06
# It: 2880, Loss: 2.003e-02, Y0: 7.248, Time: 4.59, Learning Rate: 1.000e-06
# It: 2890, Loss: 2.156e-02, Y0: 7.250, Time: 4.24, Learning Rate: 1.000e-06
# It: 2900, Loss: 2.037e-02, Y0: 7.252, Time: 4.43, Learning Rate: 1.000e-06
# It: 2910, Loss: 2.190e-02, Y0: 7.252, Time: 4.29, Learning Rate: 1.000e-06
# It: 2920, Loss: 2.131e-02, Y0: 7.253, Time: 4.22, Learning Rate: 1.000e-06
# It: 2930, Loss: 1.983e-02, Y0: 7.253, Time: 4.55, Learning Rate: 1.000e-06
# It: 2940, Loss: 2.303e-02, Y0: 7.252, Time: 4.23, Learning Rate: 1.000e-06
# It: 2950, Loss: 2.132e-02, Y0: 7.247, Time: 4.20, Learning Rate: 1.000e-06
# It: 2960, Loss: 2.337e-02, Y0: 7.248, Time: 4.55, Learning Rate: 1.000e-06
# It: 2970, Loss: 2.145e-02, Y0: 7.254, Time: 4.24, Learning Rate: 1.000e-06
# It: 2980, Loss: 2.138e-02, Y0: 7.256, Time: 4.61, Learning Rate: 1.000e-06
# It: 2990, Loss: 2.066e-02, Y0: 7.257, Time: 4.23, Learning Rate: 1.000e-06
#
# Predicted Y0: 7.2536
# Exact Y0:     7.2225
